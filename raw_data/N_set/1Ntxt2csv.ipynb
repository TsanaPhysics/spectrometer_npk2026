# %% [markdown]
# แสดงชื่อ ขนาดและจำนวนไฟล์  ".txt "ทั้งหมดในทุกโฟลเดอร์ย่อยของโฟลเดอร์  N พร้อมแสดงโฟเดอร์ย่อยที่จัดเก็บไฟล์

# %%
import os

def scan_txt_files(folder_path):
    for root, _, files in os.walk(folder_path):
        for file_name in files:
            if file_name.endswith(".txt"):
                file_path = os.path.join(root, file_name)
                print("-" * 50)
                # เปิดไฟล์ .txt เพื่ออ่านข้อมูล
                with open(file_path, "r", encoding="utf-8") as file:
                    lines = file.readlines()
                    
                    # แสดงข้อมูลที่คุณต้องการ
                    num_rows = len(lines)
                    num_columns = len(lines[0].split()) if num_rows > 0 else 0
                    header = lines[0].strip() if num_rows > 0 else None
                    
                    print(f"ไฟล์: {file_name}")
                    if header:
                        print(f"หัวเรื่อง: {header}")
                    print(f"จำนวนแถว: {num_rows}")
                    print(f"จำนวนคอลัมน์: {num_columns}")
                    print(f"ที่อยู่ของไฟล์: {file_path}")  # เพิ่มแถวนี้เพื่อแสดงที่อยู่ของไฟล์
                    print("\n")

# ระบุโฟลเดอร์หลักที่คุณต้องการสแกน
main_folder = "N"
scan_txt_files(main_folder)
# Out:
# --------------------------------------------------
# ไฟล์: N8_W.txt
# หัวเรื่อง: N_8_WaterPure water tube 5ml   No reagent :08/10/2023,17:27:32
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N8_W.txt
#
#
# --------------------------------------------------
# ไฟล์: N10_W.txt
# หัวเรื่อง: N_10_WaterPure water tube 5ml   No reagent :08/10/2023,18:06:52
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N10_W.txt
#
#
# --------------------------------------------------
# ไฟล์: N80_NoR.txt
# หัวเรื่อง: N_80_No_RNH4CL 80mg/L tube  5ml  No Reagent :08/10/2023,21:54:35
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N80_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N20_NoR.txt
# หัวเรื่อง: N_20_No_RNH4CL 20mg/L tube  5ml  No Reagent :08/10/2023,19:58:22
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N20_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N4_NoR.txt
# หัวเรื่อง: N_4_No_RNH4CL 4mg/L tube  5ml  No Reagent :08/10/2023,16:26:19
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N4_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N40_NoR.txt
# หัวเรื่อง: N_40_No_RNH4CL 40mg/L tube  5ml  No Reagent :08/10/2023,20:37:42
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N40_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N6_NoR.txt
# หัวเรื่อง: N_6_No_RNH4CL 6mg/L tube  5ml  No Reagent :08/10/2023,17:04:46
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N6_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N100_NoR.txt
# หัวเรื่อง: N_100_No_RNH4CL 1000mg/L tube  5ml  No Reagent :08/10/2023,22:34:14
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N100_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N100_W.txt
# หัวเรื่อง: N_100_WaterPure water tube 5ml   No reagent :08/10/2023,22:17:56
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N100_W.txt
#
#
# --------------------------------------------------
# ไฟล์: N10_NoR.txt
# หัวเรื่อง: N_10_No_RNH4CL 10mg/L tube  5ml  No Reagent :08/10/2023,18:23:36
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N10_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N2_NoR.txt
# หัวเรื่อง: N_2n_No_RNH4CL 2mg/L tube  5ml  No Reagent :08/10/2023,23:58:13
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N2_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N20_W.txt
# หัวเรื่อง: N_20_WaterPure water tube 5ml   No reagent :08/10/2023,19:42:16
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N20_W.txt
#
#
# --------------------------------------------------
# ไฟล์: N2_W.txt
# หัวเรื่อง: N_2n_WaterPure water tube 5ml   No reagent :08/10/2023,23:42:37
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N2_W.txt
#
#
# --------------------------------------------------
# ไฟล์: N60_W.txt
# หัวเรื่อง: N_60_WaterPure water tube 5ml   No reagent :08/10/2023,21:00:16
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N60_W.txt
#
#
# --------------------------------------------------
# ไฟล์: N8_NoR.txt
# หัวเรื่อง: N_8_No_RNH4CL 8mg/L tube  5ml  No Reagent :08/10/2023,17:44:10
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N8_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N60_NoR.txt
# หัวเรื่อง: N_60_No_RNH4CL 60mg/L tube  5ml  No Reagent :08/10/2023,21:16:03
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N60_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: N40_W.txt
# หัวเรื่อง: N_40_WaterPure water tube 5ml   No reagent :08/10/2023,20:21:57
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N40_W.txt
#
#
# --------------------------------------------------
# ไฟล์: N80_W.txt
# หัวเรื่อง: N_80_WaterPure water tube 5ml   No reagent :08/10/2023,21:38:44
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N80_W.txt
#
#
# --------------------------------------------------
# ไฟล์: N6_W.txt
# หัวเรื่อง: N_6_WaterPure water tube 5ml   No reagent :08/10/2023,16:48:46
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N6_W.txt
#
#
# --------------------------------------------------
# ไฟล์: N4_W.txt
# หัวเรื่อง: N_4_WaterPure water tube 5ml   No reagent :08/10/2023,16:10:06
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: N/N4_W.txt

# %% [markdown]
# แปลงไฟล์ txt ในแต่ละโฟลเดอร์  เป็น cvs   และบันทึกไว้ในโฟลเดอร์  NdatasetCSV

# %%
import os
import csv

# ระบุโฟลเดอร์หลัก N_raw
main_folder = "N"

# ระบุโฟลเดอร์ที่จะบันทึกไฟล์ .csv
output_folder_path = "NdatasetCSV"

# ตรวจสอบว่าโฟลเดอร์ output_folder_path มีอยู่หรือไม่ และสร้างถ้าไม่มี
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# วนลูปผ่านโฟลเดอร์และไฟล์ทั้งหมดในโฟลเดอร์หลัก
for root, _, files in os.walk(main_folder):
    for filename in files:
        if filename.endswith(".txt"):
            # รับที่อยู่ของไฟล์ .txt
            input_file_path = os.path.join(root, filename)
            
            # สร้างชื่อไฟล์ .csv ใหม่โดยนำชื่อไฟล์เดิมมาใช้
            output_file_path = os.path.join(output_folder_path, os.path.splitext(filename)[0] + ".csv")

            # เปิดไฟล์ .txt สำหรับอ่าน
            with open(input_file_path, "r") as txt_file:
                # อ่านข้อมูลทั้งหมดจากไฟล์ .txt
                lines = txt_file.readlines()

            # ตรวจสอบว่ามีข้อมูลในไฟล์หรือไม่
            if len(lines) > 0:
                # ลบข้อมูลในแถวแรก
                lines = lines[1:]

                # เปิดไฟล์ .csv สำหรับเขียน
                with open(output_file_path, "w", newline='') as csv_file:
                    # สร้างอ็อบเจ็กต์ writer สำหรับเขียนข้อมูล CSV
                    csv_writer = csv.writer(csv_file)

                    # เขียนข้อมูลลงในไฟล์ .csv
                    for line in lines:
                        # แบ่งข้อมูลในแต่ละบรรทัดด้วยเครื่องหมาย "," และลบช่องว่างด้านหน้าและหลัง
                        row_data = line.strip().split(",")
                        csv_writer.writerow(row_data)

            print(f"แปลงไฟล์ '{filename}' และบันทึกเป็น '{os.path.basename(output_file_path)}'")

print("เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ NdatasetCSV")
# Out:
# แปลงไฟล์ 'N8_W.txt' และบันทึกเป็น 'N8_W.csv'
# แปลงไฟล์ 'N10_W.txt' และบันทึกเป็น 'N10_W.csv'
# แปลงไฟล์ 'N80_NoR.txt' และบันทึกเป็น 'N80_NoR.csv'
# แปลงไฟล์ 'N20_NoR.txt' และบันทึกเป็น 'N20_NoR.csv'
# แปลงไฟล์ 'N4_NoR.txt' และบันทึกเป็น 'N4_NoR.csv'
# แปลงไฟล์ 'N40_NoR.txt' และบันทึกเป็น 'N40_NoR.csv'
# แปลงไฟล์ 'N6_NoR.txt' และบันทึกเป็น 'N6_NoR.csv'
# แปลงไฟล์ 'N100_NoR.txt' และบันทึกเป็น 'N100_NoR.csv'
# แปลงไฟล์ 'N100_W.txt' และบันทึกเป็น 'N100_W.csv'
# แปลงไฟล์ 'N10_NoR.txt' และบันทึกเป็น 'N10_NoR.csv'
# แปลงไฟล์ 'N2_NoR.txt' และบันทึกเป็น 'N2_NoR.csv'
# แปลงไฟล์ 'N20_W.txt' และบันทึกเป็น 'N20_W.csv'
# แปลงไฟล์ 'N2_W.txt' และบันทึกเป็น 'N2_W.csv'
# แปลงไฟล์ 'N60_W.txt' และบันทึกเป็น 'N60_W.csv'
# แปลงไฟล์ 'N8_NoR.txt' และบันทึกเป็น 'N8_NoR.csv'
# แปลงไฟล์ 'N60_NoR.txt' และบันทึกเป็น 'N60_NoR.csv'
# แปลงไฟล์ 'N40_W.txt' และบันทึกเป็น 'N40_W.csv'
# แปลงไฟล์ 'N80_W.txt' และบันทึกเป็น 'N80_W.csv'
# แปลงไฟล์ 'N6_W.txt' และบันทึกเป็น 'N6_W.csv'
# แปลงไฟล์ 'N4_W.txt' และบันทึกเป็น 'N4_W.csv'
# เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ NdatasetCSV

# %% [markdown]
# เลื่อนข้อมูลในคอลัมน์ 'Intensity' ขึ้นหนึ่งแถว และลบแถวที่มีคอลัมน์ 'Order' เท่ากับ 0 และคอลัมน์ 'Color' เท่ากับ 'Black' หลังจากนั้นบันทึกข้อมูลที่แก้ไขแล้วในไฟล์ .csv

# %%
import os
import pandas as pd

# Define the column names
column_names = ["No.", "Order", "Color", "Intensity"]

# Specify the folder path
folder_path = "NdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file with the specified column names
    df = pd.read_csv(file_path, names=column_names)

    # Shift the data in the 'Intensity' column up by one row
    df['Intensity'] = df['Intensity'].shift(-1)

    # Drop rows where 'Order' is equal to 0 and 'Color' is equal to 'Black'
    df = df[(df['Order'] != 0) | (df['Color'] != 'Black')]

    # Specify the original file path and save the modified DataFrame
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'NdatasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to NdatasetCSV/N2_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N10_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N20_W.csv
# Modified DataFrame saved to NdatasetCSV/N2_W.csv
# Modified DataFrame saved to NdatasetCSV/N60_W.csv
# Modified DataFrame saved to NdatasetCSV/N8_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N4_W.csv
# Modified DataFrame saved to NdatasetCSV/N60_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N40_W.csv
# Modified DataFrame saved to NdatasetCSV/N80_W.csv
# Modified DataFrame saved to NdatasetCSV/N6_W.csv
# Modified DataFrame saved to NdatasetCSV/N10_W.csv
# Modified DataFrame saved to NdatasetCSV/N8_W.csv
# Modified DataFrame saved to NdatasetCSV/N20_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N4_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N80_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N40_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N6_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N100_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N100_W.csv
# All CSV files in the 'NdatasetCSV' folder have been processed.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "NdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Remove the last row from the DataFrame
    df = df.iloc[:-1]

    # Save the modified DataFrame back to the same file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Last row removed and file '{csv_file}' saved with the same name.")

print("All CSV files in the 'NdatasetCSV' folder have had their last row removed and saved with the same name.")
# Out:
# Last row removed and file 'N2_NoR.csv' saved with the same name.
# Last row removed and file 'N10_NoR.csv' saved with the same name.
# Last row removed and file 'N20_W.csv' saved with the same name.
# Last row removed and file 'N2_W.csv' saved with the same name.
# Last row removed and file 'N60_W.csv' saved with the same name.
# Last row removed and file 'N8_NoR.csv' saved with the same name.
# Last row removed and file 'N4_W.csv' saved with the same name.
# Last row removed and file 'N60_NoR.csv' saved with the same name.
# Last row removed and file 'N40_W.csv' saved with the same name.
# Last row removed and file 'N80_W.csv' saved with the same name.
# Last row removed and file 'N6_W.csv' saved with the same name.
# Last row removed and file 'N10_W.csv' saved with the same name.
# Last row removed and file 'N8_W.csv' saved with the same name.
# Last row removed and file 'N20_NoR.csv' saved with the same name.
# Last row removed and file 'N4_NoR.csv' saved with the same name.
# Last row removed and file 'N80_NoR.csv' saved with the same name.
# Last row removed and file 'N40_NoR.csv' saved with the same name.
# Last row removed and file 'N6_NoR.csv' saved with the same name.
# Last row removed and file 'N100_NoR.csv' saved with the same name.
# Last row removed and file 'N100_W.csv' saved with the same name.
# All CSV files in the 'NdatasetCSV' folder have had their last row removed and saved with the same name.

# %%
import os

# ระบุโฟลเดอร์หลักที่คุณต้องการทำการสแกน (เช่น 'N_raw')
main_folder = 'N'

# ฟังก์ชันสำหรับแสดงข้อมูลจากไฟล์ .txt และเพิ่มบรรทัดว่างหลังจากแต่ละไฟล์
def display_txt_file_contents(root, files):
    for file in files:
        if file.endswith(".txt"):
            file_path = os.path.join(root, file)
            print(f"ไฟล์: {file_path}")
            with open(file_path, 'r', encoding='utf-8') as txt_file:
                lines = txt_file.readlines()
                for line in lines:
                    print(line.strip())  # แสดงข้อมูลของแต่ละไลน์ในไฟล์
            print("\n" + "=" * 50 + "\n")  # เพิ่มบรรทัดว่างหลังจากแต่ละไฟล์

# เรียกใช้ฟังก์ชันเพื่อทำงาน
if os.path.exists(main_folder):
    for root, dirs, files in os.walk(main_folder):
        display_txt_file_contents(root, files)
else:
    print(f"โฟลเดอร์ '{main_folder}' ไม่พบ")
# Out:
# ไฟล์: N/N8_W.txt
# N_8_WaterPure water tube 5ml   No reagent :08/10/2023,17:27:32
# 1,1,White,4
# 2,2,White,948
# 3,3,White,943
# 4,4,White,936
# 5,5,White,944
# 6,6,White,939
# 7,7,White,947
# 8,8,White,940
# 9,9,White,940
# 10,10,White,935
# 11,11,White,939
# 12,12,White,941
# 13,13,White,947
# 14,14,White,946
# 15,15,White,940
# 16,16,White,946
# 17,17,White,948
# 18,18,White,947
# 19,19,White,943
# 20,20,White,938
# 21,21,White,943
# 22,22,White,939
# 23,23,White,944
# 24,24,White,943
# 25,25,White,942
# 26,26,White,942
# 27,27,White,941
# 28,28,White,939
# 29,29,White,947
# 30,1,Red,941
# 31,2,Red,340
# 32,3,Red,340
# 33,4,Red,337
# 34,5,Red,342
# 35,6,Red,336
# 36,7,Red,343
# 37,8,Red,341
# 38,9,Red,341
# 39,10,Red,337
# 40,11,Red,341
# 41,12,Red,342
# 42,13,Red,342
# 43,14,Red,339
# 44,15,Red,338
# 45,16,Red,341
# 46,17,Red,337
# 47,18,Red,341
# 48,19,Red,342
# 49,20,Red,337
# 50,21,Red,339
# 51,22,Red,339
# 52,23,Red,339
# 53,24,Red,340
# 54,25,Red,336
# 55,26,Red,340
# 56,27,Red,339
# 57,28,Red,343
# 58,29,Red,337
# 59,30,Red,340
# 60,1,Green,340
# 61,2,Green,417
# 62,3,Green,411
# 63,4,Green,414
# 64,5,Green,421
# 65,6,Green,422
# 66,7,Green,420
# 67,8,Green,419
# 68,9,Green,423
# 69,10,Green,423
# 70,11,Green,414
# 71,12,Green,424
# 72,13,Green,421
# 73,14,Green,414
# 74,15,Green,417
# 75,16,Green,422
# 76,17,Green,418
# 77,18,Green,422
# 78,19,Green,417
# 79,20,Green,418
# 80,21,Green,418
# 81,22,Green,417
# 82,23,Green,421
# 83,24,Green,417
# 84,25,Green,417
# 85,26,Green,417
# 86,27,Green,420
# 87,28,Green,416
# 88,29,Green,414
# 89,1,Blue,416
# 90,2,Blue,274
# 91,3,Blue,273
# 92,4,Blue,267
# 93,5,Blue,268
# 94,6,Blue,273
# 95,7,Blue,270
# 96,8,Blue,272
# 97,9,Blue,274
# 98,10,Blue,267
# 99,11,Blue,271
# 100,12,Blue,271
# 101,13,Blue,270
# 102,14,Blue,268
# 103,15,Blue,268
# 104,16,Blue,268
# 105,17,Blue,267
# 106,18,Blue,267
# 107,19,Blue,271
# 108,20,Blue,270
# 109,21,Blue,273
# 110,22,Blue,271
# 111,23,Blue,271
# 112,24,Blue,275
# 113,25,Blue,269
# 114,26,Blue,267
# 115,27,Blue,269
# 116,28,Blue,270
# 117,29,Blue,269
# 118,30,Blue,266
# 119,1,Black,269
# 120,2,Black,4
# 121,3,Black,3
# 122,4,Black,3
# 123,5,Black,3
# 124,6,Black,4
# 125,7,Black,4
# 126,8,Black,4
# 127,9,Black,3
# 128,10,Black,4
# 129,11,Black,3
# 130,12,Black,3
# 131,13,Black,3
# 132,14,Black,3
# 133,15,Black,4
# 134,16,Black,3
# 135,17,Black,3
# 136,18,Black,3
# 137,19,Black,3
# 138,20,Black,4
# 139,21,Black,3
# 140,22,Black,3
# 141,23,Black,3
# 142,24,Black,3
# 143,25,Black,3
# 144,26,Black,4
# 145,27,Black,4
# 146,28,Black,4
# 147,29,Black,4
# 148,0,Black,4
# 149,0,Black,4
# 150,0,Black,4
# 151,0,Black,4
# 152,0,Black,4
# 153,0,Black,4
# 154,0,Black,4
# 155,0,Black,3
# 156,0,Black,3
# 157,0,Black,3
# 158,0,Black,4
# 159,0,Black,3
# 160,0,Black,4
# 161,0,Black,3
# 162,0,Black,4
# 163,0,Black,3
# 164,0,Black,3
# 165,0,Black,3
# 166,0,Black,3
# 167,0,Black,3
# 168,0,Black,3
# 169,0,Black,4
# 170,0,Black,4
# 171,0,Black,3
# 172,0,Black,4
# 173,0,Black,3
# 174,0,Black,3
# 175,0,Black,3
# 176,0,Black,3
# 177,0,Black,4
# 178,1,White,3
# 179,2,White,942
# 180,3,White,945
# 181,4,White,947
# 182,5,White,938
# 183,6,White,943
# 184,7,White,940
# 185,8,White,945
# 186,9,White,941
# 187,10,White,942
# 188,11,White,943
# 189,12,White,944
# 190,13,White,944
# 191,14,White,941
# 192,15,White,937
# 193,16,White,945
# 194,17,White,946
# 195,18,White,944
# 196,19,White,944
# 197,20,White,946
# 198,21,White,944
# 199,22,White,946
# 200,23,White,941
# 201,24,White,936
# 202,25,White,941
# 203,26,White,944
# 204,27,White,944
# 205,28,White,939
# 206,29,White,939
# 207,1,Red,940
# 208,2,Red,337
# 209,3,Red,337
# 210,4,Red,340
# 211,5,Red,343
# 212,6,Red,341
# 213,7,Red,343
# 214,8,Red,337
# 215,9,Red,341
# 216,10,Red,336
# 217,11,Red,335
# 218,12,Red,339
# 219,13,Red,340
# 220,14,Red,339
# 221,15,Red,340
# 222,16,Red,344
# 223,17,Red,335
# 224,18,Red,335
# 225,19,Red,344
# 226,20,Red,341
# 227,21,Red,336
# 228,22,Red,336
# 229,23,Red,336
# 230,24,Red,337
# 231,25,Red,337
# 232,26,Red,341
# 233,27,Red,335
# 234,28,Red,336
# 235,29,Red,335
# 236,30,Red,339
# 237,1,Green,339
# 238,2,Green,416
# 239,3,Green,421
# 240,4,Green,422
# 241,5,Green,418
# 242,6,Green,418
# 243,7,Green,418
# 244,8,Green,416
# 245,9,Green,419
# 246,10,Green,413
# 247,11,Green,420
# 248,12,Green,421
# 249,13,Green,421
# 250,14,Green,423
# 251,15,Green,418
# 252,16,Green,419
# 253,17,Green,419
# 254,18,Green,416
# 255,19,Green,414
# 256,20,Green,417
# 257,21,Green,420
# 258,22,Green,409
# 259,23,Green,418
# 260,24,Green,420
# 261,25,Green,415
# 262,26,Green,421
# 263,27,Green,414
# 264,28,Green,415
# 265,29,Green,419
# 266,1,Blue,419
# 267,2,Blue,272
# 268,3,Blue,268
# 269,4,Blue,267
# 270,5,Blue,270
# 271,6,Blue,271
# 272,7,Blue,274
# 273,8,Blue,269
# 274,9,Blue,267
# 275,10,Blue,267
# 276,11,Blue,271
# 277,12,Blue,269
# 278,13,Blue,271
# 279,14,Blue,271
# 280,15,Blue,267
# 281,16,Blue,270
# 282,17,Blue,269
# 283,18,Blue,272
# 284,19,Blue,274
# 285,20,Blue,274
# 286,21,Blue,274
# 287,22,Blue,272
# 288,23,Blue,269
# 289,24,Blue,270
# 290,25,Blue,265
# 291,26,Blue,265
# 292,27,Blue,271
# 293,28,Blue,270
# 294,29,Blue,264
# 295,30,Blue,273
# 296,1,Black,269
# 297,2,Black,4
# 298,3,Black,3
# 299,4,Black,4
# 300,5,Black,3
# 301,6,Black,4
# 302,7,Black,3
# 303,8,Black,4
# 304,9,Black,4
# 305,10,Black,4
# 306,11,Black,4
# 307,12,Black,4
# 308,13,Black,4
# 309,14,Black,4
# 310,15,Black,3
# 311,16,Black,3
# 312,17,Black,4
# 313,18,Black,4
# 314,19,Black,3
# 315,20,Black,3
# 316,21,Black,4
# 317,22,Black,3
# 318,23,Black,4
# 319,24,Black,3
# 320,25,Black,3
# 321,26,Black,3
# 322,27,Black,3
# 323,28,Black,3
# 324,29,Black,4
# 325,30,Black,3
# 326,0,Black,3
# 327,0,Black,3
# 328,0,Black,4
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,4
# 332,0,Black,3
# 333,0,Black,3
# 334,0,Black,4
# 335,0,Black,4
# 336,0,Black,3
# 337,0,Black,5
# 338,0,Black,3
# 339,0,Black,4
# 340,0,Black,4
# 341,0,Black,3
# 342,0,Black,4
# 343,0,Black,3
# 344,0,Black,4
# 345,0,Black,4
# 346,0,Black,4
# 347,0,Black,4
# 348,0,Black,4
# 349,0,Black,3
# 350,0,Black,4
# 351,0,Black,3
# 352,0,Black,3
# 353,0,Black,3
# 354,0,Black,4
# 355,1,White,4
# 356,2,White,943
# 357,3,White,944
# 358,4,White,944
# 359,5,White,946
# 360,6,White,948
# 361,7,White,940
# 362,8,White,941
# 363,9,White,944
# 364,10,White,942
# 365,11,White,940
# 366,12,White,942
# 367,13,White,941
# 368,14,White,944
# 369,15,White,936
# 370,16,White,947
# 371,17,White,945
# 372,18,White,939
# 373,19,White,947
# 374,20,White,946
# 375,21,White,940
# 376,22,White,945
# 377,23,White,940
# 378,24,White,945
# 379,25,White,947
# 380,26,White,944
# 381,27,White,941
# 382,28,White,942
# 383,29,White,949
# 384,30,White,939
# 385,1,Red,938
# 386,2,Red,338
# 387,3,Red,343
# 388,4,Red,337
# 389,5,Red,340
# 390,6,Red,337
# 391,7,Red,340
# 392,8,Red,340
# 393,9,Red,338
# 394,10,Red,337
# 395,11,Red,337
# 396,12,Red,337
# 397,13,Red,335
# 398,14,Red,337
# 399,15,Red,335
# 400,16,Red,336
# 401,17,Red,340
# 402,18,Red,342
# 403,19,Red,342
# 404,20,Red,336
# 405,21,Red,338
# 406,22,Red,332
# 407,23,Red,339
# 408,24,Red,341
# 409,25,Red,336
# 410,26,Red,340
# 411,27,Red,338
# 412,28,Red,334
# 413,29,Red,337
# 414,1,Green,339
# 415,2,Green,419
# 416,3,Green,415
# 417,4,Green,414
# 418,5,Green,419
# 419,6,Green,416
# 420,7,Green,418
# 421,8,Green,410
# 422,9,Green,424
# 423,10,Green,421
# 424,11,Green,424
# 425,12,Green,420
# 426,13,Green,418
# 427,14,Green,418
# 428,15,Green,415
# 429,16,Green,420
# 430,17,Green,418
# 431,18,Green,421
# 432,19,Green,419
# 433,20,Green,413
# 434,21,Green,424
# 435,22,Green,424
# 436,23,Green,420
# 437,24,Green,419
# 438,25,Green,421
# 439,26,Green,419
# 440,27,Green,417
# 441,28,Green,420
# 442,29,Green,424
# 443,30,Green,413
# 444,1,Blue,422
# 445,2,Blue,269
# 446,3,Blue,265
# 447,4,Blue,268
# 448,5,Blue,273
# 449,6,Blue,267
# 450,7,Blue,270
# 451,8,Blue,271
# 452,9,Blue,270
# 453,10,Blue,274
# 454,11,Blue,269
# 455,12,Blue,269
# 456,13,Blue,274
# 457,14,Blue,274
# 458,15,Blue,270
# 459,16,Blue,268
# 460,17,Blue,268
# 461,18,Blue,269
# 462,19,Blue,273
# 463,20,Blue,274
# 464,21,Blue,269
# 465,22,Blue,268
# 466,23,Blue,271
# 467,24,Blue,270
# 468,25,Blue,272
# 469,26,Blue,273
# 470,27,Blue,272
# 471,28,Blue,269
# 472,29,Blue,265
# 473,1,Black,271
# 474,2,Black,4
# 475,3,Black,4
# 476,4,Black,3
# 477,5,Black,3
# 478,6,Black,5
# 479,7,Black,3
# 480,8,Black,3
# 481,9,Black,4
# 482,10,Black,3
# 483,11,Black,3
# 484,12,Black,4
# 485,13,Black,3
# 486,14,Black,4
# 487,15,Black,4
# 488,16,Black,4
# 489,17,Black,4
# 490,18,Black,3
# 491,19,Black,3
# 492,20,Black,4
# 493,21,Black,4
# 494,22,Black,3
# 495,23,Black,3
# 496,24,Black,4
# 497,25,Black,3
# 498,26,Black,3
# 499,27,Black,4
# 500,28,Black,4
# 501,29,Black,4
# 502,30,Black,4
# 503,0,Black,3
# 504,0,Black,3
# 505,0,Black,4
# 506,0,Black,3
# 507,0,Black,4
# 508,0,Black,4
# 509,0,Black,4
# 510,0,Black,4
# 511,0,Black,4
# 512,0,Black,3
# 513,0,Black,4
# 514,0,Black,4
# 515,0,Black,4
# 516,0,Black,3
# 517,0,Black,4
# 518,0,Black,3
# 519,0,Black,4
# 520,0,Black,4
# 521,0,Black,4
# 522,0,Black,3
# 523,0,Black,3
# 524,0,Black,4
# 525,0,Black,3
# 526,0,Black,4
# 527,0,Black,4
# 528,0,Black,3
# 529,0,Black,3
# 530,0,Black,3
# 531,0,Black,4
# 532,1,White,3
# 533,2,White,944
# 534,3,White,944
# 535,4,White,941
# 536,5,White,943
# 537,6,White,948
# 538,7,White,946
# 539,8,White,938
# 540,9,White,942
# 541,10,White,941
# 542,11,White,941
# 543,12,White,941
# 544,13,White,941
# 545,14,White,935
# 546,15,White,940
# 547,16,White,939
# 548,17,White,946
# 549,18,White,934
# 550,19,White,943
# 551,20,White,945
# 552,21,White,941
# 553,22,White,940
# 554,23,White,940
# 555,24,White,941
# 556,25,White,947
# 557,26,White,944
# 558,27,White,944
# 559,28,White,944
# 560,29,White,942
# 561,30,White,942
# 562,1,Red,946
# 563,2,Red,342
# 564,3,Red,337
# 565,4,Red,343
# 566,5,Red,342
# 567,6,Red,336
# 568,7,Red,337
# 569,8,Red,339
# 570,9,Red,342
# 571,10,Red,338
# 572,11,Red,338
# 573,12,Red,338
# 574,13,Red,339
# 575,14,Red,338
# 576,15,Red,338
# 577,16,Red,342
# 578,17,Red,340
# 579,18,Red,337
# 580,19,Red,342
# 581,20,Red,340
# 582,21,Red,335
# 583,22,Red,335
# 584,23,Red,332
# 585,24,Red,333
# 586,25,Red,337
# 587,26,Red,341
# 588,27,Red,340
# 589,28,Red,339
# 590,29,Red,333
# 591,1,Green,333
# 592,2,Green,422
# 593,3,Green,422
# 594,4,Green,421
# 595,5,Green,417
# 596,6,Green,418
# 597,7,Green,420
# 598,8,Green,419
# 599,9,Green,420
# 600,10,Green,422
# 601,11,Green,412
# 602,12,Green,419
# 603,13,Green,418
# 604,14,Green,417
# 605,15,Green,422
# 606,16,Green,420
# 607,17,Green,420
# 608,18,Green,420
# 609,19,Green,415
# 610,20,Green,422
# 611,21,Green,422
# 612,22,Green,421
# 613,23,Green,417
# 614,24,Green,412
# 615,25,Green,418
# 616,26,Green,420
# 617,27,Green,422
# 618,28,Green,412
# 619,29,Green,416
# 620,30,Green,415
# 621,1,Blue,420
# 622,2,Blue,270
# 623,3,Blue,273
# 624,4,Blue,272
# 625,5,Blue,272
# 626,6,Blue,265
# 627,7,Blue,267
# 628,8,Blue,270
# 629,9,Blue,273
# 630,10,Blue,274
# 631,11,Blue,271
# 632,12,Blue,267
# 633,13,Blue,269
# 634,14,Blue,274
# 635,15,Blue,272
# 636,16,Blue,272
# 637,17,Blue,272
# 638,18,Blue,269
# 639,19,Blue,270
# 640,20,Blue,266
# 641,21,Blue,272
# 642,22,Blue,267
# 643,23,Blue,267
# 644,24,Blue,270
# 645,25,Blue,274
# 646,26,Blue,262
# 647,27,Blue,270
# 648,28,Blue,269
# 649,29,Blue,272
# 650,1,Black,271
# 651,2,Black,3
# 652,3,Black,4
# 653,4,Black,4
# 654,5,Black,3
# 655,6,Black,4
# 656,7,Black,5
# 657,8,Black,4
# 658,9,Black,5
# 659,10,Black,3
# 660,11,Black,4
# 661,12,Black,4
# 662,13,Black,4
# 663,14,Black,4
# 664,15,Black,4
# 665,16,Black,3
# 666,17,Black,4
# 667,18,Black,4
# 668,19,Black,3
# 669,20,Black,3
# 670,21,Black,4
# 671,22,Black,4
# 672,23,Black,3
# 673,24,Black,3
# 674,25,Black,3
# 675,26,Black,4
# 676,27,Black,3
# 677,28,Black,4
# 678,29,Black,3
# 679,30,Black,3
# 680,0,Black,4
#
# ==================================================
#
# ไฟล์: N/N10_W.txt
# N_10_WaterPure water tube 5ml   No reagent :08/10/2023,18:06:52
# 1,1,White,3
# 2,2,White,763
# 3,3,White,758
# 4,4,White,764
# 5,5,White,764
# 6,6,White,769
# 7,7,White,763
# 8,8,White,762
# 9,9,White,762
# 10,10,White,759
# 11,11,White,770
# 12,12,White,767
# 13,13,White,762
# 14,14,White,762
# 15,15,White,758
# 16,16,White,766
# 17,17,White,762
# 18,18,White,765
# 19,19,White,767
# 20,20,White,769
# 21,21,White,772
# 22,22,White,768
# 23,23,White,765
# 24,24,White,764
# 25,25,White,770
# 26,26,White,770
# 27,27,White,765
# 28,28,White,765
# 29,29,White,772
# 30,1,Red,773
# 31,2,Red,311
# 32,3,Red,308
# 33,4,Red,311
# 34,5,Red,308
# 35,6,Red,306
# 36,7,Red,308
# 37,8,Red,310
# 38,9,Red,307
# 39,10,Red,306
# 40,11,Red,314
# 41,12,Red,307
# 42,13,Red,308
# 43,14,Red,310
# 44,15,Red,305
# 45,16,Red,309
# 46,17,Red,310
# 47,18,Red,308
# 48,19,Red,313
# 49,20,Red,306
# 50,21,Red,307
# 51,22,Red,307
# 52,23,Red,307
# 53,24,Red,310
# 54,25,Red,304
# 55,26,Red,308
# 56,27,Red,312
# 57,28,Red,311
# 58,29,Red,310
# 59,30,Red,308
# 60,1,Green,310
# 61,2,Green,286
# 62,3,Green,297
# 63,4,Green,292
# 64,5,Green,289
# 65,6,Green,289
# 66,7,Green,289
# 67,8,Green,292
# 68,9,Green,290
# 69,10,Green,290
# 70,11,Green,287
# 71,12,Green,285
# 72,13,Green,290
# 73,14,Green,289
# 74,15,Green,290
# 75,16,Green,302
# 76,17,Green,305
# 77,18,Green,301
# 78,19,Green,302
# 79,20,Green,306
# 80,21,Green,297
# 81,22,Green,303
# 82,23,Green,308
# 83,24,Green,304
# 84,25,Green,303
# 85,26,Green,300
# 86,27,Green,304
# 87,28,Green,301
# 88,29,Green,299
# 89,1,Blue,301
# 90,2,Blue,196
# 91,3,Blue,196
# 92,4,Blue,195
# 93,5,Blue,195
# 94,6,Blue,196
# 95,7,Blue,191
# 96,8,Blue,191
# 97,9,Blue,195
# 98,10,Blue,194
# 99,11,Blue,191
# 100,12,Blue,193
# 101,13,Blue,191
# 102,14,Blue,193
# 103,15,Blue,192
# 104,16,Blue,194
# 105,17,Blue,196
# 106,18,Blue,193
# 107,19,Blue,190
# 108,20,Blue,196
# 109,21,Blue,192
# 110,22,Blue,194
# 111,23,Blue,194
# 112,24,Blue,193
# 113,25,Blue,195
# 114,26,Blue,191
# 115,27,Blue,199
# 116,28,Blue,198
# 117,29,Blue,195
# 118,1,Black,192
# 119,2,Black,3
# 120,3,Black,3
# 121,4,Black,3
# 122,5,Black,4
# 123,6,Black,3
# 124,7,Black,3
# 125,8,Black,3
# 126,9,Black,4
# 127,10,Black,3
# 128,11,Black,3
# 129,12,Black,3
# 130,13,Black,3
# 131,14,Black,4
# 132,15,Black,3
# 133,16,Black,4
# 134,17,Black,3
# 135,18,Black,4
# 136,19,Black,3
# 137,20,Black,3
# 138,21,Black,4
# 139,22,Black,3
# 140,23,Black,3
# 141,24,Black,3
# 142,25,Black,4
# 143,26,Black,3
# 144,27,Black,3
# 145,28,Black,4
# 146,29,Black,3
# 147,30,Black,4
# 148,0,Black,3
# 149,0,Black,3
# 150,0,Black,3
# 151,0,Black,4
# 152,0,Black,3
# 153,0,Black,3
# 154,0,Black,3
# 155,0,Black,4
# 156,0,Black,3
# 157,0,Black,3
# 158,0,Black,4
# 159,0,Black,3
# 160,0,Black,3
# 161,0,Black,4
# 162,0,Black,3
# 163,0,Black,3
# 164,0,Black,3
# 165,0,Black,3
# 166,0,Black,4
# 167,0,Black,3
# 168,0,Black,4
# 169,0,Black,3
# 170,0,Black,3
# 171,0,Black,3
# 172,0,Black,3
# 173,0,Black,4
# 174,0,Black,4
# 175,0,Black,5
# 176,0,Black,3
# 177,1,White,3
# 178,2,White,770
# 179,3,White,771
# 180,4,White,758
# 181,5,White,772
# 182,6,White,775
# 183,7,White,767
# 184,8,White,761
# 185,9,White,764
# 186,10,White,765
# 187,11,White,770
# 188,12,White,760
# 189,13,White,766
# 190,14,White,766
# 191,15,White,771
# 192,16,White,773
# 193,17,White,763
# 194,18,White,770
# 195,19,White,773
# 196,20,White,768
# 197,21,White,767
# 198,22,White,775
# 199,23,White,772
# 200,24,White,763
# 201,25,White,767
# 202,26,White,773
# 203,27,White,765
# 204,28,White,770
# 205,29,White,777
# 206,30,White,765
# 207,1,Red,769
# 208,2,Red,308
# 209,3,Red,311
# 210,4,Red,306
# 211,5,Red,314
# 212,6,Red,309
# 213,7,Red,309
# 214,8,Red,306
# 215,9,Red,308
# 216,10,Red,310
# 217,11,Red,312
# 218,12,Red,307
# 219,13,Red,308
# 220,14,Red,308
# 221,15,Red,306
# 222,16,Red,309
# 223,17,Red,305
# 224,18,Red,314
# 225,19,Red,312
# 226,20,Red,302
# 227,21,Red,308
# 228,22,Red,306
# 229,23,Red,304
# 230,24,Red,312
# 231,25,Red,314
# 232,26,Red,305
# 233,27,Red,312
# 234,28,Red,314
# 235,29,Red,314
# 236,1,Green,305
# 237,2,Green,292
# 238,3,Green,297
# 239,4,Green,298
# 240,5,Green,296
# 241,6,Green,294
# 242,7,Green,290
# 243,8,Green,291
# 244,9,Green,292
# 245,10,Green,300
# 246,11,Green,298
# 247,12,Green,294
# 248,13,Green,297
# 249,14,Green,299
# 250,15,Green,289
# 251,16,Green,294
# 252,17,Green,296
# 253,18,Green,293
# 254,19,Green,288
# 255,20,Green,290
# 256,21,Green,293
# 257,22,Green,294
# 258,23,Green,294
# 259,24,Green,292
# 260,25,Green,288
# 261,26,Green,285
# 262,27,Green,291
# 263,28,Green,289
# 264,29,Green,286
# 265,1,Blue,287
# 266,2,Blue,197
# 267,3,Blue,192
# 268,4,Blue,198
# 269,5,Blue,191
# 270,6,Blue,196
# 271,7,Blue,194
# 272,8,Blue,197
# 273,9,Blue,189
# 274,10,Blue,193
# 275,11,Blue,192
# 276,12,Blue,193
# 277,13,Blue,193
# 278,14,Blue,196
# 279,15,Blue,191
# 280,16,Blue,193
# 281,17,Blue,194
# 282,18,Blue,194
# 283,19,Blue,197
# 284,20,Blue,193
# 285,21,Blue,193
# 286,22,Blue,196
# 287,23,Blue,191
# 288,24,Blue,193
# 289,25,Blue,193
# 290,26,Blue,197
# 291,27,Blue,196
# 292,28,Blue,192
# 293,29,Blue,194
# 294,30,Blue,199
# 295,1,Black,190
# 296,2,Black,3
# 297,3,Black,3
# 298,4,Black,3
# 299,5,Black,4
# 300,6,Black,3
# 301,7,Black,3
# 302,8,Black,3
# 303,9,Black,3
# 304,10,Black,3
# 305,11,Black,4
# 306,12,Black,4
# 307,13,Black,4
# 308,14,Black,3
# 309,15,Black,3
# 310,16,Black,3
# 311,17,Black,3
# 312,18,Black,3
# 313,19,Black,3
# 314,20,Black,3
# 315,21,Black,3
# 316,22,Black,4
# 317,23,Black,3
# 318,24,Black,4
# 319,25,Black,3
# 320,26,Black,4
# 321,27,Black,3
# 322,28,Black,4
# 323,29,Black,4
# 324,0,Black,3
# 325,0,Black,3
# 326,0,Black,3
# 327,0,Black,4
# 328,0,Black,3
# 329,0,Black,4
# 330,0,Black,3
# 331,0,Black,3
# 332,0,Black,3
# 333,0,Black,3
# 334,0,Black,3
# 335,0,Black,3
# 336,0,Black,3
# 337,0,Black,3
# 338,0,Black,4
# 339,0,Black,3
# 340,0,Black,3
# 341,0,Black,4
# 342,0,Black,4
# 343,0,Black,4
# 344,0,Black,3
# 345,0,Black,3
# 346,0,Black,3
# 347,0,Black,3
# 348,0,Black,3
# 349,0,Black,3
# 350,0,Black,3
# 351,0,Black,3
# 352,0,Black,4
# 353,1,White,3
# 354,2,White,755
# 355,3,White,763
# 356,4,White,761
# 357,5,White,762
# 358,6,White,763
# 359,7,White,763
# 360,8,White,760
# 361,9,White,759
# 362,10,White,760
# 363,11,White,759
# 364,12,White,761
# 365,13,White,761
# 366,14,White,762
# 367,15,White,759
# 368,16,White,761
# 369,17,White,758
# 370,18,White,767
# 371,19,White,769
# 372,20,White,752
# 373,21,White,760
# 374,22,White,762
# 375,23,White,761
# 376,24,White,762
# 377,25,White,765
# 378,26,White,768
# 379,27,White,765
# 380,28,White,765
# 381,29,White,768
# 382,30,White,771
# 383,1,Red,756
# 384,2,Red,307
# 385,3,Red,308
# 386,4,Red,311
# 387,5,Red,308
# 388,6,Red,308
# 389,7,Red,307
# 390,8,Red,311
# 391,9,Red,308
# 392,10,Red,305
# 393,11,Red,308
# 394,12,Red,312
# 395,13,Red,310
# 396,14,Red,312
# 397,15,Red,303
# 398,16,Red,309
# 399,17,Red,312
# 400,18,Red,308
# 401,19,Red,312
# 402,20,Red,308
# 403,21,Red,307
# 404,22,Red,312
# 405,23,Red,313
# 406,24,Red,312
# 407,25,Red,309
# 408,26,Red,312
# 409,27,Red,314
# 410,28,Red,306
# 411,29,Red,308
# 412,1,Green,310
# 413,2,Green,294
# 414,3,Green,289
# 415,4,Green,291
# 416,5,Green,287
# 417,6,Green,289
# 418,7,Green,288
# 419,8,Green,288
# 420,9,Green,287
# 421,10,Green,295
# 422,11,Green,288
# 423,12,Green,296
# 424,13,Green,292
# 425,14,Green,283
# 426,15,Green,288
# 427,16,Green,288
# 428,17,Green,286
# 429,18,Green,285
# 430,19,Green,283
# 431,20,Green,283
# 432,21,Green,292
# 433,22,Green,290
# 434,23,Green,293
# 435,24,Green,293
# 436,25,Green,292
# 437,26,Green,289
# 438,27,Green,288
# 439,28,Green,286
# 440,29,Green,292
# 441,30,Green,289
# 442,1,Blue,290
# 443,2,Blue,196
# 444,3,Blue,195
# 445,4,Blue,197
# 446,5,Blue,197
# 447,6,Blue,191
# 448,7,Blue,189
# 449,8,Blue,195
# 450,9,Blue,194
# 451,10,Blue,194
# 452,11,Blue,192
# 453,12,Blue,197
# 454,13,Blue,190
# 455,14,Blue,193
# 456,15,Blue,193
# 457,16,Blue,195
# 458,17,Blue,191
# 459,18,Blue,199
# 460,19,Blue,190
# 461,20,Blue,197
# 462,21,Blue,190
# 463,22,Blue,195
# 464,23,Blue,197
# 465,24,Blue,196
# 466,25,Blue,190
# 467,26,Blue,199
# 468,27,Blue,193
# 469,28,Blue,190
# 470,29,Blue,193
# 471,1,Black,193
# 472,2,Black,3
# 473,3,Black,3
# 474,4,Black,3
# 475,5,Black,3
# 476,6,Black,4
# 477,7,Black,3
# 478,8,Black,3
# 479,9,Black,3
# 480,10,Black,4
# 481,11,Black,3
# 482,12,Black,3
# 483,13,Black,4
# 484,14,Black,3
# 485,15,Black,4
# 486,16,Black,3
# 487,17,Black,4
# 488,18,Black,3
# 489,19,Black,3
# 490,20,Black,4
# 491,21,Black,3
# 492,22,Black,4
# 493,23,Black,3
# 494,24,Black,4
# 495,25,Black,4
# 496,26,Black,3
# 497,27,Black,3
# 498,28,Black,3
# 499,29,Black,4
# 500,0,Black,3
# 501,0,Black,4
# 502,0,Black,3
# 503,0,Black,3
# 504,0,Black,3
# 505,0,Black,4
# 506,0,Black,3
# 507,0,Black,4
# 508,0,Black,3
# 509,0,Black,3
# 510,0,Black,3
# 511,0,Black,4
# 512,0,Black,3
# 513,0,Black,3
# 514,0,Black,3
# 515,0,Black,4
# 516,0,Black,3
# 517,0,Black,4
# 518,0,Black,3
# 519,0,Black,3
# 520,0,Black,3
# 521,0,Black,3
# 522,0,Black,4
# 523,0,Black,3
# 524,0,Black,4
# 525,0,Black,3
# 526,0,Black,4
# 527,0,Black,4
# 528,0,Black,3
# 529,0,Black,3
# 530,1,White,3
# 531,2,White,766
# 532,3,White,762
# 533,4,White,761
# 534,5,White,760
# 535,6,White,757
# 536,7,White,762
# 537,8,White,759
# 538,9,White,755
# 539,10,White,758
# 540,11,White,758
# 541,12,White,763
# 542,13,White,757
# 543,14,White,762
# 544,15,White,763
# 545,16,White,758
# 546,17,White,757
# 547,18,White,759
# 548,19,White,759
# 549,20,White,759
# 550,21,White,761
# 551,22,White,758
# 552,23,White,765
# 553,24,White,767
# 554,25,White,763
# 555,26,White,761
# 556,27,White,768
# 557,28,White,770
# 558,29,White,759
# 559,1,Red,761
# 560,2,Red,308
# 561,3,Red,310
# 562,4,Red,309
# 563,5,Red,310
# 564,6,Red,310
# 565,7,Red,309
# 566,8,Red,310
# 567,9,Red,309
# 568,10,Red,306
# 569,11,Red,307
# 570,12,Red,313
# 571,13,Red,310
# 572,14,Red,315
# 573,15,Red,308
# 574,16,Red,308
# 575,17,Red,304
# 576,18,Red,309
# 577,19,Red,310
# 578,20,Red,315
# 579,21,Red,308
# 580,22,Red,307
# 581,23,Red,309
# 582,24,Red,313
# 583,25,Red,313
# 584,26,Red,310
# 585,27,Red,307
# 586,28,Red,308
# 587,29,Red,311
# 588,30,Red,308
# 589,1,Green,309
# 590,2,Green,302
# 591,3,Green,302
# 592,4,Green,301
# 593,5,Green,300
# 594,6,Green,301
# 595,7,Green,310
# 596,8,Green,303
# 597,9,Green,304
# 598,10,Green,311
# 599,11,Green,303
# 600,12,Green,302
# 601,13,Green,310
# 602,14,Green,310
# 603,15,Green,299
# 604,16,Green,306
# 605,17,Green,305
# 606,18,Green,303
# 607,19,Green,305
# 608,20,Green,306
# 609,21,Green,304
# 610,22,Green,306
# 611,23,Green,305
# 612,24,Green,305
# 613,25,Green,304
# 614,26,Green,303
# 615,27,Green,304
# 616,28,Green,301
# 617,29,Green,301
# 618,1,Blue,305
# 619,2,Blue,198
# 620,3,Blue,193
# 621,4,Blue,194
# 622,5,Blue,192
# 623,6,Blue,196
# 624,7,Blue,197
# 625,8,Blue,191
# 626,9,Blue,197
# 627,10,Blue,195
# 628,11,Blue,190
# 629,12,Blue,190
# 630,13,Blue,193
# 631,14,Blue,196
# 632,15,Blue,193
# 633,16,Blue,198
# 634,17,Blue,191
# 635,18,Blue,196
# 636,19,Blue,193
# 637,20,Blue,195
# 638,21,Blue,192
# 639,22,Blue,190
# 640,23,Blue,193
# 641,24,Blue,195
# 642,25,Blue,191
# 643,26,Blue,192
# 644,27,Blue,192
# 645,28,Blue,196
# 646,29,Blue,198
# 647,1,Black,193
# 648,2,Black,4
# 649,3,Black,3
# 650,4,Black,3
# 651,5,Black,4
# 652,6,Black,4
# 653,7,Black,3
# 654,8,Black,3
# 655,9,Black,4
# 656,10,Black,3
# 657,11,Black,3
# 658,12,Black,4
# 659,13,Black,3
# 660,14,Black,4
# 661,15,Black,3
# 662,16,Black,3
# 663,17,Black,3
# 664,18,Black,4
# 665,19,Black,3
# 666,20,Black,3
# 667,21,Black,3
# 668,22,Black,3
# 669,23,Black,3
# 670,24,Black,3
# 671,25,Black,4
# 672,26,Black,4
# 673,27,Black,3
# 674,28,Black,3
# 675,29,Black,3
# 676,30,Black,4
# 677,0,Black,4
# 678,0,Black,4
# 679,0,Black,4
# 680,0,Black,3
#
# ==================================================
#
# ไฟล์: N/N80_NoR.txt
# N_80_No_RNH4CL 80mg/L tube  5ml  No Reagent :08/10/2023,21:54:35
# 1,1,White,4
# 2,2,White,808
# 3,3,White,808
# 4,4,White,798
# 5,5,White,811
# 6,6,White,810
# 7,7,White,808
# 8,8,White,816
# 9,9,White,809
# 10,10,White,811
# 11,11,White,812
# 12,12,White,808
# 13,13,White,816
# 14,14,White,806
# 15,15,White,812
# 16,16,White,805
# 17,17,White,812
# 18,18,White,810
# 19,19,White,809
# 20,20,White,811
# 21,21,White,804
# 22,22,White,815
# 23,23,White,813
# 24,24,White,808
# 25,25,White,813
# 26,26,White,798
# 27,27,White,806
# 28,28,White,793
# 29,29,White,803
# 30,1,Red,805
# 31,2,Red,302
# 32,3,Red,301
# 33,4,Red,306
# 34,5,Red,305
# 35,6,Red,302
# 36,7,Red,306
# 37,8,Red,303
# 38,9,Red,296
# 39,10,Red,302
# 40,11,Red,304
# 41,12,Red,302
# 42,13,Red,300
# 43,14,Red,299
# 44,15,Red,301
# 45,16,Red,301
# 46,17,Red,298
# 47,18,Red,297
# 48,19,Red,302
# 49,20,Red,303
# 50,21,Red,298
# 51,22,Red,300
# 52,23,Red,296
# 53,24,Red,299
# 54,25,Red,305
# 55,26,Red,302
# 56,27,Red,302
# 57,28,Red,301
# 58,29,Red,298
# 59,30,Red,303
# 60,1,Green,299
# 61,2,Green,327
# 62,3,Green,325
# 63,4,Green,332
# 64,5,Green,329
# 65,6,Green,328
# 66,7,Green,332
# 67,8,Green,333
# 68,9,Green,327
# 69,10,Green,331
# 70,11,Green,329
# 71,12,Green,326
# 72,13,Green,328
# 73,14,Green,331
# 74,15,Green,330
# 75,16,Green,330
# 76,17,Green,331
# 77,18,Green,329
# 78,19,Green,330
# 79,20,Green,335
# 80,21,Green,336
# 81,22,Green,332
# 82,23,Green,328
# 83,24,Green,331
# 84,25,Green,333
# 85,26,Green,335
# 86,27,Green,323
# 87,28,Green,330
# 88,29,Green,330
# 89,1,Blue,335
# 90,2,Blue,219
# 91,3,Blue,225
# 92,4,Blue,222
# 93,5,Blue,218
# 94,6,Blue,221
# 95,7,Blue,223
# 96,8,Blue,226
# 97,9,Blue,220
# 98,10,Blue,225
# 99,11,Blue,226
# 100,12,Blue,222
# 101,13,Blue,225
# 102,14,Blue,223
# 103,15,Blue,224
# 104,16,Blue,224
# 105,17,Blue,225
# 106,18,Blue,225
# 107,19,Blue,221
# 108,20,Blue,223
# 109,21,Blue,223
# 110,22,Blue,221
# 111,23,Blue,227
# 112,24,Blue,220
# 113,25,Blue,221
# 114,26,Blue,222
# 115,27,Blue,222
# 116,28,Blue,224
# 117,29,Blue,226
# 118,1,Black,223
# 119,2,Black,5
# 120,3,Black,5
# 121,4,Black,5
# 122,5,Black,5
# 123,6,Black,5
# 124,7,Black,4
# 125,8,Black,5
# 126,9,Black,5
# 127,10,Black,5
# 128,11,Black,4
# 129,12,Black,4
# 130,13,Black,4
# 131,14,Black,5
# 132,15,Black,4
# 133,16,Black,4
# 134,17,Black,4
# 135,18,Black,5
# 136,19,Black,4
# 137,20,Black,4
# 138,21,Black,5
# 139,22,Black,5
# 140,23,Black,5
# 141,24,Black,5
# 142,25,Black,5
# 143,26,Black,4
# 144,27,Black,4
# 145,28,Black,5
# 146,29,Black,5
# 147,30,Black,5
# 148,0,Black,5
# 149,0,Black,5
# 150,0,Black,5
# 151,0,Black,5
# 152,0,Black,4
# 153,0,Black,4
# 154,0,Black,4
# 155,0,Black,4
# 156,0,Black,5
# 157,0,Black,5
# 158,0,Black,5
# 159,0,Black,4
# 160,0,Black,4
# 161,0,Black,5
# 162,0,Black,4
# 163,0,Black,5
# 164,0,Black,4
# 165,0,Black,5
# 166,0,Black,5
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,6
# 170,0,Black,5
# 171,0,Black,6
# 172,0,Black,4
# 173,0,Black,4
# 174,0,Black,5
# 175,0,Black,5
# 176,0,Black,5
# 177,1,White,5
# 178,2,White,813
# 179,3,White,816
# 180,4,White,820
# 181,5,White,812
# 182,6,White,808
# 183,7,White,815
# 184,8,White,815
# 185,9,White,818
# 186,10,White,818
# 187,11,White,816
# 188,12,White,807
# 189,13,White,812
# 190,14,White,814
# 191,15,White,822
# 192,16,White,811
# 193,17,White,818
# 194,18,White,817
# 195,19,White,821
# 196,20,White,808
# 197,21,White,819
# 198,22,White,810
# 199,23,White,812
# 200,24,White,818
# 201,25,White,822
# 202,26,White,817
# 203,27,White,820
# 204,28,White,812
# 205,29,White,814
# 206,1,Red,816
# 207,2,Red,300
# 208,3,Red,301
# 209,4,Red,300
# 210,5,Red,301
# 211,6,Red,306
# 212,7,Red,300
# 213,8,Red,301
# 214,9,Red,304
# 215,10,Red,295
# 216,11,Red,303
# 217,12,Red,307
# 218,13,Red,300
# 219,14,Red,297
# 220,15,Red,300
# 221,16,Red,304
# 222,17,Red,306
# 223,18,Red,306
# 224,19,Red,300
# 225,20,Red,301
# 226,21,Red,304
# 227,22,Red,302
# 228,23,Red,305
# 229,24,Red,305
# 230,25,Red,306
# 231,26,Red,300
# 232,27,Red,301
# 233,28,Red,299
# 234,29,Red,307
# 235,30,Red,304
# 236,1,Green,304
# 237,2,Green,336
# 238,3,Green,335
# 239,4,Green,333
# 240,5,Green,338
# 241,6,Green,333
# 242,7,Green,339
# 243,8,Green,335
# 244,9,Green,338
# 245,10,Green,335
# 246,11,Green,341
# 247,12,Green,334
# 248,13,Green,337
# 249,14,Green,334
# 250,15,Green,338
# 251,16,Green,334
# 252,17,Green,332
# 253,18,Green,339
# 254,19,Green,335
# 255,20,Green,336
# 256,21,Green,342
# 257,22,Green,339
# 258,23,Green,334
# 259,24,Green,342
# 260,25,Green,342
# 261,26,Green,342
# 262,27,Green,334
# 263,28,Green,337
# 264,29,Green,341
# 265,1,Blue,337
# 266,2,Blue,224
# 267,3,Blue,221
# 268,4,Blue,219
# 269,5,Blue,229
# 270,6,Blue,227
# 271,7,Blue,225
# 272,8,Blue,225
# 273,9,Blue,229
# 274,10,Blue,228
# 275,11,Blue,223
# 276,12,Blue,224
# 277,13,Blue,228
# 278,14,Blue,219
# 279,15,Blue,226
# 280,16,Blue,226
# 281,17,Blue,225
# 282,18,Blue,227
# 283,19,Blue,228
# 284,20,Blue,229
# 285,21,Blue,225
# 286,22,Blue,220
# 287,23,Blue,230
# 288,24,Blue,225
# 289,25,Blue,226
# 290,26,Blue,224
# 291,27,Blue,229
# 292,28,Blue,226
# 293,29,Blue,219
# 294,30,Blue,224
# 295,1,Black,225
# 296,2,Black,4
# 297,3,Black,5
# 298,4,Black,5
# 299,5,Black,4
# 300,6,Black,4
# 301,7,Black,4
# 302,8,Black,5
# 303,9,Black,5
# 304,10,Black,5
# 305,11,Black,4
# 306,12,Black,5
# 307,13,Black,5
# 308,14,Black,4
# 309,15,Black,5
# 310,16,Black,5
# 311,17,Black,4
# 312,18,Black,4
# 313,19,Black,4
# 314,20,Black,6
# 315,21,Black,5
# 316,22,Black,4
# 317,23,Black,4
# 318,24,Black,5
# 319,25,Black,5
# 320,26,Black,5
# 321,27,Black,4
# 322,28,Black,4
# 323,29,Black,6
# 324,0,Black,5
# 325,0,Black,4
# 326,0,Black,5
# 327,0,Black,4
# 328,0,Black,5
# 329,0,Black,5
# 330,0,Black,5
# 331,0,Black,5
# 332,0,Black,4
# 333,0,Black,4
# 334,0,Black,4
# 335,0,Black,4
# 336,0,Black,4
# 337,0,Black,5
# 338,0,Black,4
# 339,0,Black,4
# 340,0,Black,4
# 341,0,Black,4
# 342,0,Black,4
# 343,0,Black,5
# 344,0,Black,5
# 345,0,Black,4
# 346,0,Black,4
# 347,0,Black,5
# 348,0,Black,5
# 349,0,Black,5
# 350,0,Black,5
# 351,0,Black,5
# 352,0,Black,4
# 353,1,White,5
# 354,2,White,819
# 355,3,White,816
# 356,4,White,821
# 357,5,White,818
# 358,6,White,812
# 359,7,White,812
# 360,8,White,822
# 361,9,White,815
# 362,10,White,818
# 363,11,White,818
# 364,12,White,813
# 365,13,White,814
# 366,14,White,818
# 367,15,White,815
# 368,16,White,817
# 369,17,White,809
# 370,18,White,822
# 371,19,White,816
# 372,20,White,809
# 373,21,White,813
# 374,22,White,815
# 375,23,White,820
# 376,24,White,818
# 377,25,White,811
# 378,26,White,814
# 379,27,White,818
# 380,28,White,818
# 381,29,White,821
# 382,30,White,813
# 383,1,Red,814
# 384,2,Red,300
# 385,3,Red,305
# 386,4,Red,301
# 387,5,Red,304
# 388,6,Red,307
# 389,7,Red,300
# 390,8,Red,301
# 391,9,Red,298
# 392,10,Red,306
# 393,11,Red,299
# 394,12,Red,301
# 395,13,Red,301
# 396,14,Red,304
# 397,15,Red,299
# 398,16,Red,299
# 399,17,Red,305
# 400,18,Red,300
# 401,19,Red,303
# 402,20,Red,301
# 403,21,Red,305
# 404,22,Red,298
# 405,23,Red,301
# 406,24,Red,295
# 407,25,Red,306
# 408,26,Red,300
# 409,27,Red,301
# 410,28,Red,306
# 411,29,Red,302
# 412,1,Green,300
# 413,2,Green,333
# 414,3,Green,335
# 415,4,Green,339
# 416,5,Green,333
# 417,6,Green,336
# 418,7,Green,339
# 419,8,Green,340
# 420,9,Green,340
# 421,10,Green,335
# 422,11,Green,330
# 423,12,Green,338
# 424,13,Green,338
# 425,14,Green,337
# 426,15,Green,332
# 427,16,Green,339
# 428,17,Green,334
# 429,18,Green,332
# 430,19,Green,332
# 431,20,Green,337
# 432,21,Green,341
# 433,22,Green,334
# 434,23,Green,334
# 435,24,Green,332
# 436,25,Green,332
# 437,26,Green,340
# 438,27,Green,336
# 439,28,Green,336
# 440,29,Green,334
# 441,30,Green,338
# 442,1,Blue,336
# 443,2,Blue,228
# 444,3,Blue,224
# 445,4,Blue,229
# 446,5,Blue,225
# 447,6,Blue,226
# 448,7,Blue,229
# 449,8,Blue,222
# 450,9,Blue,226
# 451,10,Blue,223
# 452,11,Blue,224
# 453,12,Blue,227
# 454,13,Blue,222
# 455,14,Blue,223
# 456,15,Blue,226
# 457,16,Blue,229
# 458,17,Blue,225
# 459,18,Blue,222
# 460,19,Blue,221
# 461,20,Blue,218
# 462,21,Blue,222
# 463,22,Blue,223
# 464,23,Blue,229
# 465,24,Blue,230
# 466,25,Blue,222
# 467,26,Blue,228
# 468,27,Blue,227
# 469,28,Blue,226
# 470,29,Blue,229
# 471,1,Black,223
# 472,2,Black,4
# 473,3,Black,5
# 474,4,Black,4
# 475,5,Black,4
# 476,6,Black,4
# 477,7,Black,5
# 478,8,Black,4
# 479,9,Black,5
# 480,10,Black,4
# 481,11,Black,4
# 482,12,Black,4
# 483,13,Black,4
# 484,14,Black,5
# 485,15,Black,4
# 486,16,Black,5
# 487,17,Black,5
# 488,18,Black,5
# 489,19,Black,4
# 490,20,Black,5
# 491,21,Black,5
# 492,22,Black,5
# 493,23,Black,4
# 494,24,Black,5
# 495,25,Black,5
# 496,26,Black,5
# 497,27,Black,4
# 498,28,Black,4
# 499,29,Black,5
# 500,0,Black,6
# 501,0,Black,5
# 502,0,Black,5
# 503,0,Black,5
# 504,0,Black,4
# 505,0,Black,5
# 506,0,Black,4
# 507,0,Black,5
# 508,0,Black,4
# 509,0,Black,5
# 510,0,Black,4
# 511,0,Black,5
# 512,0,Black,5
# 513,0,Black,4
# 514,0,Black,4
# 515,0,Black,4
# 516,0,Black,4
# 517,0,Black,3
# 518,0,Black,4
# 519,0,Black,4
# 520,0,Black,4
# 521,0,Black,5
# 522,0,Black,5
# 523,0,Black,5
# 524,0,Black,4
# 525,0,Black,5
# 526,0,Black,4
# 527,0,Black,4
# 528,0,Black,4
# 529,0,Black,4
# 530,1,White,6
# 531,2,White,813
# 532,3,White,814
# 533,4,White,807
# 534,5,White,819
# 535,6,White,815
# 536,7,White,814
# 537,8,White,817
# 538,9,White,815
# 539,10,White,815
# 540,11,White,818
# 541,12,White,822
# 542,13,White,817
# 543,14,White,811
# 544,15,White,819
# 545,16,White,816
# 546,17,White,817
# 547,18,White,814
# 548,19,White,813
# 549,20,White,817
# 550,21,White,819
# 551,22,White,813
# 552,23,White,816
# 553,24,White,812
# 554,25,White,810
# 555,26,White,821
# 556,27,White,814
# 557,28,White,818
# 558,29,White,805
# 559,1,Red,813
# 560,2,Red,300
# 561,3,Red,302
# 562,4,Red,298
# 563,5,Red,299
# 564,6,Red,300
# 565,7,Red,299
# 566,8,Red,305
# 567,9,Red,304
# 568,10,Red,301
# 569,11,Red,298
# 570,12,Red,303
# 571,13,Red,302
# 572,14,Red,303
# 573,15,Red,297
# 574,16,Red,299
# 575,17,Red,307
# 576,18,Red,305
# 577,19,Red,297
# 578,20,Red,307
# 579,21,Red,302
# 580,22,Red,305
# 581,23,Red,299
# 582,24,Red,304
# 583,25,Red,300
# 584,26,Red,298
# 585,27,Red,299
# 586,28,Red,303
# 587,29,Red,299
# 588,1,Green,302
# 589,2,Green,341
# 590,3,Green,338
# 591,4,Green,335
# 592,5,Green,334
# 593,6,Green,335
# 594,7,Green,336
# 595,8,Green,333
# 596,9,Green,336
# 597,10,Green,333
# 598,11,Green,328
# 599,12,Green,337
# 600,13,Green,339
# 601,14,Green,340
# 602,15,Green,334
# 603,16,Green,335
# 604,17,Green,333
# 605,18,Green,338
# 606,19,Green,336
# 607,20,Green,340
# 608,21,Green,336
# 609,22,Green,333
# 610,23,Green,336
# 611,24,Green,335
# 612,25,Green,336
# 613,26,Green,338
# 614,27,Green,333
# 615,28,Green,333
# 616,29,Green,335
# 617,30,Green,338
# 618,1,Blue,329
# 619,2,Blue,224
# 620,3,Blue,223
# 621,4,Blue,225
# 622,5,Blue,230
# 623,6,Blue,227
# 624,7,Blue,226
# 625,8,Blue,227
# 626,9,Blue,225
# 627,10,Blue,226
# 628,11,Blue,221
# 629,12,Blue,224
# 630,13,Blue,227
# 631,14,Blue,225
# 632,15,Blue,221
# 633,16,Blue,230
# 634,17,Blue,227
# 635,18,Blue,226
# 636,19,Blue,223
# 637,20,Blue,227
# 638,21,Blue,223
# 639,22,Blue,223
# 640,23,Blue,219
# 641,24,Blue,225
# 642,25,Blue,223
# 643,26,Blue,222
# 644,27,Blue,226
# 645,28,Blue,227
# 646,29,Blue,222
# 647,1,Black,223
# 648,2,Black,4
# 649,3,Black,5
# 650,4,Black,4
# 651,5,Black,5
# 652,6,Black,5
# 653,7,Black,6
# 654,8,Black,4
# 655,9,Black,5
# 656,10,Black,5
# 657,11,Black,5
# 658,12,Black,5
# 659,13,Black,5
# 660,14,Black,5
# 661,15,Black,4
# 662,16,Black,4
# 663,17,Black,5
# 664,18,Black,4
# 665,19,Black,5
# 666,20,Black,6
# 667,21,Black,4
# 668,22,Black,4
# 669,23,Black,5
# 670,24,Black,4
# 671,25,Black,4
# 672,26,Black,4
# 673,27,Black,5
# 674,28,Black,6
# 675,29,Black,5
# 676,30,Black,4
# 677,0,Black,4
# 678,0,Black,4
# 679,0,Black,4
# 680,0,Black,5
#
# ==================================================
#
# ไฟล์: N/N20_NoR.txt
# N_20_No_RNH4CL 20mg/L tube  5ml  No Reagent :08/10/2023,19:58:22
# 1,1,White,4
# 2,2,White,847
# 3,3,White,851
# 4,4,White,843
# 5,5,White,849
# 6,6,White,851
# 7,7,White,846
# 8,8,White,847
# 9,9,White,846
# 10,10,White,850
# 11,11,White,849
# 12,12,White,852
# 13,13,White,844
# 14,14,White,845
# 15,15,White,849
# 16,16,White,850
# 17,17,White,848
# 18,18,White,844
# 19,19,White,850
# 20,20,White,849
# 21,21,White,843
# 22,22,White,843
# 23,23,White,847
# 24,24,White,843
# 25,25,White,848
# 26,26,White,840
# 27,27,White,836
# 28,28,White,846
# 29,29,White,837
# 30,1,Red,847
# 31,2,Red,324
# 32,3,Red,321
# 33,4,Red,325
# 34,5,Red,327
# 35,6,Red,324
# 36,7,Red,320
# 37,8,Red,320
# 38,9,Red,326
# 39,10,Red,324
# 40,11,Red,325
# 41,12,Red,323
# 42,13,Red,323
# 43,14,Red,321
# 44,15,Red,316
# 45,16,Red,321
# 46,17,Red,326
# 47,18,Red,321
# 48,19,Red,315
# 49,20,Red,326
# 50,21,Red,317
# 51,22,Red,326
# 52,23,Red,319
# 53,24,Red,325
# 54,25,Red,314
# 55,26,Red,322
# 56,27,Red,322
# 57,28,Red,321
# 58,29,Red,325
# 59,30,Red,325
# 60,1,Green,319
# 61,2,Green,356
# 62,3,Green,356
# 63,4,Green,355
# 64,5,Green,350
# 65,6,Green,340
# 66,7,Green,348
# 67,8,Green,348
# 68,9,Green,351
# 69,10,Green,348
# 70,11,Green,350
# 71,12,Green,350
# 72,13,Green,355
# 73,14,Green,351
# 74,15,Green,352
# 75,16,Green,353
# 76,17,Green,356
# 77,18,Green,356
# 78,19,Green,352
# 79,20,Green,351
# 80,21,Green,352
# 81,22,Green,356
# 82,23,Green,355
# 83,24,Green,353
# 84,25,Green,358
# 85,26,Green,351
# 86,27,Green,355
# 87,28,Green,358
# 88,29,Green,354
# 89,30,Green,349
# 90,1,Blue,355
# 91,2,Blue,229
# 92,3,Blue,223
# 93,4,Blue,231
# 94,5,Blue,224
# 95,6,Blue,229
# 96,7,Blue,224
# 97,8,Blue,232
# 98,9,Blue,229
# 99,10,Blue,229
# 100,11,Blue,231
# 101,12,Blue,232
# 102,13,Blue,226
# 103,14,Blue,225
# 104,15,Blue,229
# 105,16,Blue,226
# 106,17,Blue,231
# 107,18,Blue,230
# 108,19,Blue,226
# 109,20,Blue,228
# 110,21,Blue,227
# 111,22,Blue,230
# 112,23,Blue,229
# 113,24,Blue,225
# 114,25,Blue,228
# 115,26,Blue,226
# 116,27,Blue,227
# 117,28,Blue,225
# 118,29,Blue,226
# 119,1,Black,221
# 120,2,Black,5
# 121,3,Black,4
# 122,4,Black,4
# 123,5,Black,4
# 124,6,Black,4
# 125,7,Black,5
# 126,8,Black,4
# 127,9,Black,4
# 128,10,Black,4
# 129,11,Black,4
# 130,12,Black,4
# 131,13,Black,4
# 132,14,Black,5
# 133,15,Black,4
# 134,16,Black,4
# 135,17,Black,4
# 136,18,Black,5
# 137,19,Black,5
# 138,20,Black,4
# 139,21,Black,5
# 140,22,Black,4
# 141,23,Black,4
# 142,24,Black,4
# 143,25,Black,5
# 144,26,Black,4
# 145,27,Black,4
# 146,28,Black,4
# 147,29,Black,4
# 148,30,Black,4
# 149,0,Black,5
# 150,0,Black,5
# 151,0,Black,4
# 152,0,Black,4
# 153,0,Black,4
# 154,0,Black,5
# 155,0,Black,4
# 156,0,Black,4
# 157,0,Black,4
# 158,0,Black,5
# 159,0,Black,4
# 160,0,Black,4
# 161,0,Black,5
# 162,0,Black,4
# 163,0,Black,4
# 164,0,Black,3
# 165,0,Black,4
# 166,0,Black,4
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black,5
# 171,0,Black,4
# 172,0,Black,6
# 173,0,Black,4
# 174,0,Black,4
# 175,0,Black,4
# 176,0,Black,4
# 177,0,Black,4
# 178,0,Black,4
# 179,1,White,4
# 180,2,White,847
# 181,3,White,852
# 182,4,White,850
# 183,5,White,847
# 184,6,White,845
# 185,7,White,844
# 186,8,White,852
# 187,9,White,858
# 188,10,White,855
# 189,11,White,857
# 190,12,White,855
# 191,13,White,845
# 192,14,White,859
# 193,15,White,859
# 194,16,White,853
# 195,17,White,851
# 196,18,White,850
# 197,19,White,858
# 198,20,White,856
# 199,21,White,857
# 200,22,White,851
# 201,23,White,855
# 202,24,White,853
# 203,25,White,850
# 204,26,White,851
# 205,27,White,851
# 206,28,White,850
# 207,29,White,848
# 208,1,Red,851
# 209,2,Red,318
# 210,3,Red,321
# 211,4,Red,316
# 212,5,Red,321
# 213,6,Red,318
# 214,7,Red,318
# 215,8,Red,317
# 216,9,Red,320
# 217,10,Red,321
# 218,11,Red,324
# 219,12,Red,326
# 220,13,Red,327
# 221,14,Red,319
# 222,15,Red,326
# 223,16,Red,321
# 224,17,Red,324
# 225,18,Red,324
# 226,19,Red,327
# 227,20,Red,317
# 228,21,Red,322
# 229,22,Red,326
# 230,23,Red,324
# 231,24,Red,322
# 232,25,Red,322
# 233,26,Red,317
# 234,27,Red,318
# 235,28,Red,317
# 236,29,Red,323
# 237,30,Red,318
# 238,1,Green,315
# 239,2,Green,354
# 240,3,Green,352
# 241,4,Green,359
# 242,5,Green,355
# 243,6,Green,359
# 244,7,Green,351
# 245,8,Green,357
# 246,9,Green,354
# 247,10,Green,354
# 248,11,Green,357
# 249,12,Green,353
# 250,13,Green,351
# 251,14,Green,354
# 252,15,Green,355
# 253,16,Green,354
# 254,17,Green,353
# 255,18,Green,351
# 256,19,Green,354
# 257,20,Green,356
# 258,21,Green,349
# 259,22,Green,351
# 260,23,Green,356
# 261,24,Green,353
# 262,25,Green,355
# 263,26,Green,355
# 264,27,Green,348
# 265,28,Green,350
# 266,29,Green,352
# 267,30,Green,350
# 268,1,Blue,355
# 269,2,Blue,225
# 270,3,Blue,226
# 271,4,Blue,227
# 272,5,Blue,224
# 273,6,Blue,224
# 274,7,Blue,226
# 275,8,Blue,224
# 276,9,Blue,233
# 277,10,Blue,233
# 278,11,Blue,225
# 279,12,Blue,225
# 280,13,Blue,233
# 281,14,Blue,228
# 282,15,Blue,223
# 283,16,Blue,231
# 284,17,Blue,231
# 285,18,Blue,231
# 286,19,Blue,225
# 287,20,Blue,224
# 288,21,Blue,229
# 289,22,Blue,220
# 290,23,Blue,225
# 291,24,Blue,224
# 292,25,Blue,227
# 293,26,Blue,231
# 294,27,Blue,225
# 295,28,Blue,225
# 296,29,Blue,230
# 297,1,Black,225
# 298,2,Black,5
# 299,3,Black,4
# 300,4,Black,4
# 301,5,Black,4
# 302,6,Black,4
# 303,7,Black,4
# 304,8,Black,4
# 305,9,Black,4
# 306,10,Black,4
# 307,11,Black,4
# 308,12,Black,4
# 309,13,Black,4
# 310,14,Black,5
# 311,15,Black,5
# 312,16,Black,3
# 313,17,Black,5
# 314,18,Black,4
# 315,19,Black,5
# 316,20,Black,4
# 317,21,Black,5
# 318,22,Black,4
# 319,23,Black,4
# 320,24,Black,4
# 321,25,Black,4
# 322,26,Black,4
# 323,27,Black,4
# 324,28,Black,4
# 325,29,Black,4
# 326,30,Black,4
# 327,0,Black,4
# 328,0,Black,5
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,5
# 332,0,Black,4
# 333,0,Black,3
# 334,0,Black,5
# 335,0,Black,4
# 336,0,Black,5
# 337,0,Black,4
# 338,0,Black,4
# 339,0,Black,4
# 340,0,Black,4
# 341,0,Black,5
# 342,0,Black,5
# 343,0,Black,4
# 344,0,Black,4
# 345,0,Black,4
# 346,0,Black,4
# 347,0,Black,4
# 348,0,Black,4
# 349,0,Black,3
# 350,0,Black,5
# 351,0,Black,4
# 352,0,Black,5
# 353,0,Black,4
# 354,0,Black,4
# 355,0,Black,4
# 356,0,Black,4
# 357,1,White,5
# 358,2,White,850
# 359,3,White,848
# 360,4,White,854
# 361,5,White,847
# 362,6,White,853
# 363,7,White,845
# 364,8,White,851
# 365,9,White,851
# 366,10,White,851
# 367,11,White,849
# 368,12,White,849
# 369,13,White,853
# 370,14,White,852
# 371,15,White,848
# 372,16,White,841
# 373,17,White,855
# 374,18,White,850
# 375,19,White,850
# 376,20,White,851
# 377,21,White,847
# 378,22,White,851
# 379,23,White,850
# 380,24,White,852
# 381,25,White,849
# 382,26,White,849
# 383,27,White,849
# 384,28,White,851
# 385,29,White,853
# 386,1,Red,857
# 387,2,Red,323
# 388,3,Red,322
# 389,4,Red,323
# 390,5,Red,323
# 391,6,Red,319
# 392,7,Red,325
# 393,8,Red,325
# 394,9,Red,325
# 395,10,Red,324
# 396,11,Red,325
# 397,12,Red,319
# 398,13,Red,323
# 399,14,Red,325
# 400,15,Red,327
# 401,16,Red,326
# 402,17,Red,321
# 403,18,Red,319
# 404,19,Red,319
# 405,20,Red,320
# 406,21,Red,317
# 407,22,Red,322
# 408,23,Red,326
# 409,24,Red,319
# 410,25,Red,321
# 411,26,Red,326
# 412,27,Red,323
# 413,28,Red,316
# 414,29,Red,321
# 415,30,Red,324
# 416,1,Green,321
# 417,2,Green,349
# 418,3,Green,353
# 419,4,Green,354
# 420,5,Green,353
# 421,6,Green,348
# 422,7,Green,348
# 423,8,Green,351
# 424,9,Green,345
# 425,10,Green,358
# 426,11,Green,349
# 427,12,Green,349
# 428,13,Green,356
# 429,14,Green,354
# 430,15,Green,352
# 431,16,Green,351
# 432,17,Green,357
# 433,18,Green,350
# 434,19,Green,356
# 435,20,Green,353
# 436,21,Green,357
# 437,22,Green,352
# 438,23,Green,352
# 439,24,Green,352
# 440,25,Green,348
# 441,26,Green,353
# 442,27,Green,349
# 443,28,Green,358
# 444,29,Green,353
# 445,30,Green,355
# 446,1,Blue,349
# 447,2,Blue,223
# 448,3,Blue,225
# 449,4,Blue,227
# 450,5,Blue,227
# 451,6,Blue,230
# 452,7,Blue,231
# 453,8,Blue,228
# 454,9,Blue,226
# 455,10,Blue,225
# 456,11,Blue,225
# 457,12,Blue,226
# 458,13,Blue,225
# 459,14,Blue,225
# 460,15,Blue,225
# 461,16,Blue,233
# 462,17,Blue,228
# 463,18,Blue,232
# 464,19,Blue,225
# 465,20,Blue,225
# 466,21,Blue,227
# 467,22,Blue,231
# 468,23,Blue,226
# 469,24,Blue,229
# 470,25,Blue,226
# 471,26,Blue,228
# 472,27,Blue,228
# 473,28,Blue,221
# 474,29,Blue,225
# 475,1,Black,224
# 476,2,Black,4
# 477,3,Black,5
# 478,4,Black,5
# 479,5,Black,5
# 480,6,Black,4
# 481,7,Black,5
# 482,8,Black,5
# 483,9,Black,4
# 484,10,Black,4
# 485,11,Black,4
# 486,12,Black,4
# 487,13,Black,4
# 488,14,Black,5
# 489,15,Black,4
# 490,16,Black,5
# 491,17,Black,5
# 492,18,Black,4
# 493,19,Black,5
# 494,20,Black,5
# 495,21,Black,4
# 496,22,Black,4
# 497,23,Black,4
# 498,24,Black,5
# 499,25,Black,5
# 500,26,Black,5
# 501,27,Black,4
# 502,28,Black,4
# 503,29,Black,4
# 504,30,Black,4
# 505,0,Black,4
# 506,0,Black,5
# 507,0,Black,5
# 508,0,Black,5
# 509,0,Black,5
# 510,0,Black,4
# 511,0,Black,4
# 512,0,Black,4
# 513,0,Black,5
# 514,0,Black,4
# 515,0,Black,5
# 516,0,Black,5
# 517,0,Black,5
# 518,0,Black,4
# 519,0,Black,4
# 520,0,Black,4
# 521,0,Black,4
# 522,0,Black,4
# 523,0,Black,4
# 524,0,Black,4
# 525,0,Black,5
# 526,0,Black,5
# 527,0,Black,4
# 528,0,Black,4
# 529,0,Black,4
# 530,0,Black,5
# 531,0,Black,5
# 532,0,Black,5
# 533,0,Black,4
# 534,0,Black,4
# 535,1,White,5
# 536,2,White,847
# 537,3,White,857
# 538,4,White,844
# 539,5,White,853
# 540,6,White,853
# 541,7,White,849
# 542,8,White,850
# 543,9,White,851
# 544,10,White,853
# 545,11,White,849
# 546,12,White,856
# 547,13,White,849
# 548,14,White,851
# 549,15,White,852
# 550,16,White,854
# 551,17,White,858
# 552,18,White,848
# 553,19,White,855
# 554,20,White,851
# 555,21,White,848
# 556,22,White,856
# 557,23,White,853
# 558,24,White,854
# 559,25,White,852
# 560,26,White,849
# 561,27,White,851
# 562,28,White,856
# 563,29,White,845
# 564,1,Red,851
# 565,2,Red,325
# 566,3,Red,320
# 567,4,Red,318
# 568,5,Red,321
# 569,6,Red,322
# 570,7,Red,322
# 571,8,Red,326
# 572,9,Red,327
# 573,10,Red,319
# 574,11,Red,321
# 575,12,Red,322
# 576,13,Red,314
# 577,14,Red,321
# 578,15,Red,324
# 579,16,Red,320
# 580,17,Red,323
# 581,18,Red,321
# 582,19,Red,320
# 583,20,Red,324
# 584,21,Red,325
# 585,22,Red,323
# 586,23,Red,324
# 587,24,Red,323
# 588,25,Red,324
# 589,26,Red,321
# 590,27,Red,322
# 591,28,Red,318
# 592,29,Red,318
# 593,30,Red,319
# 594,1,Green,317
# 595,2,Green,357
# 596,3,Green,351
# 597,4,Green,355
# 598,5,Green,348
# 599,6,Green,356
# 600,7,Green,354
# 601,8,Green,351
# 602,9,Green,352
# 603,10,Green,359
# 604,11,Green,355
# 605,12,Green,354
# 606,13,Green,346
# 607,14,Green,350
# 608,15,Green,350
# 609,16,Green,350
# 610,17,Green,355
# 611,18,Green,358
# 612,19,Green,358
# 613,20,Green,352
# 614,21,Green,354
# 615,22,Green,357
# 616,23,Green,354
# 617,24,Green,351
# 618,25,Green,356
# 619,26,Green,351
# 620,27,Green,351
# 621,28,Green,351
# 622,29,Green,352
# 623,30,Green,354
# 624,1,Blue,352
# 625,2,Blue,228
# 626,3,Blue,228
# 627,4,Blue,230
# 628,5,Blue,226
# 629,6,Blue,224
# 630,7,Blue,223
# 631,8,Blue,231
# 632,9,Blue,226
# 633,10,Blue,230
# 634,11,Blue,228
# 635,12,Blue,229
# 636,13,Blue,229
# 637,14,Blue,227
# 638,15,Blue,225
# 639,16,Blue,225
# 640,17,Blue,228
# 641,18,Blue,228
# 642,19,Blue,228
# 643,20,Blue,225
# 644,21,Blue,230
# 645,22,Blue,229
# 646,23,Blue,224
# 647,24,Blue,221
# 648,25,Blue,225
# 649,26,Blue,231
# 650,27,Blue,224
# 651,28,Blue,232
# 652,29,Blue,225
# 653,1,Black,226
# 654,2,Black,3
# 655,3,Black,4
# 656,4,Black,4
# 657,5,Black,4
# 658,6,Black,4
# 659,7,Black,4
# 660,8,Black,4
# 661,9,Black,5
# 662,10,Black,4
# 663,11,Black,4
# 664,12,Black,4
# 665,13,Black,5
# 666,14,Black,4
# 667,15,Black,4
# 668,16,Black,5
# 669,17,Black,4
# 670,18,Black,4
# 671,19,Black,4
# 672,20,Black,5
# 673,21,Black,4
# 674,22,Black,4
# 675,23,Black,4
# 676,24,Black,4
# 677,25,Black,4
# 678,26,Black,5
# 679,27,Black,5
# 680,28,Black,4
#
# ==================================================
#
# ไฟล์: N/N4_NoR.txt
# N_4_No_RNH4CL 4mg/L tube  5ml  No Reagent :08/10/2023,16:26:19
# 1,1,White,5
# 2,2,White,924
# 3,3,White,928
# 4,4,White,927
# 5,5,White,936
# 6,6,White,933
# 7,7,White,924
# 8,8,White,929
# 9,9,White,934
# 10,10,White,926
# 11,11,White,934
# 12,12,White,932
# 13,13,White,931
# 14,14,White,930
# 15,15,White,929
# 16,16,White,930
# 17,17,White,930
# 18,18,White,934
# 19,19,White,930
# 20,20,White,932
# 21,21,White,931
# 22,22,White,931
# 23,23,White,931
# 24,24,White,934
# 25,25,White,930
# 26,26,White,933
# 27,27,White,925
# 28,28,White,929
# 29,29,White,934
# 30,1,Red,932
# 31,2,Red,327
# 32,3,Red,325
# 33,4,Red,332
# 34,5,Red,324
# 35,6,Red,329
# 36,7,Red,324
# 37,8,Red,325
# 38,9,Red,324
# 39,10,Red,326
# 40,11,Red,329
# 41,12,Red,333
# 42,13,Red,329
# 43,14,Red,326
# 44,15,Red,328
# 45,16,Red,331
# 46,17,Red,327
# 47,18,Red,330
# 48,19,Red,332
# 49,20,Red,328
# 50,21,Red,330
# 51,22,Red,329
# 52,23,Red,323
# 53,24,Red,329
# 54,25,Red,323
# 55,26,Red,332
# 56,27,Red,333
# 57,28,Red,330
# 58,29,Red,331
# 59,30,Red,329
# 60,1,Green,323
# 61,2,Green,403
# 62,3,Green,400
# 63,4,Green,399
# 64,5,Green,398
# 65,6,Green,396
# 66,7,Green,399
# 67,8,Green,398
# 68,9,Green,389
# 69,10,Green,399
# 70,11,Green,396
# 71,12,Green,398
# 72,13,Green,397
# 73,14,Green,403
# 74,15,Green,401
# 75,16,Green,392
# 76,17,Green,401
# 77,18,Green,396
# 78,19,Green,395
# 79,20,Green,401
# 80,21,Green,395
# 81,22,Green,396
# 82,23,Green,399
# 83,24,Green,399
# 84,25,Green,399
# 85,26,Green,396
# 86,27,Green,401
# 87,28,Green,394
# 88,29,Green,400
# 89,30,Green,398
# 90,1,Blue,402
# 91,2,Blue,273
# 92,3,Blue,278
# 93,4,Blue,276
# 94,5,Blue,273
# 95,6,Blue,270
# 96,7,Blue,266
# 97,8,Blue,277
# 98,9,Blue,275
# 99,10,Blue,273
# 100,11,Blue,272
# 101,12,Blue,275
# 102,13,Blue,276
# 103,14,Blue,271
# 104,15,Blue,269
# 105,16,Blue,273
# 106,17,Blue,271
# 107,18,Blue,272
# 108,19,Blue,270
# 109,20,Blue,270
# 110,21,Blue,272
# 111,22,Blue,274
# 112,23,Blue,276
# 113,24,Blue,267
# 114,25,Blue,272
# 115,26,Blue,275
# 116,27,Blue,270
# 117,28,Blue,273
# 118,29,Blue,272
# 119,1,Black,271
# 120,2,Black,4
# 121,3,Black,4
# 122,4,Black,4
# 123,5,Black,4
# 124,6,Black,4
# 125,7,Black,5
# 126,8,Black,4
# 127,9,Black,5
# 128,10,Black,4
# 129,11,Black,4
# 130,12,Black,4
# 131,13,Black,4
# 132,14,Black,4
# 133,15,Black,5
# 134,16,Black,4
# 135,17,Black,4
# 136,18,Black,4
# 137,19,Black,4
# 138,20,Black,4
# 139,21,Black,4
# 140,22,Black,4
# 141,23,Black,5
# 142,24,Black,5
# 143,25,Black,4
# 144,26,Black,5
# 145,27,Black,4
# 146,28,Black,5
# 147,29,Black,4
# 148,30,Black,3
# 149,0,Black,5
# 150,0,Black,4
# 151,0,Black,4
# 152,0,Black,5
# 153,0,Black,5
# 154,0,Black,5
# 155,0,Black,5
# 156,0,Black,5
# 157,0,Black,5
# 158,0,Black,4
# 159,0,Black,4
# 160,0,Black,4
# 161,0,Black,4
# 162,0,Black,5
# 163,0,Black,4
# 164,0,Black,4
# 165,0,Black,5
# 166,0,Black,4
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,5
# 170,0,Black,5
# 171,0,Black,4
# 172,0,Black,4
# 173,0,Black,5
# 174,0,Black,4
# 175,0,Black,4
# 176,0,Black,5
# 177,0,Black,4
# 178,0,Black,5
# 179,1,White,4
# 180,2,White,928
# 181,3,White,927
# 182,4,White,935
# 183,5,White,924
# 184,6,White,919
# 185,7,White,928
# 186,8,White,931
# 187,9,White,928
# 188,10,White,927
# 189,11,White,934
# 190,12,White,923
# 191,13,White,934
# 192,14,White,931
# 193,15,White,930
# 194,16,White,931
# 195,17,White,922
# 196,18,White,929
# 197,19,White,929
# 198,20,White,932
# 199,21,White,926
# 200,22,White,930
# 201,23,White,923
# 202,24,White,934
# 203,25,White,929
# 204,26,White,926
# 205,27,White,926
# 206,28,White,934
# 207,29,White,932
# 208,1,Red,928
# 209,2,Red,325
# 210,3,Red,324
# 211,4,Red,325
# 212,5,Red,329
# 213,6,Red,329
# 214,7,Red,323
# 215,8,Red,328
# 216,9,Red,324
# 217,10,Red,327
# 218,11,Red,330
# 219,12,Red,325
# 220,13,Red,326
# 221,14,Red,327
# 222,15,Red,325
# 223,16,Red,330
# 224,17,Red,333
# 225,18,Red,329
# 226,19,Red,327
# 227,20,Red,330
# 228,21,Red,327
# 229,22,Red,330
# 230,23,Red,324
# 231,24,Red,326
# 232,25,Red,328
# 233,26,Red,331
# 234,27,Red,322
# 235,28,Red,325
# 236,29,Red,331
# 237,30,Red,320
# 238,1,Green,326
# 239,2,Green,395
# 240,3,Green,396
# 241,4,Green,398
# 242,5,Green,403
# 243,6,Green,399
# 244,7,Green,397
# 245,8,Green,398
# 246,9,Green,399
# 247,10,Green,395
# 248,11,Green,403
# 249,12,Green,396
# 250,13,Green,395
# 251,14,Green,395
# 252,15,Green,400
# 253,16,Green,396
# 254,17,Green,397
# 255,18,Green,394
# 256,19,Green,400
# 257,20,Green,396
# 258,21,Green,402
# 259,22,Green,393
# 260,23,Green,391
# 261,24,Green,398
# 262,25,Green,396
# 263,26,Green,398
# 264,27,Green,392
# 265,28,Green,396
# 266,29,Green,390
# 267,30,Green,397
# 268,1,Blue,401
# 269,2,Blue,273
# 270,3,Blue,270
# 271,4,Blue,269
# 272,5,Blue,269
# 273,6,Blue,267
# 274,7,Blue,275
# 275,8,Blue,276
# 276,9,Blue,271
# 277,10,Blue,275
# 278,11,Blue,274
# 279,12,Blue,270
# 280,13,Blue,276
# 281,14,Blue,267
# 282,15,Blue,266
# 283,16,Blue,274
# 284,17,Blue,277
# 285,18,Blue,272
# 286,19,Blue,270
# 287,20,Blue,274
# 288,21,Blue,274
# 289,22,Blue,271
# 290,23,Blue,273
# 291,24,Blue,274
# 292,25,Blue,276
# 293,26,Blue,273
# 294,27,Blue,271
# 295,28,Blue,269
# 296,29,Blue,269
# 297,1,Black,273
# 298,2,Black,5
# 299,3,Black,4
# 300,4,Black,5
# 301,5,Black,5
# 302,6,Black,4
# 303,7,Black,4
# 304,8,Black,4
# 305,9,Black,4
# 306,10,Black,5
# 307,11,Black,6
# 308,12,Black,4
# 309,13,Black,4
# 310,14,Black,4
# 311,15,Black,5
# 312,16,Black,4
# 313,17,Black,5
# 314,18,Black,4
# 315,19,Black,4
# 316,20,Black,4
# 317,21,Black,4
# 318,22,Black,4
# 319,23,Black,5
# 320,24,Black,5
# 321,25,Black,5
# 322,26,Black,4
# 323,27,Black,4
# 324,28,Black,5
# 325,29,Black,5
# 326,30,Black,4
# 327,0,Black,4
# 328,0,Black,5
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,5
# 332,0,Black,4
# 333,0,Black,4
# 334,0,Black,4
# 335,0,Black,5
# 336,0,Black,4
# 337,0,Black,4
# 338,0,Black,4
# 339,0,Black,4
# 340,0,Black,4
# 341,0,Black,4
# 342,0,Black,4
# 343,0,Black,4
# 344,0,Black,4
# 345,0,Black,5
# 346,0,Black,4
# 347,0,Black,4
# 348,0,Black,4
# 349,0,Black,4
# 350,0,Black,5
# 351,0,Black,4
# 352,0,Black,5
# 353,0,Black,4
# 354,0,Black,4
# 355,0,Black,4
# 356,0,Black,5
# 357,1,White,4
# 358,2,White,922
# 359,3,White,932
# 360,4,White,926
# 361,5,White,928
# 362,6,White,934
# 363,7,White,930
# 364,8,White,930
# 365,9,White,935
# 366,10,White,928
# 367,11,White,925
# 368,12,White,924
# 369,13,White,928
# 370,14,White,926
# 371,15,White,921
# 372,16,White,928
# 373,17,White,933
# 374,18,White,928
# 375,19,White,921
# 376,20,White,931
# 377,21,White,930
# ...
# 331,0,Black,4
# 332,0,Black,4
# 333,0,Black,5
# 334,0,Black,5
# 335,0,Black,4
# 336,0,Black,4
# 337,0,Black,4
# 338,0,Black,4
# 339,0,Black,3
# 340,0,Black,4
# 341,0,Black,4
# 342,0,Black,5
# 343,0,Black,4
# 344,0,Black,4
# 345,0,Black,5
# 346,0,Black,5
# 347,0,Black,5
# 348,0,Black,4
# 349,0,Black,4
# 350,0,Black,4
# 351,0,Black,4
# 352,0,Black,4
# 353,0,Black,4
# 354,0,Black,4
# 355,1,White,4
# 356,2,White,943
# 357,3,White,944
# 358,4,White,944
# 359,5,White,945
# 360,6,White,945
# 361,7,White,951
# 362,8,White,947
# 363,9,White,945
# 364,10,White,945
# 365,11,White,946
# 366,12,White,950
# 367,13,White,947
# 368,14,White,951
# 369,15,White,946
# 370,16,White,951
# 371,17,White,950
# 372,18,White,953
# 373,19,White,949
# 374,20,White,946
# 375,21,White,945
# 376,22,White,946
# 377,23,White,949
# 378,24,White,950
# 379,25,White,946
# 380,26,White,946
# 381,27,White,953
# 382,28,White,947
# 383,29,White,953
# 384,30,White,950
# 385,1,Red,952
# 386,2,Red,337
# 387,3,Red,339
# 388,4,Red,336
# 389,5,Red,341
# 390,6,Red,342
# 391,7,Red,339
# 392,8,Red,339
# 393,9,Red,333
# 394,10,Red,343
# 395,11,Red,336
# 396,12,Red,339
# 397,13,Red,331
# 398,14,Red,332
# 399,15,Red,340
# 400,16,Red,338
# 401,17,Red,335
# 402,18,Red,340
# 403,19,Red,339
# 404,20,Red,339
# 405,21,Red,343
# 406,22,Red,337
# 407,23,Red,337
# 408,24,Red,339
# 409,25,Red,338
# 410,26,Red,336
# 411,27,Red,337
# 412,28,Red,341
# 413,29,Red,344
# 414,1,Green,337
# 415,2,Green,412
# 416,3,Green,419
# 417,4,Green,413
# 418,5,Green,418
# 419,6,Green,420
# 420,7,Green,419
# 421,8,Green,411
# 422,9,Green,414
# 423,10,Green,412
# 424,11,Green,416
# 425,12,Green,416
# 426,13,Green,413
# 427,14,Green,419
# 428,15,Green,414
# 429,16,Green,416
# 430,17,Green,415
# 431,18,Green,410
# 432,19,Green,414
# 433,20,Green,416
# 434,21,Green,414
# 435,22,Green,417
# 436,23,Green,415
# 437,24,Green,413
# 438,25,Green,411
# 439,26,Green,417
# 440,27,Green,420
# 441,28,Green,420
# 442,29,Green,407
# 443,30,Green,413
# 444,1,Blue,407
# 445,2,Blue,296
# 446,3,Blue,296
# 447,4,Blue,303
# 448,5,Blue,298
# 449,6,Blue,299
# 450,7,Blue,302
# 451,8,Blue,298
# 452,9,Blue,297
# 453,10,Blue,297
# 454,11,Blue,300
# 455,12,Blue,301
# 456,13,Blue,301
# 457,14,Blue,298
# 458,15,Blue,295
# 459,16,Blue,298
# 460,17,Blue,294
# 461,18,Blue,298
# 462,19,Blue,294
# 463,20,Blue,300
# 464,21,Blue,297
# 465,22,Blue,299
# 466,23,Blue,303
# 467,24,Blue,295
# 468,25,Blue,303
# 469,26,Blue,301
# 470,27,Blue,299
# 471,28,Blue,293
# 472,29,Blue,298
# 473,1,Black,297
# 474,2,Black,4
# 475,3,Black,4
# 476,4,Black,5
# 477,5,Black,5
# 478,6,Black,4
# 479,7,Black,3
# 480,8,Black,4
# 481,9,Black,4
# 482,10,Black,4
# 483,11,Black,4
# 484,12,Black,4
# 485,13,Black,3
# 486,14,Black,4
# 487,15,Black,4
# 488,16,Black,4
# 489,17,Black,4
# 490,18,Black,3
# 491,19,Black,4
# 492,20,Black,4
# 493,21,Black,4
# 494,22,Black,4
# 495,23,Black,4
# 496,24,Black,4
# 497,25,Black,4
# 498,26,Black,4
# 499,27,Black,4
# 500,28,Black,4
# 501,29,Black,4
# 502,30,Black,4
# 503,0,Black,4
# 504,0,Black,4
# 505,0,Black,4
# 506,0,Black,3
# 507,0,Black,4
# 508,0,Black,5
# 509,0,Black,4
# 510,0,Black,4
# 511,0,Black,4
# 512,0,Black,4
# 513,0,Black,4
# 514,0,Black,5
# 515,0,Black,4
# 516,0,Black,4
# 517,0,Black,3
# 518,0,Black,4
# 519,0,Black,5
# 520,0,Black,4
# 521,0,Black,4
# 522,0,Black,4
# 523,0,Black,4
# 524,0,Black,4
# 525,0,Black,4
# 526,0,Black,4
# 527,0,Black,4
# 528,0,Black,4
# 529,0,Black,5
# 530,0,Black,4
# 531,0,Black,4
# 532,1,White,4
# 533,2,White,945
# 534,3,White,950
# 535,4,White,949
# 536,5,White,945
# 537,6,White,951
# 538,7,White,950
# 539,8,White,943
# 540,9,White,951
# 541,10,White,948
# 542,11,White,951
# 543,12,White,951
# 544,13,White,953
# 545,14,White,949
# 546,15,White,952
# 547,16,White,947
# 548,17,White,949
# 549,18,White,952
# 550,19,White,948
# 551,20,White,948
# 552,21,White,948
# 553,22,White,946
# 554,23,White,949
# 555,24,White,948
# 556,25,White,947
# 557,26,White,953
# 558,27,White,948
# 559,28,White,951
# 560,29,White,950
# 561,30,White,953
# 562,1,Red,947
# 563,2,Red,341
# 564,3,Red,336
# 565,4,Red,331
# 566,5,Red,341
# 567,6,Red,339
# 568,7,Red,342
# 569,8,Red,339
# 570,9,Red,339
# 571,10,Red,339
# 572,11,Red,334
# 573,12,Red,333
# 574,13,Red,340
# 575,14,Red,339
# 576,15,Red,340
# 577,16,Red,337
# 578,17,Red,332
# 579,18,Red,341
# 580,19,Red,338
# 581,20,Red,343
# 582,21,Red,336
# 583,22,Red,342
# 584,23,Red,338
# 585,24,Red,336
# 586,25,Red,336
# 587,26,Red,334
# 588,27,Red,336
# 589,28,Red,338
# 590,29,Red,342
# 591,1,Green,332
# 592,2,Green,418
# 593,3,Green,421
# 594,4,Green,411
# 595,5,Green,418
# 596,6,Green,410
# 597,7,Green,412
# 598,8,Green,411
# 599,9,Green,418
# 600,10,Green,415
# 601,11,Green,406
# 602,12,Green,412
# 603,13,Green,411
# 604,14,Green,410
# 605,15,Green,411
# 606,16,Green,408
# 607,17,Green,408
# 608,18,Green,407
# 609,19,Green,414
# 610,20,Green,413
# 611,21,Green,418
# 612,22,Green,415
# 613,23,Green,416
# 614,24,Green,416
# 615,25,Green,412
# 616,26,Green,419
# 617,27,Green,414
# 618,28,Green,411
# 619,29,Green,413
# 620,30,Green,411
# 621,1,Blue,413
# 622,2,Blue,295
# 623,3,Blue,297
# 624,4,Blue,295
# 625,5,Blue,296
# 626,6,Blue,297
# 627,7,Blue,300
# 628,8,Blue,303
# 629,9,Blue,302
# 630,10,Blue,302
# 631,11,Blue,297
# 632,12,Blue,301
# 633,13,Blue,296
# 634,14,Blue,297
# 635,15,Blue,299
# 636,16,Blue,296
# 637,17,Blue,296
# 638,18,Blue,303
# 639,19,Blue,295
# 640,20,Blue,296
# 641,21,Blue,300
# 642,22,Blue,296
# 643,23,Blue,299
# 644,24,Blue,297
# 645,25,Blue,297
# 646,26,Blue,303
# 647,27,Blue,301
# 648,28,Blue,299
# 649,29,Blue,296
# 650,1,Black,300
# 651,2,Black,5
# 652,3,Black,4
# 653,4,Black,4
# 654,5,Black,3
# 655,6,Black,3
# 656,7,Black,4
# 657,8,Black,4
# 658,9,Black,5
# 659,10,Black,4
# 660,11,Black,4
# 661,12,Black,4
# 662,13,Black,4
# 663,14,Black,4
# 664,15,Black,4
# 665,16,Black,5
# 666,17,Black,4
# 667,18,Black,4
# 668,19,Black,3
# 669,20,Black,3
# 670,21,Black,4
# 671,22,Black,4
# 672,23,Black,4
# 673,24,Black,5
# 674,25,Black,4
# 675,26,Black,5
# 676,27,Black,3
# 677,28,Black,4
# 678,29,Black,4
# 679,30,Black,5
# 680,0,Black,3
#
# ==================================================
#
# ไฟล์: N/N4_W.txt
# N_4_WaterPure water tube 5ml   No reagent :08/10/2023,16:10:06
# 1,1,White,4
# 2,2,White,943
# 3,3,White,944
# 4,4,White,946
# 5,5,White,948
# 6,6,White,944
# 7,7,White,946
# 8,8,White,942
# 9,9,White,950
# 10,10,White,947
# 11,11,White,943
# 12,12,White,945
# 13,13,White,945
# 14,14,White,948
# 15,15,White,950
# 16,16,White,942
# 17,17,White,947
# 18,18,White,937
# 19,19,White,943
# 20,20,White,942
# 21,21,White,947
# 22,22,White,942
# 23,23,White,947
# 24,24,White,945
# 25,25,White,943
# 26,26,White,942
# 27,27,White,941
# 28,28,White,943
# 29,29,White,949
# 30,1,Red,942
# 31,2,Red,336
# 32,3,Red,335
# 33,4,Red,338
# 34,5,Red,335
# 35,6,Red,336
# 36,7,Red,337
# 37,8,Red,332
# 38,9,Red,336
# 39,10,Red,335
# 40,11,Red,336
# 41,12,Red,335
# 42,13,Red,333
# 43,14,Red,332
# 44,15,Red,330
# 45,16,Red,330
# 46,17,Red,334
# 47,18,Red,331
# 48,19,Red,332
# 49,20,Red,336
# 50,21,Red,336
# 51,22,Red,331
# 52,23,Red,332
# 53,24,Red,335
# 54,25,Red,330
# 55,26,Red,333
# 56,27,Red,327
# 57,28,Red,332
# 58,29,Red,336
# 59,30,Red,326
# 60,1,Green,334
# 61,2,Green,413
# 62,3,Green,414
# 63,4,Green,413
# 64,5,Green,412
# 65,6,Green,417
# 66,7,Green,417
# 67,8,Green,409
# 68,9,Green,414
# 69,10,Green,418
# 70,11,Green,413
# 71,12,Green,413
# 72,13,Green,412
# 73,14,Green,418
# 74,15,Green,416
# 75,16,Green,417
# 76,17,Green,413
# 77,18,Green,416
# 78,19,Green,416
# 79,20,Green,417
# 80,21,Green,410
# 81,22,Green,418
# 82,23,Green,414
# 83,24,Green,413
# 84,25,Green,417
# 85,26,Green,411
# 86,27,Green,415
# 87,28,Green,415
# 88,29,Green,412
# 89,30,Green,414
# 90,1,Blue,414
# 91,2,Blue,280
# 92,3,Blue,286
# 93,4,Blue,283
# 94,5,Blue,289
# 95,6,Blue,287
# 96,7,Blue,284
# 97,8,Blue,283
# 98,9,Blue,283
# 99,10,Blue,282
# 100,11,Blue,285
# 101,12,Blue,281
# 102,13,Blue,287
# 103,14,Blue,281
# 104,15,Blue,283
# 105,16,Blue,285
# 106,17,Blue,288
# 107,18,Blue,286
# 108,19,Blue,287
# 109,20,Blue,286
# 110,21,Blue,285
# 111,22,Blue,286
# 112,23,Blue,291
# 113,24,Blue,288
# 114,25,Blue,286
# 115,26,Blue,284
# 116,27,Blue,285
# 117,28,Blue,286
# 118,29,Blue,289
# 119,1,Black,288
# 120,2,Black,5
# 121,3,Black,4
# 122,4,Black,5
# 123,5,Black,4
# 124,6,Black,4
# 125,7,Black,5
# 126,8,Black,5
# 127,9,Black,4
# 128,10,Black,4
# 129,11,Black,4
# 130,12,Black,4
# 131,13,Black,5
# 132,14,Black,4
# 133,15,Black,4
# 134,16,Black,4
# 135,17,Black,4
# 136,18,Black,5
# 137,19,Black,4
# 138,20,Black,4
# 139,21,Black,5
# 140,22,Black,5
# 141,23,Black,5
# 142,24,Black,4
# 143,25,Black,4
# 144,26,Black,5
# 145,27,Black,4
# 146,28,Black,4
# 147,29,Black,5
# 148,30,Black,4
# 149,0,Black,4
# 150,0,Black,4
# 151,0,Black,4
# 152,0,Black,5
# 153,0,Black,4
# 154,0,Black,4
# 155,0,Black,4
# 156,0,Black,4
# 157,0,Black,4
# 158,0,Black,5
# 159,0,Black,4
# 160,0,Black,4
# 161,0,Black,4
# 162,0,Black,5
# 163,0,Black,4
# 164,0,Black,5
# 165,0,Black,4
# 166,0,Black,4
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black,4
# 171,0,Black,4
# 172,0,Black,5
# 173,0,Black,4
# 174,0,Black,4
# 175,0,Black,4
# 176,0,Black,4
# 177,0,Black,5
# 178,0,Black,5
# 179,1,White,4
# 180,2,White,949
# 181,3,White,944
# 182,4,White,944
# 183,5,White,945
# 184,6,White,937
# 185,7,White,946
# 186,8,White,943
# 187,9,White,944
# 188,10,White,946
# 189,11,White,949
# 190,12,White,942
# 191,13,White,950
# 192,14,White,947
# 193,15,White,946
# 194,16,White,943
# 195,17,White,946
# 196,18,White,942
# 197,19,White,941
# 198,20,White,945
# 199,21,White,942
# 200,22,White,942
# 201,23,White,945
# 202,24,White,943
# 203,25,White,944
# 204,26,White,945
# 205,27,White,946
# 206,28,White,945
# 207,29,White,949
# 208,1,Red,943
# 209,2,Red,331
# 210,3,Red,332
# 211,4,Red,334
# 212,5,Red,326
# 213,6,Red,334
# 214,7,Red,333
# 215,8,Red,337
# 216,9,Red,334
# 217,10,Red,329
# 218,11,Red,332
# 219,12,Red,331
# 220,13,Red,335
# 221,14,Red,335
# 222,15,Red,336
# 223,16,Red,331
# 224,17,Red,330
# 225,18,Red,338
# 226,19,Red,329
# 227,20,Red,330
# 228,21,Red,333
# 229,22,Red,333
# 230,23,Red,331
# 231,24,Red,329
# 232,25,Red,331
# 233,26,Red,336
# 234,27,Red,332
# 235,28,Red,335
# 236,29,Red,332
# 237,30,Red,325
# 238,1,Green,334
# 239,2,Green,419
# 240,3,Green,413
# 241,4,Green,414
# 242,5,Green,414
# 243,6,Green,413
# 244,7,Green,416
# 245,8,Green,410
# 246,9,Green,414
# 247,10,Green,412
# 248,11,Green,414
# 249,12,Green,419
# 250,13,Green,416
# 251,14,Green,416
# 252,15,Green,416
# 253,16,Green,413
# 254,17,Green,409
# 255,18,Green,416
# 256,19,Green,420
# 257,20,Green,413
# 258,21,Green,414
# 259,22,Green,418
# 260,23,Green,421
# 261,24,Green,414
# 262,25,Green,412
# 263,26,Green,413
# 264,27,Green,418
# 265,28,Green,411
# 266,29,Green,416
# 267,30,Green,413
# 268,1,Blue,416
# 269,2,Blue,283
# 270,3,Blue,286
# 271,4,Blue,285
# 272,5,Blue,285
# 273,6,Blue,286
# 274,7,Blue,289
# 275,8,Blue,284
# 276,9,Blue,285
# 277,10,Blue,284
# 278,11,Blue,289
# 279,12,Blue,283
# 280,13,Blue,289
# 281,14,Blue,287
# 282,15,Blue,290
# 283,16,Blue,282
# 284,17,Blue,282
# 285,18,Blue,285
# 286,19,Blue,284
# 287,20,Blue,291
# 288,21,Blue,290
# 289,22,Blue,288
# 290,23,Blue,289
# 291,24,Blue,285
# 292,25,Blue,286
# 293,26,Blue,284
# 294,27,Blue,290
# 295,28,Blue,287
# 296,29,Blue,288
# 297,1,Black,282
# 298,2,Black,4
# 299,3,Black,5
# 300,4,Black,5
# 301,5,Black,4
# 302,6,Black,4
# 303,7,Black,4
# 304,8,Black,4
# 305,9,Black,4
# 306,10,Black,4
# 307,11,Black,4
# 308,12,Black,5
# 309,13,Black,4
# 310,14,Black,5
# 311,15,Black,4
# 312,16,Black,4
# 313,17,Black,4
# 314,18,Black,4
# 315,19,Black,4
# 316,20,Black,4
# 317,21,Black,4
# 318,22,Black,5
# 319,23,Black,4
# 320,24,Black,5
# 321,25,Black,4
# 322,26,Black,4
# 323,27,Black,4
# 324,28,Black,5
# 325,29,Black,4
# 326,30,Black,5
# 327,0,Black,4
# 328,0,Black,5
# 329,0,Black,4
# 330,0,Black,5
# 331,0,Black,4
# 332,0,Black,4
# 333,0,Black,5
# 334,0,Black,5
# 335,0,Black,4
# 336,0,Black,4
# 337,0,Black,5
# 338,0,Black,5
# 339,0,Black,5
# 340,0,Black,4
# 341,0,Black,4
# 342,0,Black,5
# 343,0,Black,4
# 344,0,Black,5
# 345,0,Black,4
# 346,0,Black,4
# 347,0,Black,5
# 348,0,Black,4
# 349,0,Black,5
# 350,0,Black,5
# 351,0,Black,4
# 352,0,Black,4
# 353,0,Black,4
# 354,0,Black,4
# 355,0,Black,4
# 356,0,Black,5
# 357,1,White,4
# 358,2,White,940
# 359,3,White,943
# 360,4,White,944
# 361,5,White,946
# 362,6,White,943
# 363,7,White,942
# 364,8,White,947
# 365,9,White,945
# 366,10,White,948
# 367,11,White,946
# 368,12,White,942
# 369,13,White,941
# 370,14,White,943
# 371,15,White,946
# 372,16,White,940
# 373,17,White,940
# 374,18,White,940
# 375,19,White,945
# 376,20,White,941
# 377,21,White,943
# 378,22,White,946
# 379,23,White,939
# 380,24,White,943
# 381,25,White,946
# 382,26,White,942
# 383,27,White,942
# 384,28,White,949
# 385,29,White,941
# 386,1,Red,942
# 387,2,Red,325
# 388,3,Red,333
# 389,4,Red,335
# 390,5,Red,335
# 391,6,Red,329
# 392,7,Red,332
# 393,8,Red,337
# 394,9,Red,330
# 395,10,Red,335
# 396,11,Red,334
# 397,12,Red,331
# 398,13,Red,331
# 399,14,Red,329
# 400,15,Red,328
# 401,16,Red,328
# 402,17,Red,330
# 403,18,Red,333
# 404,19,Red,328
# 405,20,Red,331
# 406,21,Red,331
# 407,22,Red,325
# 408,23,Red,327
# 409,24,Red,328
# 410,25,Red,330
# 411,26,Red,332
# 412,27,Red,330
# 413,28,Red,328
# 414,29,Red,327
# 415,30,Red,333
# 416,1,Green,335
# 417,2,Green,421
# 418,3,Green,415
# 419,4,Green,419
# 420,5,Green,417
# 421,6,Green,413
# 422,7,Green,412
# 423,8,Green,416
# 424,9,Green,412
# 425,10,Green,413
# 426,11,Green,411
# 427,12,Green,417
# 428,13,Green,415
# 429,14,Green,414
# 430,15,Green,418
# 431,16,Green,416
# 432,17,Green,414
# 433,18,Green,416
# 434,19,Green,416
# 435,20,Green,416
# 436,21,Green,413
# 437,22,Green,412
# 438,23,Green,410
# 439,24,Green,413
# 440,25,Green,416
# 441,26,Green,408
# 442,27,Green,417
# 443,28,Green,414
# 444,29,Green,413
# 445,30,Green,412
# 446,1,Blue,418
# 447,2,Blue,285
# 448,3,Blue,289
# 449,4,Blue,290
# 450,5,Blue,290
# 451,6,Blue,284
# 452,7,Blue,285
# 453,8,Blue,287
# 454,9,Blue,285
# 455,10,Blue,289
# 456,11,Blue,282
# 457,12,Blue,285
# 458,13,Blue,286
# 459,14,Blue,291
# 460,15,Blue,284
# 461,16,Blue,289
# 462,17,Blue,285
# 463,18,Blue,289
# 464,19,Blue,290
# 465,20,Blue,289
# 466,21,Blue,288
# 467,22,Blue,286
# 468,23,Blue,291
# 469,24,Blue,289
# 470,25,Blue,285
# 471,26,Blue,284
# 472,27,Blue,289
# 473,28,Blue,287
# 474,29,Blue,288
# 475,1,Black,285
# 476,2,Black,5
# 477,3,Black,4
# 478,4,Black,4
# 479,5,Black,5
# 480,6,Black,5
# 481,7,Black,5
# 482,8,Black,4
# 483,9,Black,5
# 484,10,Black,5
# 485,11,Black,4
# 486,12,Black,5
# 487,13,Black,5
# 488,14,Black,4
# 489,15,Black,4
# 490,16,Black,4
# 491,17,Black,6
# 492,18,Black,5
# 493,19,Black,4
# 494,20,Black,4
# 495,21,Black,4
# 496,22,Black,5
# 497,23,Black,5
# 498,24,Black,4
# 499,25,Black,4
# 500,26,Black,4
# 501,27,Black,3
# 502,28,Black,4
# 503,29,Black,4
# 504,30,Black,5
# 505,0,Black,6
# 506,0,Black,4
# 507,0,Black,4
# 508,0,Black,4
# 509,0,Black,4
# 510,0,Black,5
# 511,0,Black,4
# 512,0,Black,4
# 513,0,Black,4
# 514,0,Black,4
# 515,0,Black,5
# 516,0,Black,5
# 517,0,Black,4
# 518,0,Black,4
# 519,0,Black,4
# 520,0,Black,4
# 521,0,Black,4
# 522,0,Black,3
# 523,0,Black,4
# 524,0,Black,4
# 525,0,Black,5
# 526,0,Black,4
# 527,0,Black,4
# 528,0,Black,4
# 529,0,Black,4
# 530,0,Black,4
# 531,0,Black,4
# 532,0,Black,4
# 533,0,Black,4
# 534,0,Black,4
# 535,1,White,5
# 536,2,White,947
# 537,3,White,936
# 538,4,White,948
# 539,5,White,936
# 540,6,White,942
# 541,7,White,940
# 542,8,White,940
# 543,9,White,947
# 544,10,White,943
# 545,11,White,942
# 546,12,White,942
# 547,13,White,937
# 548,14,White,946
# 549,15,White,946
# 550,16,White,944
# 551,17,White,941
# 552,18,White,943
# 553,19,White,944
# 554,20,White,941
# 555,21,White,945
# 556,22,White,948
# 557,23,White,948
# 558,24,White,943
# 559,25,White,938
# 560,26,White,939
# 561,27,White,943
# 562,28,White,944
# 563,29,White,937
# 564,1,Red,940
# 565,2,Red,330
# 566,3,Red,333
# 567,4,Red,330
# 568,5,Red,328
# 569,6,Red,329
# 570,7,Red,334
# 571,8,Red,336
# 572,9,Red,328
# 573,10,Red,330
# 574,11,Red,328
# 575,12,Red,336
# 576,13,Red,337
# 577,14,Red,327
# 578,15,Red,334
# 579,16,Red,334
# 580,17,Red,330
# 581,18,Red,328
# 582,19,Red,332
# 583,20,Red,328
# 584,21,Red,331
# 585,22,Red,331
# 586,23,Red,330
# 587,24,Red,328
# 588,25,Red,332
# 589,26,Red,328
# 590,27,Red,332
# 591,28,Red,326
# 592,29,Red,335
# 593,30,Red,332
# 594,1,Green,334
# 595,2,Green,412
# 596,3,Green,407
# 597,4,Green,417
# 598,5,Green,415
# 599,6,Green,420
# 600,7,Green,415
# 601,8,Green,415
# 602,9,Green,415
# 603,10,Green,412
# 604,11,Green,409
# 605,12,Green,414
# 606,13,Green,409
# 607,14,Green,419
# 608,15,Green,409
# 609,16,Green,410
# 610,17,Green,419
# 611,18,Green,417
# 612,19,Green,414
# 613,20,Green,413
# 614,21,Green,414
# 615,22,Green,416
# 616,23,Green,420
# 617,24,Green,414
# 618,25,Green,412
# 619,26,Green,412
# 620,27,Green,418
# 621,28,Green,412
# 622,29,Green,416
# 623,30,Green,416
# 624,1,Blue,417
# 625,2,Blue,284
# 626,3,Blue,282
# 627,4,Blue,291
# 628,5,Blue,289
# 629,6,Blue,286
# 630,7,Blue,285
# 631,8,Blue,283
# 632,9,Blue,284
# 633,10,Blue,283
# 634,11,Blue,287
# 635,12,Blue,288
# 636,13,Blue,286
# 637,14,Blue,286
# 638,15,Blue,290
# 639,16,Blue,289
# 640,17,Blue,288
# 641,18,Blue,289
# 642,19,Blue,291
# 643,20,Blue,284
# 644,21,Blue,285
# 645,22,Blue,284
# 646,23,Blue,287
# 647,24,Blue,284
# 648,25,Blue,292
# 649,26,Blue,289
# 650,27,Blue,285
# 651,28,Blue,279
# 652,29,Blue,286
# 653,1,Black,284
# 654,2,Black,4
# 655,3,Black,4
# 656,4,Black,4
# 657,5,Black,4
# 658,6,Black,4
# 659,7,Black,4
# 660,8,Black,4
# 661,9,Black,4
# 662,10,Black,4
# 663,11,Black,4
# 664,12,Black,4
# 665,13,Black,5
# 666,14,Black,5
# 667,15,Black,4
# 668,16,Black,5
# 669,17,Black,4
# 670,18,Black,4
# 671,19,Black,4
# 672,20,Black,5
# 673,21,Black,4
# 674,22,Black,4
# 675,23,Black,4
# 676,24,Black,4
# 677,25,Black,4
# 678,26,Black,4
# 679,27,Black,5
# 680,28,Black,5
#
# ==================================================

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "NdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Convert the 'Intensity' column to integers
    df['Intensity'] = df['Intensity'].astype(int)

    # Save the modified DataFrame back to the CSV file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'NdatasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to NdatasetCSV/N2_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N10_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N20_W.csv
# Modified DataFrame saved to NdatasetCSV/N2_W.csv
# Modified DataFrame saved to NdatasetCSV/N60_W.csv
# Modified DataFrame saved to NdatasetCSV/N8_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N4_W.csv
# Modified DataFrame saved to NdatasetCSV/N60_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N40_W.csv
# Modified DataFrame saved to NdatasetCSV/N80_W.csv
# Modified DataFrame saved to NdatasetCSV/N6_W.csv
# Modified DataFrame saved to NdatasetCSV/N10_W.csv
# Modified DataFrame saved to NdatasetCSV/N8_W.csv
# Modified DataFrame saved to NdatasetCSV/N20_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N4_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N80_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N40_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N6_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N100_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N100_W.csv
# All CSV files in the 'NdatasetCSV' folder have been processed.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "NdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Iterate through each CSV file and process it
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Filter and remove rows where 'Order' is in the specified values (1,2,3,4,5,25,26, 27, 28, 29, 30)
    df = df[~df['Order'].isin([25,26, 27, 28, 29, 30])]

    # Save the modified DataFrame back to the same file
    df.to_csv(file_path, index=False)

    # Report the file name and the number of rows after the removal
    print(f"File: {csv_file}, Rows After Removal: {len(df)}")
# Out:
# File: N2_NoR.csv, Rows After Removal: 480
# File: N10_NoR.csv, Rows After Removal: 480
# File: N20_W.csv, Rows After Removal: 480
# File: N2_W.csv, Rows After Removal: 480
# File: N60_W.csv, Rows After Removal: 480
# File: N8_NoR.csv, Rows After Removal: 480
# File: N4_W.csv, Rows After Removal: 480
# File: N60_NoR.csv, Rows After Removal: 480
# File: N40_W.csv, Rows After Removal: 480
# File: N80_W.csv, Rows After Removal: 480
# File: N6_W.csv, Rows After Removal: 480
# File: N10_W.csv, Rows After Removal: 480
# File: N8_W.csv, Rows After Removal: 480
# File: N20_NoR.csv, Rows After Removal: 480
# File: N4_NoR.csv, Rows After Removal: 480
# File: N80_NoR.csv, Rows After Removal: 480
# File: N40_NoR.csv, Rows After Removal: 480
# File: N6_NoR.csv, Rows After Removal: 480
# File: N100_NoR.csv, Rows After Removal: 480
# File: N100_W.csv, Rows After Removal: 480
