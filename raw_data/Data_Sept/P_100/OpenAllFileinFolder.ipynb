# %% [markdown]
# โค้ดแสดงข้อมูลจากไฟล์ทั้งหมดในโฟลเดอร์ "raw_data" ที่มีนามสกุล ".txt" โดยแสดงข้อมูลของแต่ละไลน์ในแต่ละไฟล์ และเพิ่มบรรทัดว่างหลังจากแต่ละไฟล์เพื่อให้ข้อมูลดูเรียบร้อยขึ้นในผลลัพธ์ที่แสดงออกมาแบบเป็นรายการตามไฟล์ที่อยู่ในโฟลเดอร์ "raw_data" ทั้งหมด.

# %%
import os

# ระบุโฟลเดอร์ raw_data
folder_path = "raw_data"

# ตรวจสอบว่าโฟลเดอร์นี้มีอยู่จริงหรือไม่
if os.path.exists(folder_path):
    # รายการไฟล์ในโฟลเดอร์
    files = os.listdir(folder_path)

    # วนลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์
    for filename in files:
        file_path = os.path.join(folder_path, filename)

        # ตรวจสอบว่าไฟล์นี้เป็นไฟล์ข้อความหรือไม่
        if filename.endswith(".txt"):
            print(f"แสดงข้อมูลจากไฟล์ '{filename}':")
            
            # เปิดไฟล์สำหรับอ่าน
            with open(file_path, "r") as text_file:
                # อ่านและแสดงข้อมูลของแต่ละไลน์
                for line in text_file:
                    print(line.strip())  # ใช้ strip() เพื่อลบช่องว่างที่อาจจะเกิดขึ้น

            print("\n")  # เพิ่มบรรทัดว่างหลังจากแสดงข้อมูลของแต่ละไฮน์
else:
    print(f"โฟลเดอร์ '{folder_path}' ไม่มีอยู่หรือไม่สามารถเข้าถึงได้")
# Out:
# แสดงข้อมูลจากไฟล์ 'P100_day1.txt':
# Phosphorus_concentrate 100 mg/L RepeatOld1
# 1,1,White,4
# 2,2,White,129
# 3,3,White,124
# 4,4,White,125
# 5,5,White,124
# 6,6,White,126
# 7,7,White,125
# 8,8,White,125
# 9,9,White,128
# 10,10,White,125
# 11,11,White,129
# 12,12,White,124
# 13,13,White,128
# 14,14,White,126
# 15,1,Red,130
# 16,2,Red,55
# 17,3,Red,55
# 18,4,Red,55
# 19,5,Red,56
# 20,6,Red,56
# 21,7,Red,52
# 22,8,Red,51
# 23,9,Red,51
# 24,10,Red,53
# 25,11,Red,52
# 26,12,Red,54
# 27,13,Red,52
# 28,14,Red,53
# 29,15,Red,53
# 30,1,Green,53
# 31,2,Green,60
# 32,3,Green,55
# 33,4,Green,60
# 34,5,Green,58
# 35,6,Green,56
# 36,7,Green,55
# 37,8,Green,55
# 38,9,Green,57
# 39,10,Green,56
# 40,11,Green,55
# 41,12,Green,56
# 42,13,Green,57
# 43,14,Green,54
# 44,15,Green,56
# 45,1,Blue,59
# 46,2,Blue,23
# 47,3,Blue,21
# 48,4,Blue,23
# 49,5,Blue,21
# 50,6,Blue,25
# 51,7,Blue,23
# 52,8,Blue,23
# 53,9,Blue,26
# 54,10,Blue,23
# 55,11,Blue,22
# 56,12,Blue,26
# 57,13,Blue,23
# 58,14,Blue,25
# 59,1,Black,25
# 60,2,Black,3
# 61,3,Black,4
# 62,4,Black,4
# 63,5,Black,4
# 64,6,Black,4
# 65,7,Black,3
# 66,8,Black,4
# 67,9,Black,4
# 68,10,Black,4
# 69,11,Black,3
# 70,12,Black,4
# 71,13,Black,4
# 72,14,Black,5
# 73,15,Black,5
# 74,0,Black,3
# 75,0,Black,3
# 76,0,Black,4
# 77,0,Black,4
# 78,0,Black,3
# 79,0,Black,5
# 80,0,Black,4
# 81,0,Black,4
# 82,0,Black,4
# 83,0,Black,4
# 84,0,Black,4
# 85,0,Black,4
# 86,0,Black,5
# 87,0,Black,3
# 88,0,Black,3
# 89,1,White,4
# 90,2,White,125
# 91,3,White,128
# 92,4,White,128
# 93,5,White,122
# 94,6,White,125
# 95,7,White,126
# 96,8,White,123
# 97,9,White,124
# 98,10,White,129
# 99,11,White,125
# 100,12,White,121
# 101,13,White,124
# 102,14,White,124
# 103,1,Red,129
# 104,2,Red,56
# 105,3,Red,53
# 106,4,Red,50
# 107,5,Red,50
# 108,6,Red,51
# 109,7,Red,51
# 110,8,Red,56
# 111,9,Red,51
# 112,10,Red,54
# 113,11,Red,51
# 114,12,Red,53
# 115,13,Red,53
# 116,14,Red,53
# 117,15,Red,54
# 118,1,Green,50
# 119,2,Green,58
# 120,3,Green,57
# 121,4,Green,58
# 122,5,Green,59
# 123,6,Green,54
# 124,7,Green,55
# 125,8,Green,55
# 126,9,Green,55
# 127,10,Green,57
# 128,11,Green,56
# 129,12,Green,57
# 130,13,Green,59
# 131,14,Green,54
# 132,15,Green,57
# 133,1,Blue,57
# 134,2,Blue,24
# 135,3,Blue,24
# 136,4,Blue,22
# 137,5,Blue,25
# 138,6,Blue,24
# 139,7,Blue,24
# 140,8,Blue,23
# 141,9,Blue,22
# 142,10,Blue,22
# 143,11,Blue,23
# 144,12,Blue,22
# 145,13,Blue,24
# 146,14,Blue,20
# 147,1,Black,25
# 148,2,Black,4
# 149,3,Black,4
# 150,4,Black,4
# 151,5,Black,3
# 152,6,Black,4
# 153,7,Black,3
# 154,8,Black,4
# 155,9,Black,4
# 156,10,Black,4
# 157,11,Black,4
# 158,12,Black,3
# 159,13,Black,4
# 160,14,Black,5
# 161,15,Black,4
# 162,0,Black,4
# 163,0,Black,5
# 164,0,Black,4
# 165,0,Black,4
# 166,0,Black,3
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,3
# 170,0,Black,4
# 171,0,Black,4
# 172,0,Black,5
# 173,0,Black,3
# 174,0,Black,4
# 175,0,Black,4
# 176,0,Black,4
# 177,1,White,3
# 178,2,White,123
# 179,3,White,124
# 180,4,White,125
# 181,5,White,122
# 182,6,White,123
# 183,7,White,124
# 184,8,White,124
# 185,9,White,125
# 186,10,White,125
# 187,11,White,125
# 188,12,White,124
# 189,13,White,125
# 190,14,White,122
# 191,15,White,123
# 192,1,Red,122
# 193,2,Red,52
# 194,3,Red,52
# 195,4,Red,50
# 196,5,Red,53
# 197,6,Red,52
# 198,7,Red,54
# 199,8,Red,51
# 200,9,Red,54
# 201,10,Red,53
# 202,11,Red,52
# 203,12,Red,51
# 204,13,Red,55
# 205,14,Red,55
# 206,1,Green,52
# 207,2,Green,57
# 208,3,Green,57
# 209,4,Green,59
# 210,5,Green,55
# 211,6,Green,59
# 212,7,Green,55
# 213,8,Green,56
# 214,9,Green,58
# 215,10,Green,56
# 216,11,Green,54
# 217,12,Green,57
# 218,13,Green,55
# 219,14,Green,58
# 220,15,Green,55
# 221,1,Blue,55
# 222,2,Blue,25
# 223,3,Blue,24
# 224,4,Blue,22
# 225,5,Blue,23
# 226,6,Blue,23
# 227,7,Blue,25
# 228,8,Blue,24
# 229,9,Blue,25
# 230,10,Blue,25
# 231,11,Blue,24
# 232,12,Blue,22
# 233,13,Blue,22
# 234,14,Blue,23
# 235,15,Blue,22
# 236,1,Black,23
# 237,2,Black,5
# 238,3,Black,4
# 239,4,Black,5
# 240,5,Black,4
# 241,6,Black,4
# 242,7,Black,4
# 243,8,Black,4
# 244,9,Black,3
# 245,10,Black,5
# 246,11,Black,3
# 247,12,Black,4
# 248,13,Black,5
# 249,14,Black,3
# 250,0,Black,5
# 251,0,Black,4
# 252,0,Black,4
# 253,0,Black,4
# 254,0,Black,4
# 255,0,Black,4
# 256,0,Black,4
# 257,0,Black,4
# 258,0,Black,4
# 259,0,Black,3
# 260,0,Black,4
# 261,0,Black,4
# 262,0,Black,4
# 263,0,Black,4
# 264,0,Black,3
# 265,1,White,4
# 266,2,White,122
# 267,3,White,126
# 268,4,White,124
# 269,5,White,123
# 270,6,White,121
# 271,7,White,123
# 272,8,White,123
# 273,9,White,122
# 274,10,White,122
# 275,11,White,126
# 276,12,White,125
# 277,13,White,122
# 278,14,White,126
# 279,15,White,122
# 280,1,Red,124
# 281,2,Red,52
# 282,3,Red,51
# 283,4,Red,50
# 284,5,Red,55
# 285,6,Red,53
# 286,7,Red,52
# 287,8,Red,52
# 288,9,Red,51
# 289,10,Red,51
# 290,11,Red,49
# 291,12,Red,54
# 292,13,Red,52
# 293,14,Red,51
# 294,1,Green,49
# 295,2,Green,58
# 296,3,Green,54
# 297,4,Green,55
# 298,5,Green,58
# 299,6,Green,55
# 300,7,Green,55
# 301,8,Green,59
# 302,9,Green,55
# 303,10,Green,57
# 304,11,Green,54
# 305,12,Green,54
# 306,13,Green,54
# 307,14,Green,55
# 308,15,Green,57
# 309,1,Blue,58
# 310,2,Blue,22
# 311,3,Blue,25
# 312,4,Blue,25
# 313,5,Blue,22
# 314,6,Blue,24
# 315,7,Blue,22
# 316,8,Blue,25
# 317,9,Blue,22
# 318,10,Blue,22
# 319,11,Blue,24
# 320,12,Blue,21
# 321,13,Blue,21
# 322,14,Blue,23
# 323,15,Blue,22
# 324,1,Black,23
# 325,2,Black,3
# 326,3,Black,5
# 327,4,Black,3
# 328,5,Black,3
# 329,6,Black,3
# 330,7,Black,4
# 331,8,Black,4
# 332,9,Black,4
# 333,10,Black,4
# 334,11,Black,4
# 335,12,Black,5
# 336,13,Black,4
# 337,14,Black,4
# 338,0,Black,4
# 339,0,Black,3
# 340,0,Black,5
# 341,0,Black,4
# 342,0,Black,4
# 343,0,Black,3
# 344,0,Black,3
# 345,0,Black,4
# 346,0,Black,4
# 347,0,Black,5
# 348,0,Black,4
# 349,0,Black,3
# 350,0,Black,4
# 351,0,Black,4
# 352,0,Black,4
# 353,1,White,4
# 354,2,White,124
# 355,3,White,125
# 356,4,White,123
# 357,5,White,128
# 358,6,White,124
# 359,7,White,128
# 360,8,White,121
# 361,9,White,121
# 362,10,White,120
# 363,11,White,124
# 364,12,White,120
# 365,13,White,124
# 366,14,White,125
# 367,15,White,120
# 368,1,Red,121
# 369,2,Red,52
# 370,3,Red,53
# 371,4,Red,50
# 372,5,Red,51
# 373,6,Red,55
# 374,7,Red,55
# 375,8,Red,54
# 376,9,Red,49
# 377,10,Red,54
# 378,11,Red,51
# 379,12,Red,52
# 380,13,Red,52
# 381,14,Red,53
# 382,15,Red,52
# 383,1,Green,52
# 384,2,Green,56
# 385,3,Green,55
# 386,4,Green,56
# 387,5,Green,59
# 388,6,Green,56
# 389,7,Green,57
# 390,8,Green,57
# 391,9,Green,57
# 392,10,Green,57
# 393,11,Green,57
# 394,12,Green,56
# 395,13,Green,56
# 396,14,Green,59
# 397,1,Blue,53
# 398,2,Blue,22
# 399,3,Blue,22
# 400,4,Blue,25
# 401,5,Blue,23
# 402,6,Blue,23
# 403,7,Blue,22
# 404,8,Blue,24
# 405,9,Blue,25
# 406,10,Blue,22
# 407,11,Blue,21
# 408,12,Blue,23
# 409,13,Blue,23
# 410,14,Blue,22
# 411,15,Blue,23
# 412,1,Black,24
# 413,2,Black,4
# 414,3,Black,3
# 415,4,Black,3
# 416,5,Black,4
# 417,6,Black,3
# 418,7,Black,4
# 419,8,Black,4
# 420,9,Black,4
# 421,10,Black,4
# 422,11,Black,4
# 423,12,Black,3
# 424,13,Black,3
# 425,14,Black,5
# 426,15,Black,4
# 427,0,Black,4
# 428,0,Black,5
# 429,0,Black,4
# 430,0,Black,3
# 431,0,Black,4
# 432,0,Black,5
# 433,0,Black,4
# 434,0,Black,4
# 435,0,Black,3
# 436,0,Black,4
# 437,0,Black,3
# 438,0,Black,3
# 439,0,Black,3
# 440,0,Black,4
# 441,1,White,4
# 442,2,White,122
# 443,3,White,120
# 444,4,White,126
# 445,5,White,120
# 446,6,White,126
# 447,7,White,121
# 448,8,White,120
# 449,9,White,123
# 450,10,White,119
# 451,11,White,121
# 452,12,White,121
# 453,13,White,127
# 454,14,White,123
# 455,15,White,122
# 456,1,Red,122
# 457,2,Red,55
# 458,3,Red,50
# 459,4,Red,54
# 460,5,Red,50
# 461,6,Red,54
# 462,7,Red,51
# 463,8,Red,53
# 464,9,Red,50
# 465,10,Red,51
# 466,11,Red,51
# 467,12,Red,49
# 468,13,Red,50
# 469,14,Red,53
# 470,15,Red,51
# 471,1,Green,52
# 472,2,Green,54
# 473,3,Green,56
# 474,4,Green,55
# 475,5,Green,55
# 476,6,Green,58
# 477,7,Green,55
# 478,8,Green,55
# 479,9,Green,54
# 480,10,Green,57
# 481,11,Green,58
# 482,12,Green,56
# 483,13,Green,60
# 484,14,Green,55
# 485,1,Blue,55
# 486,2,Blue,22
# 487,3,Blue,23
# 488,4,Blue,23
# 489,5,Blue,24
# 490,6,Blue,25
# 491,7,Blue,21
# 492,8,Blue,21
# 493,9,Blue,22
# 494,10,Blue,21
# 495,11,Blue,24
# 496,12,Blue,21
# 497,13,Blue,24
# 498,14,Blue,25
# 499,15,Blue,21
# 500,1,Black,23
# 501,2,Black,4
# 502,3,Black,4
# 503,4,Black,4
# 504,5,Black,4
# 505,6,Black,4
# 506,7,Black,4
# 507,8,Black,4
# 508,9,Black,4
# 509,10,Black,3
# 510,11,Black,4
# 511,12,Black,3
# 512,13,Black,3
# 513,14,Black,4
# 514,15,Black,4
# 515,0,Black,4
# 516,0,Black,4
# 517,0,Black,3
# 518,0,Black,5
# 519,0,Black,4
# 520,0,Black,3
# 521,0,Black,4
# 522,0,Black,4
# 523,0,Black,5
# 524,0,Black,3
# 525,0,Black,4
# 526,0,Black,4
# 527,0,Black,3
# 528,0,Black,5
# 529,1,White,4
# 530,2,White,123
# 531,3,White,120
# 532,4,White,123
# 533,5,White,119
# 534,6,White,120
# 535,7,White,120
# 536,8,White,122
# 537,9,White,125
# 538,10,White,122
# 539,11,White,124
# 540,12,White,121
# 541,13,White,119
# 542,14,White,119
# 543,15,White,123
# 544,1,Red,122
# 545,2,Red,49
# 546,3,Red,50
# 547,4,Red,51
# 548,5,Red,50
# 549,6,Red,50
# 550,7,Red,51
# 551,8,Red,51
# 552,9,Red,52
# 553,10,Red,52
# 554,11,Red,48
# 555,12,Red,52
# 556,13,Red,49
# 557,14,Red,51
# 558,15,Red,50
# 559,1,Green,49
# 560,2,Green,59
# 561,3,Green,56
# 562,4,Green,59
# 563,5,Green,54
# 564,6,Green,53
# 565,7,Green,58
# 566,8,Green,58
# 567,9,Green,55
# 568,10,Green,53
# 569,11,Green,58
# 570,12,Green,54
# 571,13,Green,53
# 572,14,Green,57
# 573,15,Green,58
# 574,1,Blue,55
# 575,2,Blue,22
# 576,3,Blue,22
# 577,4,Blue,24
# 578,5,Blue,22
# 579,6,Blue,22
# 580,7,Blue,24
# 581,8,Blue,22
# 582,9,Blue,23
# 583,10,Blue,23
# 584,11,Blue,22
# 585,12,Blue,24
# 586,13,Blue,23
# 587,14,Blue,22
# 588,1,Black,22
# 589,2,Black,4
# 590,3,Black,4
# 591,4,Black,4
# 592,5,Black,5
# 593,6,Black,4
# 594,7,Black,4
# 595,8,Black,4
# 596,9,Black,4
# 597,10,Black,4
# 598,11,Black,4
# 599,12,Black,5
# 600,13,Black,4
# 601,14,Black,4
# 602,15,Black,4
# 603,0,Black,4
# 604,0,Black,4
# 605,0,Black,4
# 606,0,Black,4
# 607,0,Black,4
# 608,0,Black,4
# 609,0,Black,3
# 610,0,Black,4
# 611,0,Black,4
# 612,0,Black,4
# 613,0,Black,4
# 614,0,Black,3
# 615,0,Black,5
# 616,0,Black,3
# 617,0,Black,4
# 618,1,White,4
# 619,2,White,119
# 620,3,White,122
# 621,4,White,119
# 622,5,White,119
# 623,6,White,119
# 624,7,White,120
# 625,8,White,122
# 626,9,White,118
# 627,10,White,120
# 628,11,White,124
# 629,12,White,124
# 630,13,White,123
# 631,14,White,126
# 632,1,Red,119
# 633,2,Red,50
# 634,3,Red,51
# 635,4,Red,49
# 636,5,Red,54
# 637,6,Red,51
# 638,7,Red,54
# 639,8,Red,50
# 640,9,Red,53
# 641,10,Red,53
# 642,11,Red,50
# 643,12,Red,50
# 644,13,Red,49
# 645,14,Red,54
# 646,15,Red,49
# 647,1,Green,49
# 648,2,Green,53
# 649,3,Green,55
# 650,4,Green,57
# 651,5,Green,55
# 652,6,Green,53
# 653,7,Green,57
# 654,8,Green,57
# 655,9,Green,53
# 656,10,Green,55
# 657,11,Green,54
# 658,12,Green,55
# 659,13,Green,58
# 660,14,Green,54
# 661,15,Green,58
# 662,1,Blue,56
# 663,2,Blue,22
# 664,3,Blue,21
# 665,4,Blue,24
# 666,5,Blue,24
# 667,6,Blue,24
# 668,7,Blue,22
# 669,8,Blue,22
# 670,9,Blue,22
# 671,10,Blue,21
# 672,11,Blue,24
# 673,12,Blue,24
# 674,13,Blue,22
# 675,14,Blue,23
# 676,1,Black,22
# 677,2,Black,4
# 678,3,Black,4
# 679,4,Black,5
# 680,5,Black,3
# 681,6,Black,4
# 682,7,Black,5
# 683,8,Black,4
# 684,9,Black,3
# 685,10,Black,4
# 686,11,Black,5
# 687,12,Black,4
# 688,13,Black,4
# 689,14,Black,4
# 690,15,Black,4
# 691,0,Black,3
# 692,0,Black,3
# 693,0,Black,3
# 694,0,Black,4
# 695,0,Black,5
# 696,0,Black,3
# 697,0,Black,4
# 698,0,Black,4
# 699,0,Black,4
# 700,0,Black,4
# 701,0,Black,4
# 702,0,Black,3
# 703,0,Black,4
# 704,0,Black,3
# 705,0,Black,4
# 706,1,White,4
# 707,2,White,120
# 708,3,White,119
# 709,4,White,118
# 710,5,White,121
# 711,6,White,119
# 712,7,White,123
# 713,8,White,122
# 714,9,White,120
# 715,10,White,120
# 716,11,White,119
# 717,12,White,122
# 718,13,White,120
# 719,14,White,125
# 720,1,Red,119
# 721,2,Red,52
# 722,3,Red,52
# 723,4,Red,50
# 724,5,Red,49
# 725,6,Red,52
# 726,7,Red,54
# 727,8,Red,48
# 728,9,Red,51
# 729,10,Red,52
# 730,11,Red,53
# 731,12,Red,50
# 732,13,Red,50
# 733,14,Red,49
# 734,15,Red,52
# 735,1,Green,50
# 736,2,Green,53
# 737,3,Green,55
# 738,4,Green,55
# 739,5,Green,54
# 740,6,Green,57
# 741,7,Green,58
# 742,8,Green,57
# 743,9,Green,54
# 744,10,Green,55
# 745,11,Green,59
# 746,12,Green,56
# 747,13,Green,53
# 748,14,Green,54
# 749,15,Green,58
# 750,1,Blue,52
# 751,2,Blue,23
# 752,3,Blue,24
# 753,4,Blue,22
# 754,5,Blue,22
# 755,6,Blue,21
# 756,7,Blue,24
# 757,8,Blue,23
# 758,9,Blue,22
# 759,10,Blue,24
# 760,11,Blue,22
# 761,12,Blue,24
# 762,13,Blue,21
# 763,14,Blue,22
# 764,1,Black,23
# 765,2,Black,3
# 766,3,Black,4
# 767,4,Black,3
# 768,5,Black,4
# 769,6,Black,3
# 770,7,Black,4
# 771,8,Black,4
# 772,9,Black,4
# 773,10,Black,4
# 774,11,Black,4
# 775,12,Black,3
# 776,13,Black,4
# 777,14,Black,5
# 778,15,Black,4
# 779,0,Black,4
# 780,0,Black,4
# 781,0,Black,4
# 782,0,Black,4
# 783,0,Black,3
# 784,0,Black,5
# 785,0,Black,4
# 786,0,Black,3
# 787,0,Black,4
# 788,0,Black,4
# 789,0,Black,4
# 790,0,Black,4
# 791,0,Black,4
# 792,0,Black,4
# 793,0,Black,4
# 794,1,White,4
# 795,2,White,118
# 796,3,White,125
# 797,4,White,124
# 798,5,White,119
# 799,6,White,120
# 800,7,White,119
# 801,8,White,120
# 802,9,White,119
# 803,10,White,124
# 804,11,White,118
# 805,12,White,120
# 806,13,White,119
# 807,14,White,124
# 808,15,White,125
# 809,1,Red,124
# 810,2,Red,53
# 811,3,Red,50
# 812,4,Red,52
# 813,5,Red,50
# 814,6,Red,51
# 815,7,Red,54
# 816,8,Red,51
# 817,9,Red,48
# 818,10,Red,49
# 819,11,Red,53
# 820,12,Red,49
# 821,13,Red,52
# 822,14,Red,52
# 823,1,Green,51
# 824,2,Green,54
# 825,3,Green,56
# 826,4,Green,56
# 827,5,Green,57
# 828,6,Green,58
# 829,7,Green,56
# 830,8,Green,53
# 831,9,Green,54
# 832,10,Green,56
# 833,11,Green,57
# 834,12,Green,54
# 835,13,Green,57
# 836,14,Green,59
# 837,15,Green,54
# 838,1,Blue,53
# 839,2,Blue,21
# 840,3,Blue,21
# 841,4,Blue,22
# 842,5,Blue,22
# 843,6,Blue,23
# 844,7,Blue,23
# 845,8,Blue,21
# 846,9,Blue,23
# 847,10,Blue,24
# 848,11,Blue,23
# 849,12,Blue,22
# 850,13,Blue,21
# 851,14,Blue,21
# 852,15,Blue,21
# 853,1,Black,24
# 854,2,Black,4
# 855,3,Black,4
# 856,4,Black,4
# 857,5,Black,4
# 858,6,Black,4
# 859,7,Black,4
# 860,8,Black,3
# 861,9,Black,3
# 862,10,Black,4
# 863,11,Black,5
# 864,12,Black,4
# 865,13,Black,4
# 866,14,Black,4
# 867,0,Black,4
# 868,0,Black,4
# 869,0,Black,4
# 870,0,Black,4
# 871,0,Black,4
# 872,0,Black,3
# 873,0,Black,4
# 874,0,Black,4
# 875,0,Black,4
# 876,0,Black,5
# 877,0,Black,4
# 878,0,Black,3
# 879,0,Black,4
# 880,0,Black,4
# 881,0,Black,4
# 882,1,White,3
# 883,2,White,119
# 884,3,White,121
# 885,4,White,120
# 886,5,White,122
# 887,6,White,120
# 888,7,White,119
# 889,8,White,122
# 890,9,White,120
# 891,10,White,122
# 892,11,White,119
# 893,12,White,117
# 894,13,White,119
# 895,14,White,121
# 896,15,White,118
# 897,1,Red,122
# 898,2,Red,53
# 899,3,Red,50
# 900,4,Red,53
# 901,5,Red,50
# 902,6,Red,51
# 903,7,Red,49
# 904,8,Red,50
# 905,9,Red,49
# 906,10,Red,49
# 907,11,Red,52
# 908,12,Red,51
# 909,13,Red,53
# 910,14,Red,52
# 911,1,Green,49
# 912,2,Green,56
# 913,3,Green,58
# 914,4,Green,56
# 915,5,Green,54
# 916,6,Green,53
# 917,7,Green,54
# 918,8,Green,57
# 919,9,Green,54
# 920,10,Green,54
# 921,11,Green,56
# 922,12,Green,55
# 923,13,Green,57
# 924,14,Green,55
# 925,15,Green,54
# 926,1,Blue,53
# 927,2,Blue,21
# 928,3,Blue,21
# 929,4,Blue,22
# 930,5,Blue,22
# 931,6,Blue,22
# 932,7,Blue,22
# 933,8,Blue,22
# 934,9,Blue,24
# 935,10,Blue,21
# 936,11,Blue,24
# 937,12,Blue,21
# 938,13,Blue,23
# 939,14,Blue,21
# 940,15,Blue,24
# 941,1,Black,24
# 942,2,Black,3
# 943,3,Black,5
# 944,4,Black,4
# 945,5,Black,4
# 946,6,Black,4
# 947,7,Black,4
# 948,8,Black,4
# 949,9,Black,5
# 950,10,Black,5
# 951,11,Black,4
# 952,12,Black,4
# 953,13,Black,4
# 954,14,Black,4
# 955,0,Black,3
# 956,0,Black,4
# 957,0,Black,5
# 958,0,Black,5
# 959,0,Black,4
# 960,0,Black,5
# 961,0,Black,5
# 962,0,Black,3
# 963,0,Black,4
# 964,0,Black,4
# 965,0,Black,5
# 966,0,Black,3
# 967,0,Black,4
# 968,0,Black,5
# 969,0,Black,4
# 970,1,White,3
# 971,2,White,118
# 972,3,White,121
# 973,4,White,121
# 974,5,White,121
# 975,6,White,122
# 976,7,White,121
# 977,8,White,118
# 978,9,White,119
# 979,10,White,117
# 980,11,White,119
# 981,12,White,118
# 982,13,White,120
# 983,14,White,118
# 984,15,White,119
# 985,1,Red,123
# 986,2,Red,47
# 987,3,Red,50
# 988,4,Red,52
# 989,5,Red,48
# 990,6,Red,49
# 991,7,Red,50
# 992,8,Red,48
# 993,9,Red,51
# 994,10,Red,48
# 995,11,Red,48
# 996,12,Red,53
# 997,13,Red,48
# 998,14,Red,51
# 999,15,Red,53
# 1000,1,Green,48
# 1001,2,Green,57
# 1002,3,Green,58
# 1003,4,Green,58
# 1004,5,Green,55
# 1005,6,Green,57
# 1006,7,Green,54
# 1007,8,Green,52
# 1008,9,Green,56
# 1009,10,Green,53
# 1010,11,Green,52
# 1011,12,Green,56
# 1012,13,Green,54
# 1013,14,Green,57
# 1014,1,Blue,56
# 1015,2,Blue,24
# 1016,3,Blue,21
# 1017,4,Blue,21
# 1018,5,Blue,22
# 1019,6,Blue,23
# 1020,7,Blue,22
# 1021,8,Blue,23
# 1022,9,Blue,23
# 1023,10,Blue,23
# 1024,11,Blue,23
# 1025,12,Blue,21
# 1026,13,Blue,21
# 1027,14,Blue,21
# 1028,15,Blue,21
# 1029,1,Black,21
# 1030,2,Black,4
# 1031,3,Black,4
# 1032,4,Black,4
# 1033,5,Black,4
# 1798,6,Green,56
# 1799,7,Green,57
# 1800,8,Green,56
#
#
# แสดงข้อมูลจากไฟล์ 'P100_day2.txt':
# Phosphorus_concentrate 100 mg/L RepeatOld2
# 1,1,White,4
# 2,2,White,143
# 3,3,White,140
# 4,4,White,142
# 5,5,White,140
# 6,6,White,146
# 7,7,White,140
# 8,8,White,144
# 9,9,White,143
# 10,10,White,141
# 11,11,White,140
# 12,12,White,145
# 13,13,White,139
# 14,14,White,141
# 15,1,Red,142
# 16,2,Red,57
# 17,3,Red,61
# 18,4,Red,58
# 19,5,Red,60
# 20,6,Red,58
# 21,7,Red,59
# 22,8,Red,60
# 23,9,Red,62
# 24,10,Red,62
# 25,11,Red,60
# 26,12,Red,57
# 27,13,Red,55
# 28,14,Red,58
# 29,15,Red,61
# 30,1,Green,58
# 31,2,Green,62
# 32,3,Green,60
# 33,4,Green,62
# 34,5,Green,61
# 35,6,Green,65
# 36,7,Green,62
# 37,8,Green,61
# 38,9,Green,64
# 39,10,Green,64
# 40,11,Green,62
# 41,12,Green,61
# 42,13,Green,62
# 43,14,Green,61
# 44,15,Green,62
# 45,1,Blue,61
# 46,2,Blue,27
# 47,3,Blue,28
# 48,4,Blue,30
# 49,5,Blue,31
# 50,6,Blue,27
# 51,7,Blue,31
# 52,8,Blue,30
# 53,9,Blue,27
# 54,10,Blue,28
# 55,11,Blue,27
# 56,12,Blue,28
# 57,13,Blue,27
# 58,14,Blue,28
# 59,1,Black,26
# 60,2,Black,4
# 61,3,Black,4
# 62,4,Black,4
# 63,5,Black,3
# 64,6,Black,4
# 65,7,Black,4
# 66,8,Black,4
# 67,9,Black,4
# 68,10,Black,5
# 69,11,Black,4
# 70,12,Black,3
# 71,13,Black,4
# 72,14,Black,3
# 73,15,Black,3
# 74,0,Black,3
# 75,0,Black,4
# 76,0,Black,4
# 77,0,Black,4
# 78,0,Black,4
# 79,0,Black,3
# 80,0,Black,4
# 81,0,Black,5
# 82,0,Black,5
# 83,0,Black,4
# 84,0,Black,3
# 85,0,Black,4
# 86,0,Black,3
# 87,0,Black,3
# 88,0,Black,4
# 89,1,White,4
# 90,2,White,139
# 91,3,White,137
# 92,4,White,141
# 93,5,White,142
# 94,6,White,139
# 95,7,White,140
# 96,8,White,142
# 97,9,White,138
# 98,10,White,141
# 99,11,White,135
# 100,12,White,139
# 101,13,White,144
# 102,14,White,141
# 103,1,Red,139
# 104,2,Red,59
# 105,3,Red,60
# 106,4,Red,56
# 107,5,Red,59
# 108,6,Red,59
# 109,7,Red,57
# 110,8,Red,57
# 111,9,Red,57
# 112,10,Red,60
# 113,11,Red,59
# 114,12,Red,58
# 115,13,Red,57
# 116,14,Red,58
# 117,15,Red,58
# 118,1,Green,56
# 119,2,Green,64
# 120,3,Green,59
# 121,4,Green,64
# 122,5,Green,63
# 123,6,Green,65
# 124,7,Green,61
# 125,8,Green,59
# 126,9,Green,64
# 127,10,Green,61
# 128,11,Green,61
# 129,12,Green,62
# 130,13,Green,65
# 131,14,Green,60
# 132,15,Green,62
# 133,1,Blue,64
# 134,2,Blue,30
# 135,3,Blue,27
# 136,4,Blue,28
# 137,5,Blue,26
# 138,6,Blue,29
# 139,7,Blue,28
# 140,8,Blue,29
# 141,9,Blue,28
# 142,10,Blue,30
# 143,11,Blue,28
# 144,12,Blue,27
# 145,13,Blue,28
# 146,14,Blue,29
# 147,1,Black,30
# 148,2,Black,5
# 149,3,Black,4
# 150,4,Black,5
# 151,5,Black,4
# 152,6,Black,3
# 153,7,Black,4
# 154,8,Black,4
# 155,9,Black,5
# 156,10,Black,4
# 157,11,Black,4
# 158,12,Black,4
# 159,13,Black,4
# 160,14,Black,4
# 161,15,Black,4
# 162,0,Black,4
# 163,0,Black,4
# 164,0,Black,4
# 165,0,Black,3
# 166,0,Black,3
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black,4
# 171,0,Black,4
# 172,0,Black,3
# 173,0,Black,4
# 174,0,Black,4
# 175,0,Black,4
# 176,0,Black,4
# 177,1,White,5
# 178,2,White,139
# 179,3,White,137
# 180,4,White,139
# 181,5,White,137
# 182,6,White,139
# 183,7,White,141
# 184,8,White,137
# 185,9,White,136
# 186,10,White,139
# 187,11,White,139
# 188,12,White,139
# 189,13,White,143
# 190,14,White,136
# 191,15,White,137
# 192,1,Red,139
# 193,2,Red,57
# 194,3,Red,56
# 195,4,Red,55
# 196,5,Red,57
# 197,6,Red,60
# 198,7,Red,56
# 199,8,Red,58
# 200,9,Red,57
# 201,10,Red,58
# 202,11,Red,59
# 203,12,Red,59
# 204,13,Red,59
# 205,14,Red,60
# 206,1,Green,59
# 207,2,Green,59
# 208,3,Green,64
# 209,4,Green,59
# 210,5,Green,62
# 211,6,Green,59
# 212,7,Green,59
# 213,8,Green,62
# 214,9,Green,60
# 215,10,Green,60
# 216,11,Green,60
# 217,12,Green,61
# 218,13,Green,61
# 219,14,Green,57
# 220,15,Green,61
# 221,1,Blue,61
# 222,2,Blue,27
# 223,3,Blue,28
# 224,4,Blue,30
# 225,5,Blue,29
# 226,6,Blue,28
# 227,7,Blue,30
# 228,8,Blue,27
# 229,9,Blue,29
# 230,10,Blue,27
# 231,11,Blue,30
# 232,12,Blue,26
# 233,13,Blue,27
# 234,14,Blue,27
# 235,15,Blue,26
# 236,1,Black,28
# 237,2,Black,4
# 238,3,Black,4
# 239,4,Black,4
# 240,5,Black,4
# 241,6,Black,3
# 242,7,Black,3
# 243,8,Black,5
# 244,9,Black,4
# 245,10,Black,4
# 246,11,Black,5
# 247,12,Black,3
# 248,13,Black,5
# 249,14,Black,4
# 250,0,Black,4
# 251,0,Black,3
# 252,0,Black,5
# 253,0,Black,3
# 254,0,Black,4
# 255,0,Black,3
# 256,0,Black,5
# 257,0,Black,4
# 258,0,Black,4
# 259,0,Black,4
# 260,0,Black,5
# 261,0,Black,4
# 262,0,Black,4
# 263,0,Black,3
# 264,0,Black,4
# 265,1,White,4
# 266,2,White,134
# 267,3,White,137
# 268,4,White,139
# 269,5,White,136
# 270,6,White,143
# 271,7,White,139
# 272,8,White,140
# 273,9,White,137
# 274,10,White,139
# 275,11,White,135
# 276,12,White,137
# 277,13,White,140
# 278,14,White,140
# 279,15,White,137
# 280,1,Red,139
# 281,2,Red,58
# 282,3,Red,60
# 283,4,Red,55
# 284,5,Red,59
# 285,6,Red,59
# 286,7,Red,57
# 287,8,Red,56
# 288,9,Red,60
# 289,10,Red,54
# 290,11,Red,56
# 291,12,Red,54
# 292,13,Red,56
# 293,14,Red,57
# 294,1,Green,55
# 295,2,Green,62
# 296,3,Green,59
# 297,4,Green,59
# 298,5,Green,62
# 299,6,Green,62
# 300,7,Green,64
# 301,8,Green,58
# 302,9,Green,59
# 303,10,Green,63
# 304,11,Green,64
# 305,12,Green,60
# 306,13,Green,61
# 307,14,Green,60
# 308,15,Green,58
# 309,1,Blue,60
# 310,2,Blue,28
# 311,3,Blue,26
# 312,4,Blue,28
# 313,5,Blue,28
# 314,6,Blue,30
# 315,7,Blue,27
# 316,8,Blue,26
# 317,9,Blue,28
# 318,10,Blue,27
# 319,11,Blue,30
# 320,12,Blue,28
# 321,13,Blue,28
# 322,14,Blue,29
# 323,15,Blue,27
# 324,1,Black,29
# 325,2,Black,4
# 326,3,Black,3
# 327,4,Black,4
# 328,5,Black,3
# 329,6,Black,5
# 330,7,Black,3
# 331,8,Black,4
# 332,9,Black,4
# 333,10,Black,3
# 334,11,Black,3
# 335,12,Black,4
# 336,13,Black,3
# 337,14,Black,3
# 338,0,Black,4
# 339,0,Black,4
# 340,0,Black,5
# 341,0,Black,4
# 342,0,Black,4
# 343,0,Black,4
# 344,0,Black,4
# 345,0,Black,5
# 346,0,Black,4
# 347,0,Black,5
# 348,0,Black,3
# 349,0,Black,3
# 350,0,Black,4
# 351,0,Black,3
# 352,0,Black,4
# 353,1,White,3
# 354,2,White,135
# 355,3,White,142
# 356,4,White,138
# 357,5,White,140
# 358,6,White,136
# 359,7,White,138
# 360,8,White,137
# 361,9,White,137
# 362,10,White,139
# 363,11,White,141
# 364,12,White,137
# 365,13,White,134
# 366,14,White,139
# 367,15,White,140
# 368,1,Red,140
# 369,2,Red,57
# 370,3,Red,56
# 371,4,Red,55
# 372,5,Red,58
# 373,6,Red,55
# 374,7,Red,55
# 375,8,Red,56
# 376,9,Red,55
# 377,10,Red,54
# 378,11,Red,58
# 379,12,Red,57
# 380,13,Red,56
# 381,14,Red,59
# 382,1,Green,57
# 383,2,Green,58
# 384,3,Green,58
# 385,4,Green,61
# 386,5,Green,64
# 387,6,Green,57
# 388,7,Green,61
# 389,8,Green,62
# 390,9,Green,64
# 391,10,Green,62
# 392,11,Green,63
# 393,12,Green,59
# 394,13,Green,63
# 395,14,Green,65
# 396,15,Green,60
# 397,1,Blue,59
# 398,2,Blue,28
# 399,3,Blue,27
# 400,4,Blue,29
# 401,5,Blue,28
# 402,6,Blue,29
# 403,7,Blue,28
# 404,8,Blue,25
# 405,9,Blue,29
# 406,10,Blue,30
# 407,11,Blue,28
# 408,12,Blue,28
# 409,13,Blue,27
# 410,14,Blue,28
# 411,15,Blue,26
# 412,1,Black,27
# 413,2,Black,3
# 414,3,Black,3
# 415,4,Black,4
# 416,5,Black,3
# 417,6,Black,4
# 418,7,Black,4
# 419,8,Black,3
# 420,9,Black,4
# 421,10,Black,4
# 422,11,Black,3
# 423,12,Black,3
# 424,13,Black,3
# 425,14,Black,3
# 426,15,Black,3
# 427,0,Black,3
# 428,0,Black,4
# 429,0,Black,4
# 430,0,Black,5
# 431,0,Black,4
# 432,0,Black,4
# 433,0,Black,3
# 434,0,Black,4
# 435,0,Black,3
# 436,0,Black,4
# 437,0,Black,4
# 438,0,Black,5
# 439,0,Black,3
# 440,0,Black,4
# 441,1,White,4
# 442,2,White,139
# 443,3,White,138
# 444,4,White,137
# 445,5,White,134
# 446,6,White,135
# 447,7,White,137
# 448,8,White,135
# 449,9,White,140
# 450,10,White,138
# 451,11,White,137
# 452,12,White,138
# 453,13,White,137
# 454,14,White,135
# 455,15,White,139
# 456,1,Red,140
# 457,2,Red,59
# 458,3,Red,55
# 459,4,Red,56
# 460,5,Red,57
# 461,6,Red,54
# 462,7,Red,54
# 463,8,Red,55
# 464,9,Red,54
# 465,10,Red,59
# 466,11,Red,55
# 467,12,Red,55
# 468,13,Red,56
# 469,14,Red,57
# 470,15,Red,55
# 471,1,Green,55
# 472,2,Green,59
# 473,3,Green,61
# 474,4,Green,63
# 475,5,Green,63
# 476,6,Green,59
# 477,7,Green,63
# 478,8,Green,61
# 479,9,Green,57
# 480,10,Green,62
# 481,11,Green,63
# 482,12,Green,59
# 483,13,Green,60
# 484,14,Green,61
# 485,1,Blue,57
# 486,2,Blue,27
# 487,3,Blue,29
# 488,4,Blue,29
# 489,5,Blue,31
# 490,6,Blue,26
# 491,7,Blue,28
# 492,8,Blue,29
# 493,9,Blue,27
# 494,10,Blue,28
# 495,11,Blue,26
# 496,12,Blue,28
# 497,13,Blue,30
# 498,14,Blue,29
# 499,15,Blue,26
# 500,1,Black,30
# 501,2,Black,4
# 502,3,Black,4
# 503,4,Black,4
# 504,5,Black,4
# 505,6,Black,3
# 506,7,Black,4
# 507,8,Black,3
# 508,9,Black,4
# 509,10,Black,4
# 510,11,Black,4
# 511,12,Black,4
# 512,13,Black,4
# 513,14,Black,4
# 514,15,Black,3
# 515,0,Black,5
# 516,0,Black,3
# 517,0,Black,3
# 518,0,Black,3
# 519,0,Black,3
# 520,0,Black,5
# 521,0,Black,5
# 522,0,Black,5
# 523,0,Black,4
# 524,0,Black,3
# 525,0,Black,3
# 526,0,Black,3
# 527,0,Black,4
# 528,0,Black,4
# 529,1,White,3
# 530,2,White,138
# 531,3,White,134
# 532,4,White,133
# 533,5,White,137
# 534,6,White,139
# 535,7,White,134
# 536,8,White,133
# 537,9,White,136
# 538,10,White,136
# 539,11,White,138
# 540,12,White,135
# 541,13,White,137
# 542,14,White,140
# 543,15,White,135
# 544,1,Red,134
# 545,2,Red,54
# 546,3,Red,57
# 547,4,Red,57
# 548,5,Red,57
# 549,6,Red,55
# 550,7,Red,56
# 551,8,Red,55
# 552,9,Red,57
# 553,10,Red,54
# 554,11,Red,56
# 555,12,Red,58
# 556,13,Red,57
# 557,14,Red,56
# 558,15,Red,55
# 559,1,Green,56
# 560,2,Green,59
# 561,3,Green,59
# 562,4,Green,60
# 563,5,Green,57
# 564,6,Green,59
# 565,7,Green,59
# 566,8,Green,59
# 567,9,Green,59
# 568,10,Green,58
# 569,11,Green,62
# 570,12,Green,58
# 571,13,Green,59
# 572,14,Green,59
# 573,1,Blue,58
# 574,2,Blue,29
# 575,3,Blue,28
# 576,4,Blue,29
# 577,5,Blue,27
# 578,6,Blue,27
# 579,7,Blue,25
# 580,8,Blue,26
# 581,9,Blue,27
# 582,10,Blue,28
# 583,11,Blue,29
# 584,12,Blue,28
# 585,13,Blue,28
# 586,14,Blue,28
# 587,15,Blue,29
# 588,1,Black,25
# 589,2,Black,4
# 590,3,Black,5
# 591,4,Black,3
# 592,5,Black,4
# 593,6,Black,3
# 594,7,Black,4
# 595,8,Black,4
# 596,9,Black,4
# 597,10,Black,4
# 598,11,Black,4
# 599,12,Black,3
# 600,13,Black,3
# 601,14,Black,3
# 602,15,Black,4
# 603,0,Black,4
# 604,0,Black,4
# 605,0,Black,4
# 606,0,Black,4
# 607,0,Black,4
# 608,0,Black,4
# 609,0,Black,4
# 610,0,Black,4
# 611,0,Black,5
# 612,0,Black,4
# 613,0,Black,5
# 614,0,Black,4
# 615,0,Black,3
# 616,0,Black,4
# 617,1,White,4
# 618,2,White,137
# 619,3,White,134
# 620,4,White,133
# 621,5,White,140
# 622,6,White,134
# 623,7,White,137
# 624,8,White,140
# 625,9,White,137
# 626,10,White,139
# 627,11,White,134
# 628,12,White,138
# 629,13,White,134
# 630,14,White,135
# 631,15,White,137
# 632,1,Red,135
# 633,2,Red,54
# 634,3,Red,57
# 635,4,Red,55
# 636,5,Red,53
# 637,6,Red,58
# 638,7,Red,58
# 639,8,Red,59
# 640,9,Red,56
# 641,10,Red,56
# 642,11,Red,58
# 643,12,Red,59
# 644,13,Red,54
# 645,14,Red,56
# 646,15,Red,58
# 647,1,Green,59
# 648,2,Green,61
# 649,3,Green,58
# 650,4,Green,60
# 651,5,Green,62
# 652,6,Green,62
# 653,7,Green,61
# 654,8,Green,58
# 655,9,Green,58
# 656,10,Green,58
# 657,11,Green,63
# 658,12,Green,58
# 659,13,Green,60
# 660,14,Green,63
# 661,15,Green,61
# 662,1,Blue,59
# 663,2,Blue,27
# 664,3,Blue,26
# 665,4,Blue,26
# 666,5,Blue,27
# 667,6,Blue,26
# 668,7,Blue,26
# 669,8,Blue,26
# 670,9,Blue,27
# 671,10,Blue,27
# 672,11,Blue,26
# 673,12,Blue,27
# 674,13,Blue,29
# 675,14,Blue,29
# 676,1,Black,28
# 677,2,Black,4
# 678,3,Black,4
# 679,4,Black,5
# 680,5,Black,4
# 681,6,Black,4
# 682,7,Black,4
# 683,8,Black,4
# 684,9,Black,4
# 685,10,Black,3
# 686,11,Black,5
# 687,12,Black,4
# 688,13,Black,5
# 689,14,Black,4
# 690,15,Black,4
# 691,0,Black,4
# 692,0,Black,4
# 693,0,Black,4
# 694,0,Black,4
# 695,0,Black,4
# 696,0,Black,4
# 697,0,Black,4
# 698,0,Black,4
# 699,0,Black,4
# 700,0,Black,5
# 701,0,Black,5
# 702,0,Black,4
# 703,0,Black,5
# 704,0,Black,3
# 705,0,Black,5
# 706,1,White,5
# 707,2,White,134
# 708,3,White,136
# 709,4,White,135
# 710,5,White,133
# 711,6,White,135
# 712,7,White,137
# 713,8,White,133
# 714,9,White,135
# 715,10,White,135
# 716,11,White,137
# 717,12,White,135
# 718,13,White,138
# 719,14,White,135
# 720,1,Red,135
# 721,2,Red,58
# 722,3,Red,56
# 723,4,Red,54
# 724,5,Red,59
# 725,6,Red,58
# 726,7,Red,55
# 727,8,Red,53
# 728,9,Red,54
# 729,10,Red,59
# 730,11,Red,55
# 731,12,Red,59
# 732,13,Red,54
# 733,14,Red,55
# 734,15,Red,60
# 735,1,Green,57
# 736,2,Green,62
# 737,3,Green,59
# 738,4,Green,64
# 739,5,Green,57
# 740,6,Green,62
# 741,7,Green,63
# 742,8,Green,61
# 743,9,Green,59
# 744,10,Green,59
# 745,11,Green,60
# 746,12,Green,61
# 747,13,Green,57
# 748,14,Green,60
# 749,15,Green,63
# 750,1,Blue,62
# 751,2,Blue,27
# 752,3,Blue,28
# 753,4,Blue,26
# 754,5,Blue,28
# 755,6,Blue,26
# 756,7,Blue,28
# 757,8,Blue,26
# 758,9,Blue,26
# 759,10,Blue,26
# 760,11,Blue,25
# 761,12,Blue,26
# 762,13,Blue,26
# 763,14,Blue,26
# 764,1,Black,26
# 765,2,Black,4
# 766,3,Black,4
# 767,4,Black,5
# 768,5,Black,4
# 769,6,Black,4
# 770,7,Black,4
# 771,8,Black,4
# 772,9,Black,4
# 773,10,Black,4
# 774,11,Black,4
# 775,12,Black,4
# 776,13,Black,5
# 777,14,Black,4
# 778,15,Black,5
# 779,0,Black,4
# 780,0,Black,3
# 781,0,Black,4
# 782,0,Black,4
# 783,0,Black,4
# 784,0,Black,4
# 785,0,Black,5
# 786,0,Black,4
# 787,0,Black,4
# 788,0,Black,4
# 789,0,Black,4
# 790,0,Black,4
# 791,0,Black,4
# 792,0,Black,4
# 793,0,Black,4
# 794,1,White,5
# 795,2,White,137
# 796,3,White,137
# 797,4,White,138
# 798,5,White,133
# 799,6,White,137
# 800,7,White,137
# 801,8,White,132
# 802,9,White,133
# 803,10,White,135
# 804,11,White,136
# 805,12,White,135
# 806,13,White,135
# 807,14,White,133
# 808,1,Red,133
# 809,2,Red,54
# 810,3,Red,56
# 811,4,Red,55
# 812,5,Red,55
# 813,6,Red,57
# 814,7,Red,54
# 815,8,Red,55
# 816,9,Red,56
# 817,10,Red,57
# 818,11,Red,56
# 819,12,Red,55
# 820,13,Red,58
# 821,14,Red,53
# 822,15,Red,58
# 823,1,Green,55
# 824,2,Green,60
# 825,3,Green,62
# 826,4,Green,60
# 827,5,Green,57
# 828,6,Green,60
# 829,7,Green,58
# 830,8,Green,63
# 831,9,Green,60
# 832,10,Green,58
# 833,11,Green,58
# 834,12,Green,62
# 835,13,Green,58
# 836,14,Green,62
# 837,15,Green,58
# 838,1,Blue,61
# 839,2,Blue,30
# 840,3,Blue,28
# 841,4,Blue,28
# 842,5,Blue,28
# 843,6,Blue,29
# 844,7,Blue,28
# 845,8,Blue,28
# 846,9,Blue,25
# 847,10,Blue,30
# 848,11,Blue,27
# 849,12,Blue,27
# 850,13,Blue,27
# 851,14,Blue,28
# 852,15,Blue,29
# 853,1,Black,25
# 854,2,Black,4
# 855,3,Black,4
# 856,4,Black,4
# 857,5,Black,4
# 858,6,Black,4
# 859,7,Black,3
# 860,8,Black,3
# 861,9,Black,3
# 862,10,Black,3
# 863,11,Black,4
# 864,12,Black,3
# 865,13,Black,4
# 866,14,Black,4
# 867,0,Black,4
# 868,0,Black,4
# 869,0,Black,5
# 870,0,Black,4
# 871,0,Black,3
# 872,0,Black,4
# 873,0,Black,4
# 874,0,Black,4
# 875,0,Black,4
# 876,0,Black,3
# 877,0,Black,4
# 878,0,Black,3
# 879,0,Black,4
# 880,0,Black,4
# 881,0,Black,4
# 882,1,White,4
# 883,2,White,132
# 884,3,White,134
# 885,4,White,135
# 886,5,White,136
# 887,6,White,134
# 888,7,White,136
# 889,8,White,138
# 890,9,White,135
# 891,10,White,133
# 892,11,White,136
# 893,12,White,137
# 894,13,White,133
# 895,14,White,135
# 896,15,White,134
# 897,1,Red,133
# 898,2,Red,55
# 899,3,Red,54
# 900,4,Red,55
# 901,5,Red,56
# 902,6,Red,54
# 903,7,Red,56
# 904,8,Red,56
# 905,9,Red,58
# 906,10,Red,55
# 907,11,Red,55
# 908,12,Red,53
# 909,13,Red,57
# 910,14,Red,55
# 911,1,Green,54
# 912,2,Green,57
# 913,3,Green,59
# 914,4,Green,58
# 915,5,Green,58
# 916,6,Green,64
# 917,7,Green,60
# 918,8,Green,62
# 919,9,Green,61
# 920,10,Green,59
# 921,11,Green,58
# 922,12,Green,62
# 923,13,Green,58
# 924,14,Green,60
# 925,15,Green,59
# 926,1,Blue,57
# 927,2,Blue,26
# 928,3,Blue,28
# 929,4,Blue,26
# 930,5,Blue,25
# 931,6,Blue,25
# 932,7,Blue,29
# 933,8,Blue,27
# 934,9,Blue,27
# 935,10,Blue,29
# 936,11,Blue,29
# 937,12,Blue,27
# 938,13,Blue,28
# 939,14,Blue,26
# 940,15,Blue,27
# 941,1,Black,27
# 942,2,Black,4
# 943,3,Black,4
# 944,4,Black,4
# 945,5,Black,4
# 946,6,Black,4
# 947,7,Black,4
# 948,8,Black,4
# 949,9,Black,3
# 950,10,Black,4
# 951,11,Black,4
# 952,12,Black,5
# 953,13,Black,5
# 954,14,Black,4
# 955,0,Black,4
# 956,0,Black,4
# 957,0,Black,5
# 958,0,Black,4
# 959,0,Black,4
# 960,0,Black,4
# 961,0,Black,4
# 962,0,Black,3
# 963,0,Black,4
# 964,0,Black,4
# 965,0,Black,4
# 966,0,Black,5
# 967,0,Black,4
# 968,0,Black,4
# 969,0,Black,4
# 970,1,White,4
# 971,2,White,132
# 972,3,White,131
# 973,4,White,136
# 974,5,White,138
# 975,6,White,138
# 976,7,White,137
# 977,8,White,139
# 978,9,White,136
# 979,10,White,138
# 980,11,White,135
# 981,12,White,133
# 982,13,White,134
# 983,14,White,134
# 984,15,White,139
# 985,1,Red,132
# 986,2,Red,57
# 987,3,Red,57
# 988,4,Red,54
# 989,5,Red,56
# 990,6,Red,55
# 991,7,Red,54
# 992,8,Red,57
# 993,9,Red,57
# 994,10,Red,55
# 995,11,Red,56
# 996,12,Red,53
# 997,13,Red,57
# 998,14,Red,54
# 999,1,Green,55
# 1000,2,Green,62
# 1001,3,Green,61
# 1002,4,Green,57
# 1003,5,Green,59
# 1004,6,Green,59
# 1005,7,Green,58
# 1006,8,Green,58
# 1007,9,Green,57
# 1008,10,Green,58
# 1009,11,Green,59
# 1010,12,Green,59
# 1011,13,Green,58
# 1012,14,Green,59
# 1013,15,Green,60
# 1014,1,Blue,58
# 1015,2,Blue,27
# 1016,3,Blue,26
# 1017,4,Blue,28
# 1018,5,Blue,28
# 1019,6,Blue,29
# 1020,7,Blue,26
# 1021,8,Blue,30
# 1022,9,Blue,26
# 1023,10,Blue,28
# 1024,11,Blue,29
# 1025,12,Blue,28
# 1026,13,Blue,28
# 1027,14,Blue,28
# 1028,15,Blue,26
# 1029,1,Black,28
# 1030,2,Black,3
# 1031,3,Black,4
# 1032,4,Black,4
# 1033,5,Black,4
# 1034,6,Black,4
# 1035,7,Black,4
# 1036,8,Black,5
# 1037,9,Black,4
# 1038,10,Black,4
# 1039,11,Black,3
# 1040,12,Black,4
# 1041,13,Black,4
# 1042,14,Black,3
# 1043,0,Black,4
# 1044,0,Black,4
# 1045,0,Black,4
# 1046,0,Black,3
# 1047,0,Black,4
# 1048,0,Black,4
# 1049,0,Black,3
# 1050,0,Black,4
# 1051,0,Black,4
# 1052,0,Black,4
# 1053,0,Black,4
# 1054,0,Black,4
# 1055,0,Black,4
# 1056,0,Black,4
# 1057,0,Black,4
# 1058,1,White,4
# 1059,2,White,130
# 1060,3,White,132
# 1061,4,White,130
# 1062,5,White,135
# 1063,6,White,133
# 1064,7,White,139
# 1065,8,White,135
# 1066,9,White,136
# 1067,10,White,135
# 1068,11,White,138
# 1069,12,White,133
# 1070,13,White,131
# 1071,14,White,136
# 1072,15,White,136
# 1073,1,Red,132
# 1074,2,Red,55
# 1075,3,Red,57
# 1076,4,Red,53
# 1077,5,Red,58
# 1078,6,Red,55
# 1079,7,Red,55
# 1080,8,Red,57
# 1081,9,Red,54
# 1082,10,Red,56
# 1083,11,Red,55
# 1084,12,Red,54
# 1085,13,Red,56
# 1086,14,Red,55
# 1087,15,Red,57
# 1088,1,Green,55
# 1089,2,Green,57
# 1090,3,Green,59
# 1091,4,Green,62
# 1092,5,Green,59
# 1347,11,Red,53
# 1348,12,Red,54
# 1349,13,Red,53
# 1350,14,Red,54
# 1351,15,Red,53
# 1352,1,Green,52
# 1353,2,Green,56
# 1354,3,Green,60
# 1355,4,Green,59
# 1356,5,Green,57
# 1357,6,Green,57
# 1358,7,Green,62
# 1359,8,Green,57
# 1360,9,Green,58
# 1361,10,Green,61
# 1362,11,Green,58
# 1363,12,Green,59
# 1364,13,Green,58
# 1365,14,Green,59
# 1366,15,Green,57
# 1367,1,Blue,60
# 1368,2,Blue,26
# 1369,3,Blue,27
# 1370,4,Blue,24
# 1371,5,Blue,26
# 1372,6,Blue,29
# 1373,7,Blue,27
# 1374,8,Blue,27
# 1375,9,Blue,28
# 1376,10,Blue,25
# 1377,11,Blue,25
# 1378,12,Blue,25
# 1379,13,Blue,25
# 1380,14,Blue,25
# 1381,1,Black,25
# 1382,2,Black,4
# 1383,3,Black,4
# 1384,4,Black,4
# 1385,5,Black,4
# 1386,6,Black,4
# 1387,7,Black,4
# 1388,8,Black,4
# 1389,9,Black,4
# 1390,10,Black,4
# 1391,11,Black,3
# 1392,12,Black,4
# 1393,13,Black,5
# 1394,14,Black,3
# 1395,15,Black,4
# 1396,0,Black,3
# ...
# 764,15,Blue,35
# 765,1,Black,36
# 766,2,Black,4
# 767,3,Black,4
# 768,4,Black,4
# 769,5,Black,4
# 770,6,Black,4
# 771,7,Black,3
# 772,8,Black,4
# 773,9,Black,3
# 774,10,Black,4
# 775,11,Black,4
# 776,12,Black,5
# 777,13,Black,4
# 778,14,Black,4
# 779,0,Black,4
# 780,0,Black,4
# 781,0,Black,4
# 782,0,Black,3
# 783,0,Black,4
# 784,0,Black,4
# 785,0,Black,4
# 786,0,Black,4
# 787,0,Black,4
# 788,0,Black,5
# 789,0,Black,4
# 790,0,Black,3
# 791,0,Black,4
# 792,0,Black,3
# 793,0,Black,4
# 794,1,White,5
# 795,2,White,168
# 796,3,White,166
# 797,4,White,164
# 798,5,White,168
# 799,6,White,166
# 800,7,White,162
# 801,8,White,167
# 802,9,White,163
# 803,10,White,166
# 804,11,White,165
# 805,12,White,162
# 806,13,White,165
# 807,14,White,162
# 808,15,White,162
# 809,1,Red,164
# 810,2,Red,75
# 811,3,Red,76
# 812,4,Red,71
# 813,5,Red,70
# 814,6,Red,71
# 815,7,Red,70
# 816,8,Red,73
# 817,9,Red,74
# 818,10,Red,70
# 819,11,Red,70
# 820,12,Red,73
# 821,13,Red,75
# 822,14,Red,71
# 823,1,Green,70
# 824,2,Green,67
# 825,3,Green,65
# 826,4,Green,69
# 827,5,Green,67
# 828,6,Green,69
# 829,7,Green,68
# 830,8,Green,65
# 831,9,Green,69
# 832,10,Green,63
# 833,11,Green,64
# 834,12,Green,63
# 835,13,Green,67
# 836,14,Green,66
# 837,15,Green,64
# 838,1,Blue,63
# 839,2,Blue,36
# 840,3,Blue,35
# 841,4,Blue,35
# 842,5,Blue,35
# 843,6,Blue,35
# 844,7,Blue,34
# 845,8,Blue,36
# 846,9,Blue,36
# 847,10,Blue,36
# 848,11,Blue,36
# 849,12,Blue,37
# 850,13,Blue,37
# 851,14,Blue,35
# 852,15,Blue,35
# 853,1,Black,34
# 854,2,Black,4
# 855,3,Black,4
# 856,4,Black,5
# 857,5,Black,4
# 858,6,Black,4
# 859,7,Black,5
# 860,8,Black,5
# 861,9,Black,4
# 862,10,Black,4
# 863,11,Black,4
# 864,12,Black,4
# 865,13,Black,4
# 866,14,Black,5
# 867,0,Black,4
# 868,0,Black,4
# 869,0,Black,4
# 870,0,Black,4
# 871,0,Black,4
# 872,0,Black,4
# 873,0,Black,3
# 874,0,Black,3
# 875,0,Black,4
# 876,0,Black,4
# 877,0,Black,4
# 878,0,Black,4
# 879,0,Black,4
# 880,0,Black,4
# 881,0,Black,4
# 882,1,White,4
# 883,2,White,168
# 884,3,White,165
# 885,4,White,163
# 886,5,White,167
# 887,6,White,163
# 888,7,White,164
# 889,8,White,163
# 890,9,White,162
# 891,10,White,159
# 892,11,White,161
# 893,12,White,155
# 894,13,White,159
# 895,14,White,164
# 896,15,White,161
# 897,1,Red,159
# 898,2,Red,71
# 899,3,Red,74
# 900,4,Red,70
# 901,5,Red,71
# 902,6,Red,69
# 903,7,Red,72
# 904,8,Red,69
# 905,9,Red,69
# 906,10,Red,74
# 907,11,Red,73
# 908,12,Red,72
# 909,13,Red,70
# 910,14,Red,70
# 911,1,Green,68
# 912,2,Green,65
# 913,3,Green,62
# 914,4,Green,64
# 915,5,Green,65
# 916,6,Green,63
# 917,7,Green,64
# 918,8,Green,66
# 919,9,Green,64
# 920,10,Green,66
# 921,11,Green,67
# 922,12,Green,64
# 923,13,Green,65
# 924,14,Green,65
# 925,15,Green,65
# 926,1,Blue,65
# 927,2,Blue,34
# 928,3,Blue,31
# 929,4,Blue,34
# 930,5,Blue,35
# 931,6,Blue,36
# 932,7,Blue,36
# 933,8,Blue,35
# 934,9,Blue,34
# 935,10,Blue,33
# 936,11,Blue,36
# 937,12,Blue,36
# 938,13,Blue,33
# 939,14,Blue,35
# 940,15,Blue,31
# 941,1,Black,36
# 942,2,Black,4
# 943,3,Black,4
# 944,4,Black,4
# 945,5,Black,4
# 946,6,Black,4
# 947,7,Black,4
# 948,8,Black,4
# 949,9,Black,5
# 950,10,Black,4
# 951,11,Black,3
# 952,12,Black,4
# 953,13,Black,4
# 954,14,Black,3
# 955,15,Black,4
# 956,0,Black,4
# 957,0,Black,4
# 958,0,Black,4
# 959,0,Black,4
# 960,0,Black,4
# 961,0,Black,4
# 962,0,Black,3
# 963,0,Black,4
# 964,0,Black,4
# 965,0,Black,4
# 966,0,Black,4
# 967,0,Black,3
# 968,0,Black,4
# 969,0,Black,3
# 970,1,White,4
# 971,2,White,158
# 972,3,White,158
# 973,4,White,164
# 974,5,White,157
# 975,6,White,164
# 976,7,White,162
# 977,8,White,163
# 978,9,White,158
# 979,10,White,162
# 980,11,White,161
# 981,12,White,160
# 982,13,White,163
# 983,14,White,161
# 984,15,White,161
# 985,1,Red,164
# 986,2,Red,72
# 987,3,Red,69
# 988,4,Red,72
# 989,5,Red,71
# 990,6,Red,73
# 991,7,Red,68
# 992,8,Red,68
# 993,9,Red,68
# 994,10,Red,72
# 995,11,Red,73
# 996,12,Red,69
# 997,13,Red,69
# 998,14,Red,69
# 999,15,Red,72
# 1000,1,Green,70
# 1001,2,Green,65
# 1002,3,Green,65
# 1003,4,Green,64
# 1004,5,Green,63
# 1005,6,Green,63
# 1006,7,Green,62
# 1007,8,Green,61
# 1008,9,Green,63
# 1009,10,Green,65
# 1010,11,Green,65
# 1011,12,Green,68
# 1012,13,Green,68
# 1013,14,Green,68
# 1014,1,Blue,66
# 1015,2,Blue,33
# 1016,3,Blue,35
# 1017,4,Blue,36
# 1018,5,Blue,34
# 1019,6,Blue,31
# 1020,7,Blue,32
# 1021,8,Blue,34
# 1022,9,Blue,32
# 1023,10,Blue,33
# 1024,11,Blue,36
# 1025,12,Blue,36
# 1026,13,Blue,36
# 1027,14,Blue,36
# 1028,15,Blue,32
# 1029,1,Black,31
# 1030,2,Black,4
# 1031,3,Black,4
# 1032,4,Black,4
# 1033,5,Black,4
# 1034,6,Black,4
# 1035,7,Black,4
# 1036,8,Black,3
# 1037,9,Black,4
# 1038,10,Black,4
# 1039,11,Black,4
# 1040,12,Black,3
# 1041,13,Black,4
# 1042,14,Black,3
# 1043,15,Black,4
# 1044,0,Black,3
# 1045,0,Black,3
# 1046,0,Black,3
# 1047,0,Black,5
# 1048,0,Black,4
# 1049,0,Black,3
# 1050,0,Black,4
# 1051,0,Black,5
# 1052,0,Black,3
# 1053,0,Black,4
# 1054,0,Black,3
# 1055,0,Black,4
# 1056,0,Black,4
# 1057,0,Black,4
# 1058,1,White,4
# 1059,2,White,157
# 1060,3,White,157
# 1061,4,White,161
# 1062,5,White,157
# 1063,6,White,155
# 1064,7,White,162
# 1065,8,White,158
# 1066,9,White,156
# 1067,10,White,156
# 1068,11,White,155
# 1069,12,White,161
# 1070,13,White,156
# 1071,14,White,156
# 1072,15,White,157
# 1073,1,Red,154
# 1074,2,Red,67
# 1075,3,Red,68
# 1076,4,Red,67
# 1077,5,Red,67
# 1078,6,Red,71
# 1079,7,Red,68
# 1080,8,Red,67
# 1081,9,Red,73
# 1082,10,Red,68
# 1083,11,Red,69
# 1084,12,Red,67
# 1085,13,Red,70
# 1086,14,Red,67
# 1087,15,Red,70
# 1088,1,Green,68
# 1089,2,Green,64
# 1090,3,Green,65
# 1091,4,Green,61
# 1092,5,Green,67
# 1093,6,Green,62
# 1094,7,Green,63
# 1095,8,Green,63
# 1096,9,Green,64
# 1097,10,Green,66
# 1098,11,Green,61
# 1099,12,Green,65
# 1100,13,Green,61
# 1101,14,Green,67
# 1102,1,Blue,61
# 1103,2,Blue,32
# 1104,3,Blue,32
# 1105,4,Blue,33
# 1106,5,Blue,35
# 1107,6,Blue,32
# 1108,7,Blue,34
# 1109,8,Blue,34
# 1110,9,Blue,35
# 1111,10,Blue,32
# 1112,11,Blue,35
# 1494,0,Black,3
# 1495,0,Black,4
# 1496,0,Black,4
# 1497,0,Black,4
# 1498,0,Black,4
# 1499,1,White,4
# 1500,2,White,148
# 1501,3,White,148
# 1502,4,White,147
# 1503,5,White,150
# 1504,6,White,147
# 1505,7,White,154
# 1506,8,White,152
# 1507,9,White,153
# 1508,10,White,151
# 1509,11,White,148
# 1510,12,White,152
# 1511,13,White,150
# 1512,14,White,152
# 1513,15,White,149
# 1514,1,Red,151
# 1515,2,Red,64
# 1516,3,Red,68
# 1517,4,Red,68
# 1518,5,Red,66
# 1519,6,Red,62
# 1520,7,Red,69
# 1521,8,Red,63
# 1522,9,Red,65
# 1523,10,Red,64
# 1524,11,Red,63
# 1525,12,Red,64
# 1526,13,Red,62
# 1527,14,Red,63
# 1528,1,Green,67
# 1529,2,Green,60
# 1530,3,Green,58
# 1531,4,Green,64
# 1532,5,Green,61
# 1533,6,Green,63
# 1534,7,Green,62
# 1535,8,Green,62
# 1536,9,Green,61
# 1537,10,Green,63
# 1538,11,Green,60
# 1539,12,Green,63
# 1540,13,Green,64
# 1541,14,Green,61
# 1542,15,Green,60
# 1543,1,Blue,60
# 1544,2,Blue,29
# 1545,3,Blue,29
# 1546,4,Blue,30
# 1547,5,Blue,33
# 1548,6,Blue,29
# 1549,7,Blue,29
# 1550,8,Blue,31
# 1551,9,Blue,30
# 1552,10,Blue,29
# 1553,11,Blue,29
# 1554,12,Blue,32
# 1555,13,Blue,30
# 1556,14,Blue,30
# 1557,15,Blue,30
# 1558,1,Black,29
# 1559,2,Black,4
# 1560,3,Black,4
# 1561,4,Black,5
# 1562,5,Black,4
# 1563,6,Black,4
# 1564,7,Black,3
# 1565,8,Black,4
# 1566,9,Black,3
# 1567,10,Black,4
# 1568,11,Black,3
# 1569,12,Black,4
# 1570,13,Black,5
# 1571,14,Black,4
# 1572,15,Black,3
# 1573,0,Black,4
# 1574,0,Black,3
# 1575,0,Black,4
# 1576,0,Black,4
# 1577,0,Black,3
# 1578,0,Black,4
# 1579,0,Black,5
# 1580,0,Black,5
# 1581,0,Black,4
# 1582,0,Black,4
# 1583,0,Black,4
# 1584,0,Black,4
# 1585,0,Black,4
# 1586,0,Black,4
# 1587,1,White,3
# 1588,2,White,152
# 1589,3,White,147
# 1590,4,White,147
# 1591,5,White,146
# 1592,6,White,144
# 1593,7,White,144
# 1594,8,White,146
# 1595,9,White,146
# 1596,10,White,146
# 1597,11,White,143
# 1598,12,White,145
# 1599,13,White,149
# 1600,14,White,145
# 1601,15,White,151
# 1602,1,Red,153
# 1603,2,Red,64
# 1604,3,Red,67
# 1605,4,Red,61
# 1606,5,Red,64
# 1607,6,Red,63
# 1608,7,Red,64
# 1609,8,Red,65
# 1610,9,Red,66
# 1611,10,Red,68
# 1612,11,Red,66
# 1613,12,Red,67
# 1614,13,Red,65
# 1615,14,Red,66
# 1616,15,Red,63
# 1617,1,Green,64
# 1618,2,Green,60
# 1619,3,Green,63
# 1620,4,Green,64
# 1621,5,Green,63
# 1748,15,Black,3
# 1749,0,Black,4
# 1750,0,Black,4
# 1751,0,Black,4
# 1752,0,Black,4
# 1753,0,Black,4
# 1754,0,Black,4
# 1755,0,Black,4
# 1756,0,Black,4
# 1757,0,Black,4
# 1758,0,Black,4
# 1759,0,Black,3
# 1760,0,Black,3
# 1761,0,Black,4
# 1762,0,Black,4
# 1763,1,White,4
# 1764,2,White,147
# 1765,3,White,143
# 1766,4,White,148
# 1767,5,White,147
# 1768,6,White,143
# 1769,7,White,147
# 1770,8,White,147
# 1771,9,White,142
# 1772,10,White,144
# 1773,11,White,143
# 1774,12,White,148
# 1775,13,White,145
# 1776,14,White,144
# 1777,15,White,147
# 1778,1,Red,143
# 1779,2,Red,66
# 1780,3,Red,61
# 1781,4,Red,67
# 1782,5,Red,60
# 1783,6,Red,61
# 1784,7,Red,61
# 1785,8,Red,66
# 1786,9,Red,66
# 1787,10,Red,61
# 1788,11,Red,67
# 1789,12,Red,62
# 1790,13,Red,66
# 1791,14,Red,66
# 1792,15,Red,62
# 1793,1,Green,62
# 1794,2,Green,58
# 1795,3,Green,59
# 1796,4,Green,58
# 1797,5,Green,62
# 1798,6,Green,58
# 1799,7,Green,59
# 1800,8,Green,60

# %% [markdown]
# โค้ดแปลงไฟล์ .txt ทุกไฟล์ในโฟลเดอร์ "raw_data" เป็นไฟล์ .csv และบันทึกในโฟลเดอร์ "datasetCSV" โดยลบข้อมูลในแถวแรกของแต่ละไฟล์ .txt ก่อนจะเขียนลงในไฟล์ .csv ที่สร้างขึ้นใหม่

# %%
import os
import csv

# ระบุโฟลเดอร์ raw_data
input_folder_path = "raw_data"

# ระบุโฟลเดอร์ที่จะบันทึกไฟล์ .csv
output_folder_path = "datasetCSV"

# ตรวจสอบว่าโฟลเดอร์ output_folder_path มีอยู่หรือไม่ และสร้างถ้าไม่มี
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# รายการไฟล์ในโฟลเดอร์ input_folder_path
files = os.listdir(input_folder_path)

# วนลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์ input_folder_path
for filename in files:
    input_file_path = os.path.join(input_folder_path, filename)

    # ตรวจสอบว่าไฟล์นี้เป็นไฟล์ข้อความหรือไม่
    if filename.endswith(".txt"):
        # สร้างชื่อไฟล์ .csv ใหม่โดยนำชื่อไฟล์เดิมมาใช้
        output_file_path = os.path.join(output_folder_path, os.path.splitext(filename)[0] + ".csv")

        # เปิดไฟล์ .txt สำหรับอ่าน
        with open(input_file_path, "r") as txt_file:
            # อ่านข้อมูลทั้งหมดจากไฟล์ .txt
            lines = txt_file.readlines()

        # ตรวจสอบว่ามีข้อมูลในไฟล์หรือไม่
        if len(lines) > 0:
            # ลบข้อมูลในแถวแรก
            lines = lines[1:]

            # เปิดไฟล์ .csv สำหรับเขียน
            with open(output_file_path, "w", newline='') as csv_file:
                # สร้างอ็อบเจ็กต์ writer สำหรับเขียนข้อมูล CSV
                csv_writer = csv.writer(csv_file)

                # เขียนข้อมูลลงในไฟล์ .csv
                for line in lines:
                    # แบ่งข้อมูลในแต่ละบรรทัดด้วยเครื่องหมาย "," และลบช่องว่างด้านหน้าและหลัง
                    row_data = line.strip().split(",")
                    csv_writer.writerow(row_data)

        print(f"แปลงไฟล์ '{filename}' และบันทึกเป็น '{os.path.basename(output_file_path)}'")

print("เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ datasetCSV")
# Out:
# แปลงไฟล์ 'P100_day1.txt' และบันทึกเป็น 'P100_day1.csv'
# แปลงไฟล์ 'P100_day2.txt' และบันทึกเป็น 'P100_day2.csv'
# แปลงไฟล์ 'P100_No_Reag.txt' และบันทึกเป็น 'P100_No_Reag.csv'
# แปลงไฟล์ 'P100_2.txt' และบันทึกเป็น 'P100_2.csv'
# แปลงไฟล์ 'P100_3.txt' และบันทึกเป็น 'P100_3.csv'
# เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ datasetCSV

# %% [markdown]
# เพิ่มหัวตารางในไฟล์ CSV  " column_names = ["No.", "Order", "Color", "Intensity"] "

# %%
import os
import pandas as pd

# Define the column names
column_names = ["No.", "Order", "Color", "Intensity"]

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file with the specified column names
    df = pd.read_csv(file_path, names=column_names)

    # Shift the data in the 'Intensity' column up by one row
    df['Intensity'] = df['Intensity'].shift(-1)

    # Drop rows where 'Order' is equal to 0 and 'Color' is equal to 'Black'
    df = df[(df['Order'] != 0) | (df['Color'] != 'Black')]

    # Specify the original file path and save the modified DataFrame
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to datasetCSV/P100_day2.csv
# Modified DataFrame saved to datasetCSV/P100_day1.csv
# Modified DataFrame saved to datasetCSV/P100_2.csv
# Modified DataFrame saved to datasetCSV/P100_3.csv
# Modified DataFrame saved to datasetCSV/P100_No_Reag.csv
# All CSV files in the 'datasetCSV' folder have been processed.

# %% [markdown]
# ลบข้อมูลในแถวสุดท้ายของแต่ละไฟล์ .csv ในโฟลเดอร์ "datasetCSV" และบันทึกไฟล์ด้วยชื่อเดิม หลังจากดำเนินการนี้กับทุกไฟล์ .csv ในโฟลเดอร์ จะแสดงข้อความ "All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name." เพื่อแสดงว่าการประมวลผลเสร็จสิ้นสำหรับทุกไฟล์ในโฟลเดอร์นี้.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Remove the last row from the DataFrame
    df = df.iloc[:-1]

    # Save the modified DataFrame back to the same file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Last row removed and file '{csv_file}' saved with the same name.")

print("All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name.")
# Out:
# Last row removed and file 'P100_day2.csv' saved with the same name.
# Last row removed and file 'P100_day1.csv' saved with the same name.
# Last row removed and file 'P100_2.csv' saved with the same name.
# Last row removed and file 'P100_3.csv' saved with the same name.
# Last row removed and file 'P100_No_Reag.csv' saved with the same name.
# All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name.

# %% [markdown]
# แปลงค่าในคอลัมน์ "Intensity" ของไฟล์ CSV เป็นจำนวนเต็มและบันทึกไปยังไฟล์ CSV ที่แก้ไขแล้วในโฟลเดอร์ "datasetCSV" ของทุกไฟล์ .csv ที่อยู่ในโฟลเดอร์นั้น การแปลงจะเป็นการเปลี่ยนชนิดข้อมูลเพียงอย่างเดียวและจะไม่มีการปฏิบัติกับข้อมูลที่ไม่ใช่จำนวนเต็ม.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Convert the 'Intensity' column to integers
    df['Intensity'] = df['Intensity'].astype(int)

    # Save the modified DataFrame back to the CSV file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to datasetCSV/P100_day2.csv
# Modified DataFrame saved to datasetCSV/P100_day1.csv
# Modified DataFrame saved to datasetCSV/P100_2.csv
# Modified DataFrame saved to datasetCSV/P100_3.csv
# Modified DataFrame saved to datasetCSV/P100_No_Reag.csv
# All CSV files in the 'datasetCSV' folder have been processed.

# %% [markdown]
# โค้ดวนลูปผ่านทุกไฟล์ .csv ในโฟลเดอร์ "datasetCSV" และแสดงข้อมูลจากแต่ละไฟล์ CSV ที่อยู่ในโฟลเดอร์นั้น ผ่านการใช้ pd.read_csv เพื่อโหลดข้อมูลลงใน DataFrame แล้วแสดงผลลัพธ์ด้วย print.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Loop through each CSV file and display its data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Display the data from the current CSV file
    print(f"Data from '{csv_file}':")
    print(df)
    print("\n")

print("All CSV files in the 'datasetCSV' folder have been displayed.")
# Out:
# Data from 'P100_day2.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        143
# 1        2      2  White        140
# 2        3      3  White        142
# 3        4      4  White        140
# 4        5      5  White        146
# ...    ...    ...    ...        ...
# 1500  1795      3  Green         56
# 1501  1796      4  Green         57
# 1502  1797      5  Green         56
# 1503  1798      6  Green         62
# 1504  1799      7  Green         56
#
# [1505 rows x 4 columns]
#
#
# Data from 'P100_day1.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        129
# 1        2      2  White        124
# 2        3      3  White        125
# 3        4      4  White        124
# 4        5      5  White        126
# ...    ...    ...    ...        ...
# 1500  1795      3  Green         55
# 1501  1796      4  Green         52
# 1502  1797      5  Green         56
# 1503  1798      6  Green         57
# 1504  1799      7  Green         56
#
# [1505 rows x 4 columns]
#
#
# Data from 'P100_2.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        278
# 1        2      2  White        279
# 2        3      3  White        244
# 3        4      4  White        283
# 4        5      5  White        284
# ...    ...    ...    ...        ...
# 1501  1795      3  Green         66
# 1502  1796      4  Green         63
# 1503  1797      5  Green         64
# 1504  1798      6  Green         67
# 1505  1799      7  Green         67
#
# [1506 rows x 4 columns]
#
#
# Data from 'P100_3.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        237
# 1        2      2  White        235
# 2        3      3  White        234
# 3        4      4  White        233
# 4        5      5  White        232
# ...    ...    ...    ...        ...
# 1501  1795      3  Green         58
# 1502  1796      4  Green         62
# 1503  1797      5  Green         58
# 1504  1798      6  Green         59
# 1505  1799      7  Green         60
#
# [1506 rows x 4 columns]
#
#
# Data from 'P100_No_Reag.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        830
# 1        2      2  White        822
# 2        3      3  White        832
# 3        4      4  White        832
# 4        5      5  White        823
# ...    ...    ...    ...        ...
# 1498  1795      4  Green        191
# 1499  1796      5  Green        195
# 1500  1797      6  Green        196
# 1501  1798      7  Green        198
# 1502  1799      8  Green        201
#
# [1503 rows x 4 columns]
#
#
# All CSV files in the 'datasetCSV' folder have been displayed.

# %% [markdown]
# # แสดงค่าเฉลี่ยและส่วนเบี่ยงเบนมาตรฐานของแต่ละ Order ของแต่ละ Color  ของแต่ละไฟล์

# %%
import os
import pandas as pd
import numpy as np

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Create empty lists to store the calculated statistics
average_intensity_values = []
std_dev_intensity_values = []

# Loop through each CSV file and calculate statistics for 'Intensity' column
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Group data by 'Order' and 'Color' columns, then calculate mean and standard deviation
    grouped_data = df.groupby(['Order', 'Color'])['Intensity']
    mean_intensity = grouped_data.mean()
    std_dev_intensity = grouped_data.std()

    # Append the calculated statistics to the lists
    average_intensity_values.append(mean_intensity)
    std_dev_intensity_values.append(std_dev_intensity)

# Combine the calculated statistics from all files into one DataFrame
average_intensity_df = pd.concat(average_intensity_values, axis=1)
std_dev_intensity_df = pd.concat(std_dev_intensity_values, axis=1)

# Rename columns to indicate file names
average_intensity_df.columns = csv_files
std_dev_intensity_df.columns = csv_files

# Print the calculated statistics
print("Average Intensity Values:")
print(average_intensity_df)

print("\nStandard Deviation of Intensity Values:")
print(std_dev_intensity_df)
# Out:
# Average Intensity Values:
#              P100_day2.csv  P100_day1.csv  P100_2.csv  P100_3.csv  \
# Order Color
# 1     Black       3.850000       3.800000    4.050000    3.950000
#       Blue       27.250000      22.350000   36.450000   36.950000
#       Green      59.571429      55.476190   74.857143   65.809524
#       Red        55.714286      51.095238   79.952381   73.333333
#       White     134.761905     119.761905  184.619048  169.047619
# ...                    ...            ...         ...         ...
# 15    Black       3.923077       3.928571    4.142857    3.857143
#       Blue       26.785714      22.692308   35.785714   35.214286
#       Green      60.071429      55.357143   77.000000   67.000000
#       Red        55.928571      49.500000   78.800000   73.666667
#       White     134.066667     120.000000  179.857143  164.642857
#
#              P100_No_Reag.csv
# Order Color
# 1     Black          6.100000
#       Blue         330.700000
#       Green        197.952381
#       Red          339.666667
#       White        821.666667
# ...                       ...
# 15    Black          6.071429
#       Blue         331.333333
#       Green        197.785714
#       Red          339.066667
#       White        820.250000
#
# [75 rows x 5 columns]
#
# Standard Deviation of Intensity Values:
#              P100_day2.csv  P100_day1.csv  P100_2.csv  P100_3.csv  \
# Order Color
# 1     Black       0.587143       0.523148    0.510418    0.394034
#       Blue        1.292692       1.268028    7.863808    6.320185
#       Green       2.336053       2.204973    8.368308    5.635770
#       Red         2.171241       2.385472   14.565288    9.603819
#       White       3.548306       3.871754   32.333382   23.191542
# ...                    ...            ...         ...         ...
# 15    Black       0.759555       0.474631    0.534522    0.363137
#       Blue        1.672335       1.182132    6.974443    5.351902
#       Green       1.730464       2.205139    9.591663    6.139406
#       Red         1.817195       2.066212   14.198591   10.417476
#       White       3.807261       3.525418   20.616861   16.222525
#
#              P100_No_Reag.csv
# Order Color
# 1     Black          1.209611
#       Blue           3.757099
#       Green          2.036570
#       Red            2.762849
#       White          4.234777
# ...                       ...
# 15    Black          0.730046
#       Blue           2.146173
#       Green          2.636389
#       Red            3.390463
#       White          3.545163
#
# [75 rows x 5 columns]

# %% [markdown]
# โค้ดบันทึกข้อมูลค่าเฉลี่ยและส่วนเบี่ยงเบนมาตรฐานของคอลัมน์ "Intensity" ที่คำนวณมาไว้ในไฟล์ "MSD.csv" ซึ่งจะถูกบันทึกในโฟลเดอร์ "datasetCSV" ที่เดียวกับไฟล์ CSV อื่นๆ ที่มีอยู่ในโฟลเดอร์นั้น โดยใช้ to_csv โดยที่ index=True เพื่อรวมข้อมูลรายการลงในไฟล์ "MSD.csv" และ mode='a' เพื่อเพิ่มข้อมูลในโหมดผนวก. คำสั่ง print ที่อยู่ต่อท้ายจะแสดงข้อความยืนยันว่าข้อมูลถูกบันทึกเรียบร้อยแล้ว.

# %%
import os
import pandas as pd
import numpy as np

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Create empty lists to store the calculated statistics
average_intensity_values = []
std_dev_intensity_values = []

# Loop through each CSV file and calculate statistics for 'Intensity' column
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Group data by 'Order' and 'Color' columns, then calculate mean and standard deviation
    grouped_data = df.groupby(['Order', 'Color'])['Intensity']
    mean_intensity = grouped_data.mean()
    std_dev_intensity = grouped_data.std()

    # Append the calculated statistics to the lists
    average_intensity_values.append(mean_intensity)
    std_dev_intensity_values.append(std_dev_intensity)

# Combine the calculated statistics from all files into one DataFrame
average_intensity_df = pd.concat(average_intensity_values, axis=1)
std_dev_intensity_df = pd.concat(std_dev_intensity_values, axis=1)

# Rename columns to indicate file names
average_intensity_df.columns = csv_files
std_dev_intensity_df.columns = csv_files

# Print the calculated statistics
print("Average Intensity Values:")
print(average_intensity_df)

print("\nStandard Deviation of Intensity Values:")
print(std_dev_intensity_df)

# Save the calculated statistics to 'MSD.csv'
msd_output_path = os.path.join(folder_path, "MSD.csv")
average_intensity_df.to_csv(msd_output_path, index=True)
std_dev_intensity_df.to_csv(msd_output_path, index=True, mode='a')

print(f"Calculated statistics saved to '{msd_output_path}'")
# Out:
# Average Intensity Values:
#              MSD_P100_No_Reag.csv  MSD_P100_day2.csv  MSD_P100_day1.csv  \
# Order Color
# 1     Black              6.100000           3.850000           3.800000
#       Blue             330.700000          27.250000          22.350000
#       Green            197.952381          59.571429          55.476190
#       Red              339.666667          55.714286          51.095238
#       White            821.666667         134.761905         119.761905
# ...                           ...                ...                ...
# 15    Black              6.071429           3.923077           3.928571
#       Blue             331.333333          26.785714          22.692308
#       Green            197.785714          60.071429          55.357143
#       Red              339.066667          55.928571          49.500000
#       White            820.250000         134.066667         120.000000
#
#              P100_day2.csv  P100_day1.csv  MSD_P100_2.csv  MSD_P100_3.csv  \
# Order Color
# 1     Black       3.850000       3.800000        4.050000        3.950000
#       Blue       27.250000      22.350000       36.450000       36.950000
#       Green      59.571429      55.476190       74.857143       65.809524
#       Red        55.714286      51.095238       79.952381       73.333333
#       White     134.761905     119.761905      184.619048      169.047619
# ...                    ...            ...             ...             ...
# 15    Black       3.923077       3.928571        4.142857        3.857143
#       Blue       26.785714      22.692308       35.785714       35.214286
#       Green      60.071429      55.357143       77.000000       67.000000
#       Red        55.928571      49.500000       78.800000       73.666667
#       White     134.066667     120.000000      179.857143      164.642857
#
#              P100_2.csv  P100_3.csv  P100_No_Reag.csv
# Order Color
# 1     Black    4.050000    3.950000          6.100000
#       Blue    36.450000   36.950000        330.700000
#       Green   74.857143   65.809524        197.952381
#       Red     79.952381   73.333333        339.666667
#       White  184.619048  169.047619        821.666667
# ...                 ...         ...               ...
# 15    Black    4.142857    3.857143          6.071429
#       Blue    35.785714   35.214286        331.333333
#       Green   77.000000   67.000000        197.785714
#       Red     78.800000   73.666667        339.066667
#       White  179.857143  164.642857        820.250000
#
# [75 rows x 10 columns]
#
# Standard Deviation of Intensity Values:
#              MSD_P100_No_Reag.csv  MSD_P100_day2.csv  MSD_P100_day1.csv  \
# Order Color
# 1     Black                   NaN                NaN                NaN
#       Blue                    NaN                NaN                NaN
#       Green                   NaN                NaN                NaN
#       Red                     NaN                NaN                NaN
#       White                   NaN                NaN                NaN
# ...                           ...                ...                ...
# 15    Black                   NaN                NaN                NaN
#       Blue                    NaN                NaN                NaN
#       Green                   NaN                NaN                NaN
#       Red                     NaN                NaN                NaN
#       White                   NaN                NaN                NaN
#
#              P100_day2.csv  P100_day1.csv  MSD_P100_2.csv  MSD_P100_3.csv  \
# Order Color
# 1     Black       0.587143       0.523148             NaN             NaN
#       Blue        1.292692       1.268028             NaN             NaN
#       Green       2.336053       2.204973             NaN             NaN
#       Red         2.171241       2.385472             NaN             NaN
#       White       3.548306       3.871754             NaN             NaN
# ...                    ...            ...             ...             ...
# 15    Black       0.759555       0.474631             NaN             NaN
#       Blue        1.672335       1.182132             NaN             NaN
#       Green       1.730464       2.205139             NaN             NaN
#       Red         1.817195       2.066212             NaN             NaN
#       White       3.807261       3.525418             NaN             NaN
#
#              P100_2.csv  P100_3.csv  P100_No_Reag.csv
# Order Color
# 1     Black    0.510418    0.394034          1.209611
#       Blue     7.863808    6.320185          3.757099
#       Green    8.368308    5.635770          2.036570
#       Red     14.565288    9.603819          2.762849
#       White   32.333382   23.191542          4.234777
# ...                 ...         ...               ...
# 15    Black    0.534522    0.363137          0.730046
#       Blue     6.974443    5.351902          2.146173
#       Green    9.591663    6.139406          2.636389
#       Red     14.198591   10.417476          3.390463
#       White   20.616861   16.222525          3.545163
#
# [75 rows x 10 columns]
# Calculated statistics saved to 'datasetCSV/MSD.csv'

# %% [markdown]
# # บันทึกไฟล์  โดยให้จำนวนลูปอยู่ในแนวนอน ของแต่ละไฟล์ MSD_.   ในโฟลเดอร์ datasetCSV

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(original_file_path)

    # Group the DataFrame by 'Order' and 'Color' columns
    grouped_df = df.groupby(['Order', 'Color']).mean().reset_index()

    # Define the new file name
    new_file_name = "MSD_" + csv_file

    # Define the new file path
    new_file_path = os.path.join(folder_path, new_file_name)

    # Save the grouped DataFrame to the new file
    grouped_df.to_csv(new_file_path, index=False)

    # Print a confirmation message
    print(f"Grouped DataFrame saved to {new_file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Grouped DataFrame saved to datasetCSV/MSD_P100_day2.csv
# Grouped DataFrame saved to datasetCSV/MSD_P100_day1.csv
# Grouped DataFrame saved to datasetCSV/MSD_P100_2.csv
# Grouped DataFrame saved to datasetCSV/MSD_P100_3.csv
# Grouped DataFrame saved to datasetCSV/MSD_P100_No_Reag.csv
# All CSV files in the 'datasetCSV' folder have been processed.

# %% [markdown]
# แสดงผลแบบ จำนวนลูปอยู่ในแนวนอน ของแต่ละไฟล์ MSD_.   ในโฟลเดอร์ datasetCSV

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    grouped_df = pd.read_csv(original_file_path)

    # Create a pivot table with 'Order' as columns and 'Color' as index
    pivot_df = grouped_df.pivot_table(values='Intensity', index='Color', columns='Order')

    # Print the pivot table
    print(f"Pivot Table for {csv_file}:")
    print(pivot_df)
    print("\n")
# Out:
# Pivot Table for MSD_P100_No_Reag.csv:
# Order          1           2           3           4           5           6   \
# Color
# Black    6.100000    6.250000    5.800000    5.850000    6.050000    6.150000
# Blue   330.700000  332.100000  332.750000  332.700000  331.850000  331.550000
# Green  197.952381  197.761905  197.476190  197.333333  198.095238  196.714286
# Red    339.666667  339.333333  340.000000  338.666667  341.190476  340.523810
# White  821.666667  819.904762  822.095238  821.619048  821.095238  822.047619
#
# Order          7           8           9           10          11          12  \
# Color
# Black    6.450000    5.950000    6.250000    6.100000    6.300000    6.050000
# Blue   333.500000  332.650000  332.850000  331.450000  333.300000  332.700000
# Green  197.666667  198.190476  197.700000  198.600000  196.450000  197.650000
# Red    339.571429  341.666667  339.666667  339.714286  340.190476  340.619048
# White  821.666667  821.761905  821.619048  821.000000  820.952381  821.571429
#
# Order          13          14          15
# Color
# Black    5.750000    5.750000    6.071429
# Blue   331.900000  331.550000  331.333333
# Green  198.000000  198.250000  197.785714
# Red    340.428571  339.619048  339.066667
# White  823.952381  821.809524  820.250000
#
#
# Pivot Table for MSD_P100_day2.csv:
# Order          1           2           3           4           5           6   \
# Color
# Black    3.850000    3.950000    4.150000    3.800000    3.750000    3.700000
# Blue    27.250000   27.050000   27.200000   27.450000   27.200000   27.150000
# Green   59.571429   59.761905   60.000000   59.380952   59.714286   60.428571
# Red     55.714286   56.238095   54.809524   56.047619   55.952381   55.095238
# White  134.761905  134.619048  134.809524  135.000000  135.952381  135.619048
#
# Order          7           8           9           10          11          12  \
# Color
# Black    3.850000    3.950000    3.850000    3.900000    3.750000    4.100000
# Blue    27.000000   26.950000   27.450000   27.150000   26.700000   27.200000
# Green   59.666667   59.300000   59.450000   60.350000   59.950000   59.750000
# Red     55.619048   56.190476   56.238095   55.619048   55.523810   55.571429
# White  135.952381  134.904762  135.428571  134.476190  135.428571  134.904762
#
# Order          13          14          15
# Color
# Black    3.800000    4.050000    3.923077
# Blue    27.150000   26.700000   26.785714
# Green   59.600000   59.450000   60.071429
# Red     55.761905   55.809524   55.928571
# White  134.666667  135.238095  134.066667
#
#
# Pivot Table for MSD_P100_day1.csv:
# Order          1           2           3           4           5           6   \
# Color
# Black
# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    grouped_df = pd.read_csv(original_file_path)

    # Create a pivot table with 'Order' as columns and 'Color' as index
    pivot_df = grouped_df.pivot_table(values='Intensity', index='Color', columns='Order', aggfunc='mean')

    # Calculate the standard deviation for each row (Color)
    std_deviation = pivot_df.apply(lambda row: row.std(), axis=1)

    # Add the mean and standard deviation columns to the pivot table
    pivot_df['Mean'] = pivot_df.mean(axis=1)
    pivot_df['Std Deviation'] = std_deviation

    # Print the pivot table
    print(f"Pivot Table for {csv_file}:")
    print(pivot_df)
    print("\n")

    # Save the pivot table to a CSV file with the same name in the same folder
    output_file_path = os.path.join(folder_path, csv_file)
    pivot_df.to_csv(output_file_path, index=True)
# Out:
# Pivot Table for MSD_P100_No_Reag.csv:
# Order           1           2           3           4           5           6  \
# Color
# Black    6.100000    6.250000    5.800000    5.850000    6.050000    6.150000
# Blue   330.700000  332.100000  332.750000  332.700000  331.850000  331.550000
# Green  197.952381  197.761905  197.476190  197.333333  198.095238  196.714286
# Red    339.666667  339.333333  340.000000  338.666667  341.190476  340.523810
# White  821.666667  819.904762  822.095238  821.619048  821.095238  822.047619
#
# Order           7           8           9          10          11          12  \
# Color
# Black    6.450000    5.950000    6.250000    6.100000    6.300000    6.050000
# Blue   333.500000  332.650000  332.850000  331.450000  333.300000  332.700000
# Green  197.666667  198.190476  197.700000  198.600000  196.450000  197.650000
# Red    339.571429  341.666667  339.666667  339.714286  340.190476  340.619048
# White  821.666667  821.761905  821.619048  821.000000  820.952381  821.571429
#
# Order          13          14          15        Mean  Std Deviation
# Color
# Black    5.750000    5.750000    6.071429    6.058095       0.208648
# Blue   331.900000  331.550000  331.333333  332.192222       0.799897
# Green  198.000000  198.250000  197.785714  197.708413       0.560317
# Red    340.428571  339.619048  339.066667  339.994921       0.792742
# White  823.952381  821.809524  820.250000  821.534127       0.915162
#
#
# Pivot Table for MSD_P100_day2.csv:
# Order           1           2           3           4           5           6  \
# Color
# Black    3.850000    3.950000    4.150000    3.800000    3.750000    3.700000
# Blue    27.250000   27.050000   27.200000   27.450000   27.200000   27.150000
# Green   59.571429   59.761905   60.000000   59.380952   59.714286   60.428571
# Red     55.714286   56.238095   54.809524   56.047619   55.952381   55.095238
# White  134.761905  134.619048  134.809524  135.000000  135.952381  135.619048
#
# Order           7           8           9          10          11          12  \
# Color
# Black    3.850000    3.950000    3.850000    3.900000    3.750000    4.100000
# Blue    27.000000   26.950000   27.450000   27.150000   26.700000   27.200000
# Green   59.666667   59.300000   59.450000   60.350000   59.950000   59.750000
# Red     55.619048   56.190476   56.238095   55.619048   55.523810   55.571429
# White  135.952381  134.904762  135.428571  134.476190  135.428571  134.904762
#
# Order          13          14          15        Mean  Std Deviation
# Color
# Black    3.800000    4.050000    3.923077    3.891538       0.131464
# Blue    27.150000   26.700000   26.785714   27.092381       0.232672
# Green   59.600000   59.450000   60.071429   59.763016       0.338608
# Red     55.761905   55.809524   55.928571   55.741270       0.402340
# White  134.666667  135.238095  134.066667  135.055238       0.540395
#
#
# Pivot Table for MSD_P100_day1.csv:
# Order           1           2           3           4           5           6  \
# Color
# Black
# %% [markdown]
# แสดงค่าเฉลี่ย และส่วนเบี่ยงเบนมาตรฐานของแต่ละไฟล์

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    if "MSD_P" in csv_file:
        # Construct the full file path
        original_file_path = os.path.join(folder_path, csv_file)

        # Read the CSV file into a DataFrame
        grouped_df = pd.read_csv(original_file_path)

        # Create a pivot table with 'Order' as columns and 'Color' as index
        pivot_df = grouped_df.pivot_table(values='Mean', index='Color', aggfunc='mean')

        # Calculate the standard deviation for each row (Color)
        std_deviation = pivot_df.apply(lambda row: row.std(), axis=1)

        # Add the mean and standard deviation columns to the pivot table
        pivot_df['Mean'] = pivot_df.mean(axis=1)
        pivot_df['Std Deviation'] = std_deviation

        # Print the 'Mean' column for 'MSD_P' files
        print(f"Mean for {csv_file} (MSD_P):")
        print(pivot_df['Mean'])
        print("\n")
# Out:
# Mean for MSD_P100_No_Reag.csv (MSD_P):
# Color
# Black      6.058095
# Blue     332.192222
# Green    197.708413
# Red      339.994921
# White    821.534127
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P100_day2.csv (MSD_P):
# Color
# Black      3.891538
# Blue      27.092381
# Green     59.763016
# Red       55.741270
# White    135.055238
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P100_day1.csv (MSD_P):
# Color
# Black      3.971905
# Blue      22.472821
# Green     55.322063
# Red       50.404762
# White    120.361905
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P100_2.csv (MSD_P):
# Color
# Black      4.076190
# Blue      36.109048
# Green     75.814603
# Red       79.897778
# White    183.685714
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P100_3.csv (MSD_P):
# Color
# Black      3.887143
# Blue      36.370952
# Green     66.568730
# Red       73.619048
# White    168.649206
# Name: Mean, dtype: float64

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# วนลูปเพื่ออ่านและแสดงข้อมูลจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลทุกคอลัมน์และแถว
    with pd.option_context('display.max_columns', None, 'display.max_rows', None):
        print(df)
    
    print("\n" + "="*80 + "\n")  # สร้างเส้นขั้นบรรทัด
# Out:
# ชื่อไฟล์: MSD_P100_No_Reag.csv
#
#    Color           1           2           3           4           5  \
# 0  Black    6.100000    6.250000    5.800000    5.850000    6.050000
# 1   Blue  330.700000  332.100000  332.750000  332.700000  331.850000
# 2  Green  197.952381  197.761905  197.476190  197.333333  198.095238
# 3    Red  339.666667  339.333333  340.000000  338.666667  341.190476
# 4  White  821.666667  819.904762  822.095238  821.619048  821.095238
#
#             6           7           8           9          10          11  \
# 0    6.150000    6.450000    5.950000    6.250000    6.100000    6.300000
# 1  331.550000  333.500000  332.650000  332.850000  331.450000  333.300000
# 2  196.714286  197.666667  198.190476  197.700000  198.600000  196.450000
# 3  340.523810  339.571429  341.666667  339.666667  339.714286  340.190476
# 4  822.047619  821.666667  821.761905  821.619048  821.000000  820.952381
#
#            12          13          14          15        Mean  Std Deviation
# 0    6.050000    5.750000    5.750000    6.071429    6.058095       0.208648
# 1  332.700000  331.900000  331.550000  331.333333  332.192222       0.799897
# 2  197.650000  198.000000  198.250000  197.785714  197.708413       0.560317
# 3  340.619048  340.428571  339.619048  339.066667  339.994921       0.792742
# 4  821.571429  823.952381  821.809524  820.250000  821.534127       0.915162
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_3.csv
#
#    Color           1           2           3           4           5  \
# 0  Black    3.950000    4.000000    4.100000    3.850000    3.800000
# 1   Blue   36.950000   35.800000   36.400000   36.850000   36.450000
# 2  Green   65.809524   66.619048   66.523810   66.761905   66.428571
# 3    Red   73.333333   73.904762   73.428571   73.523810   73.809524
# 4  White  169.047619  169.523810  169.666667  168.619048  168.380952
#
#             6           7           8           9          10          11  \
# 0    3.800000    3.800000    3.900000    3.700000    3.900000    3.750000
# 1   36.250000   36.750000   36.600000   36.300000   36.600000   36.850000
# 2   65.952381   66.285714   66.150000   66.350000   66.300000   66.750000
# 3   73.857143   73.000000   73.428571   73.380952   74.142857   74.190476
# 4  169.714286  170.047619  168.714286  168.619048  168.666667  168.428571
#
#            12          13          14          15        Mean  Std Deviation
# 0    3.950000    4.100000    3.850000    3.857143    3.887143       0.117064
# 1   36.600000   36.150000   35.800000   35.214286   36.370952       0.475151
# 2   67.550000   66.900000   67.150000   67.000000   66.568730       0.464653
# 3   73.523810   73.428571   73.666667   73.666667   73.619048       0.319438
# 4  168.619048  168.095238  168.952381  164.642857  168.649206       1.242876
#
# ================================================================================

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# วนลูปเพื่ออ่านและแสดงข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    print("\n" + "="*80 + "\n")  # สร้างเส้นขั้นบรรทัด
# Out:
# ชื่อไฟล์: MSD_P100_No_Reag.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.058095       0.208648
# 1   Blue  332.192222       0.799897
# 2  Green  197.708413       0.560317
# 3    Red  339.994921       0.792742
# 4  White  821.534127       0.915162
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_day2.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.891538       0.131464
# 1   Blue   27.092381       0.232672
# 2  Green   59.763016       0.338608
# 3    Red   55.741270       0.402340
# 4  White  135.055238       0.540395
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_day1.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.971905       0.133834
# 1   Blue   22.472821       0.221344
# 2  Green   55.322063       0.369490
# 3    Red   50.404762       0.548948
# 4  White  120.361905       0.403580
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_2.csv
#
#    Color        Mean  Std Deviation
# 0  Black    4.076190       0.157737
# 1   Blue   36.109048       0.326786
# 2  Green   75.814603       0.554841
# 3    Red   79.897778       0.573256
# 4  White  183.685714       1.319019
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_3.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.887143       0.117064
# 1   Blue   36.370952       0.475151
# 2  Green   66.568730       0.464653
# 3    Red   73.619048       0.319438
# 4  White  168.649206       1.242876
#
# ================================================================================

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้างรายการเปล่าที่จะเก็บข้อมูล
result_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    # เพิ่มข้อมูลลงในรายการ result_data
    result_data.append(selected_columns)

    print("\n" + "="*80 + "\n")

# รวมข้อมูลจากทุกไฟล์ CSV เป็น DataFrame เดียว
combined_data = pd.concat(result_data, axis=1)

# แสดงผลรายการ combined_data
print(combined_data)
# Out:
# ชื่อไฟล์: MSD_P100_No_Reag.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.058095       0.208648
# 1   Blue  332.192222       0.799897
# 2  Green  197.708413       0.560317
# 3    Red  339.994921       0.792742
# 4  White  821.534127       0.915162
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_day2.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.891538       0.131464
# 1   Blue   27.092381       0.232672
# 2  Green   59.763016       0.338608
# 3    Red   55.741270       0.402340
# 4  White  135.055238       0.540395
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_day1.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.971905       0.133834
# 1   Blue   22.472821       0.221344
# 2  Green   55.322063       0.369490
# 3    Red   50.404762       0.548948
# 4  White  120.361905       0.403580
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_2.csv
#
#    Color        Mean  Std Deviation
# 0  Black    4.076190       0.157737
# 1   Blue   36.109048       0.326786
# 2  Green   75.814603       0.554841
# 3    Red   79.897778       0.573256
# 4  White  183.685714       1.319019
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_3.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.887143       0.117064
# 1   Blue   36.370952       0.475151
# 2  Green   66.568730       0.464653
# 3    Red   73.619048       0.319438
# 4  White  168.649206       1.242876
#
# ================================================================================
#
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    6.058095       0.208648  Black    3.891538       0.131464  Black
# 1   Blue  332.192222       0.799897   Blue   27.092381       0.232672   Blue
# 2  Green  197.708413       0.560317  Green   59.763016       0.338608  Green
# 3    Red  339.994921       0.792742    Red   55.741270       0.402340    Red
# 4  White  821.534127       0.915162  White  135.055238       0.540395  White
#
#          Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0    3.971905       0.133834  Black    4.076190       0.157737  Black
# 1   22.472821       0.221344   Blue   36.109048       0.326786   Blue
# 2   55.322063       0.369490  Green   75.814603       0.554841  Green
# 3   50.404762       0.548948    Red   79.897778       0.573256    Red
# 4  120.361905       0.403580  White  183.685714       1.319019  White
#
#          Mean  Std Deviation
# 0    3.887143       0.117064
# 1   36.370952       0.475151
# 2   66.568730       0.464653
# 3   73.619048       0.319438
# 4  168.649206       1.242876

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้าง DataFrame ที่เก็บข้อมูลทั้งหมด
all_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เลือกคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่มข้อมูลที่เลือกเข้ากับรายการข้อมูลทั้งหมด
    all_data.append(selected_columns)

# รวมข้อมูลทุกไฟล์เข้าด้วยกัน
result = pd.concat(all_data, axis=1)

# แสดงผลลัพธ์
print(result)
# Out:
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    6.058095       0.208648  Black    3.891538       0.131464  Black
# 1   Blue  332.192222       0.799897   Blue   27.092381       0.232672   Blue
# 2  Green  197.708413       0.560317  Green   59.763016       0.338608  Green
# 3    Red  339.994921       0.792742    Red   55.741270       0.402340    Red
# 4  White  821.534127       0.915162  White  135.055238       0.540395  White
#
#          Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0    3.971905       0.133834  Black    4.076190       0.157737  Black
# 1   22.472821       0.221344   Blue   36.109048       0.326786   Blue
# 2   55.322063       0.369490  Green   75.814603       0.554841  Green
# 3   50.404762       0.548948    Red   79.897778       0.573256    Red
# 4  120.361905       0.403580  White  183.685714       1.319019  White
#
#          Mean  Std Deviation
# 0    3.887143       0.117064
# 1   36.370952       0.475151
# 2   66.568730       0.464653
# 3   73.619048       0.319438
# 4  168.649206       1.242876

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้าง DataFrame ที่เก็บข้อมูลทั้งหมด
all_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เพิ่มคอลัมน์ "ชื่อไฟล์" เพื่อเก็บชื่อไฟล์ของแต่ละไฟล์
    df.insert(0, "ชื่อไฟล์", csv_file)
    
    # เลือกคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่มข้อมูลที่เลือกเข้ากับรายการข้อมูลทั้งหมด
    all_data.append(selected_columns)

# รวมข้อมูลทุกไฟล์เข้าด้วยกัน
result = pd.concat(all_data, axis=1)

# แสดงผลลัพธ์
print(result)
# Out:
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    6.058095       0.208648  Black    3.891538       0.131464  Black
# 1   Blue  332.192222       0.799897   Blue   27.092381       0.232672   Blue
# 2  Green  197.708413       0.560317  Green   59.763016       0.338608  Green
# 3    Red  339.994921       0.792742    Red   55.741270       0.402340    Red
# 4  White  821.534127       0.915162  White  135.055238       0.540395  White
#
#          Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0    3.971905       0.133834  Black    4.076190       0.157737  Black
# 1   22.472821       0.221344   Blue   36.109048       0.326786   Blue
# 2   55.322063       0.369490  Green   75.814603       0.554841  Green
# 3   50.404762       0.548948    Red   79.897778       0.573256    Red
# 4  120.361905       0.403580  White  183.685714       1.319019  White
#
#          Mean  Std Deviation
# 0    3.887143       0.117064
# 1   36.370952       0.475151
# 2   66.568730       0.464653
# 3   73.619048       0.319438
# 4  168.649206       1.242876

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้างรายการของ DataFrame ที่จะรวมข้อมูล
dataframes_to_concat = []

# วนลูปเพื่ออ่านและรวมข้อมูลจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เลือกข้อมูลเฉพาะคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่ม DataFrame ที่ได้สร้างลงในรายการ
    dataframes_to_concat.append(selected_columns)

# รวมข้อมูลในรายการ DataFrame โดยใช้ pd.concat()
all_data = pd.concat(dataframes_to_concat, ignore_index=True)

# บันทึก DataFrame ที่รวมข้อมูลลงในไฟล์ "AllMSD.csv"
output_file_path = os.path.join(folder_path, 'AllMSD.csv')
all_data.to_csv(output_file_path, index=False)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMSD.csv
