# %% [markdown]
# โค้ดแสดงข้อมูลจากไฟล์ทั้งหมดในโฟลเดอร์ "raw_data" ที่มีนามสกุล ".txt" โดยแสดงข้อมูลของแต่ละไลน์ในแต่ละไฟล์ และเพิ่มบรรทัดว่างหลังจากแต่ละไฟล์เพื่อให้ข้อมูลดูเรียบร้อยขึ้นในผลลัพธ์ที่แสดงออกมาแบบเป็นรายการตามไฟล์ที่อยู่ในโฟลเดอร์ "raw_data" ทั้งหมด.

# %%
import os

# ระบุโฟลเดอร์ raw_data
folder_path = "raw_data"

# ตรวจสอบว่าโฟลเดอร์นี้มีอยู่จริงหรือไม่
if os.path.exists(folder_path):
    # รายการไฟล์ในโฟลเดอร์
    files = os.listdir(folder_path)

    # วนลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์
    for filename in files:
        file_path = os.path.join(folder_path, filename)

        # ตรวจสอบว่าไฟล์นี้เป็นไฟล์ข้อความหรือไม่
        if filename.endswith(".txt"):
            print(f"แสดงข้อมูลจากไฟล์ '{filename}':")
            
            # เปิดไฟล์สำหรับอ่าน
            with open(file_path, "r") as text_file:
                # อ่านและแสดงข้อมูลของแต่ละไลน์
                for line in text_file:
                    print(line.strip())  # ใช้ strip() เพื่อลบช่องว่างที่อาจจะเกิดขึ้น

            print("\n")  # เพิ่มบรรทัดว่างหลังจากแสดงข้อมูลของแต่ละไฮน์
else:
    print(f"โฟลเดอร์ '{folder_path}' ไม่มีอยู่หรือไม่สามารถเข้าถึงได้")
# Out:
# แสดงข้อมูลจากไฟล์ 'P10_NRe.txt':
# Phosphorus_No_reag 1,8000 rows
# 1,1,White,6
# 2,2,White,792
# 3,3,White,786
# 4,4,White,791
# 5,5,White,796
# 6,6,White,793
# 7,7,White,799
# 8,8,White,798
# 9,9,White,798
# 10,10,White,797
# 11,11,White,790
# 12,12,White,790
# 13,13,White,796
# 14,14,White,798
# 15,1,Red,791
# 16,2,Red,323
# 17,3,Red,321
# 18,4,Red,326
# 19,5,Red,326
# 20,6,Red,326
# 21,7,Red,320
# 22,8,Red,316
# 23,9,Red,319
# 24,10,Red,325
# 25,11,Red,324
# 26,12,Red,326
# 27,13,Red,323
# 28,14,Red,319
# 29,15,Red,314
# 30,1,Green,315
# 31,2,Green,187
# 32,3,Green,190
# 33,4,Green,189
# 34,5,Green,189
# 35,6,Green,188
# 36,7,Green,187
# 37,8,Green,189
# 38,9,Green,188
# 39,10,Green,188
# 40,11,Green,189
# 41,12,Green,191
# 42,13,Green,193
# 43,14,Green,189
# 44,1,Blue,188
# 45,2,Blue,327
# 46,3,Blue,325
# 47,4,Blue,318
# 48,5,Blue,326
# 49,6,Blue,326
# 50,7,Blue,328
# 51,8,Blue,323
# 52,9,Blue,323
# 53,10,Blue,322
# 54,11,Blue,324
# 55,12,Blue,331
# 56,13,Blue,329
# 57,14,Blue,332
# 58,15,Blue,327
# 59,1,Black,324
# 60,2,Black,7
# 61,3,Black,5
# 62,4,Black,6
# 63,5,Black,5
# 64,6,Black,4
# 65,7,Black,5
# 66,8,Black,4
# 67,9,Black,5
# 68,10,Black,7
# 69,11,Black,6
# 70,12,Black,5
# 71,13,Black,5
# 72,14,Black,6
# 73,15,Black,6
# 74,0,Black,5
# 75,0,Black,4
# 76,0,Black,5
# 77,0,Black,7
# 78,0,Black,4
# 79,0,Black,4
# 80,0,Black,5
# 81,0,Black,5
# 82,0,Black,6
# 83,0,Black,5
# 84,0,Black,5
# 85,0,Black,5
# 86,0,Black,6
# 87,0,Black,6
# 88,1,White,5
# 89,2,White,792
# 90,3,White,794
# 91,4,White,800
# 92,5,White,795
# 93,6,White,793
# 94,7,White,791
# 95,8,White,790
# 96,9,White,793
# 97,10,White,783
# 98,11,White,796
# 99,12,White,792
# 100,13,White,794
# 101,14,White,795
# 102,15,White,796
# 103,1,Red,796
# 104,2,Red,322
# 105,3,Red,326
# 106,4,Red,321
# 107,5,Red,317
# 108,6,Red,318
# 109,7,Red,326
# 110,8,Red,322
# 111,9,Red,319
# 112,10,Red,323
# 113,11,Red,320
# 114,12,Red,322
# 115,13,Red,322
# 116,14,Red,315
# 117,1,Green,317
# 118,2,Green,185
# 119,3,Green,190
# 120,4,Green,193
# 121,5,Green,188
# 122,6,Green,187
# 123,7,Green,193
# 124,8,Green,189
# 125,9,Green,190
# 126,10,Green,189
# 127,11,Green,184
# 128,12,Green,188
# 129,13,Green,187
# 130,14,Green,186
# 131,15,Green,189
# 132,1,Blue,190
# 133,2,Blue,331
# 134,3,Blue,323
# 135,4,Blue,324
# 136,5,Blue,323
# 137,6,Blue,330
# 138,7,Blue,330
# 139,8,Blue,325
# 140,9,Blue,329
# 141,10,Blue,324
# 142,11,Blue,328
# 143,12,Blue,327
# 144,13,Blue,326
# 145,14,Blue,321
# 146,15,Blue,325
# 147,1,Black,331
# 148,2,Black,5
# 149,3,Black,4
# 150,4,Black,5
# 151,5,Black,5
# 152,6,Black,6
# 153,7,Black,6
# 154,8,Black,5
# 155,9,Black,5
# 156,10,Black,5
# 157,11,Black,6
# 158,12,Black,5
# 159,13,Black,4
# 160,14,Black,6
# 161,0,Black,5
# 162,0,Black,5
# 163,0,Black,5
# 164,0,Black,5
# 165,0,Black,7
# 166,0,Black,4
# 167,0,Black,5
# 168,0,Black,6
# 169,0,Black,6
# 170,0,Black,6
# 171,0,Black,5
# 172,0,Black,5
# 173,0,Black,6
# 174,0,Black,6
# 175,0,Black,5
# 176,1,White,4
# 177,2,White,786
# 178,3,White,794
# 179,4,White,794
# 180,5,White,785
# 181,6,White,790
# 182,7,White,794
# 183,8,White,794
# 184,9,White,791
# 185,10,White,790
# 186,11,White,795
# 187,12,White,793
# 188,13,White,793
# 189,14,White,788
# 190,1,Red,791
# 191,2,Red,325
# 192,3,Red,319
# 193,4,Red,316
# 194,5,Red,322
# 195,6,Red,317
# 196,7,Red,325
# 197,8,Red,315
# 198,9,Red,317
# 199,10,Red,321
# 200,11,Red,325
# 201,12,Red,325
# 202,13,Red,321
# 203,14,Red,324
# 204,15,Red,316
# 205,1,Green,318
# 206,2,Green,193
# 207,3,Green,187
# 208,4,Green,189
# 209,5,Green,191
# 210,6,Green,194
# 211,7,Green,189
# 212,8,Green,185
# 213,9,Green,192
# 214,10,Green,193
# 215,11,Green,190
# 216,12,Green,188
# 217,13,Green,188
# 218,14,Green,185
# 219,15,Green,188
# 220,1,Blue,185
# 221,2,Blue,320
# 222,3,Blue,325
# 223,4,Blue,321
# 224,5,Blue,328
# 225,6,Blue,328
# 226,7,Blue,331
# 227,8,Blue,327
# 228,9,Blue,327
# 229,10,Blue,329
# 230,11,Blue,326
# 231,12,Blue,324
# 232,13,Blue,343
# 233,14,Blue,336
# 234,1,Black,333
# 235,2,Black,6
# 236,3,Black,6
# 237,4,Black,6
# 238,5,Black,5
# 239,6,Black,5
# 240,7,Black,4
# 241,8,Black,4
# 242,9,Black,6
# 243,10,Black,4
# 244,11,Black,5
# 245,12,Black,6
# 246,13,Black,5
# 247,14,Black,5
# 248,15,Black,4
# 249,0,Black,5
# 250,0,Black,5
# 251,0,Black,4
# 252,0,Black,4
# 253,0,Black,6
# 254,0,Black,6
# 255,0,Black,5
# 256,0,Black,5
# 257,0,Black,5
# 258,0,Black,4
# 259,0,Black,4
# 260,0,Black,6
# 261,0,Black,4
# 262,0,Black,4
# 263,0,Black,5
# 264,1,White,6
# 265,2,White,794
# 266,3,White,787
# 267,4,White,789
# 268,5,White,796
# 269,6,White,800
# 270,7,White,796
# 271,8,White,795
# 272,9,White,794
# 273,10,White,792
# 274,11,White,795
# 275,12,White,796
# 276,13,White,793
# 277,14,White,794
# 278,1,Red,798
# 279,2,Red,321
# 280,3,Red,321
# 281,4,Red,326
# 282,5,Red,323
# 283,6,Red,324
# 284,7,Red,320
# 285,8,Red,325
# 286,9,Red,321
# 287,10,Red,325
# 288,11,Red,318
# 289,12,Red,320
# 290,13,Red,320
# 291,14,Red,320
# 292,15,Red,320
# 293,1,Green,322
# 294,2,Green,193
# 295,3,Green,193
# 296,4,Green,186
# 297,5,Green,185
# 298,6,Green,188
# 299,7,Green,188
# 300,8,Green,188
# 301,9,Green,186
# 302,10,Green,192
# 303,11,Green,188
# 304,12,Green,190
# 305,13,Green,191
# 306,14,Green,191
# 307,1,Blue,188
# 308,2,Blue,325
# 309,3,Blue,320
# 310,4,Blue,321
# 311,5,Blue,330
# 312,6,Blue,325
# 313,7,Blue,329
# 314,8,Blue,324
# 315,9,Blue,323
# 316,10,Blue,332
# 317,11,Blue,319
# 318,12,Blue,324
# 319,13,Blue,330
# 320,14,Blue,322
# 321,15,Blue,324
# 322,1,Black,322
# 323,2,Black,5
# 324,3,Black,4
# 325,4,Black,7
# 326,5,Black,5
# 327,6,Black,5
# 328,7,Black,5
# 329,8,Black,4
# 330,9,Black,4
# 331,10,Black,5
# 332,11,Black,5
# 333,12,Black,4
# 334,13,Black,4
# 335,14,Black,6
# 336,15,Black,6
# 337,0,Black,5
# 338,0,Black,4
# 339,0,Black,4
# 340,0,Black,5
# 341,0,Black,4
# 342,0,Black,5
# 343,0,Black,5
# 344,0,Black,5
# 345,0,Black,4
# 346,0,Black,4
# 347,0,Black,6
# 348,0,Black,6
# 349,0,Black,5
# 350,0,Black,4
# 351,1,White,5
# 352,2,White,794
# 353,3,White,794
# 354,4,White,791
# 355,5,White,797
# 356,6,White,791
# 357,7,White,792
# 358,8,White,791
# 359,9,White,799
# 360,10,White,800
# 361,11,White,791
# 362,12,White,799
# 363,13,White,801
# 364,14,White,797
# 365,15,White,791
# 366,1,Red,792
# 367,2,Red,320
# 368,3,Red,320
# 369,4,Red,325
# 370,5,Red,326
# 371,6,Red,322
# 372,7,Red,319
# 373,8,Red,323
# 374,9,Red,317
# 375,10,Red,327
# 376,11,Red,321
# 377,12,Red,326
# 378,13,Red,323
# 379,14,Red,321
# 380,1,Green,325
# 381,2,Green,190
# 382,3,Green,192
# 383,4,Green,189
# 384,5,Green,187
# 385,6,Green,194
# 386,7,Green,188
# 387,8,Green,188
# 388,9,Green,185
# 389,10,Green,186
# 390,11,Green,188
# 391,12,Green,187
# 392,13,Green,193
# 393,14,Green,192
# 394,15,Green,195
# 395,1,Blue,191
# 396,2,Blue,321
# 397,3,Blue,329
# 398,4,Blue,324
# 399,5,Blue,323
# 400,6,Blue,328
# 401,7,Blue,326
# 402,8,Blue,320
# 403,9,Blue,323
# 404,10,Blue,326
# 405,11,Blue,322
# 406,12,Blue,323
# 407,13,Blue,321
# 408,14,Blue,328
# 409,15,Blue,330
# 410,1,Black,322
# 411,2,Black,4
# 412,3,Black,6
# 413,4,Black,6
# 414,5,Black,5
# 415,6,Black,5
# 416,7,Black,6
# 417,8,Black,5
# 418,9,Black,5
# 419,10,Black,4
# 420,11,Black,6
# 421,12,Black,5
# 422,13,Black,5
# 423,14,Black,4
# 424,0,Black,6
# 425,0,Black,6
# 426,0,Black,5
# 427,0,Black,6
# 428,0,Black,6
# 429,0,Black,5
# 430,0,Black,5
# 431,0,Black,4
# 432,0,Black,6
# 433,0,Black,5
# 434,0,Black,4
# 435,0,Black,4
# 436,0,Black,6
# 437,0,Black,6
# 438,0,Black,4
# 439,1,White,5
# 440,2,White,788
# 441,3,White,795
# 442,4,White,792
# 443,5,White,799
# 444,6,White,795
# 445,7,White,793
# 446,8,White,794
# 447,9,White,795
# 448,10,White,795
# 449,11,White,786
# 450,12,White,790
# 451,13,White,798
# 452,14,White,801
# 453,15,White,793
# 454,1,Red,796
# 455,2,Red,322
# 456,3,Red,323
# 457,4,Red,316
# 458,5,Red,319
# 459,6,Red,321
# 460,7,Red,323
# 461,8,Red,325
# 462,9,Red,322
# 463,10,Red,326
# 464,11,Red,321
# 465,12,Red,323
# 466,13,Red,316
# 467,14,Red,324
# 468,1,Green,316
# 469,2,Green,194
# 470,3,Green,193
# 471,4,Green,192
# 472,5,Green,193
# 473,6,Green,190
# 474,7,Green,192
# 475,8,Green,185
# 476,9,Green,193
# 477,10,Green,187
# 478,11,Green,193
# 479,12,Green,187
# 480,13,Green,190
# 481,14,Green,185
# 482,15,Green,191
# 483,1,Blue,188
# 484,2,Blue,330
# 485,3,Blue,326
# 486,4,Blue,323
# 487,5,Blue,328
# 488,6,Blue,325
# 489,7,Blue,326
# 490,8,Blue,327
# 491,9,Blue,326
# 492,10,Blue,325
# 493,11,Blue,324
# 494,12,Blue,324
# 495,13,Blue,323
# 496,14,Blue,326
# 497,1,Black,324
# 498,2,Black,4
# 499,3,Black,4
# 500,4,Black,5
# 501,5,Black,6
# 502,6,Black,6
# 503,7,Black,5
# 504,8,Black,5
# 505,9,Black,7
# 506,10,Black,7
# 507,11,Black,5
# 508,12,Black,5
# 509,13,Black,5
# 510,14,Black,6
# 511,15,Black,6
# 512,0,Black,5
# 513,0,Black,6
# 514,0,Black,6
# 515,0,Black,4
# 516,0,Black,5
# 517,0,Black,5
# 518,0,Black,6
# 519,0,Black,5
# 520,0,Black,5
# 521,0,Black,7
# 522,0,Black,5
# 523,0,Black,5
# 524,0,Black,5
# 525,0,Black,5
# 526,0,Black,6
# 527,1,White,5
# 528,2,White,794
# 529,3,White,791
# 530,4,White,789
# 531,5,White,792
# 532,6,White,796
# 533,7,White,788
# 534,8,White,790
# 535,9,White,797
# 536,10,White,802
# 537,11,White,798
# 538,12,White,792
# 539,13,White,798
# 540,14,White,795
# 541,1,Red,787
# 542,2,Red,325
# 543,3,Red,319
# 544,4,Red,325
# 545,5,Red,322
# 546,6,Red,317
# 547,7,Red,322
# 548,8,Red,322
# 549,9,Red,320
# 550,10,Red,318
# 551,11,Red,324
# 552,12,Red,323
# 553,13,Red,325
# 554,14,Red,318
# 555,15,Red,317
# 556,1,Green,318
# 557,2,Green,190
# 558,3,Green,189
# 559,4,Green,194
# 560,5,Green,192
# 561,6,Green,186
# 562,7,Green,187
# 563,8,Green,187
# 564,9,Green,188
# 565,10,Green,194
# 566,11,Green,188
# 567,12,Green,187
# 568,13,Green,195
# 569,14,Green,189
# 570,1,Blue,195
# 571,2,Blue,328
# 572,3,Blue,324
# 573,4,Blue,324
# 574,5,Blue,328
# 575,6,Blue,326
# 576,7,Blue,325
# 577,8,Blue,324
# 578,9,Blue,331
# 579,10,Blue,325
# 580,11,Blue,329
# 581,12,Blue,328
# 582,13,Blue,330
# 583,14,Blue,323
# 584,15,Blue,325
# 585,1,Black,323
# 586,2,Black,5
# 587,3,Black,5
# 588,4,Black,6
# 589,5,Black,6
# 590,6,Black,6
# 591,7,Black,5
# 592,8,Black,5
# 593,9,Black,6
# 594,10,Black,7
# 595,11,Black,4
# 596,12,Black,5
# 597,13,Black,6
# 598,14,Black,5
# 599,15,Black,4
# 600,0,Black,5
# 601,0,Black,5
# 602,0,Black,5
# 603,0,Black,4
# 604,0,Black,5
# 605,0,Black,6
# 606,0,Black,6
# 607,0,Black,5
# 608,0,Black,5
# 609,0,Black,6
# 610,0,Black,5
# 611,0,Black,5
# 612,0,Black,5
# 613,0,Black,5
# 614,1,White,6
# 615,2,White,793
# 616,3,White,787
# 617,4,White,796
# 618,5,White,792
# 619,6,White,795
# 620,7,White,792
# 621,8,White,792
# 622,9,White,798
# 623,10,White,794
# 624,11,White,796
# 625,12,White,799
# 626,13,White,794
# 627,14,White,791
# 628,15,White,791
# 629,1,Red,798
# 630,2,Red,328
# 631,3,Red,322
# 632,4,Red,323
# 633,5,Red,326
# 634,6,Red,317
# 635,7,Red,324
# 636,8,Red,320
# 637,9,Red,325
# 638,10,Red,322
# 639,11,Red,314
# 640,12,Red,319
# 641,13,Red,321
# 642,14,Red,326
# 643,15,Red,322
# 644,1,Green,323
# 645,2,Green,188
# 646,3,Green,186
# 647,4,Green,193
# 648,5,Green,187
# 649,6,Green,189
# 650,7,Green,189
# 651,8,Green,192
# 652,9,Green,186
# 653,10,Green,187
# 654,11,Green,187
# 655,12,Green,188
# 656,13,Green,187
# 657,14,Green,186
# 658,1,Blue,187
# 659,2,Blue,327
# 660,3,Blue,326
# 661,4,Blue,327
# 662,5,Blue,320
# 663,6,Blue,330
# 664,7,Blue,325
# 665,8,Blue,327
# 666,9,Blue,327
# 667,10,Blue,319
# 668,11,Blue,322
# 669,12,Blue,327
# 670,13,Blue,327
# 671,14,Blue,330
# 672,15,Blue,327
# 673,1,Black,325
# 674,2,Black,6
# 675,3,Black,6
# 676,4,Black,4
# 677,5,Black,4
# 678,6,Black,5
# 679,7,Black,6
# 680,8,Black,5
# 681,9,Black,5
# 682,10,Black,5
# 683,11,Black,5
# 684,12,Black,5
# 685,13,Black,4
# 686,14,Black,7
# 687,0,Black,5
# 688,0,Black,6
# 689,0,Black,5
# 690,0,Black,4
# 691,0,Black,6
# 692,0,Black,5
# 693,0,Black,4
# 694,0,Black,4
# 695,0,Black,5
# 696,0,Black,6
# 697,0,Black,5
# 698,0,Black,4
# 699,0,Black,5
# 700,0,Black,6
# 701,0,Black,5
# 702,1,White,5
# 703,2,White,790
# 704,3,White,796
# 705,4,White,793
# 706,5,White,794
# 707,6,White,797
# 708,7,White,787
# 709,8,White,795
# 710,9,White,799
# 711,10,White,793
# 712,11,White,790
# 713,12,White,789
# 714,13,White,799
# 715,14,White,787
# 716,15,White,790
# 717,1,Red,795
# 718,2,Red,326
# 719,3,Red,324
# 720,4,Red,320
# 721,5,Red,322
# 722,6,Red,321
# 723,7,Red,320
# 724,8,Red,326
# 725,9,Red,326
# 726,10,Red,320
# 727,11,Red,327
# 728,12,Red,321
# 729,13,Red,324
# 730,14,Red,323
# 731,1,Green,320
# 732,2,Green,187
# 733,3,Green,190
# 734,4,Green,190
# 735,5,Green,186
# 736,6,Green,187
# 737,7,Green,193
# 738,8,Green,193
# 739,9,Green,185
# 740,10,Green,194
# 741,11,Green,188
# 742,12,Green,195
# 743,13,Green,189
# 744,14,Green,193
# 745,15,Green,187
# 746,1,Blue,186
# 747,2,Blue,327
# 748,3,Blue,323
# 749,4,Blue,331
# 750,5,Blue,324
# 751,6,Blue,326
# 752,7,Blue,327
# 753,8,Blue,328
# 754,9,Blue,329
# 755,10,Blue,332
# 756,11,Blue,328
# 757,12,Blue,324
# 758,13,Blue,326
# 759,14,Blue,324
# 760,1,Black,323
# 761,2,Black,6
# 762,3,Black,6
# 763,4,Black,4
# 764,5,Black,5
# 765,6,Black,6
# 766,7,Black,5
# 767,8,Black,5
# 768,9,Black,4
# 769,10,Black,6
# 770,11,Black,5
# 771,12,Black,6
# 772,13,Black,6
# 773,14,Black,6
# 774,15,Black,5
# 775,0,Black,5
# 776,0,Black,5
# 777,0,Black,5
# 778,0,Black,6
# 779,0,Black,5
# 780,0,Black,4
# 781,0,Black,5
# 782,0,Black,5
# 783,0,Black,6
# 784,0,Black,6
# 785,0,Black,6
# 786,0,Black,4
# 787,0,Black,5
# 788,0,Black,5
# 789,0,Black,5
# 790,1,White,5
# 791,2,White,800
# 792,3,White,794
# 793,4,White,796
# 794,5,White,794
# 795,6,White,789
# 796,7,White,796
# 797,8,White,791
# 798,9,White,792
# 799,10,White,795
# 800,11,White,798
# 801,12,White,784
# 802,13,White,791
# 803,14,White,790
# 804,1,Red,793
# 805,2,Red,323
# 806,3,Red,326
# 807,4,Red,319
# 808,5,Red,327
# 809,6,Red,318
# 810,7,Red,315
# 811,8,Red,325
# 812,9,Red,322
# 813,10,Red,321
# 814,11,Red,323
# 815,12,Red,316
# 816,13,Red,328
# 817,14,Red,315
# 818,15,Red,318
# 819,1,Green,317
# 820,2,Green,188
# 821,3,Green,190
# 822,4,Green,190
# 823,5,Green,191
# 824,6,Green,191
# 825,7,Green,192
# 826,8,Green,188
# 827,9,Green,192
# 828,10,Green,194
# 829,11,Green,193
# 830,12,Green,191
# 831,13,Green,192
# 832,14,Green,192
# 833,15,Green,187
# 834,1,Blue,190
# 835,2,Blue,322
# 836,3,Blue,324
# 837,4,Blue,327
# 838,5,Blue,329
# 839,6,Blue,323
# 840,7,Blue,324
# 841,8,Blue,320
# 842,9,Blue,324
# 843,10,Blue,329
# 844,11,Blue,327
# 845,12,Blue,327
# 846,13,Blue,323
# 847,14,Blue,325
# 848,1,Black,325
# 849,2,Black,5
# 850,3,Black,5
# 851,4,Black,4
# 852,5,Black,4
# 853,6,Black,5
# 854,7,Black,5
# 855,8,Black,5
# 856,9,Black,5
# 857,10,Black,5
# 858,11,Black,6
# 859,12,Black,5
# 860,13,Black,5
# 861,14,Black,5
# 862,15,Black,5
# 863,0,Black,4
# 864,0,Black,5
# 865,0,Black,5
# 866,0,Black,4
# 867,0,Black,4
# 868,0,Black,5
# 869,0,Black,5
# 870,0,Black,4
# 871,0,Black,4
# 872,0,Black,4
# 873,0,Black,5
# 874,0,Black,4
# 875,0,Black,5
# 876,0,Black,5
# 877,1,White,4
# 878,2,White,798
# 879,3,White,785
# 880,4,White,794
# 881,5,White,798
# 882,6,White,798
# 883,7,White,795
# 884,8,White,798
# 885,9,White,800
# 886,10,White,793
# 887,11,White,797
# 888,12,White,799
# 889,13,White,789
# 890,14,White,791
# 891,15,White,791
# 892,1,Red,795
# 893,2,Red,320
# 894,3,Red,326
# 895,4,Red,325
# 896,5,Red,325
# 897,6,Red,324
# 898,7,Red,312
# 899,8,Red,321
# 900,9,Red,320
# 901,10,Red,325
# 902,11,Red,326
# 903,12,Red,323
# 904,13,Red,321
# 905,14,Red,326
# 906,15,Red,320
# 907,1,Green,323
# 908,2,Green,188
# 909,3,Green,196
# 910,4,Green,189
# 911,5,Green,193
# 912,6,Green,191
# 913,7,Green,188
# 914,8,Green,187
# 915,9,Green,189
# 916,10,Green,191
# 917,11,Green,188
# 918,12,Green,185
# 919,13,Green,188
# 920,14,Green,191
# 921,1,Blue,192
# 922,2,Blue,325
# 923,3,Blue,325
# 924,4,Blue,326
# 925,5,Blue,327
# 926,6,Blue,325
# 927,7,Blue,324
# 928,8,Blue,322
# 929,9,Blue,325
# 930,10,Blue,328
# 931,11,Blue,330
# 932,12,Blue,325
# 933,13,Blue,325
# 934,14,Blue,324
# 935,15,Blue,324
# 936,1,Black,323
# 937,2,Black,6
# 938,3,Black,6
# 939,4,Black,5
# 940,5,Black,5
# 941,6,Black,6
# 942,7,Black,7
# 943,8,Black,6
# 944,9,Black,6
# 945,10,Black,5
# 946,11,Black,5
# 947,12,Black,6
# 948,13,Black,6
# 949,14,Black,7
# 950,0,Black,6
# 951,0,Black,5
# 952,0,Black,6
# 953,0,Black,6
# 954,0,Black,5
# 955,0,Black,6
# 956,0,Black,4
# 957,0,Black,5
# 958,0,Black,6
# 959,0,Black,6
# 960,0,Black,4
# 961,0,Black,4
# 962,0,Black,5
# 963,0,Black,5
# 964,0,Black,4
# 965,1,White,4
# 966,2,White,791
# 967,3,White,796
# 968,4,White,795
# 969,5,White,795
# 970,6,White,791
# 971,7,White,800
# 972,8,White,794
# 973,9,White,797
# 974,10,White,789
# 975,11,White,789
# 976,12,White,793
# 977,13,White,801
# 978,14,White,798
# 979,15,White,794
# 980,1,Red,794
# 981,2,Red,324
# 982,3,Red,327
# 983,4,Red,320
# 984,5,Red,319
# 985,6,Red,325
# 986,7,Red,325
# 987,8,Red,320
# 988,9,Red,321
# 989,10,Red,325
# 990,11,Red,319
# 991,12,Red,320
# 992,13,Red,323
# 993,14,Red,322
# 994,1,Green,326
# 995,2,Green,186
# 996,3,Green,187
# 997,4,Green,189
# 998,5,Green,187
# 999,6,Green,186
# 1000,7,Green,189
# 1001,8,Green,187
# 1002,9,Green,192
# 1003,10,Green,189
# 1004,11,Green,188
# 1005,12,Green,193
# 1006,13,Green,187
# 1007,14,Green,190
# 1008,15,Green,189
# 1009,1,Blue,194
# 1010,2,Blue,322
# 1011,3,Blue,324
# 1012,4,Blue,327
# 1013,5,Blue,325
# 1014,6,Blue,327
# 1015,7,Blue,325
# 1016,8,Blue,326
# 1017,9,Blue,321
# 1018,10,Blue,327
# 1019,11,Blue,319
# 1020,12,Blue,326
# 1021,13,Blue,325
# 1022,14,Blue,323
# 1023,15,Blue,324
# 1024,1,Black,326
# 1025,2,Black,5
# 1026,3,Black,5
# 1027,4,Black,5
# 1028,5,Black,6
# 1029,6,Black,4
# 1030,7,Black,5
# 1031,8,Black,5
# 1032,9,Black,5
# 1033,10,Black,4
# 1034,11,Black,5
# 1035,12,Black,6
# 1036,13,Black,6
# 1037,14,Black,6
# 1038,0,Black,5
# 1039,0,Black,5
# 1040,0,Black,5
# 1041,0,Black,6
# 1042,0,Black,6
# 1043,0,Black,5
# 1044,0,Black,5
# 1045,0,Black,5
# 1046,0,Black,6
# 1047,0,Black,5
# 1048,0,Black,4
# 1049,0,Black,5
# 1050,0,Black,4
# 1051,0,Black,4
# 1052,0,Black,5
# 1053,1,White,7
# 1054,2,White,796
# 1055,3,White,797
# 1056,4,White,797
# 1057,5,White,794
# 1058,6,White,793
# 1059,7,White,794
# 1060,8,White,801
# 1061,9,White,794
# 1062,10,White,790
# 1063,11,White,792
# 1064,12,White,786
# 1065,13,White,798
# 1066,14,White,800
# 1067,1,Red,796
# 1068,2,Red,324
# 1069,3,Red,320
# 1070,4,Red,324
# 1071,5,Red,315
# 1072,6,Red,321
# 1073,7,Red,321
# 1074,8,Red,322
# 1075,9,Red,323
# 1076,10,Red,322
# 1077,11,Red,318
# 1078,12,Red,326
# 1079,13,Red,322
# 1080,14,Red,322
# 1081,15,Red,325
# 1082,1,Green,314
# 1083,2,Green,194
# 1084,3,Green,192
# 1085,4,Green,188
# 1086,5,Green,190
# 1087,6,Green,189
# 1088,7,Green,191
# 1089,8,Green,192
# 1090,9,Green,188
# 1091,10,Green,186
# 1092,11,Green,190
# 1093,12,Green,187
# 1094,13,Green,186
# 1095,14,Green,192
# 1096,15,Green,187
# 1097,1,Blue,188
# 1098,2,Blue,326
# 1099,3,Blue,324
# 1100,4,Blue,323
# 1101,5,Blue,323
# 1102,6,Blue,321
# 1103,7,Blue,325
# 1104,8,Blue,322
# 1105,9,Blue,324
# 1106,10,Blue,318
# 1107,11,Blue,324
# 1108,12,Blue,326
# 1109,13,Blue,328
# 1110,14,Blue,326
# 1111,1,Black,325
# 1112,2,Black,4
# 1113,3,Black,5
# 1114,4,Black,6
# 1115,5,Black,6
# 1116,6,Black,5
# 1117,7,Black,6
# 1118,8,Black,4
# 1119,9,Black,4
# 1120,10,Black,4
# 1121,11,Black,5
# 1122,12,Black,6
# 1123,13,Black,5
# 1124,14,Black,6
# 1125,15,Black,6
# 1126,0,Black,5
# 1127,0,Black,5
# 1128,0,Black,5
# 1129,0,Black,4
# 1130,0,Black,4
# 1131,0,Black,5
# 1132,0,Black,4
# 1133,0,Black,5
# 1134,0,Black,5
# 1135,0,Black,5
# 1136,0,Black,5
# 1137,0,Black,5
# 1138,0,Black,4
# 1139,0,Black,5
# 1140,0,Black,5
# 1141,1,White,5
# 1142,2,White,789
# 1143,3,White,794
# 1144,4,White,794
# 1145,5,White,794
# 1146,6,White,794
# 1147,7,White,784
# 1148,8,White,790
# 1149,9,White,790
# 1150,10,White,798
# 1151,11,White,795
# 1152,12,White,797
# 1153,13,White,797
# 1154,14,White,792
# 1155,1,Red,789
# 1156,2,Red,323
# 1157,3,Red,321
# 1158,4,Red,327
# 1159,5,Red,325
# 1160,6,Red,322
# 1161,7,Red,323
# 1162,8,Red,325
# 1163,9,Red,320
# 1164,10,Red,323
# 1165,11,Red,324
# 1166,12,Red,322
# 1167,13,Red,318
# 1168,14,Red,322
# 1169,15,Red,317
# 1170,1,Green,326
# 1171,2,Green,187
# 1172,3,Green,190
# 1173,4,Green,188
# 1174,5,Green,188
# 1175,6,Green,183
# 1176,7,Green,192
# 1177,8,Green,188
# 1178,9,Green,192
# 1179,10,Green,189
# 1180,11,Green,191
# 1181,12,Green,187
# 1182,13,Green,193
# 1183,14,Green,187
# 1184,1,Blue,189
# 1185,2,Blue,331
# 1186,3,Blue,325
# 1187,4,Blue,324
# 1188,5,Blue,324
# 1189,6,Blue,327
# 1190,7,Blue,324
# 1191,8,Blue,324
# 1192,9,Blue,326
# 1193,10,Blue,325
# 1194,11,Blue,325
# 1195,12,Blue,324
# 1196,13,Blue,324
# 1197,14,Blue,328
# 1198,15,Blue,322
# 1199,1,Black,325
# 1200,2,Black,5
# 1201,3,Black,4
# 1202,4,Black,5
# 1203,5,Black,5
# 1204,6,Black,5
# 1205,7,Black,6
# 1206,8,Black,4
# 1207,9,Black,6
# 1208,10,Black,4
# 1209,11,Black,4
# 1210,12,Black,4
# 1211,13,Black,3
# 1212,14,Black,6
# 1213,15,Black,6
# 1214,0,Black,4
# 1215,0,Black,5
# 1216,0,Black,6
# 1217,0,Black,6
# 1218,0,Black,5
# 1219,0,Black,5
# 1220,0,Black,6
# 1221,0,Black,5
# 1222,0,Black,5
# 1223,0,Black,4
# 1224,0,Black,5
# 1225,0,Black,6
# 1226,0,Black,6
# 1227,0,Black,5
# 1228,1,White,5
# 1229,2,White,788
# 1230,3,White,791
# 1231,4,White,792
# 1232,5,White,794
# 1233,6,White,789
# 1234,7,White,794
# 1235,8,White,796
# 1236,9,White,793
# 1237,10,White,796
# 1238,11,White,794
# 1239,12,White,795
# 1240,13,White,789
# 1241,14,White,790
# 1242,15,White,794
# 1243,1,Red,797
# 1244,2,Red,321
# 1245,3,Red,316
# 1246,4,Red,321
# 1247,5,Red,326
# 1248,6,Red,325
# 1249,7,Red,326
# 1250,8,Red,321
# 1251,9,Red,321
# 1252,10,Red,322
# 1253,11,Red,321
# 1254,12,Red,324
# 1255,13,Red,323
# 1256,14,Red,317
# 1257,15,Red,321
# 1258,1,Green,321
# 1259,2,Green,192
# 1260,3,Green,186
# 1261,4,Green,189
# 1262,5,Green,192
# 1263,6,Green,187
# 1264,7,Green,185
# 1265,8,Green,186
# 1266,9,Green,193
# 1267,10,Green,191
# 1268,11,Green,187
# 1269,12,Green,194
# 1270,13,Green,189
# 1271,14,Green,189
# 1272,1,Blue,186
# 1273,2,Blue,328
# 1274,3,Blue,320
# 1275,4,Blue,323
# 1276,5,Blue,322
# 1277,6,Blue,323
# 1278,7,Blue,331
# 1279,8,Blue,322
# 1280,9,Blue,326
# 1281,10,Blue,328
# 1282,11,Blue,324
# 1283,12,Blue,326
# 1284,13,Blue,331
# 1285,14,Blue,325
# 1286,15,Blue,329
# 1287,1,Black,328
# 1288,2,Black,6
# 1289,3,Black,5
# 1290,4,Black,5
# 1291,5,Black,5
# 1292,6,Black,4
# 1293,7,Black,5
# 1294,8,Black,5
# 1295,9,Black,5
# 1296,10,Black,5
# 1297,11,Black,3
# 1298,12,Black,4
# 1299,13,Black,4
# 1300,14,Black,6
# 1301,0,Black,5
# 1302,0,Black,4
# 1303,0,Black,4
# 1304,0,Black,5
# 1305,0,Black,5
# 1306,0,Black,5
# 1307,0,Black,5
# 1308,0,Black,4
# 1309,0,Black,4
# 1310,0,Black,5
# 1311,0,Black,5
# 1312,0,Black,5
# 1313,0,Black,4
# 1314,0,Black,4
# 1315,0,Black,5
# 1316,1,White,5
# 1317,2,White,798
# 1318,3,White,797
# 1319,4,White,793
# 1320,5,White,796
# 1321,6,White,794
# 1322,7,White,785
# 1323,8,White,791
# 1324,9,White,796
# 1325,10,White,798
# 1326,11,White,797
# 1327,12,White,794
# 1328,13,White,801
# 1329,14,White,792
# 1330,15,White,799
# 1331,1,Red,795
# 1332,2,Red,318
# 1333,3,Red,325
# 1334,4,Red,326
# 1335,5,Red,317
# 1336,6,Red,318
# 1337,7,Red,319
# 1338,8,Red,324
# 1339,9,Red,322
# 1340,10,Red,320
# 1341,11,Red,320
# 1342,12,Red,328
# 1343,13,Red,323
# 1344,14,Red,321
# 1345,1,Green,324
# 1346,2,Green,184
# 1347,3,Green,189
# 1348,4,Green,188
# 1349,5,Green,187
# 1350,6,Green,187
# 1351,7,Green,191
# 1352,8,Green,187
# 1353,9,Green,191
# 1354,10,Green,188
# 1355,11,Green,189
# 1356,12,Green,193
# 1357,13,Green,187
# 1358,14,Green,191
# 1359,15,Green,189
# 1360,1,Blue,189
# 1361,2,Blue,323
# 1362,3,Blue,327
# 1363,4,Blue,324
# 1364,5,Blue,325
# 1365,6,Blue,328
# 1366,7,Blue,330
# 1367,8,Blue,322
# 1368,9,Blue,326
# 1369,10,Blue,327
# 1370,11,Blue,326
# 1371,12,Blue,328
# 1372,13,Blue,326
# 1373,14,Blue,325
# 1374,1,Black,322
# 1375,2,Black,5
# 1376,3,Black,5
# 1377,4,Black,5
# 1378,5,Black,6
# 1379,6,Black,5
# 1380,7,Black,5
# 1381,8,Black,6
# 1382,9,Black,4
# 1383,10,Black,4
# 1384,11,Black,6
# 1385,12,Black,5
# 1386,13,Black,5
# 1387,14,Black,4
# 1388,15,Black,5
# 1389,0,Black,5
# 1390,0,Black,5
# 1391,0,Black,5
# 1392,0,Black,5
# 1393,0,Black,4
# 1394,0,Black,6
# 1395,0,Black,6
# 1396,0,Black,4
# 1397,0,Black,5
# 1398,0,Black,5
# 1399,0,Black,5
# 1400,0,Black,6
# 1401,0,Black,6
# 1402,0,Black,5
# 1403,0,Black,5
# 1404,1,White,5
# 1405,2,White,797
# 1406,3,White,799
# 1407,4,White,793
# 1408,5,White,798
# 1409,6,White,801
# 1410,7,White,800
# 1411,8,White,784
# 1412,9,White,791
# 1413,10,White,792
# 1414,11,White,801
# 1415,12,White,798
# 1416,13,White,784
# 1417,14,White,796
# 1418,1,Red,800
# 1419,2,Red,326
# 1420,3,Red,325
# 1421,4,Red,326
# 1422,5,Red,317
# 1423,6,Red,323
# 1424,7,Red,328
# 1425,8,Red,321
# 1426,9,Red,324
# 1427,10,Red,315
# 1428,11,Red,324
# 1429,12,Red,324
# 1430,13,Red,322
# 1431,14,Red,320
# 1432,15,Red,316
# 1433,1,Green,320
# 1434,2,Green,193
# 1435,3,Green,188
# 1436,4,Green,190
# 1437,5,Green,191
# 1438,6,Green,189
# 1439,7,Green,188
# 1440,8,Green,186
# 1441,9,Green,184
# 1442,10,Green,191
# 1443,11,Green,193
# 1444,12,Green,187
# 1445,13,Green,192
# 1446,14,Green,189
# 1447,15,Green,191
# 1448,1,Blue,187
# 1449,2,Blue,328
# 1450,3,Blue,327
# 1451,4,Blue,325
# 1452,5,Blue,326
# 1453,6,Blue,328
# 1454,7,Blue,327
# 1455,8,Blue,324
# 1456,9,Blue,326
# 1457,10,Blue,318
# 1458,11,Blue,326
# 1459,12,Blue,325
# 1460,13,Blue,327
# 1461,14,Blue,325
# 1462,1,Black,326
# 1463,2,Black,6
# 1464,3,Black,5
# 1465,4,Black,4
# 1466,5,Black,5
# 1467,6,Black,6
# 1468,7,Black,4
# 1469,8,Black,5
# 1470,9,Black,5
# 1471,10,Black,5
# 1472,11,Black,4
# 1473,12,Black,4
# 1474,13,Black,6
# 1475,14,Black,6
# 1476,15,Black,5
# 1477,0,Black,5
# 1478,0,Black,6
# 1479,0,Black,5
# 1480,0,Black,6
# 1481,0,Black,5
# 1482,0,Black,6
# 1483,0,Black,5
# 1484,0,Black,5
# 1485,0,Black,4
# 1486,0,Black,4
# 1487,0,Black,5
# 1488,0,Black,5
# 1489,0,Black,5
# 1490,0,Black,5
# 1491,1,White,3
# 1492,2,White,801
# 1493,3,White,795
# 1494,4,White,795
# 1495,5,White,792
# 1496,6,White,795
# 1497,7,White,794
# 1498,8,White,793
# 1499,9,White,795
# 1500,10,White,799
# 1501,11,White,795
# 1502,12,White,795
# 1503,13,White,797
# 1504,14,White,795
# 1505,15,White,793
# 1506,1,Red,799
# 1507,2,Red,318
# 1508,3,Red,321
# 1509,4,Red,324
# 1510,5,Red,324
# 1511,6,Red,325
# 1512,7,Red,324
# 1513,8,Red,318
# 1514,9,Red,317
# 1515,10,Red,322
# 1516,11,Red,323
# 1517,12,Red,322
# 1518,13,Red,319
# 1519,14,Red,322
# 1520,15,Red,322
# 1521,1,Green,318
# 1522,2,Green,187
# 1523,3,Green,195
# 1524,4,Green,188
# 1525,5,Green,188
# 1526,6,Green,193
# 1527,7,Green,192
# 1528,8,Green,195
# 1529,9,Green,187
# 1530,10,Green,190
# 1531,11,Green,189
# 1532,12,Green,192
# 1533,13,Green,185
# 1534,14,Green,186
# 1535,1,Blue,189
# 1536,2,Blue,326
# 1537,3,Blue,325
# 1538,4,Blue,324
# 1539,5,Blue,327
# 1540,6,Blue,326
# 1541,7,Blue,322
# 1542,8,Blue,331
# 1543,9,Blue,325
# 1544,10,Blue,322
# 1545,11,Blue,322
# 1546,12,Blue,323
# 1547,13,Blue,324
# 1548,14,Blue,322
# 1549,15,Blue,329
# 1550,1,Black,327
# 1551,2,Black,4
# 1552,3,Black,5
# 1553,4,Black,5
# 1554,5,Black,6
# 1555,6,Black,4
# 1556,7,Black,5
# 1557,8,Black,5
# 1558,9,Black,6
# 1559,10,Black,5
# 1560,11,Black,5
# 1561,12,Black,5
# 1562,13,Black,6
# 1563,14,Black,5
# 1564,15,Black,5
# 1565,0,Black,5
# 1566,0,Black,4
# 1567,0,Black,5
# 1568,0,Black,6
# 1569,0,Black,5
# 1570,0,Black,4
# 1571,0,Black,5
# 1572,0,Black,4
# 1573,0,Black,6
# 1574,0,Black,5
# 1575,0,Black,5
# 1576,0,Black,5
# 1577,0,Black,4
# 1578,0,Black,5
# 1579,1,White,6
# 1580,2,White,799
# 1581,3,White,793
# 1582,4,White,798
# 1583,5,White,799
# 1584,6,White,793
# 1585,7,White,800
# 1586,8,White,802
# 1587,9,White,791
# 1588,10,White,795
# 1589,11,White,798
# 1590,12,White,801
# 1591,13,White,798
# 1592,14,White,802
# 1593,15,White,790
# 1594,1,Red,792
# 1595,2,Red,321
# 1596,3,Red,325
# 1597,4,Red,325
# 1598,5,Red,320
# 1599,6,Red,319
# 1600,7,Red,320
# 1601,8,Red,323
# 1602,9,Red,316
# 1603,10,Red,313
# 1604,11,Red,324
# 1605,12,Red,324
# 1606,13,Red,326
# 1607,14,Red,325
# 1608,1,Green,325
# 1609,2,Green,191
# 1610,3,Green,193
# 1611,4,Green,195
# 1612,5,Green,190
# 1613,6,Green,191
# 1614,7,Green,191
# 1615,8,Green,188
# 1616,9,Green,188
# 1617,10,Green,191
# 1618,11,Green,190
# 1619,12,Green,189
# 1620,13,Green,186
# 1621,14,Green,190
# 1622,15,Green,193
# 1623,1,Blue,192
# 1624,2,Blue,330
# 1625,3,Blue,326
# 1626,4,Blue,328
# 1627,5,Blue,325
# 1628,6,Blue,329
# 1629,7,Blue,324
# 1630,8,Blue,320
# 1631,9,Blue,328
# 1632,10,Blue,324
# 1633,11,Blue,325
# 1634,12,Blue,327
# 1635,13,Blue,323
# 1636,14,Blue,324
# 1637,1,Black,320
# 1638,2,Black,4
# 1639,3,Black,5
# 1640,4,Black,6
# 1641,5,Black,5
# 1642,6,Black,4
# 1643,7,Black,5
# 1644,8,Black,4
# 1645,9,Black,4
# 1646,10,Black,4
# 1647,11,Black,6
# 1648,12,Black,5
# 1649,13,Black,4
# 1650,14,Black,6
# 1651,0,Black,5
# 1652,0,Black,4
# 1653,0,Black,4
# 1654,0,Black,5
# 1655,0,Black,5
# 1656,0,Black,4
# 1657,0,Black,4
# 1658,0,Black,6
# 1659,0,Black,6
# 1660,0,Black,5
# 1661,0,Black,5
# 1662,0,Black,5
# 1663,0,Black,6
# 1664,0,Black,4
# 1665,1,White,4
# 1666,2,White,801
# 1667,3,White,797
# 1668,4,White,792
# 1669,5,White,794
# 1670,6,White,793
# 1671,7,White,796
# 1672,8,White,797
# 1673,9,White,794
# 1674,10,White,798
# 1675,11,White,798
# 1676,12,White,801
# 1677,13,White,788
# 1678,14,White,790
# 1679,15,White,795
# 1680,1,Red,799
# 1681,2,Red,328
# 1682,3,Red,325
# 1683,4,Red,326
# 1684,5,Red,322
# 1685,6,Red,323
# 1686,7,Red,317
# 1687,8,Red,323
# 1688,9,Red,320
# 1689,10,Red,322
# 1690,11,Red,321
# 1691,12,Red,326
# 1692,13,Red,324
# 1693,14,Red,325
# 1694,15,Red,324
# 1695,1,Green,321
# 1696,2,Green,189
# 1697,3,Green,187
# 1698,4,Green,196
# 1699,5,Green,186
# 1700,6,Green,193
# 1701,7,Green,186
# 1702,8,Green,188
# 1703,9,Green,188
# 1704,10,Green,192
# 1705,11,Green,187
# 1706,12,Green,189
# 1707,13,Green,188
# 1708,14,Green,193
# 1709,1,Blue,188
# 1710,2,Blue,328
# 1711,3,Blue,326
# 1712,4,Blue,329
# 1713,5,Blue,333
# 1714,6,Blue,320
# 1715,7,Blue,325
# 1716,8,Blue,325
# 1717,9,Blue,326
# 1718,10,Blue,325
# 1719,11,Blue,327
# 1720,12,Blue,330
# 1721,13,Blue,325
# 1722,14,Blue,326
# 1723,15,Blue,331
# 1724,1,Black,324
# 1725,2,Black,5
# 1726,3,Black,5
# 1727,4,Black,5
# 1728,5,Black,4
# 1729,6,Black,5
# 1730,7,Black,5
# 1731,8,Black,5
# 1732,9,Black,6
# 1733,10,Black,4
# 1734,11,Black,5
# 1735,12,Black,5
# 1736,13,Black,5
# 1737,14,Black,5
# 1738,0,Black,5
# 1739,0,Black,5
# 1740,0,Black,6
# 1741,0,Black,6
# 1742,0,Black,5
# 1743,0,Black,5
# 1744,0,Black,5
# 1745,0,Black,5
# 1746,0,Black,5
# 1747,0,Black,6
# 1748,0,Black,6
# 1749,0,Black,5
# 1750,0,Black,5
# 1751,0,Black,4
# 1752,0,Black,5
# 1753,1,White,6
# 1754,2,White,790
# 1755,3,White,795
# 1756,4,White,799
# 1757,5,White,798
# 1758,6,White,799
# 1759,7,White,795
# 1760,8,White,803
# 1761,9,White,788
# 1762,10,White,790
# 1763,11,White,800
# 1764,12,White,787
# 1765,13,White,795
# 1766,14,White,796
# 1767,15,White,788
# 1768,1,Red,797
# 1769,2,Red,312
# 1770,3,Red,322
# 1771,4,Red,326
# 1772,5,Red,328
# 1773,6,Red,320
# 1774,7,Red,319
# 1775,8,Red,321
# 1776,9,Red,321
# 1777,10,Red,325
# 1778,11,Red,324
# 1779,12,Red,324
# 1780,13,Red,321
# 1781,14,Red,319
# 1782,1,Green,319
# 1783,2,Green,194
# 1784,3,Green,190
# 1785,4,Green,187
# 1786,5,Green,188
# 1787,6,Green,189
# 1788,7,Green,192
# 1789,8,Green,189
# 1790,9,Green,188
# 1791,10,Green,187
# 1792,11,Green,187
# 1793,12,Green,192
# 1794,13,Green,189
# 1795,14,Green,192
# 1796,15,Green,188
# 1797,1,Blue,194
# 1798,2,Blue,323
# 1799,3,Blue,324
# 1800,4,Blue,329
#
#
# แสดงข้อมูลจากไฟล์ 'P100.txt':
# Phosphorus_concentrate 100 mg/L
# 1,1,White,4
# 2,2,White,237
# 3,3,White,235
# 4,4,White,234
# 5,5,White,233
# 6,6,White,232
# 7,7,White,235
# 8,8,White,232
# 9,9,White,229
# 10,10,White,229
# 11,11,White,229
# 12,12,White,233
# 13,13,White,228
# 14,14,White,231
# 15,1,Red,230
# 16,2,Red,98
# 17,3,Red,102
# 18,4,Red,98
# 19,5,Red,103
# 20,6,Red,101
# 21,7,Red,98
# 22,8,Red,97
# 23,9,Red,96
# 24,10,Red,99
# 25,11,Red,98
# 26,12,Red,98
# 27,13,Red,102
# 28,14,Red,101
# 29,15,Red,98
# 30,1,Green,99
# 31,2,Green,80
# 32,3,Green,83
# 33,4,Green,80
# 34,5,Green,78
# 35,6,Green,81
# 36,7,Green,80
# 37,8,Green,80
# 38,9,Green,78
# 39,10,Green,80
# 40,11,Green,78
# 41,12,Green,82
# 42,13,Green,79
# 43,14,Green,79
# 44,15,Green,83
# 45,1,Blue,79
# 46,2,Blue,50
# 47,3,Blue,52
# 48,4,Blue,51
# 49,5,Blue,52
# 50,6,Blue,51
# 51,7,Blue,53
# 52,8,Blue,50
# 53,9,Blue,54
# 54,10,Blue,51
# 55,11,Blue,50
# 56,12,Blue,51
# 57,13,Blue,54
# 58,14,Blue,50
# 59,1,Black,51
# 60,2,Black,4
# 61,3,Black,4
# 62,4,Black,4
# 63,5,Black,4
# 64,6,Black,3
# 65,7,Black,4
# 66,8,Black,4
# 67,9,Black,4
# 68,10,Black,4
# 69,11,Black,3
# 70,12,Black,4
# 71,13,Black,4
# 72,14,Black,4
# 73,15,Black,4
# 74,0,Black,4
# 75,0,Black,4
# 76,0,Black,4
# 77,0,Black,4
# 78,0,Black,4
# 79,0,Black,5
# 80,0,Black,5
# 81,0,Black,4
# 82,0,Black,4
# 83,0,Black,4
# 84,0,Black,4
# 85,0,Black,5
# 86,0,Black,4
# 87,0,Black,4
# 88,0,Black,4
# 89,1,White,4
# 90,2,White,210
# 91,3,White,211
# 92,4,White,211
# 93,5,White,210
# 94,6,White,205
# 95,7,White,206
# 96,8,White,208
# 97,9,White,209
# 98,10,White,201
# 99,11,White,207
# 100,12,White,206
# 101,13,White,208
# 102,14,White,206
# 103,1,Red,209
# 104,2,Red,89
# 105,3,Red,93
# 106,4,Red,92
# 107,5,Red,87
# 108,6,Red,93
# 109,7,Red,89
# 110,8,Red,88
# 111,9,Red,89
# 112,10,Red,88
# 113,11,Red,88
# 114,12,Red,89
# 115,13,Red,89
# 116,14,Red,87
# 117,15,Red,93
# 118,1,Green,90
# 119,2,Green,75
# 120,3,Green,77
# 121,4,Green,75
# 122,5,Green,76
# 123,6,Green,77
# 124,7,Green,77
# 125,8,Green,74
# 126,9,Green,74
# 127,10,Green,76
# 128,11,Green,74
# 129,12,Green,77
# 130,13,Green,75
# 131,14,Green,79
# 132,15,Green,77
# 133,1,Blue,75
# 134,2,Blue,49
# 135,3,Blue,46
# 136,4,Blue,46
# 137,5,Blue,50
# 138,6,Blue,49
# 139,7,Blue,44
# 140,8,Blue,47
# 141,9,Blue,48
# 142,10,Blue,46
# 143,11,Blue,45
# 144,12,Blue,44
# 145,13,Blue,46
# 146,14,Blue,45
# 147,1,Black,47
# 148,2,Black,3
# 149,3,Black,5
# 150,4,Black,4
# 151,5,Black,5
# 152,6,Black,4
# 153,7,Black,3
# 154,8,Black,4
# 155,9,Black,4
# 156,10,Black,4
# 157,11,Black,4
# 158,12,Black,4
# 159,13,Black,4
# 160,14,Black,4
# 161,15,Black,3
# 162,0,Black,4
# 163,0,Black,4
# 164,0,Black,3
# 165,0,Black,4
# 166,0,Black,4
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black,4
# 171,0,Black,4
# 172,0,Black,4
# 173,0,Black,4
# 174,0,Black,4
# 175,0,Black,4
# 176,0,Black,5
# 177,1,White,5
# 178,2,White,193
# 179,3,White,198
# 180,4,White,191
# 181,5,White,195
# 182,6,White,199
# 183,7,White,196
# 184,8,White,197
# 185,9,White,194
# 186,10,White,200
# 187,11,White,195
# 188,12,White,198
# 189,13,White,194
# 190,14,White,197
# 191,15,White,196
# 192,1,Red,197
# 193,2,Red,83
# 194,3,Red,83
# 195,4,Red,85
# 196,5,Red,87
# 197,6,Red,84
# 198,7,Red,86
# 199,8,Red,85
# 200,9,Red,87
# 201,10,Red,83
# 202,11,Red,88
# 203,12,Red,85
# 204,13,Red,83
# 205,14,Red,83
# 206,1,Green,85
# 207,2,Green,71
# 208,3,Green,73
# 209,4,Green,73
# 210,5,Green,73
# 211,6,Green,76
# 212,7,Green,72
# 213,8,Green,72
# 214,9,Green,73
# 215,10,Green,71
# 216,11,Green,71
# 217,12,Green,72
# 218,13,Green,76
# 219,14,Green,72
# 220,15,Green,71
# 221,1,Blue,72
# 222,2,Blue,47
# 223,3,Blue,42
# 224,4,Blue,45
# 225,5,Blue,44
# 226,6,Blue,46
# 227,7,Blue,46
# 228,8,Blue,44
# 229,9,Blue,47
# 230,10,Blue,45
# 231,11,Blue,43
# 232,12,Blue,44
# 233,13,Blue,47
# 234,14,Blue,45
# 235,15,Blue,43
# 236,1,Black,47
# 237,2,Black,4
# 238,3,Black,4
# 239,4,Black,4
# 240,5,Black,4
# 241,6,Black,4
# 242,7,Black,3
# 243,8,Black,4
# 244,9,Black,4
# 245,10,Black,4
# 246,11,Black,4
# 247,12,Black,3
# 248,13,Black,4
# 249,14,Black,5
# 250,0,Black,4
# 251,0,Black,4
# 252,0,Black,4
# 253,0,Black,4
# 254,0,Black,5
# 255,0,Black,3
# 256,0,Black,4
# 257,0,Black,4
# 258,0,Black,4
# 259,0,Black,4
# 260,0,Black,4
# 261,0,Black,3
# 262,0,Black,4
# 263,0,Black,3
# 264,0,Black,3
# 265,1,White,4
# 266,2,White,188
# 267,3,White,193
# 268,4,White,187
# 269,5,White,185
# 270,6,White,185
# 271,7,White,191
# 272,8,White,193
# 273,9,White,185
# 274,10,White,188
# 275,11,White,190
# 276,12,White,187
# 277,13,White,187
# 278,14,White,189
# 279,15,White,186
# 280,1,Red,186
# 281,2,Red,84
# 282,3,Red,83
# 283,4,Red,79
# 284,5,Red,81
# 285,6,Red,81
# 286,7,Red,84
# 287,8,Red,82
# 288,9,Red,85
# 289,10,Red,79
# 290,11,Red,83
# 291,12,Red,84
# 292,13,Red,81
# 293,14,Red,82
# 294,1,Green,82
# 295,2,Green,72
# 296,3,Green,73
# 297,4,Green,69
# 298,5,Green,71
# 299,6,Green,74
# 300,7,Green,74
# 301,8,Green,72
# 302,9,Green,71
# 303,10,Green,71
# 304,11,Green,70
# 305,12,Green,73
# 306,13,Green,69
# 307,14,Green,70
# 308,15,Green,69
# 309,1,Blue,72
# 310,2,Blue,42
# 311,3,Blue,41
# 312,4,Blue,42
# 313,5,Blue,42
# 314,6,Blue,39
# 315,7,Blue,42
# 316,8,Blue,43
# 317,9,Blue,42
# 318,10,Blue,42
# 319,11,Blue,42
# 320,12,Blue,44
# 321,13,Blue,41
# 322,14,Blue,41
# 323,15,Blue,43
# 324,1,Black,40
# 325,2,Black,4
# 326,3,Black,5
# 327,4,Black,4
# 328,5,Black,4
# 329,6,Black,3
# 330,7,Black,5
# 331,8,Black,3
# 332,9,Black,4
# 333,10,Black,4
# 334,11,Black,3
# 335,12,Black,3
# 336,13,Black,3
# 337,14,Black,4
# 338,0,Black,4
# 339,0,Black,5
# 340,0,Black,5
# 341,0,Black,3
# 342,0,Black,4
# 343,0,Black,3
# 344,0,Black,3
# 345,0,Black,4
# 346,0,Black,5
# 347,0,Black,3
# 348,0,Black,4
# 349,0,Black,4
# 350,0,Black,4
# 351,0,Black,3
# 352,0,Black,4
# 353,1,White,3
# 354,2,White,180
# 355,3,White,182
# 356,4,White,182
# 357,5,White,186
# 358,6,White,187
# 359,7,White,181
# 360,8,White,181
# 361,9,White,182
# 362,10,White,181
# 363,11,White,181
# 364,12,White,183
# 365,13,White,181
# 366,14,White,183
# 367,15,White,180
# 368,1,Red,181
# 369,2,Red,82
# 370,3,Red,81
# 371,4,Red,78
# 372,5,Red,84
# 373,6,Red,77
# 374,7,Red,77
# 375,8,Red,79
# 376,9,Red,80
# 377,10,Red,77
# 378,11,Red,81
# 379,12,Red,84
# 380,13,Red,78
# 381,14,Red,78
# 382,15,Red,77
# 383,1,Green,82
# 384,2,Green,69
# 385,3,Green,71
# 386,4,Green,71
# 387,5,Green,72
# 388,6,Green,67
# 389,7,Green,69
# 390,8,Green,74
# 391,9,Green,70
# 392,10,Green,74
# 393,11,Green,68
# 394,12,Green,68
# 395,13,Green,71
# 396,14,Green,73
# 397,1,Blue,69
# 398,2,Blue,41
# 399,3,Blue,39
# 400,4,Blue,39
# 401,5,Blue,43
# 402,6,Blue,42
# 403,7,Blue,42
# 404,8,Blue,39
# 405,9,Blue,39
# 406,10,Blue,43
# 407,11,Blue,40
# 408,12,Blue,41
# 409,13,Blue,42
# 410,14,Blue,41
# 411,15,Blue,40
# 412,1,Black,42
# 413,2,Black,4
# 414,3,Black,4
# 415,4,Black,4
# 416,5,Black,4
# 417,6,Black,4
# 418,7,Black,3
# 419,8,Black,4
# 420,9,Black,3
# 421,10,Black,4
# 422,11,Black,4
# 423,12,Black,4
# 424,13,Black,4
# 425,14,Black,4
# 426,15,Black,4
# 427,0,Black,3
# 428,0,Black,4
# 429,0,Black,3
# 430,0,Black,3
# 431,0,Black,3
# 432,0,Black,3
# 433,0,Black,5
# 434,0,Black,4
# 435,0,Black,5
# 436,0,Black,3
# 437,0,Black,4
# 438,0,Black,4
# 439,0,Black,4
# 440,0,Black,3
# 441,1,White,3
# 442,2,White,181
# 443,3,White,179
# 444,4,White,180
# 445,5,White,179
# 446,6,White,179
# 447,7,White,182
# 448,8,White,184
# 449,9,White,177
# 450,10,White,177
# 451,11,White,180
# 452,12,White,181
# 453,13,White,181
# 454,14,White,179
# 455,15,White,177
# 456,1,Red,180
# 457,2,Red,77
# 458,3,Red,78
# 459,4,Red,77
# 460,5,Red,75
# 461,6,Red,76
# 462,7,Red,80
# 463,8,Red,77
# 464,9,Red,80
# 465,10,Red,76
# 466,11,Red,76
# 467,12,Red,81
# 468,13,Red,82
# 469,14,Red,79
# 470,15,Red,79
# 471,1,Green,79
# 472,2,Green,70
# 473,3,Green,70
# 474,4,Green,69
# 475,5,Green,69
# 476,6,Green,68
# 477,7,Green,69
# 478,8,Green,68
# 479,9,Green,71
# 480,10,Green,67
# 481,11,Green,69
# 482,12,Green,68
# 483,13,Green,66
# 484,14,Green,67
# 485,1,Blue,71
# 486,2,Blue,42
# 487,3,Blue,38
# 488,4,Blue,37
# 489,5,Blue,37
# 490,6,Blue,38
# 491,7,Blue,38
# 492,8,Blue,42
# 493,9,Blue,37
# 494,10,Blue,38
# 495,11,Blue,39
# 496,12,Blue,37
# 497,13,Blue,39
# 498,14,Blue,37
# 499,15,Blue,37
# 500,1,Black,39
# 501,2,Black,4
# 502,3,Black,4
# 503,4,Black,4
# 504,5,Black,3
# 505,6,Black,4
# 506,7,Black,4
# 507,8,Black,4
# 508,9,Black,4
# 509,10,Black,3
# 510,11,Black,4
# 511,12,Black,3
# 512,13,Black,4
# 513,14,Black,4
# 514,15,Black,4
# 515,0,Black,4
# 516,0,Black,4
# 517,0,Black,4
# 518,0,Black,4
# 519,0,Black,3
# 520,0,Black,4
# 521,0,Black,4
# 522,0,Black,4
# 523,0,Black,4
# 524,0,Black,3
# 525,0,Black,4
# 526,0,Black,4
# 527,0,Black,4
# 528,0,Black,4
# 529,1,White,3
# 530,2,White,172
# 531,3,White,179
# 532,4,White,176
# 533,5,White,172
# 534,6,White,177
# 535,7,White,173
# 536,8,White,174
# 537,9,White,180
# 538,10,White,173
# 539,11,White,177
# 540,12,White,174
# 541,13,White,176
# 542,14,White,172
# 543,15,White,177
# 544,1,Red,172
# 545,2,Red,76
# 546,3,Red,77
# 547,4,Red,75
# 548,5,Red,75
# 549,6,Red,77
# 550,7,Red,76
# 551,8,Red,77
# 552,9,Red,75
# 553,10,Red,75
# 554,11,Red,75
# 555,12,Red,77
# 556,13,Red,75
# 557,14,Red,79
# 558,15,Red,77
# 559,1,Green,75
# 560,2,Green,66
# 561,3,Green,71
# 562,4,Green,67
# 563,5,Green,68
# 564,6,Green,68
# 565,7,Green,67
# 566,8,Green,72
# 567,9,Green,70
# 568,10,Green,66
# 569,11,Green,69
# 570,12,Green,68
# 571,13,Green,72
# 572,14,Green,67
# 573,15,Green,70
# 574,1,Blue,70
# 575,2,Blue,40
# 576,3,Blue,40
# 577,4,Blue,36
# 578,5,Blue,38
# 579,6,Blue,37
# 580,7,Blue,36
# 581,8,Blue,39
# 582,9,Blue,36
# 583,10,Blue,37
# 584,11,Blue,40
# 585,12,Blue,39
# 586,13,Blue,40
# 587,14,Blue,37
# 588,1,Black,36
# 589,2,Black,4
# 590,3,Black,4
# 591,4,Black,3
# 592,5,Black,4
# 593,6,Black,3
# 594,7,Black,4
# 595,8,Black,4
# 596,9,Black,3
# 597,10,Black,3
# 598,11,Black,4
# 599,12,Black,4
# 600,13,Black,4
# 601,14,Black,4
# 602,15,Black,3
# 603,0,Black,4
# 604,0,Black,4
# 605,0,Black,4
# 606,0,Black,4
# 607,0,Black,4
# 608,0,Black,5
# 609,0,Black,4
# 610,0,Black,4
# 611,0,Black,4
# 612,0,Black,4
# 613,0,Black,4
# 614,0,Black,4
# 615,0,Black,3
# 616,0,Black,4
# 617,0,Black,3
# 618,1,White,4
# 619,2,White,172
# 620,3,White,172
# 621,4,White,169
# 622,5,White,169
# 623,6,White,170
# 624,7,White,170
# 625,8,White,174
# 626,9,White,171
# 627,10,White,173
# 628,11,White,171
# 629,12,White,171
# 630,13,White,171
# 631,14,White,172
# 632,1,Red,168
# 633,2,Red,73
# 634,3,Red,74
# 635,4,Red,77
# 636,5,Red,78
# 637,6,Red,77
# 638,7,Red,78
# 639,8,Red,75
# 640,9,Red,75
# 641,10,Red,76
# 642,11,Red,78
# 643,12,Red,77
# 644,13,Red,73
# 645,14,Red,72
# 646,15,Red,78
# 647,1,Green,78
# 648,2,Green,68
# 649,3,Green,65
# 650,4,Green,70
# 651,5,Green,67
# 652,6,Green,67
# 653,7,Green,67
# 654,8,Green,65
# 655,9,Green,67
# 656,10,Green,69
# 657,11,Green,67
# 658,12,Green,67
# 659,13,Green,68
# 660,14,Green,66
# 661,15,Green,68
# 662,1,Blue,68
# 663,2,Blue,36
# 664,3,Blue,36
# 665,4,Blue,38
# 666,5,Blue,36
# 667,6,Blue,39
# 668,7,Blue,35
# 669,8,Blue,38
# 670,9,Blue,36
# 671,10,Blue,36
# 672,11,Blue,36
# 673,12,Blue,36
# 674,13,Blue,36
# 675,14,Blue,35
# 676,1,Black,36
# 677,2,Black,3
# 678,3,Black,4
# 679,4,Black,4
# 680,5,Black,4
# 681,6,Black,4
# 682,7,Black,4
# 683,8,Black,3
# 684,9,Black,5
# 685,10,Black,3
# 686,11,Black,5
# 687,12,Black,4
# 688,13,Black,4
# 689,14,Black,4
# 690,15,Black,5
# 691,0,Black,4
# 692,0,Black,4
# 693,0,Black,4
# 694,0,Black,4
# 695,0,Black,4
# 696,0,Black,3
# 697,0,Black,4
# 698,0,Black,4
# 699,0,Black,4
# 700,0,Black,4
# 701,0,Black,4
# 702,0,Black,4
# 703,0,Black,4
# 704,0,Black,4
# 705,0,Black,4
# 706,1,White,4
# 707,2,White,166
# 708,3,White,171
# 709,4,White,170
# 710,5,White,167
# 711,6,White,167
# 712,7,White,171
# 713,8,White,171
# 714,9,White,166
# 715,10,White,165
# 716,11,White,171
# 717,12,White,170
# 718,13,White,169
# 719,14,White,167
# 720,1,Red,170
# 721,2,Red,72
# 722,3,Red,73
# 723,4,Red,76
# 724,5,Red,77
# 725,6,Red,77
# 726,7,Red,72
# 727,8,Red,72
# 728,9,Red,72
# 729,10,Red,75
# 730,11,Red,76
# 731,12,Red,74
# 732,13,Red,71
# 733,14,Red,73
# 734,15,Red,74
# 735,1,Green,72
# 736,2,Green,66
# 737,3,Green,69
# 738,4,Green,65
# 739,5,Green,66
# 740,6,Green,69
# 741,7,Green,68
# 742,8,Green,68
# 743,9,Green,65
# 744,10,Green,62
# 745,11,Green,67
# 746,12,Green,67
# 747,13,Green,69
# 748,14,Green,65
# 749,15,Green,69
# 750,1,Blue,67
# 751,2,Blue,35
# 752,3,Blue,35
# 753,4,Blue,37
# 754,5,Blue,34
# 755,6,Blue,38
# 756,7,Blue,34
# 757,8,Blue,35
# 758,9,Blue,37
# 759,10,Blue,35
# 760,11,Blue,38
# 761,12,Blue,36
# 762,13,Blue,34
# 763,14,Blue,33
# 764,15,Blue,35
# 765,1,Black,36
# 766,2,Black,4
# 767,3,Black,4
# 768,4,Black,4
# 769,5,Black,4
# 770,6,Black,4
# 771,7,Black,3
# 772,8,Black,4
# 773,9,Black,3
# 774,10,Black,4
# 775,11,Black,4
# 776,12,Black,5
# 777,13,Black,4
# 778,14,Black,4
# 779,0,Black,4
# 780,0,Black,4
# 781,0,Black,4
# 782,0,Black,3
# 783,0,Black,4
# 784,0,Black,4
# 785,0,Black,4
# 786,0,Black,4
# 787,0,Black,4
# 788,0,Black,5
# 789,0,Black,4
# 790,0,Black,3
# 791,0,Black,4
# 792,0,Black,3
# 793,0,Black,4
# 794,1,White,5
# 795,2,White,168
# 796,3,White,166
# 797,4,White,164
# 798,5,White,168
# 799,6,White,166
# 800,7,White,162
# 801,8,White,167
# 802,9,White,163
# 803,10,White,166
# 804,11,White,165
# 805,12,White,162
# 806,13,White,165
# 807,14,White,162
# 808,15,White,162
# 809,1,Red,164
# 810,2,Red,75
# 811,3,Red,76
# 812,4,Red,71
# 813,5,Red,70
# 814,6,Red,71
# 815,7,Red,70
# 816,8,Red,73
# 817,9,Red,74
# 818,10,Red,70
# 819,11,Red,70
# 820,12,Red,73
# 821,13,Red,75
# 822,14,Red,71
# 823,1,Green,70
# 824,2,Green,67
# 825,3,Green,65
# 826,4,Green,69
# 827,5,Green,67
# 828,6,Green,69
# 829,7,Green,68
# 830,8,Green,65
# 831,9,Green,69
# 832,10,Green,63
# 833,11,Green,64
# 834,12,Green,63
# 835,13,Green,67
# 836,14,Green,66
# 837,15,Green,64
# 838,1,Blue,63
# 839,2,Blue,36
# 840,3,Blue,35
# 841,4,Blue,35
# 842,5,Blue,35
# 843,6,Blue,35
# 844,7,Blue,34
# 845,8,Blue,36
# 846,9,Blue,36
# 847,10,Blue,36
# 848,11,Blue,36
# 849,12,Blue,37
# 850,13,Blue,37
# 851,14,Blue,35
# 852,15,Blue,35
# 853,1,Black,34
# 854,2,Black,4
# 855,3,Black,4
# 856,4,Black,5
# 857,5,Black,4
# 858,6,Black,4
# 859,7,Black,5
# 860,8,Black,5
# 861,9,Black,4
# 862,10,Black,4
# 863,11,Black,4
# 864,12,Black,4
# 865,13,Black,4
# 866,14,Black,5
# 867,0,Black,4
# 868,0,Black,4
# 869,0,Black,4
# 870,0,Black,4
# 871,0,Black,4
# 872,0,Black,4
# 873,0,Black,3
# 874,0,Black,3
# 875,0,Black,4
# 876,0,Black,4
# 877,0,Black,4
# 878,0,Black,4
# 879,0,Black,4
# 880,0,Black,4
# 881,0,Black,4
# 882,1,White,4
# 883,2,White,168
# 884,3,White,165
# 885,4,White,163
# 886,5,White,167
# 887,6,White,163
# 888,7,White,164
# 889,8,White,163
# 890,9,White,162
# 891,10,White,159
# 892,11,White,161
# 893,12,White,155
# 894,13,White,159
# 895,14,White,164
# 896,15,White,161
# 897,1,Red,159
# 898,2,Red,71
# 899,3,Red,74
# 900,4,Red,70
# 901,5,Red,71
# 902,6,Red,69
# 903,7,Red,72
# 904,8,Red,69
# 905,9,Red,69
# 906,10,Red,74
# 907,11,Red,73
# 908,12,Red,72
# 909,13,Red,70
# 910,14,Red,70
# 911,1,Green,68
# 912,2,Green,65
# 913,3,Green,62
# 914,4,Green,64
# 915,5,Green,65
# 916,6,Green,63
# 917,7,Green,64
# 918,8,Green,66
# 919,9,Green,64
# 920,10,Green,66
# 921,11,Green,67
# 922,12,Green,64
# 923,13,Green,65
# 924,14,Green,65
# 925,15,Green,65
# 926,1,Blue,65
# 927,2,Blue,34
# 928,3,Blue,31
# 929,4,Blue,34
# 930,5,Blue,35
# 931,6,Blue,36
# 932,7,Blue,36
# 933,8,Blue,35
# 934,9,Blue,34
# 935,10,Blue,33
# 936,11,Blue,36
# 937,12,Blue,36
# 938,13,Blue,33
# 939,14,Blue,35
# 940,15,Blue,31
# 941,1,Black,36
# 942,2,Black,4
# 943,3,Black,4
# 944,4,Black,4
# 945,5,Black,4
# 946,6,Black,4
# 947,7,Black,4
# 948,8,Black,4
# 949,9,Black,5
# 950,10,Black,4
# 951,11,Black,3
# 952,12,Black,4
# 953,13,Black,4
# 954,14,Black,3
# 955,15,Black,4
# 956,0,Black,4
# 957,0,Black,4
# 958,0,Black,4
# 959,0,Black,4
# 960,0,Black,4
# 961,0,Black,4
# 962,0,Black,3
# 963,0,Black,4
# 964,0,Black,4
# 965,0,Black,4
# 966,0,Black,4
# 967,0,Black,3
# 968,0,Black,4
# 969,0,Black,3
# 970,1,White,4
# 971,2,White,158
# 972,3,White,158
# 973,4,White,164
# 974,5,White,157
# 975,6,White,164
# 976,7,White,162
# 977,8,White,163
# 978,9,White,158
# 979,10,White,162
# 980,11,White,161
# 981,12,White,160
# 982,13,White,163
# 983,14,White,161
# 984,15,White,161
# 985,1,Red,164
# 986,2,Red,72
# 987,3,Red,69
# 988,4,Red,72
# 989,5,Red,71
# 990,6,Red,73
# 991,7,Red,68
# 992,8,Red,68
# 993,9,Red,68
# 994,10,Red,72
# 995,11,Red,73
# 996,12,Red,69
# 997,13,Red,69
# 998,14,Red,69
# 999,15,Red,72
# 1000,1,Green,70
# 1001,2,Green,65
# 1002,3,Green,65
# 1003,4,Green,64
# 1004,5,Green,63
# 1005,6,Green,63
# 1006,7,Green,62
# 1007,8,Green,61
# 1008,9,Green,63
# 1009,10,Green,65
# 1010,11,Green,65
# 1011,12,Green,68
# 1012,13,Green,68
# 1013,14,Green,68
# 1014,1,Blue,66
# 1015,2,Blue,33
# 1016,3,Blue,35
# 1017,4,Blue,36
# 1018,5,Blue,34
# 1019,6,Blue,31
# 1020,7,Blue,32
# 1021,8,Blue,34
# 1022,9,Blue,32
# 1023,10,Blue,33
# 1024,11,Blue,36
# 1025,12,Blue,36
# 1026,13,Blue,36
# 1027,14,Blue,36
# 1028,15,Blue,32
# 1029,1,Black,31
# 1030,2,Black,4
# 1031,3,Black,4
# 1032,4,Black,4
# 1033,5,Black,4
# 1034,6,Black,4
# 1035,7,Black,4
# 1036,8,Black,3
# 1037,9,Black,4
# 1038,10,Black,4
# 1039,11,Black,4
# 1040,12,Black,3
# 1041,13,Black,4
# 1042,14,Black,3
# 1043,15,Black,4
# 1044,0,Black,3
# 1045,0,Black,3
# 1046,0,Black,3
# 1047,0,Black,5
# 1048,0,Black,4
# 1049,0,Black,3
# 1050,0,Black,4
# 1051,0,Black,5
# 1052,0,Black,3
# 1053,0,Black,4
# 1054,0,Black,3
# 1055,0,Black,4
# 1056,0,Black,4
# 1057,0,Black,4
# 1058,1,White,4
# 1059,2,White,157
# 1060,3,White,157
# 1061,4,White,161
# 1062,5,White,157
# 1063,6,White,155
# 1064,7,White,162
# 1065,8,White,158
# 1066,9,White,156
# 1067,10,White,156
# 1068,11,White,155
# 1069,12,White,161
# 1070,13,White,156
# 1071,14,White,156
# 1072,15,White,157
# 1073,1,Red,154
# 1074,2,Red,67
# 1075,3,Red,68
# 1076,4,Red,67
# 1077,5,Red,67
# 1078,6,Red,71
# 1079,7,Red,68
# 1080,8,Red,67
# 1081,9,Red,73
# 1082,10,Red,68
# 1083,11,Red,69
# 1084,12,Red,67
# 1085,13,Red,70
# 1086,14,Red,67
# 1087,15,Red,70
# 1088,1,Green,68
# 1089,2,Green,64
# 1090,3,Green,65
# 1091,4,Green,61
# 1092,5,Green,67
# 1093,6,Green,62
# 1094,7,Green,63
# 1095,8,Green,63
# 1096,9,Green,64
# 1097,10,Green,66
# 1098,11,Green,61
# 1099,12,Green,65
# 1100,13,Green,61
# 1101,14,Green,67
# 1102,1,Blue,61
# 1103,2,Blue,32
# 1104,3,Blue,32
# 1105,4,Blue,33
# 1106,5,Blue,35
# 1107,6,Blue,32
# 1108,7,Blue,34
# 1109,8,Blue,34
# 1110,9,Blue,35
# 1111,10,Blue,32
# 1112,11,Blue,35
# 1113,12,Blue,35
# 1114,13,Blue,32
# 1115,14,Blue,35
# 1116,15,Blue,32
# 1117,1,Black,35
# 1118,2,Black,4
# 1119,3,Black,4
# 1120,4,Black,4
# 1121,5,Black,3
# 1122,6,Black,4
# 1123,7,Black,4
# 1124,8,Black,4
# 1125,9,Black,4
# 1126,10,Black,3
# 1127,11,Black,5
# 1128,12,Black,4
# 1129,13,Black,3
# 1130,14,Black,4
# 1131,15,Black,4
# 1132,0,Black,4
# 1133,0,Black,3
# 1134,0,Black,3
# 1135,0,Black,4
# 1136,0,Black,4
# 1137,0,Black,4
# 1138,0,Black,4
# 1139,0,Black,3
# 1140,0,Black,3
# 1141,0,Black,4
# 1142,0,Black,5
# 1143,0,Black,3
# 1144,0,Black,4
# 1145,0,Black,3
# 1146,0,Black,3
# 1147,1,White,4
# 1148,2,White,155
# 1149,3,White,155
# 1150,4,White,160
# 1151,5,White,157
# 1152,6,White,153
# 1153,7,White,158
# 1154,8,White,157
# 1155,9,White,157
# 1156,10,White,160
# 1157,11,White,160
# 1158,12,White,153
# 1159,13,White,155
# 1160,14,White,155
# 1161,1,Red,158
# 1162,2,Red,72
# 1163,3,Red,66
# 1164,4,Red,67
# 1165,5,Red,67
# 1166,6,Red,66
# 1167,7,Red,67
# 1168,8,Red,69
# 1169,9,Red,67
# 1170,10,Red,71
# 1171,11,Red,70
# 1172,12,Red,71
# 1173,13,Red,71
# 1174,14,Red,70
# 1175,15,Red,67
# 1176,1,Green,66
# 1177,2,Green,60
# 1178,3,Green,65
# 1179,4,Green,61
# 1180,5,Green,61
# 1181,6,Green,64
# 1182,7,Green,62
# 1183,8,Green,62
# 1184,9,Green,64
# 1185,10,Green,64
# 1186,11,Green,66
# 1187,12,Green,64
# 1188,13,Green,64
# 1189,14,Green,63
# 1190,15,Green,66
# 1191,1,Blue,65
# 1192,2,Blue,33
# 1193,3,Blue,31
# 1194,4,Blue,32
# 1195,5,Blue,33
# 1196,6,Blue,32
# 1197,7,Blue,32
# 1198,8,Blue,32
# 1199,9,Blue,35
# 1200,10,Blue,31
# 1201,11,Blue,32
# 1202,12,Blue,32
# 1203,13,Blue,32
# 1204,14,Blue,32
# 1205,1,Black,35
# 1206,2,Black,4
# 1207,3,Black,4
# 1208,4,Black,5
# 1209,5,Black,3
# 1210,6,Black,4
# 1211,7,Black,4
# 1212,8,Black,4
# 1213,9,Black,4
# 1214,10,Black,4
# 1215,11,Black,4
# 1216,12,Black,4
# 1217,13,Black,4
# 1218,14,Black,4
# 1219,15,Black,4
# 1220,0,Black,4
# 1221,0,Black,4
# 1222,0,Black,4
# 1223,0,Black,5
# 1224,0,Black,4
# 1225,0,Black,4
# 1226,0,Black,4
# 1227,0,Black,3
# 1228,0,Black,3
# 1229,0,Black,3
# 1230,0,Black,5
# 1231,0,Black,4
# 1232,0,Black,4
# 1233,0,Black,4
# 1234,0,Black,4
# 1235,1,White,3
# 1236,2,White,153
# 1237,3,White,151
# 1238,4,White,156
# 1239,5,White,156
# 1240,6,White,152
# 1241,7,White,155
# 1242,8,White,155
# 1243,9,White,159
# 1244,10,White,153
# 1245,11,White,155
# 1246,12,White,152
# 1247,13,White,156
# 1248,14,White,152
# 1249,1,Red,157
# 1250,2,Red,69
# 1251,3,Red,70
# 1252,4,Red,68
# 1253,5,Red,69
# 1254,6,Red,69
# 1255,7,Red,69
# 1256,8,Red,68
# 1257,9,Red,65
# 1258,10,Red,68
# 1259,11,Red,66
# 1260,12,Red,68
# 1261,13,Red,67
# 1262,14,Red,66
# 1263,15,Red,65
# 1264,1,Green,65
# 1265,2,Green,62
# 1266,3,Green,59
# 1267,4,Green,62
# 1268,5,Green,62
# 1269,6,Green,61
# 1270,7,Green,61
# 1271,8,Green,62
# 1272,9,Green,60
# 1273,10,Green,64
# 1274,11,Green,62
# 1275,12,Green,64
# 1276,13,Green,64
# 1277,14,Green,63
# 1278,15,Green,61
# 1279,1,Blue,65
# 1280,2,Blue,34
# 1281,3,Blue,29
# 1282,4,Blue,32
# 1283,5,Blue,30
# 1284,6,Blue,32
# 1285,7,Blue,32
# 1286,8,Blue,32
# 1287,9,Blue,34
# 1288,10,Blue,34
# 1289,11,Blue,33
# 1290,12,Blue,32
# 1291,13,Blue,30
# 1292,14,Blue,34
# 1293,1,Black,31
# 1294,2,Black,4
# 1295,3,Black,3
# 1296,4,Black,4
# 1297,5,Black,4
# 1298,6,Black,4
# 1299,7,Black,4
# 1300,8,Black,4
# 1301,9,Black,4
# 1302,10,Black,3
# 1303,11,Black,4
# 1304,12,Black,4
# 1305,13,Black,4
# 1306,14,Black,4
# 1307,15,Black,4
# 1308,0,Black,4
# 1309,0,Black,4
# 1310,0,Black,4
# 1311,0,Black,3
# 1312,0,Black,4
# 1313,0,Black,3
# 1314,0,Black,3
# 1315,0,Black,3
# 1316,0,Black,5
# 1317,0,Black,5
# 1318,0,Black,4
# 1319,0,Black,4
# 1320,0,Black,4
# 1321,0,Black,4
# 1322,0,Black,4
# 1323,1,White,4
# 1324,2,White,150
# 1325,3,White,157
# 1326,4,White,153
# 1327,5,White,151
# 1328,6,White,151
# 1329,7,White,157
# 1330,8,White,155
# 1331,9,White,155
# 1332,10,White,153
# 1333,11,White,155
# 1334,12,White,151
# 1335,13,White,153
# 1336,14,White,150
# 1337,1,Red,152
# 1338,2,Red,63
# 1339,3,Red,64
# ...
# 799,6,White,820
# 800,7,White,814
# 801,8,White,820
# 802,9,White,826
# 803,10,White,821
# 804,11,White,822
# 805,12,White,822
# 806,13,White,821
# 807,14,White,821
# 808,1,Red,822
# 809,2,Red,341
# 810,3,Red,341
# 811,4,Red,344
# 812,5,Red,340
# 813,6,Red,344
# 814,7,Red,334
# 815,8,Red,336
# 816,9,Red,340
# 817,10,Red,339
# 818,11,Red,339
# 819,12,Red,343
# 820,13,Red,339
# 821,14,Red,341
# 822,15,Red,336
# 823,1,Green,339
# 824,2,Green,196
# 825,3,Green,204
# 826,4,Green,196
# 827,5,Green,198
# 828,6,Green,202
# 829,7,Green,196
# 830,8,Green,195
# 831,9,Green,197
# 832,10,Green,196
# 833,11,Green,197
# 834,12,Green,200
# 835,13,Green,196
# 836,14,Green,203
# 837,15,Green,196
# 838,1,Blue,197
# 839,2,Blue,328
# 840,3,Blue,332
# 841,4,Blue,330
# 842,5,Blue,336
# 843,6,Blue,336
# 844,7,Blue,336
# 845,8,Blue,340
# 846,9,Blue,335
# 847,10,Blue,325
# 848,11,Blue,336
# 849,12,Blue,334
# 850,13,Blue,338
# 851,14,Blue,331
# 852,1,Black,332
# 853,2,Black,7
# 854,3,Black,6
# 855,4,Black,5
# 856,5,Black,6
# 857,6,Black,5
# 858,7,Black,6
# 859,8,Black,9
# 860,9,Black,7
# 861,10,Black,7
# 862,11,Black,8
# 863,12,Black,7
# 864,13,Black,6
# 865,14,Black,5
# 866,15,Black,7
# 867,0,Black,7
# 868,0,Black,6
# 869,0,Black,7
# 870,0,Black,8
# 871,0,Black,6
# 872,0,Black,7
# 873,0,Black,5
# 874,0,Black,8
# 875,0,Black,6
# 876,0,Black,5
# 877,0,Black,7
# 878,0,Black,8
# 879,0,Black,7
# 880,0,Black,6
# 881,0,Black,7
# 882,1,White,7
# 883,2,White,819
# 884,3,White,821
# 885,4,White,822
# 886,5,White,826
# 887,6,White,825
# 888,7,White,817
# 889,8,White,824
# 890,9,White,826
# 891,10,White,815
# 892,11,White,817
# 893,12,White,820
# 894,13,White,820
# 895,14,White,826
# 896,1,Red,821
# 897,2,Red,341
# 898,3,Red,336
# 899,4,Red,338
# 900,5,Red,338
# 901,6,Red,342
# 902,7,Red,347
# 903,8,Red,340
# 904,9,Red,342
# 905,10,Red,344
# 906,11,Red,340
# 907,12,Red,341
# 908,13,Red,341
# 909,14,Red,341
# 910,15,Red,339
# 911,1,Green,341
# 912,2,Green,197
# 913,3,Green,199
# 914,4,Green,200
# 915,5,Green,194
# 916,6,Green,202
# 917,7,Green,191
# 918,8,Green,198
# 919,9,Green,195
# 920,10,Green,198
# 921,11,Green,197
# 922,12,Green,201
# 923,13,Green,194
# 924,14,Green,197
# 925,15,Green,201
# 926,1,Blue,195
# 927,2,Blue,335
# 928,3,Blue,323
# 929,4,Blue,337
# 930,5,Blue,334
# 931,6,Blue,327
# 932,7,Blue,333
# 933,8,Blue,334
# 934,9,Blue,332
# 935,10,Blue,336
# 936,11,Blue,331
# 937,12,Blue,330
# 938,13,Blue,333
# 939,14,Blue,331
# 940,1,Black,333
# 941,2,Black,7
# 942,3,Black,7
# 943,4,Black,5
# 944,5,Black,5
# 945,6,Black,7
# 946,7,Black,7
# 947,8,Black,6
# 948,9,Black,5
# 949,10,Black,5
# 950,11,Black,5
# 951,12,Black,6
# 952,13,Black,5
# 953,14,Black,5
# 954,15,Black,5
# 955,0,Black,7
# 956,0,Black,8
# 957,0,Black,6
# 958,0,Black,6
# 959,0,Black,7
# 960,0,Black,6
# 961,0,Black,6
# 962,0,Black,5
# 963,0,Black,8
# 964,0,Black,6
# 965,0,Black,6
# 966,0,Black,5
# 967,0,Black,5
# 968,0,Black,5
# 969,0,Black,6
# 970,1,White,6
# 971,2,White,818
# 972,3,White,814
# 973,4,White,822
# 974,5,White,821
# 975,6,White,825
# 976,7,White,820
# 977,8,White,823
# 978,9,White,820
# 979,10,White,820
# 980,11,White,825
# 981,12,White,820
# 982,13,White,827
# 983,14,White,827
# 984,15,White,812
# 985,1,Red,822
# 986,2,Red,337
# 987,3,Red,340
# 988,4,Red,343
# 989,5,Red,341
# 990,6,Red,336
# 991,7,Red,339
# 992,8,Red,341
# 993,9,Red,338
# 994,10,Red,341
# 995,11,Red,339
# 996,12,Red,346
# 997,13,Red,345
# 998,14,Red,341
# 999,1,Green,344
# 1000,2,Green,197
# 1001,3,Green,200
# 1002,4,Green,196
# 1003,5,Green,197
# 1004,6,Green,197
# 1005,7,Green,195
# 1006,8,Green,198
# 1007,9,Green,196
# 1008,10,Green,201
# 1009,11,Green,197
# 1010,12,Green,198
# 1011,13,Green,204
# 1012,14,Green,200
# 1013,15,Green,201
# 1014,1,Blue,200
# 1015,2,Blue,328
# 1016,3,Blue,332
# 1017,4,Blue,332
# 1018,5,Blue,334
# 1019,6,Blue,333
# 1020,7,Blue,338
# 1021,8,Blue,333
# 1022,9,Blue,331
# 1023,10,Blue,336
# 1024,11,Blue,330
# 1025,12,Blue,337
# 1026,13,Blue,332
# 1027,14,Blue,330
# 1028,15,Blue,334
# 1029,1,Black,331
# 1030,2,Black,7
# 1031,3,Black,7
# 1032,4,Black,6
# 1033,5,Black,5
# 1034,6,Black,6
# 1035,7,Black,6
# 1036,8,Black,6
# 1037,9,Black,6
# 1038,10,Black,7
# 1039,11,Black,7
# 1040,12,Black,7
# 1041,13,Black,7
# 1042,14,Black,6
# 1043,0,Black,5
# 1044,0,Black,5
# 1045,0,Black,7
# 1046,0,Black,6
# 1047,0,Black,6
# 1048,0,Black,7
# 1049,0,Black,6
# 1050,0,Black,6
# 1051,0,Black,6
# 1052,0,Black,7
# 1053,0,Black,5
# 1054,0,Black,6
# 1055,0,Black,6
# 1056,0,Black,6
# 1057,0,Black,5
# 1058,1,White,7
# 1059,2,White,824
# 1060,3,White,819
# 1061,4,White,819
# 1062,5,White,822
# 1063,6,White,821
# 1064,7,White,824
# 1065,8,White,820
# 1066,9,White,819
# 1067,10,White,820
# 1068,11,White,817
# 1069,12,White,824
# 1070,13,White,826
# 1071,14,White,825
# 1072,15,White,824
# 1073,1,Red,812
# 1074,2,Red,337
# 1075,3,Red,339
# 1076,4,Red,339
# 1077,5,Red,339
# 1078,6,Red,340
# 1079,7,Red,344
# 1080,8,Red,336
# 1081,9,Red,341
# 1082,10,Red,338
# 1083,11,Red,338
# 1084,12,Red,343
# 1085,13,Red,342
# 1086,14,Red,342
# 1087,1,Green,339
# 1088,2,Green,201
# 1089,3,Green,200
# 1090,4,Green,196
# 1091,5,Green,201
# 1092,6,Green,202
# 1093,7,Green,202
# 1094,8,Green,199
# 1095,9,Green,197
# 1096,10,Green,194
# 1097,11,Green,195
# 1098,12,Green,195
# 1099,13,Green,197
# 1100,14,Green,201
# 1101,15,Green,197
# 1102,1,Blue,202
# 1103,2,Blue,323
# 1104,3,Blue,336
# 1105,4,Blue,328
# 1106,5,Blue,331
# 1107,6,Blue,328
# 1108,7,Blue,327
# 1109,8,Blue,333
# 1110,9,Blue,331
# 1111,10,Blue,333
# 1112,11,Blue,328
# 1113,12,Blue,329
# 1114,13,Blue,329
# 1115,14,Blue,335
# 1116,15,Blue,330
# 1117,1,Black,330
# 1118,2,Black,7
# 1119,3,Black,5
# 1120,4,Black,5
# 1121,5,Black,7
# 1122,6,Black,7
# 1123,7,Black,6
# 1124,8,Black,6
# 1125,9,Black,7
# 1126,10,Black,6
# 1127,11,Black,5
# 1128,12,Black,6
# 1129,13,Black,5
# 1130,14,Black,6
# 1131,0,Black,7
# 1132,0,Black,6
# 1133,0,Black,6
# 1134,0,Black,5
# 1135,0,Black,7
# 1136,0,Black,5
# 1137,0,Black,5
# 1138,0,Black,6
# 1139,0,Black,6
# 1140,0,Black,6
# 1141,0,Black,6
# 1142,0,Black,8
# 1143,0,Black,6
# 1144,0,Black,5
# 1145,0,Black,6
# 1146,1,White,6
# 1147,2,White,818
# 1148,3,White,821
# 1149,4,White,824
# 1150,5,White,826
# 1151,6,White,814
# 1152,7,White,821
# 1153,8,White,824
# 1154,9,White,814
# 1155,10,White,824
# 1156,11,White,824
# 1157,12,White,820
# 1158,13,White,816
# 1159,14,White,819
# 1160,15,White,826
# 1161,1,Red,821
# 1162,2,Red,334
# 1163,3,Red,337
# 1164,4,Red,343
# 1165,5,Red,336
# 1166,6,Red,339
# 1167,7,Red,338
# 1168,8,Red,337
# 1169,9,Red,344
# 1170,10,Red,338
# 1171,11,Red,338
# 1172,12,Red,342
# 1173,13,Red,339
# 1174,14,Red,340
# 1175,15,Red,337
# 1176,1,Green,343
# 1177,2,Green,200
# 1178,3,Green,196
# 1179,4,Green,193
# 1180,5,Green,196
# 1181,6,Green,197
# 1182,7,Green,198
# 1183,8,Green,194
# 1184,9,Green,202
# 1185,10,Green,196
# 1186,11,Green,200
# 1187,12,Green,195
# 1188,13,Green,197
# 1189,14,Green,202
# 1190,1,Blue,198
# 1191,2,Blue,330
# 1192,3,Blue,334
# 1193,4,Blue,334
# 1194,5,Blue,325
# 1195,6,Blue,336
# 1196,7,Blue,331
# 1197,8,Blue,330
# 1198,9,Blue,330
# 1199,10,Blue,332
# 1200,11,Blue,331
# 1201,12,Blue,335
# 1202,13,Blue,328
# 1203,14,Blue,329
# 1204,15,Blue,334
# 1205,1,Black,333
# 1206,2,Black,5
# 1207,3,Black,5
# 1208,4,Black,7
# 1209,5,Black,6
# 1210,6,Black,7
# 1211,7,Black,5
# 1212,8,Black,7
# 1213,9,Black,6
# 1214,10,Black,6
# 1215,11,Black,5
# 1216,12,Black,6
# 1217,13,Black,5
# 1218,14,Black,5
# 1219,15,Black,6
# 1220,0,Black,7
# 1221,0,Black,7
# 1222,0,Black,6
# 1223,0,Black,4
# 1224,0,Black,8
# 1225,0,Black,5
# 1226,0,Black,6
# 1227,0,Black,5
# 1228,0,Black,5
# 1229,0,Black,5
# 1230,0,Black,5
# 1231,0,Black,5
# 1232,0,Black,6
# 1233,0,Black,8
# 1234,1,White,6
# 1235,2,White,815
# 1236,3,White,822
# 1237,4,White,825
# 1238,5,White,814
# 1239,6,White,822
# 1240,7,White,826
# 1241,8,White,813
# 1242,9,White,820
# 1243,10,White,825
# 1244,11,White,814
# 1245,12,White,820
# 1246,13,White,826
# 1247,14,White,822
# 1248,15,White,820
# 1249,1,Red,819
# 1250,2,Red,339
# 1251,3,Red,339
# 1252,4,Red,340
# 1253,5,Red,340
# 1254,6,Red,341
# 1255,7,Red,341
# 1256,8,Red,335
# 1257,9,Red,340
# 1258,10,Red,342
# 1259,11,Red,339
# 1260,12,Red,336
# 1261,13,Red,341
# 1262,14,Red,342
# 1263,15,Red,338
# 1264,1,Green,336
# 1265,2,Green,198
# 1266,3,Green,192
# 1267,4,Green,197
# 1268,5,Green,200
# 1269,6,Green,195
# 1270,7,Green,197
# 1271,8,Green,202
# 1272,9,Green,199
# 1273,10,Green,201
# 1274,11,Green,200
# 1275,12,Green,193
# 1276,13,Green,196
# 1277,14,Green,194
# 1278,1,Blue,195
# 1279,2,Blue,332
# 1280,3,Blue,328
# 1281,4,Blue,333
# 1282,5,Blue,331
# 1283,6,Blue,331
# 1284,7,Blue,326
# 1285,8,Blue,336
# 1286,9,Blue,331
# 1287,10,Blue,328
# 1288,11,Blue,328
# 1289,12,Blue,330
# 1290,13,Blue,333
# 1291,14,Blue,331
# 1292,15,Blue,329
# 1293,1,Black,334
# 1294,2,Black,5
# 1295,3,Black,5
# 1296,4,Black,5
# 1297,5,Black,6
# 1298,6,Black,7
# 1299,7,Black,7
# 1300,8,Black,7
# 1301,9,Black,6
# 1302,10,Black,6
# 1303,11,Black,6
# 1304,12,Black,5
# 1305,13,Black,5
# 1306,14,Black,6
# 1307,15,Black,5
# 1308,0,Black,5
# 1309,0,Black,5
# 1310,0,Black,6
# 1311,0,Black,7
# 1312,0,Black,6
# 1313,0,Black,6
# 1314,0,Black,6
# 1315,0,Black,6
# 1316,0,Black,5
# 1317,0,Black,6
# 1318,0,Black,8
# 1319,0,Black,6
# 1320,0,Black,5
# 1321,0,Black,5
# 1322,1,White,6
# 1323,2,White,816
# 1324,3,White,820
# 1325,4,White,822
# 1326,5,White,815
# 1327,6,White,823
# 1328,7,White,818
# 1329,8,White,823
# 1330,9,White,821
# 1331,10,White,820
# 1332,11,White,814
# 1333,12,White,823
# 1334,13,White,818
# 1335,14,White,820
# 1336,15,White,815
# 1337,1,Red,819
# 1338,2,Red,337
# 1339,3,Red,336
# 1340,4,Red,334
# 1341,5,Red,339
# 1342,6,Red,336
# 1343,7,Red,337
# 1344,8,Red,340
# 1345,9,Red,338
# 1346,10,Red,344
# 1347,11,Red,341
# 1348,12,Red,339
# 1349,13,Red,345
# 1350,14,Red,338
# 1351,15,Red,338
# 1352,1,Green,337
# 1353,2,Green,197
# 1354,3,Green,196
# 1355,4,Green,200
# 1356,5,Green,195
# 1357,6,Green,197
# 1358,7,Green,196
# 1359,8,Green,198
# 1360,9,Green,198
# 1361,10,Green,193
# 1362,11,Green,196
# 1363,12,Green,201
# 1364,13,Green,197
# 1365,14,Green,198
# 1366,1,Blue,202
# 1367,2,Blue,333
# 1368,3,Blue,330
# 1369,4,Blue,330
# 1370,5,Blue,333
# 1371,6,Blue,329
# 1372,7,Blue,332
# 1373,8,Blue,330
# 1374,9,Blue,333
# 1375,10,Blue,331
# 1376,11,Blue,329
# 1377,12,Blue,330
# 1378,13,Blue,331
# 1379,14,Blue,330
# 1380,15,Blue,335
# 1381,1,Black,332
# 1382,2,Black,6
# 1383,3,Black,7
# 1384,4,Black,6
# 1385,5,Black,6
# 1386,6,Black,5
# 1387,7,Black,5
# 1388,8,Black,5
# 1389,9,Black,5
# 1390,10,Black,4
# 1391,11,Black,5
# 1392,12,Black,6
# 1393,13,Black,7
# 1394,14,Black,6
# 1395,15,Black,6
# 1396,0,Black,6
# 1397,0,Black,5
# 1398,0,Black,5
# 1399,0,Black,5
# 1400,0,Black,5
# 1401,0,Black,4
# 1402,0,Black,5
# 1403,0,Black,6
# 1404,0,Black,7
# 1405,0,Black,6
# 1406,0,Black,7
# 1407,0,Black,7
# 1408,0,Black,7
# 1409,0,Black,5
# 1410,0,Black,4
# 1411,1,White,5
# 1412,2,White,817
# 1413,3,White,810
# 1414,4,White,822
# 1415,5,White,820
# 1416,6,White,823
# 1417,7,White,820
# 1418,8,White,821
# 1419,9,White,819
# 1420,10,White,825
# 1421,11,White,824
# 1422,12,White,820
# 1423,13,White,816
# 1424,14,White,820
# 1425,1,Red,818
# 1426,2,Red,341
# 1427,3,Red,345
# 1428,4,Red,336
# 1429,5,Red,332
# 1430,6,Red,339
# 1431,7,Red,335
# 1432,8,Red,337
# 1433,9,Red,338
# 1434,10,Red,342
# 1435,11,Red,338
# 1436,12,Red,339
# 1437,13,Red,343
# 1438,14,Red,341
# 1439,15,Red,341
# 1440,1,Green,332
# 1441,2,Green,196
# 1442,3,Green,197
# 1443,4,Green,195
# 1444,5,Green,198
# 1445,6,Green,197
# 1446,7,Green,193
# 1447,8,Green,198
# 1448,9,Green,201
# 1449,10,Green,193
# 1450,11,Green,202
# 1451,12,Green,196
# 1452,13,Green,200
# 1453,14,Green,194
# 1454,15,Green,197
# 1455,1,Blue,197
# 1456,2,Blue,327
# 1457,3,Blue,336
# 1458,4,Blue,337
# 1459,5,Blue,331
# 1460,6,Blue,328
# 1461,7,Blue,332
# 1462,8,Blue,331
# 1463,9,Blue,331
# 1464,10,Blue,336
# 1465,11,Blue,327
# 1466,12,Blue,334
# 1467,13,Blue,332
# 1468,14,Blue,327
# 1469,1,Black,326
# 1470,2,Black,5
# 1471,3,Black,4
# 1472,4,Black,6
# 1473,5,Black,6
# 1474,6,Black,6
# 1475,7,Black,6
# 1476,8,Black,5
# 1477,9,Black,6
# 1478,10,Black,5
# 1479,11,Black,7
# 1480,12,Black,8
# 1481,13,Black,5
# 1482,14,Black,5
# 1483,15,Black,6
# 1484,0,Black,5
# 1485,0,Black,5
# 1486,0,Black,6
# 1487,0,Black,8
# 1488,0,Black,5
# 1489,0,Black,7
# 1490,0,Black,7
# 1491,0,Black,5
# 1492,0,Black,4
# 1493,0,Black,5
# 1494,0,Black,6
# 1495,0,Black,4
# 1496,0,Black,5
# 1497,0,Black,6
# 1498,0,Black,7
# 1499,1,White,7
# 1500,2,White,822
# 1501,3,White,813
# 1502,4,White,823
# 1503,5,White,826
# 1504,6,White,819
# 1505,7,White,821
# 1506,8,White,819
# 1507,9,White,822
# 1508,10,White,812
# 1509,11,White,821
# 1510,12,White,823
# 1511,13,White,819
# 1512,14,White,829
# 1513,1,Red,827
# 1514,2,Red,342
# 1515,3,Red,336
# 1516,4,Red,339
# 1517,5,Red,344
# 1518,6,Red,341
# 1519,7,Red,342
# 1520,8,Red,339
# 1521,9,Red,343
# 1522,10,Red,337
# 1523,11,Red,334
# 1524,12,Red,345
# 1525,13,Red,341
# 1526,14,Red,336
# 1527,15,Red,336
# 1528,1,Green,342
# 1529,2,Green,200
# 1530,3,Green,195
# 1531,4,Green,201
# 1532,5,Green,197
# 1533,6,Green,195
# 1534,7,Green,197
# 1535,8,Green,196
# 1536,9,Green,203
# 1537,10,Green,201
# 1538,11,Green,198
# 1539,12,Green,194
# 1540,13,Green,196
# 1541,14,Green,195
# 1542,15,Green,195
# 1543,1,Blue,195
# 1544,2,Blue,329
# 1545,3,Blue,330
# 1546,4,Blue,336
# 1547,5,Blue,330
# 1548,6,Blue,329
# 1549,7,Blue,336
# 1550,8,Blue,332
# 1551,9,Blue,335
# 1552,10,Blue,330
# 1553,11,Blue,330
# 1554,12,Blue,334
# 1555,13,Blue,333
# 1556,14,Blue,325
# 1557,1,Black,331
# 1558,2,Black,5
# 1559,3,Black,7
# 1560,4,Black,4
# 1561,5,Black,4
# 1562,6,Black,5
# 1563,7,Black,6
# 1564,8,Black,7
# 1565,9,Black,6
# 1566,10,Black,5
# 1567,11,Black,6
# 1568,12,Black,7
# 1569,13,Black,7
# 1570,14,Black,5
# 1571,15,Black,5
# 1572,0,Black,6
# 1573,0,Black,6
# 1574,0,Black,6
# 1575,0,Black,4
# 1576,0,Black,6
# 1577,0,Black,5
# 1578,0,Black,5
# 1579,0,Black,5
# 1580,0,Black,6
# 1581,0,Black,7
# 1582,0,Black,8
# 1583,0,Black,7
# 1584,0,Black,7
# 1585,0,Black,7
# 1586,0,Black,8
# 1587,1,White,6
# 1588,2,White,818
# 1589,3,White,813
# 1590,4,White,822
# 1591,5,White,823
# 1592,6,White,816
# 1593,7,White,820
# 1594,8,White,818
# 1595,9,White,820
# 1596,10,White,820
# 1597,11,White,820
# 1598,12,White,820
# 1599,13,White,828
# 1600,14,White,821
# 1601,1,Red,821
# 1602,2,Red,334
# 1603,3,Red,341
# 1604,4,Red,340
# 1605,5,Red,338
# 1606,6,Red,344
# 1607,7,Red,342
# 1608,8,Red,342
# 1609,9,Red,340
# 1610,10,Red,338
# 1611,11,Red,342
# 1612,12,Red,339
# 1613,13,Red,334
# 1614,14,Red,339
# 1615,15,Red,342
# 1616,1,Green,341
# 1617,2,Green,200
# 1618,3,Green,202
# 1619,4,Green,197
# 1620,5,Green,195
# 1621,6,Green,202
# 1622,7,Green,192
# 1623,8,Green,201
# 1624,9,Green,200
# 1625,10,Green,195
# 1626,11,Green,202
# 1627,12,Green,196
# 1628,13,Green,197
# 1629,14,Green,194
# 1630,15,Green,199
# 1631,1,Blue,197
# 1632,2,Blue,336
# 1633,3,Blue,334
# 1634,4,Blue,333
# 1635,5,Blue,337
# 1636,6,Blue,329
# 1637,7,Blue,331
# 1638,8,Blue,334
# 1639,9,Blue,336
# 1640,10,Blue,333
# 1641,11,Blue,332
# 1642,12,Blue,332
# 1643,13,Blue,334
# 1644,14,Blue,334
# 1645,1,Black,329
# 1646,2,Black,7
# 1647,3,Black,6
# 1648,4,Black,7
# 1649,5,Black,6
# 1650,6,Black,5
# 1651,7,Black,5
# 1652,8,Black,7
# 1653,9,Black,6
# 1654,10,Black,6
# 1655,11,Black,6
# 1656,12,Black,6
# 1657,13,Black,5
# 1658,14,Black,6
# 1659,15,Black,7
# 1660,0,Black,6
# 1661,0,Black,7
# 1662,0,Black,6
# 1663,0,Black,5
# 1664,0,Black,5
# 1665,0,Black,7
# 1666,0,Black,5
# 1667,0,Black,7
# 1668,0,Black,7
# 1669,0,Black,6
# 1670,0,Black,5
# 1671,0,Black,6
# 1672,0,Black,5
# 1673,0,Black,6
# 1674,0,Black,8
# 1675,1,White,7
# 1676,2,White,825
# 1677,3,White,820
# 1678,4,White,820
# 1679,5,White,818
# 1680,6,White,821
# 1681,7,White,826
# 1682,8,White,823
# 1683,9,White,824
# 1684,10,White,818
# 1685,11,White,822
# 1686,12,White,821
# 1687,13,White,820
# 1688,14,White,829
# 1689,15,White,820
# 1690,1,Red,822
# 1691,2,Red,342
# 1692,3,Red,340
# 1693,4,Red,338
# 1694,5,Red,342
# 1695,6,Red,341
# 1696,7,Red,338
# 1697,8,Red,339
# 1698,9,Red,341
# 1699,10,Red,336
# 1700,11,Red,337
# 1701,12,Red,343
# 1702,13,Red,336
# 1703,14,Red,340
# 1704,1,Green,339
# 1705,2,Green,200
# 1706,3,Green,201
# 1707,4,Green,198
# 1708,5,Green,195
# 1709,6,Green,190
# 1710,7,Green,195
# 1711,8,Green,200
# 1712,9,Green,194
# 1713,10,Green,198
# 1714,11,Green,200
# 1715,12,Green,198
# 1716,13,Green,195
# 1717,14,Green,200
# 1718,15,Green,199
# 1719,1,Blue,196
# 1720,2,Blue,327
# 1721,3,Blue,328
# 1722,4,Blue,331
# 1723,5,Blue,326
# 1724,6,Blue,338
# 1725,7,Blue,329
# 1726,8,Blue,335
# 1727,9,Blue,334
# 1728,10,Blue,331
# 1729,11,Blue,333
# 1730,12,Blue,334
# 1731,13,Blue,331
# 1732,14,Blue,336
# 1733,15,Blue,330
# 1734,1,Black,329
# 1735,2,Black,4
# 1736,3,Black,5
# 1737,4,Black,5
# 1738,5,Black,5
# 1739,6,Black,7
# 1740,7,Black,7
# 1741,8,Black,5
# 1742,9,Black,4
# 1743,10,Black,6
# 1744,11,Black,4
# 1745,12,Black,7
# 1746,13,Black,8
# 1747,14,Black,6
# 1748,0,Black,4
# 1749,0,Black,5
# 1750,0,Black,4
# 1751,0,Black,5
# 1752,0,Black,6
# 1753,0,Black,7
# 1754,0,Black,6
# 1755,0,Black,6
# 1756,0,Black,6
# 1757,0,Black,4
# 1758,0,Black,6
# 1759,0,Black,7
# 1760,0,Black,6
# 1761,0,Black,7
# 1762,0,Black,6
# 1763,1,White,7
# 1764,2,White,822
# 1765,3,White,818
# 1766,4,White,825
# 1767,5,White,818
# 1768,6,White,819
# 1769,7,White,826
# 1770,8,White,824
# 1771,9,White,826
# 1772,10,White,821
# 1773,11,White,823
# 1774,12,White,810
# 1775,13,White,823
# 1776,14,White,826
# 1777,15,White,823
# 1778,1,Red,818
# 1779,2,Red,344
# 1780,3,Red,339
# 1781,4,Red,342
# 1782,5,Red,337
# 1783,6,Red,345
# 1784,7,Red,339
# 1785,8,Red,339
# 1786,9,Red,339
# 1787,10,Red,334
# 1788,11,Red,342
# 1789,12,Red,340
# 1790,13,Red,343
# 1791,14,Red,345
# 1792,1,Green,335
# 1793,2,Green,197
# 1794,3,Green,200
# 1795,4,Green,201
# 1796,5,Green,191
# 1797,6,Green,195
# 1798,7,Green,196
# 1799,8,Green,198
# 1800,9,Green,201

# %% [markdown]
# โค้ดแปลงไฟล์ .txt ทุกไฟล์ในโฟลเดอร์ "raw_data" เป็นไฟล์ .csv และบันทึกในโฟลเดอร์ "datasetCSV" โดยลบข้อมูลในแถวแรกของแต่ละไฟล์ .txt ก่อนจะเขียนลงในไฟล์ .csv ที่สร้างขึ้นใหม่

# %%
import os
import csv

# ระบุโฟลเดอร์ raw_data
input_folder_path = "raw_data"

# ระบุโฟลเดอร์ที่จะบันทึกไฟล์ .csv
output_folder_path = "datasetCSV"

# ตรวจสอบว่าโฟลเดอร์ output_folder_path มีอยู่หรือไม่ และสร้างถ้าไม่มี
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# รายการไฟล์ในโฟลเดอร์ input_folder_path
files = os.listdir(input_folder_path)

# วนลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์ input_folder_path
for filename in files:
    input_file_path = os.path.join(input_folder_path, filename)

    # ตรวจสอบว่าไฟล์นี้เป็นไฟล์ข้อความหรือไม่
    if filename.endswith(".txt"):
        # สร้างชื่อไฟล์ .csv ใหม่โดยนำชื่อไฟล์เดิมมาใช้
        output_file_path = os.path.join(output_folder_path, os.path.splitext(filename)[0] + ".csv")

        # เปิดไฟล์ .txt สำหรับอ่าน
        with open(input_file_path, "r") as txt_file:
            # อ่านข้อมูลทั้งหมดจากไฟล์ .txt
            lines = txt_file.readlines()

        # ตรวจสอบว่ามีข้อมูลในไฟล์หรือไม่
        if len(lines) > 0:
            # ลบข้อมูลในแถวแรก
            lines = lines[1:]

            # เปิดไฟล์ .csv สำหรับเขียน
            with open(output_file_path, "w", newline='') as csv_file:
                # สร้างอ็อบเจ็กต์ writer สำหรับเขียนข้อมูล CSV
                csv_writer = csv.writer(csv_file)

                # เขียนข้อมูลลงในไฟล์ .csv
                for line in lines:
                    # แบ่งข้อมูลในแต่ละบรรทัดด้วยเครื่องหมาย "," และลบช่องว่างด้านหน้าและหลัง
                    row_data = line.strip().split(",")
                    csv_writer.writerow(row_data)

        print(f"แปลงไฟล์ '{filename}' และบันทึกเป็น '{os.path.basename(output_file_path)}'")

print("เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ datasetCSV")
# Out:
# แปลงไฟล์ 'P10_NRe.txt' และบันทึกเป็น 'P10_NRe.csv'
# แปลงไฟล์ 'P100.txt' และบันทึกเป็น 'P100.csv'
# แปลงไฟล์ 'P10.txt' และบันทึกเป็น 'P10.csv'
# แปลงไฟล์ 'P1000.txt' และบันทึกเป็น 'P1000.csv'
# แปลงไฟล์ 'P1000_NRe.txt' และบันทึกเป็น 'P1000_NRe.csv'
# แปลงไฟล์ 'P0.txt' และบันทึกเป็น 'P0.csv'
# แปลงไฟล์ 'P100_NRe.txt' และบันทึกเป็น 'P100_NRe.csv'
# เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ datasetCSV

# %%
        # เปิดไฟล์ .csv สำหรับอ่าน
        with open(output_file_path, "r") as csv_file:
            # อ่านข้อมูล CSV
            csv_reader = csv.reader(csv_file)
            
            # แสดงข้อมูลที่อ่านจากไฟล์ .csv บนหน้าจอ
            print(f"ข้อมูลในไฟล์ '{os.path.basename(output_file_path)}':")
            for row in csv_reader:
                print(row)
# Out:
# ข้อมูลในไฟล์ 'P100_NRe.csv':
# ['1', '1', 'White', '4']
# ['2', '2', 'White', '830']
# ['3', '3', 'White', '822']
# ['4', '4', 'White', '832']
# ['5', '5', 'White', '832']
# ['6', '6', 'White', '823']
# ['7', '7', 'White', '833']
# ['8', '8', 'White', '826']
# ['9', '9', 'White', '828']
# ['10', '10', 'White', '831']
# ['11', '11', 'White', '818']
# ['12', '12', 'White', '834']
# ['13', '13', 'White', '829']
# ['14', '14', 'White', '831']
# ['15', '1', 'Red', '832']
# ['16', '2', 'Red', '343']
# ['17', '3', 'Red', '343']
# ['18', '4', 'Red', '343']
# ['19', '5', 'Red', '336']
# ['20', '6', 'Red', '343']
# ['21', '7', 'Red', '343']
# ['22', '8', 'Red', '345']
# ['23', '9', 'Red', '346']
# ['24', '10', 'Red', '348']
# ['25', '11', 'Red', '345']
# ['26', '12', 'Red', '341']
# ['27', '13', 'Red', '347']
# ['28', '14', 'Red', '339']
# ['29', '15', 'Red', '342']
# ['30', '1', 'Green', '338']
# ['31', '2', 'Green', '197']
# ['32', '3', 'Green', '198']
# ['33', '4', 'Green', '195']
# ['34', '5', 'Green', '197']
# ['35', '6', 'Green', '202']
# ['36', '7', 'Green', '198']
# ['37', '8', 'Green', '199']
# ['38', '9', 'Green', '199']
# ['39', '10', 'Green', '201']
# ['40', '11', 'Green', '201']
# ['41', '12', 'Green', '201']
# ['42', '13', 'Green', '201']
# ['43', '14', 'Green', '202']
# ['44', '15', 'Green', '197']
# ['45', '1', 'Blue', '202']
# ['46', '2', 'Blue', '336']
# ['47', '3', 'Blue', '335']
# ['48', '4', 'Blue', '337']
# ['49', '5', 'Blue', '337']
# ['50', '6', 'Blue', '337']
# ['51', '7', 'Blue', '337']
# ['52', '8', 'Blue', '333']
# ['53', '9', 'Blue', '331']
# ['54', '10', 'Blue', '337']
# ['55', '11', 'Blue', '332']
# ['56', '12', 'Blue', '336']
# ['57', '13', 'Blue', '334']
# ['58', '14', 'Blue', '331']
# ['59', '1', 'Black', '335']
# ['60', '2', 'Black', '6']
# ['61', '3', 'Black', '7']
# ['62', '4', 'Black', '5']
# ['63', '5', 'Black', '5']
# ['64', '6', 'Black', '5']
# ['65', '7', 'Black', '6']
# ['66', '8', 'Black', '5']
# ['67', '9', 'Black', '6']
# ['68', '10', 'Black', '6']
# ['69', '11', 'Black', '7']
# ['70', '12', 'Black', '5']
# ['71', '13', 'Black', '8']
# ['72', '14', 'Black', '7']
# ['73', '15', 'Black', '5']
# ['74', '0', 'Black', '5']
# ['75', '0', 'Black', '6']
# ['76', '0', 'Black', '6']
# ['77', '0', 'Black', '6']
# ['78', '0', 'Black', '4']
# ['79', '0', 'Black', '5']
# ['80', '0', 'Black', '6']
# ['81', '0', 'Black', '6']
# ['82', '0', 'Black', '5']
# ['83', '0', 'Black', '7']
# ['84', '0', 'Black', '7']
# ['85', '0', 'Black', '6']
# ['86', '0', 'Black', '6']
# ['87', '0', 'Black', '5']
# ['88', '0', 'Black', '7']
# ['89', '1', 'White', '5']
# ['90', '2', 'White', '825']
# ['91', '3', 'White', '827']
# ['92', '4', 'White', '826']
# ['93', '5', 'White', '819']
# ['94', '6', 'White', '826']
# ['95', '7', 'White', '823']
# ['96', '8', 'White', '832']
# ['97', '9', 'White', '821']
# ['98', '10', 'White', '822']
# ['99', '11', 'White', '823']
# ['100', '12', 'White', '827']
# ['101', '13', 'White', '820']
# ['102', '14', 'White', '828']
# ['103', '1', 'Red', '821']
# ['104', '2', 'Red', '341']
# ['105', '3', 'Red', '342']
# ['106', '4', 'Red', '341']
# ['107', '5', 'Red', '339']
# ['108', '6', 'Red', '346']
# ['109', '7', 'Red', '336']
# ['110', '8', 'Red', '343']
# ['111', '9', 'Red', '340']
# ['112', '10', 'Red', '341']
# ['113', '11', 'Red', '344']
# ['114', '12', 'Red', '338']
# ['115', '13', 'Red', '341']
# ['116', '14', 'Red', '343']
# ['117', '15', 'Red', '343']
# ['118', '1', 'Green', '335']
# ['119', '2', 'Green', '196']
# ['120', '3', 'Green', '195']
# ['121', '4', 'Green', '196']
# ['122', '5', 'Green', '200']
# ['123', '6', 'Green', '200']
# ['124', '7', 'Green', '196']
# ['125', '8', 'Green', '199']
# ['126', '9', 'Green', '198']
# ['127', '10', 'Green', '197']
# ['128', '11', 'Green', '200']
# ['129', '12', 'Green', '196']
# ['130', '13', 'Green', '198']
# ['131', '14', 'Green', '198']
# ['132', '15', 'Green', '199']
# ['133', '1', 'Blue', '196']
# ['134', '2', 'Blue', '326']
# ['135', '3', 'Blue', '332']
# ['136', '4', 'Blue', '338']
# ['137', '5', 'Blue', '335']
# ['138', '6', 'Blue', '333']
# ['139', '7', 'Blue', '328']
# ['140', '8', 'Blue', '335']
# ['141', '9', 'Blue', '337']
# ['142', '10', 'Blue', '334']
# ['143', '11', 'Blue', '330']
# ['144', '12', 'Blue', '335']
# ['145', '13', 'Blue', '334']
# ['146', '14', 'Blue', '332']
# ['147', '1', 'Black', '335']
# ['148', '2', 'Black', '6']
# ['149', '3', 'Black', '7']
# ['150', '4', 'Black', '6']
# ['151', '5', 'Black', '5']
# ['152', '6', 'Black', '5']
# ['153', '7', 'Black', '6']
# ['154', '8', 'Black', '7']
# ['155', '9', 'Black', '5']
# ['156', '10', 'Black', '5']
# ['157', '11', 'Black', '5']
# ['158', '12', 'Black', '5']
# ['159', '13', 'Black', '5']
# ['160', '14', 'Black', '5']
# ['161', '15', 'Black', '4']
# ['162', '0', 'Black', '6']
# ['163', '0', 'Black', '5']
# ['164', '0', 'Black', '6']
# ['165', '0', 'Black', '6']
# ['166', '0', 'Black', '5']
# ['167', '0', 'Black', '5']
# ['168', '0', 'Black', '6']
# ['169', '0', 'Black', '6']
# ['170', '0', 'Black', '5']
# ['171', '0', 'Black', '6']
# ['172', '0', 'Black', '8']
# ['173', '0', 'Black', '7']
# ['174', '0', 'Black', '6']
# ['175', '0', 'Black', '6']
# ['176', '0', 'Black', '8']
# ['177', '1', 'White', '7']
# ['178', '2', 'White', '825']
# ['179', '3', 'White', '818']
# ['180', '4', 'White', '821']
# ['181', '5', 'White', '822']
# ['182', '6', 'White', '823']
# ['183', '7', 'White', '827']
# ['184', '8', 'White', '814']
# ['185', '9', 'White', '823']
# ['186', '10', 'White', '820']
# ['187', '11', 'White', '822']
# ['188', '12', 'White', '823']
# ['189', '13', 'White', '815']
# ['190', '14', 'White', '824']
# ['191', '1', 'Red', '827']
# ['192', '2', 'Red', '342']
# ['193', '3', 'Red', '336']
# ['194', '4', 'Red', '333']
# ['195', '5', 'Red', '337']
# ['196', '6', 'Red', '343']
# ['197', '7', 'Red', '344']
# ['198', '8', 'Red', '342']
# ['199', '9', 'Red', '346']
# ['200', '10', 'Red', '334']
# ['201', '11', 'Red', '337']
# ['202', '12', 'Red', '339']
# ['203', '13', 'Red', '340']
# ['204', '14', 'Red', '339']
# ['205', '15', 'Red', '339']
# ['206', '1', 'Green', '343']
# ['207', '2', 'Green', '197']
# ['208', '3', 'Green', '197']
# ['209', '4', 'Green', '194']
# ['210', '5', 'Green', '198']
# ['211', '6', 'Green', '202']
# ['212', '7', 'Green', '195']
# ['213', '8', 'Green', '197']
# ['214', '9', 'Green', '200']
# ['215', '10', 'Green', '196']
# ['216', '11', 'Green', '197']
# ['217', '12', 'Green', '195']
# ['218', '13', 'Green', '196']
# ['219', '14', 'Green', '197']
# ['220', '15', 'Green', '200']
# ['221', '1', 'Blue', '194']
# ['222', '2', 'Blue', '335']
# ['223', '3', 'Blue', '335']
# ['224', '4', 'Blue', '330']
# ['225', '5', 'Blue', '337']
# ['226', '6', 'Blue', '329']
# ['227', '7', 'Blue', '331']
# ['228', '8', 'Blue', '335']
# ['229', '9', 'Blue', '333']
# ['230', '10', 'Blue', '332']
# ['231', '11', 'Blue', '338']
# ['232', '12', 'Blue', '336']
# ['233', '13', 'Blue', '334']
# ['234', '14', 'Blue', '330']
# ['235', '15', 'Blue', '328']
# ['236', '1', 'Black', '329']
# ['237', '2', 'Black', '7']
# ['238', '3', 'Black', '6']
# ['239', '4', 'Black', '7']
# ['240', '5', 'Black', '5']
# ['241', '6', 'Black', '6']
# ['242', '7', 'Black', '5']
# ['243', '8', 'Black', '5']
# ['244', '9', 'Black', '6']
# ['245', '10', 'Black', '8']
# ['246', '11', 'Black', '8']
# ['247', '12', 'Black', '6']
# ['248', '13', 'Black', '7']
# ['249', '14', 'Black', '8']
# ['250', '0', 'Black', '6']
# ['251', '0', 'Black', '6']
# ['252', '0', 'Black', '6']
# ['253', '0', 'Black', '7']
# ['254', '0', 'Black', '6']
# ['255', '0', 'Black', '6']
# ['256', '0', 'Black', '6']
# ['257', '0', 'Black', '6']
# ['258', '0', 'Black', '8']
# ['259', '0', 'Black', '6']
# ['260', '0', 'Black', '5']
# ['261', '0', 'Black', '7']
# ['262', '0', 'Black', '7']
# ['263', '0', 'Black', '8']
# ['264', '0', 'Black', '8']
# ['265', '1', 'White', '8']
# ['266', '2', 'White', '824']
# ['267', '3', 'White', '821']
# ['268', '4', 'White', '818']
# ['269', '5', 'White', '828']
# ['270', '6', 'White', '821']
# ['271', '7', 'White', '828']
# ['272', '8', 'White', '821']
# ['273', '9', 'White', '817']
# ['274', '10', 'White', '822']
# ['275', '11', 'White', '823']
# ['276', '12', 'White', '820']
# ['277', '13', 'White', '821']
# ['278', '14', 'White', '821']
# ['279', '15', 'White', '831']
# ['280', '1', 'Red', '823']
# ['281', '2', 'Red', '342']
# ['282', '3', 'Red', '334']
# ['283', '4', 'Red', '345']
# ['284', '5', 'Red', '346']
# ['285', '6', 'Red', '340']
# ['286', '7', 'Red', '344']
# ['287', '8', 'Red', '336']
# ['288', '9', 'Red', '344']
# ['289', '10', 'Red', '339']
# ['290', '11', 'Red', '337']
# ['291', '12', 'Red', '338']
# ['292', '13', 'Red', '339']
# ['293', '14', 'Red', '341']
# ['294', '1', 'Green', '343']
# ['295', '2', 'Green', '195']
# ['296', '3', 'Green', '195']
# ['297', '4', 'Green', '198']
# ['298', '5', 'Green', '204']
# ['299', '6', 'Green', '198']
# ['300', '7', 'Green', '203']
# ['301', '8', 'Green', '197']
# ['302', '9', 'Green', '199']
# ['303', '10', 'Green', '198']
# ['304', '11', 'Green', '198']
# ['305', '12', 'Green', '192']
# ['306', '13', 'Green', '201']
# ['307', '14', 'Green', '198']
# ['308', '15', 'Green', '196']
# ['309', '1', 'Blue', '199']
# ['310', '2', 'Blue', '327']
# ['311', '3', 'Blue', '332']
# ['312', '4', 'Blue', '336']
# ['313', '5', 'Blue', '331']
# ['314', '6', 'Blue', '330']
# ['315', '7', 'Blue', '335']
# ['316', '8', 'Blue', '333']
# ['317', '9', 'Blue', '334']
# ['318', '10', 'Blue', '337']
# ['319', '11', 'Blue', '335']
# ['320', '12', 'Blue', '333']
# ['321', '13', 'Blue', '331']
# ['322', '14', 'Blue', '339']
# ['323', '15', 'Blue', '339']
# ['324', '1', 'Black', '332']
# ['325', '2', 'Black', '9']
# ['326', '3', 'Black', '8']
# ['327', '4', 'Black', '7']
# ['328', '5', 'Black', '8']
# ['329', '6', 'Black', '6']
# ['330', '7', 'Black', '8']
# ['331', '8', 'Black', '7']
# ['332', '9', 'Black', '7']
# ['333', '10', 'Black', '6']
# ['334', '11', 'Black', '5']
# ['335', '12', 'Black', '6']
# ['336', '13', 'Black', '7']
# ['337', '14', 'Black', '5']
# ['338', '0', 'Black', '5']
# ['339', '0', 'Black', '5']
# ['340', '0', 'Black', '7']
# ['341', '0', 'Black', '6']
# ['342', '0', 'Black', '4']
# ['343', '0', 'Black', '5']
# ['344', '0', 'Black', '6']
# ['345', '0', 'Black', '7']
# ['346', '0', 'Black', '7']
# ['347', '0', 'Black', '6']
# ['348', '0', 'Black', '8']
# ['349', '0', 'Black', '7']
# ['350', '0', 'Black', '6']
# ['351', '0', 'Black', '6']
# ['352', '0', 'Black', '5']
# ['353', '1', 'White', '5']
# ['354', '2', 'White', '827']
# ['355', '3', 'White', '825']
# ['356', '4', 'White', '816']
# ['357', '5', 'White', '825']
# ['358', '6', 'White', '826']
# ['359', '7', 'White', '817']
# ['360', '8', 'White', '823']
# ['361', '9', 'White', '825']
# ['362', '10', 'White', '829']
# ['363', '11', 'White', '820']
# ['364', '12', 'White', '815']
# ['365', '13', 'White', '820']
# ['366', '14', 'White', '826']
# ['367', '15', 'White', '824']
# ['368', '1', 'Red', '817']
# ['369', '2', 'Red', '339']
# ['370', '3', 'Red', '344']
# ['371', '4', 'Red', '344']
# ['372', '5', 'Red', '338']
# ['373', '6', 'Red', '343']
# ['374', '7', 'Red', '345']
# ['375', '8', 'Red', '338']
# ['376', '9', 'Red', '344']
# ['377', '10', 'Red', '338']
# ['378', '11', 'Red', '338']
# ['379', '12', 'Red', '340']
# ['380', '13', 'Red', '334']
# ['381', '14', 'Red', '344']
# ['382', '1', 'Green', '342']
# ['383', '2', 'Green', '196']
# ['384', '3', 'Green', '199']
# ['385', '4', 'Green', '196']
# ['386', '5', 'Green', '198']
# ['387', '6', 'Green', '198']
# ['388', '7', 'Green', '202']
# ['389', '8', 'Green', '197']
# ['390', '9', 'Green', '196']
# ['391', '10', 'Green', '198']
# ['392', '11', 'Green', '195']
# ['393', '12', 'Green', '197']
# ['394', '13', 'Green', '197']
# ['395', '14', 'Green', '194']
# ['396', '15', 'Green', '199']
# ['397', '1', 'Blue', '201']
# ['398', '2', 'Blue', '330']
# ['399', '3', 'Blue', '331']
# ['400', '4', 'Blue', '336']
# ['401', '5', 'Blue', '336']
# ['402', '6', 'Blue', '331']
# ['403', '7', 'Blue', '330']
# ['404', '8', 'Blue', '331']
# ['405', '9', 'Blue', '332']
# ['406', '10', 'Blue', '332']
# ['407', '11', 'Blue', '331']
# ['408', '12', 'Blue', '334']
# ['409', '13', 'Blue', '330']
# ['410', '14', 'Blue', '333']
# ['411', '15', 'Blue', '334']
# ['412', '1', 'Black', '330']
# ['413', '2', 'Black', '4']
# ['414', '3', 'Black', '6']
# ['415', '4', 'Black', '7']
# ['416', '5', 'Black', '8']
# ['417', '6', 'Black', '6']
# ['418', '7', 'Black', '5']
# ['419', '8', 'Black', '6']
# ['420', '9', 'Black', '6']
# ['421', '10', 'Black', '6']
# ['422', '11', 'Black', '5']
# ['423', '12', 'Black', '6']
# ['424', '13', 'Black', '6']
# ['425', '14', 'Black', '6']
# ['426', '0', 'Black', '5']
# ['427', '0', 'Black', '7']
# ['428', '0', 'Black', '7']
# ['429', '0', 'Black', '6']
# ['430', '0', 'Black', '5']
# ['431', '0', 'Black', '7']
# ['432', '0', 'Black', '5']
# ['433', '0', 'Black', '5']
# ['434', '0', 'Black', '6']
# ['435', '0', 'Black', '7']
# ['436', '0', 'Black', '7']
# ['437', '0', 'Black', '7']
# ['438', '0', 'Black', '8']
# ['439', '0', 'Black', '6']
# ['440', '0', 'Black', '5']
# ['441', '1', 'White', '6']
# ['442', '2', 'White', '826']
# ['443', '3', 'White', '821']
# ['444', '4', 'White', '819']
# ['445', '5', 'White', '818']
# ['446', '6', 'White', '822']
# ['447', '7', 'White', '821']
# ['448', '8', 'White', '817']
# ['449', '9', 'White', '823']
# ['450', '10', 'White', '827']
# ['451', '11', 'White', '818']
# ['452', '12', 'White', '822']
# ['453', '13', 'White', '821']
# ['454', '14', 'White', '821']
# ['455', '15', 'White', '818']
# ['456', '1', 'Red', '821']
# ['457', '2', 'Red', '341']
# ['458', '3', 'Red', '335']
# ['459', '4', 'Red', '339']
# ['460', '5', 'Red', '336']
# ['461', '6', 'Red', '340']
# ['462', '7', 'Red', '338']
# ['463', '8', 'Red', '345']
# ['464', '9', 'Red', '345']
# ['465', '10', 'Red', '340']
# ['466', '11', 'Red', '343']
# ['467', '12', 'Red', '334']
# ['468', '13', 'Red', '338']
# ['469', '14', 'Red', '339']
# ['470', '15', 'Red', '341']
# ['471', '1', 'Green', '335']
# ['472', '2', 'Green', '197']
# ['473', '3', 'Green', '193']
# ['474', '4', 'Green', '198']
# ['475', '5', 'Green', '194']
# ['476', '6', 'Green', '199']
# ['477', '7', 'Green', '195']
# ['478', '8', 'Green', '194']
# ['479', '9', 'Green', '197']
# ['480', '10', 'Green', '197']
# ['481', '11', 'Green', '200']
# ['482', '12', 'Green', '197']
# ['483', '13', 'Green', '196']
# ['484', '14', 'Green', '198']
# ['485', '1', 'Blue', '200']
# ['486', '2', 'Blue', '332']
# ['487', '3', 'Blue', '332']
# ['488', '4', 'Blue', '327']
# ['489', '5', 'Blue', '333']
# ['490', '6', 'Blue', '337']
# ['491', '7', 'Blue', '331']
# ['492', '8', 'Blue', '336']
# ['493', '9', 'Blue', '333']
# ['494', '10', 'Blue', '336']
# ['495', '11', 'Blue', '334']
# ['496', '12', 'Blue', '329']
# ['497', '13', 'Blue', '337']
# ['498', '14', 'Blue', '332']
# ['499', '15', 'Blue', '325']
# ['500', '1', 'Black', '330']
# ['501', '2', 'Black', '6']
# ['502', '3', 'Black', '6']
# ['503', '4', 'Black', '5']
# ['504', '5', 'Black', '5']
# ['505', '6', 'Black', '7']
# ['506', '7', 'Black', '7']
# ['507', '8', 'Black', '8']
# ['508', '9', 'Black', '6']
# ['509', '10', 'Black', '8']
# ['510', '11', 'Black', '7']
# ['511', '12', 'Black', '8']
# ['512', '13', 'Black', '5']
# ['513', '14', 'Black', '5']
# ['514', '15', 'Black', '5']
# ['515', '0', 'Black', '6']
# ['516', '0', 'Black', '5']
# ['517', '0', 'Black', '7']
# ['518', '0', 'Black', '7']
# ['519', '0', 'Black', '7']
# ['520', '0', 'Black', '7']
# ['521', '0', 'Black', '7']
# ['522', '0', 'Black', '8']
# ['523', '0', 'Black', '7']
# ['524', '0', 'Black', '7']
# ['525', '0', 'Black', '6']
# ['526', '0', 'Black', '8']
# ['527', '0', 'Black', '7']
# ['528', '0', 'Black', '7']
# ['529', '1', 'White', '7']
# ['530', '2', 'White', '820']
# ['531', '3', 'White', '824']
# ['532', '4', 'White', '822']
# ['533', '5', 'White', '817']
# ['534', '6', 'White', '811']
# ['535', '7', 'White', '824']
# ['536', '8', 'White', '824']
# ['537', '9', 'White', '825']
# ['538', '10', 'White', '820']
# ['539', '11', 'White', '825']
# ['540', '12', 'White', '822']
# ['541', '13', 'White', '820']
# ['542', '14', 'White', '825']
# ['543', '15', 'White', '816']
# ['544', '1', 'Red', '825']
# ['545', '2', 'Red', '340']
# ['546', '3', 'Red', '346']
# ['547', '4', 'Red', '340']
# ['548', '5', 'Red', '335']
# ['549', '6', 'Red', '341']
# ['550', '7', 'Red', '342']
# ['551', '8', 'Red', '343']
# ['552', '9', 'Red', '344']
# ['553', '10', 'Red', '336']
# ['554', '11', 'Red', '339']
# ['555', '12', 'Red', '340']
# ['556', '13', 'Red', '341']
# ['557', '14', 'Red', '341']
# ['558', '15', 'Red', '343']
# ['559', '1', 'Green', '341']
# ['560', '2', 'Green', '201']
# ['561', '3', 'Green', '196']
# ['562', '4', 'Green', '201']
# ['563', '5', 'Green', '199']
# ['564', '6', 'Green', '196']
# ['565', '7', 'Green', '197']
# ['566', '8', 'Green', '194']
# ['567', '9', 'Green', '200']
# ['568', '10', 'Green', '199']
# ['569', '11', 'Green', '204']
# ['570', '12', 'Green', '194']
# ['571', '13', 'Green', '196']
# ['572', '14', 'Green', '197']
# ['573', '1', 'Blue', '197']
# ['574', '2', 'Blue', '332']
# ['575', '3', 'Blue', '331']
# ['576', '4', 'Blue', '328']
# ['577', '5', 'Blue', '334']
# ['578', '6', 'Blue', '332']
# ['579', '7', 'Blue', '329']
# ['580', '8', 'Blue', '331']
# ['581', '9', 'Blue', '330']
# ['582', '10', 'Blue', '331']
# ['583', '11', 'Blue', '331']
# ['584', '12', 'Blue', '335']
# ['585', '13', 'Blue', '332']
# ['586', '14', 'Blue', '335']
# ['587', '15', 'Blue', '331']
# ['588', '1', 'Black', '330']
# ['589', '2', 'Black', '6']
# ['590', '3', 'Black', '6']
# ['591', '4', 'Black', '6']
# ['592', '5', 'Black', '5']
# ['593', '6', 'Black', '5']
# ['594', '7', 'Black', '8']
# ['595', '8', 'Black', '8']
# ['596', '9', 'Black', '6']
# ['597', '10', 'Black', '7']
# ['598', '11', 'Black', '6']
# ['599', '12', 'Black', '6']
# ['600', '13', 'Black', '7']
# ['601', '14', 'Black', '8']
# ['602', '15', 'Black', '7']
# ['603', '0', 'Black', '6']
# ['604', '0', 'Black', '7']
# ['605', '0', 'Black', '7']
# ['606', '0', 'Black', '7']
# ['607', '0', 'Black', '7']
# ['608', '0', 'Black', '9']
# ['609', '0', 'Black', '8']
# ['610', '0', 'Black', '6']
# ['611', '0', 'Black', '5']
# ['612', '0', 'Black', '6']
# ['613', '0', 'Black', '7']
# ['614', '0', 'Black', '6']
# ['615', '0', 'Black', '7']
# ['616', '0', 'Black', '8']
# ['617', '1', 'White', '7']
# ['618', '2', 'White', '818']
# ['619', '3', 'White', '823']
# ['620', '4', 'White', '822']
# ['621', '5', 'White', '818']
# ['622', '6', 'White', '823']
# ['623', '7', 'White', '822']
# ['624', '8', 'White', '822']
# ['625', '9', 'White', '818']
# ['626', '10', 'White', '820']
# ['627', '11', 'White', '828']
# ['628', '12', 'White', '822']
# ['629', '13', 'White', '825']
# ['630', '14', 'White', '818']
# ['631', '15', 'White', '822']
# ['632', '1', 'Red', '824']
# ['633', '2', 'Red', '338']
# ['634', '3', 'Red', '337']
# ['635', '4', 'Red', '341']
# ['636', '5', 'Red', '340']
# ['637', '6', 'Red', '342']
# ['638', '7', 'Red', '344']
# ['639', '8', 'Red', '339']
# ['640', '9', 'Red', '343']
# ['641', '10', 'Red', '345']
# ['642', '11', 'Red', '344']
# ['643', '12', 'Red', '338']
# ['644', '13', 'Red', '339']
# ['645', '14', 'Red', '337']
# ['646', '15', 'Red', '337']
# ['647', '1', 'Green', '342']
# ['648', '2', 'Green', '197']
# ['649', '3', 'Green', '200']
# ['650', '4', 'Green', '200']
# ['651', '5', 'Green', '197']
# ['652', '6', 'Green', '196']
# ['653', '7', 'Green', '194']
# ['654', '8', 'Green', '198']
# ['655', '9', 'Green', '194']
# ['656', '10', 'Green', '202']
# ['657', '11', 'Green', '196']
# ['658', '12', 'Green', '194']
# ['659', '13', 'Green', '200']
# ['660', '14', 'Green', '196']
# ['661', '1', 'Blue', '196']
# ['662', '2', 'Blue', '335']
# ['663', '3', 'Blue', '334']
# ['664', '4', 'Blue', '325']
# ['665', '5', 'Blue', '332']
# ['666', '6', 'Blue', '333']
# ['667', '7', 'Blue', '332']
# ['668', '8', 'Blue', '333']
# ['669', '9', 'Blue', '331']
# ['670', '10', 'Blue', '335']
# ['671', '11', 'Blue', '330']
# ['672', '12', 'Blue', '336']
# ['673', '13', 'Blue', '336']
# ['674', '14', 'Blue', '332']
# ['675', '15', 'Blue', '330']
# ['676', '1', 'Black', '336']
# ['677', '2', 'Black', '6']
# ['678', '3', 'Black', '8']
# ['679', '4', 'Black', '5']
# ['680', '5', 'Black', '7']
# ['681', '6', 'Black', '7']
# ['682', '7', 'Black', '7']
# ['683', '8', 'Black', '6']
# ['684', '9', 'Black', '6']
# ['685', '10', 'Black', '8']
# ['686', '11', 'Black', '7']
# ['687', '12', 'Black', '5']
# ['688', '13', 'Black', '5']
# ['689', '14', 'Black', '5']
# ['690', '15', 'Black', '7']
# ['691', '0', 'Black', '6']
# ['692', '0', 'Black', '6']
# ['693', '0', 'Black', '7']
# ['694', '0', 'Black', '7']
# ['695', '0', 'Black', '8']
# ['696', '0', 'Black', '7']
# ['697', '0', 'Black', '7']
# ['698', '0', 'Black', '7']
# ['699', '0', 'Black', '7']
# ['700', '0', 'Black', '7']
# ['701', '0', 'Black', '7']
# ['702', '0', 'Black', '6']
# ['703', '0', 'Black', '8']
# ['704', '0', 'Black', '6']
# ['705', '0', 'Black', '6']
# ['706', '1', 'White', '6']
# ['707', '2', 'White', '827']
# ['708', '3', 'White', '825']
# ['709', '4', 'White', '822']
# ['710', '5', 'White', '820']
# ['711', '6', 'White', '820']
# ['712', '7', 'White', '815']
# ['713', '8', 'White', '824']
# ['714', '9', 'White', '820']
# ['715', '10', 'White', '822']
# ['716', '11', 'White', '821']
# ['717', '12', 'White', '812']
# ['718', '13', 'White', '822']
# ['719', '14', 'White', '824']
# ['720', '1', 'Red', '818']
# ['721', '2', 'Red', '338']
# ['722', '3', 'Red', '340']
# ['723', '4', 'Red', '338']
# ['724', '5', 'Red', '339']
# ['725', '6', 'Red', '339']
# ['726', '7', 'Red', '339']
# ['727', '8', 'Red', '339']
# ['728', '9', 'Red', '339']
# ['729', '10', 'Red', '339']
# ['730', '11', 'Red', '340']
# ['731', '12', 'Red', '340']
# ['732', '13', 'Red', '345']
# ['733', '14', 'Red', '340']
# ['734', '15', 'Red', '338']
# ['735', '1', 'Green', '341']
# ['736', '2', 'Green', '202']
# ['737', '3', 'Green', '198']
# ['738', '4', 'Green', '199']
# ['739', '5', 'Green', '200']
# ['740', '6', 'Green', '198']
# ['741', '7', 'Green', '203']
# ['742', '8', 'Green', '199']
# ['743', '9', 'Green', '196']
# ['744', '10', 'Green', '200']
# ['745', '11', 'Green', '197']
# ['746', '12', 'Green', '196']
# ['747', '13', 'Green', '199']
# ['748', '14', 'Green', '202']
# ['749', '15', 'Green', '201']
# ['750', '1', 'Blue', '198']
# ['751', '2', 'Blue', '333']
# ['752', '3', 'Blue', '337']
# ['753', '4', 'Blue', '337']
# ['754', '5', 'Blue', '331']
# ['755', '6', 'Blue', '331']
# ['756', '7', 'Blue', '327']
# ['757', '8', 'Blue', '335']
# ['758', '9', 'Blue', '333']
# ['759', '10', 'Blue', '332']
# ['760', '11', 'Blue', '333']
# ['761', '12', 'Blue', '333']
# ['762', '13', 'Blue', '332']
# ['763', '14', 'Blue', '335']
# ['764', '1', 'Black', '331']
# ['765', '2', 'Black', '7']
# ['766', '3', 'Black', '7']
# ['767', '4', 'Black', '7']
# ['768', '5', 'Black', '7']
# ['769', '6', 'Black', '7']
# ['770', '7', 'Black', '5']
# ['771', '8', 'Black', '7']
# ['772', '9', 'Black', '7']
# ['773', '10', 'Black', '8']
# ['774', '11', 'Black', '8']
# ['775', '12', 'Black', '8']
# ['776', '13', 'Black', '6']
# ['777', '14', 'Black', '5']
# ['778', '15', 'Black', '8']
# ['779', '0', 'Black', '7']
# ['780', '0', 'Black', '6']
# ['781', '0', 'Black', '8']
# ['782', '0', 'Black', '6']
# ['783', '0', 'Black', '7']
# ['784', '0', 'Black', '5']
# ['785', '0', 'Black', '7']
# ['786', '0', 'Black', '5']
# ['787', '0', 'Black', '8']
# ['788', '0', 'Black', '7']
# ['789', '0', 'Black', '7']
# ['790', '0', 'Black', '6']
# ['791', '0', 'Black', '7']
# ['792', '0', 'Black', '5']
# ['793', '0', 'Black', '6']
# ['794', '1', 'White', '7']
# ['795', '2', 'White', '819']
# ['796', '3', 'White', '821']
# ['797', '4', 'White', '820']
# ['798', '5', 'White', '826']
# ['799', '6', 'White', '820']
# ['800', '7', 'White', '814']
# ['801', '8', 'White', '820']
# ['802', '9', 'White', '826']
# ['803', '10', 'White', '821']
# ['804', '11', 'White', '822']
# ['805', '12', 'White', '822']
# ['806', '13', 'White', '821']
# ['807', '14', 'White', '821']
# ['808', '1', 'Red', '822']
# ['809', '2', 'Red', '341']
# ['810', '3', 'Red', '341']
# ['811', '4', 'Red', '344']
# ['812', '5', 'Red', '340']
# ['813', '6', 'Red', '344']
# ['814', '7', 'Red', '334']
# ['815', '8', 'Red', '336']
# ['816', '9', 'Red', '340']
# ['817', '10', 'Red', '339']
# ['818', '11', 'Red', '339']
# ['819', '12', 'Red', '343']
# ['820', '13', 'Red', '339']
# ['821', '14', 'Red', '341']
# ['822', '15', 'Red', '336']
# ['823', '1', 'Green', '339']
# ['824', '2', 'Green', '196']
# ['825', '3', 'Green', '204']
# ['826', '4', 'Green', '196']
# ['827', '5', 'Green', '198']
# ['828', '6', 'Green', '202']
# ['829', '7', 'Green', '196']
# ['830', '8', 'Green', '195']
# ['831', '9', 'Green', '197']
# ['832', '10', 'Green', '196']
# ['833', '11', 'Green', '197']
# ['834', '12', 'Green', '200']
# ['835', '13', 'Green', '196']
# ['836', '14', 'Green', '203']
# ['837', '15', 'Green', '196']
# ['838', '1', 'Blue', '197']
# ['839', '2', 'Blue', '328']
# ['840', '3', 'Blue', '332']
# ['841', '4', 'Blue', '330']
# ['842', '5', 'Blue', '336']
# ['843', '6', 'Blue', '336']
# ['844', '7', 'Blue', '336']
# ['845', '8', 'Blue', '340']
# ['846', '9', 'Blue', '335']
# ['847', '10', 'Blue', '325']
# ['848', '11', 'Blue', '336']
# ['849', '12', 'Blue', '334']
# ['850', '13', 'Blue', '338']
# ['851', '14', 'Blue', '331']
# ['852', '1', 'Black', '332']
# ['853', '2', 'Black', '7']
# ['854', '3', 'Black', '6']
# ['855', '4', 'Black', '5']
# ['856', '5', 'Black', '6']
# ['857', '6', 'Black', '5']
# ['858', '7', 'Black', '6']
# ['859', '8', 'Black', '9']
# ['860', '9', 'Black', '7']
# ['861', '10', 'Black', '7']
# ['862', '11', 'Black', '8']
# ['863', '12', 'Black', '7']
# ['864', '13', 'Black', '6']
# ['865', '14', 'Black', '5']
# ['866', '15', 'Black', '7']
# ['867', '0', 'Black', '7']
# ['868', '0', 'Black', '6']
# ['869', '0', 'Black', '7']
# ['870', '0', 'Black', '8']
# ['871', '0', 'Black', '6']
# ['872', '0', 'Black', '7']
# ['873', '0', 'Black', '5']
# ['874', '0', 'Black', '8']
# ['875', '0', 'Black', '6']
# ['876', '0', 'Black', '5']
# ['877', '0', 'Black', '7']
# ['878', '0', 'Black', '8']
# ['879', '0', 'Black', '7']
# ['880', '0', 'Black', '6']
# ['881', '0', 'Black', '7']
# ['882', '1', 'White', '7']
# ['883', '2', 'White', '819']
# ['884', '3', 'White', '821']
# ['885', '4', 'White', '822']
# ['886', '5', 'White', '826']
# ['887', '6', 'White', '825']
# ['888', '7', 'White', '817']
# ['889', '8', 'White', '824']
# ['890', '9', 'White', '826']
# ['891', '10', 'White', '815']
# ['892', '11', 'White', '817']
# ['893', '12', 'White', '820']
# ['894', '13', 'White', '820']
# ['895', '14', 'White', '826']
# ['896', '1', 'Red', '821']
# ['897', '2', 'Red', '341']
# ['898', '3', 'Red', '336']
# ['899', '4', 'Red', '338']
# ['900', '5', 'Red', '338']
# ['901', '6', 'Red', '342']
# ['902', '7', 'Red', '347']
# ['903', '8', 'Red', '340']
# ['904', '9', 'Red', '342']
# ['905', '10', 'Red', '344']
# ['906', '11', 'Red', '340']
# ['907', '12', 'Red', '341']
# ['908', '13', 'Red', '341']
# ['909', '14', 'Red', '341']
# ['910', '15', 'Red', '339']
# ['911', '1', 'Green', '341']
# ['912', '2', 'Green', '197']
# ['913', '3', 'Green', '199']
# ['914', '4', 'Green', '200']
# ['915', '5', 'Green', '194']
# ['916', '6', 'Green', '202']
# ['917', '7', 'Green', '191']
# ['918', '8', 'Green', '198']
# ['919', '9', 'Green', '195']
# ['920', '10', 'Green', '198']
# ['921', '11', 'Green', '197']
# ['922', '12', 'Green', '201']
# ['923', '13', 'Green', '194']
# ['924', '14', 'Green', '197']
# ['925', '15', 'Green', '201']
# ['926', '1', 'Blue', '195']
# ['927', '2', 'Blue', '335']
# ['928', '3', 'Blue', '323']
# ['929', '4', 'Blue', '337']
# ['930', '5', 'Blue', '334']
# ['931', '6', 'Blue', '327']
# ['932', '7', 'Blue', '333']
# ['933', '8', 'Blue', '334']
# ['934', '9', 'Blue', '332']
# ['935', '10', 'Blue', '336']
# ['936', '11', 'Blue', '331']
# ['937', '12', 'Blue', '330']
# ['938', '13', 'Blue', '333']
# ['939', '14', 'Blue', '331']
# ['940', '1', 'Black', '333']
# ['941', '2', 'Black', '7']
# ['942', '3', 'Black', '7']
# ['943', '4', 'Black', '5']
# ['944', '5', 'Black', '5']
# ['945', '6', 'Black', '7']
# ['946', '7', 'Black', '7']
# ['947', '8', 'Black', '6']
# ['948', '9', 'Black', '5']
# ['949', '10', 'Black', '5']
# ['950', '11', 'Black', '5']
# ['951', '12', 'Black', '6']
# ['952', '13', 'Black', '5']
# ['953', '14', 'Black', '5']
# ['954', '15', 'Black', '5']
# ['955', '0', 'Black', '7']
# ['956', '0', 'Black', '8']
# ['957', '0', 'Black', '6']
# ['958', '0', 'Black', '6']
# ['959', '0', 'Black', '7']
# ['960', '0', 'Black', '6']
# ['961', '0', 'Black', '6']
# ['962', '0', 'Black', '5']
# ['963', '0', 'Black', '8']
# ['964', '0', 'Black', '6']
# ['965', '0', 'Black', '6']
# ['966', '0', 'Black', '5']
# ['967', '0', 'Black', '5']
# ['968', '0', 'Black', '5']
# ['969', '0', 'Black', '6']
# ['970', '1', 'White', '6']
# ['971', '2', 'White', '818']
# ['972', '3', 'White', '814']
# ['973', '4', 'White', '822']
# ['974', '5', 'White', '821']
# ['975', '6', 'White', '825']
# ['976', '7', 'White', '820']
# ['977', '8', 'White', '823']
# ['978', '9', 'White', '820']
# ['979', '10', 'White', '820']
# ['980', '11', 'White', '825']
# ['981', '12', 'White', '820']
# ['982', '13', 'White', '827']
# ['983', '14', 'White', '827']
# ['984', '15', 'White', '812']
# ['985', '1', 'Red', '822']
# ['986', '2', 'Red', '337']
# ['987', '3', 'Red', '340']
# ['988', '4', 'Red', '343']
# ['989', '5', 'Red', '341']
# ['990', '6', 'Red', '336']
# ['991', '7', 'Red', '339']
# ['992', '8', 'Red', '341']
# ['993', '9', 'Red', '338']
# ['994', '10', 'Red', '341']
# ['995', '11', 'Red', '339']
# ['996', '12', 'Red', '346']
# ['997', '13', 'Red', '345']
# ['998', '14', 'Red', '341']
# ['999', '1', 'Green', '344']
# ['1000', '2', 'Green', '197']
# ['1001', '3', 'Green', '200']
# ['1002', '4', 'Green', '196']
# ['1003', '5', 'Green', '197']
# ['1004', '6', 'Green', '197']
# ['1005', '7', 'Green', '195']
# ['1006', '8', 'Green', '198']
# ['1007', '9', 'Green', '196']
# ['1008', '10', 'Green', '201']
# ['1009', '11', 'Green', '197']
# ['1010', '12', 'Green', '198']
# ['1011', '13', 'Green', '204']
# ['1012', '14', 'Green', '200']
# ['1013', '15', 'Green', '201']
# ['1014', '1', 'Blue', '200']
# ['1015', '2', 'Blue', '328']
# ['1016', '3', 'Blue', '332']
# ['1017', '4', 'Blue', '332']
# ['1018', '5', 'Blue', '334']
# ['1019', '6', 'Blue', '333']
# ['1020', '7', 'Blue', '338']
# ['1021', '8', 'Blue', '333']
# ['1022', '9', 'Blue', '331']
# ['1023', '10', 'Blue', '336']
# ['1024', '11', 'Blue', '330']
# ['1025', '12', 'Blue', '337']
# ['1026', '13', 'Blue', '332']
# ['1027', '14', 'Blue', '330']
# ['1028', '15', 'Blue', '334']
# ['1029', '1', 'Black', '331']
# ['1030', '2', 'Black', '7']
# ['1031', '3', 'Black', '7']
# ['1032', '4', 'Black', '6']
# ['1033', '5', 'Black', '5']
# ['1034', '6', 'Black', '6']
# ['1035', '7', 'Black', '6']
# ['1036', '8', 'Black', '6']
# ['1037', '9', 'Black', '6']
# ['1038', '10', 'Black', '7']
# ['1039', '11', 'Black', '7']
# ['1040', '12', 'Black', '7']
# ['1041', '13', 'Black', '7']
# ['1042', '14', 'Black', '6']
# ['1043', '0', 'Black', '5']
# ['1044', '0', 'Black', '5']
# ['1045', '0', 'Black', '7']
# ['1046', '0', 'Black', '6']
# ['1047', '0', 'Black', '6']
# ['1048', '0', 'Black', '7']
# ['1049', '0', 'Black', '6']
# ['1050', '0', 'Black', '6']
# ['1051', '0', 'Black', '6']
# ['1052', '0', 'Black', '7']
# ['1053', '0', 'Black', '5']
# ['1054', '0', 'Black', '6']
# ['1055', '0', 'Black', '6']
# ['1056', '0', 'Black', '6']
# ['1057', '0', 'Black', '5']
# ['1058', '1', 'White', '7']
# ['1059', '2', 'White', '824']
# ['1060', '3', 'White', '819']
# ['1061', '4', 'White', '819']
# ['1062', '5', 'White', '822']
# ['1063', '6', 'White', '821']
# ['1064', '7', 'White', '824']
# ['1065', '8', 'White', '820']
# ['1066', '9', 'White', '819']
# ['1067', '10', 'White', '820']
# ['1068', '11', 'White', '817']
# ['1069', '12', 'White', '824']
# ['1070', '13', 'White', '826']
# ['1071', '14', 'White', '825']
# ['1072', '15', 'White', '824']
# ['1073', '1', 'Red', '812']
# ['1074', '2', 'Red', '337']
# ['1075', '3', 'Red', '339']
# ['1076', '4', 'Red', '339']
# ['1077', '5', 'Red', '339']
# ['1078', '6', 'Red', '340']
# ['1079', '7', 'Red', '344']
# ['1080', '8', 'Red', '336']
# ['1081', '9', 'Red', '341']
# ['1082', '10', 'Red', '338']
# ['1083', '11', 'Red', '338']
# ['1084', '12', 'Red', '343']
# ['1085', '13', 'Red', '342']
# ['1086', '14', 'Red', '342']
# ['1087', '1', 'Green', '339']
# ['1088', '2', 'Green', '201']
# ['1089', '3', 'Green', '200']
# ['1090', '4', 'Green', '196']
# ['1091', '5', 'Green', '201']
# ['1092', '6', 'Green', '202']
# ['1093', '7', 'Green', '202']
# ['1094', '8', 'Green', '199']
# ['1095', '9', 'Green', '197']
# ['1096', '10', 'Green', '194']
# ['1097', '11', 'Green', '195']
# ['1098', '12', 'Green', '195']
# ['1099', '13', 'Green', '197']
# ['1100', '14', 'Green', '201']
# ['1101', '15', 'Green', '197']
# ['1102', '1', 'Blue', '202']
# ['1103', '2', 'Blue', '323']
# ['1104', '3', 'Blue', '336']
# ['1105', '4', 'Blue', '328']
# ['1106', '5', 'Blue', '331']
# ['1107', '6', 'Blue', '328']
# ['1108', '7', 'Blue', '327']
# ['1109', '8', 'Blue', '333']
# ['1110', '9', 'Blue', '331']
# ['1111', '10', 'Blue', '333']
# ['1112', '11', 'Blue', '328']
# ['1113', '12', 'Blue', '329']
# ['1114', '13', 'Blue', '329']
# ['1115', '14', 'Blue', '335']
# ['1116', '15', 'Blue', '330']
# ['1117', '1', 'Black', '330']
# ['1118', '2', 'Black', '7']
# ['1119', '3', 'Black', '5']
# ['1120', '4', 'Black', '5']
# ['1121', '5', 'Black', '7']
# ['1122', '6', 'Black', '7']
# ['1123', '7', 'Black', '6']
# ['1124', '8', 'Black', '6']
# ['1125', '9', 'Black', '7']
# ['1126', '10', 'Black', '6']
# ['1127', '11', 'Black', '5']
# ['1128', '12', 'Black', '6']
# ['1129', '13', 'Black', '5']
# ['1130', '14', 'Black', '6']
# ['1131', '0', 'Black', '7']
# ['1132', '0', 'Black', '6']
# ['1133', '0', 'Black', '6']
# ['1134', '0', 'Black', '5']
# ['1135', '0', 'Black', '7']
# ['1136', '0', 'Black', '5']
# ['1137', '0', 'Black', '5']
# ['1138', '0', 'Black', '6']
# ['1139', '0', 'Black', '6']
# ['1140', '0', 'Black', '6']
# ['1141', '0', 'Black', '6']
# ['1142', '0', 'Black', '8']
# ['1143', '0', 'Black', '6']
# ['1144', '0', 'Black', '5']
# ['1145', '0', 'Black', '6']
# ['1146', '1', 'White', '6']
# ['1147', '2', 'White', '818']
# ['1148', '3', 'White', '821']
# ['1149', '4', 'White', '824']
# ['1150', '5', 'White', '826']
# ['1151', '6', 'White', '814']
# ['1152', '7', 'White', '821']
# ['1153', '8', 'White', '824']
# ['1154', '9', 'White', '814']
# ['1155', '10', 'White', '824']
# ['1156', '11', 'White', '824']
# ['1157', '12', 'White', '820']
# ['1158', '13', 'White', '816']
# ['1159', '14', 'White', '819']
# ['1160', '15', 'White', '826']
# ['1161', '1', 'Red', '821']
# ['1162', '2', 'Red', '334']
# ['1163', '3', 'Red', '337']
# ['1164', '4', 'Red', '343']
# ['1165', '5', 'Red', '336']
# ['1166', '6', 'Red', '339']
# ['1167', '7', 'Red', '338']
# ['1168', '8', 'Red', '337']
# ['1169', '9', 'Red', '344']
# ['1170', '10', 'Red', '338']
# ['1171', '11', 'Red', '338']
# ['1172', '12', 'Red', '342']
# ['1173', '13', 'Red', '339']
# ['1174', '14', 'Red', '340']
# ['1175', '15', 'Red', '337']
# ['1176', '1', 'Green', '343']
# ['1177', '2', 'Green', '200']
# ['1178', '3', 'Green', '196']
# ['1179', '4', 'Green', '193']
# ['1180', '5', 'Green', '196']
# ['1181', '6', 'Green', '197']
# ['1182', '7', 'Green', '198']
# ['1183', '8', 'Green', '194']
# ['1184', '9', 'Green', '202']
# ['1185', '10', 'Green', '196']
# ['1186', '11', 'Green', '200']
# ['1187', '12', 'Green', '195']
# ['1188', '13', 'Green', '197']
# ['1189', '14', 'Green', '202']
# ['1190', '1', 'Blue', '198']
# ['1191', '2', 'Blue', '330']
# ['1192', '3', 'Blue', '334']
# ['1193', '4', 'Blue', '334']
# ['1194', '5', 'Blue', '325']
# ['1195', '6', 'Blue', '336']
# ['1196', '7', 'Blue', '331']
# ['1197', '8', 'Blue', '330']
# ['1198', '9', 'Blue', '330']
# ['1199', '10', 'Blue', '332']
# ['1200', '11', 'Blue', '331']
# ['1201', '12', 'Blue', '335']
# ['1202', '13', 'Blue', '328']
# ['1203', '14', 'Blue', '329']
# ['1204', '15', 'Blue', '334']
# ['1205', '1', 'Black', '333']
# ['1206', '2', 'Black', '5']
# ['1207', '3', 'Black', '5']
# ['1208', '4', 'Black', '7']
# ['1209', '5', 'Black', '6']
# ['1210', '6', 'Black', '7']
# ['1211', '7', 'Black', '5']
# ['1212', '8', 'Black', '7']
# ['1213', '9', 'Black', '6']
# ['1214', '10', 'Black', '6']
# ['1215', '11', 'Black', '5']
# ['1216', '12', 'Black', '6']
# ['1217', '13', 'Black', '5']
# ['1218', '14', 'Black', '5']
# ['1219', '15', 'Black', '6']
# ['1220', '0', 'Black', '7']
# ['1221', '0', 'Black', '7']
# ['1222', '0', 'Black', '6']
# ['1223', '0', 'Black', '4']
# ['1224', '0', 'Black', '8']
# ['1225', '0', 'Black', '5']
# ['1226', '0', 'Black', '6']
# ['1227', '0', 'Black', '5']
# ['1228', '0', 'Black', '5']
# ['1229', '0', 'Black', '5']
# ['1230', '0', 'Black', '5']
# ['1231', '0', 'Black', '5']
# ['1232', '0', 'Black', '6']
# ['1233', '0', 'Black', '8']
# ['1234', '1', 'White', '6']
# ['1235', '2', 'White', '815']
# ['1236', '3', 'White', '822']
# ['1237', '4', 'White', '825']
# ['1238', '5', 'White', '814']
# ['1239', '6', 'White', '822']
# ['1240', '7', 'White', '826']
# ['1241', '8', 'White', '813']
# ['1242', '9', 'White', '820']
# ['1243', '10', 'White', '825']
# ['1244', '11', 'White', '814']
# ['1245', '12', 'White', '820']
# ['1246', '13', 'White', '826']
# ['1247', '14', 'White', '822']
# ['1248', '15', 'White', '820']
# ['1249', '1', 'Red', '819']
# ['1250', '2', 'Red', '339']
# ['1251', '3', 'Red', '339']
# ['1252', '4', 'Red', '340']
# ['1253', '5', 'Red', '340']
# ['1254', '6', 'Red', '341']
# ['1255', '7', 'Red', '341']
# ['1256', '8', 'Red', '335']
# ['1257', '9', 'Red', '340']
# ['1258', '10', 'Red', '342']
# ['1259', '11', 'Red', '339']
# ['1260', '12', 'Red', '336']
# ['1261', '13', 'Red', '341']
# ['1262', '14', 'Red', '342']
# ['1263', '15', 'Red', '338']
# ['1264', '1', 'Green', '336']
# ['1265', '2', 'Green', '198']
# ['1266', '3', 'Green', '192']
# ['1267', '4', 'Green', '197']
# ['1268', '5', 'Green', '200']
# ['1269', '6', 'Green', '195']
# ['1270', '7', 'Green', '197']
# ['1271', '8', 'Green', '202']
# ['1272', '9', 'Green', '199']
# ['1273', '10', 'Green', '201']
# ['1274', '11', 'Green', '200']
# ['1275', '12', 'Green', '193']
# ['1276', '13', 'Green', '196']
# ['1277', '14', 'Green', '194']
# ['1278', '1', 'Blue', '195']
# ['1279', '2', 'Blue', '332']
# ['1280', '3', 'Blue', '328']
# ['1281', '4', 'Blue', '333']
# ['1282', '5', 'Blue', '331']
# ['1283', '6', 'Blue', '331']
# ['1284', '7', 'Blue', '326']
# ['1285', '8', 'Blue', '336']
# ['1286', '9', 'Blue', '331']
# ['1287', '10', 'Blue', '328']
# ['1288', '11', 'Blue', '328']
# ['1289', '12', 'Blue', '330']
# ['1290', '13', 'Blue', '333']
# ['1291', '14', 'Blue', '331']
# ['1292', '15', 'Blue', '329']
# ['1293', '1', 'Black', '334']
# ['1294', '2', 'Black', '5']
# ['1295', '3', 'Black', '5']
# ['1296', '4', 'Black', '5']
# ['1297', '5', 'Black', '6']
# ['1298', '6', 'Black', '7']
# ['1299', '7', 'Black', '7']
# ['1300', '8', 'Black', '7']
# ['1301', '9', 'Black', '6']
# ['1302', '10', 'Black', '6']
# ['1303', '11', 'Black', '6']
# ['1304', '12', 'Black', '5']
# ['1305', '13', 'Black', '5']
# ['1306', '14', 'Black', '6']
# ['1307', '15', 'Black', '5']
# ['1308', '0', 'Black', '5']
# ['1309', '0', 'Black', '5']
# ['1310', '0', 'Black', '6']
# ['1311', '0', 'Black', '7']
# ['1312', '0', 'Black', '6']
# ['1313', '0', 'Black', '6']
# ['1314', '0', 'Black', '6']
# ['1315', '0', 'Black', '6']
# ['1316', '0', 'Black', '5']
# ['1317', '0', 'Black', '6']
# ['1318', '0', 'Black', '8']
# ['1319', '0', 'Black', '6']
# ['1320', '0', 'Black', '5']
# ['1321', '0', 'Black', '5']
# ['1322', '1', 'White', '6']
# ['1323', '2', 'White', '816']
# ['1324', '3', 'White', '820']
# ['1325', '4', 'White', '822']
# ['1326', '5', 'White', '815']
# ['1327', '6', 'White', '823']
# ['1328', '7', 'White', '818']
# ['1329', '8', 'White', '823']
# ['1330', '9', 'White', '821']
# ['1331', '10', 'White', '820']
# ['1332', '11', 'White', '814']
# ['1333', '12', 'White', '823']
# ['1334', '13', 'White', '818']
# ['1335', '14', 'White', '820']
# ['1336', '15', 'White', '815']
# ['1337', '1', 'Red', '819']
# ['1338', '2', 'Red', '337']
# ['1339', '3', 'Red', '336']
# ['1340', '4', 'Red', '334']
# ['1341', '5', 'Red', '339']
# ['1342', '6', 'Red', '336']
# ['1343', '7', 'Red', '337']
# ['1344', '8', 'Red', '340']
# ['1345', '9', 'Red', '338']
# ['1346', '10', 'Red', '344']
# ['1347', '11', 'Red', '341']
# ['1348', '12', 'Red', '339']
# ['1349', '13', 'Red', '345']
# ['1350', '14', 'Red', '338']
# ['1351', '15', 'Red', '338']
# ['1352', '1', 'Green', '337']
# ['1353', '2', 'Green', '197']
# ['1354', '3', 'Green', '196']
# ['1355', '4', 'Green', '200']
# ['1356', '5', 'Green', '195']
# ['1357', '6', 'Green', '197']
# ['1358', '7', 'Green', '196']
# ['1359', '8', 'Green', '198']
# ['1360', '9', 'Green', '198']
# ['1361', '10', 'Green', '193']
# ['1362', '11', 'Green', '196']
# ['1363', '12', 'Green', '201']
# ['1364', '13', 'Green', '197']
# ['1365', '14', 'Green', '198']
# ['1366', '1', 'Blue', '202']
# ['1367', '2', 'Blue', '333']
# ['1368', '3', 'Blue', '330']
# ['1369', '4', 'Blue', '330']
# ['1370', '5', 'Blue', '333']
# ['1371', '6', 'Blue', '329']
# ['1372', '7', 'Blue', '332']
# ['1373', '8', 'Blue', '330']
# ['1374', '9', 'Blue', '333']
# ['1375', '10', 'Blue', '331']
# ['1376', '11', 'Blue', '329']
# ['1377', '12', 'Blue', '330']
# ['1378', '13', 'Blue', '331']
# ['1379', '14', 'Blue', '330']
# ['1380', '15', 'Blue', '335']
# ['1381', '1', 'Black', '332']
# ['1382', '2', 'Black', '6']
# ['1383', '3', 'Black', '7']
# ['1384', '4', 'Black', '6']
# ['1385', '5', 'Black', '6']
# ['1386', '6', 'Black', '5']
# ['1387', '7', 'Black', '5']
# ['1388', '8', 'Black', '5']
# ['1389', '9', 'Black', '5']
# ['1390', '10', 'Black', '4']
# ['1391', '11', 'Black', '5']
# ['1392', '12', 'Black', '6']
# ['1393', '13', 'Black', '7']
# ['1394', '14', 'Black', '6']
# ['1395', '15', 'Black', '6']
# ['1396', '0', 'Black', '6']
# ['1397', '0', 'Black', '5']
# ['1398', '0', 'Black', '5']
# ['1399', '0', 'Black', '5']
# ['1400', '0', 'Black', '5']
# ['1401', '0', 'Black', '4']
# ['1402', '0', 'Black', '5']
# ['1403', '0', 'Black', '6']
# ['1404', '0', 'Black', '7']
# ['1405', '0', 'Black', '6']
# ['1406', '0', 'Black', '7']
# ['1407', '0', 'Black', '7']
# ['1408', '0', 'Black', '7']
# ['1409', '0', 'Black', '5']
# ['1410', '0', 'Black', '4']
# ['1411', '1', 'White', '5']
# ['1412', '2', 'White', '817']
# ['1413', '3', 'White', '810']
# ['1414', '4', 'White', '822']
# ['1415', '5', 'White', '820']
# ['1416', '6', 'White', '823']
# ['1417', '7', 'White', '820']
# ['1418', '8', 'White', '821']
# ['1419', '9', 'White', '819']
# ['1420', '10', 'White', '825']
# ['1421', '11', 'White', '824']
# ['1422', '12', 'White', '820']
# ['1423', '13', 'White', '816']
# ['1424', '14', 'White', '820']
# ['1425', '1', 'Red', '818']
# ['1426', '2', 'Red', '341']
# ['1427', '3', 'Red', '345']
# ['1428', '4', 'Red', '336']
# ['1429', '5', 'Red', '332']
# ['1430', '6', 'Red', '339']
# ['1431', '7', 'Red', '335']
# ['1432', '8', 'Red', '337']
# ['1433', '9', 'Red', '338']
# ['1434', '10', 'Red', '342']
# ['1435', '11', 'Red', '338']
# ['1436', '12', 'Red', '339']
# ['1437', '13', 'Red', '343']
# ['1438', '14', 'Red', '341']
# ['1439', '15', 'Red', '341']
# ['1440', '1', 'Green', '332']
# ['1441', '2', 'Green', '196']
# ['1442', '3', 'Green', '197']
# ['1443', '4', 'Green', '195']
# ['1444', '5', 'Green', '198']
# ['1445', '6', 'Green', '197']
# ['1446', '7', 'Green', '193']
# ['1447', '8', 'Green', '198']
# ['1448', '9', 'Green', '201']
# ['1449', '10', 'Green', '193']
# ['1450', '11', 'Green', '202']
# ['1451', '12', 'Green', '196']
# ['1452', '13', 'Green', '200']
# ['1453', '14', 'Green', '194']
# ['1454', '15', 'Green', '197']
# ['1455', '1', 'Blue', '197']
# ['1456', '2', 'Blue', '327']
# ['1457', '3', 'Blue', '336']
# ['1458', '4', 'Blue', '337']
# ['1459', '5', 'Blue', '331']
# ['1460', '6', 'Blue', '328']
# ['1461', '7', 'Blue', '332']
# ['1462', '8', 'Blue', '331']
# ['1463', '9', 'Blue', '331']
# ['1464', '10', 'Blue', '336']
# ['1465', '11', 'Blue', '327']
# ['1466', '12', 'Blue', '334']
# ['1467', '13', 'Blue', '332']
# ['1468', '14', 'Blue', '327']
# ['1469', '1', 'Black', '326']
# ['1470', '2', 'Black', '5']
# ['1471', '3', 'Black', '4']
# ['1472', '4', 'Black', '6']
# ['1473', '5', 'Black', '6']
# ['1474', '6', 'Black', '6']
# ['1475', '7', 'Black', '6']
# ['1476', '8', 'Black', '5']
# ['1477', '9', 'Black', '6']
# ['1478', '10', 'Black', '5']
# ['1479', '11', 'Black', '7']
# ['1480', '12', 'Black', '8']
# ['1481', '13', 'Black', '5']
# ['1482', '14', 'Black', '5']
# ['1483', '15', 'Black', '6']
# ['1484', '0', 'Black', '5']
# ['1485', '0', 'Black', '5']
# ['1486', '0', 'Black', '6']
# ['1487', '0', 'Black', '8']
# ['1488', '0', 'Black', '5']
# ['1489', '0', 'Black', '7']
# ['1490', '0', 'Black', '7']
# ['1491', '0', 'Black', '5']
# ['1492', '0', 'Black', '4']
# ['1493', '0', 'Black', '5']
# ['1494', '0', 'Black', '6']
# ['1495', '0', 'Black', '4']
# ['1496', '0', 'Black', '5']
# ['1497', '0', 'Black', '6']
# ['1498', '0', 'Black', '7']
# ['1499', '1', 'White', '7']
# ['1500', '2', 'White', '822']
# ['1501', '3', 'White', '813']
# ['1502', '4', 'White', '823']
# ['1503', '5', 'White', '826']
# ['1504', '6', 'White', '819']
# ['1505', '7', 'White', '821']
# ['1506', '8', 'White', '819']
# ['1507', '9', 'White', '822']
# ['1508', '10', 'White', '812']
# ['1509', '11', 'White', '821']
# ['1510', '12', 'White', '823']
# ['1511', '13', 'White', '819']
# ['1512', '14', 'White', '829']
# ['1513', '1', 'Red', '827']
# ['1514', '2', 'Red', '342']
# ['1515', '3', 'Red', '336']
# ['1516', '4', 'Red', '339']
# ['1517', '5', 'Red', '344']
# ['1518', '6', 'Red', '341']
# ['1519', '7', 'Red', '342']
# ['1520', '8', 'Red', '339']
# ['1521', '9', 'Red', '343']
# ['1522', '10', 'Red', '337']
# ['1523', '11', 'Red', '334']
# ['1524', '12', 'Red', '345']
# ['1525', '13', 'Red', '341']
# ['1526', '14', 'Red', '336']
# ['1527', '15', 'Red', '336']
# ['1528', '1', 'Green', '342']
# ['1529', '2', 'Green', '200']
# ['1530', '3', 'Green', '195']
# ['1531', '4', 'Green', '201']
# ['1532', '5', 'Green', '197']
# ['1533', '6', 'Green', '195']
# ['1534', '7', 'Green', '197']
# ['1535', '8', 'Green', '196']
# ['1536', '9', 'Green', '203']
# ['1537', '10', 'Green', '201']
# ['1538', '11', 'Green', '198']
# ['1539', '12', 'Green', '194']
# ['1540', '13', 'Green', '196']
# ['1541', '14', 'Green', '195']
# ['1542', '15', 'Green', '195']
# ['1543', '1', 'Blue', '195']
# ['1544', '2', 'Blue', '329']
# ['1545', '3', 'Blue', '330']
# ['1546', '4', 'Blue', '336']
# ['1547', '5', 'Blue', '330']
# ['1548', '6', 'Blue', '329']
# ['1549', '7', 'Blue', '336']
# ['1550', '8', 'Blue', '332']
# ['1551', '9', 'Blue', '335']
# ['1552', '10', 'Blue', '330']
# ['1553', '11', 'Blue', '330']
# ['1554', '12', 'Blue', '334']
# ['1555', '13', 'Blue', '333']
# ['1556', '14', 'Blue', '325']
# ['1557', '1', 'Black', '331']
# ['1558', '2', 'Black', '5']
# ['1559', '3', 'Black', '7']
# ['1560', '4', 'Black', '4']
# ['1561', '5', 'Black', '4']
# ['1562', '6', 'Black', '5']
# ['1563', '7', 'Black', '6']
# ['1564', '8', 'Black', '7']
# ['1565', '9', 'Black', '6']
# ['1566', '10', 'Black', '5']
# ['1567', '11', 'Black', '6']
# ['1568', '12', 'Black', '7']
# ['1569', '13', 'Black', '7']
# ['1570', '14', 'Black', '5']
# ['1571', '15', 'Black', '5']
# ['1572', '0', 'Black', '6']
# ['1573', '0', 'Black', '6']
# ['1574', '0', 'Black', '6']
# ['1575', '0', 'Black', '4']
# ['1576', '0', 'Black', '6']
# ['1577', '0', 'Black', '5']
# ['1578', '0', 'Black', '5']
# ['1579', '0', 'Black', '5']
# ['1580', '0', 'Black', '6']
# ['1581', '0', 'Black', '7']
# ['1582', '0', 'Black', '8']
# ['1583', '0', 'Black', '7']
# ['1584', '0', 'Black', '7']
# ['1585', '0', 'Black', '7']
# ['1586', '0', 'Black', '8']
# ['1587', '1', 'White', '6']
# ['1588', '2', 'White', '818']
# ['1589', '3', 'White', '813']
# ['1590', '4', 'White', '822']
# ['1591', '5', 'White', '823']
# ['1592', '6', 'White', '816']
# ['1593', '7', 'White', '820']
# ['1594', '8', 'White', '818']
# ['1595', '9', 'White', '820']
# ['1596', '10', 'White', '820']
# ['1597', '11', 'White', '820']
# ['1598', '12', 'White', '820']
# ['1599', '13', 'White', '828']
# ['1600', '14', 'White', '821']
# ['1601', '1', 'Red', '821']
# ['1602', '2', 'Red', '334']
# ['1603', '3', 'Red', '341']
# ['1604', '4', 'Red', '340']
# ['1605', '5', 'Red', '338']
# ['1606', '6', 'Red', '344']
# ['1607', '7', 'Red', '342']
# ['1608', '8', 'Red', '342']
# ['1609', '9', 'Red', '340']
# ['1610', '10', 'Red', '338']
# ['1611', '11', 'Red', '342']
# ['1612', '12', 'Red', '339']
# ['1613', '13', 'Red', '334']
# ['1614', '14', 'Red', '339']
# ['1615', '15', 'Red', '342']
# ['1616', '1', 'Green', '341']
# ['1617', '2', 'Green', '200']
# ['1618', '3', 'Green', '202']
# ['1619', '4', 'Green', '197']
# ['1620', '5', 'Green', '195']
# ['1621', '6', 'Green', '202']
# ['1622', '7', 'Green', '192']
# ['1623', '8', 'Green', '201']
# ['1624', '9', 'Green', '200']
# ['1625', '10', 'Green', '195']
# ['1626', '11', 'Green', '202']
# ['1627', '12', 'Green', '196']
# ['1628', '13', 'Green', '197']
# ['1629', '14', 'Green', '194']
# ['1630', '15', 'Green', '199']
# ['1631', '1', 'Blue', '197']
# ['1632', '2', 'Blue', '336']
# ['1633', '3', 'Blue', '334']
# ['1634', '4', 'Blue', '333']
# ['1635', '5', 'Blue', '337']
# ['1636', '6', 'Blue', '329']
# ['1637', '7', 'Blue', '331']
# ['1638', '8', 'Blue', '334']
# ['1639', '9', 'Blue', '336']
# ['1640', '10', 'Blue', '333']
# ['1641', '11', 'Blue', '332']
# ['1642', '12', 'Blue', '332']
# ['1643', '13', 'Blue', '334']
# ['1644', '14', 'Blue', '334']
# ['1645', '1', 'Black', '329']
# ['1646', '2', 'Black', '7']
# ['1647', '3', 'Black', '6']
# ['1648', '4', 'Black', '7']
# ['1649', '5', 'Black', '6']
# ['1650', '6', 'Black', '5']
# ['1651', '7', 'Black', '5']
# ['1652', '8', 'Black', '7']
# ['1653', '9', 'Black', '6']
# ['1654', '10', 'Black', '6']
# ['1655', '11', 'Black', '6']
# ['1656', '12', 'Black', '6']
# ['1657', '13', 'Black', '5']
# ['1658', '14', 'Black', '6']
# ['1659', '15', 'Black', '7']
# ['1660', '0', 'Black', '6']
# ['1661', '0', 'Black', '7']
# ['1662', '0', 'Black', '6']
# ['1663', '0', 'Black', '5']
# ['1664', '0', 'Black', '5']
# ['1665', '0', 'Black', '7']
# ['1666', '0', 'Black', '5']
# ['1667', '0', 'Black', '7']
# ['1668', '0', 'Black', '7']
# ['1669', '0', 'Black', '6']
# ['1670', '0', 'Black', '5']
# ['1671', '0', 'Black', '6']
# ['1672', '0', 'Black', '5']
# ['1673', '0', 'Black', '6']
# ['1674', '0', 'Black', '8']
# ['1675', '1', 'White', '7']
# ['1676', '2', 'White', '825']
# ['1677', '3', 'White', '820']
# ['1678', '4', 'White', '820']
# ['1679', '5', 'White', '818']
# ['1680', '6', 'White', '821']
# ['1681', '7', 'White', '826']
# ['1682', '8', 'White', '823']
# ['1683', '9', 'White', '824']
# ['1684', '10', 'White', '818']
# ['1685', '11', 'White', '822']
# ['1686', '12', 'White', '821']
# ['1687', '13', 'White', '820']
# ['1688', '14', 'White', '829']
# ['1689', '15', 'White', '820']
# ['1690', '1', 'Red', '822']
# ['1691', '2', 'Red', '342']
# ['1692', '3', 'Red', '340']
# ['1693', '4', 'Red', '338']
# ['1694', '5', 'Red', '342']
# ['1695', '6', 'Red', '341']
# ['1696', '7', 'Red', '338']
# ['1697', '8', 'Red', '339']
# ['1698', '9', 'Red', '341']
# ['1699', '10', 'Red', '336']
# ['1700', '11', 'Red', '337']
# ['1701', '12', 'Red', '343']
# ['1702', '13', 'Red', '336']
# ['1703', '14', 'Red', '340']
# ['1704', '1', 'Green', '339']
# ['1705', '2', 'Green', '200']
# ['1706', '3', 'Green', '201']
# ['1707', '4', 'Green', '198']
# ['1708', '5', 'Green', '195']
# ['1709', '6', 'Green', '190']
# ['1710', '7', 'Green', '195']
# ['1711', '8', 'Green', '200']
# ['1712', '9', 'Green', '194']
# ['1713', '10', 'Green', '198']
# ['1714', '11', 'Green', '200']
# ['1715', '12', 'Green', '198']
# ['1716', '13', 'Green', '195']
# ['1717', '14', 'Green', '200']
# ['1718', '15', 'Green', '199']
# ['1719', '1', 'Blue', '196']
# ['1720', '2', 'Blue', '327']
# ['1721', '3', 'Blue', '328']
# ['1722', '4', 'Blue', '331']
# ['1723', '5', 'Blue', '326']
# ['1724', '6', 'Blue', '338']
# ['1725', '7', 'Blue', '329']
# ['1726', '8', 'Blue', '335']
# ['1727', '9', 'Blue', '334']
# ['1728', '10', 'Blue', '331']
# ['1729', '11', 'Blue', '333']
# ['1730', '12', 'Blue', '334']
# ['1731', '13', 'Blue', '331']
# ['1732', '14', 'Blue', '336']
# ['1733', '15', 'Blue', '330']
# ['1734', '1', 'Black', '329']
# ['1735', '2', 'Black', '4']
# ['1736', '3', 'Black', '5']
# ['1737', '4', 'Black', '5']
# ['1738', '5', 'Black', '5']
# ['1739', '6', 'Black', '7']
# ['1740', '7', 'Black', '7']
# ['1741', '8', 'Black', '5']
# ['1742', '9', 'Black', '4']
# ['1743', '10', 'Black', '6']
# ['1744', '11', 'Black', '4']
# ['1745', '12', 'Black', '7']
# ['1746', '13', 'Black', '8']
# ['1747', '14', 'Black', '6']
# ['1748', '0', 'Black', '4']
# ['1749', '0', 'Black', '5']
# ['1750', '0', 'Black', '4']
# ['1751', '0', 'Black', '5']
# ['1752', '0', 'Black', '6']
# ['1753', '0', 'Black', '7']
# ['1754', '0', 'Black', '6']
# ['1755', '0', 'Black', '6']
# ['1756', '0', 'Black', '6']
# ['1757', '0', 'Black', '4']
# ['1758', '0', 'Black', '6']
# ['1759', '0', 'Black', '7']
# ['1760', '0', 'Black', '6']
# ['1761', '0', 'Black', '7']
# ['1762', '0', 'Black', '6']
# ['1763', '1', 'White', '7']
# ['1764', '2', 'White', '822']
# ['1765', '3', 'White', '818']
# ['1766', '4', 'White', '825']
# ['1767', '5', 'White', '818']
# ['1768', '6', 'White', '819']
# ['1769', '7', 'White', '826']
# ['1770', '8', 'White', '824']
# ['1771', '9', 'White', '826']
# ['1772', '10', 'White', '821']
# ['1773', '11', 'White', '823']
# ['1774', '12', 'White', '810']
# ['1775', '13', 'White', '823']
# ['1776', '14', 'White', '826']
# ['1777', '15', 'White', '823']
# ['1778', '1', 'Red', '818']
# ['1779', '2', 'Red', '344']
# ['1780', '3', 'Red', '339']
# ['1781', '4', 'Red', '342']
# ['1782', '5', 'Red', '337']
# ['1783', '6', 'Red', '345']
# ['1784', '7', 'Red', '339']
# ['1785', '8', 'Red', '339']
# ['1786', '9', 'Red', '339']
# ['1787', '10', 'Red', '334']
# ['1788', '11', 'Red', '342']
# ['1789', '12', 'Red', '340']
# ['1790', '13', 'Red', '343']
# ['1791', '14', 'Red', '345']
# ['1792', '1', 'Green', '335']
# ['1793', '2', 'Green', '197']
# ['1794', '3', 'Green', '200']
# ['1795', '4', 'Green', '201']
# ['1796', '5', 'Green', '191']
# ['1797', '6', 'Green', '195']
# ['1798', '7', 'Green', '196']
# ['1799', '8', 'Green', '198']
# ['1800', '9', 'Green', '201']

# %% [markdown]
# เพิ่มหัวตารางในไฟล์ CSV  " column_names = ["No.", "Order", "Color", "Intensity"] "

# %%
import os
import pandas as pd

# Define the column names
column_names = ["No.", "Order", "Color", "Intensity"]

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file with the specified column names
    df = pd.read_csv(file_path, names=column_names)

    # Shift the data in the 'Intensity' column up by one row
    df['Intensity'] = df['Intensity'].shift(-1)

    # Drop rows where 'Order' is equal to 0 and 'Color' is equal to 'Black'
    df = df[(df['Order'] != 0) | (df['Color'] != 'Black')]

    # Specify the original file path and save the modified DataFrame
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to datasetCSV/RGBWP.csv
# Modified DataFrame saved to datasetCSV/AllMSD.csv
# Modified DataFrame saved to datasetCSV/P1000.csv
# Modified DataFrame saved to datasetCSV/P_Absorbption.csv
# Modified DataFrame saved to datasetCSV/Asorption_normalized-Copy1.csv
# Modified DataFrame saved to datasetCSV/P1000_NRe.csv
# Modified DataFrame saved to datasetCSV/RGBWP_modified.csv
# Modified DataFrame saved to datasetCSV/MSD_P0.csv
# Modified DataFrame saved to datasetCSV/P0.csv
# Modified DataFrame saved to datasetCSV/MSD_P100_NRe.csv
# Modified DataFrame saved to datasetCSV/MSD_P10.csv
# Modified DataFrame saved to datasetCSV/MSD_P1000.csv
# Modified DataFrame saved to datasetCSV/P100_NRe.csv
# Modified DataFrame saved to datasetCSV/AllMean_Table.csv
# Modified DataFrame saved to datasetCSV/RGBWP_updated.csv
# Modified DataFrame saved to datasetCSV/AllMeanSD_Table.csv
# Modified DataFrame saved to datasetCSV/P10_NRe.csv
# Modified DataFrame saved to datasetCSV/P100.csv
# Modified DataFrame saved to datasetCSV/MSD_P10_NRe.csv
# Modified DataFrame saved to datasetCSV/Asorption.csv
# Modified DataFrame saved to datasetCSV/MSD_P1000_NRe.csv
# Modified DataFrame saved to datasetCSV/P10.csv
# Modified DataFrame saved to datasetCSV/P_Absorption.csv
# Modified DataFrame saved to datasetCSV/MSD_P100.csv
# Modified DataFrame saved to datasetCSV/Asorption_normalized.csv
# Modified DataFrame saved to datasetCSV/MSD.csv
# All CSV files in the 'datasetCSV' folder have been processed.

# %% [markdown]
# ลบข้อมูลในแถวสุดท้ายของแต่ละไฟล์ .csv ในโฟลเดอร์ "datasetCSV" และบันทึกไฟล์ด้วยชื่อเดิม หลังจากดำเนินการนี้กับทุกไฟล์ .csv ในโฟลเดอร์ จะแสดงข้อความ "All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name." เพื่อแสดงว่าการประมวลผลเสร็จสิ้นสำหรับทุกไฟล์ในโฟลเดอร์นี้.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Remove the last row from the DataFrame
    df = df.iloc[:-1]

    # Save the modified DataFrame back to the same file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Last row removed and file '{csv_file}' saved with the same name.")

print("All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name.")
# Out:
# Last row removed and file 'RGBWP.csv' saved with the same name.
# Last row removed and file 'AllMSD.csv' saved with the same name.
# Last row removed and file 'P1000.csv' saved with the same name.
# Last row removed and file 'P_Absorbption.csv' saved with the same name.
# Last row removed and file 'Asorption_normalized-Copy1.csv' saved with the same name.
# Last row removed and file 'P1000_NRe.csv' saved with the same name.
# Last row removed and file 'RGBWP_modified.csv' saved with the same name.
# Last row removed and file 'MSD_P0.csv' saved with the same name.
# Last row removed and file 'P0.csv' saved with the same name.
# Last row removed and file 'MSD_P100_NRe.csv' saved with the same name.
# Last row removed and file 'MSD_P10.csv' saved with the same name.
# Last row removed and file 'MSD_P1000.csv' saved with the same name.
# Last row removed and file 'P100_NRe.csv' saved with the same name.
# Last row removed and file 'AllMean_Table.csv' saved with the same name.
# Last row removed and file 'RGBWP_updated.csv' saved with the same name.
# Last row removed and file 'AllMeanSD_Table.csv' saved with the same name.
# Last row removed and file 'P10_NRe.csv' saved with the same name.
# Last row removed and file 'P100.csv' saved with the same name.
# Last row removed and file 'MSD_P10_NRe.csv' saved with the same name.
# Last row removed and file 'Asorption.csv' saved with the same name.
# Last row removed and file 'MSD_P1000_NRe.csv' saved with the same name.
# Last row removed and file 'P10.csv' saved with the same name.
# Last row removed and file 'P_Absorption.csv' saved with the same name.
# Last row removed and file 'MSD_P100.csv' saved with the same name.
# Last row removed and file 'Asorption_normalized.csv' saved with the same name.
# Last row removed and file 'MSD.csv' saved with the same name.
# All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name.

# %% [markdown]
# แปลงค่าในคอลัมน์ "Intensity" ของไฟล์ CSV เป็นจำนวนเต็มและบันทึกไปยังไฟล์ CSV ที่แก้ไขแล้วในโฟลเดอร์ "datasetCSV" ของทุกไฟล์ .csv ที่อยู่ในโฟลเดอร์นั้น การแปลงจะเป็นการเปลี่ยนชนิดข้อมูลเพียงอย่างเดียวและจะไม่มีการปฏิบัติกับข้อมูลที่ไม่ใช่จำนวนเต็ม.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Convert the 'Intensity' column to integers
    df['Intensity'] = df['Intensity'].astype(int)

    # Save the modified DataFrame back to the CSV file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to datasetCSV/RGBWP.csv
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[31], line 18
#      15 df = pd.read_csv(file_path)
#      17 # Convert the 'Intensity' column to integers
# ---> 18 df['Intensity'] = df['Intensity'].astype(int)
#      20 # Save the modified DataFrame back to the CSV file
#      21 df.to_csv(file_path, index=False)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:146, in _astype_float_to_int_nansafe(values, dtype, copy)
#     142 """
#     143 astype with a check preventing converting NaN to an meaningless integer value.
#     144 """
#     145 if not np.isfinite(values).all():
# --> 146     raise IntCastingNaNError(
#     147         "Cannot convert non-finite values (NA or inf) to integer"
#     148     )
#     149 if dtype.kind == "u":
#     150     # GH#45151
#     151     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %% [markdown]
# โค้ดวนลูปผ่านทุกไฟล์ .csv ในโฟลเดอร์ "datasetCSV" และแสดงข้อมูลจากแต่ละไฟล์ CSV ที่อยู่ในโฟลเดอร์นั้น ผ่านการใช้ pd.read_csv เพื่อโหลดข้อมูลลงใน DataFrame แล้วแสดงผลลัพธ์ด้วย print.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Loop through each CSV file and display its data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Display the data from the current CSV file
    print(f"Data from '{csv_file}':")
    print(df)
    print("\n")

print("All CSV files in the 'datasetCSV' folder have been displayed.")

# %% [markdown]
# # แสดงค่าเฉลี่ยและส่วนเบี่ยงเบนมาตรฐานของแต่ละ Order ของแต่ละ Color  ของแต่ละไฟล์

# %%
import os
import pandas as pd
import numpy as np

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Create empty lists to store the calculated statistics
average_intensity_values = []
std_dev_intensity_values = []

# Loop through each CSV file and calculate statistics for 'Intensity' column
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Group data by 'Order' and 'Color' columns, then calculate mean and standard deviation
    grouped_data = df.groupby(['Order', 'Color'])['Intensity']
    mean_intensity = grouped_data.mean()
    std_dev_intensity = grouped_data.std()

    # Append the calculated statistics to the lists
    average_intensity_values.append(mean_intensity)
    std_dev_intensity_values.append(std_dev_intensity)

# Combine the calculated statistics from all files into one DataFrame
average_intensity_df = pd.concat(average_intensity_values, axis=1)
std_dev_intensity_df = pd.concat(std_dev_intensity_values, axis=1)

# Rename columns to indicate file names
average_intensity_df.columns = csv_files
std_dev_intensity_df.columns = csv_files

# Print the calculated statistics
print("Average Intensity Values:")
print(average_intensity_df)

print("\nStandard Deviation of Intensity Values:")
print(std_dev_intensity_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '3.881128430590366' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 25
#      23 # Group data by 'Order' and 'Color' columns, then calculate mean and standard deviation
#      24 grouped_data = df.groupby(['Order', 'Color'])['Intensity']
# ---> 25 mean_intensity = grouped_data.mean()
#      26 std_dev_intensity = grouped_data.std()
#      28 # Append the calculated statistics to the lists
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/base.py:336, in SingleDataManager.grouped_reduce(self, func)
#     334 def grouped_reduce(self, func):
#     335     arr = self.array
# --> 336     res = func(arr)
#     337     index = default_index(len(res))
#     339     mgr = type(self).from_array(res, index)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# โค้ดบันทึกข้อมูลค่าเฉลี่ยและส่วนเบี่ยงเบนมาตรฐานของคอลัมน์ "Intensity" ที่คำนวณมาไว้ในไฟล์ "MSD.csv" ซึ่งจะถูกบันทึกในโฟลเดอร์ "datasetCSV" ที่เดียวกับไฟล์ CSV อื่นๆ ที่มีอยู่ในโฟลเดอร์นั้น โดยใช้ to_csv โดยที่ index=True เพื่อรวมข้อมูลรายการลงในไฟล์ "MSD.csv" และ mode='a' เพื่อเพิ่มข้อมูลในโหมดผนวก. คำสั่ง print ที่อยู่ต่อท้ายจะแสดงข้อความยืนยันว่าข้อมูลถูกบันทึกเรียบร้อยแล้ว.

# %%
import os
import pandas as pd
import numpy as np

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Create empty lists to store the calculated statistics
average_intensity_values = []
std_dev_intensity_values = []

# Loop through each CSV file and calculate statistics for 'Intensity' column
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Group data by 'Order' and 'Color' columns, then calculate mean and standard deviation
    grouped_data = df.groupby(['Order', 'Color'])['Intensity']
    mean_intensity = grouped_data.mean()
    std_dev_intensity = grouped_data.std()

    # Append the calculated statistics to the lists
    average_intensity_values.append(mean_intensity)
    std_dev_intensity_values.append(std_dev_intensity)

# Combine the calculated statistics from all files into one DataFrame
average_intensity_df = pd.concat(average_intensity_values, axis=1)
std_dev_intensity_df = pd.concat(std_dev_intensity_values, axis=1)

# Rename columns to indicate file names
average_intensity_df.columns = csv_files
std_dev_intensity_df.columns = csv_files

# Print the calculated statistics
print("Average Intensity Values:")
print(average_intensity_df)

print("\nStandard Deviation of Intensity Values:")
print(std_dev_intensity_df)

# Save the calculated statistics to 'MSD.csv'
msd_output_path = os.path.join(folder_path, "MSD.csv")
average_intensity_df.to_csv(msd_output_path, index=True)
std_dev_intensity_df.to_csv(msd_output_path, index=True, mode='a')

print(f"Calculated statistics saved to '{msd_output_path}'")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '3.881128430590366' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 25
#      23 # Group data by 'Order' and 'Color' columns, then calculate mean and standard deviation
#      24 grouped_data = df.groupby(['Order', 'Color'])['Intensity']
# ---> 25 mean_intensity = grouped_data.mean()
#      26 std_dev_intensity = grouped_data.std()
#      28 # Append the calculated statistics to the lists
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/base.py:336, in SingleDataManager.grouped_reduce(self, func)
#     334 def grouped_reduce(self, func):
#     335     arr = self.array
# --> 336     res = func(arr)
#     337     index = default_index(len(res))
#     339     mgr = type(self).from_array(res, index)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# # บันทึกไฟล์  โดยให้จำนวนลูปอยู่ในแนวนอน ของแต่ละไฟล์ MSD_.   ในโฟลเดอร์ datasetCSV

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(original_file_path)

    # Group the DataFrame by 'Order' and 'Color' columns
    grouped_df = df.groupby(['Order', 'Color']).mean().reset_index()

    # Define the new file name
    new_file_name = "MSD_" + csv_file

    # Define the new file path
    new_file_path = os.path.join(folder_path, new_file_name)

    # Save the grouped DataFrame to the new file
    grouped_df.to_csv(new_file_path, index=False)

    # Print a confirmation message
    print(f"Grouped DataFrame saved to {new_file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '283.1724137931035' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 18
#      15 df = pd.read_csv(original_file_path)
#      17 # Group the DataFrame by 'Order' and 'Color' columns
# ---> 18 grouped_df = df.groupby(['Order', 'Color']).mean().reset_index()
#      20 # Define the new file name
#      21 new_file_name = "MSD_" + csv_file
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# แสดงผลแบบ จำนวนลูปอยู่ในแนวนอน ของแต่ละไฟล์ MSD_.   ในโฟลเดอร์ datasetCSV

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    grouped_df = pd.read_csv(original_file_path)

    # Create a pivot table with 'Order' as columns and 'Color' as index
    pivot_df = grouped_df.pivot_table(values='Intensity', index='Color', columns='Order')

    # Print the pivot table
    print(f"Pivot Table for {csv_file}:")
    print(pivot_df)
    print("\n")
# Out:
# Pivot Table for MSD_P0.csv:
# Order                  30.0      218.0
# Color
# 217.22222222222223       NaN  1.603311
# Mean                0.471985       NaN
#
#
# Pivot Table for MSD_P100_NRe.csv:
# Order               6.071429    15.000000   197.785714  331.333333  339.066667
# Color
# 197.7084126984127          NaN         NaN    0.792742         NaN         NaN
# 332.19222222222214         NaN         NaN         NaN    0.560317         NaN
# 339.99492063492056         NaN         NaN         NaN         NaN    0.915162
# 6.058095238095238     0.799897         NaN         NaN         NaN         NaN
# Mean                       NaN    0.208648         NaN         NaN         NaN
#
#
# Pivot Table for MSD_P10.csv:
# Order               4.562500    10.000000   55.647059   89.687500   105.375000
# Color
# 106.60416666666666         NaN         NaN         NaN         NaN     0.64802
# 4.546249999999999     0.503925         NaN         NaN         NaN         NaN
# 56.53470588235293          NaN         NaN    0.325643         NaN         NaN
# 89.62875                   NaN         NaN         NaN    0.605372         NaN
# Mean                       NaN    0.119031         NaN         NaN         NaN
#
#
# Pivot Table for MSD_P1000.csv:
# Order               3.916667   15.000000  26.785714  56.076923  59.833333
# Color
# 27.158412698412697        NaN        NaN   0.443496        NaN        NaN
# 3.8844444444444437   0.345975        NaN        NaN        NaN        NaN
# 56.04957264957264         NaN        NaN        NaN   0.408334        NaN
# 59.25873015873016         NaN        NaN        NaN        NaN   1.038925
# Mean                      NaN   0.123678        NaN        NaN        NaN
#
#
# Pivot Table for MSD_P10_NRe.csv:
# Order               4.833333    15.000000   189.500000  319.692308  325.000000
# Color
# 189.3825396825397          NaN         NaN    1.000078         NaN         NaN
# 321.7128205128205          NaN         NaN         NaN     0.73143         NaN
# 325.54126984126987         NaN         NaN         NaN         NaN    0.480294
# 5.102222222222222     0.720935         NaN         NaN         NaN         NaN
# Mean                       NaN    0.203722         NaN         NaN         NaN
#
#
# Pivot Table for MSD_P1000_NRe.csv:
# Order               5.461538    15.000000   201.416667  336.846154  344.857143
# Color
# 201.2722222222222          NaN         NaN    0.538648         NaN         NaN
# 337.478315018315           NaN         NaN         NaN    0.465415         NaN
# 343.88888888888886         NaN         NaN         NaN         NaN    0.935257
# 5.147435897435898     0.536703         NaN         NaN         NaN         NaN
# Mean                       NaN    0.161346         NaN         NaN         NaN
#
#
# Pivot Table for MSD_P100.csv:
# Order              3.857143   15.000000  35.214286  67.000000  73.666667
# Color
# 3.887142857142857   0.475151        NaN        NaN        NaN        NaN
# 36.37095238095239        NaN        NaN   0.464653        NaN        NaN
# 66.56873015873015        NaN        NaN        NaN   0.319438        NaN
# 73.61904761904763        NaN        NaN        NaN        NaN   1.242876
# Mean                     NaN   0.117064        NaN        NaN        NaN

# %% [markdown]
# บันทึกข้อมูลแต่ละไฟล์ โดยใช้ชื่อเดิมในโฟล์เดอร์เดิม

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    grouped_df = pd.read_csv(original_file_path)

    # Create a pivot table with 'Order' as columns and 'Color' as index
    pivot_df = grouped_df.pivot_table(values='Intensity', index='Color', columns='Order', aggfunc='mean')

    # Calculate the standard deviation for each row (Color)
    std_deviation = pivot_df.apply(lambda row: row.std(), axis=1)

    # Add the mean and standard deviation columns to the pivot table
    pivot_df['Mean'] = pivot_df.mean(axis=1)
    pivot_df['Std Deviation'] = std_deviation

    # Print the pivot table
    print(f"Pivot Table for {csv_file}:")
    print(pivot_df)
    print("\n")

    # Save the pivot table to a CSV file with the same name in the same folder
    output_file_path = os.path.join(folder_path, csv_file)
    pivot_df.to_csv(output_file_path, index=True)
# Out:
# Pivot Table for MSD_P0.csv:
# Order                   30.0     218.0      Mean  Std Deviation
# Color
# 217.22222222222223       NaN  1.603311  1.603311            NaN
# Mean                0.471985       NaN  0.471985            NaN
#
#
# Pivot Table for MSD_P100_NRe.csv:
# Order               6.071428571428571      15.0  197.78571428571428  \
# Color
# 197.7084126984127                 NaN       NaN            0.792742
# 332.19222222222214                NaN       NaN                 NaN
# 339.99492063492056                NaN       NaN                 NaN
# 6.058095238095238            0.799897       NaN                 NaN
# Mean                              NaN  0.208648                 NaN
#
# Order               331.3333333333333  339.06666666666666      Mean  \
# Color
# 197.7084126984127                 NaN                 NaN  0.792742
# 332.19222222222214           0.560317                 NaN  0.560317
# 339.99492063492056                NaN            0.915162  0.915162
# 6.058095238095238                 NaN                 NaN  0.799897
# Mean                              NaN                 NaN  0.208648
#
# Order               Std Deviation
# Color
# 197.7084126984127             NaN
# 332.19222222222214            NaN
# 339.99492063492056            NaN
# 6.058095238095238             NaN
# Mean                          NaN
#
#
# Pivot Table for MSD_P10.csv:
# Order                 4.5625      10.0  55.64705882352941   89.6875  105.375  \
# Color
# 106.60416666666666       NaN       NaN                NaN       NaN  0.64802
# 4.546249999999999   0.503925       NaN                NaN       NaN      NaN
# 56.53470588235293        NaN       NaN           0.325643       NaN      NaN
# 89.62875                 NaN       NaN                NaN  0.605372      NaN
# Mean                     NaN  0.119031                NaN       NaN      NaN
#
# Order                   Mean  Std Deviation
# Color
# 106.60416666666666  0.648020            NaN
# 4.546249999999999   0.503925            NaN
# 56.53470588235293   0.325643            NaN
# 89.62875            0.605372            NaN
# Mean                0.119031            NaN
#
#
# Pivot Table for MSD_P1000.csv:
# Order               3.9166666666666665      15.0  26.785714285714285  \
# Color
# 27.158412698412697                 NaN       NaN            0.443496
# 3.8844444444444437            0.345975       NaN                 NaN
# 56.04957264957264                  NaN       NaN                 NaN
# 59.25873015873016                  NaN       NaN                 NaN
# Mean                               NaN  0.123678                 NaN
#
# Order               56.07692307692308  59.833333333333336      Mean  \
# Color
# 27.158412698412697                NaN                 NaN  0.443496
# 3.8844444444444437                NaN                 NaN  0.345975
# 56.04957264957264            0.408334                 NaN  0.408334
# 59.25873015873016                 NaN            1.038925  1.038925
# Mean                              NaN                 NaN  0.123678
#
# Order               Std Deviation
# Color
# 27.158412698412697            NaN
# 3.8844444444444437            NaN
# 56.04957264957264             NaN
# 59.25873015873016             NaN
# Mean                          NaN
#
#
# Pivot Table for MSD_P10_NRe.csv:
# Order               4.833333333333333      15.0     189.5  319.6923076923077  \
# Color
# 189.3825396825397                 NaN       NaN  1.000078                NaN
# 321.7128205128205                 NaN       NaN       NaN            0.73143
# 325.54126984126987                NaN       NaN       NaN                NaN
# 5.102222222222222            0.720935       NaN       NaN                NaN
# Mean                              NaN  0.203722       NaN                NaN
#
# Order                  325.0      Mean  Std Deviation
# Color
# 189.3825396825397        NaN  1.000078            NaN
# 321.7128205128205        NaN  0.731430            NaN
# 325.54126984126987  0.480294  0.480294            NaN
# 5.102222222222222        NaN  0.720935            NaN
# Mean                     NaN  0.203722            NaN
#
#
# Pivot Table for MSD_P1000_NRe.csv:
# Order               5.461538461538462      15.0  201.41666666666663  \
# Color
# 201.2722222222222                 NaN       NaN            0.538648
# 337.478315018315                  NaN       NaN                 NaN
# 343.88888888888886                NaN       NaN                 NaN
# 5.147435897435898            0.536703       NaN                 NaN
# Mean                              NaN  0.161346                 NaN
#
# Order               336.84615384615387  344.85714285714283      Mean  \
# Color
# 201.2722222222222                  NaN                 NaN  0.538648
# 337.478315018315              0.465415                 NaN  0.465415
# 343.88888888888886                 NaN            0.935257  0.935257
# 5.147435897435898                  NaN                 NaN  0.536703
# Mean                               NaN                 NaN  0.161346
#
# Order               Std Deviation
# Color
# 201.2722222222222             NaN
# 337.478315018315              NaN
# 343.88888888888886            NaN
# 5.147435897435898             NaN
# Mean                          NaN
#
#
# Pivot Table for MSD_P100.csv:
# Order              3.857142857142857      15.0  35.214285714285715      67.0  \
# Color
# 3.887142857142857           0.475151       NaN                 NaN       NaN
# 36.37095238095239                NaN       NaN            0.464653       NaN
# 66.56873015873015                NaN       NaN                 NaN  0.319438
# 73.61904761904763                NaN       NaN                 NaN       NaN
# Mean                             NaN  0.117064                 NaN       NaN
#
# Order              73.66666666666667      Mean  Std Deviation
# Color
# 3.887142857142857                NaN  0.475151            NaN
# 36.37095238095239                NaN  0.464653            NaN
# 66.56873015873015                NaN  0.319438            NaN
# 73.61904761904763           1.242876  1.242876            NaN
# Mean                             NaN  0.117064            NaN

# %% [markdown]
# แสดงค่าเฉลี่ย และส่วนเบี่ยงเบนมาตรฐานของแต่ละไฟล์

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    if "MSD_P" in csv_file:
        # Construct the full file path
        original_file_path = os.path.join(folder_path, csv_file)

        # Read the CSV file into a DataFrame
        grouped_df = pd.read_csv(original_file_path)

        # Create a pivot table with 'Order' as columns and 'Color' as index
        pivot_df = grouped_df.pivot_table(values='Mean', index='Color', aggfunc='mean')

        # Calculate the standard deviation for each row (Color)
        std_deviation = pivot_df.apply(lambda row: row.std(), axis=1)

        # Add the mean and standard deviation columns to the pivot table
        pivot_df['Mean'] = pivot_df.mean(axis=1)
        pivot_df['Std Deviation'] = std_deviation

        # Print the 'Mean' column for 'MSD_P' files
        print(f"Mean for {csv_file} (MSD_P):")
        print(pivot_df['Mean'])
        print("\n")
# Out:
# Mean for MSD_P0.csv (MSD_P):
# Color
# 217.22222222222223    1.603311
# Mean                  0.471985
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P100_NRe.csv (MSD_P):
# Color
# 197.7084126984127     0.792742
# 332.19222222222214    0.560317
# 339.99492063492056    0.915162
# 6.058095238095238     0.799897
# Mean                  0.208648
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P10.csv (MSD_P):
# Color
# 106.60416666666666    0.648020
# 4.546249999999999     0.503925
# 56.53470588235293     0.325643
# 89.62875              0.605372
# Mean                  0.119031
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P1000.csv (MSD_P):
# Color
# 27.158412698412697    0.443496
# 3.8844444444444437    0.345975
# 56.04957264957264     0.408334
# 59.25873015873016     1.038925
# Mean                  0.123678
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P10_NRe.csv (MSD_P):
# Color
# 189.3825396825397     1.000078
# 321.7128205128205     0.731430
# 325.54126984126987    0.480294
# 5.102222222222222     0.720935
# Mean                  0.203722
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P1000_NRe.csv (MSD_P):
# Color
# 201.2722222222222     0.538648
# 337.478315018315      0.465415
# 343.88888888888886    0.935257
# 5.147435897435898     0.536703
# Mean                  0.161346
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P100.csv (MSD_P):
# Color
# 3.887142857142857    0.475151
# 36.37095238095239    0.464653
# 66.56873015873015    0.319438
# 73.61904761904763    1.242876
# Mean                 0.117064
# Name: Mean, dtype: float64

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# วนลูปเพื่ออ่านและแสดงข้อมูลจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลทุกคอลัมน์และแถว
    with pd.option_context('display.max_columns', None, 'display.max_rows', None):
        print(df)
    
    print("\n" + "="*80 + "\n")  # สร้างเส้นขั้นบรรทัด
# Out:
# ชื่อไฟล์: MSD_P0.csv
#
#                 Color      30.0     218.0      Mean  Std Deviation
# 0  217.22222222222223       NaN  1.603311  1.603311            NaN
# 1                Mean  0.471985       NaN  0.471985            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_NRe.csv
#
#                 Color  6.071428571428571      15.0  197.78571428571428  \
# 0   197.7084126984127                NaN       NaN            0.792742
# 1  332.19222222222214                NaN       NaN                 NaN
# 2  339.99492063492056                NaN       NaN                 NaN
# 3   6.058095238095238           0.799897       NaN                 NaN
# 4                Mean                NaN  0.208648                 NaN
#
#    331.3333333333333  339.06666666666666      Mean  Std Deviation
# 0                NaN                 NaN  0.792742            NaN
# 1           0.560317                 NaN  0.560317            NaN
# 2                NaN            0.915162  0.915162            NaN
# 3                NaN                 NaN  0.799897            NaN
# 4                NaN                 NaN  0.208648            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10.csv
#
#                 Color    4.5625      10.0  55.64705882352941   89.6875  \
# 0  106.60416666666666       NaN       NaN                NaN       NaN
# 1   4.546249999999999  0.503925       NaN                NaN       NaN
# 2   56.53470588235293       NaN       NaN           0.325643       NaN
# 3            89.62875       NaN       NaN                NaN  0.605372
# 4                Mean       NaN  0.119031                NaN       NaN
#
#    105.375      Mean  Std Deviation
# 0  0.64802  0.648020            NaN
# 1      NaN  0.503925            NaN
# 2      NaN  0.325643            NaN
# 3      NaN  0.605372            NaN
# 4      NaN  0.119031            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000.csv
#
#                 Color  3.9166666666666665      15.0  26.785714285714285  \
# 0  27.158412698412697                 NaN       NaN            0.443496
# 1  3.8844444444444437            0.345975       NaN                 NaN
# 2   56.04957264957264                 NaN       NaN                 NaN
# 3   59.25873015873016                 NaN       NaN                 NaN
# 4                Mean                 NaN  0.123678                 NaN
#
#    56.07692307692308  59.833333333333336      Mean  Std Deviation
# 0                NaN                 NaN  0.443496            NaN
# 1                NaN                 NaN  0.345975            NaN
# 2           0.408334                 NaN  0.408334            NaN
# 3                NaN            1.038925  1.038925            NaN
# 4                NaN                 NaN  0.123678            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_NRe.csv
#
#                 Color  4.833333333333333      15.0     189.5  \
# 0   189.3825396825397                NaN       NaN  1.000078
# 1   321.7128205128205                NaN       NaN       NaN
# 2  325.54126984126987                NaN       NaN       NaN
# 3   5.102222222222222           0.720935       NaN       NaN
# 4                Mean                NaN  0.203722       NaN
#
#    319.6923076923077     325.0      Mean  Std Deviation
# 0                NaN       NaN  1.000078            NaN
# 1            0.73143       NaN  0.731430            NaN
# 2                NaN  0.480294  0.480294            NaN
# 3                NaN       NaN  0.720935            NaN
# 4                NaN       NaN  0.203722            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_NRe.csv
#
#                 Color  5.461538461538462      15.0  201.41666666666663  \
# 0   201.2722222222222                NaN       NaN            0.538648
# 1    337.478315018315                NaN       NaN                 NaN
# 2  343.88888888888886                NaN       NaN                 NaN
# 3   5.147435897435898           0.536703       NaN                 NaN
# 4                Mean                NaN  0.161346                 NaN
#
#    336.84615384615387  344.85714285714283      Mean  Std Deviation
# 0                 NaN                 NaN  0.538648            NaN
# 1            0.465415                 NaN  0.465415            NaN
# 2                 NaN            0.935257  0.935257            NaN
# 3                 NaN                 NaN  0.536703            NaN
# 4                 NaN                 NaN  0.161346            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100.csv
#
#                Color  3.857142857142857      15.0  35.214285714285715  \
# 0  3.887142857142857           0.475151       NaN                 NaN
# 1  36.37095238095239                NaN       NaN            0.464653
# 2  66.56873015873015                NaN       NaN                 NaN
# 3  73.61904761904763                NaN       NaN                 NaN
# 4               Mean                NaN  0.117064                 NaN
#
#        67.0  73.66666666666667      Mean  Std Deviation
# 0       NaN                NaN  0.475151            NaN
# 1       NaN                NaN  0.464653            NaN
# 2  0.319438                NaN  0.319438            NaN
# 3       NaN           1.242876  1.242876            NaN
# 4       NaN                NaN  0.117064            NaN
#
# ================================================================================

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# วนลูปเพื่ออ่านและแสดงข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    print("\n" + "="*80 + "\n")  # สร้างเส้นขั้นบรรทัด
# Out:
# ชื่อไฟล์: MSD_P0.csv
#
#                 Color      Mean  Std Deviation
# 0  217.22222222222223  1.603311            NaN
# 1                Mean  0.471985            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_NRe.csv
#
#                 Color      Mean  Std Deviation
# 0   197.7084126984127  0.792742            NaN
# 1  332.19222222222214  0.560317            NaN
# 2  339.99492063492056  0.915162            NaN
# 3   6.058095238095238  0.799897            NaN
# 4                Mean  0.208648            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10.csv
#
#                 Color      Mean  Std Deviation
# 0  106.60416666666666  0.648020            NaN
# 1   4.546249999999999  0.503925            NaN
# 2   56.53470588235293  0.325643            NaN
# 3            89.62875  0.605372            NaN
# 4                Mean  0.119031            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000.csv
#
#                 Color      Mean  Std Deviation
# 0  27.158412698412697  0.443496            NaN
# 1  3.8844444444444437  0.345975            NaN
# 2   56.04957264957264  0.408334            NaN
# 3   59.25873015873016  1.038925            NaN
# 4                Mean  0.123678            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_NRe.csv
#
#                 Color      Mean  Std Deviation
# 0   189.3825396825397  1.000078            NaN
# 1   321.7128205128205  0.731430            NaN
# 2  325.54126984126987  0.480294            NaN
# 3   5.102222222222222  0.720935            NaN
# 4                Mean  0.203722            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_NRe.csv
#
#                 Color      Mean  Std Deviation
# 0   201.2722222222222  0.538648            NaN
# 1    337.478315018315  0.465415            NaN
# 2  343.88888888888886  0.935257            NaN
# 3   5.147435897435898  0.536703            NaN
# 4                Mean  0.161346            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100.csv
#
#                Color      Mean  Std Deviation
# 0  3.887142857142857  0.475151            NaN
# 1  36.37095238095239  0.464653            NaN
# 2  66.56873015873015  0.319438            NaN
# 3  73.61904761904763  1.242876            NaN
# 4               Mean  0.117064            NaN
#
# ================================================================================

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้างรายการเปล่าที่จะเก็บข้อมูล
result_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    # เพิ่มข้อมูลลงในรายการ result_data
    result_data.append(selected_columns)

    print("\n" + "="*80 + "\n")

# รวมข้อมูลจากทุกไฟล์ CSV เป็น DataFrame เดียว
combined_data = pd.concat(result_data, axis=1)

# แสดงผลรายการ combined_data
print(combined_data)
# Out:
# ชื่อไฟล์: MSD_P0.csv
#
#                 Color      Mean  Std Deviation
# 0  217.22222222222223  1.603311            NaN
# 1                Mean  0.471985            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_NRe.csv
#
#                 Color      Mean  Std Deviation
# 0   197.7084126984127  0.792742            NaN
# 1  332.19222222222214  0.560317            NaN
# 2  339.99492063492056  0.915162            NaN
# 3   6.058095238095238  0.799897            NaN
# 4                Mean  0.208648            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10.csv
#
#                 Color      Mean  Std Deviation
# 0  106.60416666666666  0.648020            NaN
# 1   4.546249999999999  0.503925            NaN
# 2   56.53470588235293  0.325643            NaN
# 3            89.62875  0.605372            NaN
# 4                Mean  0.119031            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000.csv
#
#                 Color      Mean  Std Deviation
# 0  27.158412698412697  0.443496            NaN
# 1  3.8844444444444437  0.345975            NaN
# 2   56.04957264957264  0.408334            NaN
# 3   59.25873015873016  1.038925            NaN
# 4                Mean  0.123678            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_NRe.csv
#
#                 Color      Mean  Std Deviation
# 0   189.3825396825397  1.000078            NaN
# 1   321.7128205128205  0.731430            NaN
# 2  325.54126984126987  0.480294            NaN
# 3   5.102222222222222  0.720935            NaN
# 4                Mean  0.203722            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_NRe.csv
#
#                 Color      Mean  Std Deviation
# 0   201.2722222222222  0.538648            NaN
# 1    337.478315018315  0.465415            NaN
# 2  343.88888888888886  0.935257            NaN
# 3   5.147435897435898  0.536703            NaN
# 4                Mean  0.161346            NaN
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100.csv
#
#                Color      Mean  Std Deviation
# 0  3.887142857142857  0.475151            NaN
# 1  36.37095238095239  0.464653            NaN
# 2  66.56873015873015  0.319438            NaN
# 3  73.61904761904763  1.242876            NaN
# 4               Mean  0.117064            NaN
#
# ================================================================================
#
#                 Color      Mean  Std Deviation               Color      Mean  \
# 0  217.22222222222223  1.603311            NaN   197.7084126984127  0.792742
# 1                Mean  0.471985            NaN  332.19222222222214  0.560317
# 2                 NaN       NaN            NaN  339.99492063492056  0.915162
# 3                 NaN       NaN            NaN   6.058095238095238  0.799897
# 4                 NaN       NaN            NaN                Mean  0.208648
#
#    Std Deviation               Color      Mean  Std Deviation  \
# 0            NaN  106.60416666666666  0.648020            NaN
# 1            NaN   4.546249999999999  0.503925            NaN
# 2            NaN   56.53470588235293  0.325643            NaN
# 3            NaN            89.62875  0.605372            NaN
# 4            NaN                Mean  0.119031            NaN
#
#                 Color  ...  Std Deviation               Color      Mean  \
# 0  27.158412698412697  ...            NaN   189.3825396825397  1.000078
# 1  3.8844444444444437  ...            NaN   321.7128205128205  0.731430
# 2   56.04957264957264  ...            NaN  325.54126984126987  0.480294
# 3   59.25873015873016  ...            NaN   5.102222222222222  0.720935
# 4                Mean  ...            NaN                Mean  0.203722
#
#    Std Deviation               Color      Mean  Std Deviation  \
# 0            NaN   201.2722222222222  0.538648            NaN
# 1            NaN    337.478315018315  0.465415            NaN
# 2            NaN  343.88888888888886  0.935257            NaN
# 3            NaN   5.147435897435898  0.536703            NaN
# 4            NaN                Mean  0.161346            NaN
#
#                Color      Mean  Std Deviation
# 0  3.887142857142857  0.475151            NaN
# 1  36.37095238095239  0.464653            NaN
# 2  66.56873015873015  0.319438            NaN
# 3  73.61904761904763  1.242876            NaN
# 4               Mean  0.117064            NaN
#
# [5 rows x 21 columns]

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้าง DataFrame ที่เก็บข้อมูลทั้งหมด
all_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เลือกคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่มข้อมูลที่เลือกเข้ากับรายการข้อมูลทั้งหมด
    all_data.append(selected_columns)

# รวมข้อมูลทุกไฟล์เข้าด้วยกัน
result = pd.concat(all_data, axis=1)

# แสดงผลลัพธ์
print(result)
# Out:
#                 Color      Mean  Std Deviation               Color      Mean  \
# 0  217.22222222222223  1.603311            NaN   197.7084126984127  0.792742
# 1                Mean  0.471985            NaN  332.19222222222214  0.560317
# 2                 NaN       NaN            NaN  339.99492063492056  0.915162
# 3                 NaN       NaN            NaN   6.058095238095238  0.799897
# 4                 NaN       NaN            NaN                Mean  0.208648
#
#    Std Deviation               Color      Mean  Std Deviation  \
# 0            NaN  106.60416666666666  0.648020            NaN
# 1            NaN   4.546249999999999  0.503925            NaN
# 2            NaN   56.53470588235293  0.325643            NaN
# 3            NaN            89.62875  0.605372            NaN
# 4            NaN                Mean  0.119031            NaN
#
#                 Color  ...  Std Deviation               Color      Mean  \
# 0  27.158412698412697  ...            NaN   189.3825396825397  1.000078
# 1  3.8844444444444437  ...            NaN   321.7128205128205  0.731430
# 2   56.04957264957264  ...            NaN  325.54126984126987  0.480294
# 3   59.25873015873016  ...            NaN   5.102222222222222  0.720935
# 4                Mean  ...            NaN                Mean  0.203722
#
#    Std Deviation               Color      Mean  Std Deviation  \
# 0            NaN   201.2722222222222  0.538648            NaN
# 1            NaN    337.478315018315  0.465415            NaN
# 2            NaN  343.88888888888886  0.935257            NaN
# 3            NaN   5.147435897435898  0.536703            NaN
# 4            NaN                Mean  0.161346            NaN
#
#                Color      Mean  Std Deviation
# 0  3.887142857142857  0.475151            NaN
# 1  36.37095238095239  0.464653            NaN
# 2  66.56873015873015  0.319438            NaN
# 3  73.61904761904763  1.242876            NaN
# 4               Mean  0.117064            NaN
#
# [5 rows x 21 columns]

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้าง DataFrame ที่เก็บข้อมูลทั้งหมด
all_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เพิ่มคอลัมน์ "ชื่อไฟล์" เพื่อเก็บชื่อไฟล์ของแต่ละไฟล์
    df.insert(0, "ชื่อไฟล์", csv_file)
    
    # เลือกคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่มข้อมูลที่เลือกเข้ากับรายการข้อมูลทั้งหมด
    all_data.append(selected_columns)

# รวมข้อมูลทุกไฟล์เข้าด้วยกัน
result = pd.concat(all_data, axis=1)

# แสดงผลลัพธ์
print(result)
# Out:
#                 Color      Mean  Std Deviation               Color      Mean  \
# 0  217.22222222222223  1.603311            NaN   197.7084126984127  0.792742
# 1                Mean  0.471985            NaN  332.19222222222214  0.560317
# 2                 NaN       NaN            NaN  339.99492063492056  0.915162
# 3                 NaN       NaN            NaN   6.058095238095238  0.799897
# 4                 NaN       NaN            NaN                Mean  0.208648
#
#    Std Deviation               Color      Mean  Std Deviation  \
# 0            NaN  106.60416666666666  0.648020            NaN
# 1            NaN   4.546249999999999  0.503925            NaN
# 2            NaN   56.53470588235293  0.325643            NaN
# 3            NaN            89.62875  0.605372            NaN
# 4            NaN                Mean  0.119031            NaN
#
#                 Color  ...  Std Deviation               Color      Mean  \
# 0  27.158412698412697  ...            NaN   189.3825396825397  1.000078
# 1  3.8844444444444437  ...            NaN   321.7128205128205  0.731430
# 2   56.04957264957264  ...            NaN  325.54126984126987  0.480294
# 3   59.25873015873016  ...            NaN   5.102222222222222  0.720935
# 4                Mean  ...            NaN                Mean  0.203722
#
#    Std Deviation               Color      Mean  Std Deviation  \
# 0            NaN   201.2722222222222  0.538648            NaN
# 1            NaN    337.478315018315  0.465415            NaN
# 2            NaN  343.88888888888886  0.935257            NaN
# 3            NaN   5.147435897435898  0.536703            NaN
# 4            NaN                Mean  0.161346            NaN
#
#                Color      Mean  Std Deviation
# 0  3.887142857142857  0.475151            NaN
# 1  36.37095238095239  0.464653            NaN
# 2  66.56873015873015  0.319438            NaN
# 3  73.61904761904763  1.242876            NaN
# 4               Mean  0.117064            NaN
#
# [5 rows x 21 columns]

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้างรายการของ DataFrame ที่จะรวมข้อมูล
dataframes_to_concat = []

# วนลูปเพื่ออ่านและรวมข้อมูลจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เลือกข้อมูลเฉพาะคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่ม DataFrame ที่ได้สร้างลงในรายการ
    dataframes_to_concat.append(selected_columns)

# รวมข้อมูลในรายการ DataFrame โดยใช้ pd.concat()
all_data = pd.concat(dataframes_to_concat, ignore_index=True)

# บันทึก DataFrame ที่รวมข้อมูลลงในไฟล์ "AllMSD.csv"
output_file_path = os.path.join(folder_path, 'AllMSD.csv')
all_data.to_csv(output_file_path, index=False)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMSD.csv

# %%
import pandas as pd

# ระบุที่อยู่ของไฟล์ AllMSD.csv
file_path = "datasetCSV/AllMSD.csv"

# ใช้ pandas อ่านไฟล์ CSV เข้าสู่ DataFrame
df = pd.read_csv(file_path)

# แสดงข้อมูลใน DataFrame
print(df)
# Out:
#                  Color      Mean  Std Deviation
# 0   217.22222222222223  1.603311            NaN
# 1                 Mean  0.471985            NaN
# 2    197.7084126984127  0.792742            NaN
# 3   332.19222222222214  0.560317            NaN
# 4   339.99492063492056  0.915162            NaN
# 5    6.058095238095238  0.799897            NaN
# 6                 Mean  0.208648            NaN
# 7   106.60416666666666  0.648020            NaN
# 8    4.546249999999999  0.503925            NaN
# 9    56.53470588235293  0.325643            NaN
# 10            89.62875  0.605372            NaN
# 11                Mean  0.119031            NaN
# 12  27.158412698412697  0.443496            NaN
# 13  3.8844444444444437  0.345975            NaN
# 14   56.04957264957264  0.408334            NaN
# 15   59.25873015873016  1.038925            NaN
# 16                Mean  0.123678            NaN
# 17   189.3825396825397  1.000078            NaN
# 18   321.7128205128205  0.731430            NaN
# 19  325.54126984126987  0.480294            NaN
# 20   5.102222222222222  0.720935            NaN
# 21                Mean  0.203722            NaN
# 22   201.2722222222222  0.538648            NaN
# 23    337.478315018315  0.465415            NaN
# 24  343.88888888888886  0.935257            NaN
# 25   5.147435897435898  0.536703            NaN
# 26                Mean  0.161346            NaN
# 27   3.887142857142857  0.475151            NaN
# 28   36.37095238095239  0.464653            NaN
# 29   66.56873015873015  0.319438            NaN
# 30   73.61904761904763  1.242876            NaN
# 31                Mean  0.117064            NaN

# %% [markdown]
# จัดตารางเป็น [ 'Color'  'Con_P10', 'Con_P100', 'Con_P1000']   บันทึกเป็น AllMean_Table.csv

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล Color จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P10.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ Color จาก MSD_P10.csv
new_df = pd.DataFrame({'Color': colors})

# โหลดข้อมูล Mean จากไฟล์ MSD_P10.csv, MSD_P100.csv และ MSD_P1000.csv
for prefix in ['P10', 'P100', 'P1000']:
    msd_file_path = os.path.join(folder_path, f'MSD_{prefix}.csv')
    msd_df = pd.read_csv(msd_file_path)
 
    new_df[f'Con_{prefix}'] = msd_df['Mean']

# แสดงเส้น ------------ ด้านบน
print("-" * 50)

# แสดงผลลัพธ์ในรูปแบบตาราง
print(new_df)

# แสดงเส้น ------------ ด้านล่าง
print("-" * 50)

# บันทึกเป็นไฟล์ CSV ชื่อ AllMean_Table.csv
output_file_path = os.path.join(folder_path, 'AllMean_Table.csv')
new_df.to_csv(output_file_path, index=False)

# แสดงข้อความบันทึกไฟล์
print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
# --------------------------------------------------
#                 Color   Con_P10  Con_P100  Con_P1000
# 0  106.60416666666666  0.648020  0.475151   0.443496
# 1   4.546249999999999  0.503925  0.464653   0.345975
# 2   56.53470588235293  0.325643  0.319438   0.408334
# 3            89.62875  0.605372  1.242876   1.038925
# 4                Mean  0.119031  0.117064   0.123678
# --------------------------------------------------
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMean_Table.csv

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล Color จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P10.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ Color จาก MSD_P10.csv
new_df = pd.DataFrame({'Color': colors})

# โหลดข้อมูล Mean จากไฟล์ MSD_P10.csv, MSD_P100.csv และ MSD_P1000.csv
for prefix in ['P10', 'P100', 'P1000']:
    msd_file_path = os.path.join(folder_path, f'MSD_{prefix}.csv')
    msd_df = pd.read_csv(msd_file_path)
 
    new_df[f'Con_{prefix}'] = msd_df['Mean']

# สลับแถวกับหลัก (Transpose) DataFrame
new_df = new_df.transpose()

# แสดงผลลัพธ์ในรูปแบบตาราง
print(new_df)

# บันทึกเป็นไฟล์ CSV ชื่อ AllMean_Table.csv
output_file_path = os.path.join(folder_path, 'AllMean_Table.csv')
new_df.to_csv(output_file_path, header=False)

# แสดงข้อความบันทึกไฟล์
print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
#                             0                  1                  2         3  \
# Color      106.60416666666666  4.546249999999999  56.53470588235293  89.62875
# Con_P10               0.64802           0.503925           0.325643  0.605372
# Con_P100             0.475151           0.464653           0.319438  1.242876
# Con_P1000            0.443496           0.345975           0.408334  1.038925
#
#                   4
# Color          Mean
# Con_P10    0.119031
# Con_P100   0.117064
# Con_P1000  0.123678
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMean_Table.csv

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล "Color" จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P10.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ "Concentrate" และเปลี่ยนชื่อคอลัมน์ "Color"
new_df = pd.DataFrame({'Concentrate': colors})

# โหลดข้อมูล Mean จากไฟล์ MSD_P10.csv, MSD_P100.csv และ MSD_P1000.csv
for prefix in ['P10', 'P10_NRe', 'P100', 'P100_NRe','P1000','P1000_NRe']:
    msd_file_path = os.path.join(folder_path, f'MSD_{prefix}.csv')
    msd_df = pd.read_csv(msd_file_path)
 
    # เปลี่ยนชื่อคอลัมน์ Mean เป็น "10", "100", "1000"
    msd_df.rename(columns={'Mean': prefix}, inplace=True)

    new_df[prefix] = msd_df[prefix]

# สลับแถวกับหลัก (Transpose) DataFrame
new_df = new_df.transpose()

# แสดงผลลัพธ์ในรูปแบบตาราง
print(new_df)

# บันทึกเป็นไฟล์ CSV ชื่อ AllMean_Table.csv โดยไม่รวมหัวของตาราง
output_file_path = os.path.join(folder_path, 'AllMean_Table.csv')
new_df.to_csv(output_file_path, header=False)

# แสดงข้อความบันทึกไฟล์
print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
#                               0                  1                  2  \
# Concentrate  106.60416666666666  4.546249999999999  56.53470588235293
# P10                     0.64802           0.503925           0.325643
# P10_NRe                1.000078            0.73143           0.480294
# P100                   0.475151           0.464653           0.319438
# P100_NRe               0.792742           0.560317           0.915162
# P1000                  0.443496           0.345975           0.408334
# P1000_NRe              0.538648           0.465415           0.935257
#
#                     3         4
# Concentrate  89.62875      Mean
# P10          0.605372  0.119031
# P10_NRe      0.720935  0.203722
# P100         1.242876  0.117064
# P100_NRe     0.799897  0.208648
# P1000        1.038925  0.123678
# P1000_NRe    0.536703  0.161346
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMean_Table.csv

# %%
import pandas as pd

# ระบุที่อยู่ของไฟล์ CSV
file_path = 'datasetCSV/AllMean_Table.csv'

# ใช้ pandas อ่านไฟล์ CSV
df = pd.read_csv(file_path)

# แสดงข้อมูลในตาราง
print(df)
# Out:
#   Concentrate  106.60416666666666  4.546249999999999  56.53470588235293  \
# 0         P10            0.648020           0.503925           0.325643
# 1     P10_NRe            1.000078           0.731430           0.480294
# 2        P100            0.475151           0.464653           0.319438
# 3    P100_NRe            0.792742           0.560317           0.915162
# 4       P1000            0.443496           0.345975           0.408334
# 5   P1000_NRe            0.538648           0.465415           0.935257
#
#    89.62875      Mean
# 0  0.605372  0.119031
# 1  0.720935  0.203722
# 2  1.242876  0.117064
# 3  0.799897  0.208648
# 4  1.038925  0.123678
# 5  0.536703  0.161346

# %%
import pandas as pd

# ระบุที่อยู่ของไฟล์ CSV
file_path = 'datasetCSV/AllMean_Table.csv'

# ใช้ pandas อ่านไฟล์ CSV
df = pd.read_csv(file_path)

# ลบคอลัมน์ "Black" จากคอลัมน์ "Blue," "Green," "Red," และ "White"
df['Blue'] = df['Blue'] - df['Black']
df['Green'] = df['Green'] - df['Black']
df['Red'] = df['Red'] - df['Black']
df['White'] = df['White'] - df['Black']

# ลบคอลัมน์ "Black" ออก
df.drop(columns=['Black'], inplace=True)

# บันทึกเป็นไฟล์ CSV ชื่อ "RGBWP.csv" ในโฟลเดอร์ "datasetCSV"
output_file_path = 'datasetCSV/RGBWP.csv'
df.to_csv(output_file_path, index=False)

# แสดงผลทางหน้าจอ
print(df)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
#   Concentrate       Blue      Green         Red       White
# 0         P10  51.988456  85.082500  102.057917  237.731845
# 1        P100  32.483810  62.681587   69.731905  164.762063
# 2       P1000  23.273968  52.165128   55.374286  131.067937
# บันทึกข้อมูลลงในไฟล์ datasetCSV/RGBWP.csv

# %%
import pandas as pd

# ระบุที่อยู่ของไฟล์ CSV
file_path = 'datasetCSV/AllMean_Table.csv'

# ใช้ pandas อ่านไฟล์ CSV
df = pd.read_csv(file_path)

# แปลงค่าในคอลัมน์ "Concentrate" จาก "P10", "P100", "P1000" เป็น "10", "100", "1000"
df['Concentrate'] = df['Concentrate'].str.replace('P10', '10').str.replace('P100', '100').str.replace('P1000', '1000')

# ลบคอลัมน์ "Black" จากคอลัมน์ "Blue," "Green," "Red," และ "White"
df['Blue'] = df['Blue'] - df['Black']
df['Green'] = df['Green'] - df['Black']
df['Red'] = df['Red'] - df['Black']
df['White'] = df['White'] - df['Black']

# ลบคอลัมน์ "Black" ออก
df.drop(columns=['Black'], inplace=True)

# บันทึกเป็นไฟล์ CSV ชื่อ "RGBWP.csv" ในโฟลเดอร์ "datasetCSV"
output_file_path = 'datasetCSV/RGBWP.csv'
df.to_csv(output_file_path, index=False)

# แสดงผลทางหน้าจอ
print(df)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
#   Concentrate       Blue      Green         Red       White
# 0          10  51.988456  85.082500  102.057917  237.731845
# 1         100  32.483810  62.681587   69.731905  164.762063
# 2        1000  23.273968  52.165128   55.374286  131.067937
# บันทึกข้อมูลลงในไฟล์ datasetCSV/RGBWP.csv

# %%
from scipy.stats import linregress

# สร้างกราฟเชิงเส้นและแสดงสมการเชิงเส้น
plt.figure(figsize=(12, 6))

# กราฟ Blue
plt.subplot(2, 2, 1)
plt.scatter(df['Concentrate'], df['Blue'], marker='o', color='blue', label='Blue')
slope, intercept, r_value, p_value, std_err = linregress(df['Concentrate'], df['Blue'])
plt.plot(df['Concentrate'], intercept + slope * df['Concentrate'], 'r', label=f'Fit: y={slope:.2f}x+{intercept:.2f}\nR-squared={r_value**2:.2f}')
plt.xlabel('Concentrate (log scale)')
plt.ylabel('Blue')
plt.title('Blue Concentration vs. Concentrate (log scale)')
plt.legend()

# กราฟ Green
plt.subplot(2, 2, 2)
plt.scatter(df['Concentrate'], df['Green'], marker='o', color='green', label='Green')
slope, intercept, r_value, p_value, std_err = linregress(df['Concentrate'], df['Green'])
plt.plot(df['Concentrate'], intercept + slope * df['Concentrate'], 'r', label=f'Fit: y={slope:.2f}x+{intercept:.2f}\nR-squared={r_value**2:.2f}')
plt.xlabel('Concentrate (log scale)')
plt.ylabel('Green')
plt.title('Green Concentration vs. Concentrate (log scale)')
plt.legend()

# กราฟ Red
plt.subplot(2, 2, 3)
plt.scatter(df['Concentrate'], df['Red'], marker='o', color='red', label='Red')
slope, intercept, r_value, p_value, std_err = linregress(df['Concentrate'], df['Red'])
plt.plot(df['Concentrate'], intercept + slope * df['Concentrate'], 'r', label=f'Fit: y={slope:.2f}x+{intercept:.2f}\nR-squared={r_value**2:.2f}')
plt.xlabel('Concentrate (log scale)')
plt.ylabel('Red')
plt.title('Red Concentration vs. Concentrate (log scale)')
plt.legend()

# กราฟ White
plt.subplot(2, 2, 4)
plt.scatter(df['Concentrate'], df['White'], marker='o', color='white', label='White')
slope, intercept, r_value, p_value, std_err = linregress(df['Concentrate'], df['White'])
plt.plot(df['Concentrate'], intercept + slope * df['Concentrate'], 'r', label=f'Fit: y={slope:.2f}x+{intercept:.2f}\nR-squared={r_value**2:.2f}')
plt.xlabel('Concentrate (log scale)')
plt.ylabel('White')
plt.title('White Concentration vs. Concentrate (log scale)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from scipy.optimize import curve_fit

# สร้างกราฟเชิงเส้นและแสดงสมการเชิงเส้น
plt.figure(figsize=(12, 6))

def semi_log_func(x, a, b):
    return a * np.log10(x) + b

# กราฟ Blue
plt.subplot(2, 2, 1)
plt.scatter(df['Concentrate'], df['Blue'], marker='o', color='blue', label='Blue')
params, covariance = curve_fit(semi_log_func, df['Concentrate'], df['Blue'])
plt.semilogx(df['Concentrate'], semi_log_func(df['Concentrate'], *params), 'r', label=f'Fit: y={params[0]:.2f} * log10(x) + {params[1]:.2f}')
plt.xlabel('Concentrate (log scale)')
plt.ylabel('Blue')
plt.title('Blue Concentration vs. Concentrate (semi-log scale)')
plt.legend()

# กราฟ Green
plt.subplot(2, 2, 2)
plt.scatter(df['Concentrate'], df['Green'], marker='o', color='green', label='Green')
params, covariance = curve_fit(semi_log_func, df['Concentrate'], df['Green'])
plt.semilogx(df['Concentrate'], semi_log_func(df['Concentrate'], *params), 'r', label=f'Fit: y={params[0]:.2f} * log10(x) + {params[1]:.2f}')
plt.xlabel('Concentrate (log scale)')
plt.ylabel('Green')
plt.title('Green Concentration vs. Concentrate (semi-log scale)')
plt.legend()

# กราฟ Red
plt.subplot(2, 2, 3)
plt.scatter(df['Concentrate'], df['Red'], marker='o', color='red', label='Red')
params, covariance = curve_fit(semi_log_func, df['Concentrate'], df['Red'])
plt.semilogx(df['Concentrate'], semi_log_func(df['Concentrate'], *params), 'r', label=f'Fit: y={params[0]:.2f} * log10(x) + {params[1]:.2f}')
plt.xlabel('Concentrate (log scale)')
plt.ylabel('Red')
plt.title('Red Concentration vs. Concentrate (semi-log scale)')
plt.legend()

# กราฟ White
plt.subplot(2, 2, 4)
plt.scatter(df['Concentrate'], df['White'], marker='o', color='black', label='White')  # ตรงนี้เปลี่ยนสีเป็นดำ
params, covariance = curve_fit(semi_log_func, df['Concentrate'], df['White'])
plt.semilogx(df['Concentrate'], semi_log_func(df['Concentrate'], *params), 'r', label=f'Fit: y={params[0]:.2f} * log10(x) + {params[1]:.2f}')
plt.xlabel('Concentrate (log scale)')
plt.ylabel('White')
plt.title('White Concentration vs. Concentrate (semi-log scale)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล Color จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P10.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ Color จาก MSD_P10.csv
new_df = pd.DataFrame({'Color': colors})

# รายชื่อไฟล์ CSV ที่เราต้องการคำนวณส่วนเบี่ยงเบนมาตรฐาน
csv_files = ['MSD_P10.csv', 'MSD_P100.csv', 'MSD_P1000.csv']

# โหลดข้อมูล Mean และ Std Deviation จากไฟล์ CSV
for csv_file in csv_files:
    msd_file_path = os.path.join(folder_path, csv_file)
    msd_df = pd.read_csv(msd_file_path)
    prefix = csv_file.split('_')[1].split('.')[0]
    new_df[f'Con_{prefix}'] = msd_df['Mean']
    new_df[f'StdDev_{prefix}'] = msd_df['Std Deviation']

# เรียงลำดับคอลัมน์ตามชื่อไฟล์
new_df = new_df[['Color'] + sorted([col for col in new_df.columns if col != 'Color'])]

# บันทึกเป็นไฟล์ CSV ชื่อ AllMeanSD_Table.csv
output_file_path = os.path.join(folder_path, 'AllMeanSD_Table.csv')
new_df.to_csv(output_file_path, index=False)

# แสดงผลลัพธ์ทางจอ
print("-" * 100)
print(new_df)
print("-" * 100)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
# ----------------------------------------------------------------------------------------------------
#    Color     Con_P10    Con_P100   Con_P1000  StdDev_P10  StdDev_P100  \
# 0  Black    4.546250    3.887143    3.884444    0.119031     0.117064
# 1   Blue   56.534706   36.370952   27.158413    0.503925     0.475151
# 2  Green   89.628750   66.568730   56.049573    0.325643     0.464653
# 3    Red  106.604167   73.619048   59.258730    0.605372     0.319438
# 4  White  242.278095  168.649206  134.952381    0.648020     1.242876
#
#    StdDev_P1000
# 0      0.123678
# 1      0.345975
# 2      0.443496
# 3      0.408334
# 4      1.038925
# ----------------------------------------------------------------------------------------------------
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMeanSD_Table.csv

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล Color จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P10.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ Color จาก MSD_P10.csv
new_df = pd.DataFrame({'Color': colors})

# รายชื่อไฟล์ CSV ที่เราต้องการคำนวณส่วนเบี่ยงเบนมาตรฐาน
csv_files = ['MSD_P10.csv', 'MSD_P100.csv', 'MSD_P1000.csv']

# โหลดข้อมูล Mean และ Std Deviation จากไฟล์ CSV
for csv_file in csv_files:
    msd_file_path = os.path.join(folder_path, csv_file)
    msd_df = pd.read_csv(msd_file_path)
    prefix = csv_file.split('_')[1].split('.')[0]
    new_df[f'Con_{prefix}'] = msd_df['Mean']
    new_df[f'StdDev_{prefix}'] = msd_df['Std Deviation']

# เรียงลำดับคอลัมน์ตามลำดับที่ต้องการ
column_order = ['Color', 'Con_P10', 'StdDev_P10', 'Con_P100', 'StdDev_P100', 'Con_P1000', 'StdDev_P1000']
new_df = new_df[column_order]

# บันทึกเป็นไฟล์ CSV ชื่อ AllMeanSD_Table.csv
output_file_path = os.path.join(folder_path, 'AllMeanSD_Table.csv')
new_df.to_csv(output_file_path, index=False)

# แสดงผลลัพธ์ทางจอ
print("-" * 100)
print(new_df)
print("-" * 100)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
# ----------------------------------------------------------------------------------------------------
#    Color     Con_P10  StdDev_P10    Con_P100  StdDev_P100   Con_P1000  \
# 0  Black    4.546250    0.119031    3.887143     0.117064    3.884444
# 1   Blue   56.534706    0.503925   36.370952     0.475151   27.158413
# 2  Green   89.628750    0.325643   66.568730     0.464653   56.049573
# 3    Red  106.604167    0.605372   73.619048     0.319438   59.258730
# 4  White  242.278095    0.648020  168.649206     1.242876  134.952381
#
#    StdDev_P1000
# 0      0.123678
# 1      0.345975
# 2      0.443496
# 3      0.408334
# 4      1.038925
# ----------------------------------------------------------------------------------------------------
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMeanSD_Table.csv
