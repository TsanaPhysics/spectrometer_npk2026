# %% [markdown]
# โค้ดแสดงข้อมูลจากไฟล์ทั้งหมดในโฟลเดอร์ "raw_data" ที่มีนามสกุล ".txt" โดยแสดงข้อมูลของแต่ละไลน์ในแต่ละไฟล์ และเพิ่มบรรทัดว่างหลังจากแต่ละไฟล์เพื่อให้ข้อมูลดูเรียบร้อยขึ้นในผลลัพธ์ที่แสดงออกมาแบบเป็นรายการตามไฟล์ที่อยู่ในโฟลเดอร์ "raw_data" ทั้งหมด.

# %%
import os

# ระบุโฟลเดอร์ raw_data
folder_path = "raw_data"

# ตรวจสอบว่าโฟลเดอร์นี้มีอยู่จริงหรือไม่
if os.path.exists(folder_path):
    # รายการไฟล์ในโฟลเดอร์
    files = os.listdir(folder_path)

    # วนลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์
    for filename in files:
        file_path = os.path.join(folder_path, filename)

        # ตรวจสอบว่าไฟล์นี้เป็นไฟล์ข้อความหรือไม่
        if filename.endswith(".txt"):
            print(f"แสดงข้อมูลจากไฟล์ '{filename}':")
            
            # เปิดไฟล์สำหรับอ่าน
            with open(file_path, "r") as text_file:
                # อ่านและแสดงข้อมูลของแต่ละไลน์
                for line in text_file:
                    print(line.strip())  # ใช้ strip() เพื่อลบช่องว่างที่อาจจะเกิดขึ้น

            print("\n")  # เพิ่มบรรทัดว่างหลังจากแสดงข้อมูลของแต่ละไฮน์
else:
    print(f"โฟลเดอร์ '{folder_path}' ไม่มีอยู่หรือไม่สามารถเข้าถึงได้")
# Out:
# แสดงข้อมูลจากไฟล์ 'N1000_2.txt':
# Nitrogen 1000mg/LOff,5
# White,4
# White,719
# White,724
# White,728
# White,728
# White,729
# White,727
# White,727
# White,719
# Red,720
# Red,292
# Red,292
# Red,288
# Red,293
# Red,294
# Red,293
# Red,292
# Red,292
# Red,292
# Green,291
# Green,150
# Green,152
# Green,154
# Green,155
# Green,154
# Green,153
# Green,155
# Green,151
# Green,151
# Blue,156
# Blue,312
# Blue,307
# Blue,310
# Blue,310
# Blue,311
# Blue,308
# Blue,313
# Blue,306
# Blue,307
# White,314
# White,725
# White,721
# White,721
# White,724
# White,726
# White,721
# White,727
# White,713
# White,724
# Red,723
# Red,292
# Red,297
# Red,292
# Red,293
# Red,292
# Red,292
# Red,294
# Red,291
# Red,294
# Off,290
# White,5
# White,718
# White,718
# White,720
# White,718
# White,719
# White,724
# White,722
# White,724
# Red,723
# Red,291
# Red,291
# Red,293
# Red,294
# Red,292
# Red,299
# Red,290
# Red,296
# Red,291
# Green,297
# Green,154
# Green,150
# Green,151
# Green,151
# Green,147
# Green,153
# Green,152
# Green,148
# Green,151
# Blue,150
# Blue,315
# Blue,310
# Blue,308
# Blue,311
# Blue,316
# Blue,65
# Blue,66
# Blue,70
# Blue,69
# White,69
# White,97
# White,99
# White,94
# White,95
# White,94
# White,93
# White,90
# White,91
# White,88
# Red,92
# Red,22
# Red,23
# Red,25
# Red,24
# Red,27
# Red,26
# Red,25
# Red,28
# Red,24
# Off,24
# White,6
# Red,17
# Red,18
# Red,18
# Red,19
# Red,20
# Red,19
# Red,17
# Off,17
# White,6
# White,56
# White,54
# White,57
# White,57
# White,57
# White,60
# White,58
# White,57
# Red,56
# Red,21
# Red,19
# Red,19
# Red,20
# Red,20
# Red,18
# Red,20
# Red,18
# Red,17
# Green,19
# Green,14
# Green,13
# Green,14
# Green,12
# Green,14
# Green,14
# Green,12
# Green,15
# Green,15
# Blue,12
# Blue,32
# Blue,33
# Blue,34
# Blue,34
# Blue,37
# Blue,33
# Blue,33
# Blue,36
# Blue,34
# White,35
# White,53
# White,55
# White,53
# White,53
# White,55
# White,53
# White,54
# White,50
# White,53
# Red,53
# Red,17
# Red,18
# Red,18
# Red,17
# Red,19
# Red,18
# Red,18
# Red,18
# Red,18
# Off,18
# White,6
# White,51
# White,52
# White,53
# White,53
# White,52
# White,51
# White,50
# White,52
# Red,50
# Red,17
# Red,18
# Red,18
# Red,19
# Red,18
# Red,16
# Red,20
# Red,17
# Red,16
# Green,20
# Green,14
# Green,15
# Green,14
# Green,12
# Green,13
# Green,13
# Green,14
# Green,14
# Green,14
# Blue,11
# Blue,32
# Blue,31
# Blue,29
# Blue,32
# Blue,28
# Blue,29
# Blue,34
# Blue,31
# Blue,30
# White,28
# White,49
# White,48
# White,47
# White,50
# White,47
# White,47
# White,49
# White,49
# White,51
# Red,49
# Red,18
# Red,15
# Red,19
# Red,17
# Red,15
# Red,19
# Red,17
# Red,20
# Red,18
# Off,18
# White,5
# White,51
# White,48

# %% [markdown]
# โค้ดแปลงไฟล์ .txt ทุกไฟล์ในโฟลเดอร์ "raw_data" เป็นไฟล์ .csv และบันทึกในโฟลเดอร์ "datasetCSV" โดยลบข้อมูลในแถวแรกของแต่ละไฟล์ .txt ก่อนจะเขียนลงในไฟล์ .csv ที่สร้างขึ้นใหม่

# %%
import os
import csv

# ระบุโฟลเดอร์ raw_data
input_folder_path = "raw_data"

# ระบุโฟลเดอร์ที่จะบันทึกไฟล์ .csv
output_folder_path = "datasetCSV"

# ตรวจสอบว่าโฟลเดอร์ output_folder_path มีอยู่หรือไม่ และสร้างถ้าไม่มี
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# รายการไฟล์ในโฟลเดอร์ input_folder_path
files = os.listdir(input_folder_path)

# วนลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์ input_folder_path
for filename in files:
    input_file_path = os.path.join(input_folder_path, filename)

    # ตรวจสอบว่าไฟล์นี้เป็นไฟล์ข้อความหรือไม่
    if filename.endswith(".txt"):
        # สร้างชื่อไฟล์ .csv ใหม่โดยนำชื่อไฟล์เดิมมาใช้
        output_file_path = os.path.join(output_folder_path, os.path.splitext(filename)[0] + ".csv")

        # เปิดไฟล์ .txt สำหรับอ่าน
        with open(input_file_path, "r") as txt_file:
            # อ่านข้อมูลทั้งหมดจากไฟล์ .txt
            lines = txt_file.readlines()

        # ตรวจสอบว่ามีข้อมูลในไฟล์หรือไม่
        if len(lines) > 0:
            # ลบข้อมูลในแถวแรก
            lines = lines[1:]

            # เปิดไฟล์ .csv สำหรับเขียน
            with open(output_file_path, "w", newline='') as csv_file:
                # สร้างอ็อบเจ็กต์ writer สำหรับเขียนข้อมูล CSV
                csv_writer = csv.writer(csv_file)

                # เขียนข้อมูลลงในไฟล์ .csv
                for line in lines:
                    # แบ่งข้อมูลในแต่ละบรรทัดด้วยเครื่องหมาย "," และลบช่องว่างด้านหน้าและหลัง
                    row_data = line.strip().split(",")
                    csv_writer.writerow(row_data)

        print(f"แปลงไฟล์ '{filename}' และบันทึกเป็น '{os.path.basename(output_file_path)}'")

print("เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ datasetCSV")
# Out:
# แปลงไฟล์ 'N1000_2.txt' และบันทึกเป็น 'N1000_2.csv'
# แปลงไฟล์ 'N1000_3.txt' และบันทึกเป็น 'N1000_3.csv'
# แปลงไฟล์ 'N1000_1.txt' และบันทึกเป็น 'N1000_1.csv'
# แปลงไฟล์ 'N1000_4.txt' และบันทึกเป็น 'N1000_4.csv'
# แปลงไฟล์ 'N10_3.txt' และบันทึกเป็น 'N10_3.csv'
# แปลงไฟล์ 'N10_2.txt' และบันทึกเป็น 'N10_2.csv'
# แปลงไฟล์ 'N10_1.txt' และบันทึกเป็น 'N10_1.csv'
# แปลงไฟล์ 'N100_3.txt' และบันทึกเป็น 'N100_3.csv'
# แปลงไฟล์ 'N100_2.txt' และบันทึกเป็น 'N100_2.csv'
# แปลงไฟล์ 'N100_1.txt' และบันทึกเป็น 'N100_1.csv'
# แปลงไฟล์ 'N100_4.txt' และบันทึกเป็น 'N100_4.csv'
# เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ datasetCSV

# %% [markdown]
# เพิ่มหัวตารางในไฟล์ CSV  " column_names = ["No.", "Order", "Color", "Intensity"] "

# %%
import os
import pandas as pd

# Define the column names
column_names = ["Color", "Intensity"]

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file with the specified column names
    df = pd.read_csv(file_path, names=column_names)

    # Shift the data in the 'Intensity' column up by one row
    df['Intensity'] = df['Intensity'].shift(-1)

    # Specify the original file path and save the modified DataFrame
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to datasetCSV/N1000_1.csv
# Modified DataFrame saved to datasetCSV/N1000_2.csv
# Modified DataFrame saved to datasetCSV/N1000_3.csv
# Modified DataFrame saved to datasetCSV/N10_1.csv
# Modified DataFrame saved to datasetCSV/N1000_4.csv
# Modified DataFrame saved to datasetCSV/N10_3.csv
# Modified DataFrame saved to datasetCSV/N10_2.csv
# Modified DataFrame saved to datasetCSV/N100_1.csv
# Modified DataFrame saved to datasetCSV/N100_3.csv
# Modified DataFrame saved to datasetCSV/N100_2.csv
# Modified DataFrame saved to datasetCSV/N100_4.csv
# All CSV files in the 'datasetCSV' folder have been processed.

# %% [markdown]
# ลบข้อมูลในแถวสุดท้ายของแต่ละไฟล์ .csv ในโฟลเดอร์ "datasetCSV" และบันทึกไฟล์ด้วยชื่อเดิม หลังจากดำเนินการนี้กับทุกไฟล์ .csv ในโฟลเดอร์ จะแสดงข้อความ "All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name." เพื่อแสดงว่าการประมวลผลเสร็จสิ้นสำหรับทุกไฟล์ในโฟลเดอร์นี้.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Remove the last row from the DataFrame
    df = df.iloc[:-1]

    # Save the modified DataFrame back to the same file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Last row removed and file '{csv_file}' saved with the same name.")

print("All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name.")
# Out:
# Last row removed and file 'N1000_1.csv' saved with the same name.
# Last row removed and file 'N1000_2.csv' saved with the same name.
# Last row removed and file 'N1000_3.csv' saved with the same name.
# Last row removed and file 'N10_1.csv' saved with the same name.
# Last row removed and file 'N1000_4.csv' saved with the same name.
# Last row removed and file 'N10_3.csv' saved with the same name.
# Last row removed and file 'N10_2.csv' saved with the same name.
# Last row removed and file 'N100_1.csv' saved with the same name.
# Last row removed and file 'N100_3.csv' saved with the same name.
# Last row removed and file 'N100_2.csv' saved with the same name.
# Last row removed and file 'N100_4.csv' saved with the same name.
# All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name.

# %% [markdown]
# แปลงค่าในคอลัมน์ "Intensity" ของไฟล์ CSV เป็นจำนวนเต็มและบันทึกไปยังไฟล์ CSV ที่แก้ไขแล้วในโฟลเดอร์ "datasetCSV" ของทุกไฟล์ .csv ที่อยู่ในโฟลเดอร์นั้น การแปลงจะเป็นการเปลี่ยนชนิดข้อมูลเพียงอย่างเดียวและจะไม่มีการปฏิบัติกับข้อมูลที่ไม่ใช่จำนวนเต็ม.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Convert the 'Intensity' column to integers
    df['Intensity'] = df['Intensity'].astype(int)

    # Save the modified DataFrame back to the CSV file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to datasetCSV/N1000_1.csv
# Modified DataFrame saved to datasetCSV/N1000_2.csv
# Modified DataFrame saved to datasetCSV/N1000_3.csv
# Modified DataFrame saved to datasetCSV/N10_1.csv
# Modified DataFrame saved to datasetCSV/N1000_4.csv
# Modified DataFrame saved to datasetCSV/N10_3.csv
# Modified DataFrame saved to datasetCSV/N10_2.csv
# Modified DataFrame saved to datasetCSV/N100_1.csv
# Modified DataFrame saved to datasetCSV/N100_3.csv
# Modified DataFrame saved to datasetCSV/N100_2.csv
# Modified DataFrame saved to datasetCSV/N100_4.csv
# All CSV files in the 'datasetCSV' folder have been processed.

# %% [markdown]
# โค้ดวนลูปผ่านทุกไฟล์ .csv ในโฟลเดอร์ "datasetCSV" และแสดงข้อมูลจากแต่ละไฟล์ CSV ที่อยู่ในโฟลเดอร์นั้น ผ่านการใช้ pd.read_csv เพื่อโหลดข้อมูลลงใน DataFrame แล้วแสดงผลลัพธ์ด้วย print.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Loop through each CSV file and display its data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Display the data from the current CSV file
    print(f"Data from '{csv_file}':")
    print(df)
    print("\n")

print("All CSV files in the 'datasetCSV' folder have been displayed.")
# Out:
# Data from 'N1000_1.csv':
#      Color  Intensity
# 0    White         78
# 1    White         76
# 2    White         79
# 3    White         80
# 4    White         80
# ..     ...        ...
# 708  White        645
# 709    Red        257
# 710    Red        253
# 711    Red        259
# 712    Red        262
#
# [713 rows x 2 columns]
#
#
# Data from 'N1000_2.csv':
#      Color  Intensity
# 0    White        719
# 1    White        724
# 2    White        728
# 3    White        728
# 4    White        729
# ..     ...        ...
# 172    Red         60
# 173    Red         58
# 174    Red         63
# 175    Red         56
# 176    Red         55
#
# [177 rows x 2 columns]
#
#
# Data from 'N1000_3.csv':
#      Color  Intensity
# 0    White        152
# 1    White        149
# 2    White        152
# 3    White        149
# 4    White        146
# ..     ...        ...
# 653    Red         63
# 654    Red         65
# 655    Red         70
# 656    Red         60
# 657    Red         56
#
# [658 rows x 2 columns]
#
#
# Data from 'N10_1.csv':
#       Color  Intensity
# 0     White        407
# 1     White        405
# 2     White        410
# 3     White        407
# 4     White        408
# ...     ...        ...
# 1409   Blue        273
# 1410   Blue        277
# 1411   Blue        275
# 1412   Blue        277
# 1413   Blue        272
#
# [1414 rows x 2 columns]
#
#
# Data from 'N1000_4.csv':
#       Color  Intensity
# 0     White         39
# 1     White         42
# 2     White         44
# 3     White         39
# 4     White         42
# ...     ...        ...
# 1289   Blue         51
# 1290   Blue         47
# 1291   Blue         48
# 1292   Blue         47
# 1293   Blue         50
#
# [1294 rows x 2 columns]
#
#
# Data from 'N10_3.csv':
#       Color  Intensity
# 0     White        461
# 1     White        464
# 2     White        465
# 3     White        458
# 4     White        458
# ...     ...        ...
# 1058   Blue        321
# 1059  White        742
# 1060  White        738
# 1061  White        732
# 1062  White        736
#
# [1063 rows x 2 columns]
#
#
# Data from 'N10_2.csv':
#       Color  Intensity
# 0     White        406
# 1     White        403
# 2     White        407
# 3     White        405
# 4     White        397
# ...     ...        ...
# 1245  White        663
# 1246  White        656
# 1247  White        669
# 1248  White        673
# 1249    Red        270
#
# [1250 rows x 2 columns]
#
#
# Data from 'N100_1.csv':
#       Color  Intensity
# 0     White         44
# 1     White         58
# 2     White         65
# 3     White         70
# 4     White         67
# ...     ...        ...
# 1212    Red        252
# 1213    Red        249
# 1214    Red        256
# 1215    Red        258
# 1216    Red        267
#
# [1217 rows x 2 columns]
#
#
# Data from 'N100_3.csv':
#      Color  Intensity
# 0    White         76
# 1    White         77
# 2    White         75
# 3    White         77
# 4    White         77
# ..     ...        ...
# 556    Red         19
# 557    Red         22
# 558    Red         19
# 559  Green         14
# 560  Green         12
#
# [561 rows x 2 columns]
#
#
# Data from 'N100_2.csv':
#    Color  Intensity
# 0  White        674
# 1  White        687
# 2  White        687
#
#
# Data from 'N100_4.csv':
#      Color  Intensity
# 0    White         94
# 1    White         94
# 2    White         94
# 3    White         93
# 4    White         97
# ..     ...        ...
# 657    Red         18
# 658    Red         18
# 659    Off          5
# 660  White         51
# 661  White         48
#
# [662 rows x 2 columns]
#
#
# All CSV files in the 'datasetCSV' folder have been displayed.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Loop through each CSV file and calculate the average intensity for each color
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Calculate the average intensity for each color
    color_intensity = df.groupby('Color')['Intensity'].mean()

    # Display the average intensity for each color
    print(f"Average Intensity for '{csv_file}':")
    print(color_intensity)
    print("\n")

print("Average intensities for each color in all CSV files have been displayed.")
# Out:
# Average Intensity for 'N1000_1.csv':
# Color
# Blue     125.575000
# Green     54.400000
# Off        4.727273
# Red       93.482906
# White    255.368421
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N1000_2.csv':
# Color
# Blue     192.266667
# Green    110.200000
# Off        5.500000
# Red      171.051724
# White    412.771930
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N1000_3.csv':
# Color
# Blue      79.418182
# Green     31.809091
# Off        5.600000
# Red       63.337900
# White    163.655502
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N10_1.csv':
# Color
# Blue     273.770213
# Green     47.425000
# Off        5.434783
# Red      147.468085
# White    449.778027
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N1000_4.csv':
# Color
# Blue     38.041860
# Green    14.072727
# Off       4.190476
# Red      19.348837
# White    62.519608
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N10_3.csv':
# Color
# Blue     291.072222
# Green     34.555556
# Off        4.941176
# Red      143.174286
# White    456.074405
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N10_2.csv':
# Color
# Blue     252.976190
# Green     39.585714
# Off        4.850000
# Red      128.002433
# White    405.290727
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N100_1.csv':
# Color
# Blue      71.255000
# Green     31.870000
# Off        4.350000
# Red       57.470588
# White    144.362468
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N100_3.csv':
# Color
# Blue     60.422222
# Green    13.260870
# Off       6.111111
# Red      20.115789
# White    82.133333
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N100_2.csv':
# Color
# White    682.666667
# Name: Intensity, dtype: float64
#
#
# Average Intensity for 'N100_4.csv':
# Color
# Blue     50.872727
# Green    13.572727
# Off       5.545455
# Red      19.359091
# White    73.052133
# Name: Intensity, dtype: float64
#
#
# Average intensities for each color in all CSV files have been displayed.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Loop through each CSV file and calculate the standard deviation of Intensity for each color
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Calculate the standard deviation of Intensity for each color
    color_std = df.groupby('Color')['Intensity'].std()

    # Display the standard deviation for each color
    print(f"Standard Deviation of Intensity for '{csv_file}':")
    print(color_std)
    print("\n")

print("Standard Deviations of Intensity for each color in all CSV files have been displayed.")
# Out:
# Standard Deviation of Intensity for 'N1000_1.csv':
# Color
# Blue     106.030015
# Green     57.437931
# Off        1.009050
# Red      102.436549
# White    255.103012
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N1000_2.csv':
# Color
# Blue     120.358354
# Green     60.028384
# Off        0.707107
# Red      127.409744
# White    307.885242
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N1000_3.csv':
# Color
# Blue     3.332855
# Green    2.316655
# Off      0.699206
# Red      5.270219
# White    9.820797
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N10_1.csv':
# Color
# Blue       3.200956
# Green     47.739384
# Off        0.945135
# Red       59.350626
# White    101.040709
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N1000_4.csv':
# Color
# Blue      8.522270
# Green     1.905096
# Off       0.679636
# Red       3.973008
# White    13.797041
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N10_3.csv':
# Color
# Blue      8.014673
# Green     1.691986
# Off       0.747545
# Red       2.855833
# White    31.246403
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N10_2.csv':
# Color
# Blue      8.253426
# Green    36.120410
# Off       0.587143
# Red      36.908423
# White    73.115663
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N100_1.csv':
# Color
# Blue      88.070666
# Green     44.994172
# Off        0.489360
# Red       85.180162
# White    206.637188
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N100_3.csv':
# Color
# Blue     4.102555
# Green    1.316585
# Off      1.166667
# Red      1.428087
# White    4.959501
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N100_2.csv':
# Color
# White    7.505553
# Name: Intensity, dtype: float64
#
#
# Standard Deviation of Intensity for 'N100_4.csv':
# Color
# Blue     13.385676
# Green     1.137026
# Off       0.934199
# Red       1.602840
# White    14.327201
# Name: Intensity, dtype: float64
#
#
# Standard Deviations of Intensity for each color in all CSV files have been displayed.

# %% [markdown]
# # บันทึกไฟล์  โดยให้จำนวนลูปอยู่ในแนวนอน ของแต่ละไฟล์ MSD_.   ในโฟลเดอร์ datasetCSV

# %% [markdown]
# แสดงผลแบบ จำนวนลูปอยู่ในแนวนอน ของแต่ละไฟล์ MSD_.   ในโฟลเดอร์ datasetCSV

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    grouped_df = pd.read_csv(original_file_path)

    # Create a pivot table with 'Order' as columns and 'Color' as index
    pivot_df = grouped_df.pivot_table(values='Intensity', index='Color')

    # Print the pivot table
    print(f"Pivot Table for {csv_file}:")
    print(pivot_df)
    print("\n")

# %% [markdown]
# บันทึกข้อมูลแต่ละไฟล์ โดยใช้ชื่อเดิมในโฟล์เดอร์เดิม

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    grouped_df = pd.read_csv(original_file_path)

    # Create a pivot table with 'Order' as columns and 'Color' as index
    pivot_df = grouped_df.pivot_table(values='Intensity', index='Color', aggfunc='mean')

    # Calculate the standard deviation for each row (Color)
    std_deviation = pivot_df.apply(lambda row: row.std(), axis=1)

    # Add the mean and standard deviation columns to the pivot table
    pivot_df['Mean'] = pivot_df.mean(axis=1)
    pivot_df['Std Deviation'] = std_deviation

    # Print the pivot table
    print(f"Pivot Table for {csv_file}:")
    print(pivot_df)
    print("\n")

    # Save the pivot table to a CSV file with the same name in the same folder
    output_file_path = os.path.join(folder_path, csv_file)
    pivot_df.to_csv(output_file_path, index=True)

# %% [markdown]
# แสดงค่าเฉลี่ย และส่วนเบี่ยงเบนมาตรฐานของแต่ละไฟล์

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    if "MSD_P" in csv_file:
        # Construct the full file path
        original_file_path = os.path.join(folder_path, csv_file)

        # Read the CSV file into a DataFrame
        grouped_df = pd.read_csv(original_file_path)

        # Create a pivot table with 'Order' as columns and 'Color' as index
        pivot_df = grouped_df.pivot_table(values='Mean', index='Color', aggfunc='mean')

        # Calculate the standard deviation for each row (Color)
        std_deviation = pivot_df.apply(lambda row: row.std(), axis=1)

        # Add the mean and standard deviation columns to the pivot table
        pivot_df['Mean'] = pivot_df.mean(axis=1)
        pivot_df['Std Deviation'] = std_deviation

        # Print the 'Mean' column for 'MSD_P' files
        print(f"Mean for {csv_file} (MSD_P):")
        print(pivot_df['Mean'])
        print("\n")
# Out:
# Mean for MSD_P100_No_Re.csv (MSD_P):
# Color
# Black      6.232051
# Blue     332.528571
# Green    197.898095
# Red      340.324762
# White    822.060714
# Name: Mean, dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '3.8826210826210814 P3' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 19
#      16 grouped_df = pd.read_csv(original_file_path)
#      18 # Create a pivot table with 'Order' as columns and 'Color' as index
# ---> 19 pivot_df = grouped_df.pivot_table(values='Mean', index='Color', aggfunc='mean')
#      21 # Calculate the standard deviation for each row (Color)
#      22 std_deviation = pivot_df.apply(lambda row: row.std(), axis=1)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:9193, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9176 @Substitution("")
#    9177 @Appender(_shared_docs["pivot_table"])
#    9178 def pivot_table(
#    (...)
#    9189     sort: bool = True,
#    9190 ) -> DataFrame:
#    9191     from pandas.core.reshape.pivot import pivot_table
# -> 9193     return pivot_table(
#    9194         self,
#    9195         values=values,
#    9196         index=index,
#    9197         columns=columns,
#    9198         aggfunc=aggfunc,
#    9199         fill_value=fill_value,
#    9200         margins=margins,
#    9201         dropna=dropna,
#    9202         margins_name=margins_name,
#    9203         observed=observed,
#    9204         sort=sort,
#    9205     )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:99, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      96     table = concat(pieces, keys=keys, axis=1)
#      97     return table.__finalize__(data, method="pivot_table")
# ---> 99 table = __internal_pivot_table(
#     100     data,
#     101     values,
#     102     index,
#     103     columns,
#     104     aggfunc,
#     105     fill_value,
#     106     margins,
#     107     dropna,
#     108     margins_name,
#     109     observed,
#     110     sort,
#     111 )
#     112 return table.__finalize__(data, method="pivot_table")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:169, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     166     values = list(values)
#     168 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
# --> 169 agged = grouped.agg(aggfunc)
#     171 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     172     agged = agged.dropna(how="all")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1442, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1439     kwargs["engine_kwargs"] = engine_kwargs
#    1441 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1442 result = op.agg()
#    1443 if not is_dict_like(func) and result is not None:
#    1444     # GH #52849
#    1445     if not self.as_index and is_list_like(func):
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:172, in Apply.agg(self)
#     169 kwargs = self.kwargs
#     171 if isinstance(func, str):
# --> 172     return self.apply_str()
#     174 if is_dict_like(func):
#     175     return self.agg_dict_like()
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:586, in Apply.apply_str(self)
#     584         else:
#     585             self.kwargs["axis"] = self.axis
# --> 586 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:669, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     667 f = getattr(obj, func)
#     668 if callable(f):
# --> 669     return f(*args, **kwargs)
#     671 # people may aggregate on a non-callable attribute
#     672 # but don't let them think they can pass args to it
#     673 assert len(args) == 0
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# วนลูปเพื่ออ่านและแสดงข้อมูลจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลทุกคอลัมน์และแถว
    with pd.option_context('display.max_columns', None, 'display.max_rows', None):
        print(df)
    
    print("\n" + "="*80 + "\n")  # สร้างเส้นขั้นบรรทัด
# Out:
# ชื่อไฟล์: MSD_P100_No_Re.csv
#
#    Color           1           2           3           4           5  \
# 0  Black    6.538462    6.615385    5.846154    6.000000    6.076923
# 1   Blue  330.714286  332.571429  332.500000  333.285714  332.357143
# 2  Green  197.785714  197.857143  197.000000  198.071429  199.214286
# 3    Red  339.571429  339.285714  340.785714  338.571429  341.285714
# 4  White  822.857143  821.571429  821.785714  822.857143  821.428571
#
#             6           7           8           9          10          11  \
# 0    6.307692    6.615385    6.153846    6.692308    6.384615    6.230769
# 1  331.785714  333.714286  332.538462  333.538462  332.230769  333.615385
# 2  197.500000  197.000000  197.571429  198.071429  198.142857  196.500000
# 3  341.214286  340.000000  342.571429  340.000000  340.071429  340.214286
# 4  821.857143  822.428571  821.785714  822.357143  821.642857  821.642857
#
#            12          13          14       15        Mean  Std Deviation
# 0    6.076923    5.846154    5.846154    6.250    6.232051       0.290784
# 1  333.230769  332.769231  332.076923  331.000  332.528571       0.895865
# 2  198.000000  198.928571  198.428571  198.400  197.898095       0.722360
# 3  340.714286  340.571429  340.214286  339.800  340.324762       0.944286
# 4  821.642857  824.000000  822.428571  820.625  822.060714       0.793038
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_P3.csv
#
#    Color           1           2           3           4           5  \
# 0  Black    3.846154    4.153846    4.000000    3.923077    3.769231
# 1   Blue   39.285714   38.071429   38.642857   39.142857   39.461538
# 2  Green   68.428571   69.571429   68.428571   68.785714   69.142857
# 3    Red   77.928571   78.357143   77.428571   78.071429   78.071429
# 4  White  178.928571  180.071429  179.428571  178.714286  178.714286
#
#             6           7           8           9          10          11  \
# 0    3.846154    3.846154    3.923077    3.692308    3.923077    3.769231
# 1   38.923077   39.692308   39.461538   39.000000   39.692308   39.692308
# 2   68.714286   68.714286   68.785714   68.571429   68.285714   69.000000
# 3   77.500000   77.000000   77.857143   77.357143   78.428571   78.642857
# 4  179.500000  180.142857  177.785714  177.857143  178.785714  178.142857
#
#            12          13          14          15        Mean  Std Deviation
# 0    3.846154    4.000000    3.923077    3.777778    3.882621       0.115236
# 1   39.769231   38.846154   38.307692   37.777778   39.051119       0.627408
# 2   69.285714   69.071429   69.214286   69.600000   68.906667       0.406287
# 3   77.785714   77.214286   77.857143   77.900000   77.826667       0.462370
# 4  178.071429  178.142857  178.000000  173.000000  178.352381       1.667400
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_n1.csv
#
#    Color           1           2           3           4           5  \
# 0  Black    4.000000    4.000000    4.230769    3.692308    3.923077
# 1   Blue   29.785714   30.000000   30.214286   29.785714   29.571429
# 2  Green   59.071429   59.071429   59.285714   58.285714   59.785714
# 3    Red   64.571429   64.000000   64.285714   64.714286   63.857143
# 4  White  147.357143  145.785714  145.428571  146.214286  145.214286
#
#             6           7           8           9          10          11  \
# 0    4.000000    3.692308    4.230769    4.076923    4.000000    3.769231
# 1   29.285714   29.214286   29.714286   29.923077   29.846154   29.692308
# 2   58.928571   59.214286   58.357143   59.785714   58.857143   58.571429
# 3   63.214286   63.785714   63.714286   64.357143   63.642857   64.000000
# 4  147.071429  144.214286  144.714286  144.714286  144.500000  144.928571
#
#            12          13          14          15        Mean  Std Deviation
# 0    3.769231    3.923077    4.076923    4.000000    3.958974       0.169197
# 1   29.846154   28.846154   29.461538   29.333333   29.634676       0.352782
# 2   57.785714   59.571429   58.785714   59.888889   59.016402       0.605813
# 3   63.285714   62.571429   63.785714   64.750000   63.902381       0.594935
# 4  146.071429  146.285714  145.142857  142.333333  145.331746       1.238830
#
# ================================================================================

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# วนลูปเพื่ออ่านและแสดงข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    print("\n" + "="*80 + "\n")  # สร้างเส้นขั้นบรรทัด
# Out:
# ชื่อไฟล์: MSD_P100_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.232051       0.290784
# 1   Blue  332.528571       0.895865
# 2  Green  197.898095       0.722360
# 3    Red  340.324762       0.944286
# 4  White  822.060714       0.793038
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_P3.csv
#
#    Color                   Mean  Std Deviation
# 0  Black  3.8826210826210814 P3       0.115236
# 1   Blue   39.05111925111925 P3       0.627408
# 2  Green   68.90666666666668 P3       0.406287
# 3    Red   77.82666666666667 P3       0.462370
# 4  White  178.35238095238094 P3       1.667400
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_O7.csv
#
#    Color                   Mean  Std Deviation
# 0  Black   4.546249999999999 O7       0.119031
# 1   Blue   56.53470588235293 O7       0.503925
# 2  Green            89.62875 O7       0.325643
# 3    Red  106.60416666666666 O7       0.605372
# 4  White  242.27809523809523 O7       0.648020
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.142949       0.187257
# 1   Blue  337.601384       0.651231
# 2  Green  201.241667       0.530882
# 3    Red  343.805820       0.708358
# 4  White  836.221429       0.984408
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.212179       0.224752
# 1   Blue  325.516117       0.896150
# 2  Green  189.328571       0.549848
# 3    Red  321.641799       1.126628
# 4  White  793.738095       1.128955
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_n1.csv
#
#    Color                   Mean  Std Deviation
# 0  Black  3.9589743589743582 n1       0.169197
# 1   Blue   29.63467643467644 n1       0.352782
# 2  Green  59.016402116402126 n1       0.605813
# 3    Red   63.90238095238096 n1       0.594935
# 4  White  145.33174603174604 n1       1.238830
#
# ================================================================================

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้างรายการเปล่าที่จะเก็บข้อมูล
result_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    # เพิ่มข้อมูลลงในรายการ result_data
    result_data.append(selected_columns)

    print("\n" + "="*80 + "\n")

# รวมข้อมูลจากทุกไฟล์ CSV เป็น DataFrame เดียว
combined_data = pd.concat(result_data, axis=1)

# แสดงผลรายการ combined_data
print(combined_data)
# Out:
# ชื่อไฟล์: MSD_P100_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.232051       0.290784
# 1   Blue  332.528571       0.895865
# 2  Green  197.898095       0.722360
# 3    Red  340.324762       0.944286
# 4  White  822.060714       0.793038
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_P3.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.882621       0.115236
# 1   Blue   39.051119       0.627408
# 2  Green   68.906667       0.406287
# 3    Red   77.826667       0.462370
# 4  White  178.352381       1.667400
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_O7.csv
#
#    Color        Mean  Std Deviation
# 0  Black    4.546250       0.119031
# 1   Blue   56.534706       0.503925
# 2  Green   89.628750       0.325643
# 3    Red  106.604167       0.605372
# 4  White  242.278095       0.648020
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.142949       0.187257
# 1   Blue  337.601384       0.651231
# 2  Green  201.241667       0.530882
# 3    Red  343.805820       0.708358
# 4  White  836.221429       0.984408
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.212179       0.224752
# 1   Blue  325.516117       0.896150
# 2  Green  189.328571       0.549848
# 3    Red  321.641799       1.126628
# 4  White  793.738095       1.128955
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_n1.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.958974       0.169197
# 1   Blue   29.634676       0.352782
# 2  Green   59.016402       0.605813
# 3    Red   63.902381       0.594935
# 4  White  145.331746       1.238830
#
# ================================================================================
#
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    6.232051       0.290784  Black    3.882621       0.115236  Black
# 1   Blue  332.528571       0.895865   Blue   39.051119       0.627408   Blue
# 2  Green  197.898095       0.722360  Green   68.906667       0.406287  Green
# 3    Red  340.324762       0.944286    Red   77.826667       0.462370    Red
# 4  White  822.060714       0.793038  White  178.352381       1.667400  White
#
#          Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0    4.546250       0.119031  Black    5.142949       0.187257  Black
# 1   56.534706       0.503925   Blue  337.601384       0.651231   Blue
# 2   89.628750       0.325643  Green  201.241667       0.530882  Green
# 3  106.604167       0.605372    Red  343.805820       0.708358    Red
# 4  242.278095       0.648020  White  836.221429       0.984408  White
#
#          Mean  Std Deviation  Color        Mean  Std Deviation
# 0    5.212179       0.224752  Black    3.958974       0.169197
# 1  325.516117       0.896150   Blue   29.634676       0.352782
# 2  189.328571       0.549848  Green   59.016402       0.605813
# 3  321.641799       1.126628    Red   63.902381       0.594935
# 4  793.738095       1.128955  White  145.331746       1.238830

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ที่มีคำว่า "MSD" และ "No_Re" ในชื่อไฟล์
csv_files = [f for f in os.listdir(folder_path) if 'MSD' in f and 'No_Re' in f and f.endswith('.csv')]

# สร้างรายการเปล่าที่จะเก็บข้อมูล
result_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    # เพิ่มข้อมูลลงในรายการ result_data
    result_data.append(selected_columns)

    print("\n" + "="*80 + "\n")

# รวมข้อมูลจากทุกไฟล์ CSV เป็น DataFrame เดียว
combined_data = pd.concat(result_data, axis=1)

# แสดงผลรายการ combined_data
print(combined_data)
# Out:
# ชื่อไฟล์: MSD_P100_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.232051       0.290784
# 1   Blue  332.528571       0.895865
# 2  Green  197.898095       0.722360
# 3    Red  340.324762       0.944286
# 4  White  822.060714       0.793038
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.142949       0.187257
# 1   Blue  337.601384       0.651231
# 2  Green  201.241667       0.530882
# 3    Red  343.805820       0.708358
# 4  White  836.221429       0.984408
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.212179       0.224752
# 1   Blue  325.516117       0.896150
# 2  Green  189.328571       0.549848
# 3    Red  321.641799       1.126628
# 4  White  793.738095       1.128955
#
# ================================================================================
#
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    6.232051       0.290784  Black    5.142949       0.187257  Black
# 1   Blue  332.528571       0.895865   Blue  337.601384       0.651231   Blue
# 2  Green  197.898095       0.722360  Green  201.241667       0.530882  Green
# 3    Red  340.324762       0.944286    Red  343.805820       0.708358    Red
# 4  White  822.060714       0.793038  White  836.221429       0.984408  White
#
#          Mean  Std Deviation
# 0    5.212179       0.224752
# 1  325.516117       0.896150
# 2  189.328571       0.549848
# 3  321.641799       1.126628
# 4  793.738095       1.128955

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้างรายการของ DataFrame ที่จะรวมข้อมูล
dataframes_to_concat = []

# วนลูปเพื่ออ่านและรวมข้อมูลจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เลือกข้อมูลเฉพาะคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่ม DataFrame ที่ได้สร้างลงในรายการ
    dataframes_to_concat.append(selected_columns)

# รวมข้อมูลในรายการ DataFrame โดยใช้ pd.concat()
all_data = pd.concat(dataframes_to_concat, ignore_index=True)

# บันทึก DataFrame ที่รวมข้อมูลลงในไฟล์ "AllMSD.csv"
output_file_path = os.path.join(folder_path, 'AllMSD.csv')
all_data.to_csv(output_file_path, index=False)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ที่มีคำว่า "MSD" และ "No_Re" ในชื่อไฟล์
csv_files = [f for f in os.listdir(folder_path) if 'MSD' in f and 'No_Re' in f and f.endswith('.csv')]

# เรียงลำดับชื่อไฟล์
csv_files.sort()

# สร้างรายการเปล่าที่จะเก็บข้อมูล
result_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    # เพิ่มข้อมูลลงในรายการ result_data
    result_data.append(selected_columns)

    print("\n" + "="*80 + "\n")

# รวมข้อมูลจากทุกไฟล์ CSV เป็น DataFrame เดียว
combined_data = pd.concat(result_data, axis=1)

# แสดงผลรายการ combined_data
print(combined_data)
# Out:
# ชื่อไฟล์: MSD_P1000_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.142949       0.187257
# 1   Blue  337.601384       0.651231
# 2  Green  201.241667       0.530882
# 3    Red  343.805820       0.708358
# 4  White  836.221429       0.984408
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.232051       0.290784
# 1   Blue  332.528571       0.895865
# 2  Green  197.898095       0.722360
# 3    Red  340.324762       0.944286
# 4  White  822.060714       0.793038
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_No_Re.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.212179       0.224752
# 1   Blue  325.516117       0.896150
# 2  Green  189.328571       0.549848
# 3    Red  321.641799       1.126628
# 4  White  793.738095       1.128955
#
# ================================================================================
#
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    5.142949       0.187257  Black    6.232051       0.290784  Black
# 1   Blue  337.601384       0.651231   Blue  332.528571       0.895865   Blue
# 2  Green  201.241667       0.530882  Green  197.898095       0.722360  Green
# 3    Red  343.805820       0.708358    Red  340.324762       0.944286    Red
# 4  White  836.221429       0.984408  White  822.060714       0.793038  White
#
#          Mean  Std Deviation
# 0    5.212179       0.224752
# 1  325.516117       0.896150
# 2  189.328571       0.549848
# 3  321.641799       1.126628
# 4  793.738095       1.128955

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ที่มีคำว่า "MSD_P" ในชื่อไฟล์ และไม่มี "No_Re"
csv_files = [f for f in os.listdir(folder_path) if 'MSD_P' in f and 'No_Re' not in f and f.endswith('.csv')]

# เรียงลำดับชื่อไฟล์
csv_files.sort()

# สร้างรายการเปล่าที่จะเก็บข้อมูล
result_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    # เพิ่มข้อมูลลงในรายการ result_data
    result_data.append(selected_columns)

    print("\n" + "="*80 + "\n")

# รวมข้อมูลจากทุกไฟล์ CSV เป็น DataFrame เดียว
combined_data = pd.concat(result_data, axis=1)

# แสดงผลรายการ combined_data
print(combined_data)
# Out:
# ชื่อไฟล์: MSD_P1000_n1.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.958974       0.169197
# 1   Blue   29.634676       0.352782
# 2  Green   59.016402       0.605813
# 3    Red   63.902381       0.594935
# 4  White  145.331746       1.238830
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_P3.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.882621       0.115236
# 1   Blue   39.051119       0.627408
# 2  Green   68.906667       0.406287
# 3    Red   77.826667       0.462370
# 4  White  178.352381       1.667400
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_O7.csv
#
#    Color        Mean  Std Deviation
# 0  Black    4.546250       0.119031
# 1   Blue   56.534706       0.503925
# 2  Green   89.628750       0.325643
# 3    Red  106.604167       0.605372
# 4  White  242.278095       0.648020
#
# ================================================================================
#
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    3.958974       0.169197  Black    3.882621       0.115236  Black
# 1   Blue   29.634676       0.352782   Blue   39.051119       0.627408   Blue
# 2  Green   59.016402       0.605813  Green   68.906667       0.406287  Green
# 3    Red   63.902381       0.594935    Red   77.826667       0.462370    Red
# 4  White  145.331746       1.238830  White  178.352381       1.667400  White
#
#          Mean  Std Deviation
# 0    4.546250       0.119031
# 1   56.534706       0.503925
# 2   89.628750       0.325643
# 3  106.604167       0.605372
# 4  242.278095       0.648020

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ที่มีคำว่า "MSD_P" ในชื่อไฟล์ และไม่มี "No_Re"
csv_files = [f for f in os.listdir(folder_path) if 'MSD_P' in f and 'No_Re' not in f and f.endswith('.csv')]

# เรียงลำดับชื่อไฟล์
csv_files.sort()

# สร้างรายการเปล่าที่จะเก็บข้อมูล
result_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    # เพิ่มข้อมูลลงในรายการ result_data
    result_data.append(selected_columns)

    print("\n" + "="*80 + "\n")

# รวมข้อมูลจากทุกไฟล์ CSV เป็น DataFrame เดียว
combined_data = pd.concat(result_data, axis=1)

# แสดงผลรายการ combined_data
print(combined_data)
# Out:
# ชื่อไฟล์: MSD_P1000_n1.csv
#
#    Color        Mean
# 0  Black    3.958974
# 1   Blue   29.634676
# 2  Green   59.016402
# 3    Red   63.902381
# 4  White  145.331746
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_P3.csv
#
#    Color        Mean
# 0  Black    3.882621
# 1   Blue   39.051119
# 2  Green   68.906667
# 3    Red   77.826667
# 4  White  178.352381
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_O7.csv
#
#    Color        Mean
# 0  Black    4.546250
# 1   Blue   56.534706
# 2  Green   89.628750
# 3    Red  106.604167
# 4  White  242.278095
#
# ================================================================================
#
#    Color        Mean  Color        Mean  Color        Mean
# 0  Black    3.958974  Black    3.882621  Black    4.546250
# 1   Blue   29.634676   Blue   39.051119   Blue   56.534706
# 2  Green   59.016402  Green   68.906667  Green   89.628750
# 3    Red   63.902381    Red   77.826667    Red  106.604167
# 4  White  145.331746  White  178.352381  White  242.278095
