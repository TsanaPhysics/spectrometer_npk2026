# %% [markdown]
# แสดงชื่อ ขนาดและจำนวนไฟล์  ".txt "ทั้งหมดในทุกโฟลเดอร์ย่อยของโฟลเดอร์  P พร้อมแสดงโฟเดอร์ย่อยที่จัดเก็บไฟล์

# %%
import os

def scan_txt_files(folder_path):
    for root, _, files in os.walk(folder_path):
        for file_name in files:
            if file_name.endswith(".txt"):
                file_path = os.path.join(root, file_name)
                print("-" * 50)
                # เปิดไฟล์ .txt เพื่ออ่านข้อมูล
                with open(file_path, "r", encoding="utf-8") as file:
                    lines = file.readlines()
                    
                    # แสดงข้อมูลที่คุณต้องการ
                    num_rows = len(lines)
                    num_columns = len(lines[0].split()) if num_rows > 0 else 0
                    header = lines[0].strip() if num_rows > 0 else None
                    
                    print(f"ไฟล์: {file_name}")
                    if header:
                        print(f"หัวเรื่อง: {header}")
                    print(f"จำนวนแถว: {num_rows}")
                    print(f"จำนวนคอลัมน์: {num_columns}")
                    print(f"ที่อยู่ของไฟล์: {file_path}")  # เพิ่มแถวนี้เพื่อแสดงที่อยู่ของไฟล์
                    print("\n")

# ระบุโฟลเดอร์หลักที่คุณต้องการสแกน
main_folder = "P"
scan_txt_files(main_folder)
# Out:
# --------------------------------------------------
# ไฟล์: P80_NoR.txt
# หัวเรื่อง: P_80_No_RKH2PO4  80mg/L tube  5ml  No Reagent :11/10/2023,12:21:18
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_80/P80_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: P80_W.txt
# หัวเรื่อง: P80_WPure water tube 5ml  new  No reagent :11/10/2023,17:31:00
# จำนวนแถว: 681
# จำนวนคอลัมน์: 8
# ที่อยู่ของไฟล์: P/P_80/P80_W.txt
#
#
# --------------------------------------------------
# ไฟล์: P80_WR.txt
# หัวเรื่อง: P80_WRPure water tube 5ml  Reagent 1ml. new :11/10/2023,17:38:43
# จำนวนแถว: 681
# จำนวนคอลัมน์: 8
# ที่อยู่ของไฟล์: P/P_80/P80_WR.txt
#
#
# --------------------------------------------------
# ไฟล์: P80_A.txt
# หัวเรื่อง: P80_BKH2PO4  80mg/L tube  5ml  P Reagent run No.2:11/10/2023,13:19:15
# จำนวนแถว: 681
# จำนวนคอลัมน์: 8
# ที่อยู่ของไฟล์: P/P_80/P80_A.txt
#
#
# --------------------------------------------------
# ไฟล์: P80_R.txt
# หัวเรื่อง: P_80_RKH2PO4  80mg/L tube  5ml  P Reagent :11/10/2023,12:30:34
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_80/P80_R.txt
#
#
# --------------------------------------------------
# ไฟล์: P80_blank.txt
# หัวเรื่อง: P_80_blankหลอดทดลองเปล่าสำหรับ  KH2PO4  80mg/L  Blank_Tube:11/10/2023,09:09:38
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/P_80/P80_blank.txt
#
#
# --------------------------------------------------
# ไฟล์: P20_NoR.txt
# หัวเรื่อง: P_20_No_RKH2PO4  20mg/L tube  5ml  No Reagent :11/10/2023,10:33:00
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_20/P20_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: P20_blank.txt
# หัวเรื่อง: P_20_blankหลอดทดลองเปล่าสำหรับ  KH2PO4  20mg/L  Blank_Tube:11/10/2023,08:44:22
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/P_20/P20_blank.txt
#
#
# --------------------------------------------------
# ไฟล์: P20_A.txt
# หัวเรื่อง: P20_BKH2PO4  20mg/L tube  5ml  P Reagent run No.2:11/10/2023,12:54:06
# จำนวนแถว: 681
# จำนวนคอลัมน์: 8
# ที่อยู่ของไฟล์: P/P_20/P20_A.txt
#
#
# --------------------------------------------------
# ไฟล์: P20_W.txt
# หัวเรื่อง: P20_WPure water tube 5ml   No reagent :11/10/2023,13:53:27
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_20/P20_W.txt
#
#
# --------------------------------------------------
# ไฟล์: P20_WR.txt
# หัวเรื่อง: P20_WRPure water tube 5ml  Reagent 1ml :11/10/2023,14:01:26
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_20/P20_WR.txt
#
#
# --------------------------------------------------
# ไฟล์: P20_R.txt
# หัวเรื่อง: P_20_RKH2PO4  20mg/L tube  5ml  P Reagent :11/10/2023,10:41:32
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_20/P20_R.txt
#
#
# --------------------------------------------------
# ไฟล์: P10_blank.txt
# หัวเรื่อง: P_10_blankหลอดทดลองเปล่าสำหรับ  KH2PO4  10mg/L  Blank_Tube:09/10/2023,11:14:29
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/P_10/P10_blank.txt
#
#
# --------------------------------------------------
# ไฟล์: P10_R.txt
# หัวเรื่อง: P_10KH2PO4  10mg/L tube  5ml  Reagent 1ml:09/10/2023,11:47:21
# จำนวนแถว: 681
# จำนวนคอลัมน์: 6
# ที่อยู่ของไฟล์: P/P
blankหลอดทดลองเปล่าสำหรับ  KH2PO4  60mg/L  Blank_Tube:11/10/2023,09:02:26
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/P_60/P60_blank.txt
#
#
# --------------------------------------------------
# ไฟล์: P60_R.txt
# หัวเรื่อง: P_60_RKH2PO4  60mg/L tube  5ml  P Reagent :11/10/2023,12:13:42
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_60/P60_R.txt
#
#
# --------------------------------------------------
# ไฟล์: P60_W.txt
# หัวเรื่อง: P60_WPure water tube 5ml   No reagent :11/10/2023,14:26:47
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_60/P60_W.txt
#
#
# --------------------------------------------------
# ไฟล์: P60_A.txt
# หัวเรื่อง: P60_BKH2PO4  60mg/L tube  5ml  P Reagent run No.2:11/10/2023,13:11:54
# จำนวนแถว: 681
# จำนวนคอลัมน์: 8
# ที่อยู่ของไฟล์: P/P_60/P60_A.txt
#
#
# --------------------------------------------------
# ไฟล์: P60_NoR.txt
# หัวเรื่อง: P_60_No_RKH2PO4  60mg/L tube  5ml  No Reagent :11/10/2023,12:05:00
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_60/P60_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: BG_1.txt
# หัวเรื่อง: BG_เครื่องเปล่า ไม่มีหลอดทดลอง ไม่มีฝาปิด :08/10/2023,15:13:31
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/BG/BG_1.txt
#
#
# --------------------------------------------------
# ไฟล์: BG_0.txt
# หัวเรื่อง: BG_เครื่องเปล่า ไม่มีหลอดทดลอง ไม่มีฝาปิด :08/10/2023,15:06:09
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/BG/BG_0.txt
#
#
# --------------------------------------------------
# ไฟล์: BG_rbru0.txt
# หัวเรื่อง: BG_rbruAIR:11/10/2023,08:26:45
# จำนวนแถว: 681
# จำนวนคอลัมน์: 1
# ที่อยู่ของไฟล์: P/BG/BG_rbru0.txt
#
#
# --------------------------------------------------
# ไฟล์: BG_rbru1.txt
# หัวเรื่อง: BG_rbruAIR:11/10/2023,08:36:41
# จำนวนแถว: 681
# จำนวนคอลัมน์: 1
# ที่อยู่ของไฟล์: P/BG/BG_rbru1.txt
#
#
# --------------------------------------------------
# ไฟล์: P40_blank.txt
# หัวเรื่อง: P_40_blankหลอดทดลองเปล่าสำหรับ  KH2PO4  40mg/L  Blank_Tube:11/10/2023,08:54:16
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/P_40/P40_blank.txt
#
#
# --------------------------------------------------
# ไฟล์: P40_NoR.txt
# หัวเรื่อง: P_40_No_RKH2PO4  40mg/L tube  5ml  No Reagent :11/10/2023,10:48:39
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_40/P40_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: P40_WR.txt
# หัวเรื่อง: P40_WRPure water tube 5ml  Reagent 1ml :11/10/2023,14:18:44
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_40/P40_WR.txt
#
#
# --------------------------------------------------
# ไฟล์: P40_W.txt
# หัวเรื่อง: P40_WPure water tube 5ml   No reagent :11/10/2023,14:10:43
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_40/P40_W.txt
#
#
# --------------------------------------------------
# ไฟล์: P40_A.txt
# หัวเรื่อง: P40_BKH2PO4  40mg/L tube  5ml  P Reagent run No.2:11/10/2023,13:03:36
# จำนวนแถว: 681
# จำนวนคอลัมน์: 8
# ที่อยู่ของไฟล์: P/P_40/P40_A.txt
#
#
# --------------------------------------------------
# ไฟล์: P40_R.txt
# หัวเรื่อง: P_40_RKH2PO4  40mg/L tube  5ml  P Reagent :11/10/2023,10:57:14
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_40/P40_R.txt
#
#
# --------------------------------------------------
# ไฟล์: P2_WR.txt
# หัวเรื่อง: P_2_Water_RPure water tube 5ml  Reagent 1ml :09/10/2023,07:50:47
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_2/P2_WR.txt
#
#
# --------------------------------------------------
# ไฟล์: P2_W.txt
# หัวเรื่อง: P_2_WaterPure water tube 5ml   No reagent :09/10/2023,07:42:28
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_2/P2_W.txt
#
#
# --------------------------------------------------
# ไฟล์: P2_A.txt
# หัวเรื่อง: P_2_AKH2PO4  2mg/L tube  5ml  Reagent 1ml:09/10/2023,11:57:00
# จำนวนแถว: 681
# จำนวนคอลัมน์: 6
# ที่อยู่ของไฟล์: P/P_2/P2_A.txt
#
#
# --------------------------------------------------
# ไฟล์: P2_B.txt
# หัวเรื่อง: P_2_BKH2PO4  2mg/L tube  5ml  Reagent 1ml:09/10/2023,16:09:05
# จำนวนแถว: 505
# จำนวนคอลัมน์: 6
# ที่อยู่ของไฟล์: P/P_2/P2_B.txt
#
#
# --------------------------------------------------
# ไฟล์: P2_blank.txt
# หัวเรื่อง: P_2_blankหลอดทดลองเปล่าสำหรับ  KH2PO4  2mg/L  Blank_Tube:09/10/2023,07:33:07
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/P_2/P2_blank.txt
#
#
# --------------------------------------------------
# ไฟล์: P2_NoR.txt
# หัวเรื่อง: P_2_No_RKH2PO4  2mg/L tube  5ml  No Reagent :09/10/2023,07:59:07
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_2/P2_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: P2_R.txt
# หัวเรื่อง: P_2_BKH2PO4  2mg/L tube  5ml  Reagent 1ml:09/10/2023,08:07:21
# จำนวนแถว: 681
# จำนวนคอลัมน์: 6
# ที่อยู่ของไฟล์: P/P_2/P2_R.txt
#
#
# --------------------------------------------------
# ไฟล์: P4_NoR.txt
# หัวเรื่อง: P_4_No_RKH2PO4  4mg/L tube  5ml  No Reagent :09/10/2023,08:41:45
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_4/P4_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: P4_WR.txt
# หัวเรื่อง: P_4_Water_RPure water tube 5ml  Reagent 1ml :09/10/2023,08:33:52
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_4/P4_WR.txt
#
#
# --------------------------------------------------
# ไฟล์: P4_blank.txt
# หัวเรื่อง: P_4_blankหลอดทดลองเปล่าสำหรับ  KH2PO4  4mg/L  Blank_Tube:09/10/2023,08:14:50
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/P_4/P4_blank.txt
#
#
# --------------------------------------------------
# ไฟล์: P4_R.txt
# หัวเรื่อง: P_4KH2PO4  4mg/L tube  5ml  Reagent 1ml:09/10/2023,08:52:05
# จำนวนแถว: 681
# จำนวนคอลัมน์: 6
# ที่อยู่ของไฟล์: P/P_4/P4_R.txt
#
#
# --------------------------------------------------
# ไฟล์: P4_W.txt
# หัวเรื่อง: P_4_WaterPure water tube 5ml   No reagent :09/10/2023,08:26:09
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_4/P4_W.txt
#
#
# --------------------------------------------------
# ไฟล์: P4_A.txt
# หัวเรื่อง: P_4_AKH2PO4  4mg/L tube  5ml  Reagent 1ml:09/10/2023,12:04:19
# จำนวนแถว: 681
# จำนวนคอลัมน์: 6
# ที่อยู่ของไฟล์: P/P_4/P4_A.txt
#
#
# --------------------------------------------------
# ไฟล์: P4_B.txt
# หัวเรื่อง: P_4_BKH2PO4  4mg/L tube  5ml  Reagent 1ml:09/10/2023,16:14:25
# จำนวนแถว: 681
# จำนวนคอลัมน์: 6
# ที่อยู่ของไฟล์: P/P_4/P4_B.txt
#
#
# --------------------------------------------------
# ไฟล์: P100_A.txt
# หัวเรื่อง: P100_BKH2PO4  100mg/L tube  5ml  P Reagent run No.2:11/10/2023,13:26:35
# จำนวนแถว: 681
# จำนวนคอลัมน์: 8
# ที่อยู่ของไฟล์: P/P_100/P100_A.txt
#
#
# --------------------------------------------------
# ไฟล์: P100_W.txt
# หัวเรื่อง: P100_WPure water tube 5ml  new  No reagent :11/10/2023,17:16:04
# จำนวนแถว: 681
# จำนวนคอลัมน์: 8
# ที่อยู่ของไฟล์: P/P_100/P100_W.txt
#
#
# --------------------------------------------------
# ไฟล์: P100_R.txt
# หัวเรื่อง: P_100_RKH2PO4  100mg/L tube  5ml  P Reagent :11/10/2023,12:46:38
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_100/P100_R.txt
#
#
# --------------------------------------------------
# ไฟล์: P100_NoR.txt
# หัวเรื่อง: P_100_No_RKH2PO4  100mg/L tube  5ml  No Reagent :11/10/2023,12:37:46
# จำนวนแถว: 681
# จำนวนคอลัมน์: 7
# ที่อยู่ของไฟล์: P/P_100/P100_NoR.txt
#
#
# --------------------------------------------------
# ไฟล์: P100_blank.txt
# หัวเรื่อง: P_100_blankหลอดทดลองเปล่าสำหรับ  KH2PO4  100mg/L  Blank_Tube:11/10/2023,09:16:55
# จำนวนแถว: 681
# จำนวนคอลัมน์: 4
# ที่อยู่ของไฟล์: P/P_100/P100_blank.txt
#
#
# --------------------------------------------------
# ไฟล์: P100_WR.txt
# หัวเรื่อง: P100_WRPure water tube 5ml  Reagent 1ml. new :11/10/2023,17:23:38
# จำนวนแถว: 681
# จำนวนคอลัมน์: 8
# ที่อยู่ของไฟล์: P/P_100/P100_WR.txt

# %%
import os

# ระบุโฟลเดอร์หลักที่คุณต้องการทำการสแกน (เช่น 'N')
main_folder = 'P'

# ฟังก์ชันสำหรับแสดงข้อมูลจากไฟล์ .txt และเพิ่มบรรทัดว่างหลังจากแต่ละไฟล์
def display_txt_file_contents(root, files):
    for file in files:
        if file.endswith(".txt"):
            file_path = os.path.join(root, file)
            print(f"ไฟล์: {file_path}")
            with open(file_path, 'r', encoding='utf-8') as txt_file:
                lines = txt_file.readlines()
                for line in lines:
                    print(line.strip())  # แสดงข้อมูลของแต่ละไลน์ในไฟล์
            print("\n" + "=" * 50 + "\n")  # เพิ่มบรรทัดว่างหลังจากแต่ละไฟล์

# เรียกใช้ฟังก์ชันเพื่อทำงาน
if os.path.exists(main_folder):
    for root, dirs, files in os.walk(main_folder):
        display_txt_file_contents(root, files)
else:
    print(f"โฟลเดอร์ '{main_folder}' ไม่พบ")
# Out:
# ไฟล์: P/P_80/P80_NoR.txt
# P_80_No_RKH2PO4  80mg/L tube  5ml  No Reagent :11/10/2023,12:21:18
# 1,1,White,6
# 2,2,White,912
# 3,3,White,902
# 4,4,White,908
# 5,5,White,909
# 6,6,White,902
# 7,7,White,914
# 8,8,White,917
# 9,9,White,923
# 10,10,White,915
# 11,11,White,913
# 12,12,White,906
# 13,13,White,915
# 14,14,White,918
# 15,15,White,917
# 16,16,White,907
# 17,17,White,908
# 18,18,White,913
# 19,19,White,919
# 20,20,White,903
# 21,21,White,919
# 22,22,White,920
# 23,23,White,905
# 24,24,White,908
# 25,25,White,912
# 26,26,White,916
# 27,27,White,920
# 28,28,White,910
# 29,29,White,910
# 30,1,Red,916
# 31,2,Red,322
# 32,3,Red,322
# 33,4,Red,322
# 34,5,Red,317
# 35,6,Red,321
# 36,7,Red,325
# 37,8,Red,315
# 38,9,Red,318
# 39,10,Red,319
# 40,11,Red,313
# 41,12,Red,325
# 42,13,Red,325
# 43,14,Red,326
# 44,15,Red,317
# 45,16,Red,318
# 46,17,Red,326
# 47,18,Red,321
# 48,19,Red,326
# 49,20,Red,324
# 50,21,Red,321
# 51,22,Red,323
# 52,23,Red,322
# 53,24,Red,319
# 54,25,Red,323
# 55,26,Red,318
# 56,27,Red,322
# 57,28,Red,322
# 58,29,Red,321
# 59,1,Green,323
# 60,2,Green,382
# 61,3,Green,391
# 62,4,Green,391
# 63,5,Green,383
# 64,6,Green,390
# 65,7,Green,391
# 66,8,Green,387
# 67,9,Green,388
# 68,10,Green,393
# 69,11,Green,394
# 70,12,Green,393
# 71,13,Green,391
# 72,14,Green,395
# 73,15,Green,392
# 74,16,Green,390
# 75,17,Green,390
# 76,18,Green,398
# 77,19,Green,391
# 78,20,Green,397
# 79,21,Green,393
# 80,22,Green,393
# 81,23,Green,397
# 82,24,Green,393
# 83,25,Green,396
# 84,26,Green,383
# 85,27,Green,390
# 86,28,Green,387
# 87,29,Green,392
# 88,30,Green,395
# 89,1,Blue,388
# 90,2,Blue,282
# 91,3,Blue,277
# 92,4,Blue,281
# 93,5,Blue,273
# 94,6,Blue,282
# 95,7,Blue,279
# 96,8,Blue,279
# 512,0,Black,6
# 513,0,Black,6
# 514,0,Black,6
# 515,0,Black,6
# 516,0,Black,6
# 517,0,Black,8
# 518,0,Black,7
# 519,0,Black,6
# 520,0,Black,6
# 521,0,Black,6
# 522,0,Black,5
# 523,0,Black,6
# 524,0,Black,6
# 525,0,Black,6
# 526,0,Black,5
# 527,1,White,7
# 528,2,White,921
# 529,3,White,921
# 530,4,White,922
# 531,5,White,921
# 532,6,White,919
# 533,7,White,925
# 534,8,White,923
# 535,9,White,930
# 536,10,White,920
# 537,11,White,921
# 538,12,White,914
# 539,13,White,923
# 540,14,White,926
# 541,15,White,918
# 542,16,White,923
# 543,17,White,916
# 544,18,White,923
# 545,19,White,920
# 546,20,White,914
# 547,21,White,919
# 548,22,White,920
# 549,23,White,917
# 550,24,White,925
# 551,25,White,919
# 552,26,White,918
# 553,27,White,925
# 554,28,White,922
# 555,29,White,924
# 556,1,Red,924
# 557,2,Red,317
# 558,3,Red,318
# 559,4,Red,322
# 560,5,Red,320
# 561,6,Red,319
# 562,7,Red,318
# 563,8,Red,318
# 564,9,Red,320
# 565,10,Red,321
# 566,11,Red,318
# 567,12,Red,316
# 568,13,Red,324
# 569,14,Red,317
# 570,15,Red,318
# 571,16,Red,321
# 572,17,Red,317
# 573,18,Red,318
# 574,19,Red,314
# 575,20,Red,324
# 576,21,Red,316
# 577,22,Red,320
# 578,23,Red,316
# 579,24,Red,318
# 580,25,Red,318
# 581,26,Red,322
# 582,27,Red,318
# 583,28,Red,315
# 584,29,Red,320
# 585,30,Red,322
# 586,1,Green,324
# 587,2,Green,396
# 588,3,Green,391
# 589,4,Green,396
# 590,5,Green,395
# 591,6,Green,394
# 592,7,Green,395
# 593,8,Green,392
# 594,9,Green,390
# 595,10,Green,396
# 596,11,Green,396
# 597,12,Green,396
# 598,13,Green,394
# 599,14,Green,390
# 600,15,Green,393
# 601,16,Green,393
# 602,17,Green,391
# 603,18,Green,393
# 604,19,Green,399
# 605,20,Green,390
# 606,21,Green,390
# 607,22,Green,390
# 608,23,Green,393
# 609,24,Green,391
# 610,25,Green,393
# 611,26,Green,392
# 612,27,Green,396
# 613,28,Green,390
# 614,29,Green,391
# 615,1,Blue,395
# 616,2,Blue,276
# 617,3,Blue,276
# 618,4,Blue,284
# 619,5,Blue,276
# 620,6,Blue,274
# 621,7,Blue,277
# 622,8,Blue,277
# 623,9,Blue,271
# 624,10,Blue,276
# 625,11,Blue,278
# 626,12,Blue,282
# 627,13,Blue,278
# 628,14,Blue,280
# 629,15,Blue,277
# 630,16,Blue,275
# 631,17,Blue,282
# 632,18,Blue,275
# 633,19,Blue,277
# 634,20,Blue,272
# 635,21,Blue,276
# 636,22,Blue,277
# 637,23,Blue,279
# 638,24,Blue,281
# 639,25,Blue,277
# 640,26,Blue,273
# 641,27,Blue,277
# 642,28,Blue,277
# 643,29,Blue,280
# 644,1,Black,276
# 645,2,Black,7
# 646,3,Black,5
# 647,4,Black,5
# 648,5,Black,6
# 649,6,Black,7
# 650,7,Black,6
# 651,8,Black,6
# 652,9,Black,7
# 653,10,Black,6
# 654,11,Black,7
# 655,12,Black,5
# 656,13,Black,7
# 657,14,Black,6
# 658,15,Black,6
# 659,16,Black,7
# 660,17,Black,8
# 661,18,Black,7
# 662,19,Black,6
# 663,20,Black,6
# 664,21,Black,6
# 665,22,Black,7
# 666,23,Black,5
# 667,24,Black,7
# 668,25,Black,6
# 669,26,Black,7
# 670,27,Black,7
# 671,28,Black,6
# 672,29,Black,6
# 673,0,Black,6
# 674,0,Black,5
# 675,0,Black,6
# 676,0,Black,7
# 677,0,Black,6
# 678,0,Black,5
# 679,0,Black,7
# 680,0,Black,8
#
# ==================================================
#
# ไฟล์: P/P_80/P80_W.txt
# P80_WPure water tube 5ml  new  No reagent :11/10/2023,17:31:00
# 1,1,White,8
# 2,2,White,964
# 3,3,White,966
# 4,4,White,960
# 5,5,White,965
# 6,6,White,963
# 7,7,White,964
# 8,8,White,963
# 9,9,White,965
# 10,10,White,960
# 11,11,White,962
# 12,12,White,955
# 13,13,White,966
# 14,14,White,966
# 15,15,White,963
# 16,16,White,960
# 17,17,White,965
# 18,18,White,963
# 19,19,White,962
# 20,20,White,964
# 21,21,White,962
# 22,22,White,957
# 23,23,White,962
# 24,24,White,962
# 25,25,White,963
# 26,26,White,960
# 27,27,White,961
# 28,28,White,962
# 29,29,White,964
# 30,30,White,967
# 31,1,Red,967
# 32,2,Red,350
# 33,3,Red,352
# 34,4,Red,359
# 35,5,Red,354
# 36,6,Red,355
# 37,7,Red,361
# 38,8,Red,355
# 39,9,Red,357
# 40,10,Red,351
# 41,11,Red,353
# 42,12,Red,358
# 43,13,Red,353
# 44,14,Red,351
# 45,15,Red,353
# 46,16,Red,355
# 47,17,Red,355
# 48,18,Red,353
# 49,19,Red,353
# 50,20,Red,355
# 51,21,Red,357
# 52,22,Red,351
# 53,23,Red,354
# 54,24,Red,353
# 55,25,Red,357
# 56,26,Red,357
# 57,27,Red,355
# 58,28,Red,354
# 59,29,Red,353
# 60,1,Green,354
# 61,2,Green,530
# 62,3,Green,536
# 63,4,Green,536
# 64,5,Green,532
# 65,6,Green,534
# 66,7,Green,536
# 67,8,Green,538
# 68,9,Green,535
# 69,10,Green,537
# 70,11,Green,539
# 71,12,Green,539
# 72,13,Green,537
# 73,14,Green,537
# 74,15,Green,529
# 75,16,Green,537
# 76,17,Green,537
# 77,18,Green,532
# 78,19,Green,537
# 79,20,Green,536
# 80,21,Green,533
# 81,22,Green,537
# 82,23,Green,533
# 83,24,Green,527
# 84,25,Green,539
# 85,26,Green,531
# 86,27,Green,537
# 87,28,Green,539
# 88,29,Green,537
# 89,30,Green,530
# 90,1,Blue,538
# 91,2,Blue,336
# 92,3,Blue,331
# 93,4,Blue,333
# 94,5,Blue,337
# 95,6,Blue,334
# 96,7,Blue,332
# 97,8,Blue,335
# 98,9,Blue,334
# 99,10,Blue,333
# 100,11,Blue,337
# 101,12,Blue,336
# 102,13,Blue,334
# 103,14,Blue,333
# 104,15,Blue,336
# 105,16,Blue,332
# 106,17,Blue,337
# 107,18,Blue,335
# 108,19,Blue,334
# 109,20,Blue,331
# 110,21,Blue,330
# 111,22,Blue,333
# 112,23,Blue,336
# 113,24,Blue,337
# 114,25,Blue,330
# 115,26,Blue,337
# 116,27,Blue,331
# 117,28,Blue,335
# 118,29,Blue,330
# 119,30,Blue,335
# 120,1,Black,329
# 121,2,Black,5
# 122,3,Black,5
# 123,4,Black,4
# 124,5,Black,6
# 125,6,Black,6
# 126,7,Black,6
# 127,8,Black,6
# 128,9,Black,7
# 129,10,Black,6
# 130,11,Black,5
# 131,12,Black,7
# 132,13,Black,6
# 133,14,Black,6
# 134,15,Black,7
# 135,16,Black,8
# 136,17,Black,8
# 137,18,Black,6
# 138,19,Black,5
# 139,20,Black,6
# 140,21,Black,6
# 141,22,Black,7
# 142,23,Black,7
# 143,24,Black,5
# 144,25,Black,5
# 145,26,Black,5
# 146,27,Black,5
# 147,28,Black,5
# 148,29,Black,6
# 149,30,Black,5
# 150,0,Black,5
# 151,0,Black,6
# 152,0,Black,6
# 153,0,Black,6
# 154,0,Black,4
# 155,0,Black,6
# 156,0,Black,6
# 157,0,Black,7
# 158,0,Black,8
# 159,0,Black,7
# 160,0,Black,6
# 161,0,Black,6
# 162,0,Black,6
# 163,0,Black,6
# 164,0,Black,6
# 165,0,Black,7
# 166,0,Black,6
# 167,0,Black,5
# 168,0,Black,5
# 169,0,Black,5
# 170,0,Black,5
# 171,0,Black,5
# 172,0,Black,5
# 173,0,Black,6
# 174,0,Black,6
# 175,0,Black,6
# 176,0,Black,6
# 177,0,Black,5
# 178,0,Black,5
# 179,0,Black,6
# 180,1,White,8
# 181,2,White,962
# 182,3,White,962
# 183,4,White,961
# 184,5,White,960
# 185,6,White,962
# 186,7,White,963
# 187,8,White,966
# 188,9,White,965
# 189,10,White,962
# 190,11,White,965
# 191,12,White,965
# 192,13,White,963
# 193,14,White,968
# 194,15,White,961
# 195,16,White,962
# 196,17,White,959
# 197,18,White,967
# 198,19,White,960
# 199,20,White,960
# 200,21,White,966
# 201,22,White,964
# 202,23,White,961
# 203,24,White,959
# 204,25,White,961
# 205,26,White,967
# 206,27,White,962
# 207,28,White,964
# 208,29,White,960
# 209,1,Red,965
# 210,2,Red,355
# 211,3,Red,354
# 212,4,Red,357
# 213,5,Red,358
# 214,6,Red,356
# 215,7,Red,358
# 216,8,Red,355
# 217,9,Red,354
# 218,10,Red,356
# 219,11,Red,350
# 220,12,Red,359
# 221,13,Red,362
# 222,14,Red,354
# 223,15,Red,359
# 224,16,Red,355
# 225,17,Red,358
# 226,18,Red,348
# 227,19,Red,353
# 228,20,Red,351
# 229,21,Red,351
# 230,22,Red,351
# 231,23,Red,356
# 232,24,Red,350
# 233,25,Red,355
# 234,26,Red,350
# 235,27,Red,358
# 236,28,Red,357
# 237,29,Red,359
# 238,30,Red,358
# 239,1,Green,355
# 240,2,Green,531
# 241,3,Green,534
# 242,4,Green,532
# 243,5,Green,526
# 244,6,Green,540
# 520,0,Black,6
# 521,0,Black,6
# 522,0,Black,7
# 523,0,Black,7
# 524,0,Black,6
# 525,0,Black,7
# 526,0,Black,8
# 527,0,Black,6
# 528,0,Black,7
# 529,0,Black,6
# 530,0,Black,6
# 531,0,Black,6
# 532,0,Black,6
# 533,0,Black,6
# 534,0,Black,5
# 535,0,Black,6
# 536,0,Black,7
# 537,1,White,5
# 538,2,White,963
# 539,3,White,963
# 540,4,White,960
# 541,5,White,960
# 542,6,White,961
# 543,7,White,967
# 544,8,White,960
# 545,9,White,963
# 546,10,White,961
# 547,11,White,961
# 548,12,White,961
# 549,13,White,966
# 550,14,White,964
# 551,15,White,964
# 552,16,White,963
# 553,17,White,964
# 554,18,White,967
# 555,19,White,965
# 556,20,White,961
# 557,21,White,963
# 558,22,White,961
# 559,23,White,967
# 560,24,White,961
# 561,25,White,961
# 562,26,White,961
# 563,27,White,963
# 564,28,White,965
# 565,29,White,962
# 566,30,White,962
# 567,1,Red,962
# 568,2,Red,353
# 569,3,Red,352
# 570,4,Red,354
# 571,5,Red,358
# 572,6,Red,353
# 573,7,Red,358
# 574,8,Red,355
# 575,9,Red,355
# 576,10,Red,356
# 577,11,Red,355
# 578,12,Red,347
# 579,13,Red,353
# 580,14,Red,350
# 581,15,Red,356
# 582,16,Red,355
# 583,17,Red,360
# 584,18,Red,354
# 585,19,Red,354
# 586,20,Red,359
# 587,21,Red,356
# 588,22,Red,358
# 589,23,Red,355
# 590,24,Red,359
# 591,25,Red,354
# 592,26,Red,352
# 593,27,Red,356
# 594,28,Red,359
# 595,29,Red,359
# 596,30,Red,354
# 597,1,Green,357
# 598,2,Green,536
# 599,3,Green,538
# 600,4,Green,534
# 601,5,Green,534
# 602,6,Green,536
# 603,7,Green,541
# 604,8,Green,532
# 605,9,Green,534
# 606,10,Green,537
# 607,11,Green,536
# 608,12,Green,538
# 609,13,Green,532
# 610,14,Green,530
# 611,15,Green,538
# 612,16,Green,537
# 613,17,Green,534
# 614,18,Green,538
# 615,19,Green,536
# 616,20,Green,539
# 617,21,Green,536
# 618,22,Green,534
# 619,23,Green,536
# 620,24,Green,541
# 621,25,Green,536
# 622,26,Green,529
# 623,27,Green,539
# 624,28,Green,538
# 625,29,Green,534
# 626,30,Green,537
# 627,1,Blue,536
# 628,2,Blue,333
# 629,3,Blue,328
# 630,4,Blue,332
# 631,5,Blue,336
# 632,6,Blue,335
# 633,7,Blue,331
# 634,8,Blue,338
# 635,9,Blue,329
# 636,10,Blue,333
# 637,11,Blue,331
# 638,12,Blue,331
# 639,13,Blue,332
# 640,14,Blue,331
# 641,15,Blue,333
# 642,16,Blue,333
# 643,17,Blue,333
# 644,18,Blue,334
# 645,19,Blue,333
# 646,20,Blue,337
# 647,21,Blue,336
# 648,22,Blue,338
# 649,23,Blue,334
# 650,24,Blue,331
# 651,25,Blue,330
# 652,26,Blue,336
# 653,27,Blue,336
# 654,28,Blue,336
# 655,29,Blue,332
# 656,30,Blue,335
# 657,1,Black,336
# 658,2,Black,7
# 659,3,Black,7
# 660,4,Black,6
# 661,5,Black,8
# 662,6,Black,8
# 663,7,Black,5
# 664,8,Black,6
# 665,9,Black,6
# 666,10,Black,6
# 667,11,Black,5
# 668,12,Black,7
# 669,13,Black,5
# 670,14,Black,5
# 671,15,Black,5
# 672,16,Black,5
# 673,17,Black,5
# 674,18,Black,5
# 675,19,Black,6
# 676,20,Black,5
# 677,21,Black,5
# 678,22,Black,5
# 679,23,Black,5
# 680,24,Black,5
#
# ==================================================
#
# ไฟล์: P/P_80/P80_WR.txt
# P80_WRPure water tube 5ml  Reagent 1ml. new :11/10/2023,17:38:43
# 1,1,White,4
# 2,2,White,953
# 3,3,White,956
# 4,4,White,955
# 5,5,White,954
# 6,6,White,950
# 7,7,White,950
# 8,8,White,952
# 9,9,White,949
# 10,10,White,955
# 11,11,White,957
# 12,12,White,950
# 13,13,White,956
# 14,14,White,951
# 15,15,White,955
# 16,16,White,950
# 17,17,White,956
# 18,18,White,949
# 19,19,White,950
# 20,20,White,948
# 21,21,White,953
# 22,22,White,954
# 23,23,White,956
# 24,24,White,949
# 25,25,White,952
# 26,26,White,949
# 27,27,White,949
# 28,28,White,950
# 29,29,White,951
# 30,30,White,951
# 31,1,Red,953
# 32,2,Red,318
# 33,3,Red,315
# 34,4,Red,311
# 35,5,Red,312
# 36,6,Red,315
# 37,7,Red,312
# 38,8,Red,307
# 39,9,Red,317
# 40,10,Red,311
# 41,11,Red,312
# 42,12,Red,314
# 43,13,Red,314
# 44,14,Red,311
# 45,15,Red,309
# 46,16,Red,308
# 47,17,Red,309
# 48,18,Red,308
# 49,19,Red,308
# 50,20,Red,305
# 51,21,Red,310
# 52,22,Red,310
# 53,23,Red,311
# 54,24,Red,309
# 55,25,Red,313
# 56,26,Red,311
# 57,27,Red,315
# 58,28,Red,309
# 59,29,Red,309
# 60,1,Green,308
# 61,2,Green,454
# 62,3,Green,457
# 63,4,Green,456
# 64,5,Green,450
# 65,6,Green,457
# 66,7,Green,457
# 67,8,Green,456
# 68,9,Green,455
# 69,10,Green,462
# 70,11,Green,456
# 71,12,Green,458
# 72,13,Green,458
# 73,14,Green,461
# 74,15,Green,452
# 75,16,Green,456
# 76,17,Green,451
# 77,18,Green,458
# 78,19,Green,457
# 79,20,Green,451
# 80,21,Green,459
# 81,22,Green,454
# 82,23,Green,457
# 83,24,Green,460
# 84,25,Green,459
# 85,26,Green,453
# 86,27,Green,455
# 87,28,Green,457
# 88,29,Green,461
# 89,30,Green,454
# 90,1,Blue,456
# 91,2,Blue,299
# 92,3,Blue,300
# 93,4,Blue,300
# 94,5,Blue,297
# 95,6,Blue,298
# 96,7,Blue,299
# 97,8,Blue,298
# 98,9,Blue,300
# 99,10,Blue,298
# 100,11,Blue,296
# 101,12,Blue,297
# 102,13,Blue,302
# 103,14,Blue,298
# 104,15,Blue,297
# 105,16,Blue,298
# 106,17,Blue,301
# 107,18,Blue,292
# 108,19,Blue,300
# 109,20,Blue,294
# 110,21,Blue,295
# 111,22,Blue,294
# 528,0,Black,5
# 529,0,Black,5
# 530,0,Black,4
# 531,0,Black,6
# 532,0,Black,7
# 533,0,Black,7
# 534,0,Black,7
# 535,0,Black,6
# 536,0,Black,5
# 537,1,White,5
# 538,2,White,945
# 539,3,White,950
# 540,4,White,948
# 541,5,White,946
# 542,6,White,946
# 543,7,White,952
# 544,8,White,946
# 545,9,White,946
# 546,10,White,941
# 547,11,White,947
# 548,12,White,947
# 549,13,White,945
# 550,14,White,952
# 551,15,White,948
# 552,16,White,948
# 553,17,White,948
# 554,18,White,946
# 555,19,White,951
# 556,20,White,947
# 557,21,White,946
# 558,22,White,946
# 559,23,White,947
# 560,24,White,949
# 561,25,White,946
# 562,26,White,945
# 563,27,White,951
# 564,28,White,947
# 565,29,White,945
# 566,30,White,950
# 567,1,Red,949
# 568,2,Red,300
# 569,3,Red,303
# 570,4,Red,303
# 571,5,Red,305
# 572,6,Red,309
# 573,7,Red,309
# 574,8,Red,310
# 575,9,Red,309
# 576,10,Red,301
# 577,11,Red,306
# 578,12,Red,308
# 579,13,Red,310
# 580,14,Red,305
# 581,15,Red,305
# 582,16,Red,301
# 583,17,Red,302
# 584,18,Red,305
# 585,19,Red,307
# 586,20,Red,304
# 587,21,Red,305
# 588,22,Red,306
# 589,23,Red,302
# 590,24,Red,303
# 591,25,Red,308
# 592,26,Red,310
# 593,27,Red,309
# 594,28,Red,307
# 595,29,Red,309
# 596,30,Red,301
# 597,1,Green,307
# 598,2,Green,451
# 599,3,Green,452
# 600,4,Green,450
# 601,5,Green,455
# 602,6,Green,453
# 603,7,Green,453
# 604,8,Green,443
# 605,9,Green,452
# 606,10,Green,450
# 607,11,Green,453
# 608,12,Green,449
# 609,13,Green,450
# 610,14,Green,450
# 611,15,Green,450
# 612,16,Green,449
# 613,17,Green,450
# 614,18,Green,453
# 615,19,Green,454
# 616,20,Green,448
# 617,21,Green,451
# 618,22,Green,454
# 619,23,Green,454
# 620,24,Green,451
# 621,25,Green,454
# 622,26,Green,454
# 623,27,Green,445
# 624,28,Green,447
# 625,29,Green,449
# 626,30,Green,456
# 627,1,Blue,451
# 628,2,Blue,296
# 629,3,Blue,299
# 630,4,Blue,296
# 631,5,Blue,301
# 632,6,Blue,293
# 633,7,Blue,300
# 634,8,Blue,296
# 635,9,Blue,297
# 636,10,Blue,291
# 637,11,Blue,295
# 638,12,Blue,298
# 639,13,Blue,299
# 640,14,Blue,296
# 641,15,Blue,291
# 642,16,Blue,301
# 643,17,Blue,298
# 644,18,Blue,300
# 645,19,Blue,293
# 646,20,Blue,298
# 647,21,Blue,294
# 648,22,Blue,297
# 649,23,Blue,295
# 650,24,Blue,297
# 651,25,Blue,292
# 652,26,Blue,299
# 653,27,Blue,295
# 654,28,Blue,300
# 655,29,Blue,297
# 656,30,Blue,296
# 657,1,Black,293
# 658,2,Black,6
# 659,3,Black,5
# 660,4,Black,5
# 661,5,Black,6
# 662,6,Black,7
# 663,7,Black,5
# 664,8,Black,5
# 665,9,Black,5
# 666,10,Black,4
# 667,11,Black,6
# 668,12,Black,7
# 669,13,Black,6
# 670,14,Black,7
# 671,15,Black,6
# 672,16,Black,6
# 673,17,Black,6
# 674,18,Black,6
# 675,19,Black,6
# 676,20,Black,5
# 677,21,Black,5
# 678,22,Black,6
# 679,23,Black,4
# 680,24,Black,5
#
# ==================================================
#
# ไฟล์: P/P_80/P80_A.txt
# P80_BKH2PO4  80mg/L tube  5ml  P Reagent run No.2:11/10/2023,13:19:15
# 1,1,White,5
# 2,2,White,128
# 3,3,White,127
# 4,4,White,132
# 5,5,White,134
# 6,6,White,129
# 7,7,White,129
# 8,8,White,126
# 9,9,White,130
# 10,10,White,132
# 11,11,White,132
# 12,12,White,133
# 13,13,White,127
# 14,14,White,132
# 15,15,White,135
# 16,16,White,129
# 17,17,White,133
# 18,18,White,133
# 19,19,White,135
# 20,20,White,134
# 21,21,White,131
# 22,22,White,130
# 23,23,White,130
# 24,24,White,135
# 25,25,White,131
# 26,26,White,136
# 27,27,White,131
# 28,28,White,135
# 29,29,White,130
# 30,1,Red,130
# 31,2,Red,23
# 32,3,Red,23
# 33,4,Red,26
# 34,5,Red,21
# 35,6,Red,22
# 36,7,Red,24
# 37,8,Red,22
# 38,9,Red,24
# 39,10,Red,24
# 40,11,Red,25
# 41,12,Red,25
# 42,13,Red,25
# 43,14,Red,22
# 44,15,Red,24
# 45,16,Red,23
# 46,17,Red,24
# 47,18,Red,22
# 48,19,Red,22
# 49,20,Red,23
# 50,21,Red,23
# 51,22,Red,25
# 52,23,Red,23
# 53,24,Red,23
# 54,25,Red,25
# 55,26,Red,22
# 56,27,Red,25
# 57,28,Red,23
# 58,29,Red,22
# 59,1,Green,26
# 60,2,Green,55
# 61,3,Green,50
# 62,4,Green,52
# 63,5,Green,51
# 64,6,Green,49
# 65,7,Green,49
# 66,8,Green,52
# 67,9,Green,51
# 68,10,Green,49
# 69,11,Green,49
# 70,12,Green,52
# 71,13,Green,53
# 72,14,Green,54
# 73,15,Green,54
# 74,16,Green,54
# 75,17,Green,48
# 76,18,Green,54
# 77,19,Green,55
# 78,20,Green,51
# 79,21,Green,49
# 80,22,Green,53
# 81,23,Green,50
# 82,24,Green,53
# 83,25,Green,49
# 84,26,Green,50
# 85,27,Green,49
# 86,28,Green,48
# 87,29,Green,49
# 88,30,Green,52
# 89,1,Blue,52
# 90,2,Blue,75
# 91,3,Blue,72
# 92,4,Blue,74
# 93,5,Blue,73
# 94,6,Blue,68
# 95,7,Blue,69
# 96,8,Blue,74
# 97,9,Blue,72
# 98,10,Blue,76
# 99,11,Blue,76
# 100,12,Blue,69
# 101,13,Blue,73
# 102,14,Blue,70
# 103,15,Blue,71
# 104,16,Blue,75
# 105,17,Blue,70
# 106,18,Blue,69
# 107,19,Blue,70
# 108,20,Blue,72
# 109,21,Blue,75
# 110,22,Blue,75
# 111,23,Blue,72
# 112,24,Blue,74
# 113,25,Blue,72
# 114,26,Blue,73
# 115,27,Blue,70
# 116,28,Blue,70
# 117,29,Blue,71
# 535,9,White,131
# 536,10,White,133
# 537,11,White,135
# 538,12,White,134
# 539,13,White,135
# 540,14,White,132
# 541,15,White,132
# 542,16,White,129
# 543,17,White,134
# 544,18,White,130
# 545,19,White,136
# 546,20,White,131
# 547,21,White,134
# 548,22,White,135
# 549,23,White,135
# 550,24,White,136
# 551,25,White,129
# 552,26,White,133
# 553,27,White,130
# 554,28,White,135
# 555,29,White,131
# 556,1,Red,132
# 557,2,Red,23
# 558,3,Red,22
# 559,4,Red,21
# 560,5,Red,21
# 561,6,Red,23
# 562,7,Red,21
# 563,8,Red,22
# 564,9,Red,23
# 565,10,Red,22
# 566,11,Red,20
# 567,12,Red,24
# 568,13,Red,25
# 569,14,Red,21
# 570,15,Red,22
# 571,16,Red,24
# 572,17,Red,22
# 573,18,Red,20
# 574,19,Red,24
# 575,20,Red,22
# 576,21,Red,21
# 577,22,Red,21
# 578,23,Red,24
# 579,24,Red,20
# 580,25,Red,22
# 581,26,Red,21
# 582,27,Red,24
# 583,28,Red,21
# 584,29,Red,23
# 585,30,Red,21
# 586,1,Green,23
# 587,2,Green,54
# 588,3,Green,52
# 589,4,Green,52
# 590,5,Green,53
# 591,6,Green,54
# 592,7,Green,55
# 593,8,Green,53
# 594,9,Green,54
# 595,10,Green,53
# 596,11,Green,53
# 597,12,Green,50
# 598,13,Green,51
# 599,14,Green,50
# 600,15,Green,51
# 601,16,Green,53
# 602,17,Green,50
# 603,18,Green,52
# 604,19,Green,50
# 605,20,Green,49
# 606,21,Green,52
# 607,22,Green,49
# 608,23,Green,49
# 609,24,Green,51
# 610,25,Green,50
# 611,26,Green,52
# 612,27,Green,50
# 613,28,Green,54
# 614,29,Green,50
# 615,1,Blue,50
# 616,2,Blue,71
# 617,3,Blue,74
# 618,4,Blue,71
# 619,5,Blue,69
# 620,6,Blue,73
# 621,7,Blue,71
# 622,8,Blue,69
# 623,9,Blue,67
# 624,10,Blue,73
# 625,11,Blue,67
# 626,12,Blue,70
# 627,13,Blue,70
# 628,14,Blue,71
# 629,15,Blue,67
# 630,16,Blue,69
# 631,17,Blue,70
# 632,18,Blue,68
# 633,19,Blue,67
# 634,20,Blue,72
# 635,21,Blue,72
# 636,22,Blue,74
# 637,23,Blue,66
# 638,24,Blue,73
# 639,25,Blue,67
# 640,26,Blue,73
# 641,27,Blue,71
# 642,28,Blue,66
# 643,29,Blue,69
# 644,1,Black,73
# 645,2,Black,5
# 646,3,Black,6
# 647,4,Black,6
# 648,5,Black,5
# 649,6,Black,5
# 650,7,Black,6
# 651,8,Black,6
# 652,9,Black,6
# 653,10,Black,6
# 654,11,Black,7
# 655,12,Black,6
# 656,13,Black,6
# 657,14,Black,6
# 658,15,Black,5
# 659,16,Black,6
# 660,17,Black,5
# 661,18,Black,5
# 662,19,Black,4
# 663,20,Black,6
# 664,21,Black,6
# 665,22,Black,5
# 666,23,Black,6
# 667,24,Black,8
# 668,25,Black,6
# 669,26,Black,4
# 670,27,Black,4
# 671,28,Black,5
# 672,29,Black,6
# 673,0,Black,4
# 674,0,Black,5
# 675,0,Black,6
# 676,0,Black,6
# 677,0,Black,5
# 678,0,Black,5
# 679,0,Black,5
# 680,0,Black,6
#
# ==================================================
#
# ไฟล์: P/P_80/P80_R.txt
# P_80_RKH2PO4  80mg/L tube  5ml  P Reagent :11/10/2023,12:30:34
# 1,1,White,7
# 2,2,White,285
# 3,3,White,292
# 4,4,White,283
# 5,5,White,283
# 6,6,White,289
# 7,7,White,287
# 8,8,White,284
# 9,9,White,284
# 10,10,White,276
# 11,11,White,273
# 12,12,White,272
# 13,13,White,276
# 14,14,White,272
# 15,15,White,277
# 16,16,White,272
# 17,17,White,272
# 18,18,White,278
# 19,19,White,273
# 20,20,White,270
# 21,21,White,270
# 22,22,White,267
# 23,23,White,266
# 24,24,White,267
# 25,25,White,272
# 26,26,White,267
# 27,27,White,269
# 28,28,White,268
# 29,29,White,264
# 30,1,Red,260
# 31,2,Red,47
# 32,3,Red,52
# 33,4,Red,55
# 34,5,Red,49
# 35,6,Red,50
# 36,7,Red,54
# 37,8,Red,51
# 38,9,Red,48
# 39,10,Red,52
# 40,11,Red,53
# 41,12,Red,54
# 42,13,Red,51
# 43,14,Red,50
# 44,15,Red,46
# 45,16,Red,48
# 46,17,Red,48
# 47,18,Red,49
# 48,19,Red,49
# 49,20,Red,46
# 50,21,Red,52
# 51,22,Red,48
# 52,23,Red,48
# 53,24,Red,48
# 54,25,Red,47
# 55,26,Red,49
# 56,27,Red,46
# 57,28,Red,53
# 58,29,Red,50
# 59,30,Red,49
# 60,1,Green,49
# 61,2,Green,113
# 62,3,Green,115
# 63,4,Green,106
# 64,5,Green,113
# 65,6,Green,107
# 66,7,Green,107
# 67,8,Green,105
# 68,9,Green,106
# 69,10,Green,108
# 70,11,Green,108
# 71,12,Green,107
# 72,13,Green,107
# 73,14,Green,105
# 74,15,Green,111
# 75,16,Green,111
# 76,17,Green,108
# 77,18,Green,108
# 78,19,Green,110
# 79,20,Green,104
# 80,21,Green,107
# 81,22,Green,112
# 82,23,Green,105
# 83,24,Green,106
# 84,25,Green,108
# 85,26,Green,111
# 86,27,Green,106
# 87,28,Green,106
# 88,29,Green,111
# 89,30,Green,107
# 90,1,Blue,106
# 91,2,Blue,110
# 92,3,Blue,108
# 93,4,Blue,108
# 94,5,Blue,107
# 95,6,Blue,105
# 96,7,Blue,112
# 97,8,Blue,107
# 98,9,Blue,105
# 99,10,Blue,112
# 100,11,Blue,106
# 101,12,Blue,106
# 102,13,Blue,108
# 103,14,Blue,105
# 104,15,Blue,108
# 105,16,Blue,109
# 106,17,Blue,108
# 107,18,Blue,107
# 108,19,Blue,106
# 109,20,Blue,106
# 110,21,Blue,106
# 111,22,Blue,107
# 112,23,Blue,110
# 113,24,Blue,108
# 114,25,Blue,105
# 115,26,Blue,106
# 116,27,Blue,105
# 117,28,Blue,109
# 118,29,Blue,104
# 119,1,Black,104
# 120,2,Black,5
# 121,3,Black,8
# 122,4,Black,7
# 123,5,Black,5
# 124,6,Black,6
# 125,7,Black,6
# 126,8,Black,7
# 127,9,Black,6
# 128,10,Black,8
# 129,11,Black,7
# 130,12,Black,5
# 131,13,Black,7
# 132,14,Black,5
# 133,15,Black,7
# 134,16,Black,6
# 135,17,Black,5
# 136,18,Black,8
# 137,19,Black,7
# 138,20,Black,7
# 139,21,Black,6
# 140,22,Black,6
# 141,23,Black,7
# 142,24,Black,7
# 143,25,Black,6
# 144,26,Black,5
# 145,27,Black,6
# 146,28,Black,7
# 147,29,Black,5
# 148,30,Black,5
# 149,0,Black,6
# 150,0,Black,6
# 151,0,Black,6
# 152,0,Black,6
# 153,0,Black,6
# 154,0,Black,8
# 155,0,Black,6
# 156,0,Black,6
# 157,0,Black,5
# 158,0,Black,6
# 159,0,Black,6
# 160,0,Black,6
# 161,0,Black,5
# 162,0,Black,5
# 163,0,Black,6
# 164,0,Black,5
# 165,0,Black,6
# 166,0,Black,7
# 167,0,Black,6
# 168,0,Black,7
# 169,0,Black,5
# 170,0,Black,7
# 171,0,Black,6
# 172,0,Black,5
# 173,0,Black,6
# 174,0,Black,5
# 175,0,Black,7
# 176,0,Black,7
# 177,0,Black,5
# 178,0,Black,6
# 179,1,White,5
# 180,2,White,238
# 181,3,White,234
# 182,4,White,239
# 183,5,White,234
# 184,6,White,239
# 185,7,White,230
# 186,8,White,231
# 187,9,White,234
# 188,10,White,230
# 189,11,White,234
# 190,12,White,232
# 191,13,White,236
# 192,14,White,237
# 193,15,White,230
# 194,16,White,228
# 195,17,White,233
# 196,18,White,231
# 197,19,White,233
# 198,20,White,237
# 199,21,White,235
# 200,22,White,234
# 201,23,White,234
# 202,24,White,233
# 203,25,White,234
# 204,26,White,230
# 205,27,White,231
# 206,28,White,233
# 207,29,White,230
# 208,1,Red,231
# 209,2,Red,42
# 210,3,Red,47
# 211,4,Red,43
# 212,5,Red,46
# 213,6,Red,41
# 214,7,Red,44
# 215,8,Red,46
# 216,9,Red,44
# 217,10,Red,42
# 218,11,Red,41
# 219,12,Red,42
# 220,13,Red,47
# 221,14,Red,44
# 222,15,Red,47
# 223,16,Red,43
# 224,17,Red,44
# 225,18,Red,47
# 226,19,Red,44
# 227,20,Red,42
# 228,21,Red,41
# 229,22,Red,45
# 230,23,Red,48
# 231,24,Red,44
# 232,25,Red,47
# 233,26,Red,42
# 234,27,Red,41
# 235,28,Red,44
# 236,29,Red,44
# 237,30,Red,41
# 238,1,Green,43
# 239,2,Green,96
# 240,3,Green,95
# 241,4,Green,99
# 242,5,Green,93
# 243,6,Green,96
# 244,7,Green,94
# 245,8,Green,95
# 246,9,Green,93
# 247,10,Green,92
# 248,11,Green,94
# 249,12,Green,100
# 250,13,Green,99
# 251,14,Green,94
# 252,15,Green,93
# 253,16,Green,97
# 254,17,Green,97
# 255,18,Green,91
# 256,19,Green,95
# 257,20,Green,93
# 258,21,Green,97
# 259,22,Green,91
# 260,23,Green,94
# 261,24,Green,92
# 262,25,Green,98
# 263,26,Green,98
# 264,27,Green,97
# 265,28,Green,93
# 266,29,Green,92
# 267,30,Green,97
# 268,1,Blue,92
# 269,2,Blue,104
# 270,3,Blue,108
# 271,4,Blue,106
# 272,5,Blue,103
# 273,6,Blue,100
# 274,7,Blue,105
# 275,8,Blue,102
# 276,9,Blue,106
# 277,10,Blue,106
# 278,11,Blue,101
# 279,12,Blue,107
# 280,13,Blue,102
# 281,14,Blue,106
# 282,15,Blue,104
# 283,16,Blue,104
# 284,17,Blue,104
# 285,18,Blue,104
# 286,19,Blue,107
# 287,20,Blue,107
# 288,21,Blue,100
# 289,22,Blue,106
# 290,23,Blue,101
# 291,24,Blue,100
# 292,25,Blue,106
# 293,26,Blue,105
# 294,27,Blue,103
# 295,28,Blue,101
# 296,29,Blue,99
# 297,1,Black,106
# 298,2,Black,5
# 299,3,Black,7
# 300,4,Black,6
# 301,5,Black,5
# 302,6,Black,8
# 303,7,Black,5
# 304,8,Black,7
# 305,9,Black,7
# 306,10,Black,5
# 307,11,Black,7
# 308,12,Black,6
# 309,13,Black,6
# 310,14,Black,5
# 311,15,Black,6
# 312,16,Black,7
# 313,17,Black,5
# 314,18,Black,6
# 315,19,Black,5
# 316,20,Black,6
# 317,21,Black,7
# 318,22,Black,4
# 319,23,Black,7
# 320,24,Black,5
# 321,25,Black,6
# 322,26,Black,5
# 323,27,Black,6
# 324,28,Black,6
# 325,29,Black,5
# 326,30,Black,7
# 327,0,Black,6
# 328,0,Black,7
# 329,0,Black,5
# 330,0,Black,7
# 331,0,Black,5
# 332,0,Black,6
# 333,0,Black,6
# 334,0,Black,6
# 335,0,Black,6
# 336,0,Black,6
# 337,0,Black,6
# 338,0,Black,6
# 339,0,Black,5
# 340,0,Black,7
# 341,0,Black,6
# 342,0,Black,6
# 343,0,Black,7
# 344,0,Black,5
# 345,0,Black,5
# 346,0,Black,7
# 347,0,Black,6
# 348,0,Black,5
# 349,0,Black,7
# 350,0,Black,5
# 351,0,Black,7
# 352,0,Black,6
# 353,0,Black,7
# 354,0,Black,5
# 355,0,Black,7
# 356,0,Black,5
# 357,1,White,6
# 358,2,White,218
# 359,3,White,225
# 360,4,White,220
# 361,5,White,219
# 362,6,White,225
# 363,7,White,227
# 364,8,White,222
# 365,9,White,220
# 366,10,White,218
# 367,11,White,220
# 368,12,White,217
# 369,13,White,220
# 370,14,White,220
# 371,15,White,222
# 372,16,White,222
# 373,17,White,221
# 374,18,White,221
# 375,19,White,222
# 376,20,White,219
# 377,21,White,221
# 378,22,White,220
# 379,23,White,218
# 380,24,White,219
# 381,25,White,217
# 382,26,White,223
# 383,27,White,219
# 384,28,White,222
# 385,29,White,214
# 386,1,Red,215
# 387,2,Red,40
# 388,3,Red,42
# 389,4,Red,43
# 390,5,Red,42
# 391,6,Red,40
# 392,7,Red,40
# 393,8,Red,43
# 394,9,Red,42
# 395,10,Red,39
# 396,11,Red,40
# 397,12,Red,40
# 398,13,Red,44
# 399,14,Red,41
# 400,15,Red,41
# 401,16,Red,43
# 402,17,Red,40
# 403,18,Red,39
# 404,19,Red,39
# 405,20,Red,40
# ...
# 334,0,Black,6
# 335,0,Black,10
# 336,0,Black,8
# 337,0,Black,5
# 338,0,Black,9
# 339,0,Black,6
# 340,0,Black,10
# 341,0,Black,8
# 342,0,Black,7
# 343,0,Black,8
# 344,0,Black,8
# 345,0,Black,7
# 346,0,Black,9
# 347,0,Black,9
# 348,0,Black,7
# 349,0,Black,8
# 350,0,Black,5
# 351,0,Black,9
# 352,0,Black,7
# 353,0,Black,6
# 354,0,Black,9
# 355,1,White,7
# 356,2,White,817
# 357,3,White,813
# 358,4,White,812
# 359,5,White,811
# 360,6,White,811
# 361,7,White,812
# 362,8,White,808
# 363,9,White,808
# 364,10,White,808
# 365,11,White,810
# 366,12,White,813
# 367,13,White,810
# 368,14,White,806
# 369,15,White,817
# 370,16,White,817
# 371,17,White,816
# 372,18,White,816
# 373,19,White,808
# 374,20,White,805
# 375,21,White,798
# 376,22,White,811
# 377,23,White,813
# 378,24,White,810
# 379,25,White,813
# 380,26,White,808
# 381,27,White,817
# 382,28,White,809
# 383,29,White,811
# 384,30,White,812
# 385,1,Red,811
# 386,2,Red,292
# 387,3,Red,289
# 388,4,Red,292
# 389,5,Red,294
# 390,6,Red,291
# 391,7,Red,290
# 392,8,Red,296
# 393,9,Red,290
# 394,10,Red,289
# 395,11,Red,292
# 396,12,Red,293
# 397,13,Red,290
# 398,14,Red,287
# 399,15,Red,292
# 400,16,Red,292
# 401,17,Red,290
# 402,18,Red,290
# 403,19,Red,290
# 404,20,Red,289
# 405,21,Red,295
# 406,22,Red,289
# 407,23,Red,287
# 408,24,Red,290
# 409,25,Red,284
# 410,26,Red,291
# 411,27,Red,293
# 412,28,Red,287
# 413,29,Red,295
# 414,1,Green,290
# 415,2,Green,332
# 416,3,Green,330
# 417,4,Green,332
# 418,5,Green,329
# 419,6,Green,334
# 420,7,Green,325
# 421,8,Green,329
# 422,9,Green,324
# 423,10,Green,323
# 424,11,Green,328
# 425,12,Green,333
# 426,13,Green,329
# 427,14,Green,331
# 428,15,Green,327
# 429,16,Green,333
# 430,17,Green,332
# 431,18,Green,326
# 432,19,Green,321
# 433,20,Green,327
# 434,21,Green,335
# 435,22,Green,331
# 436,23,Green,322
# 437,24,Green,328
# 438,25,Green,324
# 439,26,Green,335
# 440,27,Green,328
# 441,28,Green,331
# 442,29,Green,328
# 443,30,Green,328
# 444,1,Blue,332
# 445,2,Blue,242
# 446,3,Blue,239
# 447,4,Blue,243
# 448,5,Blue,240
# 449,6,Blue,241
# 450,7,Blue,235
# 451,8,Blue,236
# 452,9,Blue,239
# 453,10,Blue,236
# 454,11,Blue,247
# 455,12,Blue,244
# 456,13,Blue,242
# 457,14,Blue,242
# 458,15,Blue,243
# 459,16,Blue,240
# 460,17,Blue,239
# 461,18,Blue,236
# 462,19,Blue,237
# 463,20,Blue,241
# 464,21,Blue,238
# 465,22,Blue,245
# 466,23,Blue,242
# 467,24,Blue,242
# 468,25,Blue,242
# 469,26,Blue,241
# 470,27,Blue,238
# 471,28,Blue,243
# 614,24,Green,329
# 615,25,Green,335
# 616,26,Green,329
# 617,27,Green,330
# 618,28,Green,329
# 619,29,Green,329
# 620,30,Green,328
# 621,1,Blue,328
# 622,2,Blue,241
# 623,3,Blue,242
# 624,4,Blue,238
# 625,5,Blue,249
# 626,6,Blue,247
# 627,7,Blue,239
# 628,8,Blue,241
# 629,9,Blue,242
# 630,10,Blue,239
# 631,11,Blue,238
# 632,12,Blue,239
# 633,13,Blue,241
# 634,14,Blue,241
# 635,15,Blue,243
# 636,16,Blue,244
# 637,17,Blue,239
# 638,18,Blue,238
# 639,19,Blue,244
# 640,20,Blue,241
# 641,21,Blue,243
# 642,22,Blue,238
# 643,23,Blue,238
# 644,24,Blue,242
# 645,25,Blue,242
# 646,26,Blue,240
# 647,27,Blue,241
# 648,28,Blue,246
# 649,29,Blue,248
# 650,1,Black,244
# 651,2,Black,8
# 652,3,Black,8
# 653,4,Black,8
# 654,5,Black,6
# 655,6,Black,5
# 656,7,Black,8
# 657,8,Black,7
# 658,9,Black,9
# 659,10,Black,8
# 660,11,Black,7
# 661,12,Black,7
# 662,13,Black,9
# 663,14,Black,7
# 664,15,Black,9
# 665,16,Black,7
# 666,17,Black,9
# 667,18,Black,9
# 668,19,Black,7
# 669,20,Black,10
# 670,21,Black,6
# 671,22,Black,8
# 672,23,Black,7
# 673,24,Black,8
# 674,25,Black,10
# 675,26,Black,8
# 676,27,Black,8
# 677,28,Black,10
# 678,29,Black,6
# 679,30,Black,6
# 680,0,Black,9
#
# ==================================================
#
# ไฟล์: P/P_100/P100_WR.txt
# P100_WRPure water tube 5ml  Reagent 1ml. new :11/10/2023,17:23:38
# 1,1,White,5
# 2,2,White,944
# 3,3,White,949
# 4,4,White,945
# 5,5,White,947
# 6,6,White,951
# 7,7,White,947
# 8,8,White,954
# 9,9,White,956
# 10,10,White,955
# 11,11,White,956
# 12,12,White,956
# 13,13,White,957
# 14,14,White,959
# 15,15,White,957
# 16,16,White,954
# 17,17,White,958
# 18,18,White,958
# 19,19,White,957
# 20,20,White,947
# 21,21,White,952
# 22,22,White,956
# 23,23,White,956
# 24,24,White,952
# 25,25,White,950
# 26,26,White,958
# 27,27,White,956
# 28,28,White,956
# 29,29,White,953
# 30,30,White,954
# 31,1,Red,954
# 32,2,Red,326
# 33,3,Red,329
# 34,4,Red,328
# 35,5,Red,327
# 36,6,Red,327
# 37,7,Red,329
# 38,8,Red,331
# 39,9,Red,322
# 40,10,Red,328
# 41,11,Red,330
# 42,12,Red,331
# 43,13,Red,334
# 44,14,Red,330
# 45,15,Red,334
# 46,16,Red,327
# 47,17,Red,331
# 48,18,Red,327
# 49,19,Red,330
# 50,20,Red,331
# 51,21,Red,328
# 52,22,Red,328
# 53,23,Red,321
# 54,24,Red,323
# 55,25,Red,328
# 56,26,Red,328
# 57,27,Red,328
# 58,28,Red,325
# 59,29,Red,325
# 60,1,Green,331
# 61,2,Green,424
# 62,3,Green,429
# 63,4,Green,428
# 64,5,Green,424
# 65,6,Green,423
# 204,25,White,948
# 205,26,White,950
# 206,27,White,951
# 207,28,White,949
# 208,29,White,950
# 209,30,White,946
# 210,1,Red,949
# 211,2,Red,331
# 212,3,Red,329
# 213,4,Red,326
# 214,5,Red,327
# 215,6,Red,328
# 216,7,Red,333
# 217,8,Red,330
# 218,9,Red,330
# 219,10,Red,326
# 220,11,Red,329
# 221,12,Red,328
# 222,13,Red,328
# 223,14,Red,329
# 224,15,Red,324
# 225,16,Red,328
# 226,17,Red,326
# 227,18,Red,329
# 228,19,Red,327
# 229,20,Red,327
# 230,21,Red,332
# 231,22,Red,323
# 232,23,Red,330
# 233,24,Red,327
# 234,25,Red,323
# 235,26,Red,329
# 236,27,Red,331
# 237,28,Red,328
# 238,29,Red,331
# 239,1,Green,328
# 240,2,Green,423
# 241,3,Green,411
# 242,4,Green,417
# 243,5,Green,422
# 244,6,Green,406
# 245,7,Green,410
# 246,8,Green,418
# 247,9,Green,415
# 248,10,Green,418
# 249,11,Green,411
# 250,12,Green,420
# 251,13,Green,424
# 252,14,Green,418
# 253,15,Green,418
# 254,16,Green,411
# 255,17,Green,416
# 256,18,Green,418
# 257,19,Green,414
# 258,20,Green,414
# 259,21,Green,399
# 260,22,Green,397
# 261,23,Green,393
# 262,24,Green,431
# 263,25,Green,404
# 264,26,Green,411
# 265,27,Green,416
# 266,28,Green,409
# 267,29,Green,412
# 268,30,Green,413
# 269,1,Blue,408
# 270,2,Blue,311
# 271,3,Blue,311
# 272,4,Blue,308
# 273,5,Blue,310
# 274,6,Blue,314
# 275,7,Blue,309
# 276,8,Blue,312
# 277,9,Blue,310
# 278,10,Blue,308
# 279,11,Blue,314
# 280,12,Blue,308
# 281,13,Blue,314
# 282,14,Blue,311
# 283,15,Blue,301
# 284,16,Blue,307
# 285,17,Blue,308
# 286,18,Blue,309
# 287,19,Blue,309
# 288,20,Blue,307
# 289,21,Blue,312
# 290,22,Blue,309
# 291,23,Blue,311
# 292,24,Blue,315
# 293,25,Blue,312
# 294,26,Blue,309
# 295,27,Blue,305
# 296,28,Blue,311
# 297,29,Blue,309
# 298,30,Blue,315
# 299,1,Black,309
# 300,2,Black,6
# 301,3,Black,6
# 302,4,Black,6
# 303,5,Black,4
# 304,6,Black,5
# 305,7,Black,6
# 306,8,Black,6
# 307,9,Black,6
# 308,10,Black,6
# 309,11,Black,5
# 310,12,Black,5
# 311,13,Black,4
# 312,14,Black,5
# 313,15,Black,4
# 314,16,Black,4
# 315,17,Black,5
# 316,18,Black,4
# 317,19,Black,6
# 318,20,Black,5
# 319,21,Black,6
# 320,22,Black,5
# 321,23,Black,5
# 322,24,Black,5
# 323,25,Black,6
# 324,26,Black,5
# 325,27,Black,6
# 326,28,Black,6
# 327,29,Black,5
# 328,30,Black,5
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,4
# 332,0,Black,4
# 333,0,Black,5
# 334,0,Black,4
# 335,0,Black,5
# 336,0,Black,5
# 337,0,Black,5
# 338,0,Black,5
# 339,0,Black,4
# 340,0,Black,4
# 341,0,Black,5
# 342,0,Black,6
# 343,0,Black,6
# 344,0,Black,5
# 345,0,Black,6
# 346,0,Black,5
# 347,0,Black,6
# 348,0,Black,5
# 349,0,Black,5
# 350,0,Black,6
# 351,0,Black,6
# 352,0,Black,5
# 353,0,Black,5
# 354,0,Black,4
# 355,0,Black,6
# 356,0,Black,5
# 357,0,Black,6
# 358,0,Black,4
# 359,1,White,4
# 360,2,White,955
# 361,3,White,956
# 362,4,White,958
# 363,5,White,951
# 364,6,White,953
# 365,7,White,952
# 366,8,White,953
# 367,9,White,954
# 368,10,White,956
# 369,11,White,954
# 370,12,White,952
# 371,13,White,955
# 372,14,White,954
# 373,15,White,951
# 374,16,White,952
# 375,17,White,952
# 376,18,White,955
# 377,19,White,954
# 378,20,White,953
# 379,21,White,950
# 380,22,White,956
# 381,23,White,951
# 382,24,White,952
# 383,25,White,955
# 384,26,White,954
# 385,27,White,954
# 386,28,White,952
# 387,29,White,951
# 388,1,Red,956
# 389,2,Red,330
# 390,3,Red,328
# 391,4,Red,331
# 392,5,Red,324
# 393,6,Red,330
# 394,7,Red,327
# 395,8,Red,327
# 396,9,Red,329
# 397,10,Red,331
# 398,11,Red,333
# 399,12,Red,329
# 400,13,Red,325
# 401,14,Red,326
# 402,15,Red,329
# 403,16,Red,326
# 404,17,Red,325
# 405,18,Red,324
# 406,19,Red,325
# 407,20,Red,323
# 408,21,Red,324
# 409,22,Red,327
# 410,23,Red,328
# 411,24,Red,330
# 412,25,Red,328
# 413,26,Red,325
# 414,27,Red,334
# 415,28,Red,321
# 416,29,Red,327
# 417,30,Red,334
# 418,1,Green,326
# 419,2,Green,457
# 420,3,Green,449
# 421,4,Green,452
# 422,5,Green,448
# 423,6,Green,455
# 424,7,Green,446
# 425,8,Green,456
# 426,9,Green,456
# 427,10,Green,455
# 428,11,Green,455
# 429,12,Green,450
# 430,13,Green,450
# 431,14,Green,452
# 432,15,Green,454
# 433,16,Green,447
# 434,17,Green,449
# 435,18,Green,452
# 436,19,Green,452
# 437,20,Green,451
# 438,21,Green,451
# 439,22,Green,455
# 440,23,Green,453
# 441,24,Green,451
# 442,25,Green,455
# 443,26,Green,452
# 444,27,Green,457
# 445,28,Green,459
# 446,29,Green,458
# 447,30,Green,456
# 448,1,Blue,460
# 449,2,Blue,310
# 450,3,Blue,310
# 451,4,Blue,309
# 452,5,Blue,311
# 453,6,Blue,308
# 454,7,Blue,308
# 455,8,Blue,311
# 456,9,Blue,307
# 457,10,Blue,308
# 458,11,Blue,309
# 459,12,Blue,314
# 460,13,Blue,314
# 461,14,Blue,310
# 462,15,Blue,308
# 463,16,Blue,307
# 464,17,Blue,307
# 465,18,Blue,316
# 466,19,Blue,311
# 467,20,Blue,313
# 468,21,Blue,313
# 469,22,Blue,313
# 470,23,Blue,314
# 471,24,Blue,306
# 472,25,Blue,310
# 473,26,Blue,311
# 474,27,Blue,304
# 475,28,Blue,310
# 476,29,Blue,316
# 477,30,Blue,309
# 478,1,Black,308
# 479,2,Black,5
# 622,26,Green,464
# 623,27,Green,463
# 624,28,Green,467
# 625,29,Green,465
# 626,30,Green,468
# 627,1,Blue,461
# 628,2,Blue,314
# 629,3,Blue,314
# 630,4,Blue,315
# 631,5,Blue,311
# 632,6,Blue,314
# 633,7,Blue,306
# 634,8,Blue,316
# 635,9,Blue,311
# 636,10,Blue,308
# 637,11,Blue,309
# 638,12,Blue,311
# 639,13,Blue,308
# 640,14,Blue,312
# 641,15,Blue,308
# 642,16,Blue,308
# 643,17,Blue,309
# 644,18,Blue,311
# 645,19,Blue,312
# 646,20,Blue,313
# 647,21,Blue,312
# 648,22,Blue,313
# 649,23,Blue,315
# 650,24,Blue,309
# 651,25,Blue,305
# 652,26,Blue,308
# 653,27,Blue,312
# 654,28,Blue,314
# 655,29,Blue,311
# 656,30,Blue,313
# 657,1,Black,315
# 658,2,Black,5
# 659,3,Black,5
# 660,4,Black,6
# 661,5,Black,5
# 662,6,Black,6
# 663,7,Black,7
# 664,8,Black,5
# 665,9,Black,6
# 666,10,Black,5
# 667,11,Black,5
# 668,12,Black,5
# 669,13,Black,5
# 670,14,Black,5
# 671,15,Black,6
# 672,16,Black,5
# 673,17,Black,5
# 674,18,Black,5
# 675,19,Black,5
# 676,20,Black,6
# 677,21,Black,5
# 678,22,Black,5
# 679,23,Black,4
# 680,24,Black,4
#
# ==================================================

# %% [markdown]
# แปลงไฟล์ txt ในแต่ละโฟลเดอร์  เป็น cvs   และบันทึกไว้ในโฟลเดอร์  NdatasetCSV

# %%
import os
import csv

# ระบุโฟลเดอร์หลัก N
main_folder = "P"

# ระบุโฟลเดอร์ที่จะบันทึกไฟล์ .csv
output_folder_path = "PdatasetCSV"

# ตรวจสอบว่าโฟลเดอร์ output_folder_path มีอยู่หรือไม่ และสร้างถ้าไม่มี
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# วนลูปผ่านโฟลเดอร์และไฟล์ทั้งหมดในโฟลเดอร์หลัก
for root, _, files in os.walk(main_folder):
    for filename in files:
        if filename.endswith(".txt"):
            # รับที่อยู่ของไฟล์ .txt
            input_file_path = os.path.join(root, filename)
            
            # สร้างชื่อไฟล์ .csv ใหม่โดยนำชื่อไฟล์เดิมมาใช้
            output_file_path = os.path.join(output_folder_path, os.path.splitext(filename)[0] + ".csv")

            # เปิดไฟล์ .txt สำหรับอ่าน
            with open(input_file_path, "r") as txt_file:
                # อ่านข้อมูลทั้งหมดจากไฟล์ .txt
                lines = txt_file.readlines()

            # ตรวจสอบว่ามีข้อมูลในไฟล์หรือไม่
            if len(lines) > 0:
                # ลบข้อมูลในแถวแรก
                lines = lines[1:]

                # เปิดไฟล์ .csv สำหรับเขียน
                with open(output_file_path, "w", newline='') as csv_file:
                    # สร้างอ็อบเจ็กต์ writer สำหรับเขียนข้อมูล CSV
                    csv_writer = csv.writer(csv_file)

                    # เขียนข้อมูลลงในไฟล์ .csv
                    for line in lines:
                        # แบ่งข้อมูลในแต่ละบรรทัดด้วยเครื่องหมาย "," และลบช่องว่างด้านหน้าและหลัง
                        row_data = line.strip().split(",")
                        csv_writer.writerow(row_data)

            print(f"แปลงไฟล์ '{filename}' และบันทึกเป็น '{os.path.basename(output_file_path)}'")

print("เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ NdatasetCSV")
# Out:
# แปลงไฟล์ 'P80_NoR.txt' และบันทึกเป็น 'P80_NoR.csv'
# แปลงไฟล์ 'P80_W.txt' และบันทึกเป็น 'P80_W.csv'
# แปลงไฟล์ 'P80_WR.txt' และบันทึกเป็น 'P80_WR.csv'
# แปลงไฟล์ 'P80_A.txt' และบันทึกเป็น 'P80_A.csv'
# แปลงไฟล์ 'P80_R.txt' และบันทึกเป็น 'P80_R.csv'
# แปลงไฟล์ 'P80_blank.txt' และบันทึกเป็น 'P80_blank.csv'
# แปลงไฟล์ 'P20_NoR.txt' และบันทึกเป็น 'P20_NoR.csv'
# แปลงไฟล์ 'P20_blank.txt' และบันทึกเป็น 'P20_blank.csv'
# แปลงไฟล์ 'P20_A.txt' และบันทึกเป็น 'P20_A.csv'
# แปลงไฟล์ 'P20_W.txt' และบันทึกเป็น 'P20_W.csv'
# แปลงไฟล์ 'P20_WR.txt' และบันทึกเป็น 'P20_WR.csv'
# แปลงไฟล์ 'P20_R.txt' และบันทึกเป็น 'P20_R.csv'
# แปลงไฟล์ 'P10_blank.txt' และบันทึกเป็น 'P10_blank.csv'
# แปลงไฟล์ 'P10_R.txt' และบันทึกเป็น 'P10_R.csv'
# แปลงไฟล์ 'P10_W.txt' และบันทึกเป็น 'P10_W.csv'
# แปลงไฟล์ 'P10_A.txt' และบันทึกเป็น 'P10_A.csv'
# แปลงไฟล์ 'P10_B.txt' และบันทึกเป็น 'P10_B.csv'
# แปลงไฟล์ 'P10_WR.txt' และบันทึกเป็น 'P10_WR.csv'
# แปลงไฟล์ 'P10_NoR.txt' และบันทึกเป็น 'P10_NoR.csv'
# แปลงไฟล์ 'P6_blank.txt' และบันทึกเป็น 'P6_blank.csv'
# แปลงไฟล์ 'P6_WR.txt' และบันทึกเป็น 'P6_WR.csv'
# แปลงไฟล์ 'P6_NoR.txt' และบันทึกเป็น 'P6_NoR.csv'
# แปลงไฟล์ 'P6_R.txt' และบันทึกเป็น 'P6_R.csv'
# แปลงไฟล์ 'P6_B.txt' และบันทึกเป็น 'P6_B.csv'
# แปลงไฟล์ 'P6_A.txt' และบันทึกเป็น 'P6_A.csv'
# แปลงไฟล์ 'P6_W.txt' และบันทึกเป็น 'P6_W.csv'
# แปลงไฟล์ 'P8_B.txt' และบันทึกเป็น 'P8_B.csv'
# แปลงไฟล์ 'P8_WR.txt' และบันทึกเป็น 'P8_WR.csv'
# แปลงไฟล์ 'P8_A.txt' และบันทึกเป็น 'P8_A.csv'
# แปลงไฟล์ 'P8_W.txt' และบันทึกเป็น 'P8_W.csv'
# แปลงไฟล์ 'P8_R.txt' และบันทึกเป็น 'P8_R.csv'
# แปลงไฟล์ 'P8_blank.txt' และบันทึกเป็น 'P8_blank.csv'
# แปลงไฟล์ 'P8_NoR.txt' และบันทึกเป็น 'P8_NoR.csv'
# แปลงไฟล์ 'P60_WR.txt' และบันทึกเป็น 'P60_WR.csv'
# แปลงไฟล์ 'P60_blank.txt' และบันทึกเป็น 'P60_blank.csv'
# แปลงไฟล์ 'P60_R.txt' และบันทึกเป็น 'P60_R.csv'
# แปลงไฟล์ 'P60_W.txt' และบันทึกเป็น 'P60_W.csv'
# แปลงไฟล์ 'P60_A.txt' และบันทึกเป็น 'P60_A.csv'
# แปลงไฟล์ 'P60_NoR.txt' และบันทึกเป็น 'P60_NoR.csv'
# แปลงไฟล์ 'BG_1.txt' และบันทึกเป็น 'BG_1.csv'
# แปลงไฟล์ 'BG_0.txt' และบันทึกเป็น 'BG_0.csv'
# แปลงไฟล์ 'BG_rbru0.txt' และบันทึกเป็น 'BG_rbru0.csv'
# แปลงไฟล์ 'BG_rbru1.txt' และบันทึกเป็น 'BG_rbru1.csv'
# แปลงไฟล์ 'P40_blank.txt' และบันทึกเป็น 'P40_blank.csv'
# แปลงไฟล์ 'P40_NoR.txt' และบันทึกเป็น 'P40_NoR.csv'
# แปลงไฟล์ 'P40_WR.txt' และบันทึกเป็น 'P40_WR.csv'
# แปลงไฟล์ 'P40_W.txt' และบันทึกเป็น 'P40_W.csv'
# แปลงไฟล์ 'P40_A.txt' และบันทึกเป็น 'P40_A.csv'
# แปลงไฟล์ 'P40_R.txt' และบันทึกเป็น 'P40_R.csv'
# แปลงไฟล์ 'P2_WR.txt' และบันทึกเป็น 'P2_WR.csv'
# แปลงไฟล์ 'P2_W.txt' และบันทึกเป็น 'P2_W.csv'
# แปลงไฟล์ 'P2_A.txt' และบันทึกเป็น 'P2_A.csv'
# แปลงไฟล์ 'P2_B.txt' และบันทึกเป็น 'P2_B.csv'
# แปลงไฟล์ 'P2_blank.txt' และบันทึกเป็น 'P2_blank.csv'
# แปลงไฟล์ 'P2_NoR.txt' และบันทึกเป็น 'P2_NoR.csv'
# แปลงไฟล์ 'P2_R.txt' และบันทึกเป็น 'P2_R.csv'
# แปลงไฟล์ 'P4_NoR.txt' และบันทึกเป็น 'P4_NoR.csv'
# แปลงไฟล์ 'P4_WR.txt' และบันทึกเป็น 'P4_WR.csv'
# แปลงไฟล์ 'P4_blank.txt' และบันทึกเป็น 'P4_blank.csv'
# แปลงไฟล์ 'P4_R.txt' และบันทึกเป็น 'P4_R.csv'
# แปลงไฟล์ 'P4_W.txt' และบันทึกเป็น 'P4_W.csv'
# แปลงไฟล์ 'P4_A.txt' และบันทึกเป็น 'P4_A.csv'
# แปลงไฟล์ 'P4_B.txt' และบันทึกเป็น 'P4_B.csv'
# แปลงไฟล์ 'P100_A.txt' และบันทึกเป็น 'P100_A.csv'
# แปลงไฟล์ 'P100_W.txt' และบันทึกเป็น 'P100_W.csv'
# แปลงไฟล์ 'P100_R.txt' และบันทึกเป็น 'P100_R.csv'
# แปลงไฟล์ 'P100_NoR.txt' และบันทึกเป็น 'P100_NoR.csv'
# แปลงไฟล์ 'P100_blank.txt' และบันทึกเป็น 'P100_blank.csv'
# แปลงไฟล์ 'P100_WR.txt' และบันทึกเป็น 'P100_WR.csv'
# เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ NdatasetCSV

# %% [markdown]
# เลื่อนข้อมูลในคอลัมน์ 'Intensity' ขึ้นหนึ่งแถว และลบแถวที่มีคอลัมน์ 'Order' เท่ากับ 0 และคอลัมน์ 'Color' เท่ากับ 'Black' หลังจากนั้นบันทึกข้อมูลที่แก้ไขแล้วในไฟล์ .csv

# %%
import os
import pandas as pd

# Define the column names
column_names = ["No.", "Order", "Color", "Intensity"]

# Specify the folder path
folder_path = "PdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file with the specified column names
    df = pd.read_csv(file_path, names=column_names)

    # Shift the data in the 'Intensity' column up by one row
    df['Intensity'] = df['Intensity'].shift(-1)

    # Drop rows where 'Order' is equal to 0 and 'Color' is equal to 'Black'
    df = df[(df['Order'] != 0) | (df['Color'] != 'Black')]

    # Specify the original file path and save the modified DataFrame
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'NdatasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to PdatasetCSV/P4_R.csv
# Modified DataFrame saved to PdatasetCSV/P60_R.csv
# Modified DataFrame saved to PdatasetCSV/P80_W.csv
# Modified DataFrame saved to PdatasetCSV/P40_W.csv
# Modified DataFrame saved to PdatasetCSV/P40_A.csv
# Modified DataFrame saved to PdatasetCSV/P2_B.csv
# Modified DataFrame saved to PdatasetCSV/P80_WR.csv
# Modified DataFrame saved to PdatasetCSV/P80_A.csv
# Modified DataFrame saved to PdatasetCSV/P100_blank.csv
# Modified DataFrame saved to PdatasetCSV/BG_rbru0.csv
# Modified DataFrame saved to PdatasetCSV/P2_W.csv
# Modified DataFrame saved to PdatasetCSV/P2_A.csv
# Modified DataFrame saved to PdatasetCSV/BG_rbru1.csv
# Modified DataFrame saved to PdatasetCSV/P4_blank.csv
# Modified DataFrame saved to PdatasetCSV/P6_R.csv
# Modified DataFrame saved to PdatasetCSV/P10_WR.csv
# Modified DataFrame saved to PdatasetCSV/P6_A.csv
# Modified DataFrame saved to PdatasetCSV/P10_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P2_R.csv
# Modified DataFrame saved to PdatasetCSV/P6_W.csv
# Modified DataFrame saved to PdatasetCSV/P4_B.csv
# Modified DataFrame saved to PdatasetCSV/P2_blank.csv
# Modified DataFrame saved to PdatasetCSV/P80_R.csv
# Modified DataFrame saved to PdatasetCSV/P4_W.csv
# Modified DataFrame saved to PdatasetCSV/P60_W.csv
# Modified DataFrame saved to PdatasetCSV/P6_B.csv
# Modified DataFrame saved to PdatasetCSV/P2_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P40_R.csv
# Modified DataFrame saved to PdatasetCSV/P80_blank.csv
# Modified DataFrame saved to PdatasetCSV/P60_A.csv
# Modified DataFrame saved to PdatasetCSV/P4_A.csv
# Modified DataFrame saved to PdatasetCSV/P60_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P20_WR.csv
# Modified DataFrame saved to PdatasetCSV/P8_blank.csv
# Modified DataFrame saved to PdatasetCSV/P20_blank.csv
# Modified DataFrame saved to PdatasetCSV/P20_A.csv
# Modified DataFrame saved to PdatasetCSV/P100_WR.csv
# Modified DataFrame saved to PdatasetCSV/P20_W.csv
# Modified DataFrame saved to PdatasetCSV/P20_R.csv
# Modified DataFrame saved to PdatasetCSV/P8_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P60_WR.csv
# Modified DataFrame saved to PdatasetCSV/P80_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P40_blank.csv
# Modified DataFrame saved to PdatasetCSV/P20_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P6_blank.csv
# Modified DataFrame saved to PdatasetCSV/P4_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P2_WR.csv
# Modified DataFrame saved to PdatasetCSV/BG_1.csv
# Modified DataFrame saved to PdatasetCSV/BG_0.csv
# Modified DataFrame saved to PdatasetCSV/P10_blank.csv
# Modified DataFrame saved to PdatasetCSV/P8_WR.csv
# Modified DataFrame saved to PdatasetCSV/P10_R.csv
# Modified DataFrame saved to PdatasetCSV/P8_A.csv
# Modified DataFrame saved to PdatasetCSV/P60_blank.csv
# Modified DataFrame saved to PdatasetCSV/P4_WR.csv
# Modified DataFrame saved to PdatasetCSV/P8_W.csv
# Modified DataFrame saved to PdatasetCSV/P8_B.csv
# Modified DataFrame saved to PdatasetCSV/P100_A.csv
# Modified DataFrame saved to PdatasetCSV/P100_W.csv
# Modified DataFrame saved to PdatasetCSV/P40_WR.csv
# Modified DataFrame saved to PdatasetCSV/P100_R.csv
# Modified DataFrame saved to PdatasetCSV/P10_B.csv
# Modified DataFrame saved to PdatasetCSV/P100_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P6_WR.csv
# Modified DataFrame saved to PdatasetCSV/P40_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P10_W.csv
# Modified DataFrame saved to PdatasetCSV/P6_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P8_R.csv
# Modified DataFrame saved to PdatasetCSV/P10_A.csv
# All CSV files in the 'NdatasetCSV' folder have been processed.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "PdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Remove the last row from the DataFrame
    df = df.iloc[:-1]

    # Save the modified DataFrame back to the same file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Last row removed and file '{csv_file}' saved with the same name.")

print("All CSV files in the 'NdatasetCSV' folder have had their last row removed and saved with the same name.")
# Out:
# Last row removed and file 'P4_R.csv' saved with the same name.
# Last row removed and file 'P60_R.csv' saved with the same name.
# Last row removed and file 'P80_W.csv' saved with the same name.
# Last row removed and file 'P40_W.csv' saved with the same name.
# Last row removed and file 'P40_A.csv' saved with the same name.
# Last row removed and file 'P2_B.csv' saved with the same name.
# Last row removed and file 'P80_WR.csv' saved with the same name.
# Last row removed and file 'P80_A.csv' saved with the same name.
# Last row removed and file 'P100_blank.csv' saved with the same name.
# Last row removed and file 'BG_rbru0.csv' saved with the same name.
# Last row removed and file 'P2_W.csv' saved with the same name.
# Last row removed and file 'P2_A.csv' saved with the same name.
# Last row removed and file 'BG_rbru1.csv' saved with the same name.
# Last row removed and file 'P4_blank.csv' saved with the same name.
# Last row removed and file 'P6_R.csv' saved with the same name.
# Last row removed and file 'P10_WR.csv' saved with the same name.
# Last row removed and file 'P6_A.csv' saved with the same name.
# Last row removed and file 'P10_NoR.csv' saved with the same name.
# Last row removed and file 'P2_R.csv' saved with the same name.
# Last row removed and file 'P6_W.csv' saved with the same name.
# Last row removed and file 'P4_B.csv' saved with the same name.
# Last row removed and file 'P2_blank.csv' saved with the same name.
# Last row removed and file 'P80_R.csv' saved with the same name.
# Last row removed and file 'P4_W.csv' saved with the same name.
# Last row removed and file 'P60_W.csv' saved with the same name.
# Last row removed and file 'P6_B.csv' saved with the same name.
# Last row removed and file 'P2_NoR.csv' saved with the same name.
# Last row removed and file 'P40_R.csv' saved with the same name.
# Last row removed and file 'P80_blank.csv' saved with the same name.
# Last row removed and file 'P60_A.csv' saved with the same name.
# Last row removed and file 'P4_A.csv' saved with the same name.
# Last row removed and file 'P60_NoR.csv' saved with the same name.
# Last row removed and file 'P20_WR.csv' saved with the same name.
# Last row removed and file 'P8_blank.csv' saved with the same name.
# Last row removed and file 'P20_blank.csv' saved with the same name.
# Last row removed and file 'P20_A.csv' saved with the same name.
# Last row removed and file 'P100_WR.csv' saved with the same name.
# Last row removed and file 'P20_W.csv' saved with the same name.
# Last row removed and file 'P20_R.csv' saved with the same name.
# Last row removed and file 'P8_NoR.csv' saved with the same name.
# Last row removed and file 'P60_WR.csv' saved with the same name.
# Last row removed and file 'P80_NoR.csv' saved with the same name.
# Last row removed and file 'P40_blank.csv' saved with the same name.
# Last row removed and file 'P20_NoR.csv' saved with the same name.
# Last row removed and file 'P6_blank.csv' saved with the same name.
# Last row removed and file 'P4_NoR.csv' saved with the same name.
# Last row removed and file 'P2_WR.csv' saved with the same name.
# Last row removed and file 'BG_1.csv' saved with the same name.
# Last row removed and file 'BG_0.csv' saved with the same name.
# Last row removed and file 'P10_blank.csv' saved with the same name.
# Last row removed and file 'P8_WR.csv' saved with the same name.
# Last row removed and file 'P10_R.csv' saved with the same name.
# Last row removed and file 'P8_A.csv' saved with the same name.
# Last row removed and file 'P60_blank.csv' saved with the same name.
# Last row removed and file 'P4_WR.csv' saved with the same name.
# Last row removed and file 'P8_W.csv' saved with the same name.
# Last row removed and file 'P8_B.csv' saved with the same name.
# Last row removed and file 'P100_A.csv' saved with the same name.
# Last row removed and file 'P100_W.csv' saved with the same name.
# Last row removed and file 'P40_WR.csv' saved with the same name.
# Last row removed and file 'P100_R.csv' saved with the same name.
# Last row removed and file 'P10_B.csv' saved with the same name.
# Last row removed and file 'P100_NoR.csv' saved with the same name.
# Last row removed and file 'P6_WR.csv' saved with the same name.
# Last row removed and file 'P40_NoR.csv' saved with the same name.
# Last row removed and file 'P10_W.csv' saved with the same name.
# Last row removed and file 'P6_NoR.csv' saved with the same name.
# Last row removed and file 'P8_R.csv' saved with the same name.
# Last row removed and file 'P10_A.csv' saved with the same name.
# All CSV files in the 'NdatasetCSV' folder have had their last row removed and saved with the same name.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "PdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Convert the 'Intensity' column to integers
    df['Intensity'] = df['Intensity'].astype(int)

    # Save the modified DataFrame back to the CSV file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'NdatasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to PdatasetCSV/P4_R.csv
# Modified DataFrame saved to PdatasetCSV/P60_R.csv
# Modified DataFrame saved to PdatasetCSV/P80_W.csv
# Modified DataFrame saved to PdatasetCSV/P40_W.csv
# Modified DataFrame saved to PdatasetCSV/P40_A.csv
# Modified DataFrame saved to PdatasetCSV/P2_B.csv
# Modified DataFrame saved to PdatasetCSV/P80_WR.csv
# Modified DataFrame saved to PdatasetCSV/P80_A.csv
# Modified DataFrame saved to PdatasetCSV/P100_blank.csv
# Modified DataFrame saved to PdatasetCSV/BG_rbru0.csv
# Modified DataFrame saved to PdatasetCSV/P2_W.csv
# Modified DataFrame saved to PdatasetCSV/P2_A.csv
# Modified DataFrame saved to PdatasetCSV/BG_rbru1.csv
# Modified DataFrame saved to PdatasetCSV/P4_blank.csv
# Modified DataFrame saved to PdatasetCSV/P6_R.csv
# Modified DataFrame saved to PdatasetCSV/P10_WR.csv
# Modified DataFrame saved to PdatasetCSV/P6_A.csv
# Modified DataFrame saved to PdatasetCSV/P10_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P2_R.csv
# Modified DataFrame saved to PdatasetCSV/P6_W.csv
# Modified DataFrame saved to PdatasetCSV/P4_B.csv
# Modified DataFrame saved to PdatasetCSV/P2_blank.csv
# Modified DataFrame saved to PdatasetCSV/P80_R.csv
# Modified DataFrame saved to PdatasetCSV/P4_W.csv
# Modified DataFrame saved to PdatasetCSV/P60_W.csv
# Modified DataFrame saved to PdatasetCSV/P6_B.csv
# Modified DataFrame saved to PdatasetCSV/P2_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P40_R.csv
# Modified DataFrame saved to PdatasetCSV/P80_blank.csv
# Modified DataFrame saved to PdatasetCSV/P60_A.csv
# Modified DataFrame saved to PdatasetCSV/P4_A.csv
# Modified DataFrame saved to PdatasetCSV/P60_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P20_WR.csv
# Modified DataFrame saved to PdatasetCSV/P8_blank.csv
# Modified DataFrame saved to PdatasetCSV/P20_blank.csv
# Modified DataFrame saved to PdatasetCSV/P20_A.csv
# Modified DataFrame saved to PdatasetCSV/P100_WR.csv
# Modified DataFrame saved to PdatasetCSV/P20_W.csv
# Modified DataFrame saved to PdatasetCSV/P20_R.csv
# Modified DataFrame saved to PdatasetCSV/P8_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P60_WR.csv
# Modified DataFrame saved to PdatasetCSV/P80_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P40_blank.csv
# Modified DataFrame saved to PdatasetCSV/P20_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P6_blank.csv
# Modified DataFrame saved to PdatasetCSV/P4_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P2_WR.csv
# Modified DataFrame saved to PdatasetCSV/BG_1.csv
# Modified DataFrame saved to PdatasetCSV/BG_0.csv
# Modified DataFrame saved to PdatasetCSV/P10_blank.csv
# Modified DataFrame saved to PdatasetCSV/P8_WR.csv
# Modified DataFrame saved to PdatasetCSV/P10_R.csv
# Modified DataFrame saved to PdatasetCSV/P8_A.csv
# Modified DataFrame saved to PdatasetCSV/P60_blank.csv
# Modified DataFrame saved to PdatasetCSV/P4_WR.csv
# Modified DataFrame saved to PdatasetCSV/P8_W.csv
# Modified DataFrame saved to PdatasetCSV/P8_B.csv
# Modified DataFrame saved to PdatasetCSV/P100_A.csv
# Modified DataFrame saved to PdatasetCSV/P100_W.csv
# Modified DataFrame saved to PdatasetCSV/P40_WR.csv
# Modified DataFrame saved to PdatasetCSV/P100_R.csv
# Modified DataFrame saved to PdatasetCSV/P10_B.csv
# Modified DataFrame saved to PdatasetCSV/P100_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P6_WR.csv
# Modified DataFrame saved to PdatasetCSV/P40_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P10_W.csv
# Modified DataFrame saved to PdatasetCSV/P6_NoR.csv
# Modified DataFrame saved to PdatasetCSV/P8_R.csv
# Modified DataFrame saved to PdatasetCSV/P10_A.csv
# All CSV files in the 'NdatasetCSV' folder have been processed.
