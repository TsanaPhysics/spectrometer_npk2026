# %% [markdown]
# โค้ดแสดงข้อมูลจากไฟล์ทั้งหมดในโฟลเดอร์ "raw_data" ที่มีนามสกุล ".txt" โดยแสดงข้อมูลของแต่ละไลน์ในแต่ละไฟล์ และเพิ่มบรรทัดว่างหลังจากแต่ละไฟล์เพื่อให้ข้อมูลดูเรียบร้อยขึ้นในผลลัพธ์ที่แสดงออกมาแบบเป็นรายการตามไฟล์ที่อยู่ในโฟลเดอร์ "raw_data" ทั้งหมด.

# %%
import os

# ระบุโฟลเดอร์ raw_data
folder_path = "raw_data"

# ตรวจสอบว่าโฟลเดอร์นี้มีอยู่จริงหรือไม่
if os.path.exists(folder_path):
    # รายการไฟล์ในโฟลเดอร์
    files = os.listdir(folder_path)

    # วนลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์
    for filename in files:
        file_path = os.path.join(folder_path, filename)

        # ตรวจสอบว่าไฟล์นี้เป็นไฟล์ข้อความหรือไม่
        if filename.endswith(".txt"):
            print(f"แสดงข้อมูลจากไฟล์ '{filename}':")
            
            # เปิดไฟล์สำหรับอ่าน
            with open(file_path, "r") as text_file:
                # อ่านและแสดงข้อมูลของแต่ละไลน์
                for line in text_file:
                    print(line.strip())  # ใช้ strip() เพื่อลบช่องว่างที่อาจจะเกิดขึ้น

            print("\n")  # เพิ่มบรรทัดว่างหลังจากแสดงข้อมูลของแต่ละไฮน์
else:
    print(f"โฟลเดอร์ '{folder_path}' ไม่มีอยู่หรือไม่สามารถเข้าถึงได้")
# Out:
# แสดงข้อมูลจากไฟล์ 'P_emp.txt':
# Empty ทดสอบระบบ:
# 1,1,White,6
# 2,2,White,770
# 3,3,White,773
# 4,4,White,766
# 5,5,White,769
# 6,6,White,766
# 7,7,White,761
# 8,8,White,770
# 9,9,White,774
# 10,10,White,771
# 11,11,White,769
# 12,12,White,768
# 13,13,White,764
# 14,14,White,764
# 15,15,White,773
# 16,16,White,776
# 17,17,White,768
# 18,18,White,776
# 19,19,White,767
# 20,20,White,769
# 21,21,White,763
# 22,22,White,773
# 23,23,White,771
# 24,24,White,772
# 25,25,White,776
# 26,26,White,773
# 27,27,White,770
# 28,28,White,761
# 29,29,White,776
# 30,1,Red,768
# 31,2,Red,327
# 32,3,Red,331
# 33,4,Red,337
# 34,5,Red,336
# 35,6,Red,329
# 36,7,Red,333
# 37,8,Red,334
# 38,9,Red,336
# 39,10,Red,329
# 40,11,Red,331
# 41,12,Red,329
# 42,13,Red,331
# 43,14,Red,338
# 44,15,Red,338
# 45,16,Red,329
# 46,17,Red,334
# 47,18,Red,332
# 48,19,Red,338
# 49,20,Red,331
# 50,21,Red,332
# 51,22,Red,334
# 52,23,Red,337
# 53,24,Red,335
# 54,25,Red,340
# 55,26,Red,332
# 56,27,Red,337
# 57,28,Red,334
# 58,29,Red,335
# 59,1,Green,331
# 60,2,Green,196
# 61,3,Green,200
# 62,4,Green,200
# 63,5,Green,196
# 64,6,Green,205
# 65,7,Green,204
# 66,8,Green,194
# 67,9,Green,200
# 68,10,Green,201
# 69,11,Green,198
# 486,22,Black,5
# 487,23,Black,7
# 488,24,Black,6
# 489,25,Black,6
# 490,26,Black,5
# 491,27,Black,6
# 492,28,Black,5
# 493,29,Black,6
# 494,0,Black,6
# 495,0,Black,5
# 496,0,Black,5
# 497,0,Black,7
# 498,0,Black,6
# 499,0,Black,6
# 500,0,Black,6
# 501,0,Black,6
# 502,0,Black,5
# 503,0,Black,6
# 504,0,Black,7
# 505,0,Black,7
# 506,0,Black,5
# 507,0,Black,6
# 508,0,Black,6
# 509,0,Black,6
# 510,0,Black,5
# 511,0,Black,6
# 512,0,Black,5
# 513,0,Black,6
# 514,0,Black,5
# 515,0,Black,6
# 516,0,Black,7
# 517,0,Black,7
# 518,0,Black,5
# 519,0,Black,6
# 520,0,Black,5
# 521,0,Black,6
# 522,0,Black,6
# 523,1,White,6
# 524,2,White,766
# 525,3,White,770
# 526,4,White,769
# 527,5,White,765
# 528,6,White,758
# 529,7,White,768
# 530,8,White,771
# 531,9,White,768
# 532,10,White,762
# 533,11,White,765
# 534,12,White,773
# 535,13,White,769
# 536,14,White,769
# 537,15,White,774
# 538,16,White,764
# 539,17,White,767
# 540,18,White,764
#
#
# แสดงข้อมูลจากไฟล์ 'P10_NRe.txt':
# Phosphorus_No_reag 1,8000 rows
# 1,1,White,6
# 2,2,White,792
# 3,3,White,786
# 4,4,White,791
# 5,5,White,796
# 6,6,White,793
# 7,7,White,799
# 8,8,White,798
# 9,9,White,798
# 10,10,White,797
# 11,11,White,790
# 12,12,White,790
# 13,13,White,796
# 14,14,White,798
# 15,1,Red,791
# 16,2,Red,323
# 17,3,Red,321
# 18,4,Red,326
# 19,5,Red,326
# 20,6,Red,326
# 21,7,Red,320
# 22,8,Red,316
# 23,9,Red,319
# 24,10,Red,325
# 25,11,Red,324
# 26,12,Red,326
# 27,13,Red,323
# 28,14,Red,319
# 29,15,Red,314
# 30,1,Green,315
# 31,2,Green,187
# 32,3,Green,190
# 33,4,Green,189
# 34,5,Green,189
# 35,6,Green,188
# 36,7,Green,187
# 37,8,Green,189
# 38,9,Green,188
# 39,10,Green,188
# 40,11,Green,189
# 41,12,Green,191
# 42,13,Green,193
# 43,14,Green,189
# 44,1,Blue,188
# 45,2,Blue,327
# 46,3,Blue,325
# 47,4,Blue,318
# 48,5,Blue,326
# 49,6,Blue,326
# 50,7,Blue,328
# 51,8,Blue,323
# 52,9,Blue,323
# 53,10,Blue,322
# 54,11,Blue,324
# 55,12,Blue,331
# 56,13,Blue,329
# 57,14,Blue,332
# 58,15,Blue,327
# 59,1,Black,324
# 60,2,Black,7
# 61,3,Black,5
# 62,4,Black,6
# 63,5,Black,5
# 64,6,Black,4
# 65,7,Black,5
# 66,8,Black,4
# 67,9,Black,5
# 68,10,Black,7
# 69,11,Black,6
# 70,12,Black,5
# 71,13,Black,5
# 72,14,Black,6
# 73,15,Black,6
# 74,0,Black,5
# 75,0,Black,4
# 76,0,Black,5
# 77,0,Black,7
# 78,0,Black,4
# 79,0,Black,4
# 80,0,Black,5
# 81,0,Black,5
# 82,0,Black,6
# 83,0,Black,5
# 84,0,Black,5
# 85,0,Black,5
# 86,0,Black,6
# 87,0,Black,6
# 88,1,White,5
# 89,2,White,792
# 90,3,White,794
# 91,4,White,800
# 92,5,White,795
# 93,6,White,793
# 94,7,White,791
# 95,8,White,790
# 96,9,White,793
# 97,10,White,783
# 98,11,White,796
# 99,12,White,792
# 100,13,White,794
# 101,14,White,795
# 102,15,White,796
# 103,1,Red,796
# 104,2,Red,322
# 105,3,Red,326
# 106,4,Red,321
# 107,5,Red,317
# 108,6,Red,318
# 109,7,Red,326
# 110,8,Red,322
# 111,9,Red,319
# 112,10,Red,323
# 113,11,Red,320
# 114,12,Red,322
# 115,13,Red,322
# 116,14,Red,315
# 117,1,Green,317
# 118,2,Green,185
# 119,3,Green,190
# 120,4,Green,193
# 121,5,Green,188
# 122,6,Green,187
# 123,7,Green,193
# 124,8,Green,189
# 125,9,Green,190
# 126,10,Green,189
# 127,11,Green,184
# 128,12,Green,188
# 129,13,Green,187
# 130,14,Green,186
# 131,15,Green,189
# 132,1,Blue,190
# 133,2,Blue,331
# 134,3,Blue,323
# 135,4,Blue,324
# 136,5,Blue,323
# 137,6,Blue,330
# 138,7,Blue,330
# 139,8,Blue,325
# 140,9,Blue,329
# 141,10,Blue,324
# 142,11,Blue,328
# 143,12,Blue,327
# 144,13,Blue,326
# 145,14,Blue,321
# 146,15,Blue,325
# 147,1,Black,331
# 148,2,Black,5
# 149,3,Black,4
# 150,4,Black,5
# 151,5,Black,5
# 152,6,Black,6
# 153,7,Black,6
# 154,8,Black,5
# 155,9,Black,5
# 156,10,Black,5
# 157,11,Black,6
# 158,12,Black,5
# 159,13,Black,4
# 160,14,Black,6
# 161,0,Black,5
# 162,0,Black,5
# 163,0,Black,5
# 164,0,Black,5
# 165,0,Black,7
# 166,0,Black,4
# 167,0,Black,5
# 168,0,Black,6
# 169,0,Black,6
# 170,0,Black,6
# 171,0,Black,5
# 172,0,Black,5
# 173,0,Black,6
# 174,0,Black,6
# 175,0,Black,5
# 176,1,White,4
# 177,2,White,786
# 178,3,White,794
# 179,4,White,794
# 180,5,White,785
# 181,6,White,790
# 182,7,White,794
# 183,8,White,794
# 184,9,White,791
# 185,10,White,790
# 186,11,White,795
# 187,12,White,793
# 188,13,White,793
# 189,14,White,788
# 190,1,Red,791
# 191,2,Red,325
# 192,3,Red,319
# 193,4,Red,316
# 194,5,Red,322
# 195,6,Red,317
# 196,7,Red,325
# 197,8,Red,315
# 198,9,Red,317
# 199,10,Red,321
# 200,11,Red,325
# 201,12,Red,325
# 202,13,Red,321
# 203,14,Red,324
# 204,15,Red,316
# 205,1,Green,318
# 206,2,Green,193
# 207,3,Green,187
# 208,4,Green,189
# 209,5,Green,191
# 210,6,Green,194
# 211,7,Green,189
# 212,8,Green,185
# 213,9,Green,192
# 214,10,Green,193
# 215,11,Green,190
# 216,12,Green,188
# 217,13,Green,188
# 218,14,Green,185
# 219,15,Green,188
# 220,1,Blue,185
# 221,2,Blue,320
# 782,0,Black,5
# 783,0,Black,6
# 784,0,Black,6
# 785,0,Black,6
# 786,0,Black,4
# 787,0,Black,5
# 788,0,Black,5
# 789,0,Black,5
# 790,1,White,5
# 791,2,White,800
# 792,3,White,794
# 793,4,White,796
# 794,5,White,794
# 795,6,White,789
# 796,7,White,796
# 797,8,White,791
# 798,9,White,792
# 799,10,White,795
# 800,11,White,798
# 801,12,White,784
# 802,13,White,791
# 803,14,White,790
# 804,1,Red,793
# 805,2,Red,323
# 806,3,Red,326
# 807,4,Red,319
# 808,5,Red,327
# 809,6,Red,318
# 810,7,Red,315
# 811,8,Red,325
# 812,9,Red,322
# 813,10,Red,321
# 814,11,Red,323
# 815,12,Red,316
# 816,13,Red,328
# 817,14,Red,315
# 818,15,Red,318
# 819,1,Green,317
# 820,2,Green,188
# 821,3,Green,190
# 822,4,Green,190
# 823,5,Green,191
# 824,6,Green,191
# 825,7,Green,192
# 826,8,Green,188
# 827,9,Green,192
# 828,10,Green,194
# 829,11,Green,193
# 830,12,Green,191
# 831,13,Green,192
# 832,14,Green,192
# 833,15,Green,187
# 834,1,Blue,190
# 835,2,Blue,322
# 836,3,Blue,324
# 837,4,Blue,327
# 838,5,Blue,329
# 839,6,Blue,323
# 840,7,Blue,324
# 841,8,Blue,320
# 842,9,Blue,324
# 843,10,Blue,329
# 844,11,Blue,327
# 845,12,Blue,327
# 846,13,Blue,323
# 847,14,Blue,325
# 848,1,Black,325
# 849,2,Black,5
# 850,3,Black,5
# 851,4,Black,4
# 852,5,Black,4
# 853,6,Black,5
# 854,7,Black,5
# 855,8,Black,5
# 856,9,Black,5
# 857,10,Black,5
# 858,11,Black,6
# 859,12,Black,5
# 860,13,Black,5
# 861,14,Black,5
# 862,15,Black,5
# 863,0,Black,4
# 864,0,Black,5
# 865,0,Black,5
# 866,0,Black,4
# 867,0,Black,4
# 868,0,Black,5
# 869,0,Black,5
# 870,0,Black,4
# 871,0,Black,4
# 872,0,Black,4
# 873,0,Black,5
# 874,0,Black,4
# 875,0,Black,5
# 876,0,Black,5
# 877,1,White,4
# 878,2,White,798
# 879,3,White,785
# 880,4,White,794
# 881,5,White,798
# 882,6,White,798
# 883,7,White,795
# 884,8,White,798
# 885,9,White,800
# 886,10,White,793
# 887,11,White,797
# 888,12,White,799
# 889,13,White,789
# 890,14,White,791
# 891,15,White,791
# 892,1,Red,795
# 893,2,Red,320
# 894,3,Red,326
# 895,4,Red,325
# 896,5,Red,325
# 897,6,Red,324
# 898,7,Red,312
# 899,8,Red,321
# 900,9,Red,320
# 901,10,Red,325
# 902,11,Red,326
# 903,12,Red,323
# 904,13,Red,321
# 905,14,Red,326
# 906,15,Red,320
# 907,1,Green,323
# 908,2,Green,188
# 909,3,Green,196
# 910,4,Green,189
# 911,5,Green,193
# 912,6,Green,191
# 913,7,Green,188
# 914,8,Green,187
# 915,9,Green,189
# 916,10,Green,191
# 917,11,Green,188
# 918,12,Green,185
# 919,13,Green,188
# 920,14,Green,191
# 921,1,Blue,192
# 922,2,Blue,325
# 23,9,Red,96
# 24,10,Red,99
# 25,11,Red,98
# 26,12,Red,98
# 27,13,Red,102
# 28,14,Red,101
# 29,15,Red,98
# 30,1,Green,99
# 31,2,Green,80
# 32,3,Green,83
# 33,4,Green,80
# 34,5,Green,78
# 35,6,Green,81
# 36,7,Green,80
# 37,8,Green,80
# 38,9,Green,78
# 39,10,Green,80
# 40,11,Green,78
# 41,12,Green,82
# 42,13,Green,79
# 43,14,Green,79
# 44,15,Green,83
# 45,1,Blue,79
# 46,2,Blue,50
# 47,3,Blue,52
# 48,4,Blue,51
# 49,5,Blue,52
# 50,6,Blue,51
# 51,7,Blue,53
# 52,8,Blue,50
# 53,9,Blue,54
# 54,10,Blue,51
# 55,11,Blue,50
# 56,12,Blue,51
# 57,13,Blue,54
# 58,14,Blue,50
# 59,1,Black,51
# 60,2,Black,4
# 61,3,Black,4
# 62,4,Black,4
# 63,5,Black,4
# 64,6,Black,3
# 65,7,Black,4
# 66,8,Black,4
# 67,9,Black,4
# 68,10,Black,4
# 69,11,Black,3
# 70,12,Black,4
# 71,13,Black,4
# 72,14,Black,4
# 73,15,Black,4
# 74,0,Black,4
# 75,0,Black,4
# 76,0,Black,4
# 77,0,Black,4
# 78,0,Black,4
# 79,0,Black,5
# 80,0,Black,5
# 81,0,Black,4
# 82,0,Black,4
# 83,0,Black,4
# 84,0,Black,4
# 85,0,Black,5
# 86,0,Black,4
# 87,0,Black,4
# 88,0,Black,4
# 89,1,White,4
# 90,2,White,210
# 91,3,White,211
# 92,4,White,211
# 93,5,White,210
# 94,6,White,205
# 95,7,White,206
# 96,8,White,208
# 97,9,White,209
# 98,10,White,201
# 99,11,White,207
# 100,12,White,206
# 101,13,White,208
# 102,14,White,206
# 103,1,Red,209
# 104,2,Red,89
# 105,3,Red,93
# 106,4,Red,92
# 107,5,Red,87
# 108,6,Red,93
# 109,7,Red,89
# 110,8,Red,88
# 111,9,Red,89
# 112,10,Red,88
# 113,11,Red,88
# 114,12,Red,89
# 115,13,Red,89
# 116,14,Red,87
# 117,15,Red,93
# 118,1,Green,90
# 119,2,Green,75
# 120,3,Green,77
# 121,4,Green,75
# 122,5,Green,76
# 123,6,Green,77
# 124,7,Green,77
# 125,8,Green,74
# 126,9,Green,74
# 127,10,Green,76
# 128,11,Green,74
# 129,12,Green,77
# 130,13,Green,75
# 131,14,Green,79
# 132,15,Green,77
# 133,1,Blue,75
# 134,2,Blue,49
# 135,3,Blue,46
# 136,4,Blue,46
# 137,5,Blue,50
# 138,6,Blue,49
# 139,7,Blue,44
# 140,8,Blue,47
# 141,9,Blue,48
# 142,10,Blue,46
# 143,11,Blue,45
# 144,12,Blue,44
# 145,13,Blue,46
# 146,14,Blue,45
# 147,1,Black,47
# 148,2,Black,3
# 149,3,Black,5
# 150,4,Black,4
# 151,5,Black,5
# 152,6,Black,4
# 153,7,Black,3
# 154,8,Black,4
# 155,9,Black,4
# 156,10,Black,4
# 157,11,Black,4
# 158,12,Black,4
# 159,13,Black,4
# 160,14,Black,4
# 161,15,Black,3
# 162,0,Black,4
# 163,0,Black,4
# 164,0,Black,3
# 165,0,Black,4
# 166,0,Black,4
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black
# 444,4,White,180
# 445,5,White,179
# 446,6,White,179
# 447,7,White,182
# 448,8,White,184
# 449,9,White,177
# 450,10,White,177
# 451,11,White,180
# 452,12,White,181
# 453,13,White,181
# 454,14,White,179
# 455,15,White,177
# 456,1,Red,180
# 457,2,Red,77
# 458,3,Red,78
# 459,4,Red,77
# 460,5,Red,75
# 461,6,Red,76
# 462,7,Red,80
# 463,8,Red,77
# 464,9,Red,80
# 465,10,Red,76
# 466,11,Red,76
# 467,12,Red,81
# 468,13,Red,82
# 469,14,Red,79
# 470,15,Red,79
# 471,1,Green,79
# 472,2,Green,70
# 473,3,Green,70
# 474,4,Green,69
# 475,5,Green,69
# 476,6,Green,68
# 477,7,Green,69
# 478,8,Green,68
# 479,9,Green,71
# 480,10,Green,67
# 481,11,Green,69
# 482,12,Green,68
# 483,13,Green,66
# 484,14,Green,67
# 485,1,Blue,71
# 486,2,Blue,42
# 487,3,Blue,38
# 488,4,Blue,37
# 489,5,Blue,37
# 490,6,Blue,38
# 491,7,Blue,38
# 492,8,Blue,42
# 493,9,Blue,37
# 494,10,Blue,38
# 495,11,Blue,39
# 496,12,Blue,37
# 497,13,Blue,39
# 498,14,Blue,37
# 499,15,Blue,37
# 500,1,Black,39
# 501,2,Black,4
# 502,3,Black,4
# 503,4,Black,4
# 504,5,Black,3
# 505,6,Black,4
# 506,7,Black,4
# 507,8,Black,4
# 508,9,Black,4
# 509,10,Black,3
# 510,11,Black,4
# 511,12,Black,3
# 512,13,Black,4
# 513,14,Black,4
# 514,15,Black,4
# 515,0,Black,4
# 516,0,Black,4
# 517,0,Black,4
# 518,0,Black,4
# 519,0,Black,3
# 520,0,Black,4
# 521,0,Black,4
# 522,0,Black,4
# 523,0,Black,4
# 524,0,Black,3
# 525,0,Black,4
# 526,0,Black,4
# 527,0,Black,4
# 528,0,Black,4
# 529,1,White,3
# 530,2,White,172
# 531,3,White,179
# 532,4,White,176
# 533,5,White,172
# 534,6,White,177
# 535,7,White,173
# 536,8,White,174
# 537,9,White,180
# 538,10,White,173
# 539,11,White,177
# 540,12,White,174
# 541,13,White,176
# 542,14,White,172
# 543,15,White,177
# 544,1,Red,172
# 545,2,Red,76
# 546,3,Red,77
# 547,4,Red,75
# 548,5,Red,75
# 549,6,Red,77
# 550,7,Red,76
# 551,8,Red,77
# 552,9,Red,75
# 553,10,Red,75
# 554,11,Red,75
# 555,12,Red,77
# 556,13,Red,75
# 557,14,Red,79
# 558,15,Red,77
# 559,1,Green,75
# 560,2,Green,66
# 561,3,Green,71
# 562,4,Green,67
# 563,5,Green,68
# 564,6,Green,68
# 565,7,Green,67
# 566,8,Green,72
# 567,9,Green,70
# 568,10,Green,66
# 569,11,Green,69
# 570,12,Green,68
# 571,13,Green,72
# 572,14,Green,67
# 573,15,Green,70
# 574,1,Blue,70
# 575,2,Blue,40
# 576,3,Blue,40
# 577,4,Blue,36
# 578,5,Blue,38
# 579,6,Blue,37
# 580,7,Blue,36
# 581,8,Blue,39
# 582,9,Blue,36
# 583,10,Blue,37
# 724,5,Red,77
# 725,6,Red,77
# 726,7,Red,72
# 727,8,Red,72
# 728,9,Red,72
# 729,10,Red,75
# 730,11,Red,76
# 731,12,Red,74
# 732,13,Red,71
# 733,14,Red,73
# 734,15,Red,74
# 735,1,Green,72
# 736,2,Green,66
# 737,3,Green,69
# 738,4,Green,65
# 739,5,Green,66
# 740,6,Green,69
# 741,7,Green,68
# 742,8,Green,68
# 743,9,Green,65
# 744,10,Green,62
# 745,11,Green,67
# 746,12,Green,67
# 747,13,Green,69
# 748,14,Green,65
# 749,15,Green,69
# 750,1,Blue,67
# 751,2,Blue,35
# 752,3,Blue,35
# 753,4,Blue,37
# 754,5,Blue,34
# 755,6,Blue,38
# 756,7,Blue,34
# 757,8,Blue,35
# 758,9,Blue,37
# 759,10,Blue,35
# 760,11,Blue,38
# 761,12,Blue,36
# 762,13,Blue,34
# 763,14,Blue,33
# 764,15,Blue,35
# 765,1,Black,36
# 766,2,Black,4
# 767,3,Black,4
# 768,4,Black,4
# 769,5,Black,4
# 770,6,Black,4
# 771,7,Black,3
# 772,8,Black,4
# 773,9,Black,3
# 774,10,Black,4
# 775,11,Black,4
# 776,12,Black,5
# 777,13,Black,4
# 778,14,Black,4
# 779,0,Black,4
# 780,0,Black,4
# 781,0,Black,4
# 782,0,Black,3
# 783,0,Black,4
# 784,0,Black,4
# 785,0,Black,4
# 786,0,Black,4
# 787,0,Black,4
# 788,0,Black,5
# 789,0,Black,4
# 790,0,Black,3
# 791,0,Black,4
# 792,0,Black,3
# 793,0,Black,4
# 794,1,White,5
# 795,2,White,168
# 796,3,White,166
# 797,4,White,164
# 798,5,White,168
# ...
# 799,6,White,820
# 800,7,White,814
# 801,8,White,820
# 802,9,White,826
# 803,10,White,821
# 804,11,White,822
# 805,12,White,822
# 806,13,White,821
# 807,14,White,821
# 808,1,Red,822
# 809,2,Red,341
# 810,3,Red,341
# 811,4,Red,344
# 812,5,Red,340
# 813,6,Red,344
# 814,7,Red,334
# 815,8,Red,336
# 816,9,Red,340
# 817,10,Red,339
# 818,11,Red,339
# 819,12,Red,343
# 820,13,Red,339
# 821,14,Red,341
# 822,15,Red,336
# 823,1,Green,339
# 824,2,Green,196
# 825,3,Green,204
# 826,4,Green,196
# 827,5,Green,198
# 828,6,Green,202
# 829,7,Green,196
# 830,8,Green,195
# 831,9,Green,197
# 832,10,Green,196
# 833,11,Green,197
# 834,12,Green,200
# 835,13,Green,196
# 836,14,Green,203
# 837,15,Green,196
# 838,1,Blue,197
# 839,2,Blue,328
# 840,3,Blue,332
# 841,4,Blue,330
# 842,5,Blue,336
# 843,6,Blue,336
# 844,7,Blue,336
# 845,8,Blue,340
# 846,9,Blue,335
# 847,10,Blue,325
# 848,11,Blue,336
# 849,12,Blue,334
# 850,13,Blue,338
# 851,14,Blue,331
# 852,1,Black,332
# 853,2,Black,7
# 854,3,Black,6
# 855,4,Black,5
# 856,5,Black,6
# 857,6,Black,5
# 858,7,Black,6
# 859,8,Black,9
# 860,9,Black,7
# 861,10,Black,7
# 862,11,Black,8
# 863,12,Black,7
# 864,13,Black,6
# 865,14,Black,5
# 866,15,Black,7
# 867,0,Black,7
# 868,0,Black,6
# 869,0,Black,7
# 870,0,Black,8
# 871,0,Black,6
# 872,0,Black,7
# 873,0,Black,5
# 874,0,Black,8
# 875,0,Black,6
# 876,0,Black,5
# 877,0,Black,7
# 878,0,Black,8
# 879,0,Black,7
# 880,0,Black,6
# 881,0,Black,7
# 882,1,White,7
# 883,2,White,819
# 884,3,White,821
# 885,4,White,822
# 886,5,White,826
# 887,6,White,825
# 888,7,White,817
# 889,8,White,824
# 890,9,White,826
# 891,10,White,815
# 892,11,White,817
# 893,12,White,820
# 894,13,White,820
# 895,14,White,826
# 896,1,Red,821
# 897,2,Red,341
# 898,3,Red,336
# 899,4,Red,338
# 900,5,Red,338
# 901,6,Red,342
# 902,7,Red,347
# 903,8,Red,340
# 904,9,Red,342
# 905,10,Red,344
# 906,11,Red,340
# 907,12,Red,341
# 908,13,Red,341
# 909,14,Red,341
# 910,15,Red,339
# 911,1,Green,341
# 912,2,Green,197
# 913,3,Green,199
# 914,4,Green,200
# 915,5,Green,194
# 916,6,Green,202
# 917,7,Green,191
# 918,8,Green,198
# 919,9,Green,195
# 920,10,Green,198
# 921,11,Green,197
# 922,12,Green,201
# 923,13,Green,194
# 924,14,Green,197
# 925,15,Green,201
# 926,1,Blue,195
# 927,2,Blue,335
# 928,3,Blue,323
# 929,4,Blue,337
# 930,5,Blue,334
# 931,6,Blue,327
# 932,7,Blue,333
# 933,8,Blue,334
# 934,9,Blue,332
# 935,10,Blue,336
# 936,11,Blue,331
# 937,12,Blue,330
# 938,13,Blue,333
# 939,14,Blue,331
# 940,1,Black,333
# 941,2,Black,7
# 942,3,Black,7
# 943,4,Black,5
# 944,5,Black,5
# 945,6,Black,7
# 946,7,Black,7
# 947,8,Black,6
# 948,9,Black,5
# 949,10,Black,5
# 950,11,Black,5
# 951,12,Black,6
# 952,13,Black,5
# 953,14,Black,5
# 954,15,Black,5
# 955,0,Black,7
# 956,0,Black,8
# 957,0,Black,6
# 958,0,Black,6
# 959,0,Black,7
# 960,0,Black,6
# 961,0,Black,6
# 962,0,Black,5
# 963,0,Black,8
# 964,0,Black,6
# 965,0,Black,6
# 966,0,Black,5
# 967,0,Black,5
# 968,0,Black,5
# 969,0,Black,6
# 970,1,White,6
# 971,2,White,818
# 972,3,White,814
# 973,4,White,822
# 974,5,White,821
# 975,6,White,825
# 976,7,White,820
# 977,8,White,823
# 978,9,White,820
# 979,10,White,820
# 980,11,White,825
# 981,12,White,820
# 982,13,White,827
# 983,14,White,827
# 984,15,White,812
# 985,1,Red,822
# 986,2,Red,337
# 987,3,Red,340
# 988,4,Red,343
# 989,5,Red,341
# 990,6,Red,336
# 991,7,Red,339
# 992,8,Red,341
# 993,9,Red,338
# 994,10,Red,341
# 995,11,Red,339
# 996,12,Red,346
# 997,13,Red,345
# 998,14,Red,341
# 999,1,Green,344
# 1000,2,Green,197
# 1001,3,Green,200
# 1002,4,Green,196
# 1769,7,White,826
# 1770,8,White,824
# 1771,9,White,826
# 1772,10,White,821
# 1773,11,White,823
# 1774,12,White,810
# 1775,13,White,823
# 1776,14,White,826
# 1777,15,White,823
# 1778,1,Red,818
# 1779,2,Red,344
# 1780,3,Red,339
# 1781,4,Red,342
# 1782,5,Red,337
# 1783,6,Red,345
# 1784,7,Red,339
# 1785,8,Red,339
# 1786,9,Red,339
# 1787,10,Red,334
# 1788,11,Red,342
# 1789,12,Red,340
# 1790,13,Red,343
# 1791,14,Red,345
# 1792,1,Green,335
# 1793,2,Green,197
# 1794,3,Green,200
# 1795,4,Green,201
# 1796,5,Green,191
# 1797,6,Green,195
# 1798,7,Green,196
# 1799,8,Green,198
# 1800,9,Green,201

# %% [markdown]
# โค้ดแปลงไฟล์ .txt ทุกไฟล์ในโฟลเดอร์ "raw_data" เป็นไฟล์ .csv และบันทึกในโฟลเดอร์ "datasetCSV" โดยลบข้อมูลในแถวแรกของแต่ละไฟล์ .txt ก่อนจะเขียนลงในไฟล์ .csv ที่สร้างขึ้นใหม่

# %%
import os
import csv

# ระบุโฟลเดอร์ raw_data
input_folder_path = "raw_data"

# ระบุโฟลเดอร์ที่จะบันทึกไฟล์ .csv
output_folder_path = "datasetCSV"

# ตรวจสอบว่าโฟลเดอร์ output_folder_path มีอยู่หรือไม่ และสร้างถ้าไม่มี
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# รายการไฟล์ในโฟลเดอร์ input_folder_path
files = os.listdir(input_folder_path)

# วนลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์ input_folder_path
for filename in files:
    input_file_path = os.path.join(input_folder_path, filename)

    # ตรวจสอบว่าไฟล์นี้เป็นไฟล์ข้อความหรือไม่
    if filename.endswith(".txt"):
        # สร้างชื่อไฟล์ .csv ใหม่โดยนำชื่อไฟล์เดิมมาใช้
        output_file_path = os.path.join(output_folder_path, os.path.splitext(filename)[0] + ".csv")

        # เปิดไฟล์ .txt สำหรับอ่าน
        with open(input_file_path, "r") as txt_file:
            # อ่านข้อมูลทั้งหมดจากไฟล์ .txt
            lines = txt_file.readlines()

        # ตรวจสอบว่ามีข้อมูลในไฟล์หรือไม่
        if len(lines) > 0:
            # ลบข้อมูลในแถวแรก
            lines = lines[1:]

            # เปิดไฟล์ .csv สำหรับเขียน
            with open(output_file_path, "w", newline='') as csv_file:
                # สร้างอ็อบเจ็กต์ writer สำหรับเขียนข้อมูล CSV
                csv_writer = csv.writer(csv_file)

                # เขียนข้อมูลลงในไฟล์ .csv
                for line in lines:
                    # แบ่งข้อมูลในแต่ละบรรทัดด้วยเครื่องหมาย "," และลบช่องว่างด้านหน้าและหลัง
                    row_data = line.strip().split(",")
                    csv_writer.writerow(row_data)

        print(f"แปลงไฟล์ '{filename}' และบันทึกเป็น '{os.path.basename(output_file_path)}'")

print("เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ datasetCSV")
# Out:
# แปลงไฟล์ 'P_emp.txt' และบันทึกเป็น 'P_emp.csv'
# แปลงไฟล์ 'P10_NRe.txt' และบันทึกเป็น 'P10_NRe.csv'
# แปลงไฟล์ 'P100.txt' และบันทึกเป็น 'P100.csv'
# แปลงไฟล์ 'P_water.txt' และบันทึกเป็น 'P_water.csv'
# แปลงไฟล์ 'P10.txt' และบันทึกเป็น 'P10.csv'
# แปลงไฟล์ 'P_urea.txt' และบันทึกเป็น 'P_urea.csv'
# แปลงไฟล์ 'P1000.txt' และบันทึกเป็น 'P1000.csv'
# แปลงไฟล์ 'P1000_NRe.txt' และบันทึกเป็น 'P1000_NRe.csv'
# แปลงไฟล์ 'P_soil.txt' และบันทึกเป็น 'P_soil.csv'
# แปลงไฟล์ 'P0.txt' และบันทึกเป็น 'P0.csv'
# แปลงไฟล์ 'P100_NRe.txt' และบันทึกเป็น 'P100_NRe.csv'
# เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ datasetCSV

# %%
        # เปิดไฟล์ .csv สำหรับอ่าน
        with open(output_file_path, "r") as csv_file:
            # อ่านข้อมูล CSV
            csv_reader = csv.reader(csv_file)
            
            # แสดงข้อมูลที่อ่านจากไฟล์ .csv บนหน้าจอ
            print(f"ข้อมูลในไฟล์ '{os.path.basename(output_file_path)}':")
            for row in csv_reader:
                print(row)
# Out:
# ข้อมูลในไฟล์ 'P100_NRe.csv':
# ['1', '1', 'White', '4']
# ['2', '2', 'White', '830']
# ['3', '3', 'White', '822']
# ['4', '4', 'White', '832']
# ['5', '5', 'White', '832']
# ['6', '6', 'White', '823']
# ['7', '7', 'White', '833']
# ['8', '8', 'White', '826']
# ['9', '9', 'White', '828']
# ['10', '10', 'White', '831']
# ['11', '11', 'White', '818']
# ['12', '12', 'White', '834']
# ['13', '13', 'White', '829']
# ['14', '14', 'White', '831']
# ['15', '1', 'Red', '832']
# ['16', '2', 'Red', '343']
# ['17', '3', 'Red', '343']
# ['18', '4', 'Red', '343']
# ['19', '5', 'Red', '336']
# ['20', '6', 'Red', '343']
# ['21', '7', 'Red', '343']
# ['22', '8', 'Red', '345']
# ['23', '9', 'Red', '346']
# ['24', '10', 'Red', '348']
# ['25', '11', 'Red', '345']
# ['26', '12', 'Red', '341']
# ['27', '13', 'Red', '347']
# ['28', '14', 'Red', '339']
# ['29', '15', 'Red', '342']
# ['30', '1', 'Green', '338']
# ['31', '2', 'Green', '197']
# ['32', '3', 'Green', '198']
# ['33', '4', 'Green', '195']
# ['34', '5', 'Green', '197']
# ['35', '6', 'Green', '202']
# ['36', '7', 'Green', '198']
# ['37', '8', 'Green', '199']
# ['38', '9', 'Green', '199']
# ['39', '10', 'Green', '201']
# ['40', '11', 'Green', '201']
# ['41', '12', 'Green', '201']
# ['42', '13', 'Green', '201']
# ['43', '14', 'Green', '202']
# ['44', '15', 'Green', '197']
# ['45', '1', 'Blue', '202']
# ['46', '2', 'Blue', '336']
# ['47', '3', 'Blue', '335']
# ['48', '4', 'Blue', '337']
# ['49', '5', 'Blue', '337']
# ['50', '6', 'Blue', '337']
# ['51', '7', 'Blue', '337']
# ['52', '8', 'Blue', '333']
# ['53', '9', 'Blue', '331']
# ['54', '10', 'Blue', '337']
# ['55', '11', 'Blue', '332']
# ['56', '12', 'Blue', '336']
# ['57', '13', 'Blue', '334']
# ['58', '14', 'Blue', '331']
# ['59', '1', 'Black', '335']
# ['60', '2', 'Black', '6']
# ['61', '3', 'Black', '7']
# ['62', '4', 'Black', '5']
# ['63', '5', 'Black', '5']
# ['64', '6', 'Black', '5']
# ['65', '7', 'Black', '6']
# ['66', '8', 'Black', '5']
# ['67', '9', 'Black', '6']
# ['68', '10', 'Black', '6']
# ['69', '11', 'Black', '7']
# ['70', '12', 'Black', '5']
# ['71', '13', 'Black', '8']
# ['72', '14', 'Black', '7']
# ['73', '15', 'Black', '5']
# ['74', '0', 'Black', '5']
# ['75', '0', 'Black', '6']
# ['76', '0', 'Black', '6']
# ['77', '0', 'Black', '6']
# ['78', '0', 'Black', '4']
# ['79', '0', 'Black', '5']
# ['80', '0', 'Black', '6']
# ['81', '0', 'Black', '6']
# ['82', '0', 'Black', '5']
# ['83', '0', 'Black', '7']
# ['84', '0', 'Black', '7']
# ['85', '0', 'Black', '6']
# ['86', '0', 'Black', '6']
# ['87', '0', 'Black', '5']
# ['88', '0', 'Black', '7']
# ['89', '1', 'White', '5']
# ['90', '2', 'White', '825']
# ['91', '3', 'White', '827']
# ['92', '4', 'White', '826']
# ['93', '5', 'White', '819']
# ['94', '6', 'White', '826']
# ['95', '7', 'White', '823']
# ['96', '8', 'White', '832']
# ['97', '9', 'White', '821']
# ['98', '10', 'White', '822']
# ['99', '11', 'White', '823']
# ['100', '12', 'White', '827']
# ['101', '13', 'White', '820']
# ['102', '14', 'White', '828']
# ['103', '1', 'Red', '821']
# ['104', '2', 'Red', '341']
# ['105', '3', 'Red', '342']
# ['106', '4', 'Red', '341']
# ['107', '5', 'Red', '339']
# ['108', '6', 'Red', '346']
# ['109', '7', 'Red', '336']
# ['110', '8', 'Red', '343']
# ['111', '9', 'Red', '340']
# ['112', '10', 'Red', '341']
# ['113', '11', 'Red', '344']
# ['114', '12', 'Red', '338']
# ['115', '13', 'Red', '341']
# ['116', '14', 'Red', '343']
# ['117', '15', 'Red', '343']
# ['118', '1', 'Green', '335']
# ['119', '2', 'Green', '196']
# ['120', '3', 'Green', '195']
# ['121', '4', 'Green', '196']
# ['122', '5', 'Green', '200']
# ['123', '6', 'Green', '200']
# ['124', '7', 'Green', '196']
# ['125', '8', 'Green', '199']
# ['126', '9', 'Green', '198']
# ['127', '10', 'Green', '197']
# ['128', '11', 'Green', '200']
# ['129', '12', 'Green', '196']
# ['130', '13', 'Green', '198']
# ['131', '14', 'Green', '198']
# ['132', '15', 'Green', '199']
# ['133', '1', 'Blue', '196']
# ['134', '2', 'Blue', '326']
# ['135', '3', 'Blue', '332']
# ['136', '4', 'Blue', '338']
# ['137', '5', 'Blue', '335']
# ['138', '6', 'Blue', '333']
# ['139', '7', 'Blue', '328']
# ['140', '8', 'Blue', '335']
# ['141', '9', 'Blue', '337']
# ['142', '10', 'Blue', '334']
# ['143', '11', 'Blue', '330']
# ['144', '12', 'Blue', '335']
# ['145', '13', 'Blue', '334']
# ['146', '14', 'Blue', '332']
# ['147', '1', 'Black', '335']
# ['148', '2', 'Black', '6']
# ['149', '3', 'Black', '7']
# ['150', '4', 'Black', '6']
# ['151', '5', 'Black', '5']
# ['152', '6', 'Black', '5']
# ['153', '7', 'Black', '6']
# ['154', '8', 'Black', '7']
# ['155', '9', 'Black', '5']
# ['156', '10', 'Black', '5']
# ['157', '11', 'Black', '5']
# ['158', '12', 'Black', '5']
# ['159', '13', 'Black', '5']
# ['160', '14', 'Black', '5']
# ['161', '15', 'Black', '4']
# ['162', '0', 'Black', '6']
# ['163', '0', 'Black', '5']
# ['164', '0', 'Black', '6']
# ['165', '0', 'Black', '6']
# ['166', '0', 'Black', '5']
# ['167', '0', 'Black', '5']
# ['168', '0', 'Black', '6']
# ['169', '0', 'Black', '6']
# ['170', '0', 'Black', '5']
# ['171', '0', 'Black', '6']
# ['172', '0', 'Black', '8']
# ['173', '0', 'Black', '7']
# ['174', '0', 'Black', '6']
# ['175', '0', 'Black', '6']
# ['176', '0', 'Black', '8']
# ['177', '1', 'White', '7']
# ['178', '2', 'White', '825']
# ['179', '3', 'White', '818']
# ['180', '4', 'White', '821']
# ['181', '5', 'White', '822']
# ['182', '6', 'White', '823']
# ['183', '7', 'White', '827']
# ['184', '8', 'White', '814']
# ['185', '9', 'White', '823']
# ['186', '10', 'White', '820']
# ['187', '11', 'White', '822']
# ['188', '12', 'White', '823']
# ['189', '13', 'White', '815']
# ['190', '14', 'White', '824']
# ['191', '1', 'Red', '827']
# ['192', '2', 'Red', '342']
# ['193', '3', 'Red', '336']
# ['194', '4', 'Red', '333']
# ['195', '5', 'Red', '337']
# ['196', '6', 'Red', '343']
# ['197', '7', 'Red', '344']
# ['198', '8', 'Red', '342']
# ['199', '9', 'Red', '346']
# ['200', '10', 'Red', '334']
# ['201', '11', 'Red', '337']
# ['202', '12', 'Red', '339']
# ['203', '13', 'Red', '340']
# ['204', '14', 'Red', '339']
# ['205', '15', 'Red', '339']
# ['206', '1', 'Green', '343']
# ['207', '2', 'Green', '197']
# ['208', '3', 'Green', '197']
# ['209', '4', 'Green', '194']
# ['210', '5', 'Green', '198']
# ['211', '6', 'Green', '202']
# ['212', '7', 'Green', '195']
# ['213', '8', 'Green', '197']
# ['214', '9', 'Green', '200']
# ['215', '10', 'Green', '196']
# ['216', '11', 'Green', '197']
# ['217', '12', 'Green', '195']
# ['218', '13', 'Green', '196']
# ['219', '14', 'Green', '197']
# ['220', '15', 'Green', '200']
# ['221', '1', 'Blue', '194']
# ['222', '2', 'Blue', '335']
# ['223', '3', 'Blue', '335']
# ['224', '4', 'Blue', '330']
# ['225', '5', 'Blue', '337']
# ['226', '6', 'Blue', '329']
# ['227', '7', 'Blue', '331']
# ['228', '8', 'Blue', '335']
# ['229', '9', 'Blue', '333']
# ['230', '10', 'Blue', '332']
# ['231', '11', 'Blue', '338']
# ['232', '12', 'Blue', '336']
# ['233', '13', 'Blue', '334']
# ['234', '14', 'Blue', '330']
# ['235', '15', 'Blue', '328']
# ['236', '1', 'Black', '329']
# ['237', '2', 'Black', '7']
# ['238', '3', 'Black', '6']
# ['239', '4', 'Black', '7']
# ['240', '5', 'Black', '5']
# ['241', '6', 'Black', '6']
# ['242', '7', 'Black', '5']
# ['243', '8', 'Black', '5']
# ['244', '9', 'Black', '6']
# ['245', '10', 'Black', '8']
# ['246', '11', 'Black', '8']
# ['247', '12', 'Black', '6']
# ['248', '13', 'Black', '7']
# ['249', '14', 'Black', '8']
# ['250', '0', 'Black', '6']
# ['251', '0', 'Black', '6']
# ['252', '0', 'Black', '6']
# ['253', '0', 'Black', '7']
# ['254', '0', 'Black', '6']
# ['255', '0', 'Black', '6']
# ['256', '0', 'Black', '6']
# ['257', '0', 'Black', '6']
# ['258', '0', 'Black', '8']
# ['259', '0', 'Black', '6']
# ['260', '0', 'Black', '5']
# ['261', '0', 'Black', '7']
# ['262', '0', 'Black', '7']
# ['263', '0', 'Black', '8']
# ['264', '0', 'Black', '8']
# ['265', '1', 'White', '8']
# ['266', '2', 'White', '824']
# ['267', '3', 'White', '821']
# ['268', '4', 'White', '818']
# ['269', '5', 'White', '828']
# ['270', '6', 'White', '821']
# ['271', '7', 'White', '828']
# ['272', '8', 'White', '821']
# ['273', '9', 'White', '817']
# ['274', '10', 'White', '822']
# ['275', '11', 'White', '823']
# ['276', '12', 'White', '820']
# ['277', '13', 'White', '821']
# ['278', '14', 'White', '821']
# ['279', '15', 'White', '831']
# ['280', '1', 'Red', '823']
# ['281', '2', 'Red', '342']
# ['282', '3', 'Red', '334']
# ['283', '4', 'Red', '345']
# ['284', '5', 'Red', '346']
# ['285', '6', 'Red', '340']
# ['286', '7', 'Red', '344']
# ['287', '8', 'Red', '336']
# ['288', '9', 'Red', '344']
# ['289', '10', 'Red', '339']
# ['290', '11', 'Red', '337']
# ['291', '12', 'Red', '338']
# ['292', '13', 'Red', '339']
# ['293', '14', 'Red', '341']
# ['294', '1', 'Green', '343']
# ['295', '2', 'Green', '195']
# ['296', '3', 'Green', '195']
# ['297', '4', 'Green', '198']
# ['298', '5', 'Green', '204']
# ['299', '6', 'Green', '198']
# ['300', '7', 'Green', '203']
# ['301', '8', 'Green', '197']
# ['302', '9', 'Green', '199']
# ['303', '10', 'Green', '198']
# ['304', '11', 'Green', '198']
# ['305', '12', 'Green', '192']
# ['306', '13', 'Green', '201']
# ['307', '14', 'Green', '198']
# ['308', '15', 'Green', '196']
# ['309', '1', 'Blue', '199']
# ['310', '2', 'Blue', '327']
# ['311', '3', 'Blue', '332']
# ['312', '4', 'Blue', '336']
# ['313', '5', 'Blue', '331']
# ['314', '6', 'Blue', '330']
# ['315', '7', 'Blue', '335']
# ['316', '8', 'Blue', '333']
# ['317', '9', 'Blue', '334']
# ['318', '10', 'Blue', '337']
# ['319', '11', 'Blue', '335']
# ['320', '12', 'Blue', '333']
# ['321', '13', 'Blue', '331']
# ['322', '14', 'Blue', '339']
# ['323', '15', 'Blue', '339']
# ['324', '1', 'Black', '332']
# ['325', '2', 'Black', '9']
# ['326', '3', 'Black', '8']
# ['327', '4', 'Black', '7']
# ['328', '5', 'Black', '8']
# ['329', '6', 'Black', '6']
# ['330', '7', 'Black', '8']
# ['331', '8', 'Black', '7']
# ['332', '9', 'Black', '7']
# ['333', '10', 'Black', '6']
# ['334', '11', 'Black', '5']
# ['335', '12', 'Black', '6']
# ['336', '13', 'Black', '7']
# ['337', '14', 'Black', '5']
# ['338', '0', 'Black', '5']
# ['339', '0', 'Black', '5']
# ['340', '0', 'Black', '7']
# ['341', '0', 'Black', '6']
# ['342', '0', 'Black', '4']
# ['343', '0', 'Black', '5']
# ['344', '0', 'Black', '6']
# ['345', '0', 'Black', '7']
# ['346', '0', 'Black', '7']
# ['347', '0', 'Black', '6']
# ['348', '0', 'Black', '8']
# ['349', '0', 'Black', '7']
# ['350', '0', 'Black', '6']
# ['351', '0', 'Black', '6']
# ['352', '0', 'Black', '5']
# ['353', '1', 'White', '5']
# ['354', '2', 'White', '827']
# ['355', '3', 'White', '825']
# ['356', '4', 'White', '816']
# ['357', '5', 'White', '825']
# ['358', '6', 'White', '826']
# ['359', '7', 'White', '817']
# ['360', '8', 'White', '823']
# ['361', '9', 'White', '825']
# ['362', '10', 'White', '829']
# ['363', '11', 'White', '820']
# ['364', '12', 'White', '815']
# ['365', '13', 'White', '820']
# ['366', '14', 'White', '826']
# ['367', '15', 'White', '824']
# ['368', '1', 'Red', '817']
# ['369', '2', 'Red', '339']
# ['370', '3', 'Red', '344']
# ['371', '4', 'Red', '344']
# ['372', '5', 'Red', '338']
# ['373', '6', 'Red', '343']
# ['374', '7', 'Red', '345']
# ['375', '8', 'Red', '338']
# ['376', '9', 'Red', '344']
# ['377', '10', 'Red', '338']
# ['378', '11', 'Red', '338']
# ['379', '12', 'Red', '340']
# ['380', '13', 'Red', '334']
# ['381', '14', 'Red', '344']
# ['382', '1', 'Green', '342']
# ['383', '2', 'Green', '196']
# ['384', '3', 'Green', '199']
# ['385', '4', 'Green', '196']
# ['386', '5', 'Green', '198']
# ['387', '6', 'Green', '198']
# ['388', '7', 'Green', '202']
# ['389', '8', 'Green', '197']
# ['390', '9', 'Green', '196']
# ['391', '10', 'Green', '198']
# ['392', '11', 'Green', '195']
# ['393', '12', 'Green', '197']
# ['394', '13', 'Green', '197']
# ['395', '14', 'Green', '194']
# ['396', '15', 'Green', '199']
# ['397', '1', 'Blue', '201']
# ['398', '2', 'Blue', '330']
# ['399', '3', 'Blue', '331']
# ['400', '4', 'Blue', '336']
# ['401', '5', 'Blue', '336']
# ['402', '6', 'Blue', '331']
# ['403', '7', 'Blue', '330']
# ['404', '8', 'Blue', '331']
# ['405', '9', 'Blue', '332']
# ['406', '10', 'Blue', '332']
# ['407', '11', 'Blue', '331']
# ['408', '12', 'Blue', '334']
# ['409', '13', 'Blue', '330']
# ['410', '14', 'Blue', '333']
# ['411', '15', 'Blue', '334']
# ['412', '1', 'Black', '330']
# ['413', '2', 'Black', '4']
# ['414', '3', 'Black', '6']
# ['415', '4', 'Black', '7']
# ['416', '5', 'Black', '8']
# ['417', '6', 'Black', '6']
# ['418', '7', 'Black', '5']
# ['419', '8', 'Black', '6']
# ['420', '9', 'Black', '6']
# ['421', '10', 'Black', '6']
# ['422', '11', 'Black', '5']
# ['423', '12', 'Black', '6']
# ['424', '13', 'Black', '6']
# ['425', '14', 'Black', '6']
# ['426', '0', 'Black', '5']
# ['427', '0', 'Black', '7']
# ['428', '0', 'Black', '7']
# ['429', '0', 'Black', '6']
# ['430', '0', 'Black', '5']
# ['431', '0', 'Black', '7']
# ['432', '0', 'Black', '5']
# ['433', '0', 'Black', '5']
# ['434', '0', 'Black', '6']
# ['435', '0', 'Black', '7']
# ['436', '0', 'Black', '7']
# ['437', '0', 'Black', '7']
# ['438', '0', 'Black', '8']
# ['439', '0', 'Black', '6']
# ['440', '0', 'Black', '5']
# ['441', '1', 'White', '6']
# ['442', '2', 'White', '826']
# ['443', '3', 'White', '821']
# ['444', '4', 'White', '819']
# ['445', '5', 'White', '818']
# ['446', '6', 'White', '822']
# ['447', '7', 'White', '821']
# ['448', '8', 'White', '817']
# ['449', '9', 'White', '823']
# ['450', '10', 'White', '827']
# ['451', '11', 'White', '818']
# ['452', '12', 'White', '822']
# ['453', '13', 'White', '821']
# ['454', '14', 'White', '821']
# ['455', '15', 'White', '818']
# ['456', '1', 'Red', '821']
# ['457', '2', 'Red', '341']
# ['458', '3', 'Red', '335']
# ['459', '4', 'Red', '339']
# ['460', '5', 'Red', '336']
# ['461', '6', 'Red', '340']
# ['462', '7', 'Red', '338']
# ['463', '8', 'Red', '345']
# ['464', '9', 'Red', '345']
# ['465', '10', 'Red', '340']
# ['466', '11', 'Red', '343']
# ['467', '12', 'Red', '334']
# ['468', '13', 'Red', '338']
# ['469', '14', 'Red', '339']
# ['470', '15', 'Red', '341']
# ['471', '1', 'Green', '335']
# ['472', '2', 'Green', '197']
# ['473', '3', 'Green', '193']
# ['474', '4', 'Green', '198']
# ['475', '5', 'Green', '194']
# ['476', '6', 'Green', '199']
# ['477', '7', 'Green', '195']
# ['478', '8', 'Green', '194']
# ['479', '9', 'Green', '197']
# ['480', '10', 'Green', '197']
# ['481', '11', 'Green', '200']
# ['482', '12', 'Green', '197']
# ['483', '13', 'Green', '196']
# ['484', '14', 'Green', '198']
# ['485', '1', 'Blue', '200']
# ['486', '2', 'Blue', '332']
# ['487', '3', 'Blue', '332']
# ['488', '4', 'Blue', '327']
# ['489', '5', 'Blue', '333']
# ['490', '6', 'Blue', '337']
# ['491', '7', 'Blue', '331']
# ['492', '8', 'Blue', '336']
# ['493', '9', 'Blue', '333']
# ['494', '10', 'Blue', '336']
# ['495', '11', 'Blue', '334']
# ['496', '12', 'Blue', '329']
# ['497', '13', 'Blue', '337']
# ['498', '14', 'Blue', '332']
# ['499', '15', 'Blue', '325']
# ['500', '1', 'Black', '330']
# ['501', '2', 'Black', '6']
# ['502', '3', 'Black', '6']
# ['503', '4', 'Black', '5']
# ['504', '5', 'Black', '5']
# ['505', '6', 'Black', '7']
# ['506', '7', 'Black', '7']
# ['507', '8', 'Black', '8']
# ['508', '9', 'Black', '6']
# ['509', '10', 'Black', '8']
# ['510', '11', 'Black', '7']
# ['511', '12', 'Black', '8']
# ['512', '13', 'Black', '5']
# ['513', '14', 'Black', '5']
# ['514', '15', 'Black', '5']
# ['515', '0', 'Black', '6']
# ['516', '0', 'Black', '5']
# ['517', '0', 'Black', '7']
# ['518', '0', 'Black', '7']
# ['519', '0', 'Black', '7']
# ['520', '0', 'Black', '7']
# ['521', '0', 'Black', '7']
# ['522', '0', 'Black', '8']
# ['523', '0', 'Black', '7']
# ['524', '0', 'Black', '7']
# ['525', '0', 'Black', '6']
# ['526', '0', 'Black', '8']
# ['527', '0', 'Black', '7']
# ['528', '0', 'Black', '7']
# ['529', '1', 'White', '7']
# ['530', '2', 'White', '820']
# ['531', '3', 'White', '824']
# ['532', '4', 'White', '822']
# ['533', '5', 'White', '817']
# ['534', '6', 'White', '811']
# ['535', '7', 'White', '824']
# ['536', '8', 'White', '824']
# ['537', '9', 'White', '825']
# ['538', '10', 'White', '820']
# ['539', '11', 'White', '825']
# ['540', '12', 'White', '822']
# ['541', '13', 'White', '820']
# ['542', '14', 'White', '825']
# ['543', '15', 'White', '816']
# ['544', '1', 'Red', '825']
# ['545', '2', 'Red', '340']
# ['546', '3', 'Red', '346']
# ['547', '4', 'Red', '340']
# ['548', '5', 'Red', '335']
# ['549', '6', 'Red', '341']
# ['550', '7', 'Red', '342']
# ['551', '8', 'Red', '343']
# ['552', '9', 'Red', '344']
# ['553', '10', 'Red', '336']
# ['554', '11', 'Red', '339']
# ['555', '12', 'Red', '340']
# ['556', '13', 'Red', '341']
# ['557', '14', 'Red', '341']
# ['558', '15', 'Red', '343']
# ['559', '1', 'Green', '341']
# ['560', '2', 'Green', '201']
# ['561', '3', 'Green', '196']
# ['562', '4', 'Green', '201']
# ['563', '5', 'Green', '199']
# ['564', '6', 'Green', '196']
# ['565', '7', 'Green', '197']
# ['566', '8', 'Green', '194']
# ['567', '9', 'Green', '200']
# ['568', '10', 'Green', '199']
# ['569', '11', 'Green', '204']
# ['570', '12', 'Green', '194']
# ['571', '13', 'Green', '196']
# ['572', '14', 'Green', '197']
# ['573', '1', 'Blue', '197']
# ['574', '2', 'Blue', '332']
# ['575', '3', 'Blue', '331']
# ['576', '4', 'Blue', '328']
# ['577', '5', 'Blue', '334']
# ['578', '6', 'Blue', '332']
# ['579', '7', 'Blue', '329']
# ['580', '8', 'Blue', '331']
# ['581', '9', 'Blue', '330']
# ['582', '10', 'Blue', '331']
# ['583', '11', 'Blue', '331']
# ['584', '12', 'Blue', '335']
# ['585', '13', 'Blue', '332']
# ['586', '14', 'Blue', '335']
# ['587', '15', 'Blue', '331']
# ['588', '1', 'Black', '330']
# ['589', '2', 'Black', '6']
# ['590', '3', 'Black', '6']
# ['591', '4', 'Black', '6']
# ['592', '5', 'Black', '5']
# ['593', '6', 'Black', '5']
# ['594', '7', 'Black', '8']
# ['595', '8', 'Black', '8']
# ['596', '9', 'Black', '6']
# ['597', '10', 'Black', '7']
# ['598', '11', 'Black', '6']
# ['599', '12', 'Black', '6']
# ['600', '13', 'Black', '7']
# ['601', '14', 'Black', '8']
# ['602', '15', 'Black', '7']
# ['603', '0', 'Black', '6']
# ['604', '0', 'Black', '7']
# ['605', '0', 'Black', '7']
# ['606', '0', 'Black', '7']
# ['607', '0', 'Black', '7']
# ['608', '0', 'Black', '9']
# ['609', '0', 'Black', '8']
# ['610', '0', 'Black', '6']
# ['611', '0', 'Black', '5']
# ['612', '0', 'Black', '6']
# ['613', '0', 'Black', '7']
# ['614', '0', 'Black', '6']
# ['615', '0', 'Black', '7']
# ['616', '0', 'Black', '8']
# ['617', '1', 'White', '7']
# ['618', '2', 'White', '818']
# ['619', '3', 'White', '823']
# ['620', '4', 'White', '822']
# ['621', '5', 'White', '818']
# ['622', '6', 'White', '823']
# ['623', '7', 'White', '822']
# ['624', '8', 'White', '822']
# ['625', '9', 'White', '818']
# ['626', '10', 'White', '820']
# ['627', '11', 'White', '828']
# ['628', '12', 'White', '822']
# ['629', '13', 'White', '825']
# ['630', '14', 'White', '818']
# ['631', '15', 'White', '822']
# ['632', '1', 'Red', '824']
# ['633', '2', 'Red', '338']
# ['634', '3', 'Red', '337']
# ['635', '4', 'Red', '341']
# ['636', '5', 'Red', '340']
# ['637', '6', 'Red', '342']
# ['638', '7', 'Red', '344']
# ['639', '8', 'Red', '339']
# ['640', '9', 'Red', '343']
# ['641', '10', 'Red', '345']
# ['642', '11', 'Red', '344']
# ['643', '12', 'Red', '338']
# ['644', '13', 'Red', '339']
# ['645', '14', 'Red', '337']
# ['646', '15', 'Red', '337']
# ['647', '1', 'Green', '342']
# ['648', '2', 'Green', '197']
# ['649', '3', 'Green', '200']
# ['650', '4', 'Green', '200']
# ['651', '5', 'Green', '197']
# ['652', '6', 'Green', '196']
# ['653', '7', 'Green', '194']
# ['654', '8', 'Green', '198']
# ['655', '9', 'Green', '194']
# ['656', '10', 'Green', '202']
# ['657', '11', 'Green', '196']
# ['658', '12', 'Green', '194']
# ['659', '13', 'Green', '200']
# ['660', '14', 'Green', '196']
# ['661', '1', 'Blue', '196']
# ['662', '2', 'Blue', '335']
# ['663', '3', 'Blue', '334']
# ['664', '4', 'Blue', '325']
# ['665', '5', 'Blue', '332']
# ['666', '6', 'Blue', '333']
# ['667', '7', 'Blue', '332']
# ['668', '8', 'Blue', '333']
# ['669', '9', 'Blue', '331']
# ['670', '10', 'Blue', '335']
# ['671', '11', 'Blue', '330']
# ['672', '12', 'Blue', '336']
# ['673', '13', 'Blue', '336']
# ['674', '14', 'Blue', '332']
# ['675', '15', 'Blue', '330']
# ['676', '1', 'Black', '336']
# ['677', '2', 'Black', '6']
# ['678', '3', 'Black', '8']
# ['679', '4', 'Black', '5']
# ['680', '5', 'Black', '7']
# ['681', '6', 'Black', '7']
# ['682', '7', 'Black', '7']
# ['683', '8', 'Black', '6']
# ['684', '9', 'Black', '6']
# ['685', '10', 'Black', '8']
# ['686', '11', 'Black', '7']
# ['687', '12', 'Black', '5']
# ['688', '13', 'Black', '5']
# ['689', '14', 'Black', '5']
# ['690', '15', 'Black', '7']
# ['691', '0', 'Black', '6']
# ['692', '0', 'Black', '6']
# ['693', '0', 'Black', '7']
# ['694', '0', 'Black', '7']
# ['695', '0', 'Black', '8']
# ['696', '0', 'Black', '7']
# ['697', '0', 'Black', '7']
# ['698', '0', 'Black', '7']
# ['699', '0', 'Black', '7']
# ['700', '0', 'Black', '7']
# ['701', '0', 'Black', '7']
# ['702', '0', 'Black', '6']
# ['703', '0', 'Black', '8']
# ['704', '0', 'Black', '6']
# ['705', '0', 'Black', '6']
# ['706', '1', 'White', '6']
# ['707', '2', 'White', '827']
# ['708', '3', 'White', '825']
# ['709', '4', 'White', '822']
# ['710', '5', 'White', '820']
# ['711', '6', 'White', '820']
# ['712', '7', 'White', '815']
# ['713', '8', 'White', '824']
# ['714', '9', 'White', '820']
# ['715', '10', 'White', '822']
# ['716', '11', 'White', '821']
# ['717', '12', 'White', '812']
# ['718', '13', 'White', '822']
# ['719', '14', 'White', '824']
# ['720', '1', 'Red', '818']
# ['721', '2', 'Red', '338']
# ['722', '3', 'Red', '340']
# ['723', '4', 'Red', '338']
# ['724', '5', 'Red', '339']
# ['725', '6', 'Red', '339']
# ['726', '7', 'Red', '339']
# ['727', '8', 'Red', '339']
# ['728', '9', 'Red', '339']
# ['729', '10', 'Red', '339']
# ['730', '11', 'Red', '340']
# ['731', '12', 'Red', '340']
# ['732', '13', 'Red', '345']
# ['733', '14', 'Red', '340']
# ['734', '15', 'Red', '338']
# ['735', '1', 'Green', '341']
# ['736', '2', 'Green', '202']
# ['737', '3', 'Green', '198']
# ['738', '4', 'Green', '199']
# ['739', '5', 'Green', '200']
# ['740', '6', 'Green', '198']
# ['741', '7', 'Green', '203']
# ['742', '8', 'Green', '199']
# ['743', '9', 'Green', '196']
# ['744', '10', 'Green', '200']
# ['745', '11', 'Green', '197']
# ['746', '12', 'Green', '196']
# ['747', '13', 'Green', '199']
# ['748', '14', 'Green', '202']
# ['749', '15', 'Green', '201']
# ['750', '1', 'Blue', '198']
# ['751', '2', 'Blue', '333']
# ['752', '3', 'Blue', '337']
# ['753', '4', 'Blue', '337']
# ['754', '5', 'Blue', '331']
# ['755', '6', 'Blue', '331']
# ['756', '7', 'Blue', '327']
# ['757', '8', 'Blue', '335']
# ['758', '9', 'Blue', '333']
# ['759', '10', 'Blue', '332']
# ['760', '11', 'Blue', '333']
# ['761', '12', 'Blue', '333']
# ['762', '13', 'Blue', '332']
# ['763', '14', 'Blue', '335']
# ['764', '1', 'Black', '331']
# ['765', '2', 'Black', '7']
# ['766', '3', 'Black', '7']
# ['767', '4', 'Black', '7']
# ['768', '5', 'Black', '7']
# ['769', '6', 'Black', '7']
# ['770', '7', 'Black', '5']
# ['771', '8', 'Black', '7']
# ['772', '9', 'Black', '7']
# ['773', '10', 'Black', '8']
# ['774', '11', 'Black', '8']
# ['775', '12', 'Black', '8']
# ['776', '13', 'Black', '6']
# ['777', '14', 'Black', '5']
# ['778', '15', 'Black', '8']
# ['779', '0', 'Black', '7']
# ['780', '0', 'Black', '6']
# ['781', '0', 'Black', '8']
# ['782', '0', 'Black', '6']
# ['783', '0', 'Black', '7']
# ['784', '0', 'Black', '5']
# ['785', '0', 'Black', '7']
# ['786', '0', 'Black', '5']
# ['787', '0', 'Black', '8']
# ['788', '0', 'Black', '7']
# ['789', '0', 'Black', '7']
# ['790', '0', 'Black', '6']
# ['791', '0', 'Black', '7']
# ['792', '0', 'Black', '5']
# ['793', '0', 'Black', '6']
# ['794', '1', 'White', '7']
# ['795', '2', 'White', '819']
# ['796', '3', 'White', '821']
# ['797', '4', 'White', '820']
# ['798', '5', 'White', '826']
# ['799', '6', 'White', '820']
# ['800', '7', 'White', '814']
# ['801', '8', 'White', '820']
# ['802', '9', 'White', '826']
# ['803', '10', 'White', '821']
# ['804', '11', 'White', '822']
# ['805', '12', 'White', '822']
# ['806', '13', 'White', '821']
# ['807', '14', 'White', '821']
# ['808', '1', 'Red', '822']
# ['809', '2', 'Red', '341']
# ['810', '3', 'Red', '341']
# ['811', '4', 'Red', '344']
# ['812', '5', 'Red', '340']
# ['813', '6', 'Red', '344']
# ['814', '7', 'Red', '334']
# ['815', '8', 'Red', '336']
# ['816', '9', 'Red', '340']
# ['817', '10', 'Red', '339']
# ['818', '11', 'Red', '339']
# ['819', '12', 'Red', '343']
# ['820', '13', 'Red', '339']
# ['821', '14', 'Red', '341']
# ['822', '15', 'Red', '336']
# ['823', '1', 'Green', '339']
# ['824', '2', 'Green', '196']
# ['825', '3', 'Green', '204']
# ['826', '4', 'Green', '196']
# ['827', '5', 'Green', '198']
# ['828', '6', 'Green', '202']
# ['829', '7', 'Green', '196']
# ['830', '8', 'Green', '195']
# ['831', '9', 'Green', '197']
# ['832', '10', 'Green', '196']
# ['833', '11', 'Green', '197']
# ['834', '12', 'Green', '200']
# ['835', '13', 'Green', '196']
# ['836', '14', 'Green', '203']
# ['837', '15', 'Green', '196']
# ['838', '1', 'Blue', '197']
# ['839', '2', 'Blue', '328']
# ['840', '3', 'Blue', '332']
# ['841', '4', 'Blue', '330']
# ['842', '5', 'Blue', '336']
# ['843', '6', 'Blue', '336']
# ['844', '7', 'Blue', '336']
# ['845', '8', 'Blue', '340']
# ['846', '9', 'Blue', '335']
# ['847', '10', 'Blue', '325']
# ['848', '11', 'Blue', '336']
# ['849', '12', 'Blue', '334']
# ['850', '13', 'Blue', '338']
# ['851', '14', 'Blue', '331']
# ['852', '1', 'Black', '332']
# ['853', '2', 'Black', '7']
# ['854', '3', 'Black', '6']
# ['855', '4', 'Black', '5']
# ['856', '5', 'Black', '6']
# ['857', '6', 'Black', '5']
# ['858', '7', 'Black', '6']
# ['859', '8', 'Black', '9']
# ['860', '9', 'Black', '7']
# ['861', '10', 'Black', '7']
# ['862', '11', 'Black', '8']
# ['863', '12', 'Black', '7']
# ['864', '13', 'Black', '6']
# ['865', '14', 'Black', '5']
# ['866', '15', 'Black', '7']
# ['867', '0', 'Black', '7']
# ['868', '0', 'Black', '6']
# ['869', '0', 'Black', '7']
# ['870', '0', 'Black', '8']
# ['871', '0', 'Black', '6']
# ['872', '0', 'Black', '7']
# ['873', '0', 'Black', '5']
# ['874', '0', 'Black', '8']
# ['875', '0', 'Black', '6']
# ['876', '0', 'Black', '5']
# ['877', '0', 'Black', '7']
# ['878', '0', 'Black', '8']
# ['879', '0', 'Black', '7']
# ['880', '0', 'Black', '6']
# ['881', '0', 'Black', '7']
# ['882', '1', 'White', '7']
# ['883', '2', 'White', '819']
# ['884', '3', 'White', '821']
# ['885', '4', 'White', '822']
# ['886', '5', 'White', '826']
# ['887', '6', 'White', '825']
# ['888', '7', 'White', '817']
# ['889', '8', 'White', '824']
# ['890', '9', 'White', '826']
# ['891', '10', 'White', '815']
# ['892', '11', 'White', '817']
# ['893', '12', 'White', '820']
# ['894', '13', 'White', '820']
# ['895', '14', 'White', '826']
# ['896', '1', 'Red', '821']
# ['897', '2', 'Red', '341']
# ['898', '3', 'Red', '336']
# ['899', '4', 'Red', '338']
# ['900', '5', 'Red', '338']
# ['901', '6', 'Red', '342']
# ['902', '7', 'Red', '347']
# ['903', '8', 'Red', '340']
# ['904', '9', 'Red', '342']
# ['905', '10', 'Red', '344']
# ['906', '11', 'Red', '340']
# ['907', '12', 'Red', '341']
# ['908', '13', 'Red', '341']
# ['909', '14', 'Red', '341']
# ['910', '15', 'Red', '339']
# ['911', '1', 'Green', '341']
# ['912', '2', 'Green', '197']
# ['913', '3', 'Green', '199']
# ['914', '4', 'Green', '200']
# ['915', '5', 'Green', '194']
# ['916', '6', 'Green', '202']
# ['917', '7', 'Green', '191']
# ['918', '8', 'Green', '198']
# ['919', '9', 'Green', '195']
# ['920', '10', 'Green', '198']
# ['921', '11', 'Green', '197']
# ['922', '12', 'Green', '201']
# ['923', '13', 'Green', '194']
# ['924', '14', 'Green', '197']
# ['925', '15', 'Green', '201']
# ['926', '1', 'Blue', '195']
# ['927', '2', 'Blue', '335']
# ['928', '3', 'Blue', '323']
# ['929', '4', 'Blue', '337']
# ['930', '5', 'Blue', '334']
# ['931', '6', 'Blue', '327']
# ['932', '7', 'Blue', '333']
# ['933', '8', 'Blue', '334']
# ['934', '9', 'Blue', '332']
# ['935', '10', 'Blue', '336']
# ['936', '11', 'Blue', '331']
# ['937', '12', 'Blue', '330']
# ['938', '13', 'Blue', '333']
# ['939', '14', 'Blue', '331']
# ['940', '1', 'Black', '333']
# ['941', '2', 'Black', '7']
# ['942', '3', 'Black', '7']
# ['943', '4', 'Black', '5']
# ['944', '5', 'Black', '5']
# ['945', '6', 'Black', '7']
# ['946', '7', 'Black', '7']
# ['947', '8', 'Black', '6']
# ['948', '9', 'Black', '5']
# ['949', '10', 'Black', '5']
# ['950', '11', 'Black', '5']
# ['951', '12', 'Black', '6']
# ['952', '13', 'Black', '5']
# ['953', '14', 'Black', '5']
# ['954', '15', 'Black', '5']
# ['955', '0', 'Black', '7']
# ['956', '0', 'Black', '8']
# ['957', '0', 'Black', '6']
# ['958', '0', 'Black', '6']
# ['959', '0', 'Black', '7']
# ['960', '0', 'Black', '6']
# ['961', '0', 'Black', '6']
# ['962', '0', 'Black', '5']
# ['963', '0', 'Black', '8']
# ['964', '0', 'Black', '6']
# ['965', '0', 'Black', '6']
# ['966', '0', 'Black', '5']
# ['967', '0', 'Black', '5']
# ['968', '0', 'Black', '5']
# ['969', '0', 'Black', '6']
# ['970', '1', 'White', '6']
# ['971', '2', 'White', '818']
# ['972', '3', 'White', '814']
# ['973', '4', 'White', '822']
# ['974', '5', 'White', '821']
# ['975', '6', 'White', '825']
# ['976', '7', 'White', '820']
# ['977', '8', 'White', '823']
# ['978', '9', 'White', '820']
# ['979', '10', 'White', '820']
# ['980', '11', 'White', '825']
# ['981', '12', 'White', '820']
# ['982', '13', 'White', '827']
# ['983', '14', 'White', '827']
# ['984', '15', 'White', '812']
# ['985', '1', 'Red', '822']
# ['986', '2', 'Red', '337']
# ['987', '3', 'Red', '340']
# ['988', '4', 'Red', '343']
# ['989', '5', 'Red', '341']
# ['990', '6', 'Red', '336']
# ['991', '7', 'Red', '339']
# ['992', '8', 'Red', '341']
# ['993', '9', 'Red', '338']
# ['994', '10', 'Red', '341']
# ['995', '11', 'Red', '339']
# ['996', '12', 'Red', '346']
# ['997', '13', 'Red', '345']
# ['998', '14', 'Red', '341']
# ['999', '1', 'Green', '344']
# ['1000', '2', 'Green', '197']
# ['1001', '3', 'Green', '200']
# ['1002', '4', 'Green', '196']
# ['1003', '5', 'Green', '197']
# ['1004', '6', 'Green', '197']
# ['1005', '7', 'Green', '195']
# ['1006', '8', 'Green', '198']
# ['1007', '9', 'Green', '196']
# ['1008', '10', 'Green', '201']
# ['1009', '11', 'Green', '197']
# ['1010', '12', 'Green', '198']
# ['1011', '13', 'Green', '204']
# ['1012', '14', 'Green', '200']
# ['1013', '15', 'Green', '201']
# ['1014', '1', 'Blue', '200']
# ['1015', '2', 'Blue', '328']
# ['1016', '3', 'Blue', '332']
# ['1017', '4', 'Blue', '332']
# ['1018', '5', 'Blue', '334']
# ['1019', '6', 'Blue', '333']
# ['1020', '7', 'Blue', '338']
# ['1021', '8', 'Blue', '333']
# ['1022', '9', 'Blue', '331']
# ['1023', '10', 'Blue', '336']
# ['1024', '11', 'Blue', '330']
# ['1025', '12', 'Blue', '337']
# ['1026', '13', 'Blue', '332']
# ['1027', '14', 'Blue', '330']
# ['1028', '15', 'Blue', '334']
# ['1029', '1', 'Black', '331']
# ['1030', '2', 'Black', '7']
# ['1031', '3', 'Black', '7']
# ['1032', '4', 'Black', '6']
# ['1033', '5', 'Black', '5']
# ['1034', '6', 'Black', '6']
# ['1035', '7', 'Black', '6']
# ['1036', '8', 'Black', '6']
# ['1037', '9', 'Black', '6']
# ['1038', '10', 'Black', '7']
# ['1039', '11', 'Black', '7']
# ['1040', '12', 'Black', '7']
# ['1041', '13', 'Black', '7']
# ['1042', '14', 'Black', '6']
# ['1043', '0', 'Black', '5']
# ['1044', '0', 'Black', '5']
# ['1045', '0', 'Black', '7']
# ['1046', '0', 'Black', '6']
# ['1047', '0', 'Black', '6']
# ['1048', '0', 'Black', '7']
# ['1049', '0', 'Black', '6']
# ['1050', '0', 'Black', '6']
# ['1051', '0', 'Black', '6']
# ['1052', '0', 'Black', '7']
# ['1053', '0', 'Black', '5']
# ['1054', '0', 'Black', '6']
# ['1055', '0', 'Black', '6']
# ['1056', '0', 'Black', '6']
# ['1057', '0', 'Black', '5']
# ['1058', '1', 'White', '7']
# ['1059', '2', 'White', '824']
# ['1060', '3', 'White', '819']
# ['1061', '4', 'White', '819']
# ['1062', '5', 'White', '822']
# ['1063', '6', 'White', '821']
# ['1064', '7', 'White', '824']
# ['1065', '8', 'White', '820']
# ['1066', '9', 'White', '819']
# ['1067', '10', 'White', '820']
# ['1068', '11', 'White', '817']
# ['1069', '12', 'White', '824']
# ['1070', '13', 'White', '826']
# ['1071', '14', 'White', '825']
# ['1072', '15', 'White', '824']
# ['1073', '1', 'Red', '812']
# ['1074', '2', 'Red', '337']
# ['1075', '3', 'Red', '339']
# ['1076', '4', 'Red', '339']
# ['1077', '5', 'Red', '339']
# ['1078', '6', 'Red', '340']
# ['1079', '7', 'Red', '344']
# ['1080', '8', 'Red', '336']
# ['1081', '9', 'Red', '341']
# ['1082', '10', 'Red', '338']
# ['1083', '11', 'Red', '338']
# ['1084', '12', 'Red', '343']
# ['1085', '13', 'Red', '342']
# ['1086', '14', 'Red', '342']
# ['1087', '1', 'Green', '339']
# ['1088', '2', 'Green', '201']
# ['1089', '3', 'Green', '200']
# ['1090', '4', 'Green', '196']
# ['1091', '5', 'Green', '201']
# ['1092', '6', 'Green', '202']
# ['1093', '7', 'Green', '202']
# ['1094', '8', 'Green', '199']
# ['1095', '9', 'Green', '197']
# ['1096', '10', 'Green', '194']
# ['1097', '11', 'Green', '195']
# ['1098', '12', 'Green', '195']
# ['1099', '13', 'Green', '197']
# ['1100', '14', 'Green', '201']
# ['1101', '15', 'Green', '197']
# ['1102', '1', 'Blue', '202']
# ['1103', '2', 'Blue', '323']
# ['1104', '3', 'Blue', '336']
# ['1105', '4', 'Blue', '328']
# ['1106', '5', 'Blue', '331']
# ['1107', '6', 'Blue', '328']
# ['1108', '7', 'Blue', '327']
# ['1109', '8', 'Blue', '333']
# ['1110', '9', 'Blue', '331']
# ['1111', '10', 'Blue', '333']
# ['1112', '11', 'Blue', '328']
# ['1113', '12', 'Blue', '329']
# ['1114', '13', 'Blue', '329']
# ['1115', '14', 'Blue', '335']
# ['1116', '15', 'Blue', '330']
# ['1117', '1', 'Black', '330']
# ['1118', '2', 'Black', '7']
# ['1119', '3', 'Black', '5']
# ['1120', '4', 'Black', '5']
# ['1121', '5', 'Black', '7']
# ['1122', '6', 'Black', '7']
# ['1123', '7', 'Black', '6']
# ['1124', '8', 'Black', '6']
# ['1125', '9', 'Black', '7']
# ['1126', '10', 'Black', '6']
# ['1127', '11', 'Black', '5']
# ['1128', '12', 'Black', '6']
# ['1129', '13', 'Black', '5']
# ['1130', '14', 'Black', '6']
# ['1131', '0', 'Black', '7']
# ['1132', '0', 'Black', '6']
# ['1133', '0', 'Black', '6']
# ['1134', '0', 'Black', '5']
# ['1135', '0', 'Black', '7']
# ['1136', '0', 'Black', '5']
# ['1137', '0', 'Black', '5']
# ['1138', '0', 'Black', '6']
# ['1139', '0', 'Black', '6']
# ['1140', '0', 'Black', '6']
# ['1141', '0', 'Black', '6']
# ['1142', '0', 'Black', '8']
# ['1143', '0', 'Black', '6']
# ['1144', '0', 'Black', '5']
# ['1145', '0', 'Black', '6']
# ['1146', '1', 'White', '6']
# ['1147', '2', 'White', '818']
# ['1148', '3', 'White', '821']
# ['1149', '4', 'White', '824']
# ['1150', '5', 'White', '826']
# ['1151', '6', 'White', '814']
# ['1152', '7', 'White', '821']
# ['1153', '8', 'White', '824']
# ['1154', '9', 'White', '814']
# ['1155', '10', 'White', '824']
# ['1156', '11', 'White', '824']
# ['1157', '12', 'White', '820']
# ['1158', '13', 'White', '816']
# ['1159', '14', 'White', '819']
# ['1160', '15', 'White', '826']
# ['1161', '1', 'Red', '821']
# ['1162', '2', 'Red', '334']
# ['1163', '3', 'Red', '337']
# ['1164', '4', 'Red', '343']
# ['1165', '5', 'Red', '336']
# ['1166', '6', 'Red', '339']
# ['1167', '7', 'Red', '338']
# ['1168', '8', 'Red', '337']
# ['1169', '9', 'Red', '344']
# ['1170', '10', 'Red', '338']
# ['1171', '11', 'Red', '338']
# ['1172', '12', 'Red', '342']
# ['1173', '13', 'Red', '339']
# ['1174', '14', 'Red', '340']
# ['1175', '15', 'Red', '337']
# ['1176', '1', 'Green', '343']
# ['1177', '2', 'Green', '200']
# ['1178', '3', 'Green', '196']
# ['1179', '4', 'Green', '193']
# ['1180', '5', 'Green', '196']
# ['1181', '6', 'Green', '197']
# ['1182', '7', 'Green', '198']
# ['1183', '8', 'Green', '194']
# ['1184', '9', 'Green', '202']
# ['1185', '10', 'Green', '196']
# ['1186', '11', 'Green', '200']
# ['1187', '12', 'Green', '195']
# ['1188', '13', 'Green', '197']
# ['1189', '14', 'Green', '202']
# ['1190', '1', 'Blue', '198']
# ['1191', '2', 'Blue', '330']
# ['1192', '3', 'Blue', '334']
# ['1193', '4', 'Blue', '334']
# ['1194', '5', 'Blue', '325']
# ['1195', '6', 'Blue', '336']
# ['1196', '7', 'Blue', '331']
# ['1197', '8', 'Blue', '330']
# ['1198', '9', 'Blue', '330']
# ['1199', '10', 'Blue', '332']
# ['1200', '11', 'Blue', '331']
# ['1201', '12', 'Blue', '335']
# ['1202', '13', 'Blue', '328']
# ['1203', '14', 'Blue', '329']
# ['1204', '15', 'Blue', '334']
# ['1205', '1', 'Black', '333']
# ['1206', '2', 'Black', '5']
# ['1207', '3', 'Black', '5']
# ['1208', '4', 'Black', '7']
# ['1209', '5', 'Black', '6']
# ['1210', '6', 'Black', '7']
# ['1211', '7', 'Black', '5']
# ['1212', '8', 'Black', '7']
# ['1213', '9', 'Black', '6']
# ['1214', '10', 'Black', '6']
# ['1215', '11', 'Black', '5']
# ['1216', '12', 'Black', '6']
# ['1217', '13', 'Black', '5']
# ['1218', '14', 'Black', '5']
# ['1219', '15', 'Black', '6']
# ['1220', '0', 'Black', '7']
# ['1221', '0', 'Black', '7']
# ['1222', '0', 'Black', '6']
# ['1223', '0', 'Black', '4']
# ['1224', '0', 'Black', '8']
# ['1225', '0', 'Black', '5']
# ['1226', '0', 'Black', '6']
# ['1227', '0', 'Black', '5']
# ['1228', '0', 'Black', '5']
# ['1229', '0', 'Black', '5']
# ['1230', '0', 'Black', '5']
# ['1231', '0', 'Black', '5']
# ['1232', '0', 'Black', '6']
# ['1233', '0', 'Black', '8']
# ['1234', '1', 'White', '6']
# ['1235', '2', 'White', '815']
# ['1236', '3', 'White', '822']
# ['1237', '4', 'White', '825']
# ['1238', '5', 'White', '814']
# ['1239', '6', 'White', '822']
# ['1240', '7', 'White', '826']
# ['1241', '8', 'White', '813']
# ['1242', '9', 'White', '820']
# ['1243', '10', 'White', '825']
# ['1244', '11', 'White', '814']
# ['1245', '12', 'White', '820']
# ['1246', '13', 'White', '826']
# ['1247', '14', 'White', '822']
# ['1248', '15', 'White', '820']
# ['1249', '1', 'Red', '819']
# ['1250', '2', 'Red', '339']
# ['1251', '3', 'Red', '339']
# ['1252', '4', 'Red', '340']
# ['1253', '5', 'Red', '340']
# ['1254', '6', 'Red', '341']
# ['1255', '7', 'Red', '341']
# ['1256', '8', 'Red', '335']
# ['1257', '9', 'Red', '340']
# ['1258', '10', 'Red', '342']
# ['1259', '11', 'Red', '339']
# ['1260', '12', 'Red', '336']
# ['1261', '13', 'Red', '341']
# ['1262', '14', 'Red', '342']
# ['1263', '15', 'Red', '338']
# ['1264', '1', 'Green', '336']
# ['1265', '2', 'Green', '198']
# ['1266', '3', 'Green', '192']
# ['1267', '4', 'Green', '197']
# ['1268', '5', 'Green', '200']
# ['1269', '6', 'Green', '195']
# ['1270', '7', 'Green', '197']
# ['1271', '8', 'Green', '202']
# ['1272', '9', 'Green', '199']
# ['1273', '10', 'Green', '201']
# ['1274', '11', 'Green', '200']
# ['1275', '12', 'Green', '193']
# ['1276', '13', 'Green', '196']
# ['1277', '14', 'Green', '194']
# ['1278', '1', 'Blue', '195']
# ['1279', '2', 'Blue', '332']
# ['1280', '3', 'Blue', '328']
# ['1281', '4', 'Blue', '333']
# ['1282', '5', 'Blue', '331']
# ['1283', '6', 'Blue', '331']
# ['1284', '7', 'Blue', '326']
# ['1285', '8', 'Blue', '336']
# ['1286', '9', 'Blue', '331']
# ['1287', '10', 'Blue', '328']
# ['1288', '11', 'Blue', '328']
# ['1289', '12', 'Blue', '330']
# ['1290', '13', 'Blue', '333']
# ['1291', '14', 'Blue', '331']
# ['1292', '15', 'Blue', '329']
# ['1293', '1', 'Black', '334']
# ['1294', '2', 'Black', '5']
# ['1295', '3', 'Black', '5']
# ['1296', '4', 'Black', '5']
# ['1297', '5', 'Black', '6']
# ['1298', '6', 'Black', '7']
# ['1299', '7', 'Black', '7']
# ['1300', '8', 'Black', '7']
# ['1301', '9', 'Black', '6']
# ['1302', '10', 'Black', '6']
# ['1303', '11', 'Black', '6']
# ['1304', '12', 'Black', '5']
# ['1305', '13', 'Black', '5']
# ['1306', '14', 'Black', '6']
# ['1307', '15', 'Black', '5']
# ['1308', '0', 'Black', '5']
# ['1309', '0', 'Black', '5']
# ['1310', '0', 'Black', '6']
# ['1311', '0', 'Black', '7']
# ['1312', '0', 'Black', '6']
# ['1313', '0', 'Black', '6']
# ['1314', '0', 'Black', '6']
# ['1315', '0', 'Black', '6']
# ['1316', '0', 'Black', '5']
# ['1317', '0', 'Black', '6']
# ['1318', '0', 'Black', '8']
# ['1319', '0', 'Black', '6']
# ['1320', '0', 'Black', '5']
# ['1321', '0', 'Black', '5']
# ['1322', '1', 'White', '6']
# ['1323', '2', 'White', '816']
# ['1324', '3', 'White', '820']
# ['1325', '4', 'White', '822']
# ['1326', '5', 'White', '815']
# ['1327', '6', 'White', '823']
# ['1328', '7', 'White', '818']
# ['1329', '8', 'White', '823']
# ['1330', '9', 'White', '821']
# ['1331', '10', 'White', '820']
# ['1332', '11', 'White', '814']
# ['1333', '12', 'White', '823']
# ['1334', '13', 'White', '818']
# ['1335', '14', 'White', '820']
# ['1336', '15', 'White', '815']
# ['1337', '1', 'Red', '819']
# ['1338', '2', 'Red', '337']
# ['1339', '3', 'Red', '336']
# ['1340', '4', 'Red', '334']
# ['1341', '5', 'Red', '339']
# ['1342', '6', 'Red', '336']
# ['1343', '7', 'Red', '337']
# ['1344', '8', 'Red', '340']
# ['1345', '9', 'Red', '338']
# ['1346', '10', 'Red', '344']
# ['1347', '11', 'Red', '341']
# ['1348', '12', 'Red', '339']
# ['1349', '13', 'Red', '345']
# ['1350', '14', 'Red', '338']
# ['1351', '15', 'Red', '338']
# ['1352', '1', 'Green', '337']
# ['1353', '2', 'Green', '197']
# ['1354', '3', 'Green', '196']
# ['1355', '4', 'Green', '200']
# ['1356', '5', 'Green', '195']
# ['1357', '6', 'Green', '197']
# ['1358', '7', 'Green', '196']
# ['1359', '8', 'Green', '198']
# ['1360', '9', 'Green', '198']
# ['1361', '10', 'Green', '193']
# ['1362', '11', 'Green', '196']
# ['1363', '12', 'Green', '201']
# ['1364', '13', 'Green', '197']
# ['1365', '14', 'Green', '198']
# ['1366', '1', 'Blue', '202']
# ['1367', '2', 'Blue', '333']
# ['1368', '3', 'Blue', '330']
# ['1369', '4', 'Blue', '330']
# ['1370', '5', 'Blue', '333']
# ['1371', '6', 'Blue', '329']
# ['1372', '7', 'Blue', '332']
# ['1373', '8', 'Blue', '330']
# ['1374', '9', 'Blue', '333']
# ['1375', '10', 'Blue', '331']
# ['1376', '11', 'Blue', '329']
# ['1377', '12', 'Blue', '330']
# ['1378', '13', 'Blue', '331']
# ['1379', '14', 'Blue', '330']
# ['1380', '15', 'Blue', '335']
# ['1381', '1', 'Black', '332']
# ['1382', '2', 'Black', '6']
# ['1383', '3', 'Black', '7']
# ['1384', '4', 'Black', '6']
# ['1385', '5', 'Black', '6']
# ['1386', '6', 'Black', '5']
# ['1387', '7', 'Black', '5']
# ['1388', '8', 'Black', '5']
# ['1389', '9', 'Black', '5']
# ['1390', '10', 'Black', '4']
# ['1391', '11', 'Black', '5']
# ['1392', '12', 'Black', '6']
# ['1393', '13', 'Black', '7']
# ['1394', '14', 'Black', '6']
# ['1395', '15', 'Black', '6']
# ['1396', '0', 'Black', '6']
# ['1397', '0', 'Black', '5']
# ['1398', '0', 'Black', '5']
# ['1399', '0', 'Black', '5']
# ['1400', '0', 'Black', '5']
# ['1401', '0', 'Black', '4']
# ['1402', '0', 'Black', '5']
# ['1403', '0', 'Black', '6']
# ['1404', '0', 'Black', '7']
# ['1405', '0', 'Black', '6']
# ['1406', '0', 'Black', '7']
# ['1407', '0', 'Black', '7']
# ['1408', '0', 'Black', '7']
# ['1409', '0', 'Black', '5']
# ['1410', '0', 'Black', '4']
# ['1411', '1', 'White', '5']
# ['1412', '2', 'White', '817']
# ['1413', '3', 'White', '810']
# ['1414', '4', 'White', '822']
# ['1415', '5', 'White', '820']
# ['1416', '6', 'White', '823']
# ['1417', '7', 'White', '820']
# ['1418', '8', 'White', '821']
# ['1419', '9', 'White', '819']
# ['1420', '10', 'White', '825']
# ['1421', '11', 'White', '824']
# ['1422', '12', 'White', '820']
# ['1423', '13', 'White', '816']
# ['1424', '14', 'White', '820']
# ['1425', '1', 'Red', '818']
# ['1426', '2', 'Red', '341']
# ['1427', '3', 'Red', '345']
# ['1428', '4', 'Red', '336']
# ['1429', '5', 'Red', '332']
# ['1430', '6', 'Red', '339']
# ['1431', '7', 'Red', '335']
# ['1432', '8', 'Red', '337']
# ['1433', '9', 'Red', '338']
# ['1434', '10', 'Red', '342']
# ['1435', '11', 'Red', '338']
# ['1436', '12', 'Red', '339']
# ['1437', '13', 'Red', '343']
# ['1438', '14', 'Red', '341']
# ['1439', '15', 'Red', '341']
# ['1440', '1', 'Green', '332']
# ['1441', '2', 'Green', '196']
# ['1442', '3', 'Green', '197']
# ['1443', '4', 'Green', '195']
# ['1444', '5', 'Green', '198']
# ['1445', '6', 'Green', '197']
# ['1446', '7', 'Green', '193']
# ['1447', '8', 'Green', '198']
# ['1448', '9', 'Green', '201']
# ['1449', '10', 'Green', '193']
# ['1450', '11', 'Green', '202']
# ['1451', '12', 'Green', '196']
# ['1452', '13', 'Green', '200']
# ['1453', '14', 'Green', '194']
# ['1454', '15', 'Green', '197']
# ['1455', '1', 'Blue', '197']
# ['1456', '2', 'Blue', '327']
# ['1457', '3', 'Blue', '336']
# ['1458', '4', 'Blue', '337']
# ['1459', '5', 'Blue', '331']
# ['1460', '6', 'Blue', '328']
# ['1461', '7', 'Blue', '332']
# ['1462', '8', 'Blue', '331']
# ['1463', '9', 'Blue', '331']
# ['1464', '10', 'Blue', '336']
# ['1465', '11', 'Blue', '327']
# ['1466', '12', 'Blue', '334']
# ['1467', '13', 'Blue', '332']
# ['1468', '14', 'Blue', '327']
# ['1469', '1', 'Black', '326']
# ['1470', '2', 'Black', '5']
# ['1471', '3', 'Black', '4']
# ['1472', '4', 'Black', '6']
# ['1473', '5', 'Black', '6']
# ['1474', '6', 'Black', '6']
# ['1475', '7', 'Black', '6']
# ['1476', '8', 'Black', '5']
# ['1477', '9', 'Black', '6']
# ['1478', '10', 'Black', '5']
# ['1479', '11', 'Black', '7']
# ['1480', '12', 'Black', '8']
# ['1481', '13', 'Black', '5']
# ['1482', '14', 'Black', '5']
# ['1483', '15', 'Black', '6']
# ['1484', '0', 'Black', '5']
# ['1485', '0', 'Black', '5']
# ['1486', '0', 'Black', '6']
# ['1487', '0', 'Black', '8']
# ['1488', '0', 'Black', '5']
# ['1489', '0', 'Black', '7']
# ['1490', '0', 'Black', '7']
# ['1491', '0', 'Black', '5']
# ['1492', '0', 'Black', '4']
# ['1493', '0', 'Black', '5']
# ['1494', '0', 'Black', '6']
# ['1495', '0', 'Black', '4']
# ['1496', '0', 'Black', '5']
# ['1497', '0', 'Black', '6']
# ['1498', '0', 'Black', '7']
# ['1499', '1', 'White', '7']
# ['1500', '2', 'White', '822']
# ['1501', '3', 'White', '813']
# ['1502', '4', 'White', '823']
# ['1503', '5', 'White', '826']
# ['1504', '6', 'White', '819']
# ['1505', '7', 'White', '821']
# ['1506', '8', 'White', '819']
# ['1507', '9', 'White', '822']
# ['1508', '10', 'White', '812']
# ['1509', '11', 'White', '821']
# ['1510', '12', 'White', '823']
# ['1511', '13', 'White', '819']
# ['1512', '14', 'White', '829']
# ['1513', '1', 'Red', '827']
# ['1514', '2', 'Red', '342']
# ['1515', '3', 'Red', '336']
# ['1516', '4', 'Red', '339']
# ['1517', '5', 'Red', '344']
# ['1518', '6', 'Red', '341']
# ['1519', '7', 'Red', '342']
# ['1520', '8', 'Red', '339']
# ['1521', '9', 'Red', '343']
# ['1522', '10', 'Red', '337']
# ['1523', '11', 'Red', '334']
# ['1524', '12', 'Red', '345']
# ['1525', '13', 'Red', '341']
# ['1526', '14', 'Red', '336']
# ['1527', '15', 'Red', '336']
# ['1528', '1', 'Green', '342']
# ['1529', '2', 'Green', '200']
# ['1530', '3', 'Green', '195']
# ['1531', '4', 'Green', '201']
# ['1532', '5', 'Green', '197']
# ['1533', '6', 'Green', '195']
# ['1534', '7', 'Green', '197']
# ['1535', '8', 'Green', '196']
# ['1536', '9', 'Green', '203']
# ['1537', '10', 'Green', '201']
# ['1538', '11', 'Green', '198']
# ['1539', '12', 'Green', '194']
# ['1540', '13', 'Green', '196']
# ['1541', '14', 'Green', '195']
# ['1542', '15', 'Green', '195']
# ['1543', '1', 'Blue', '195']
# ['1544', '2', 'Blue', '329']
# ['1545', '3', 'Blue', '330']
# ['1546', '4', 'Blue', '336']
# ['1547', '5', 'Blue', '330']
# ['1548', '6', 'Blue', '329']
# ['1549', '7', 'Blue', '336']
# ['1550', '8', 'Blue', '332']
# ['1551', '9', 'Blue', '335']
# ['1552', '10', 'Blue', '330']
# ['1553', '11', 'Blue', '330']
# ['1554', '12', 'Blue', '334']
# ['1555', '13', 'Blue', '333']
# ['1556', '14', 'Blue', '325']
# ['1557', '1', 'Black', '331']
# ['1558', '2', 'Black', '5']
# ['1559', '3', 'Black', '7']
# ['1560', '4', 'Black', '4']
# ['1561', '5', 'Black', '4']
# ['1562', '6', 'Black', '5']
# ['1563', '7', 'Black', '6']
# ['1564', '8', 'Black', '7']
# ['1565', '9', 'Black', '6']
# ['1566', '10', 'Black', '5']
# ['1567', '11', 'Black', '6']
# ['1568', '12', 'Black', '7']
# ['1569', '13', 'Black', '7']
# ['1570', '14', 'Black', '5']
# ['1571', '15', 'Black', '5']
# ['1572', '0', 'Black', '6']
# ['1573', '0', 'Black', '6']
# ['1574', '0', 'Black', '6']
# ['1575', '0', 'Black', '4']
# ['1576', '0', 'Black', '6']
# ['1577', '0', 'Black', '5']
# ['1578', '0', 'Black', '5']
# ['1579', '0', 'Black', '5']
# ['1580', '0', 'Black', '6']
# ['1581', '0', 'Black', '7']
# ['1582', '0', 'Black', '8']
# ['1583', '0', 'Black', '7']
# ['1584', '0', 'Black', '7']
# ['1585', '0', 'Black', '7']
# ['1586', '0', 'Black', '8']
# ['1587', '1', 'White', '6']
# ['1588', '2', 'White', '818']
# ['1589', '3', 'White', '813']
# ['1590', '4', 'White', '822']
# ['1591', '5', 'White', '823']
# ['1592', '6', 'White', '816']
# ['1593', '7', 'White', '820']
# ['1594', '8', 'White', '818']
# ['1595', '9', 'White', '820']
# ['1596', '10', 'White', '820']
# ['1597', '11', 'White', '820']
# ['1598', '12', 'White', '820']
# ['1599', '13', 'White', '828']
# ['1600', '14', 'White', '821']
# ['1601', '1', 'Red', '821']
# ['1602', '2', 'Red', '334']
# ['1603', '3', 'Red', '341']
# ['1604', '4', 'Red', '340']
# ['1605', '5', 'Red', '338']
# ['1606', '6', 'Red', '344']
# ['1607', '7', 'Red', '342']
# ['1608', '8', 'Red', '342']
# ['1609', '9', 'Red', '340']
# ['1610', '10', 'Red', '338']
# ['1611', '11', 'Red', '342']
# ['1612', '12', 'Red', '339']
# ['1613', '13', 'Red', '334']
# ['1614', '14', 'Red', '339']
# ['1615', '15', 'Red', '342']
# ['1616', '1', 'Green', '341']
# ['1617', '2', 'Green', '200']
# ['1618', '3', 'Green', '202']
# ['1619', '4', 'Green', '197']
# ['1620', '5', 'Green', '195']
# ['1621', '6', 'Green', '202']
# ['1622', '7', 'Green', '192']
# ['1623', '8', 'Green', '201']
# ['1624', '9', 'Green', '200']
# ['1625', '10', 'Green', '195']
# ['1626', '11', 'Green', '202']
# ['1627', '12', 'Green', '196']
# ['1628', '13', 'Green', '197']
# ['1629', '14', 'Green', '194']
# ['1630', '15', 'Green', '199']
# ['1631', '1', 'Blue', '197']
# ['1632', '2', 'Blue', '336']
# ['1633', '3', 'Blue', '334']
# ['1634', '4', 'Blue', '333']
# ['1635', '5', 'Blue', '337']
# ['1636', '6', 'Blue', '329']
# ['1637', '7', 'Blue', '331']
# ['1638', '8', 'Blue', '334']
# ['1639', '9', 'Blue', '336']
# ['1640', '10', 'Blue', '333']
# ['1641', '11', 'Blue', '332']
# ['1642', '12', 'Blue', '332']
# ['1643', '13', 'Blue', '334']
# ['1644', '14', 'Blue', '334']
# ['1645', '1', 'Black', '329']
# ['1646', '2', 'Black', '7']
# ['1647', '3', 'Black', '6']
# ['1648', '4', 'Black', '7']
# ['1649', '5', 'Black', '6']
# ['1650', '6', 'Black', '5']
# ['1651', '7', 'Black', '5']
# ['1652', '8', 'Black', '7']
# ['1653', '9', 'Black', '6']
# ['1654', '10', 'Black', '6']
# ['1655', '11', 'Black', '6']
# ['1656', '12', 'Black', '6']
# ['1657', '13', 'Black', '5']
# ['1658', '14', 'Black', '6']
# ['1659', '15', 'Black', '7']
# ['1660', '0', 'Black', '6']
# ['1661', '0', 'Black', '7']
# ['1662', '0', 'Black', '6']
# ['1663', '0', 'Black', '5']
# ['1664', '0', 'Black', '5']
# ['1665', '0', 'Black', '7']
# ['1666', '0', 'Black', '5']
# ['1667', '0', 'Black', '7']
# ['1668', '0', 'Black', '7']
# ['1669', '0', 'Black', '6']
# ['1670', '0', 'Black', '5']
# ['1671', '0', 'Black', '6']
# ['1672', '0', 'Black', '5']
# ['1673', '0', 'Black', '6']
# ['1674', '0', 'Black', '8']
# ['1675', '1', 'White', '7']
# ['1676', '2', 'White', '825']
# ['1677', '3', 'White', '820']
# ['1678', '4', 'White', '820']
# ['1679', '5', 'White', '818']
# ['1680', '6', 'White', '821']
# ['1681', '7', 'White', '826']
# ['1682', '8', 'White', '823']
# ['1683', '9', 'White', '824']
# ['1684', '10', 'White', '818']
# ['1685', '11', 'White', '822']
# ['1686', '12', 'White', '821']
# ['1687', '13', 'White', '820']
# ['1688', '14', 'White', '829']
# ['1689', '15', 'White', '820']
# ['1690', '1', 'Red', '822']
# ['1691', '2', 'Red', '342']
# ['1692', '3', 'Red', '340']
# ['1693', '4', 'Red', '338']
# ['1694', '5', 'Red', '342']
# ['1695', '6', 'Red', '341']
# ['1696', '7', 'Red', '338']
# ['1697', '8', 'Red', '339']
# ['1698', '9', 'Red', '341']
# ['1699', '10', 'Red', '336']
# ['1700', '11', 'Red', '337']
# ['1701', '12', 'Red', '343']
# ['1702', '13', 'Red', '336']
# ['1703', '14', 'Red', '340']
# ['1704', '1', 'Green', '339']
# ['1705', '2', 'Green', '200']
# ['1706', '3', 'Green', '201']
# ['1707', '4', 'Green', '198']
# ['1708', '5', 'Green', '195']
# ['1709', '6', 'Green', '190']
# ['1710', '7', 'Green', '195']
# ['1711', '8', 'Green', '200']
# ['1712', '9', 'Green', '194']
# ['1713', '10', 'Green', '198']
# ['1714', '11', 'Green', '200']
# ['1715', '12', 'Green', '198']
# ['1716', '13', 'Green', '195']
# ['1717', '14', 'Green', '200']
# ['1718', '15', 'Green', '199']
# ['1719', '1', 'Blue', '196']
# ['1720', '2', 'Blue', '327']
# ['1721', '3', 'Blue', '328']
# ['1722', '4', 'Blue', '331']
# ['1723', '5', 'Blue', '326']
# ['1724', '6', 'Blue', '338']
# ['1725', '7', 'Blue', '329']
# ['1726', '8', 'Blue', '335']
# ['1727', '9', 'Blue', '334']
# ['1728', '10', 'Blue', '331']
# ['1729', '11', 'Blue', '333']
# ['1730', '12', 'Blue', '334']
# ['1731', '13', 'Blue', '331']
# ['1732', '14', 'Blue', '336']
# ['1733', '15', 'Blue', '330']
# ['1734', '1', 'Black', '329']
# ['1735', '2', 'Black', '4']
# ['1736', '3', 'Black', '5']
# ['1737', '4', 'Black', '5']
# ['1738', '5', 'Black', '5']
# ['1739', '6', 'Black', '7']
# ['1740', '7', 'Black', '7']
# ['1741', '8', 'Black', '5']
# ['1742', '9', 'Black', '4']
# ['1743', '10', 'Black', '6']
# ['1744', '11', 'Black', '4']
# ['1745', '12', 'Black', '7']
# ['1746', '13', 'Black', '8']
# ['1747', '14', 'Black', '6']
# ['1748', '0', 'Black', '4']
# ['1749', '0', 'Black', '5']
# ['1750', '0', 'Black', '4']
# ['1751', '0', 'Black', '5']
# ['1752', '0', 'Black', '6']
# ['1753', '0', 'Black', '7']
# ['1754', '0', 'Black', '6']
# ['1755', '0', 'Black', '6']
# ['1756', '0', 'Black', '6']
# ['1757', '0', 'Black', '4']
# ['1758', '0', 'Black', '6']
# ['1759', '0', 'Black', '7']
# ['1760', '0', 'Black', '6']
# ['1761', '0', 'Black', '7']
# ['1762', '0', 'Black', '6']
# ['1763', '1', 'White', '7']
# ['1764', '2', 'White', '822']
# ['1765', '3', 'White', '818']
# ['1766', '4', 'White', '825']
# ['1767', '5', 'White', '818']
# ['1768', '6', 'White', '819']
# ['1769', '7', 'White', '826']
# ['1770', '8', 'White', '824']
# ['1771', '9', 'White', '826']
# ['1772', '10', 'White', '821']
# ['1773', '11', 'White', '823']
# ['1774', '12', 'White', '810']
# ['1775', '13', 'White', '823']
# ['1776', '14', 'White', '826']
# ['1777', '15', 'White', '823']
# ['1778', '1', 'Red', '818']
# ['1779', '2', 'Red', '344']
# ['1780', '3', 'Red', '339']
# ['1781', '4', 'Red', '342']
# ['1782', '5', 'Red', '337']
# ['1783', '6', 'Red', '345']
# ['1784', '7', 'Red', '339']
# ['1785', '8', 'Red', '339']
# ['1786', '9', 'Red', '339']
# ['1787', '10', 'Red', '334']
# ['1788', '11', 'Red', '342']
# ['1789', '12', 'Red', '340']
# ['1790', '13', 'Red', '343']
# ['1791', '14', 'Red', '345']
# ['1792', '1', 'Green', '335']
# ['1793', '2', 'Green', '197']
# ['1794', '3', 'Green', '200']
# ['1795', '4', 'Green', '201']
# ['1796', '5', 'Green', '191']
# ['1797', '6', 'Green', '195']
# ['1798', '7', 'Green', '196']
# ['1799', '8', 'Green', '198']
# ['1800', '9', 'Green', '201']

# %% [markdown]
# เพิ่มหัวตารางในไฟล์ CSV  " column_names = ["No.", "Order", "Color", "Intensity"] "

# %%
import os
import pandas as pd

# Define the column names
column_names = ["No.", "Order", "Color", "Intensity"]

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file with the specified column names
    df = pd.read_csv(file_path, names=column_names)

    # Shift the data in the 'Intensity' column up by one row
    df['Intensity'] = df['Intensity'].shift(-1)

    # Drop rows where 'Order' is equal to 0 and 'Color' is equal to 'Black'
    df = df[(df['Order'] != 0) | (df['Color'] != 'Black')]

    # Specify the original file path and save the modified DataFrame
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to datasetCSV/P1000.csv
# Modified DataFrame saved to datasetCSV/P1000_NRe.csv
# Modified DataFrame saved to datasetCSV/P0.csv
# Modified DataFrame saved to datasetCSV/P_soil.csv
# Modified DataFrame saved to datasetCSV/P100_NRe.csv
# Modified DataFrame saved to datasetCSV/P_emp.csv
# Modified DataFrame saved to datasetCSV/P10_NRe.csv
# Modified DataFrame saved to datasetCSV/P100.csv
# Modified DataFrame saved to datasetCSV/P10.csv
# Modified DataFrame saved to datasetCSV/P_urea.csv
# Modified DataFrame saved to datasetCSV/P_water.csv
# All CSV files in the 'datasetCSV' folder have been processed.

# %% [markdown]
# ลบข้อมูลในแถวสุดท้ายของแต่ละไฟล์ .csv ในโฟลเดอร์ "datasetCSV" และบันทึกไฟล์ด้วยชื่อเดิม หลังจากดำเนินการนี้กับทุกไฟล์ .csv ในโฟลเดอร์ จะแสดงข้อความ "All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name." เพื่อแสดงว่าการประมวลผลเสร็จสิ้นสำหรับทุกไฟล์ในโฟลเดอร์นี้.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Remove the last row from the DataFrame
    df = df.iloc[:-1]

    # Save the modified DataFrame back to the same file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Last row removed and file '{csv_file}' saved with the same name.")

print("All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name.")
# Out:
# Last row removed and file 'P1000.csv' saved with the same name.
# Last row removed and file 'P1000_NRe.csv' saved with the same name.
# Last row removed and file 'P0.csv' saved with the same name.
# Last row removed and file 'P_soil.csv' saved with the same name.
# Last row removed and file 'P100_NRe.csv' saved with the same name.
# Last row removed and file 'P_emp.csv' saved with the same name.
# Last row removed and file 'P10_NRe.csv' saved with the same name.
# Last row removed and file 'P100.csv' saved with the same name.
# Last row removed and file 'P10.csv' saved with the same name.
# Last row removed and file 'P_urea.csv' saved with the same name.
# Last row removed and file 'P_water.csv' saved with the same name.
# All CSV files in the 'datasetCSV' folder have had their last row removed and saved with the same name.

# %% [markdown]
# แปลงค่าในคอลัมน์ "Intensity" ของไฟล์ CSV เป็นจำนวนเต็มและบันทึกไปยังไฟล์ CSV ที่แก้ไขแล้วในโฟลเดอร์ "datasetCSV" ของทุกไฟล์ .csv ที่อยู่ในโฟลเดอร์นั้น การแปลงจะเป็นการเปลี่ยนชนิดข้อมูลเพียงอย่างเดียวและจะไม่มีการปฏิบัติกับข้อมูลที่ไม่ใช่จำนวนเต็ม.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Convert the 'Intensity' column to integers
    df['Intensity'] = df['Intensity'].astype(int)

    # Save the modified DataFrame back to the CSV file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to datasetCSV/P1000.csv
# Modified DataFrame saved to datasetCSV/P1000_NRe.csv
# Modified DataFrame saved to datasetCSV/P0.csv
# Modified DataFrame saved to datasetCSV/P_soil.csv
# Modified DataFrame saved to datasetCSV/P100_NRe.csv
# Modified DataFrame saved to datasetCSV/P_emp.csv
# Modified DataFrame saved to datasetCSV/P10_NRe.csv
# Modified DataFrame saved to datasetCSV/P100.csv
# Modified DataFrame saved to datasetCSV/P10.csv
# Modified DataFrame saved to datasetCSV/P_urea.csv
# Modified DataFrame saved to datasetCSV/P_water.csv
# All CSV files in the 'datasetCSV' folder have been processed.

# %% [markdown]
# โค้ดวนลูปผ่านทุกไฟล์ .csv ในโฟลเดอร์ "datasetCSV" และแสดงข้อมูลจากแต่ละไฟล์ CSV ที่อยู่ในโฟลเดอร์นั้น ผ่านการใช้ pd.read_csv เพื่อโหลดข้อมูลลงใน DataFrame แล้วแสดงผลลัพธ์ด้วย print.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Loop through each CSV file and display its data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Display the data from the current CSV file
    print(f"Data from '{csv_file}':")
    print(df)
    print("\n")

print("All CSV files in the 'datasetCSV' folder have been displayed.")
# Out:
# Data from 'P1000.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        183
# 1        2      2  White        180
# 2        3      3  White        182
# 3        4      4  White        182
# 4        5      5  White        181
# ...    ...    ...    ...        ...
# 1503  1795     12  Green         48
# 1504  1796     13  Green         47
# 1505  1797     14  Green         47
# 1506  1798     15  Green         46
# 1507  1799      1   Blue         21
#
# [1508 rows x 4 columns]
#
#
# Data from 'P1000_NRe.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        839
# 1        2      2  White        840
# 2        3      3  White        841
# 3        4      4  White        842
# 4        5      5  White        836
# ...    ...    ...    ...        ...
# 1502  1795     12  Green        203
# 1503  1796     13  Green        197
# 1504  1797     14  Green        200
# 1505  1798     15  Green        201
# 1506  1799      1   Blue        340
#
# [1507 rows x 4 columns]
#
#
# Data from 'P0.csv':
#      No.  Order  Color  Intensity
# 0      1      1  White        802
# 1      2      2  White        800
# 2      3      3  White        801
# 3      4      4  White        806
# 4      5      5  White        799
# ..   ...    ...    ...        ...
# 446  535     11  White        808
# 447  536     12  White        810
# 448  537     13  White        812
# 449  538     14  White        812
# 450  539     15  White        809
#
# [451 rows x 4 columns]
#
#
# Data from 'P_soil.csv':
#      No.  Order  Color  Intensity
# 0      1      1  White        312
# 1      2      2  White        320
# 2      3      3  White        313
# 3      4      4  White        313
# 4      5      5  White        317
# ..   ...    ...    ...        ...
# 447  535     13  White        324
# 448  536     14  White        326
# 449  537     15  White        329
# 450  538     16  White        329
# 451  539     17  White        327
#
# [452 rows x 4 columns]
#
#
# Data from 'P100_NRe.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        830
# 1        2      2  White        822
# 2        3      3  White        832
# 3        4      4  White        832
# 4        5      5  White        823
# ...    ...    ...    ...        ...
# 1498  1795      4  Green        191
# 1499  1796      5  Green        195
# 1500  1797      6  Green        196
# 1501  1798      7  Green        198
# 1502  1799      8  Green        201
#
# [1503 rows x 4 columns]
#
#
# Data from 'P_emp.csv':
#      No.  Order  Color  Intensity
# 0      1      1  White        770
# 1      2      2  White        773
# 2      3      3  White        766
# 3      4      4  White        769
# 4      5      5  White        766
# ..   ...    ...    ...        ...
# 447  535     13  White        769
# 448  536     14  White        774
# 449  537     15  White        764
# 450  538     16  White        767
# 451  539     17  White        764
#
# [452 rows x 4 columns]
#
#
# Data from 'P10_NRe.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        792
# 1        2      2  White        786
# 2        3      3  White        791
# 3        4      4  White        796
# 4        5      5  White        793
# ...    ...    ...    ...        ...
# 1502  1795     14  Green        188
# 1503  1796     15  Green        194
# 1504  1797      1   Blue        323
# 1505  1798      2   Blue        324
# 1506  1799      3   Blue        329
#
# [1507 rows x 4 columns]
#
#
# Data from 'P100.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        237
# 1        2      2  White        235
# 2        3      3  White        234
# 3        4      4  White        233
# 4        5      5  White        232
# ...    ...    ...    ...        ...
# 1501  1795      3  Green         58
# 1502  1796      4  Green         62
# 1503  1797      5  Green         58
# 1504  1798      6  Green         59
# 1505  1799      7  Green         60
#
# [1506 rows x 4 columns]
#
#
# Data from 'P10.csv':
#        No.  Order  Color  Intensity
# 0        1      1  White        268
# 1        2      2  White        262
# 2        3      3  White        264
# 3        4      4  White        267
# 4        5      5  White        263
# ...    ...    ...    ...        ...
# 998   1195      5    Red        101
# 999   1196      6    Red        100
# 1000  1197      7    Red        103
# 1001  1198      8    Red        102
# 1002  1199      9    Red        101
#
# [1003 rows x 4 columns]
#
#
# Data from 'P_urea.csv':
#      No.  Order  Color  Intensity
# 0      1      1  White        845
# 1      2      2  White        842
# 2      3      3  White        837
# 3      4      4  White        842
# 4      5      5  White        833
# ..   ...    ...    ...        ...
# 446  535     11  White        847
# 447  536     12  White        844
# 448  537     13  White        842
# 449  538     14  White        844
# 450  539     15  White        845
#
# [451 rows x 4 columns]
#
#
# Data from 'P_water.csv':
#      No.  Order  Color  Intensity
# 0      1      1  White        802
# 1      2      2  White        800
# 2      3      3  White        801
# 3      4      4  White        806
# 4      5      5  White        799
# ..   ...    ...    ...        ...
# 446  535     11  White        808
# 447  536     12  White        810
# 448  537     13  White        812
# 449  538     14  White        812
# 450  539     15  White        809
#
# [451 rows x 4 columns]
#
#
# All CSV files in the 'datasetCSV' folder have been displayed.

# %% [markdown]
# # แสดงค่าเฉลี่ยและส่วนเบี่ยงเบนมาตรฐานของแต่ละ Order ของแต่ละ Color  ของแต่ละไฟล์

# %%
import os
import pandas as pd
import numpy as np

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Create empty lists to store the calculated statistics
average_intensity_values = []
std_dev_intensity_values = []

# Loop through each CSV file and calculate statistics for 'Intensity' column
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Group data by 'Order' and 'Color' columns, then calculate mean and standard deviation
    grouped_data = df.groupby(['Order', 'Color'])['Intensity']
    mean_intensity = grouped_data.mean()
    std_dev_intensity = grouped_data.std()

    # Append the calculated statistics to the lists
    average_intensity_values.append(mean_intensity)
    std_dev_intensity_values.append(std_dev_intensity)

# Combine the calculated statistics from all files into one DataFrame
average_intensity_df = pd.concat(average_intensity_values, axis=1)
std_dev_intensity_df = pd.concat(std_dev_intensity_values, axis=1)

# Rename columns to indicate file names
average_intensity_df.columns = csv_files
std_dev_intensity_df.columns = csv_files

# Print the calculated statistics
print("Average Intensity Values:")
print(average_intensity_df)

print("\nStandard Deviation of Intensity Values:")
print(std_dev_intensity_df)
# Out:
# Average Intensity Values:
#               P1000.csv  P1000_NRe.csv      P0.csv  P_soil.csv  P100_NRe.csv  \
# Order Color
# 1     Black    3.900000       5.200000    6.333333    4.000000      6.100000
#       Blue    27.190476     338.428571  291.000000  133.666667    330.700000
#       Green   56.095238     200.857143  216.666667   74.666667    197.952381
#       Red     59.571429     343.714286  353.333333  124.666667    339.666667
#       White  136.476190     836.333333  810.500000  321.500000    821.666667
# ...                 ...            ...         ...         ...           ...
# 29    Green         NaN            NaN  217.666667   73.333333           NaN
#       Red           NaN            NaN  351.333333  123.000000           NaN
#       White         NaN            NaN  812.666667  321.666667           NaN
# 30    Green         NaN            NaN  218.000000         NaN           NaN
#       White         NaN            NaN         NaN         NaN           NaN
#
#               P_emp.csv  P10_NRe.csv    P100.csv     P10.csv  P_urea.csv  \
# Order Color
# 1     Black    5.000000     5.150000    3.950000    4.550000    8.333333
#       Blue   277.000000   326.095238   36.950000   56.750000  321.333333
#       Green  199.666667   189.523810   65.809524   89.550000  229.666667
#       Red    331.333333   322.380952   73.333333  106.380952  350.666667
#       White  767.750000   793.857143  169.047619  241.666667  843.750000
# ...                 ...          ...         ...         ...         ...
# 29    Green  199.666667          NaN         NaN         NaN  228.666667
#       Red    335.666667          NaN         NaN         NaN  350.000000
#       White  769.333333          NaN         NaN         NaN  840.000000
# 30    Green         NaN          NaN         NaN         NaN         NaN
#       White         NaN          NaN         NaN         NaN  836.000000
#
#              P_water.csv
# Order Color
# 1     Black     6.333333
#       Blue    291.000000
#       Green   216.666667
#       Red     353.333333
#       White   810.500000
# ...                  ...
# 29    Green   217.666667
#       Red     351.333333
#       White   812.666667
# 30    Green   218.000000
#       White          NaN
#
# [147 rows x 11 columns]
#
# Standard Deviation of Intensity Values:
#              P1000.csv  P1000_NRe.csv    P0.csv  P_soil.csv  P100_NRe.csv  \
# Order Color
# 1     Black   0.640723       0.695852  1.527525    0.000000      1.209611
#       Blue    5.173191       2.038907  2.645751    2.081666      3.757099
#       Green   6.788997       2.151411  1.154701    3.511885      2.036570
#       Red     9.135488       2.813234  2.309401    1.154701      2.762849
#       White  20.667896       4.640402  6.608076    8.346656      4.234777
# ...                ...            ...       ...         ...           ...
# 29    Green        NaN            NaN  2.516611    1.527525           NaN
#       Red          NaN            NaN  3.055050    1.732051           NaN
#       White        NaN            NaN  4.725816    2.081666           NaN
# 30    Green        NaN            NaN       NaN         NaN           NaN
#       White        NaN            NaN       NaN         NaN           NaN
#
#              P_emp.csv  P10_NRe.csv   P100.csv   P10.csv  P_urea.csv  \
# Order Color
# 1     Black   0.000000     0.875094   0.394034  0.759155    0.577350
#       Blue    1.000000     3.269629   6.320185  3.697439    4.041452
#       Green   3.214550     3.172051   5.635770  3.561120    4.041452
#       Red     6.658328     3.694268   9.603819  4.466276    2.081666
#       White   4.031129     4.552864  23.191542  9.291573    2.629956
# ...                ...          ...        ...       ...         ...
# 29    Green   1.154701          NaN        NaN       NaN    3.214550
#       Red     4.041452          NaN        NaN       NaN    3.000000
#       White   2.309401          NaN        NaN       NaN    2.000000
# 30    Green        NaN          NaN        NaN       NaN         NaN
#       White        NaN          NaN        NaN       NaN         NaN
#
#              P_water.csv
# Order Color
# 1     Black     1.527525
#       Blue      2.645751
#       Green     1.154701
#       Red       2.309401
#       White     6.608076
# ...                  ...
# 29    Green     2.516611
#       Red       3.055050
#       White     4.725816
# 30    Green          NaN
#       White          NaN
#
# [147 rows x 11 columns]

# %% [markdown]
# โค้ดบันทึกข้อมูลค่าเฉลี่ยและส่วนเบี่ยงเบนมาตรฐานของคอลัมน์ "Intensity" ที่คำนวณมาไว้ในไฟล์ "MSD.csv" ซึ่งจะถูกบันทึกในโฟลเดอร์ "datasetCSV" ที่เดียวกับไฟล์ CSV อื่นๆ ที่มีอยู่ในโฟลเดอร์นั้น โดยใช้ to_csv โดยที่ index=True เพื่อรวมข้อมูลรายการลงในไฟล์ "MSD.csv" และ mode='a' เพื่อเพิ่มข้อมูลในโหมดผนวก. คำสั่ง print ที่อยู่ต่อท้ายจะแสดงข้อความยืนยันว่าข้อมูลถูกบันทึกเรียบร้อยแล้ว.

# %%
import os
import pandas as pd
import numpy as np

# Specify the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Create empty lists to store the calculated statistics
average_intensity_values = []
std_dev_intensity_values = []

# Loop through each CSV file and calculate statistics for 'Intensity' column
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Group data by 'Order' and 'Color' columns, then calculate mean and standard deviation
    grouped_data = df.groupby(['Order', 'Color'])['Intensity']
    mean_intensity = grouped_data.mean()
    std_dev_intensity = grouped_data.std()

    # Append the calculated statistics to the lists
    average_intensity_values.append(mean_intensity)
    std_dev_intensity_values.append(std_dev_intensity)

# Combine the calculated statistics from all files into one DataFrame
average_intensity_df = pd.concat(average_intensity_values, axis=1)
std_dev_intensity_df = pd.concat(std_dev_intensity_values, axis=1)

# Rename columns to indicate file names
average_intensity_df.columns = csv_files
std_dev_intensity_df.columns = csv_files

# Print the calculated statistics
print("Average Intensity Values:")
print(average_intensity_df)

print("\nStandard Deviation of Intensity Values:")
print(std_dev_intensity_df)

# Save the calculated statistics to 'MSD.csv'
msd_output_path = os.path.join(folder_path, "MSD.csv")
average_intensity_df.to_csv(msd_output_path, index=True)
std_dev_intensity_df.to_csv(msd_output_path, index=True, mode='a')

print(f"Calculated statistics saved to '{msd_output_path}'")
# Out:
# Average Intensity Values:
#               P1000.csv  P1000_NRe.csv      P0.csv  P_soil.csv  P100_NRe.csv  \
# Order Color
# 1     Black    3.900000       5.200000    6.333333    4.000000      6.100000
#       Blue    27.190476     338.428571  291.000000  133.666667    330.700000
#       Green   56.095238     200.857143  216.666667   74.666667    197.952381
#       Red     59.571429     343.714286  353.333333  124.666667    339.666667
#       White  136.476190     836.333333  810.500000  321.500000    821.666667
# ...                 ...            ...         ...         ...           ...
# 29    Green         NaN            NaN  217.666667   73.333333           NaN
#       Red           NaN            NaN  351.333333  123.000000           NaN
#       White         NaN            NaN  812.666667  321.666667           NaN
# 30    Green         NaN            NaN  218.000000         NaN           NaN
#       White         NaN            NaN         NaN         NaN           NaN
#
#               P_emp.csv  P10_NRe.csv    P100.csv     P10.csv  P_urea.csv  \
# Order Color
# 1     Black    5.000000     5.150000    3.950000    4.550000    8.333333
#       Blue   277.000000   326.095238   36.950000   56.750000  321.333333
#       Green  199.666667   189.523810   65.809524   89.550000  229.666667
#       Red    331.333333   322.380952   73.333333  106.380952  350.666667
#       White  767.750000   793.857143  169.047619  241.666667  843.750000
# ...                 ...          ...         ...         ...         ...
# 29    Green  199.666667          NaN         NaN         NaN  228.666667
#       Red    335.666667          NaN         NaN         NaN  350.000000
#       White  769.333333          NaN         NaN         NaN  840.000000
# 30    Green         NaN          NaN         NaN         NaN         NaN
#       White         NaN          NaN         NaN         NaN  836.000000
#
#              P_water.csv
# Order Color
# 1     Black     6.333333
#       Blue    291.000000
#       Green   216.666667
#       Red     353.333333
#       White   810.500000
# ...                  ...
# 29    Green   217.666667
#       Red     351.333333
#       White   812.666667
# 30    Green   218.000000
#       White          NaN
#
# [147 rows x 11 columns]
#
# Standard Deviation of Intensity Values:
#              P1000.csv  P1000_NRe.csv    P0.csv  P_soil.csv  P100_NRe.csv  \
# Order Color
# 1     Black   0.640723       0.695852  1.527525    0.000000      1.209611
#       Blue    5.173191       2.038907  2.645751    2.081666      3.757099
#       Green   6.788997       2.151411  1.154701    3.511885      2.036570
#       Red     9.135488       2.813234  2.309401    1.154701      2.762849
#       White  20.667896       4.640402  6.608076    8.346656      4.234777
# ...                ...            ...       ...         ...           ...
# 29    Green        NaN            NaN  2.516611    1.527525           NaN
#       Red          NaN            NaN  3.055050    1.732051           NaN
#       White        NaN            NaN  4.725816    2.081666           NaN
# 30    Green        NaN            NaN       NaN         NaN           NaN
#       White        NaN            NaN       NaN         NaN           NaN
#
#              P_emp.csv  P10_NRe.csv   P100.csv   P10.csv  P_urea.csv  \
# Order Color
# 1     Black   0.000000     0.875094   0.394034  0.759155    0.577350
#       Blue    1.000000     3.269629   6.320185  3.697439    4.041452
#       Green   3.214550     3.172051   5.635770  3.561120    4.041452
#       Red     6.658328     3.694268   9.603819  4.466276    2.081666
#       White   4.031129     4.552864  23.191542  9.291573    2.629956
# ...                ...          ...        ...       ...         ...
# 29    Green   1.154701          NaN        NaN       NaN    3.214550
#       Red     4.041452          NaN        NaN       NaN    3.000000
#       White   2.309401          NaN        NaN       NaN    2.000000
# 30    Green        NaN          NaN        NaN       NaN         NaN
#       White        NaN          NaN        NaN       NaN         NaN
#
#              P_water.csv
# Order Color
# 1     Black     1.527525
#       Blue      2.645751
#       Green     1.154701
#       Red       2.309401
#       White     6.608076
# ...                  ...
# 29    Green     2.516611
#       Red       3.055050
#       White     4.725816
# 30    Green          NaN
#       White          NaN
#
# [147 rows x 11 columns]
# Calculated statistics saved to 'datasetCSV/MSD.csv'

# %% [markdown]
# # บันทึกไฟล์  โดยให้จำนวนลูปอยู่ในแนวนอน ของแต่ละไฟล์ MSD_.   ในโฟลเดอร์ datasetCSV

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(original_file_path)

    # Group the DataFrame by 'Order' and 'Color' columns
    grouped_df = df.groupby(['Order', 'Color']).mean().reset_index()

    # Define the new file name
    new_file_name = "MSD_" + csv_file

    # Define the new file path
    new_file_path = os.path.join(folder_path, new_file_name)

    # Save the grouped DataFrame to the new file
    grouped_df.to_csv(new_file_path, index=False)

    # Print a confirmation message
    print(f"Grouped DataFrame saved to {new_file_path}")

print("All CSV files in the 'datasetCSV' folder have been processed.")
# Out:
# Grouped DataFrame saved to datasetCSV/MSD_P1000.csv
# Grouped DataFrame saved to datasetCSV/MSD_P1000_NRe.csv
# Grouped DataFrame saved to datasetCSV/MSD_P0.csv
# Grouped DataFrame saved to datasetCSV/MSD_P_soil.csv
# Grouped DataFrame saved to datasetCSV/MSD_P100_NRe.csv
# Grouped DataFrame saved to datasetCSV/MSD_P_emp.csv
# Grouped DataFrame saved to datasetCSV/MSD_P10_NRe.csv
# Grouped DataFrame saved to datasetCSV/MSD_P100.csv
# Grouped DataFrame saved to datasetCSV/MSD_P10.csv
# Grouped DataFrame saved to datasetCSV/MSD_P_urea.csv
# Grouped DataFrame saved to datasetCSV/MSD_P_water.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '3.90.6407232755171873' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 18
#      15 df = pd.read_csv(original_file_path)
#      17 # Group the DataFrame by 'Order' and 'Color' columns
# ---> 18 grouped_df = df.groupby(['Order', 'Color']).mean().reset_index()
#      20 # Define the new file name
#      21 new_file_name = "MSD_" + csv_file
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# แสดงผลแบบ จำนวนลูปอยู่ในแนวนอน ของแต่ละไฟล์ MSD_.   ในโฟลเดอร์ datasetCSV

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    grouped_df = pd.read_csv(original_file_path)

    # Create a pivot table with 'Order' as columns and 'Color' as index
    pivot_df = grouped_df.pivot_table(values='Intensity', index='Color', columns='Order')

    # Print the pivot table
    print(f"Pivot Table for {csv_file}:")
    print(pivot_df)
    print("\n")
# Out:
# Pivot Table for MSD_P0.csv:
# Order          1           2           3           4           5           6   \
# Color
# Black
# Red    349.333333  351.666667  351.000000  345.000000  349.666667  351.000000
# White  842.000000  840.333333  846.000000  844.000000  842.333333  846.333333
#
# Order          28          29     30
# Color
# Black    7.333333    6.666667    NaN
# Blue   316.666667  319.000000    NaN
# Green  226.000000  228.666667    NaN
# Red    346.000000  350.000000    NaN
# White  845.333333  840.000000  836.0
#
# [5 rows x 30 columns]

# %% [markdown]
# บันทึกข้อมูลแต่ละไฟล์ โดยใช้ชื่อเดิมในโฟล์เดอร์เดิม

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    original_file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    grouped_df = pd.read_csv(original_file_path)

    # Create a pivot table with 'Order' as columns and 'Color' as index
    pivot_df = grouped_df.pivot_table(values='Intensity', index='Color', columns='Order', aggfunc='mean')

    # Calculate the standard deviation for each row (Color)
    std_deviation = pivot_df.apply(lambda row: row.std(), axis=1)

    # Add the mean and standard deviation columns to the pivot table
    pivot_df['Mean'] = pivot_df.mean(axis=1)
    pivot_df['Std Deviation'] = std_deviation

    # Print the pivot table
    print(f"Pivot Table for {csv_file}:")
    print(pivot_df)
    print("\n")

    # Save the pivot table to a CSV file with the same name in the same folder
    output_file_path = os.path.join(folder_path, csv_file)
    pivot_df.to_csv(output_file_path, index=True)
# Out:
# Pivot Table for MSD_P0.csv:
# Order           1           2           3           4           5           6  \
# Color
# Black    6.333333    7.333333    7.000000    5.666667    7.333333    6.333333
# Blue   291.000000  289.000000  287.666667  288.666667  292.666667  287.666667
# Green  216.666667  217.666667  217.666667  216.666667  217.333333  216.000000
# Red    353.333333  349.333333  355.333333  350.000000  349.666667  348.666667
# White  810.500000  807.500000  812.750000  811.250000  807.000000  809.750000
#
# Order           7           8           9          10  ...          23  \
# Color                                                  ...
# Black    6.666667    7.333333    7.000000    6.000000  ...    6.000000
# Blue   289.000000  290.333333  290.666667  291.333333  ...  292.000000
# Green  217.000000  218.000000  218.333333  216.000000  ...  219.666667
# Red    349.333333  352.666667  352.000000  351.333333  ...  351.666667
# White  812.000000  810.250000  806.500000  811.750000  ...  807.666667
#
# Order          24          25          26          27          28          29  \
# Color
# Black    6.666667    7.000000    7.000000    6.666667    6.000000    7.333333
# Blue   290.333333  291.666667  288.333333  290.000000  288.000000  289.333333
# Green  219.000000  217.000000  217.000000  217.666667  215.000000  217.666667
# Red    353.000000  352.000000  351.000000  350.666667  351.666667  351.333333
# White  811.000000  807.000000  810.000000  811.333333  813.000000  812.666667
#
# Order     30        Mean  Std Deviation
# Color
# Black    NaN    6.609195       0.471985
# Blue     NaN  289.781609       1.414987
# Green  218.0  217.222222       1.511979
# Red      NaN  351.241379       1.603311
# White    NaN  809.847701       1.881677
#
# [5 rows x 32 columns]
#
#
# Pivot Table for MSD_P100_NRe.csv:
# Order           1           2           3           4           5           6  \
# Color
# Black    6.100000    6.250000    5.800000    5.850000    6.050000    6.150000
# Blue   330.700000  332.100000  332.750000  332.700000  331.850000  331.550000
# Green  197.952381  197.761905  197.476190  197.333333  198.095238  196.714286
# Red    339.666667  339.333333  340.000000  338.666667  341.190476  340.523810
# White  821.666667  819.904762  822.095238  821.619048  821.095238  822.047619
#
# Order           7           8           9          10          11          12  \
# Color
# Black    6.450000    5.950000    6.250000    6.100000    6.300000    6.050000
# Blue   333.500000  332.650000  332.850000  331.450000  333.300000  332.700000
# Green  197.666667  198.190476  197.700000  198.600000  196.450000  197.650000
# Red    339.571429  341.666667  339.666667  339.714286  340.190476  340.619048
# White  821.666667  821.761905  821.619048  821.000000  820.952381  821.571429
#
# Order          13          14          15        Mean  Std Deviation
# Color
# Black
# Red    336.000000  334.666667  330.000000  332.333333  ...  335.666667
# White  770.250000  768.750000  766.500000  766.500000  ...  771.333333
#
# Order          23          24          25          26          27          28  \
# Color
# Black    5.666667    6.000000    5.666667    6.000000    5.333333    6.333333
# Blue   276.000000  275.333333  277.333333  279.000000  278.000000  277.000000
# Green  202.666667  199.666667  199.000000  200.000000  198.666667  199.000000
# Red    333.666667  333.666667  332.000000  336.333333  333.333333  332.000000
# White  771.333333  772.333333  768.000000  768.666667  768.333333  771.666667
#
# Order          29        Mean  Std Deviation
# Color
# Black    5.666667    5.919540       0.442353
# Blue   279.333333  276.747126       1.595269
# Green  199.666667  199.425287       1.479748
# Red    335.666667  333.816092       1.820488
# White  769.333333  769.005747       2.133204
#
# [5 rows x 31 columns]
#
#
# Pivot Table for MSD_P_urea.csv:
# Order           1           2           3           4           5           6  \
# Color
# Black    8.333333    7.000000    7.000000    7.000000    8.000000    7.333333
# Blue   321.333333  317.666667  315.666667  317.333333  320.333333  321.666667
# Green  229.666667  228.000000  228.000000  230.666667  231.666667  225.333333
# Red    350.666667  351.333333  349.666667  347.666667  352.000000  348.666667
# White  843.750000  841.250000  842.500000  841.250000  841.500000  841.500000
#
# Order           7           8           9          10  ...          23  \
# Color                                                  ...
# Black    7.333333    8.000000    7.333333    7.333333  ...    7.333333
# Blue   319.000000  318.666667  317.333333  320.333333  ...  315.333333
# Green  225.333333  229.000000  228.666667  227.000000  ...  228.000000
# Red    348.666667  355.333333  349.333333  350.000000  ...  351.666667
# White  842.000000  839.750000  841.250000  840.000000  ...  840.333333
#
# Order          24          25          26          27          28          29  \
# Color
# Black    7.666667    7.666667    8.000000    8.000000    7.333333    6.666667
# Blue   318.333333  317.666667  319.666667  319.000000  316.666667  319.000000
# Green  226.333333  230.666667  228.666667  229.000000  226.000000  228.666667
# Red    351.000000  345.000000  349.666667  351.000000  346.000000  350.000000
# White  846.000000  844.000000  842.333333  846.333333  845.333333  840.000000
#
# Order     30        Mean  Std Deviation
# Color
# Black    NaN    7.505747       0.442043
# Blue     NaN  318.712644       2.083046
# Green    NaN  228.425287       1.620544
# Red      NaN  349.505747       2.154030
# White  836.0  842.336111       2.590829
#
# [5 rows x 32 columns]

# %% [markdown]
# แสดงค่าเฉลี่ย และส่วนเบี่ยงเบนมาตรฐานของแต่ละไฟล์

# %%
import os
import pandas as pd

# Define the folder path
folder_path = "datasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.startswith("MSD_") and f.endswith(".csv")]

for csv_file in csv_files:
    if "MSD_P" in csv_file:
        # Construct the full file path
        original_file_path = os.path.join(folder_path, csv_file)

        # Read the CSV file into a DataFrame
        grouped_df = pd.read_csv(original_file_path)

        # Create a pivot table with 'Order' as columns and 'Color' as index
        pivot_df = grouped_df.pivot_table(values='Mean', index='Color', aggfunc='mean')

        # Calculate the standard deviation for each row (Color)
        std_deviation = pivot_df.apply(lambda row: row.std(), axis=1)

        # Add the mean and standard deviation columns to the pivot table
        pivot_df['Mean'] = pivot_df.mean(axis=1)
        pivot_df['Std Deviation'] = std_deviation

        # Print the 'Mean' column for 'MSD_P' files
        print(f"Mean for {csv_file} (MSD_P):")
        print(pivot_df['Mean'])
        print("\n")
# Out:
# Mean for MSD_P0.csv (MSD_P):
# Color
# Black      6.609195
# Blue     289.781609
# Green    217.222222
# Red      351.241379
# White    809.847701
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P100_NRe.csv (MSD_P):
# Color
# Black      6.058095
# Blue     332.192222
# Green    197.708413
# Red      339.994921
# White    821.534127
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P10.csv (MSD_P):
# Color
# Black      4.546250
# Blue      56.534706
# Green     89.628750
# Red      106.604167
# White    242.278095
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P1000.csv (MSD_P):
# Color
# Black      3.884444
# Blue      27.158413
# Green     56.049573
# Red       59.258730
# White    134.952381
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P_soil.csv (MSD_P):
# Color
# Black      4.252874
# Blue     134.298851
# Green     74.091954
# Red      124.172414
# White    320.873563
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P10_NRe.csv (MSD_P):
# Color
# Black      5.102222
# Blue     325.541270
# Green    189.382540
# Red      321.712821
# White    794.203663
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P1000_NRe.csv (MSD_P):
# Color
# Black      5.147436
# Blue     337.478315
# Green    201.272222
# Red      343.888889
# White    835.830159
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P_water.csv (MSD_P):
# Color
# Black      6.609195
# Blue     289.781609
# Green    217.222222
# Red      351.241379
# White    809.847701
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P100.csv (MSD_P):
# Color
# Black      3.887143
# Blue      36.370952
# Green     66.568730
# Red       73.619048
# White    168.649206
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P_emp.csv (MSD_P):
# Color
# Black      5.919540
# Blue     276.747126
# Green    199.425287
# Red      333.816092
# White    769.005747
# Name: Mean, dtype: float64
#
#
# Mean for MSD_P_urea.csv (MSD_P):
# Color
# Black      7.505747
# Blue     318.712644
# Green    228.425287
# Red      349.505747
# White    842.336111
# Name: Mean, dtype: float64

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# วนลูปเพื่ออ่านและแสดงข้อมูลจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลทุกคอลัมน์และแถว
    with pd.option_context('display.max_columns', None, 'display.max_rows', None):
        print(df)
    
    print("\n" + "="*80 + "\n")  # สร้างเส้นขั้นบรรทัด
# Out:
# ชื่อไฟล์: MSD_P0.csv
#
#    Color           1           2           3           4           5  \
# 0  Black    6.333333    7.333333    7.000000    5.666667    7.333333
# 1   Blue  291.000000  289.000000  287.666667  288.666667  292.666667
# 2  Green  216.666667  217.666667  217.666667  216.666667  217.333333
# 3    Red  353.333333  349.333333  355.333333  350.000000  349.666667
# 4  White  810.500000  807.500000  812.750000  811.250000  807.000000
#
#             6           7           8           9          10          11  \
# 0    6.333333    6.666667    7.333333    7.000000    6.000000    6.333333
# 1  287.666667  289.000000  290.333333  290.666667  291.333333  291.333333
# 2  216.000000  217.000000  218.000000  218.333333  216.000000  215.333333
# 3  348.666667  349.333333  352.666667  352.000000  351.333333  351.000000
# 4  809.750000  812.000000  810.250000  806.500000  811.750000  810.250000
#
#            12          13          14          15          16          17  \
# 0    6.666667    6.000000    6.000000    6.333333    6.333333    7.000000
# 1  290.666667  290.000000  289.666667  290.666667  287.000000  289.666667
# 2  219.666667  215.666667  215.000000  218.000000  215.333333  219.000000
# 3  352.000000  352.333333  351.000000  349.666667  350.666667  353.333333
# 4  807.250000  810.750000  808.750000  809.000000  811.333333  808.333333
#
#            18          19          20          21          22          23  \
# 0    6.666667    6.333333    6.666667    7.000000    6.666667    6.000000
# 1  291.000000  288.000000  289.333333  289.333333  289.333333  292.000000
# 2  217.333333  220.000000  216.333333  218.666667  214.000000  219.666667
# 3  353.666667  350.666667  349.333333  350.666667  348.666667  351.666667
csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.058095       0.208648
# 1   Blue  332.192222       0.799897
# 2  Green  197.708413       0.560317
# 3    Red  339.994921       0.792742
# 4  White  821.534127       0.915162
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10.csv
#
#    Color        Mean  Std Deviation
# 0  Black    4.546250       0.119031
# 1   Blue   56.534706       0.503925
# 2  Green   89.628750       0.325643
# 3    Red  106.604167       0.605372
# 4  White  242.278095       0.648020
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.884444       0.123678
# 1   Blue   27.158413       0.345975
# 2  Green   56.049573       0.443496
# 3    Red   59.258730       0.408334
# 4  White  134.952381       1.038925
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P_soil.csv
#
#    Color        Mean  Std Deviation
# 0  Black    4.252874       0.424032
# 1   Blue  134.298851       1.212844
# 2  Green   74.091954       0.885942
# 3    Red  124.172414       1.542058
# 4  White  320.873563       1.760403
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_NRe.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.102222       0.203722
# 1   Blue  325.541270       0.720935
# 2  Green  189.382540       0.480294
# 3    Red  321.712821       1.000078
# 4  White  794.203663       0.731430
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_NRe.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.147436       0.161346
# 1   Blue  337.478315       0.536703
# 2  Green  201.272222       0.465415
# 3    Red  343.888889       0.538648
# 4  White  835.830159       0.935257
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P_water.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.609195       0.471985
# 1   Blue  289.781609       1.414987
# 2  Green  217.222222       1.511979
# 3    Red  351.241379       1.603311
# 4  White  809.847701       1.881677
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.887143       0.117064
# 1   Blue   36.370952       0.475151
# 2  Green   66.568730       0.464653
# 3    Red   73.619048       0.319438
# 4  White  168.649206       1.242876
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P_emp.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.919540       0.442353
# 1   Blue  276.747126       1.595269
# 2  Green  199.425287       1.479748
# 3    Red  333.816092       1.820488
# 4  White  769.005747       2.133204
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P_urea.csv
#
#    Color        Mean  Std Deviation
# 0  Black    7.505747       0.442043
# 1   Blue  318.712644       2.083046
# 2  Green  228.425287       1.620544
# 3    Red  349.505747       2.154030
# 4  White  842.336111       2.590829
#
# ================================================================================

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้างรายการเปล่าที่จะเก็บข้อมูล
result_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    print(f"ชื่อไฟล์: {csv_file}\n")
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # แสดงข้อมูลเฉพาะคอลัมน์ที่ระบุ
    selected_columns = df[columns_to_display]
    print(selected_columns)
    
    # เพิ่มข้อมูลลงในรายการ result_data
    result_data.append(selected_columns)

    print("\n" + "="*80 + "\n")

# รวมข้อมูลจากทุกไฟล์ CSV เป็น DataFrame เดียว
combined_data = pd.concat(result_data, axis=1)

# แสดงผลรายการ combined_data
print(combined_data)
# Out:
# ชื่อไฟล์: MSD_P0.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.609195       0.471985
# 1   Blue  289.781609       1.414987
# 2  Green  217.222222       1.511979
# 3    Red  351.241379       1.603311
# 4  White  809.847701       1.881677
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100_NRe.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.058095       0.208648
# 1   Blue  332.192222       0.799897
# 2  Green  197.708413       0.560317
# 3    Red  339.994921       0.792742
# 4  White  821.534127       0.915162
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10.csv
#
#    Color        Mean  Std Deviation
# 0  Black    4.546250       0.119031
# 1   Blue   56.534706       0.503925
# 2  Green   89.628750       0.325643
# 3    Red  106.604167       0.605372
# 4  White  242.278095       0.648020
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.884444       0.123678
# 1   Blue   27.158413       0.345975
# 2  Green   56.049573       0.443496
# 3    Red   59.258730       0.408334
# 4  White  134.952381       1.038925
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P_soil.csv
#
#    Color        Mean  Std Deviation
# 0  Black    4.252874       0.424032
# 1   Blue  134.298851       1.212844
# 2  Green   74.091954       0.885942
# 3    Red  124.172414       1.542058
# 4  White  320.873563       1.760403
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P10_NRe.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.102222       0.203722
# 1   Blue  325.541270       0.720935
# 2  Green  189.382540       0.480294
# 3    Red  321.712821       1.000078
# 4  White  794.203663       0.731430
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P1000_NRe.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.147436       0.161346
# 1   Blue  337.478315       0.536703
# 2  Green  201.272222       0.465415
# 3    Red  343.888889       0.538648
# 4  White  835.830159       0.935257
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P_water.csv
#
#    Color        Mean  Std Deviation
# 0  Black    6.609195       0.471985
# 1   Blue  289.781609       1.414987
# 2  Green  217.222222       1.511979
# 3    Red  351.241379       1.603311
# 4  White  809.847701       1.881677
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P100.csv
#
#    Color        Mean  Std Deviation
# 0  Black    3.887143       0.117064
# 1   Blue   36.370952       0.475151
# 2  Green   66.568730       0.464653
# 3    Red   73.619048       0.319438
# 4  White  168.649206       1.242876
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P_emp.csv
#
#    Color        Mean  Std Deviation
# 0  Black    5.919540       0.442353
# 1   Blue  276.747126       1.595269
# 2  Green  199.425287       1.479748
# 3    Red  333.816092       1.820488
# 4  White  769.005747       2.133204
#
# ================================================================================
#
# ชื่อไฟล์: MSD_P_urea.csv
#
#    Color        Mean  Std Deviation
# 0  Black    7.505747       0.442043
# 1   Blue  318.712644       2.083046
# 2  Green  228.425287       1.620544
# 3    Red  349.505747       2.154030
# 4  White  842.336111       2.590829
#
# ================================================================================
#
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    6.609195       0.471985  Black    6.058095       0.208648  Black
# 1   Blue  289.781609       1.414987   Blue  332.192222       0.799897   Blue
# 2  Green  217.222222       1.511979  Green  197.708413       0.560317  Green
# 3    Red  351.241379       1.603311    Red  339.994921       0.792742    Red
# 4  White  809.847701       1.881677  White  821.534127       0.915162  White
#
#          Mean  Std Deviation  Color  ...  Std Deviation  Color        Mean  \
# 0    4.546250       0.119031  Black  ...       0.471985  Black    3.887143
# 1   56.534706       0.503925   Blue  ...       1.414987   Blue   36.370952
# 2   89.628750       0.325643  Green  ...       1.511979  Green   66.568730
# 3  106.604167       0.605372    Red  ...       1.603311    Red   73.619048
# 4  242.278095       0.648020  White  ...       1.881677  White  168.649206
#
#    Std Deviation  Color        Mean  Std Deviation  Color        Mean  \
# 0       0.117064  Black    5.919540       0.442353  Black    7.505747
# 1       0.475151   Blue  276.747126       1.595269   Blue  318.712644
# 2       0.464653  Green  199.425287       1.479748  Green  228.425287
# 3       0.319438    Red  333.816092       1.820488    Red  349.505747
# 4       1.242876  White  769.005747       2.133204  White  842.336111
#
#    Std Deviation
# 0       0.442043
# 1       2.083046
# 2       1.620544
# 3       2.154030
# 4       2.590829
#
# [5 rows x 33 columns]

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้าง DataFrame ที่เก็บข้อมูลทั้งหมด
all_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เลือกคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่มข้อมูลที่เลือกเข้ากับรายการข้อมูลทั้งหมด
    all_data.append(selected_columns)

# รวมข้อมูลทุกไฟล์เข้าด้วยกัน
result = pd.concat(all_data, axis=1)

# แสดงผลลัพธ์
print(result)
# Out:
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    6.609195       0.471985  Black    6.058095       0.208648  Black
# 1   Blue  289.781609       1.414987   Blue  332.192222       0.799897   Blue
# 2  Green  217.222222       1.511979  Green  197.708413       0.560317  Green
# 3    Red  351.241379       1.603311    Red  339.994921       0.792742    Red
# 4  White  809.847701       1.881677  White  821.534127       0.915162  White
#
#          Mean  Std Deviation  Color  ...  Std Deviation  Color        Mean  \
# 0    4.546250       0.119031  Black  ...       0.471985  Black    3.887143
# 1   56.534706       0.503925   Blue  ...       1.414987   Blue   36.370952
# 2   89.628750       0.325643  Green  ...       1.511979  Green   66.568730
# 3  106.604167       0.605372    Red  ...       1.603311    Red   73.619048
# 4  242.278095       0.648020  White  ...       1.881677  White  168.649206
#
#    Std Deviation  Color        Mean  Std Deviation  Color        Mean  \
# 0       0.117064  Black    5.919540       0.442353  Black    7.505747
# 1       0.475151   Blue  276.747126       1.595269   Blue  318.712644
# 2       0.464653  Green  199.425287       1.479748  Green  228.425287
# 3       0.319438    Red  333.816092       1.820488    Red  349.505747
# 4       1.242876  White  769.005747       2.133204  White  842.336111
#
#    Std Deviation
# 0       0.442043
# 1       2.083046
# 2       1.620544
# 3       2.154030
# 4       2.590829
#
# [5 rows x 33 columns]

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้าง DataFrame ที่เก็บข้อมูลทั้งหมด
all_data = []

# วนลูปเพื่ออ่านข้อมูลเฉพาะคอลัมน์ที่ระบุจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เพิ่มคอลัมน์ "ชื่อไฟล์" เพื่อเก็บชื่อไฟล์ของแต่ละไฟล์
    df.insert(0, "ชื่อไฟล์", csv_file)
    
    # เลือกคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่มข้อมูลที่เลือกเข้ากับรายการข้อมูลทั้งหมด
    all_data.append(selected_columns)

# รวมข้อมูลทุกไฟล์เข้าด้วยกัน
result = pd.concat(all_data, axis=1)

# แสดงผลลัพธ์
print(result)
# Out:
#    Color        Mean  Std Deviation  Color        Mean  Std Deviation  Color  \
# 0  Black    6.609195       0.471985  Black    6.058095       0.208648  Black
# 1   Blue  289.781609       1.414987   Blue  332.192222       0.799897   Blue
# 2  Green  217.222222       1.511979  Green  197.708413       0.560317  Green
# 3    Red  351.241379       1.603311    Red  339.994921       0.792742    Red
# 4  White  809.847701       1.881677  White  821.534127       0.915162  White
#
#          Mean  Std Deviation  Color  ...  Std Deviation  Color        Mean  \
# 0    4.546250       0.119031  Black  ...       0.471985  Black    3.887143
# 1   56.534706       0.503925   Blue  ...       1.414987   Blue   36.370952
# 2   89.628750       0.325643  Green  ...       1.511979  Green   66.568730
# 3  106.604167       0.605372    Red  ...       1.603311    Red   73.619048
# 4  242.278095       0.648020  White  ...       1.881677  White  168.649206
#
#    Std Deviation  Color        Mean  Std Deviation  Color        Mean  \
# 0       0.117064  Black    5.919540       0.442353  Black    7.505747
# 1       0.475151   Blue  276.747126       1.595269   Blue  318.712644
# 2       0.464653  Green  199.425287       1.479748  Green  228.425287
# 3       0.319438    Red  333.816092       1.820488    Red  349.505747
# 4       1.242876  White  769.005747       2.133204  White  842.336111
#
#    Std Deviation
# 0       0.442043
# 1       2.083046
# 2       1.620544
# 3       2.154030
# 4       2.590829
#
# [5 rows x 33 columns]

# %%
import os
import pandas as pd

# ระบุคอลัมน์ที่ต้องการแสดง
columns_to_display = ["Color", "Mean", "Std Deviation"]

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# หาไฟล์ CSV ทั้งหมดในโฟลเดอร์
csv_files = [f for f in os.listdir(folder_path) if f.startswith('MSD_P') and f.endswith('.csv')]

# สร้างรายการของ DataFrame ที่จะรวมข้อมูล
dataframes_to_concat = []

# วนลูปเพื่ออ่านและรวมข้อมูลจากไฟล์ CSV แต่ละไฟล์
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # ใช้ pandas อ่านข้อมูลจากไฟล์ CSV
    df = pd.read_csv(file_path)
    
    # เลือกข้อมูลเฉพาะคอลัมน์ที่ต้องการแสดง
    selected_columns = df[columns_to_display]
    
    # เพิ่ม DataFrame ที่ได้สร้างลงในรายการ
    dataframes_to_concat.append(selected_columns)

# รวมข้อมูลในรายการ DataFrame โดยใช้ pd.concat()
all_data = pd.concat(dataframes_to_concat, ignore_index=True)

# บันทึก DataFrame ที่รวมข้อมูลลงในไฟล์ "AllMSD.csv"
output_file_path = os.path.join(folder_path, 'AllMSD.csv')
all_data.to_csv(output_file_path, index=False)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMSD.csv

# %%
import pandas as pd

# ระบุที่อยู่ของไฟล์ AllMSD.csv
file_path = "datasetCSV/AllMSD.csv"

# ใช้ pandas อ่านไฟล์ CSV เข้าสู่ DataFrame
df = pd.read_csv(file_path)

# แสดงข้อมูลใน DataFrame
print(df)
# Out:
#     Color        Mean  Std Deviation
# 0   Black    6.609195       0.471985
# 1    Blue  289.781609       1.414987
# 2   Green  217.222222       1.511979
# 3     Red  351.241379       1.603311
# 4   White  809.847701       1.881677
# 5   Black    6.058095       0.208648
# 6    Blue  332.192222       0.799897
# 7   Green  197.708413       0.560317
# 8     Red  339.994921       0.792742
# 9   White  821.534127       0.915162
# 10  Black    4.546250       0.119031
# 11   Blue   56.534706       0.503925
# 12  Green   89.628750       0.325643
# 13    Red  106.604167       0.605372
# 14  White  242.278095       0.648020
# 15  Black    3.884444       0.123678
# 16   Blue   27.158413       0.345975
# 17  Green   56.049573       0.443496
# 18    Red   59.258730       0.408334
# 19  White  134.952381       1.038925
# 20  Black    4.252874       0.424032
# 21   Blue  134.298851       1.212844
# 22  Green   74.091954       0.885942
# 23    Red  124.172414       1.542058
# 24  White  320.873563       1.760403
# 25  Black    5.102222       0.203722
# 26   Blue  325.541270       0.720935
# 27  Green  189.382540       0.480294
# 28    Red  321.712821       1.000078
# 29  White  794.203663       0.731430
# 30  Black    5.147436       0.161346
# 31   Blue  337.478315       0.536703
# 32  Green  201.272222       0.465415
# 33    Red  343.888889       0.538648
# 34  White  835.830159       0.935257
# 35  Black    6.609195       0.471985
# 36   Blue  289.781609       1.414987
# 37  Green  217.222222       1.511979
# 38    Red  351.241379       1.603311
# 39  White  809.847701       1.881677
# 40  Black    3.887143       0.117064
# 41   Blue   36.370952       0.475151
# 42  Green   66.568730       0.464653
# 43    Red   73.619048       0.319438
# 44  White  168.649206       1.242876
# 45  Black    5.919540       0.442353
# 46   Blue  276.747126       1.595269
# 47  Green  199.425287       1.479748
# 48    Red  333.816092       1.820488
# 49  White  769.005747       2.133204
# 50  Black    7.505747       0.442043
# 51   Blue  318.712644       2.083046
# 52  Green  228.425287       1.620544
# 53    Red  349.505747       2.154030
# 54  White  842.336111       2.590829

# %% [markdown]
# จัดตารางเป็น [ 'Color'  'Con_P10', 'Con_P100', 'Con_P1000']   บันทึกเป็น AllMean_Table.csv

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล Color จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P0.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ Color จาก MSD_P10.csv
new_df = pd.DataFrame({'Color': colors})

# โหลดข้อมูล Mean จากไฟล์ MSD_P10.csv, MSD_P100.csv และ MSD_P1000.csv
for prefix in ['P0','P10', 'P100', 'P1000']:
    msd_file_path = os.path.join(folder_path, f'MSD_{prefix}.csv')
    msd_df = pd.read_csv(msd_file_path)
 
    new_df[f'Con_{prefix}'] = msd_df['Mean']

# แสดงเส้น ------------ ด้านบน
print("-" * 80)

# แสดงผลลัพธ์ในรูปแบบตาราง
print(new_df)

# แสดงเส้น ------------ ด้านล่าง
print("-" * 80)

# บันทึกเป็นไฟล์ CSV ชื่อ AllMean_Table.csv
output_file_path = os.path.join(folder_path, 'AllMean_Table.csv')
new_df.to_csv(output_file_path, index=False)

# แสดงข้อความบันทึกไฟล์
print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
# --------------------------------------------------------------------------------
#    Color      Con_P0     Con_P10    Con_P100   Con_P1000
# 0  Black    6.609195    4.546250    3.887143    3.884444
# 1   Blue  289.781609   56.534706   36.370952   27.158413
# 2  Green  217.222222   89.628750   66.568730   56.049573
# 3    Red  351.241379  106.604167   73.619048   59.258730
# 4  White  809.847701  242.278095  168.649206  134.952381
# --------------------------------------------------------------------------------
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMean_Table.csv

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล Color จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P0.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ Color จาก MSD_P10.csv
new_df = pd.DataFrame({'Color': colors})

# โหลดข้อมูล Mean จากไฟล์ MSD_P10.csv, MSD_P100.csv และ MSD_P1000.csv
for prefix in ['P0','P10', 'P100', 'P1000']:
    msd_file_path = os.path.join(folder_path, f'MSD_{prefix}.csv')
    msd_df = pd.read_csv(msd_file_path)
 
    new_df[f'Con_{prefix}'] = msd_df['Mean']

# สลับแถวกับหลัก (Transpose) DataFrame
new_df = new_df.transpose()

# แสดงผลลัพธ์ในรูปแบบตาราง
print(new_df)

# บันทึกเป็นไฟล์ CSV ชื่อ AllMean_Table.csv
output_file_path = os.path.join(folder_path, 'AllMean_Table.csv')
new_df.to_csv(output_file_path, header=False)

# แสดงข้อความบันทึกไฟล์
print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
#                   0           1           2           3           4
# Color         Black        Blue       Green         Red       White
# Con_P0     6.609195  289.781609  217.222222  351.241379  809.847701
# Con_P10     4.54625   56.534706    89.62875  106.604167  242.278095
# Con_P100   3.887143   36.370952    66.56873   73.619048  168.649206
# Con_P1000  3.884444   27.158413   56.049573    59.25873  134.952381
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMean_Table.csv

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล "Color" จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P0.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ "Concentrate" และเปลี่ยนชื่อคอลัมน์ "Color"
new_df = pd.DataFrame({'Concentrate': colors})

# โหลดข้อมูล Mean จากไฟล์ MSD_P10.csv, MSD_P100.csv และ MSD_P1000.csv
for prefix in ['P0','P10', 'P100', 'P1000']:
    msd_file_path = os.path.join(folder_path, f'MSD_{prefix}.csv')
    msd_df = pd.read_csv(msd_file_path)
 
    # เปลี่ยนชื่อคอลัมน์ Mean เป็น "10", "100", "1000"
    msd_df.rename(columns={'Mean': prefix}, inplace=True)

    new_df[prefix] = msd_df[prefix]

# สลับแถวกับหลัก (Transpose) DataFrame
new_df = new_df.transpose()

# แสดงผลลัพธ์ในรูปแบบตาราง
print(new_df)

# บันทึกเป็นไฟล์ CSV ชื่อ AllMean_Table.csv โดยไม่รวมหัวของตาราง
output_file_path = os.path.join(folder_path, 'AllMean_Table.csv')
new_df.to_csv(output_file_path, header=False)

# แสดงข้อความบันทึกไฟล์
print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
#                     0           1           2           3           4
# Concentrate     Black        Blue       Green         Red       White
# P0           6.609195  289.781609  217.222222  351.241379  809.847701
# P10           4.54625   56.534706    89.62875  106.604167  242.278095
# P100         3.887143   36.370952    66.56873   73.619048  168.649206
# P1000        3.884444   27.158413   56.049573    59.25873  134.952381
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMean_Table.csv

# %%
import pandas as pd

# ระบุที่อยู่ของไฟล์ CSV
file_path = 'datasetCSV/AllMean_Table.csv'

# ใช้ pandas อ่านไฟล์ CSV
df = pd.read_csv(file_path)

# แสดงข้อมูลในตาราง
print(df)
# Out:
#   Concentrate     Black        Blue       Green         Red       White
# 0          P0  6.609195  289.781609  217.222222  351.241379  809.847701
# 1         P10  4.546250   56.534706   89.628750  106.604167  242.278095
# 2        P100  3.887143   36.370952   66.568730   73.619048  168.649206
# 3       P1000  3.884444   27.158413   56.049573   59.258730  134.952381

# %%
import pandas as pd

# ระบุที่อยู่ของไฟล์ CSV
file_path = 'datasetCSV/AllMean_Table.csv'

# ใช้ pandas อ่านไฟล์ CSV
df = pd.read_csv(file_path)

# ลบคอลัมน์ "Black" จากคอลัมน์ "Blue," "Green," "Red," และ "White"
df['Blue'] = df['Blue'] - df['Black']
df['Green'] = df['Green'] - df['Black']
df['Red'] = df['Red'] - df['Black']
df['White'] = df['White'] - df['Black']

# ลบคอลัมน์ "Black" ออก
df.drop(columns=['Black'], inplace=True)

# บันทึกเป็นไฟล์ CSV ชื่อ "RGBWP.csv" ในโฟลเดอร์ "datasetCSV"
output_file_path = 'datasetCSV/RGBWP.csv'
df.to_csv(output_file_path, index=False)

# แสดงผลทางหน้าจอ
print(df)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
#   Concentrate        Blue       Green         Red       White
# 0          P0  283.172414  210.613027  344.632184  803.238506
# 1         P10   51.988456   85.082500  102.057917  237.731845
# 2        P100   32.483810   62.681587   69.731905  164.762063
# 3       P1000   23.273968   52.165128   55.374286  131.067937
# บันทึกข้อมูลลงในไฟล์ datasetCSV/RGBWP.csv

# %%
import pandas as pd

# ระบุที่อยู่ของไฟล์ CSV
file_path = 'datasetCSV/AllMean_Table.csv'

# ใช้ pandas อ่านไฟล์ CSV
df = pd.read_csv(file_path)

# แปลงค่าในคอลัมน์ "Concentrate" จาก "P10", "P100", "P1000" เป็น "10", "100", "1000"
df['Concentrate'] = df['Concentrate'].str.replace('P0', '0').str.replace('P10', '10').str.replace('P100', '100').str.replace('P1000', '1000')

# ลบคอลัมน์ "Black" จากคอลัมน์ "Blue," "Green," "Red," และ "White"
df['Blue'] = df['Blue'] - df['Black']
df['Green'] = df['Green'] - df['Black']
df['Red'] = df['Red'] - df['Black']
df['White'] = df['White'] - df['Black']

# ลบคอลัมน์ "Black" ออก
df.drop(columns=['Black'], inplace=True)

# บันทึกเป็นไฟล์ CSV ชื่อ "RGBWP.csv" ในโฟลเดอร์ "datasetCSV"
output_file_path = 'datasetCSV/RGBWP.csv'
df.to_csv(output_file_path, index=False)

# แสดงผลทางหน้าจอ
print(df)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
#   Concentrate        Blue       Green         Red       White
# 0           0  283.172414  210.613027  344.632184  803.238506
# 1          10   51.988456   85.082500  102.057917  237.731845
# 2         100   32.483810   62.681587   69.731905  164.762063
# 3        1000   23.273968   52.165128   55.374286  131.067937
# บันทึกข้อมูลลงในไฟล์ datasetCSV/RGBWP.csv

# %%
import pandas as pd

# อ่านไฟล์ CSV
csv_file_path = 'datasetCSV/RGBWP.csv'
df = pd.read_csv(csv_file_path)

# ลบข้อมูลในแถวที่ 0 จากข้อมูลในแถวที่ 1, 2, และ 3 โดยยกเว้นคอลัมน์ 'Concentrate'
columns_to_exclude = ['Concentrate']
df.loc[1, df.columns.difference(columns_to_exclude)] = df.loc[0, df.columns.difference(columns_to_exclude)] - df.loc[1, df.columns.difference(columns_to_exclude)]
df.loc[2, df.columns.difference(columns_to_exclude)] = df.loc[0, df.columns.difference(columns_to_exclude)] - df.loc[2, df.columns.difference(columns_to_exclude)]
df.loc[3, df.columns.difference(columns_to_exclude)] = df.loc[0, df.columns.difference(columns_to_exclude)] - df.loc[3, df.columns.difference(columns_to_exclude)]
df.loc[0, df.columns.difference(columns_to_exclude)] = df.loc[0, df.columns.difference(columns_to_exclude)] - df.loc[0, df.columns.difference(columns_to_exclude)]
# บันทึกข้อมูลลงในไฟล์ CSV ใหม่ (หากต้องการ)
new_csv_file_path = 'datasetCSV/RGBWP_updated.csv'
df.to_csv(new_csv_file_path, index=False)

# แสดงข้อมูลหลังจากการปรับแก้
print(df)
# Out:
#    Concentrate        Blue       Green         Red       White
# 0            0    0.000000    0.000000    0.000000    0.000000
# 1           10  231.183958  125.530527  242.574267  565.506661
# 2          100  250.688604  147.931440  274.900279  638.476442
# 3         1000  259.898446  158.447899  289.257898  672.170569

# %%
import pandas as pd

# อ่านไฟล์ CSV
csv_file_path = 'datasetCSV/RGBWP.csv'
df = pd.read_csv(csv_file_path)

# คำนวณค่าใหม่โดยลบแถวที่ 0 จากแถวที่ 1, 2, และ 3 โดยยกเว้นคอลัมน์ 'Concentrate'
columns_to_exclude = ['Concentrate']
for i in range(1, 4):
    df.iloc[i, 1:] = df.iloc[0, 1:] - df.iloc[i, 1:]

# เปลี่ยนข้อมูลในแถวที่ 0 เป็น 0
df.iloc[0, 1:] = 0

# บันทึกข้อมูลลงในไฟล์ CSV ใหม่ (หากต้องการ)
new_csv_file_path = 'datasetCSV/Asorption.csv'
df.to_csv(new_csv_file_path, index=False)

# แสดงข้อมูลหลังจากการปรับแก้
print(df)
# Out:
#    Concentrate        Blue       Green         Red       White
# 0            0    0.000000    0.000000    0.000000    0.000000
# 1           10  231.183958  125.530527  242.574267  565.506661
# 2          100  250.688604  147.931440  274.900279  638.476442
# 3         1000  259.898446  158.447899  289.257898  672.170569

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านไฟล์ CSV ที่ normalize แล้ว
csv_file_path = 'datasetCSV/Asorption.csv'
df = pd.read_csv(csv_file_path)

# สร้างกราฟแสดงจุดข้อมูล
plt.figure(figsize=(10, 6))  # กำหนดขนาดของกราฟ

# ใช้คอลัมน์ 'Concentrate' เป็นแกนนอน และคอลัมน์ 'Blue', 'Green', 'Red', 'White' เป็นแกนตั้ง
plt.scatter(df['Concentrate'], df['Blue'], label='Blue')
plt.scatter(df['Concentrate'], df['Green'], label='Green')
plt.scatter(df['Concentrate'], df['Red'], label='Red')
plt.scatter(df['Concentrate'], df['White'], label='White')

plt.xlabel('Concentrate')  # ตั้งชื่อแกนนอน
plt.ylabel('Value')  # ตั้งชื่อแกนตั้ง
plt.title('Scatter Plot of Concentrate vs Blue/Green/Red/White')  # ตั้งชื่อกราฟ
plt.legend()  # เพิ่มแสดงคำอธิบายของข้อมูล

plt.show()  # แสดงกราฟ

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านไฟล์ CSV
csv_file_path = 'datasetCSV/Asorption.csv'
df = pd.read_csv(csv_file_path)

# สร้างกราฟแสดงจุดข้อมูล
plt.figure(figsize=(10, 6))  # กำหนดขนาดของกราฟ

# ใช้คอลัมน์ 'Concentrate' เป็นแกนนอนแบบ log และคอลัมน์ 'Blue', 'Green', 'Red', 'White' เป็นแกนตั้ง
plt.scatter(df['Concentrate'], df['Blue'], label='Blue')
plt.scatter(df['Concentrate'], df['Green'], label='Green')
plt.scatter(df['Concentrate'], df['Red'], label='Red')
plt.scatter(df['Concentrate'], df['White'], label='White')

plt.xscale('log')  # ทำแกนนอนเป็นแกน log
plt.xlabel('Concentrate (log scale)')  # ตั้งชื่อแกนนอน
plt.ylabel('Value')  # ตั้งชื่อแกนตั้ง
plt.title('Scatter Plot of Concentrate vs Blue/Green/Red/White')  # ตั้งชื่อกราฟ
plt.legend()  # เพิ่มแสดงคำอธิบายของข้อมูล

plt.show()  # แสดงกราฟ

# %%
import pandas as pd

# อ่านไฟล์ CSV
csv_file_path = 'datasetCSV/Asorption.csv'
df = pd.read_csv(csv_file_path)

# ทำการ normalization ข้อมูลในคอลัมน์ 'Blue', 'Green', 'Red', และ 'White'
columns_to_normalize = ['Blue', 'Green', 'Red', 'White']

for column in columns_to_normalize:
    df[column] = (df[column] - df[column].min()) / (df[column].max() - df[column].min())

# บันทึกข้อมูลลงในไฟล์ CSV ที่ normalize แล้ว (หากต้องการ)
new_csv_file_path = 'datasetCSV/Asorption_normalized.csv'
df.to_csv(new_csv_file_path, index=False)

# แสดงข้อมูลหลังจาก normalization
print(df)
# Out:
#    Concentrate      Blue     Green       Red     White
# 0            0  0.000000  0.000000  0.000000  0.000000
# 1           10  0.889517  0.792251  0.838609  0.841314
# 2          100  0.964564  0.933628  0.950364  0.949873
# 3         1000  1.000000  1.000000  1.000000  1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านไฟล์ CSV ที่ normalize แล้ว
csv_file_path = 'datasetCSV/Asorption_normalized.csv'
df = pd.read_csv(csv_file_path)

# สร้าง subplot
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# คอลัมน์และสีที่จะใช้
columns = ['Blue', 'Green', 'Red', 'White']
colors = ['b', 'g', 'r', 'k']  # สีดำถูกเพิ่มเข้ามาในลิสต์สี

# วนลูปเพื่อสร้างแต่ละ subplot
for i, (column, color) in enumerate(zip(columns, colors)):
    ax = axs[i//2, i%2]  # เลือก subplot
    ax.scatter(df['Concentrate'], df[column], color=color)  # วาด scatter plot
    
    ax.set_xlabel('Concentrate')  # ตั้งชื่อแกนนอน
    ax.set_ylabel(column + '_Absorption')  # ตั้งชื่อแกนตั้ง
    
    ax.set_xscale('log')  # ทำแกนนอนเป็นแกน log
    ax.set_title(f'P_Content [mg/L] vs {column}_Absorption')  # ตั้งชื่อกราฟ

# ปรับระยะห่างระหว่าง subplots
plt.tight_layout()

plt.show()  # แสดงกราฟ

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านไฟล์ CSV ที่ normalize แล้ว
csv_file_path = 'datasetCSV/Asorption_normalized.csv'
df = pd.read_csv(csv_file_path)

# สร้าง subplot
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# คอลัมน์และสีที่จะใช้
columns = ['Blue', 'Green', 'Red', 'White']
colors = ['b', 'g', 'r', 'k']  # สีดำถูกเพิ่มเข้ามาในลิสต์สี

# วนลูปเพื่อสร้างแต่ละ subplot
for i, (column, color) in enumerate(zip(columns, colors)):
    ax = axs[i//2, i%2]  # เลือก subplot
    ax.scatter(df['Concentrate'], df[column], color=color)  # วาด scatter plot
    
    ax.set_xlabel('P_Content [mg/L]')  # ตั้งชื่อแกนนอน
    ax.set_ylabel(column + '_Normalize_Absorption')  # ตั้งชื่อแกนตั้ง
    
    ax.set_xscale('log')  # ทำแกนนอนเป็นแกน log
    #ax.set_title(f'P_Content [mg/L] vs {column}_Absorption')  # ตั้งชื่อกราฟ
    
    ax.set_ylim(0.75, 1.05)  # กำหนดช่วงของแกนตั้ง

# ปรับระยะห่างระหว่าง subplots
plt.tight_layout()

plt.show()  # แสดงกราฟ

# %%
import pandas as pd

# อ่านข้อมูลจากไฟล์ CSV
data = pd.read_csv('datasetCSV/Asorption_normalized.csv')

# แสดงข้อมูล
print(data)
# Out:
#    Concentrate      Blue     Green       Red     White
# 0            0  0.000000  0.000000  0.000000  0.000000
# 1           10  0.889517  0.792251  0.838609  0.841314
# 2          100  0.964564  0.933628  0.950364  0.949873
# 3         1000  1.000000  1.000000  1.000000  1.000000

# %%
import pandas as pd

# อ่านข้อมูลจากไฟล์ CSV
data = pd.read_csv('datasetCSV/Asorption_normalized.csv')

# ลบแถวที่ 0
data = data.drop(0)

# บันทึกข้อมูลใหม่ไปยังไฟล์ CSV ด้วยชื่อเดิม
data.to_csv('datasetCSV/Asorption_normalized.csv', index=False)

# %%
import pandas as pd

# อ่านข้อมูลจากไฟล์ CSV
data = pd.read_csv('datasetCSV/Asorption_normalized.csv')

# แสดงข้อมูล
print(data)
# Out:
#    Concentrate      Blue     Green       Red     White
# 0           10  0.889517  0.792251  0.838609  0.841314
# 1          100  0.964564  0.933628  0.950364  0.949873
# 2         1000  1.000000  1.000000  1.000000  1.000000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

df = pd.read_csv('datasetCSV/Asorption_normalized.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

def linear(x, a, b):
    return a * x + b

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('datasetCSV/Asorption_normalized.csv')

# คำนวณเส้นแนวโน้มและค่า R^2 สำหรับแต่ละคอลัมน์
columns = ['Blue', 'Green', 'Red', 'White']

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
axes = axes.flatten()

results = []

for i, col in enumerate(columns):
    x = df['Concentrate'].values
    y = df[col].values

    # Fit เส้นแนวโน้ม
    params, _ = curve_fit(linear, x, y)

    # คำนวณค่า R^2
    y_pred = linear(x, *params)
    r2 = r2_score(y, y_pred)

    results.append({'Column': col, 'Parameters': params, 'R^2': r2})

    # พล็อตเส้นแนวโน้มและข้อมูลจริง
    color = col.lower()
    if col == 'White':
        color = 'black'  # เปลี่ยนสี White เป็น Black
    axes[i].scatter(x, y, label=f'{col}', color=color)
    axes[i].plot(x, linear(x, *params), label=f'Fit: {col}', linestyle='--', color=color)

    axes[i].set_xlabel('Concentrate (log)')
    axes[i].set_ylabel('Value')
    axes[i].legend()
    axes[i].grid(True)
    axes[i].set_title(f'Linear Fit for {col} (R^2={r2:.2f})')

plt.tight_layout()
plt.show()

# แสดงสมการแนวโน้มสำหรับแต่ละคอลัมน์
for result in results:
    col = result['Column']
    params = result['Parameters']
    print(f'{col} Fit Equation: y = {params[0]:.4f}x + {params[1]:.4f}')
# Out:
# Blue Fit Equation: y = 0.0001x + 0.9209
# Green Fit Equation: y = 0.0002x + 0.8514
# Red Fit Equation: y = 0.0001x + 0.8855
# White Fit Equation: y = 0.0001x + 0.8868

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล Color จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P10.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ Color จาก MSD_P10.csv
new_df = pd.DataFrame({'Color': colors})

# รายชื่อไฟล์ CSV ที่เราต้องการคำนวณส่วนเบี่ยงเบนมาตรฐาน
csv_files = ['MSD_P10.csv', 'MSD_P100.csv', 'MSD_P1000.csv']

# โหลดข้อมูล Mean และ Std Deviation จากไฟล์ CSV
for csv_file in csv_files:
    msd_file_path = os.path.join(folder_path, csv_file)
    msd_df = pd.read_csv(msd_file_path)
    prefix = csv_file.split('_')[1].split('.')[0]
    new_df[f'Con_{prefix}'] = msd_df['Mean']
    new_df[f'StdDev_{prefix}'] = msd_df['Std Deviation']

# เรียงลำดับคอลัมน์ตามชื่อไฟล์
new_df = new_df[['Color'] + sorted([col for col in new_df.columns if col != 'Color'])]

# บันทึกเป็นไฟล์ CSV ชื่อ AllMeanSD_Table.csv
output_file_path = os.path.join(folder_path, 'AllMeanSD_Table.csv')
new_df.to_csv(output_file_path, index=False)

# แสดงผลลัพธ์ทางจอ
print("-" * 100)
print(new_df)
print("-" * 100)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
# ----------------------------------------------------------------------------------------------------
#    Color     Con_P10    Con_P100   Con_P1000  StdDev_P10  StdDev_P100  \
# 0  Black    4.546250    3.887143    3.884444    0.119031     0.117064
# 1   Blue   56.534706   36.370952   27.158413    0.503925     0.475151
# 2  Green   89.628750   66.568730   56.049573    0.325643     0.464653
# 3    Red  106.604167   73.619048   59.258730    0.605372     0.319438
# 4  White  242.278095  168.649206  134.952381    0.648020     1.242876
#
#    StdDev_P1000
# 0      0.123678
# 1      0.345975
# 2      0.443496
# 3      0.408334
# 4      1.038925
# ----------------------------------------------------------------------------------------------------
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMeanSD_Table.csv

# %%
import os
import pandas as pd

# ระบุโฟลเดอร์ที่เก็บไฟล์ CSV
folder_path = 'datasetCSV'

# อ่านข้อมูล Color จากไฟล์ MSD_P10.csv
msd_p10_path = os.path.join(folder_path, 'MSD_P10.csv')
msd_p10_df = pd.read_csv(msd_p10_path)
colors = msd_p10_df['Color']

# สร้าง DataFrame ใหม่โดยใช้คอลัมน์ Color จาก MSD_P10.csv
new_df = pd.DataFrame({'Color': colors})

# รายชื่อไฟล์ CSV ที่เราต้องการคำนวณส่วนเบี่ยงเบนมาตรฐาน
csv_files = ['MSD_P10.csv', 'MSD_P_urea.csv','MSD_P_soil.csv']

# โหลดข้อมูล Mean และ Std Deviation จากไฟล์ CSV
for csv_file in csv_files:
    msd_file_path = os.path.join(folder_path, csv_file)
    msd_df = pd.read_csv(msd_file_path)
    prefix = csv_file.split('_')[1].split('.')[0]
    new_df[f'Con_{prefix}'] = msd_df['Mean']
    # new_df[f'StdDev_{prefix}'] = msd_df['Std Deviation']

# เรียงลำดับคอลัมน์ตามชื่อไฟล์
new_df = new_df[['Color'] + sorted([col for col in new_df.columns if col != 'Color'])]

# บันทึกเป็นไฟล์ CSV ชื่อ AllMeanSD_Table.csv
output_file_path = os.path.join(folder_path, 'AllMeanSD_Table.csv')
new_df.to_csv(output_file_path, index=False)

# แสดงผลลัพธ์ทางจอ
print("-" * 100)
print(new_df)
print("-" * 100)

print(f"บันทึกข้อมูลลงในไฟล์ {output_file_path}")
# Out:
# ----------------------------------------------------------------------------------------------------
#    Color       Con_P     Con_P10
# 0  Black    4.252874    4.546250
# 1   Blue  134.298851   56.534706
# 2  Green   74.091954   89.628750
# 3    Red  124.172414  106.604167
# 4  White  320.873563  242.278095
# ----------------------------------------------------------------------------------------------------
# บันทึกข้อมูลลงในไฟล์ datasetCSV/AllMeanSD_Table.csv
