# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "FdatasetCSV"

# List all CSV files in the folder starting with "BG_"
csv_files = [f for f in os.listdir(folder_path) if f.startswith("F16_") and f.endswith(".csv")]

# Create a subplot for each file
fig, axs = plt.subplots(len(csv_files), figsize=(8, 6 * len(csv_files)))

# Iterate through CSV files
for i, csv_file in enumerate(csv_files):
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Extract 'No.' and 'Intensity' columns
    no = df['No.']
    intensity = df['Intensity']

    # Create a plot for each file
    axs[i].plot(no, intensity, label=csv_file)
    axs[i].set_xlabel('No.')
    axs[i].set_ylabel('Intensity')
    axs[i].set_title(f'Intensity vs. No. for {csv_file}')
    axs[i].legend()

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "FdatasetCSV"

# List all CSV files in the folder starting with "BG_"
csv_files = [f for f in os.listdir(folder_path) if f.startswith("F46_") and f.endswith(".csv")]

# Create a DataFrame to store data from all "BG_" files
combined_df = pd.DataFrame()

# Iterate through the "BG_" files and plot their data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each "BG_" file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for BG_ Files")

# Show legend for each "BG_" file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "FdatasetCSV"

# List all CSV files in the folder starting with "N2_"
csv_files = [f for f in os.listdir(folder_path) if f.startswith("F16_") and f.endswith(".csv")]

# Create a DataFrame to store data from all "N2_" files
combined_df = pd.DataFrame()

# Iterate through the "N2_" files and plot their data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each "N2_" file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for F16_ Files")

# Show legend for each "N2_" file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "FdatasetCSV"

# List all CSV files in the folder matching the pattern "N*_R.csv"
csv_files = [f for f in os.listdir(folder_path) if f.endswith("_N.csv")]

# Create a DataFrame to store data from all "N*_R.csv" files
combined_df = pd.DataFrame()

# Iterate through the "N*_R.csv" files and plot their data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each "N*_R.csv" file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for F*_R Files")

# Show legend for each "N*_R.csv" file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "FdatasetCSV"

# List all CSV files in the folder matching the pattern "N*_R.csv"
csv_files = [f for f in os.listdir(folder_path) if f.endswith("_P.csv")]

# Create a DataFrame to store data from all "N*_R.csv" files
combined_df = pd.DataFrame()

# Iterate through the "N*_R.csv" files and plot their data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each "N*_R.csv" file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for F*_R Files")

# Show legend for each "N*_R.csv" file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "FdatasetCSV"

# List of file names to include in the graph
file_names = ["F16_N.csv", "F16_P.csv", "F46_N.csv", "F46_P.csv"]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph
file_names = ["F16_NoRN.csv", "F16_NoRP.csv", "F46_NoRN.csv", "F46_NoRP.csv"]
# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 19
#      16 file_path = os.path.join(folder_path, csv_file)
#      18 # Load the CSV file
# ---> 19 df = pd.read_csv(file_path)
#      21 # Plot the data for each selected file
#      22 plt.plot(df['No.'], df['Intensity'], label=csv_file)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NdatasetCSV/F16_NoRN.csv'

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph
file_names = ["N2_R.csv", "N2n_R.csv"]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph
file_names = ["N2_R.csv", "N2n_R.csv", "N2_A.csv", "N2_B.csv"]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph for N4
n4_file_names = ["N4_R.csv", "N4_A.csv", "N4_B.csv"]

# List of file names to include in the graph for N6
n6_file_names = ["N6_R.csv", "N6_A.csv", "N6_B.csv"]

# List of file names to include in the graph for N8
n8_file_names = ["N8_R.csv", "N8_A.csv", "N8_B.csv"]

# List of file names to include in the graph for N10
n10_file_names = ["N10_R.csv", "N10_A.csv", "N10_B.csv"]

# Function to create a plot for a list of file names
def create_plot(file_names, title):
    combined_df = pd.DataFrame()
    
    for csv_file in file_names:
        file_path = os.path.join(folder_path, csv_file)
        df = pd.read_csv(file_path)
        plt.plot(df['No.'], df['Intensity'], label=csv_file)
        combined_df = pd.concat([combined_df, df], ignore_index=True)
    
    plt.xlabel("No.")
    plt.ylabel("Intensity")
    plt.title(title)
    plt.legend()
    plt.show()
    
    # If you want to save the combined data to a CSV file, you can use:
    # combined_df.to_csv("combined_data.csv", index=False)

# Create plots for N4
create_plot(n4_file_names, "Intensity vs. No. for N4 Files")

# Create plots for N6
create_plot(n6_file_names, "Intensity vs. No. for N6 Files")

# Create plots for N8
create_plot(n8_file_names, "Intensity vs. No. for N8 Files")

# Create plots for N10
create_plot(n10_file_names, "Intensity vs. No. for N10 Files")

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith("_NoR.csv")]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith("_NoR.csv")]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph
file_names = ["N2n_NoR.csv", "N4_NoR.csv", "N6_NoR.csv", "N8_NoR.csv", "N10_NoR.csv"]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph
file_names = ["N10_NoR.csv", "N20_NoR.csv", "N40_NoR.csv", "N60_NoR.csv", "N80_NoR.csv","N100_NoR.csv"]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph
file_names = []

# Iterate through files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith("_blank.csv") or filename.startswith("BG_"):
        file_names.append(filename)

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph
file_names = ["N2_blank.csv", "N2n_blank.csv"] + [f for f in os.listdir(folder_path) if f.startswith("BG_") and f.endswith(".csv")]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph
file_names = ["N4_blank.csv", "N6_blank.csv"] + [f for f in os.listdir(folder_path) if f.startswith("BG_") and f.endswith(".csv")]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of file names to include in the graph
file_names = ["N8_blank.csv", "N10_blank.csv"] + [f for f in os.listdir(folder_path) if f.startswith("BG_") and f.endswith(".csv")]

# Create a DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Iterate through the selected files and plot their data
for csv_file in file_names:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Plot the data for each selected file
    plt.plot(df['No.'], df['Intensity'], label=csv_file)

    # Append the data to the combined DataFrame
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Set labels and title for the plot
plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No. for Selected Files")

# Show legend for each selected file
plt.legend()

# Show the plot
plt.show()

# If you want to save the combined data to a CSV file, you can use:
# combined_df.to_csv("combined_data.csv", index=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N2_blank.csv", "N2_W.csv", "N2_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N4_blank.csv", "N4_W.csv", "N4_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N6_blank.csv", "N6_W.csv", "N6_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N8_blank.csv", "N8_W.csv", "N8_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N10_blank.csv", "N10_W.csv", "N10_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N20_blank.csv", "N20_W.csv", "N20_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N40_blank.csv", "N40_W.csv", "N40_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N60_blank.csv", "N60_W.csv", "N60_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N80_blank.csv", "N80_W.csv", "N80_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N100_blank.csv", "N100_W.csv", "N100_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N2n_R.csv", "N2n_W.csv", "N2n_NoR.csv" ,"N2n_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N4_R.csv", "N4_W.csv", "N4_NoR.csv" ,"N4_WR.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N2n_R.csv", "N4_R.csv", "N6_R.csv", "N8_R.csv", "N10_R.csv", "N20_R.csv", "N40_R.csv", "N60_R.csv", "N80_R.csv", "N100_R.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of CSV files to be plotted
csv_files_to_plot = ["N2n_R.csv", "N4_R.csv", "N6_R.csv", "N8_R.csv", "N10_R.csv"]

# Create an empty DataFrame to store data from selected files
combined_df = pd.DataFrame()

# Read and combine data from selected files
for csv_file in csv_files_to_plot:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

# Rename the columns to match the file names
combined_df.columns = csv_files_to_plot

# Plot the data
plt.figure(figsize=(10, 6))
for csv_file in csv_files_to_plot:
    plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

plt.xlabel("No.")
plt.ylabel("Intensity")
plt.title("Intensity vs. No.")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of lists containing CSV files to be plotted for each group
csv_files_to_plot_list = [
    ["N2n_R.csv", "N2n_W.csv", "N2n_NoR.csv", "N2n_WR.csv"],
    ["N4_R.csv", "N4_W.csv", "N4_NoR.csv", "N4_WR.csv"],
    ["N6_R.csv", "N6_W.csv", "N6_NoR.csv", "N6_WR.csv"],
    ["N8_R.csv", "N8_W.csv", "N8_NoR.csv", "N8_WR.csv"],
    ["N10_R.csv", "N10_W.csv", "N10_NoR.csv", "N10_WR.csv"],
    ["N20_R.csv", "N20_W.csv", "N20_NoR.csv", "N20_WR.csv"],
    ["N40_R.csv", "N40_W.csv", "N40_NoR.csv", "N40_WR.csv"],
    ["N60_R.csv", "N60_W.csv", "N60_NoR.csv", "N60_WR.csv"],
    ["N80_R.csv", "N80_W.csv", "N80_NoR.csv", "N80_WR.csv"],
    ["N100_R.csv", "N100_W.csv", "N100_NoR.csv", "N100_WR.csv"],
    # Add more lists for other groups here
]

# Plot the data for each group
for group_idx, csv_files_to_plot in enumerate(csv_files_to_plot_list):
    # Create an empty DataFrame to store data from selected files
    combined_df = pd.DataFrame()

    # Read and combine data from selected files
    for csv_file in csv_files_to_plot:
        file_path = os.path.join(folder_path, csv_file)
        df = pd.read_csv(file_path)
        combined_df = pd.concat([combined_df, df['Intensity']], axis=1, ignore_index=True)

    # Rename the columns to match the file names
    combined_df.columns = csv_files_to_plot

    # Plot the data
    plt.figure(figsize=(10, 6))
    for csv_file in csv_files_to_plot:
        plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

    plt.xlabel("No.")
    plt.ylabel("Intensity")
    plt.title(f"Intensity vs. No. (Group {group_idx + 1})")
    plt.legend()
    plt.grid(True)

    # Show the plot
    plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# List of lists containing CSV files to be plotted for each group
csv_files_to_plot_list = [
    ["N2n_R.csv", "N2n_W.csv", "N2n_NoR.csv", "N2n_WR.csv"],
    ["N4_R.csv", "N4_W.csv", "N4_NoR.csv", "N4_WR.csv"],
    ["N6_R.csv", "N6_W.csv", "N6_NoR.csv", "N6_WR.csv"],
    ["N8_R.csv", "N8_W.csv", "N8_NoR.csv", "N8_WR.csv"],
    ["N10_R.csv", "N10_W.csv", "N10_NoR.csv", "N10_WR.csv"],
    ["N20_R.csv", "N20_W.csv", "N20_NoR.csv", "N20_WR.csv"],
    ["N40_R.csv", "N40_W.csv", "N40_NoR.csv", "N40_WR.csv"],
    ["N60_R.csv", "N60_W.csv", "N60_NoR.csv", "N60_WR.csv"],
    ["N80_R.csv", "N80_W.csv", "N80_NoR.csv", "N80_WR.csv"],
    ["N100_R.csv", "N100_W.csv", "N100_NoR.csv", "N100_WR.csv"],
    # Add more lists for other groups here
]

# Function to plot data for a group
def plot_group_data(csv_files_to_plot, group_idx):
    # Create an empty DataFrame to store data from selected files
    combined_df = pd.concat([pd.read_csv(os.path.join(folder_path, csv_file))['Intensity'] for csv_file in csv_files_to_plot], axis=1, ignore_index=True)
    combined_df.columns = csv_files_to_plot

    # Plot the data
    plt.figure(figsize=(10, 6))
    for csv_file in csv_files_to_plot:
        plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

    plt.xlabel("No.")
    plt.ylabel("Intensity")
    plt.title(f"Intensity vs. No. (Group {group_idx + 1})")
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot the data for each group
for group_idx, csv_files_to_plot in enumerate(csv_files_to_plot_list):
    plot_group_data(csv_files_to_plot, group_idx)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Specify the folder path
folder_path = "NdatasetCSV"

# Plot the data for each group
for group_idx, csv_files_to_plot in enumerate(csv_files_to_plot_list):
    plot_group_data(csv_files_to_plot, group_idx)

# Function to plot data for a group
def plot_group_data(csv_files_to_plot, group_idx):
    # Create an empty DataFrame to store data from selected files
    combined_df = pd.concat([pd.read_csv(os.path.join(folder_path, csv_file))['Intensity'] for csv_file in csv_files_to_plot], axis=1, ignore_index=True)
    combined_df.columns = csv_files_to_plot

    # Plot the data
    plt.figure(figsize=(10, 6))
    for csv_file in csv_files_to_plot:
        plt.plot(combined_df.index, combined_df[csv_file], label=csv_file)

    plt.xlabel("No.")
    plt.ylabel("Intensity")
    plt.title(f"Intensity vs. No. (Group {group_idx + 1})")
    plt.legend()
    plt.grid(True)
    plt.show()

# List of lists containing CSV files to be plotted for each group
groups = [2, 4, 6, 8, 10, 20, 40, 60, 80, 100]  # Define the groups
csv_files_to_plot_list = [[f"N{group}_R.csv", f"N{group}_W.csv", f"N{group}_NoR.csv", f"N{group}_WR.csv"] for group in groups]
