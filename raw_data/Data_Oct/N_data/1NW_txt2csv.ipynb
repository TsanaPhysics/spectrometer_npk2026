# %% [markdown]
# แปลงไฟล์ txt ในแต่ละโฟลเดอร์  เป็น cvs   และบันทึกไว้ในโฟลเดอร์  NdatasetCSV

# %%
import os
import csv

# ระบุโฟลเดอร์หลัก N_raw
main_folder = "N_raw"

# ระบุโฟลเดอร์ที่จะบันทึกไฟล์ .csv
output_folder_path = "NWdatasetCSV"

# ตรวจสอบว่าโฟลเดอร์ output_folder_path มีอยู่หรือไม่ และสร้างถ้าไม่มี
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# วนลูปผ่านโฟลเดอร์และไฟล์ทั้งหมดในโฟลเดอร์หลัก
for root, _, files in os.walk(main_folder):
    for filename in files:
        if filename.endswith(".txt"):
            # รับที่อยู่ของไฟล์ .txt
            input_file_path = os.path.join(root, filename)
            
            # สร้างชื่อไฟล์ .csv ใหม่โดยนำชื่อไฟล์เดิมมาใช้
            output_file_path = os.path.join(output_folder_path, os.path.splitext(filename)[0] + ".csv")

            # เปิดไฟล์ .txt สำหรับอ่าน
            with open(input_file_path, "r") as txt_file:
                # อ่านข้อมูลทั้งหมดจากไฟล์ .txt
                lines = txt_file.readlines()

            # ตรวจสอบว่ามีข้อมูลในไฟล์หรือไม่
            if len(lines) > 0:
                # ลบข้อมูลในแถวแรก
                lines = lines[1:]

                # เปิดไฟล์ .csv สำหรับเขียน
                with open(output_file_path, "w", newline='') as csv_file:
                    # สร้างอ็อบเจ็กต์ writer สำหรับเขียนข้อมูล CSV
                    csv_writer = csv.writer(csv_file)

                    # เขียนข้อมูลลงในไฟล์ .csv
                    for line in lines:
                        # แบ่งข้อมูลในแต่ละบรรทัดด้วยเครื่องหมาย "," และลบช่องว่างด้านหน้าและหลัง
                        row_data = line.strip().split(",")
                        csv_writer.writerow(row_data)

            print(f"แปลงไฟล์ '{filename}' และบันทึกเป็น '{os.path.basename(output_file_path)}'")

print("เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ NWdatasetCSV")
# Out:
# แปลงไฟล์ 'N100_R.txt' และบันทึกเป็น 'N100_R.csv'
# แปลงไฟล์ 'N100_B.txt' และบันทึกเป็น 'N100_B.csv'
# แปลงไฟล์ 'N100_NoR.txt' และบันทึกเป็น 'N100_NoR.csv'
# แปลงไฟล์ 'N100_W.txt' และบันทึกเป็น 'N100_W.csv'
# แปลงไฟล์ 'N100_A.txt' และบันทึกเป็น 'N100_A.csv'
# แปลงไฟล์ 'N100_blank.txt' และบันทึกเป็น 'N100_blank.csv'
# แปลงไฟล์ 'N100_WR.txt' และบันทึกเป็น 'N100_WR.csv'
# แปลงไฟล์ 'N4_WR.txt' และบันทึกเป็น 'N4_WR.csv'
# แปลงไฟล์ 'N4_NoR.txt' และบันทึกเป็น 'N4_NoR.csv'
# แปลงไฟล์ 'N4_blank.txt' และบันทึกเป็น 'N4_blank.csv'
# แปลงไฟล์ 'N4_R.txt' และบันทึกเป็น 'N4_R.csv'
# แปลงไฟล์ 'N4_B.txt' และบันทึกเป็น 'N4_B.csv'
# แปลงไฟล์ 'N4_W.txt' และบันทึกเป็น 'N4_W.csv'
# แปลงไฟล์ 'N4_A.txt' และบันทึกเป็น 'N4_A.csv'
# แปลงไฟล์ 'N40_WR.txt' และบันทึกเป็น 'N40_WR.csv'
# แปลงไฟล์ 'N40_NoR.txt' และบันทึกเป็น 'N40_NoR.csv'
# แปลงไฟล์ 'N40_blank.txt' และบันทึกเป็น 'N40_blank.csv'
# แปลงไฟล์ 'N40_R.txt' และบันทึกเป็น 'N40_R.csv'
# แปลงไฟล์ 'N40_W.txt' และบันทึกเป็น 'N40_W.csv'
# แปลงไฟล์ 'N40_A.txt' และบันทึกเป็น 'N40_A.csv'
# แปลงไฟล์ 'N40_B.txt' และบันทึกเป็น 'N40_B.csv'
# แปลงไฟล์ 'N2_WR.txt' และบันทึกเป็น 'N2_WR.csv'
# แปลงไฟล์ 'N2_blank.txt' และบันทึกเป็น 'N2_blank.csv'
# แปลงไฟล์ 'N2n_NoR.txt' และบันทึกเป็น 'N2n_NoR.csv'
# แปลงไฟล์ 'N2_B.txt' และบันทึกเป็น 'N2_B.csv'
# แปลงไฟล์ 'N2_W.txt' และบันทึกเป็น 'N2_W.csv'
# แปลงไฟล์ 'N2n_R.txt' และบันทึกเป็น 'N2n_R.csv'
# แปลงไฟล์ 'N2_A.txt' และบันทึกเป็น 'N2_A.csv'
# แปลงไฟล์ 'N2_R.txt' และบันทึกเป็น 'N2_R.csv'
# แปลงไฟล์ 'N2n_W.txt' และบันทึกเป็น 'N2n_W.csv'
# แปลงไฟล์ 'N2n_blank.txt' และบันทึกเป็น 'N2n_blank.csv'
# แปลงไฟล์ 'N2n_B.txt' และบันทึกเป็น 'N2n_B.csv'
# แปลงไฟล์ 'N2n_WR.txt' และบันทึกเป็น 'N2n_WR.csv'
# แปลงไฟล์ 'N60_WR.txt' และบันทึกเป็น 'N60_WR.csv'
# แปลงไฟล์ 'N60_B.txt' และบันทึกเป็น 'N60_B.csv'
# แปลงไฟล์ 'N60_W.txt' และบันทึกเป็น 'N60_W.csv'
# แปลงไฟล์ 'N60_A.txt' และบันทึกเป็น 'N60_A.csv'
# แปลงไฟล์ 'N60_blank.txt' และบันทึกเป็น 'N60_blank.csv'
# แปลงไฟล์ 'N60_NoR.txt' และบันทึกเป็น 'N60_NoR.csv'
# แปลงไฟล์ 'N60_R.txt' และบันทึกเป็น 'N60_R.csv'
# แปลงไฟล์ 'BG_1.txt' และบันทึกเป็น 'BG_1.csv'
# แปลงไฟล์ 'BG_0.txt' และบันทึกเป็น 'BG_0.csv'
# แปลงไฟล์ 'N20_NoR.txt' และบันทึกเป็น 'N20_NoR.csv'
# แปลงไฟล์ 'N20_blank.txt' และบันทึกเป็น 'N20_blank.csv'
# แปลงไฟล์ 'N20_R.txt' และบันทึกเป็น 'N20_R.csv'
# แปลงไฟล์ 'N20_B.txt' และบันทึกเป็น 'N20_B.csv'
# แปลงไฟล์ 'N20_A.txt' และบันทึกเป็น 'N20_A.csv'
# แปลงไฟล์ 'N20_W.txt' และบันทึกเป็น 'N20_W.csv'
# แปลงไฟล์ 'N20_WR.txt' และบันทึกเป็น 'N20_WR.csv'
# แปลงไฟล์ 'N80_blank.txt' และบันทึกเป็น 'N80_blank.csv'
# แปลงไฟล์ 'N80_NoR.txt' และบันทึกเป็น 'N80_NoR.csv'
# แปลงไฟล์ 'N80_WR.txt' และบันทึกเป็น 'N80_WR.csv'
# แปลงไฟล์ 'N80_R.txt' และบันทึกเป็น 'N80_R.csv'
# แปลงไฟล์ 'N80_W.txt' และบันทึกเป็น 'N80_W.csv'
# แปลงไฟล์ 'N80_A.txt' และบันทึกเป็น 'N80_A.csv'
# แปลงไฟล์ 'N80_B.txt' และบันทึกเป็น 'N80_B.csv'
# แปลงไฟล์ 'N10_B.txt' และบันทึกเป็น 'N10_B.csv'
# แปลงไฟล์ 'N10_W.txt' และบันทึกเป็น 'N10_W.csv'
# แปลงไฟล์ 'N10_A.txt' และบันทึกเป็น 'N10_A.csv'
# แปลงไฟล์ 'N10_R.txt' และบันทึกเป็น 'N10_R.csv'
# แปลงไฟล์ 'N10_NoR.txt' และบันทึกเป็น 'N10_NoR.csv'
# แปลงไฟล์ 'N10_blank.txt' และบันทึกเป็น 'N10_blank.csv'
# แปลงไฟล์ 'N10_WR.txt' และบันทึกเป็น 'N10_WR.csv'
# แปลงไฟล์ 'N8_A.txt' และบันทึกเป็น 'N8_A.csv'
# แปลงไฟล์ 'N8_W.txt' และบันทึกเป็น 'N8_W.csv'
# แปลงไฟล์ 'N8_B.txt' และบันทึกเป็น 'N8_B.csv'
# แปลงไฟล์ 'N8_WR.txt' และบันทึกเป็น 'N8_WR.csv'
# แปลงไฟล์ 'N8_R.txt' และบันทึกเป็น 'N8_R.csv'
# แปลงไฟล์ 'N8_blank.txt' และบันทึกเป็น 'N8_blank.csv'
# แปลงไฟล์ 'N8_NoR.txt' และบันทึกเป็น 'N8_NoR.csv'
# แปลงไฟล์ 'N6_blank.txt' และบันทึกเป็น 'N6_blank.csv'
# แปลงไฟล์ 'N6_WR.txt' และบันทึกเป็น 'N6_WR.csv'
# แปลงไฟล์ 'N6_NoR.txt' และบันทึกเป็น 'N6_NoR.csv'
# แปลงไฟล์ 'N6_R.txt' และบันทึกเป็น 'N6_R.csv'
# แปลงไฟล์ 'N6_A.txt' และบันทึกเป็น 'N6_A.csv'
# แปลงไฟล์ 'N6_W.txt' และบันทึกเป็น 'N6_W.csv'
# แปลงไฟล์ 'N6_B.txt' และบันทึกเป็น 'N6_B.csv'
# เสร็จสิ้นการแปลงไฟล์ .txt เป็น .csv และบันทึกในโฟลเดอร์ NWdatasetCSV

# %% [markdown]
# เลื่อนข้อมูลในคอลัมน์ 'Intensity' ขึ้นหนึ่งแถว และลบแถวที่มีคอลัมน์ 'Order' เท่ากับ 0 และคอลัมน์ 'Color' เท่ากับ 'Black' หลังจากนั้นบันทึกข้อมูลที่แก้ไขแล้วในไฟล์ .csv

# %%
import os
import pandas as pd

# Define the column names
column_names = ["No.", "Order", "Color", "Intensity"]

# Specify the folder path
folder_path = "NWdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file with the specified column names
    df = pd.read_csv(file_path, names=column_names)

    # Shift the data in the 'Intensity' column up by one row
    df['Intensity'] = df['Intensity'].shift(-1)

    # Drop rows where 'Order' is equal to 0 and 'Color' is equal to 'Black'
    df = df[(df['Order'] != 0) | (df['Color'] != 'Black')]

    # Specify the original file path and save the modified DataFrame
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'NWdatasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to NWdatasetCSV/N10_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N10_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/N4_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N20_R.csv
# Modified DataFrame saved to NWdatasetCSV/N10_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N2n_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/N20_A.csv
# Modified DataFrame saved to NWdatasetCSV/N20_W.csv
# Modified DataFrame saved to NWdatasetCSV/N80_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N100_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N20_B.csv
# Modified DataFrame saved to NWdatasetCSV/N40_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N2_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N2_W.csv
# Modified DataFrame saved to NWdatasetCSV/N8_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N40_R.csv
# Modified DataFrame saved to NWdatasetCSV/N80_R.csv
# Modified DataFrame saved to NWdatasetCSV/N60_W.csv
# Modified DataFrame saved to NWdatasetCSV/N2n_R.csv
# Modified DataFrame saved to NWdatasetCSV/N8_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/N6_R.csv
# Modified DataFrame saved to NWdatasetCSV/N60_A.csv
# Modified DataFrame saved to NWdatasetCSV/N2_A.csv
# Modified DataFrame saved to NWdatasetCSV/N4_R.csv
# Modified DataFrame saved to NWdatasetCSV/N60_B.csv
# Modified DataFrame saved to NWdatasetCSV/N2_B.csv
# Modified DataFrame saved to NWdatasetCSV/N6_B.csv
# Modified DataFrame saved to NWdatasetCSV/N2n_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N4_W.csv
# Modified DataFrame saved to NWdatasetCSV/N2n_B.csv
# Modified DataFrame saved to NWdatasetCSV/N4_A.csv
# Modified DataFrame saved to NWdatasetCSV/N80_B.csv
# Modified DataFrame saved to NWdatasetCSV/N100_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N40_B.csv
# Modified DataFrame saved to NWdatasetCSV/N2n_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N60_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/N60_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N2_R.csv
# Modified DataFrame saved to NWdatasetCSV/N40_W.csv
# Modified DataFrame saved to NWdatasetCSV/N20_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N60_R.csv
# Modified DataFrame saved to NWdatasetCSV/N6_A.csv
# Modified DataFrame saved to NWdatasetCSV/N80_W.csv
# Modified DataFrame saved to NWdatasetCSV/N4_B.csv
# Modified DataFrame saved to NWdatasetCSV/N2n_W.csv
# Modified DataFrame saved to NWdatasetCSV/N6_W.csv
# Modified DataFrame saved to NWdatasetCSV/N80_A.csv
# Modified DataFrame saved to NWdatasetCSV/N40_A.csv
# Modified DataFrame saved to NWdatasetCSV/N8_B.csv
# Modified DataFrame saved to NWdatasetCSV/N6_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N10_W.csv
# Modified DataFrame saved to NWdatasetCSV/N10_A.csv
# Modified DataFrame saved to NWdatasetCSV/N80_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N8_A.csv
# Modified DataFrame saved to NWdatasetCSV/N10_B.csv
# Modified DataFrame saved to NWdatasetCSV/N8_W.csv
# Modified DataFrame saved to NWdatasetCSV/N6_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N20_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/N4_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/N8_R.csv
# Modified DataFrame saved to NWdatasetCSV/N4_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N80_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/BG_1.csv
# Modified DataFrame saved to NWdatasetCSV/N8_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N10_R.csv
# Modified DataFrame saved to NWdatasetCSV/N60_WR.csv
# Modified DataFrame saved to NWdatasetCSV/BG_0.csv
# Modified DataFrame saved to NWdatasetCSV/N40_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/N6_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/N100_R.csv
# Modified DataFrame saved to NWdatasetCSV/N40_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N20_blank.csv
# Modified DataFrame saved to NWdatasetCSV/N100_NoR.csv
# Modified DataFrame saved to NWdatasetCSV/N100_W.csv
# Modified DataFrame saved to NWdatasetCSV/N2_WR.csv
# Modified DataFrame saved to NWdatasetCSV/N100_A.csv
# Modified DataFrame saved to NWdatasetCSV/N100_B.csv
# All CSV files in the 'NWdatasetCSV' folder have been processed.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "NWdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Remove the last row from the DataFrame
    df = df.iloc[:-1]

    # Save the modified DataFrame back to the same file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Last row removed and file '{csv_file}' saved with the same name.")

print("All CSV files in the 'NWdatasetCSV' folder have had their last row removed and saved with the same name.")
# Out:
# Last row removed and file 'N10_blank.csv' saved with the same name.
# Last row removed and file 'N10_NoR.csv' saved with the same name.
# Last row removed and file 'N4_blank.csv' saved with the same name.
# Last row removed and file 'N20_R.csv' saved with the same name.
# Last row removed and file 'N10_WR.csv' saved with the same name.
# Last row removed and file 'N2n_NoR.csv' saved with the same name.
# Last row removed and file 'N20_A.csv' saved with the same name.
# Last row removed and file 'N20_W.csv' saved with the same name.
# Last row removed and file 'N80_WR.csv' saved with the same name.
# Last row removed and file 'N100_blank.csv' saved with the same name.
# Last row removed and file 'N20_B.csv' saved with the same name.
# Last row removed and file 'N40_blank.csv' saved with the same name.
# Last row removed and file 'N2_blank.csv' saved with the same name.
# Last row removed and file 'N2_W.csv' saved with the same name.
# Last row removed and file 'N8_blank.csv' saved with the same name.
# Last row removed and file 'N40_R.csv' saved with the same name.
# Last row removed and file 'N80_R.csv' saved with the same name.
# Last row removed and file 'N60_W.csv' saved with the same name.
# Last row removed and file 'N2n_R.csv' saved with the same name.
# Last row removed and file 'N8_NoR.csv' saved with the same name.
# Last row removed and file 'N6_R.csv' saved with the same name.
# Last row removed and file 'N60_A.csv' saved with the same name.
# Last row removed and file 'N2_A.csv' saved with the same name.
# Last row removed and file 'N4_R.csv' saved with the same name.
# Last row removed and file 'N60_B.csv' saved with the same name.
# Last row removed and file 'N2_B.csv' saved with the same name.
# Last row removed and file 'N6_B.csv' saved with the same name.
# Last row removed and file 'N2n_blank.csv' saved with the same name.
# Last row removed and file 'N4_W.csv' saved with the same name.
# Last row removed and file 'N2n_B.csv' saved with the same name.
# Last row removed and file 'N4_A.csv' saved with the same name.
# Last row removed and file 'N80_B.csv' saved with the same name.
# Last row removed and file 'N100_WR.csv' saved with the same name.
# Last row removed and file 'N40_B.csv' saved with the same name.
# Last row removed and file 'N2n_WR.csv' saved with the same name.
# Last row removed and file 'N60_NoR.csv' saved with the same name.
# Last row removed and file 'N60_blank.csv' saved with the same name.
# Last row removed and file 'N2_R.csv' saved with the same name.
# Last row removed and file 'N40_W.csv' saved with the same name.
# Last row removed and file 'N20_WR.csv' saved with the same name.
# Last row removed and file 'N60_R.csv' saved with the same name.
# Last row removed and file 'N6_A.csv' saved with the same name.
# Last row removed and file 'N80_W.csv' saved with the same name.
# Last row removed and file 'N4_B.csv' saved with the same name.
# Last row removed and file 'N2n_W.csv' saved with the same name.
# Last row removed and file 'N6_W.csv' saved with the same name.
# Last row removed and file 'N80_A.csv' saved with the same name.
# Last row removed and file 'N40_A.csv' saved with the same name.
# Last row removed and file 'N8_B.csv' saved with the same name.
# Last row removed and file 'N6_WR.csv' saved with the same name.
# Last row removed and file 'N10_W.csv' saved with the same name.
# Last row removed and file 'N10_A.csv' saved with the same name.
# Last row removed and file 'N80_blank.csv' saved with the same name.
# Last row removed and file 'N8_A.csv' saved with the same name.
# Last row removed and file 'N10_B.csv' saved with the same name.
# Last row removed and file 'N8_W.csv' saved with the same name.
# Last row removed and file 'N6_blank.csv' saved with the same name.
# Last row removed and file 'N20_NoR.csv' saved with the same name.
# Last row removed and file 'N4_NoR.csv' saved with the same name.
# Last row removed and file 'N8_R.csv' saved with the same name.
# Last row removed and file 'N4_WR.csv' saved with the same name.
# Last row removed and file 'N80_NoR.csv' saved with the same name.
# Last row removed and file 'BG_1.csv' saved with the same name.
# Last row removed and file 'N8_WR.csv' saved with the same name.
# Last row removed and file 'N10_R.csv' saved with the same name.
# Last row removed and file 'N60_WR.csv' saved with the same name.
# Last row removed and file 'BG_0.csv' saved with the same name.
# Last row removed and file 'N40_NoR.csv' saved with the same name.
# Last row removed and file 'N6_NoR.csv' saved with the same name.
# Last row removed and file 'N100_R.csv' saved with the same name.
# Last row removed and file 'N40_WR.csv' saved with the same name.
# Last row removed and file 'N20_blank.csv' saved with the same name.
# Last row removed and file 'N100_NoR.csv' saved with the same name.
# Last row removed and file 'N100_W.csv' saved with the same name.
# Last row removed and file 'N2_WR.csv' saved with the same name.
# Last row removed and file 'N100_A.csv' saved with the same name.
# Last row removed and file 'N100_B.csv' saved with the same name.
# All CSV files in the 'NWdatasetCSV' folder have had their last row removed and saved with the same name.

# %%
import os

# ระบุโฟลเดอร์หลักที่คุณต้องการทำการสแกน (เช่น 'N_raw')
main_folder = 'N_raw'

# ฟังก์ชันสำหรับแสดงข้อมูลจากไฟล์ .txt และเพิ่มบรรทัดว่างหลังจากแต่ละไฟล์
def display_txt_file_contents(root, files):
    for file in files:
        if file.endswith(".txt"):
            file_path = os.path.join(root, file)
            print(f"ไฟล์: {file_path}")
            with open(file_path, 'r', encoding='utf-8') as txt_file:
                lines = txt_file.readlines()
                for line in lines:
                    print(line.strip())  # แสดงข้อมูลของแต่ละไลน์ในไฟล์
            print("\n" + "=" * 50 + "\n")  # เพิ่มบรรทัดว่างหลังจากแต่ละไฟล์

# เรียกใช้ฟังก์ชันเพื่อทำงาน
if os.path.exists(main_folder):
    for root, dirs, files in os.walk(main_folder):
        display_txt_file_contents(root, files)
else:
    print(f"โฟลเดอร์ '{main_folder}' ไม่พบ")
# Out:
# ไฟล์: N_raw/N_100/N100_R.txt
# N_100NH4CL 100mg/L tube  5ml  Reagent 500ul :08/10/2023,22:42:28
# 1,1,White,4
# 2,2,White,39
# 3,3,White,39
# 4,4,White,39
# 5,5,White,38
# 6,6,White,40
# 7,7,White,42
# 8,8,White,39
# 9,9,White,42
# 10,10,White,40
# 11,11,White,41
# 12,12,White,43
# 13,13,White,41
# 14,14,White,42
# 15,15,White,39
# 16,16,White,39
# 17,17,White,39
# 18,18,White,38
# 19,19,White,39
# 20,20,White,39
# 21,21,White,39
# 22,22,White,40
# 23,23,White,40
# 24,24,White,41
# 25,25,White,42
# 26,26,White,39
# 27,27,White,38
# 28,28,White,36
# 29,29,White,39
# 30,1,Red,39
# 31,2,Red,24
# 32,3,Red,25
# 33,4,Red,25
# 34,5,Red,24
# 35,6,Red,23
# 36,7,Red,24
# 37,8,Red,25
# 38,9,Red,24
# 39,10,Red,23
# 40,11,Red,24
# 41,12,Red,22
# 42,13,Red,24
# 43,14,Red,23
# 44,15,Red,22
# 45,16,Red,23
# 46,17,Red,25
# 47,18,Red,22
# 48,19,Red,24
# 49,20,Red,24
# 50,21,Red,22
# 51,22,Red,22
# 52,23,Red,22
# 53,24,Red,23
# 54,25,Red,25
# 55,26,Red,22
# 56,27,Red,22
# 57,28,Red,25
# 58,29,Red,24
# 59,1,Green,23
# 60,2,Green,13
# 61,3,Green,15
# 62,4,Green,14
# 63,5,Green,14
# 64,6,Green,15
# 65,7,Green,12
# 66,8,Green,14
# 67,9,Green,14
# 68,10,Green,15
# 69,11,Green,13
# 70,12,Green,16
# 71,13,Green,14
# 72,14,Green,13
# 73,15,Green,15
# 74,16,Green,15
# 75,17,Green,14
# 76,18,Green,14
# 77,19,Green,14
# 78,20,Green,13
# 79,21,Green,12
# 80,22,Green,15
# 81,23,Green,13
# 82,24,Green,13
# 83,25,Green,13
# 84,26,Green,14
# 85,27,Green,15
# 86,28,Green,12
# 87,29,Green,12
# 88,30,Green,14
# 89,1,Blue,13
# 90,2,Blue,11
# 91,3,Blue,10
# 92,4,Blue,11
# 93,5,Blue,11
# 94,6,Blue,9
# 95,7,Blue,9
# 96,8,Blue,10
# 97,9,Blue,10
# 98,10,Blue,10
# 99,11,Blue,10
# 100,12,Blue,9
# 101,13,Blue,9
# 102,14,Blue,10
# 103,15,Blue,10
# 104,16,Blue,11
# 105,17,Blue,11
# 106,18,Blue,9
# 107,19,Blue,10
# 108,20,Blue,11
# 109,21,Blue,11
# 110,22,Blue,11
# 111,23,Blue,12
# 112,24,Blue,9
# 113,25,Blue,12
# 114,26,Blue,10
# 115,27,Blue,12
# 116,28,Blue,9
# 117,29,Blue,9
# 118,1,Black,9
# 119,2,Black,3
# 120,3,Black,4
# 121,4,Black,4
# 122,5,Black,4
# 123,6,Black,5
# 124,7,Black,5
# 125,8,Black,4
# 126,9,Black,4
# 127,10,Black,4
# 128,11,Black,4
# 129,12,Black,5
# 130,13,Black,5
# 131,14,Black,4
# 132,15,Black,4
# 133,16,Black,4
# 134,17,Black,5
# 135,18,Black,4
# 136,19,Black,4
# 137,20,Black,4
# 138,21,Black,5
# 139,22,Black,4
# 140,23,Black,3
# 141,24,Black,3
# 142,25,Black,4
# 143,26,Black,4
# 144,27,Black,4
# 145,28,Black,5
# 146,29,Black,4
# 147,0,Black,4
# 148,0,Black,4
# 149,0,Black,4
# 150,0,Black,4
# 151,0,Black,4
# 152,0,Black,5
# 153,0,Black,4
# 154,0,Black,4
# 155,0,Black,4
# 156,0,Black,4
# 157,0,Black,3
# 158,0,Black,4
# 159,0,Black,4
# 160,0,Black,4
# 161,0,Black,4
# 162,0,Black,5
# 163,0,Black,4
# 164,0,Black,4
# 165,0,Black,4
# 166,0,Black,4
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black,5
# 171,0,Black,4
# 172,0,Black,4
# 173,0,Black,5
# 174,0,Black,4
# 175,0,Black,4
# 176,1,White,4
# 177,2,White,37
# 178,3,White,39
# 179,4,White,39
# 180,5,White,39
# 181,6,White,36
# 182,7,White,36
# 183,8,White,39
# 184,9,White,38
# 185,10,White,39
# 186,11,White,37
# 187,12,White,38
# 188,13,White,39
# 189,14,White,37
# 190,15,White,37
# 191,16,White,39
# 192,17,White,40
# 193,18,White,41
# 194,19,White,37
# 195,20,White,40
# 196,21,White,41
# 197,22,White,38
# 198,23,White,37
# 199,24,White,40
# 200,25,White,37
# 201,26,White,36
# 202,27,White,38
# 203,28,White,36
# 204,29,White,39
# 205,30,White,36
# 206,1,Red,38
# 207,2,Red,21
# 208,3,Red,22
# 209,4,Red,24
# 210,5,Red,20
# 211,6,Red,23
# 212,7,Red,23
# 213,8,Red,21
# 214,9,Red,24
# 215,10,Red,23
# 216,11,Red,22
# 217,12,Red,20
# 218,13,Red,22
# 219,14,Red,21
# 220,15,Red,22
# 221,16,Red,23
# 222,17,Red,22
# 223,18,Red,22
# 224,19,Red,24
# 225,20,Red,23
# 226,21,Red,24
# 227,22,Red,21
# 228,23,Red,22
# 229,24,Red,24
# 230,25,Red,21
# 231,26,Red,23
# 232,27,Red,23
# 233,28,Red,21
# 234,29,Red,22
# 235,1,Green,20
# 236,2,Green,14
# 237,3,Green,13
# 238,4,Green,14
# 239,5,Green,12
# 240,6,Green,15
# 241,7,Green,15
# 242,8,Green,13
# 243,9,Green,13
# 244,10,Green,13
# 245,11,Green,13
# 246,12,Green,13
# 247,13,Green,13
# 248,14,Green,13
# 249,15,Green,15
# 250,16,Green,13
# 251,17,Green,13
# 252,18,Green,13
# 253,19,Green,14
# 254,20,Green,13
# 255,21,Green,15
# 256,22,Green,13
# 257,23,Green,13
# 258,24,Green,15
# 259,25,Green,13
# 260,26,Green,12
# 261,27,Green,14
# 262,28,Green,14
# 263,29,Green,15
# 264,1,Blue,13
# 265,2,Blue,9
# 266,3,Blue,9
# 267,4,Blue,9
# 268,5,Blue,11
# 269,6,Blue,10
# 270,7,Blue,10
# 271,8,Blue,11
# 272,9,Blue,9
# 273,10,Blue,10
# 274,11,Blue,11
# 275,12,Blue,11
# 276,13,Blue,9
# 277,14,Blue,10
# 278,15,Blue,10
# 279,16,Blue,11
# 280,17,Blue,9
# 281,18,Blue,10
# 282,19,Blue,11
# 283,20,Blue,10
# 284,21,Blue,11
# 285,22,Blue,10
# 286,23,Blue,9
# 287,24,Blue,11
# 288,25,Blue,9
# 289,26,Blue,10
# 290,27,Blue,9
# 291,28,Blue,11
# 292,29,Blue,11
# 293,1,Black,9
# 294,2,Black,4
# 295,3,Black,4
# 296,4,Black,4
# 297,5,Black,4
# 298,6,Black,4
# 299,7,Black,4
# 300,8,Black,4
# 301,9,Black,5
# 302,10,Black,5
# 303,11,Black,4
# 304,12,Black,4
# 305,13,Black,4
# 306,14,Black,4
# 307,15,Black,4
# 308,16,Black,4
# 309,17,Black,5
# 310,18,Black,4
# 311,19,Black,3
# 312,20,Black,4
# 313,21,Black,4
# 314,22,Black,4
# 315,23,Black,3
# 316,24,Black,4
# 317,25,Black,4
# 318,26,Black,5
# 319,27,Black,4
# 320,28,Black,4
# 321,29,Black,4
# 322,30,Black,4
# 323,0,Black,4
# 324,0,Black,4
# 325,0,Black,4
# 326,0,Black,4
# 327,0,Black,4
# 328,0,Black,4
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,3
# 332,0,Black,4
# 333,0,Black,3
# 334,0,Black,4
# 335,0,Black,3
# 336,0,Black,5
# 337,0,Black,4
# 338,0,Black,3
# 339,0,Black,4
# 340,0,Black,5
# 341,0,Black,5
# 342,0,Black,4
# 343,0,Black,4
# 344,0,Black,5
# 345,0,Black,5
# 346,0,Black,4
# 347,0,Black,5
# 348,0,Black,4
# 349,0,Black,4
# 350,0,Black,4
# 351,0,Black,4
# 352,1,White,3
# 353,2,White,35
# 354,3,White,38
# 355,4,White,39
# 356,5,White,36
# 357,6,White,40
# 358,7,White,36
# 359,8,White,38
# 360,9,White,39
# 361,10,White,35
# 362,11,White,37
# 363,12,White,38
# 364,13,White,37
# 365,14,White,34
# 366,15,White,37
# 367,16,White,39
# 368,17,White,41
# 369,18,White,37
# 370,19,White,38
# 371,20,White,39
# 372,21,White,36
# 373,22,White,37
# 374,23,White,36
# 375,24,White,39
# 376,25,White,37
# 377,26,White,38
# 378,27,White,35
# 379,28,White,35
# 380,29,White,35
# 381,1,Red,35
# 382,2,Red,19
# 383,3,Red,22
# 384,4,Red,24
# 385,5,Red,21
# 386,6,Red,19
# 387,7,Red,21
# 388,8,Red,22
# 389,9,Red,22
# 390,10,Red,21
# 391,11,Red,21
# 392,12,Red,22
# 393,13,Red,24
# 394,14,Red,20
# 395,15,Red,21
# 396,16,Red,21
# 397,17,Red,19
# 398,18,Red,20
# 399,19,Red,21
# 400,20,Red,20
# 401,21,Red,19
# 402,22,Red,23
# 403,23,Red,22
# 404,24,Red,21
# 405,25,Red,21
# 406,26,Red,23
# 407,27,Red,23
# 408,28,Red,21
# 409,29,Red,21
# 410,1,Green,21
# 411,2,Green,14
# 412,3,Green,13
# 413,4,Green,13
# 414,5,Green,14
# 415,6,Green,13
# 416,7,Green,15
# 417,8,Green,13
# 418,9,Green,16
# 419,10,Green,13
# 420,11,Green,12
# 421,12,Green,13
# 422,13,Green,15
# 423,14,Green,15
# 424,15,Green,13
# 425,16,Green,13
# 426,17,Green,14
# 427,18,Green,13
# 428,19,Green,14
# 429,20,Green,13
# 430,21,Green,13
# 431,22,Green,14
# 432,23,Green,15
# 433,24,Green,13
# 434,25,Green,15
# 435,26,Green,13
# 436,27,Green,14
# 437,28,Green,14
# 438,29,Green,15
# 439,30,Green,13
# 440,1,Blue,15
# 441,2,Blue,10
# 442,3,Blue,11
# 443,4,Blue,10
# 444,5,Blue,11
# 445,6,Blue,10
# 446,7,Blue,11
# 447,8,Blue,9
# 448,9,Blue,9
# 449,10,Blue,9
# 450,11,Blue,9
# 451,12,Blue,10
# 452,13,Blue,10
# 453,14,Blue,10
# 454,15,Blue,9
# 455,16,Blue,10
# 456,17,Blue,11
# 457,18,Blue,11
# 458,19,Blue,10
# 459,20,Blue,11
# 460,21,Blue,11
# 461,22,Blue,10
# 462,23,Blue,9
# 463,24,Blue,9
# 464,25,Blue,9
# 465,26,Blue,11
# 466,27,Blue,10
# 467,28,Blue,10
# 468,29,Blue,11
# 469,1,Black,10
# 470,2,Black,4
# 471,3,Black,4
# 472,4,Black,4
# 473,5,Black,4
# 474,6,Black,4
# 475,7,Black,3
# 476,8,Black,4
# 477,9,Black,4
# 478,10,Black,4
# 479,11,Black,5
# 480,12,Black,4
# 481,13,Black,3
# 482,14,Black,4
# 483,15,Black,4
# 484,16,Black,4
# 485,17,Black,4
# 486,18,Black,4
# 487,19,Black,4
# 488,20,Black,4
# 489,21,Black,4
# 490,22,Black,4
# 491,23,Black,4
# 492,24,Black,4
# 493,25,Black,4
# 494,26,Black,5
# 495,27,Black,4
# 496,28,Black,4
# 497,29,Black,4
# 498,0,Black,3
# 499,0,Black,4
# 500,0,Black,4
# 501,0,Black,4
# 502,0,Black,4
# 503,0,Black,4
# 504,0,Black,4
# 505,0,Black,4
# 506,0,Black,4
# 507,0,Black,5
# 508,0,Black,5
# 509,0,Black,4
# 510,0,Black,4
# 511,0,Black,4
# 512,0,Black,5
# 513,0,Black,4
# 514,0,Black,4
# 515,0,Black,4
# 516,0,Black,3
# 517,0,Black,4
# 518,0,Black,5
# 519,0,Black,4
# 520,0,Black,4
# 521,0,Black,3
# 522,0,Black,4
# 523,0,Black,4
# 524,0,Black,4
# 525,0,Black,4
# 526,0,Black,4
# 527,1,White,4
# 528,2,White,37
# 529,3,White,35
# 530,4,White,35
# 531,5,White,39
# 532,6,White,35
# 533,7,White,35
# 534,8,White,35
# 535,9,White,37
# 536,10,White,39
# 537,11,White,39
# 538,12,White,39
# 539,13,White,40
# 540,14,White,35
# 541,15,White,36
# 542,16,White,35
# 543,17,White,38
# 544,18,White,39
# 545,19,White,36
# 546,20,White,35
# 547,21,White,37
# 548,22,White,36
# 549,23,White,37
# 550,24,White,39
# 551,25,White,38
# 552,26,White,37
# 553,27,White,37
# 554,28,White,38
# 555,29,White,36
# 556,30,White,35
# 557,1,Red,36
# 558,2,Red,21
# 559,3,Red,19
# 560,4,Red,22
# 561,5,Red,23
# 562,6,Red,23
# 563,7,Red,22
# 564,8,Red,21
# 565,9,Red,20
# 566,10,Red,22
# 567,11,Red,19
# 568,12,Red,22
# 569,13,Red,19
# 570,14,Red,19
# 571,15,Red,20
# 572,16,Red,20
# 573,17,Red,22
# 574,18,Red,21
# 575,19,Red,22
# 576,20,Red,20
# 577,21,Red,21
# 578,22,Red,21
# 579,23,Red,20
# 580,24,Red,19
# 581,25,Red,21
# 582,26,Red,23
# 583,27,Red,20
# 584,28,Red,19
# 585,29,Red,22
# 586,1,Green,20
# 587,2,Green,13
# 588,3,Green,15
# 589,4,Green,16
# 590,5,Green,14
# 591,6,Green,13
# 592,7,Green,13
# 593,8,Green,14
# 594,9,Green,14
# 595,10,Green,14
# 596,11,Green,13
# 597,12,Green,12
# 598,13,Green,13
# 599,14,Green,13
# 600,15,Green,15
# 601,16,Green,14
# 602,17,Green,15
# 603,18,Green,14
# 604,19,Green,13
# 605,20,Green,13
# 606,21,Green,13
# 607,22,Green,14
# 608,23,Green,13
# 609,24,Green,13
# 610,25,Green,16
# 611,26,Green,12
# 612,27,Green,14
# 613,28,Green,14
# 614,29,Green,13
# 615,1,Blue,15
# 616,2,Blue,9
# 617,3,Blue,11
# 618,4,Blue,10
# 619,5,Blue,10
# 620,6,Blue,10
# 621,7,Blue,10
# 622,8,Blue,11
# 623,9,Blue,9
# 624,10,Blue,11
# 625,11,Blue,12
# 626,12,Blue,10
# 627,13,Blue,12
# 628,14,Blue,9
# 629,15,Blue,10
# 630,16,Blue,10
# 631,17,Blue,11
# 632,18,Blue,9
# 633,19,Blue,10
# 634,20,Blue,9
# 635,21,Blue,11
# 636,22,Blue,10
# 637,23,Blue,11
# 638,24,Blue,11
# 639,25,Blue,9
# 640,26,Blue,9
# 641,27,Blue,11
# 642,28,Blue,9
# 643,29,Blue,11
# 644,1,Black,10
# 645,2,Black,4
# 646,3,Black,5
# 647,4,Black,4
# 648,5,Black,4
# 649,6,Black,5
# 650,7,Black,4
# 651,8,Black,4
# 652,9,Black,5
# 653,10,Black,4
# 654,11,Black,4
# 655,12,Black,4
# 656,13,Black,4
# 657,14,Black,5
# 658,15,Black,4
# 659,16,Black,4
# 660,17,Black,4
# 661,18,Black,4
# 662,19,Black,4
# 663,20,Black,4
# 664,21,Black,4
# 665,22,Black,5
# 666,23,Black,4
# 667,24,Black,4
# 668,25,Black,4
# 669,26,Black,4
# 670,27,Black,4
# 671,28,Black,4
# 672,29,Black,4
# 673,0,Black,5
# 674,0,Black,4
# 675,0,Black,3
# 676,0,Black,4
# 677,0,Black,4
# 678,0,Black,4
# 679,0,Black,4
# 680,0,Black,4
#
# ==================================================
#
# ไฟล์: N_raw/N_100/N100_B.txt
# N_100_BNH4CL 100mg/L tube  5ml  Reagent 500ul ten hours :09/10/2023,01:19:48
# 1,1,White,3
# 2,2,White,30
# 3,3,White,30
# 4,4,White,28
# 5,5,White,28
# 6,6,White,32
# 7,7,White,29
# 8,8,White,27
# 9,9,White,27
# 10,10,White,31
# 11,11,White,27
# 12,12,White,29
# 13,13,White,28
# 14,14,White,29
# 15,15,White,29
# 16,16,White,30
# 17,17,White,30
# 18,18,White,28
# 19,19,White,31
# 20,20,White,29
# 21,21,White,27
# 22,22,White,27
# 23,23,White,31
# 24,24,White,28
# 25,25,White,29
# 26,26,White,30
# 27,27,White,28
# 28,28,White,29
# 29,29,White,27
# 30,1,Red,28
# 31,2,Red,14
# 32,3,Red,16
# 33,4,Red,13
# 34,5,Red,15
# 35,6,Red,14
# 36,7,Red,16
# 37,8,Red,14
# 38,9,Red,14
# 39,10,Red,14
# 40,11,Red,14
# 41,12,Red,14
# 42,13,Red,13
# 43,14,Red,14
# 44,15,Red,16
# 45,16,Red,13
# 46,17,Red,14
# 47,18,Red,14
# 48,19,Red,14
# 49,20,Red,13
# 50,21,Red,13
# 51,22,Red,15
# 52,23,Red,15
# 53,24,Red,14
# 54,25,Red,14
# 55,26,Red,16
# 56,27,Red,16
# 57,28,Red,14
# 58,29,Red,13
# 59,1,Green,15
# 60,2,Green,12
# 61,3,Green,15
# 62,4,Green,12
# 63,5,Green,14
# 64,6,Green,14
# 65,7,Green,12
# 66,8,Green,12
# 67,9,Green,13
# 68,10,Green,13
# 69,11,Green,13
# 70,12,Green,12
# 71,13,Green,12
# 72,14,Green,15
# 73,15,Green,14
# 74,16,Green,12
# 75,17,Green,13
# 76,18,Green,13
# 77,19,Green,12
# 78,20,Green,12
# 79,21,Green,12
# 80,22,Green,13
# 81,23,Green,13
# 82,24,Green,14
# 83,25,Green,12
# 84,26,Green,15
# 85,27,Green,12
# 86,28,Green,15
# 87,29,Green,12
# 88,1,Blue,12
# 89,2,Blue,9
# 90,3,Blue,8
# 91,4,Blue,9
# 92,5,Blue,8
# 93,6,Blue,8
# 94,7,Blue,9
# 95,8,Blue,10
# 96,9,Blue,9
# 97,10,Blue,10
# 98,11,Blue,9
# 99,12,Blue,8
# 100,13,Blue,9
# 101,14,Blue,9
# 102,15,Blue,9
# 103,16,Blue,8
# 104,17,Blue,9
# 105,18,Blue,9
# 106,19,Blue,9
# 107,20,Blue,8
# 108,21,Blue,9
# 109,22,Blue,10
# 110,23,Blue,9
# 111,24,Blue,9
# 112,25,Blue,9
# 113,26,Blue,10
# 114,27,Blue,9
# 115,28,Blue,9
# 116,29,Blue,8
# 117,1,Black,10
# 118,2,Black,4
# 119,3,Black,5
# 120,4,Black,4
# 121,5,Black,4
# 122,6,Black,4
# 123,7,Black,4
# 124,8,Black,4
# 125,9,Black,3
# 126,10,Black,4
# 127,11,Black,4
# 128,12,Black,3
# 129,13,Black,5
# 130,14,Black,4
# 131,15,Black,4
# 132,16,Black,4
# 133,17,Black,4
# 134,18,Black,4
# 135,19,Black,4
# 136,20,Black,5
# 137,21,Black,4
# 138,22,Black,4
# 139,23,Black,5
# 140,24,Black,4
# 141,25,Black,5
# 142,26,Black,3
# 143,27,Black,4
# 144,28,Black,5
# 145,29,Black,4
# 146,0,Black,4
# 147,0,Black,4
# 148,0,Black,4
# 149,0,Black,4
# 150,0,Black,3
# 151,0,Black,4
# 152,0,Black,5
# 153,0,Black,4
# 154,0,Black,5
# 155,0,Black,3
# 156,0,Black,4
# 157,0,Black,4
# 158,0,Black,4
# 159,0,Black,4
# 160,0,Black,3
# 161,0,Black,4
# 162,0,Black,4
# 163,0,Black,4
# 164,0,Black,4
# 165,0,Black,3
# 166,0,Black,4
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black,4
# 171,0,Black,5
# 172,0,Black,4
# 173,0,Black,4
# 174,0,Black,5
# 175,1,White,3
# 176,2,White,33
# 177,3,White,32
# 178,4,White,35
# 179,5,White,34
# 180,6,White,32
# 181,7,White,32
# 182,8,White,32
# 183,9,White,33
# 184,10,White,36
# 185,11,White,33
# 186,12,White,33
# 187,13,White,35
# 188,14,White,36
# 189,15,White,34
# 190,16,White,35
# 191,17,White,35
# 192,18,White,34
# 193,19,White,32
# 194,20,White,35
# 195,21,White,33
# 196,22,White,34
# 197,23,White,36
# 198,24,White,36
# 199,25,White,33
# 200,26,White,33
# 201,27,White,37
# 202,28,White,37
# 203,29,White,37
# 204,1,Red,34
# 205,2,Red,19
# 206,3,Red,19
# 207,4,Red,20
# 208,5,Red,21
# 209,6,Red,21
# 210,7,Red,21
# 211,8,Red,21
# 212,9,Red,19
# 213,10,Red,20
# 214,11,Red,21
# 215,12,Red,19
# 216,13,Red,19
# 217,14,Red,19
# 218,15,Red,21
# 219,16,Red,20
# 220,17,Red,21
# 221,18,Red,19
# 222,19,Red,22
# 223,20,Red,21
# 224,21,Red,21
# 225,22,Red,19
# 226,23,Red,22
# 227,24,Red,19
# 228,25,Red,22
# 229,26,Red,19
# 230,27,Red,21
# 231,28,Red,22
# 232,29,Red,21
# 233,1,Green,19
# 234,2,Green,14
# 235,3,Green,13
# 236,4,Green,13
# 237,5,Green,13
# 238,6,Green,13
# 239,7,Green,15
# 240,8,Green,13
# 241,9,Green,15
# 242,10,Green,15
# 243,11,Green,14
# 244,12,Green,16
# 245,13,Green,13
# 246,14,Green,13
# 247,15,Green,16
# 248,16,Green,15
# 249,17,Green,14
# 250,18,Green,14
# 251,19,Green,13
# 252,20,Green,16
# 253,21,Green,13
# 254,22,Green,15
# 255,23,Green,14
# 256,24,Green,15
# 257,25,Green,13
# 258,26,Green,13
# 259,27,Green,13
# 260,28,Green,15
# 261,29,Green,12
# 262,1,Blue,16
# 263,2,Blue,10
# 264,3,Blue,9
# 265,4,Blue,8
# 266,5,Blue,9
# 267,6,Blue,9
# 268,7,Blue,9
# 269,8,Blue,9
# 270,9,Blue,9
# 271,10,Blue,8
# 272,11,Blue,9
# 273,12,Blue,9
# 274,13,Blue,10
# 275,14,Blue,10
# 276,15,Blue,10
# 277,16,Blue,9
# 278,17,Blue,8
# 279,18,Blue,9
# 280,19,Blue,8
# 281,20,Blue,9
# 282,21,Blue,9
# 283,22,Blue,10
# 284,23,Blue,10
# 285,24,Blue,9
# 286,25,Blue,9
# 287,26,Blue,8
# 288,27,Blue,9
# 289,28,Blue,10
# 290,29,Blue,9
# 291,1,Black,8
# 292,2,Black,3
# 293,3,Black,5
# 294,4,Black,4
# 295,5,Black,5
# 296,6,Black,3
# 297,7,Black,4
# 298,8,Black,4
# 299,9,Black,5
# 300,10,Black,4
# 301,11,Black,4
# 302,12,Black,5
# 303,13,Black,4
# 304,14,Black,4
# 305,15,Black,5
# 306,16,Black,4
# 307,17,Black,3
# 308,18,Black,4
# 309,19,Black,3
# 310,20,Black,4
# 311,21,Black,4
# 312,22,Black,4
# 313,23,Black,3
# 314,24,Black,4
# 315,25,Black,4
# 316,26,Black,4
# 317,27,Black,4
# 318,28,Black,4
# 319,29,Black,4
# 320,0,Black,4
# 321,0,Black,3
# 322,0,Black,3
# 323,0,Black,4
# 324,0,Black,4
# 325,0,Black,4
# 326,0,Black,4
# 327,0,Black,4
# 328,0,Black,4
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,3
# 332,0,Black,3
# 333,0,Black,4
# 334,0,Black,4
# 335,0,Black,4
# 336,0,Black,3
# 337,0,Black,4
# 338,0,Black,5
# 339,0,Black,4
# 340,0,Black,3
# 341,0,Black,4
# 342,0,Black,4
# 343,0,Black,4
# 344,0,Black,5
# 345,0,Black,4
# 346,0,Black,5
# 347,0,Black,4
# 348,0,Black,4
# 349,1,White,4
# 350,2,White,40
# 351,3,White,41
# 352,4,White,41
# 353,5,White,38
# 354,6,White,41
# 355,7,White,41
# 356,8,White,41
# 357,9,White,41
# 358,10,White,43
# 359,11,White,39
# 360,12,White,42
# 361,13,White,39
# 362,14,White,42
# 363,15,White,41
# 364,16,White,39
# 365,17,White,39
# 366,18,White,41
# 367,19,White,41
# 368,20,White,43
# 369,21,White,38
# 370,22,White,39
# 371,23,White,43
# 372,24,White,40
# 373,25,White,40
# 374,26,White,39
# 375,27,White,39
# 376,28,White,41
# 377,29,White,44
# 378,1,Red,41
# 379,2,Red,24
# 380,3,Red,24
# 381,4,Red,24
# 382,5,Red,25
# 383,6,Red,23
# 384,7,Red,23
# 385,8,Red,25
# 386,9,Red,26
# 387,10,Red,24
# 388,11,Red,27
# 389,12,Red,24
# 390,13,Red,25
# 391,14,Red,27
# 392,15,Red,23
# 393,16,Red,25
# 394,17,Red,25
# 395,18,Red,24
# 396,19,Red,23
# 397,20,Red,24
# 398,21,Red,24
# 399,22,Red,28
# 400,23,Red,27
# 401,24,Red,25
# 402,25,Red,25
# 403,26,Red,25
# 404,27,Red,25
# 405,28,Red,23
# 406,29,Red,27
# 407,1,Green,25
# 408,2,Green,15
# 409,3,Green,14
# 410,4,Green,15
# 411,5,Green,14
# 412,6,Green,16
# 413,7,Green,14
# 414,8,Green,15
# 415,9,Green,17
# 416,10,Green,17
# 417,11,Green,14
# 418,12,Green,16
# 419,13,Green,15
# 420,14,Green,15
# 421,15,Green,16
# 422,16,Green,16
# 423,17,Green,13
# 424,18,Green,15
# 425,19,Green,14
# 426,20,Green,14
# 427,21,Green,16
# 428,22,Green,16
# 429,23,Green,16
# 430,24,Green,14
# 431,25,Green,16
# 432,26,Green,17
# 433,27,Green,14
# 434,28,Green,15
# 435,29,Green,16
# 436,1,Blue,14
# 437,2,Blue,8
# 438,3,Blue,10
# 439,4,Blue,10
# 440,5,Blue,10
# 441,6,Blue,9
# 442,7,Blue,9
# 443,8,Blue,10
# 444,9,Blue,10
# 445,10,Blue,9
# 446,11,Blue,9
# 447,12,Blue,10
# 448,13,Blue,9
# 449,14,Blue,8
# 450,15,Blue,9
# 451,16,Blue,9
# 452,17,Blue,10
# 453,18,Blue,11
# 454,19,Blue,11
# 455,20,Blue,9
# 456,21,Blue,9
# 457,22,Blue,9
# 458,23,Blue,10
# 459,24,Blue,9
# 460,25,Blue,9
# 461,26,Blue,11
# 462,27,Blue,10
# 463,28,Blue,9
# 464,29,Blue,11
# 465,1,Black,9
# 466,2,Black,4
# 467,3,Black,4
# 468,4,Black,4
# 469,5,Black,3
# 470,6,Black,4
# 471,7,Black,4
# 472,8,Black,4
# 473,9,Black,3
# 474,10,Black,5
# 475,11,Black,4
# 476,12,Black,4
# 477,13,Black,4
# 478,14,Black,4
# 479,15,Black,4
# 480,16,Black,4
# 481,17,Black,3
# 482,18,Black,4
# 483,19,Black,3
# 484,20,Black,4
# 485,21,Black,4
# 486,22,Black,4
# 487,23,Black,4
# 488,24,Black,4
# 489,25,Black,4
# 490,26,Black,4
# 491,27,Black,5
# 492,28,Black,4
# 493,29,Black,5
# 494,0,Black,4
# 495,0,Black,4
# 496,0,Black,4
# 497,0,Black,3
# 498,0,Black,4
# 499,0,Black,4
# 500,0,Black,5
# 501,0,Black,5
# 502,0,Black,4
# 503,0,Black,3
# 504,0,Black,4
# 505,0,Black,4
# 506,0,Black,4
# 507,0,Black,4
# 508,0,Black,4
# 509,0,Black,3
# 510,0,Black,4
# 511,0,Black,4
# 512,0,Black,4
# 513,0,Black,3
# 514,0,Black,4
# 515,0,Black,4
# 516,0,Black,4
# 517,0,Black,4
# 518,0,Black,4
# 519,0,Black,4
# 520,0,Black,5
# 521,0,Black,4
# 522,0,Black,4
# 523,1,White,4
# 524,2,White,43
# 525,3,White,46
# 526,4,White,41
# 527,5,White,43
# 528,6,White,46
# 529,7,White,42
# 530,8,White,42
# 531,9,White,44
# 532,10,White,45
# 533,11,White,43
# 534,12,White,47
# 535,13,White,47
# 536,14,White,43
# 537,15,White,43
# 538,16,White,43
# 539,17,White,44
# 540,18,White,48
# 541,19,White,48
# 542,20,White,44
# 543,21,White,47
# 544,22,White,49
# 545,23,White,44
# 546,24,White,45
# 547,25,White,47
# 548,26,White,43
# 549,27,White,43
# 550,28,White,47
# 551,29,White,43
# 552,1,Red,43
# 553,2,Red,28
# 554,3,Red,26
# 555,4,Red,27
# 556,5,Red,26
# 557,6,Red,27
# 558,7,Red,29
# 559,8,Red,28
# 560,9,Red,26
# 561,10,Red,26
# 562,11,Red,29
# 563,12,Red,29
# 564,13,Red,29
# 565,14,Red,27
# 566,15,Red,26
# 567,16,Red,27
# 568,17,Red,29
# 569,18,Red,27
# 570,19,Red,28
# 571,20,Red,28
# 572,21,Red,27
# 573,22,Red,27
# 574,23,Red,27
# 575,24,Red,29
# 576,25,Red,26
# 577,26,Red,27
# 578,27,Red,30
# 579,28,Red,31
# 580,29,Red,27
# 581,1,Green,31
# 582,2,Green,15
# 583,3,Green,15
# 584,4,Green,17
# 585,5,Green,16
# 586,6,Green,16
# 587,7,Green,17
# 588,8,Green,15
# 589,9,Green,15
# 590,10,Green,15
# 591,11,Green,16
# 592,12,Green,15
# 593,13,Green,15
# 594,14,Green,17
# 595,15,Green,15
# 596,16,Green,16
# 597,17,Green,15
# 598,18,Green,17
# 599,19,Green,15
# 600,20,Green,17
# 601,21,Green,15
# 602,22,Green,15
# 603,23,Green,14
# 604,24,Green,15
# 605,25,Green,17
# 606,26,Green,15
# 607,27,Green,16
# 608,28,Green,17
# 609,29,Green,16
# 610,1,Blue,17
# 611,2,Blue,10
# 612,3,Blue,10
# 613,4,Blue,10
# 614,5,Blue,10
# 615,6,Blue,9
# 616,7,Blue,9
# 617,8,Blue,10
# 618,9,Blue,9
# 619,10,Blue,10
# 620,11,Blue,9
# 621,12,Blue,9
# 622,13,Blue,10
# 623,14,Blue,9
# 624,15,Blue,9
# 625,16,Blue,10
# 626,17,Blue,10
# 627,18,Blue,10
# 628,19,Blue,10
# 629,20,Blue,9
# 630,21,Blue,11
# 631,22,Blue,9
# 632,23,Blue,9
# 633,24,Blue,9
# 634,25,Blue,11
# 635,26,Blue,10
# 636,27,Blue,9
# 637,28,Blue,9
# 638,29,Blue,10
# 639,1,Black,9
# 640,2,Black,5
# 641,3,Black,4
# 642,4,Black,4
# 643,5,Black,3
# 644,6,Black,4
# 645,7,Black,3
# 646,8,Black,4
# 647,9,Black,5
# 648,10,Black,4
# 649,11,Black,4
# 650,12,Black,5
# 651,13,Black,4
# 652,14,Black,4
# 653,15,Black,4
# 654,16,Black,4
# 655,17,Black,3
# 656,18,Black,5
# 657,19,Black,4
# 658,20,Black,4
# 659,21,Black,4
# 660,22,Black,4
# 661,23,Black,5
# 662,24,Black,5
# 663,25,Black,4
# 664,26,Black,3
# 665,27,Black,4
# 666,28,Black,4
# 667,29,Black,5
# 668,0,Black,3
# 669,0,Black,5
# 670,0,Black,4
# 671,0,Black,4
# 672,0,Black,4
# 673,0,Black,4
# 674,0,Black,4
# 675,0,Black,4
# 676,0,Black,4
# 677,0,Black,4
# 678,0,Black,3
# 679,0,Black,3
# 680,0,Black,4
#
# ==================================================
#
# ไฟล์: N_raw/N_100/N100_NoR.txt
# N_100_No_RNH4CL 1000mg/L tube  5ml  No Reagent :08/10/2023,22:34:14
# 1,1,White,5
# 2,2,White,839
# 3,3,White,841
# 4,4,White,846
# 5,5,White,849
# 6,6,White,852
# 7,7,White,849
# 8,8,White,850
# 9,9,White,849
# 10,10,White,852
# 11,11,White,852
# 12,12,White,855
# 13,13,White,853
# 14,14,White,850
# 15,15,White,848
# 16,16,White,848
# 17,17,White,849
# 18,18,White,852
# 19,19,White,857
# 20,20,White,858
# 21,21,White,857
# 22,22,White,858
# 23,23,White,854
# 24,24,White,852
# 25,25,White,861
# 26,26,White,858
# 27,27,White,851
# 28,28,White,857
# 29,29,White,860
# 30,1,Red,859
# 31,2,Red,315
# 32,3,Red,319
# 33,4,Red,316
# 34,5,Red,321
# 35,6,Red,317
# 36,7,Red,316
# 37,8,Red,315
# 38,9,Red,315
# 39,10,Red,313
# 40,11,Red,318
# 41,12,Red,321
# 42,13,Red,317
# 43,14,Red,309
# 44,15,Red,316
# 45,16,Red,314
# 46,17,Red,313
# 47,18,Red,314
# 48,19,Red,315
# 49,20,Red,316
# 50,21,Red,318
# 51,22,Red,315
# 52,23,Red,312
# 53,24,Red,315
# 54,25,Red,317
# 55,26,Red,310
# 56,27,Red,318
# 57,28,Red,317
# 58,29,Red,317
# 59,1,Green,313
# 60,2,Green,356
# 61,3,Green,358
# 62,4,Green,356
# 63,5,Green,359
# 64,6,Green,353
# 65,7,Green,356
# 66,8,Green,356
# 67,9,Green,363
# 68,10,Green,356
# 69,11,Green,355
# 70,12,Green,357
# 71,13,Green,362
# 72,14,Green,359
# 73,15,Green,362
# 74,16,Green,355
# 75,17,Green,357
# 76,18,Green,362
# 77,19,Green,362
# 78,20,Green,362
# 79,21,Green,358
# 80,22,Green,354
# 81,23,Green,357
# 82,24,Green,361
# 83,25,Green,362
# 84,26,Green,354
# 85,27,Green,360
# 86,28,Green,358
# 87,29,Green,361
# 88,1,Blue,354
# 89,2,Blue,238
# 90,3,Blue,237
# 91,4,Blue,236
# 92,5,Blue,234
# 93,6,Blue,233
# 94,7,Blue,241
# 95,8,Blue,236
# 96,9,Blue,231
# 97,10,Blue,233
# 98,11,Blue,238
# 99,12,Blue,237
# 100,13,Blue,241
# 101,14,Blue,236
# 102,15,Blue,237
# 103,16,Blue,236
# 104,17,Blue,233
# 105,18,Blue,234
# 106,19,Blue,238
# 107,20,Blue,235
# 108,21,Blue,234
# 109,22,Blue,235
# 110,23,Blue,238
# 111,24,Blue,238
# 112,25,Blue,239
# 113,26,Blue,237
# 114,27,Blue,235
# 115,28,Blue,239
# 116,29,Blue,238
# 117,30,Blue,234
# 118,1,Black,235
# 119,2,Black,4
# 120,3,Black,4
# 121,4,Black,4
# 122,5,Black,4
# 123,6,Black,5
# 124,7,Black,4
# 125,8,Black,5
# 126,9,Black,4
# 127,10,Black,4
# 128,11,Black,4
# 129,12,Black,4
# 130,13,Black,4
# 131,14,Black,4
# 132,15,Black,4
# 133,16,Black,4
# 134,17,Black,4
# 135,18,Black,4
# 136,19,Black,4
# 137,20,Black,4
# 138,21,Black,4
# 139,22,Black,4
# 140,23,Black,4
# 141,24,Black,4
# 142,25,Black,5
# 143,26,Black,4
# 144,27,Black,5
# 145,28,Black,4
# 146,29,Black,5
# 147,0,Black,4
# 148,0,Black,4
# 149,0,Black,4
# 150,0,Black,4
# 151,0,Black,3
# 152,0,Black,4
# 153,0,Black,4
# 154,0,Black,4
# 155,0,Black,5
# 156,0,Black,4
# 157,0,Black,4
# 158,0,Black,4
# 159,0,Black,4
# 160,0,Black,4
# 161,0,Black,3
# 162,0,Black,5
# 163,0,Black,4
# 164,0,Black,4
# 165,0,Black,3
# 166,0,Black,5
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,5
# 170,0,Black,5
# 171,0,Black,5
# 172,0,Black,4
# 173,0,Black,4
# 174,0,Black,4
# 175,0,Black,4
# 176,1,White,4
# 177,2,White,855
# 178,3,White,851
# 179,4,White,861
# 180,5,White,861
# 181,6,White,856
# 182,7,White,853
# 183,8,White,856
# 184,9,White,854
# 185,10,White,855
# 186,11,White,848
# 187,12,White,854
# 188,13,White,860
# 189,14,White,848
# 190,15,White,855
# 191,16,White,851
# 192,17,White,845
# 193,18,White,853
# 194,19,White,857
# 195,20,White,848
# 196,21,White,857
# 197,22,White,857
# 198,23,White,853
# 199,24,White,850
# 200,25,White,855
# 201,26,White,857
# 202,27,White,854
# 203,28,White,852
# 204,29,White,849
# 205,1,Red,862
# 206,2,Red,320
# 207,3,Red,314
# 208,4,Red,313
# 209,5,Red,314
# 210,6,Red,315
# 211,7,Red,320
# 212,8,Red,318
# 213,9,Red,318
# 214,10,Red,313
# 215,11,Red,318
# 216,12,Red,316
# 217,13,Red,318
# 218,14,Red,314
# 219,15,Red,321
# 220,16,Red,321
# 221,17,Red,314
# 222,18,Red,313
# 223,19,Red,311
# 224,20,Red,315
# 225,21,Red,317
# 226,22,Red,314
# 227,23,Red,314
# 228,24,Red,312
# 229,25,Red,314
# 230,26,Red,314
# 231,27,Red,314
# 232,28,Red,310
# 233,29,Red,318
# 234,30,Red,318
# 235,1,Green,318
# 236,2,Green,352
# 237,3,Green,358
# 238,4,Green,357
# 239,5,Green,355
# 240,6,Green,353
# 241,7,Green,353
# 242,8,Green,357
# 243,9,Green,356
# 244,10,Green,355
# 245,11,Green,357
# 246,12,Green,358
# 247,13,Green,355
# 248,14,Green,352
# 249,15,Green,352
# 250,16,Green,351
# 251,17,Green,356
# 252,18,Green,356
# 253,19,Green,353
# 254,20,Green,354
# 255,21,Green,352
# 256,22,Green,350
# 257,23,Green,349
# 258,24,Green,353
# 259,25,Green,359
# 260,26,Green,353
# 261,27,Green,349
# 262,28,Green,350
# 263,29,Green,354
# 264,1,Blue,350
# 265,2,Blue,237
# 266,3,Blue,237
# 267,4,Blue,236
# 268,5,Blue,240
# 269,6,Blue,233
# 270,7,Blue,233
# 271,8,Blue,234
# 272,9,Blue,236
# 273,10,Blue,234
# 274,11,Blue,233
# 275,12,Blue,236
# 276,13,Blue,241
# 277,14,Blue,235
# 278,15,Blue,235
# 279,16,Blue,240
# 280,17,Blue,233
# 281,18,Blue,234
# 282,19,Blue,234
# 283,20,Blue,234
# 284,21,Blue,230
# 285,22,Blue,237
# 286,23,Blue,233
# 287,24,Blue,235
# 288,25,Blue,231
# 289,26,Blue,230
# 290,27,Blue,241
# 291,28,Blue,234
# 292,29,Blue,235
# 293,1,Black,230
# 294,2,Black,4
# 295,3,Black,4
# 296,4,Black,5
# 297,5,Black,3
# 298,6,Black,5
# 299,7,Black,4
# 300,8,Black,4
# 301,9,Black,4
# 302,10,Black,4
# 303,11,Black,4
# 304,12,Black,4
# 305,13,Black,5
# 306,14,Black,4
# 307,15,Black,4
# 308,16,Black,5
# 309,17,Black,4
# 310,18,Black,5
# 311,19,Black,4
# 312,20,Black,5
# 313,21,Black,4
# 314,22,Black,4
# 315,23,Black,4
# 316,24,Black,4
# 317,25,Black,4
# 318,26,Black,5
# 319,27,Black,4
# 320,28,Black,5
# 321,29,Black,5
# 322,0,Black,5
# 323,0,Black,4
# 324,0,Black,4
# 325,0,Black,4
# 326,0,Black,4
# 327,0,Black,4
# 328,0,Black,5
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,4
# 332,0,Black,4
# 333,0,Black,4
# 334,0,Black,4
# 335,0,Black,4
# 336,0,Black,4
# 337,0,Black,4
# 338,0,Black,4
# 339,0,Black,4
# 340,0,Black,5
# 341,0,Black,4
# 342,0,Black,4
# 343,0,Black,4
# 344,0,Black,5
# 345,0,Black,4
# 346,0,Black,4
# 347,0,Black,4
# 348,0,Black,4
# 349,0,Black,4
# 350,0,Black,4
# 351,0,Black,5
# 352,1,White,4
# 353,2,White,852
# 354,3,White,858
# 355,4,White,851
# 356,5,White,844
# 357,6,White,852
# 358,7,White,855
# 359,8,White,856
# 360,9,White,853
# 361,10,White,855
# 362,11,White,852
# 363,12,White,855
# 364,13,White,856
# 365,14,White,853
# 366,15,White,852
# 367,16,White,851
# 368,17,White,849
# 369,18,White,850
# 370,19,White,853
# 371,20,White,850
# 372,21,White,852
# 373,22,White,851
# 374,23,White,849
# 375,24,White,857
# 376,25,White,855
# 377,26,White,853
# 378,27,White,853
# 379,28,White,851
# 380,29,White,857
# 381,1,Red,856
# 382,2,Red,314
# 383,3,Red,317
# 384,4,Red,319
# 385,5,Red,309
# 386,6,Red,316
# 387,7,Red,314
# 388,8,Red,314
# 389,9,Red,314
# 390,10,Red,314
# 391,11,Red,318
# 392,12,Red,319
# 393,13,Red,314
# 394,14,Red,318
# 395,15,Red,313
# 396,16,Red,311
# 397,17,Red,314
# 398,18,Red,310
# 399,19,Red,313
# 400,20,Red,313
# 401,21,Red,315
# 402,22,Red,311
# 403,23,Red,308
# 404,24,Red,316
# 405,25,Red,321
# 406,26,Red,315
# 407,27,Red,314
# 408,28,Red,320
# 409,29,Red,307
# 410,1,Green,314
# 411,2,Green,354
# 412,3,Green,351
# 413,4,Green,352
# 414,5,Green,354
# 415,6,Green,351
# 416,7,Green,355
# 417,8,Green,352
# 418,9,Green,359
# 419,10,Green,353
# 420,11,Green,352
# 421,12,Green,358
# 422,13,Green,357
# 423,14,Green,354
# 424,15,Green,350
# 425,16,Green,357
# 426,17,Green,355
# 427,18,Green,359
# 428,19,Green,353
# 429,20,Green,354
# 430,21,Green,355
# 431,22,Green,352
# 432,23,Green,352
# 433,24,Green,351
# 434,25,Green,356
# 435,26,Green,347
# 436,27,Green,357
# 437,28,Green,358
# 438,29,Green,355
# 439,1,Blue,354
# 440,2,Blue,233
# 441,3,Blue,240
# 442,4,Blue,238
# 443,5,Blue,237
# 444,6,Blue,232
# 445,7,Blue,237
# 446,8,Blue,232
# 447,9,Blue,239
# 448,10,Blue,239
# 449,11,Blue,238
# 450,12,Blue,234
# 451,13,Blue,236
# 452,14,Blue,233
# 453,15,Blue,235
# 454,16,Blue,237
# 455,17,Blue,239
# 456,18,Blue,236
# 457,19,Blue,236
# 458,20,Blue,237
# 459,21,Blue,233
# 460,22,Blue,236
# 461,23,Blue,234
# 462,24,Blue,236
# 463,25,Blue,240
# 464,26,Blue,241
# 465,27,Blue,238
# 466,28,Blue,237
# 467,29,Blue,236
# 468,30,Blue,239
# 469,1,Black,240
# 470,2,Black,4
# 471,3,Black,4
# 472,4,Black,4
# 473,5,Black,4
# 474,6,Black,5
# 475,7,Black,3
# 476,8,Black,4
# 477,9,Black,5
# 478,10,Black,4
# 479,11,Black,4
# 480,12,Black,5
# 481,13,Black,5
# 482,14,Black,5
# 483,15,Black,5
# 484,16,Black,4
# 485,17,Black,4
# 486,18,Black,5
# 487,19,Black,4
# 488,20,Black,4
# 489,21,Black,4
# 490,22,Black,5
# 491,23,Black,4
# 492,24,Black,4
# 493,25,Black,5
# 494,26,Black,4
# 495,27,Black,4
# 496,28,Black,4
# 497,29,Black,4
# 498,0,Black,4
# 499,0,Black,4
# 500,0,Black,4
# 501,0,Black,4
# 502,0,Black,4
# 503,0,Black,4
# 504,0,Black,4
# 505,0,Black,4
# 506,0,Black,4
# 507,0,Black,5
# 508,0,Black,4
# 509,0,Black,4
# 510,0,Black,4
# 511,0,Black,4
# 512,0,Black,4
# 513,0,Black,4
# 514,0,Black,4
# 515,0,Black,5
# 516,0,Black,4
# 517,0,Black,4
# 518,0,Black,4
# 519,0,Black,4
# 520,0,Black,4
# 521,0,Black,4
# 522,0,Black,4
# 523,0,Black,5
# 524,0,Black,4
# 525,0,Black,4
# 526,0,Black,4
# 527,1,White,5
# 528,2,White,848
# 529,3,White,858
# 530,4,White,854
# 531,5,White,849
# 532,6,White,854
# 533,7,White,855
# 534,8,White,855
# 535,9,White,848
# 536,10,White,847
# 537,11,White,852
# 538,12,White,860
# 539,13,White,852
# 540,14,White,843
# 541,15,White,857
# 542,16,White,851
# 543,17,White,850
# 544,18,White,854
# 545,19,White,853
# 546,20,White,852
# 547,21,White,854
# 548,22,White,851
# 549,23,White,850
# 550,24,White,853
# 551,25,White,852
# 552,26,White,852
# 553,27,White,855
# 554,28,White,850
# 555,29,White,859
# 556,1,Red,851
# 557,2,Red,320
# 558,3,Red,311
# 559,4,Red,320
# 560,5,Red,315
# 561,6,Red,315
# 562,7,Red,318
# 563,8,Red,314
# 564,9,Red,315
# 565,10,Red,319
# 566,11,Red,312
# 567,12,Red,315
# 568,13,Red,314
# 569,14,Red,316
# 570,15,Red,321
# 571,16,Red,314
# 572,17,Red,313
# 573,18,Red,313
# 574,19,Red,317
# 575,20,Red,317
# 576,21,Red,315
# 577,22,Red,316
# 578,23,Red,311
# 579,24,Red,316
# 580,25,Red,315
# 581,26,Red,313
# 582,27,Red,315
# 583,28,Red,317
# 584,29,Red,317
# 585,30,Red,316
# 586,1,Green,315
# 587,2,Green,351
# 588,3,Green,350
# 589,4,Green,356
# 590,5,Green,347
# 591,6,Green,350
# 592,7,Green,352
# 593,8,Green,357
# 594,9,Green,345
# 595,10,Green,346
# 596,11,Green,348
# 597,12,Green,350
# 598,13,Green,350
# 599,14,Green,350
# 600,15,Green,348
# 601,16,Green,351
# 602,17,Green,352
# 603,18,Green,350
# 604,19,Green,350
# 605,20,Green,353
# 606,21,Green,353
# 607,22,Green,348
# 608,23,Green,356
# 609,24,Green,348
# 610,25,Green,357
# 611,26,Green,351
# 612,27,Green,350
# 613,28,Green,352
# 614,29,Green,356
# 615,1,Blue,348
# 616,2,Blue,236
# 617,3,Blue,238
# 618,4,Blue,235
# 619,5,Blue,235
# 620,6,Blue,237
# 621,7,Blue,238
# 622,8,Blue,239
# 623,9,Blue,235
# 624,10,Blue,239
# 625,11,Blue,235
# 626,12,Blue,236
# 627,13,Blue,241
# 628,14,Blue,234
# 629,15,Blue,234
# 630,16,Blue,236
# 631,17,Blue,237
# 632,18,Blue,238
# 633,19,Blue,234
# 634,20,Blue,236
# 635,21,Blue,235
# 636,22,Blue,236
# 637,23,Blue,233
# 638,24,Blue,240
# 639,25,Blue,234
# 640,26,Blue,236
# 641,27,Blue,234
# 642,28,Blue,235
# 643,29,Blue,236
# 644,1,Black,237
# 645,2,Black,4
# 646,3,Black,5
# 647,4,Black,4
# 648,5,Black,4
# 649,6,Black,5
# 650,7,Black,4
# 651,8,Black,4
# 652,9,Black,4
# 653,10,Black,4
# 654,11,Black,4
# 655,12,Black,4
# 656,13,Black,4
# 657,14,Black,4
# 658,15,Black,4
# 659,16,Black,5
# 660,17,Black,4
# 661,18,Black,5
# 662,19,Black,4
# 663,20,Black,4
# 664,21,Black,4
# 665,22,Black,4
# 666,23,Black,4
# 667,24,Black,4
# 668,25,Black,4
# 669,26,Black,4
# 670,27,Black,4
# 671,28,Black,4
# 672,29,Black,5
# 673,0,Black,5
# 674,0,Black,4
# 675,0,Black,6
# 676,0,Black,4
# 677,0,Black,5
# 678,0,Black,4
# 679,0,Black,4
# 680,0,Black,4
#
# ==================================================
#
# ไฟล์: N_raw/N_100/N100_W.txt
# N_100_WaterPure water tube 5ml   No reagent :08/10/2023,22:17:56
# 1,1,White,5
# 2,2,White,947
# 3,3,White,950
# 4,4,White,952
# 5,5,White,947
# 6,6,White,952
# 7,7,White,952
# 8,8,White,951
# 9,9,White,947
# 10,10,White,942
# 11,11,White,949
# 12,12,White,954
# 13,13,White,955
# 14,14,White,950
# 15,15,White,945
# 16,16,White,950
# 17,17,White,950
# 18,18,White,954
# 19,19,White,954
# 20,20,White,955
# 21,21,White,952
# 22,22,White,953
# 23,23,White,948
# 24,24,White,952
# 25,25,White,949
# 26,26,White,949
# 27,27,White,951
# 28,28,White,952
# 29,29,White,948
# 30,1,Red,946
# 31,2,Red,337
# 32,3,Red,344
# 33,4,Red,348
# 34,5,Red,340
# 35,6,Red,344
# 36,7,Red,345
# 37,8,Red,335
# 38,9,Red,340
# 39,10,Red,339
# 40,11,Red,346
# 41,12,Red,337
# 42,13,Red,344
# 43,14,Red,335
# 44,15,Red,342
# 45,16,Red,340
# 46,17,Red,338
# 47,18,Red,347
# 48,19,Red,346
# 49,20,Red,346
# 50,21,Red,347
# 51,22,Red,344
# 52,23,Red,344
# 53,24,Red,342
# 54,25,Red,339
# 55,26,Red,347
# 56,27,Red,342
# 57,28,Red,347
# 58,29,Red,345
# 59,1,Green,348
# 60,2,Green,433
# 61,3,Green,431
# 62,4,Green,437
# 63,5,Green,426
# 64,6,Green,432
# 65,7,Green,437
# 66,8,Green,428
# 67,9,Green,435
# 68,10,Green,440
# 69,11,Green,434
# 70,12,Green,437
# 71,13,Green,434
# 72,14,Green,433
# 73,15,Green,432
# 74,16,Green,437
# 75,17,Green,434
# 76,18,Green,435
# 77,19,Green,439
# 78,20,Green,426
# 79,21,Green,431
# 80,22,Green,439
# 81,23,Green,435
# 82,24,Green,432
# 83,25,Green,439
# 84,26,Green,441
# 85,27,Green,433
# 86,28,Green,435
# 87,29,Green,439
# 88,30,Green,438
# 89,1,Blue,434
# 90,2,Blue,286
# 91,3,Blue,281
# 92,4,Blue,286
# 93,5,Blue,283
# 94,6,Blue,287
# 95,7,Blue,288
# 96,8,Blue,277
# 97,9,Blue,284
# 98,10,Blue,282
# 99,11,Blue,282
# 100,12,Blue,281
# 101,13,Blue,281
# 102,14,Blue,283
# 103,15,Blue,279
# 104,16,Blue,289
# 105,17,Blue,282
# 106,18,Blue,285
# 107,19,Blue,286
# 108,20,Blue,285
# 109,21,Blue,283
# 110,22,Blue,285
# 111,23,Blue,279
# 112,24,Blue,283
# 113,25,Blue,284
# 114,26,Blue,286
# 115,27,Blue,283
# 116,28,Blue,284
# 117,29,Blue,285
# 118,1,Black,280
# 119,2,Black,4
# 120,3,Black,4
# 121,4,Black,5
# 122,5,Black,5
# 123,6,Black,4
# 124,7,Black,4
# 125,8,Black,4
# 126,9,Black,4
# 127,10,Black,4
# 128,11,Black,4
# 129,12,Black,4
# 130,13,Black,4
# 131,14,Black,5
# 132,15,Black,4
# 133,16,Black,4
# 134,17,Black,5
# 135,18,Black,4
# 136,19,Black,4
# 137,20,Black,4
# 138,21,Black,4
# 139,22,Black,5
# 140,23,Black,4
# 141,24,Black,4
# 142,25,Black,4
# 143,26,Black,4
# 144,27,Black,4
# 145,28,Black,4
# 146,29,Black,4
# 147,0,Black,4
# 148,0,Black,4
# 149,0,Black,4
# 150,0,Black,5
# 151,0,Black,5
# 152,0,Black,4
# 153,0,Black,5
# 154,0,Black,4
# 155,0,Black,4
# 156,0,Black,5
# 157,0,Black,5
# 158,0,Black,4
# 159,0,Black,4
# 160,0,Black,5
# 161,0,Black,4
# 162,0,Black,4
# 163,0,Black,5
# 164,0,Black,5
# 165,0,Black,5
# 166,0,Black,5
# 167,0,Black,3
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black,4
# 171,0,Black,4
# 172,0,Black,4
# 173,0,Black,4
# 174,0,Black,5
# 175,0,Black,4
# 176,1,White,5
# 177,2,White,950
# 178,3,White,955
# 179,4,White,948
# 180,5,White,955
# 181,6,White,946
# 182,7,White,954
# 183,8,White,955
# 184,9,White,947
# 185,10,White,942
# 186,11,White,950
# 187,12,White,953
# 188,13,White,952
# 189,14,White,952
# 190,15,White,948
# 191,16,White,953
# 192,17,White,948
# 193,18,White,946
# 194,19,White,947
# 195,20,White,947
# 196,21,White,949
# 197,22,White,954
# 198,23,White,948
# 199,24,White,947
# 200,25,White,954
# 201,26,White,953
# 202,27,White,946
# 203,28,White,951
# 204,29,White,947
# 205,1,Red,947
# 206,2,Red,340
# 207,3,Red,338
# 208,4,Red,342
# 209,5,Red,342
# 210,6,Red,347
# 211,7,Red,347
# 212,8,Red,336
# 213,9,Red,348
# 214,10,Red,343
# 215,11,Red,340
# 216,12,Red,345
# 217,13,Red,340
# 218,14,Red,342
# 219,15,Red,345
# 220,16,Red,341
# 221,17,Red,343
# 222,18,Red,344
# 223,19,Red,342
# 224,20,Red,340
# 225,21,Red,341
# 226,22,Red,345
# 227,23,Red,342
# 228,24,Red,343
# 229,25,Red,343
# 230,26,Red,340
# 231,27,Red,345
# 232,28,Red,345
# 233,29,Red,344
# 234,30,Red,341
# 235,1,Green,345
# 236,2,Green,428
# 237,3,Green,434
# 238,4,Green,436
# 239,5,Green,432
# 240,6,Green,434
# 241,7,Green,437
# 242,8,Green,426
# 243,9,Green,437
# 244,10,Green,429
# 245,11,Green,436
# 246,12,Green,434
# 247,13,Green,432
# 248,14,Green,437
# 249,15,Green,433
# 250,16,Green,437
# 251,17,Green,434
# 252,18,Green,430
# 253,19,Green,441
# 254,20,Green,437
# 255,21,Green,434
# 256,22,Green,433
# 257,23,Green,439
# 258,24,Green,435
# 259,25,Green,431
# 260,26,Green,427
# 261,27,Green,441
# 262,28,Green,437
# 263,29,Green,431
# 264,1,Blue,438
# 265,2,Blue,286
# 266,3,Blue,283
# 267,4,Blue,284
# 268,5,Blue,281
# 269,6,Blue,281
# 270,7,Blue,283
# 271,8,Blue,285
# 272,9,Blue,283
# 273,10,Blue,287
# 274,11,Blue,286
# 275,12,Blue,288
# 276,13,Blue,287
# 277,14,Blue,289
# 278,15,Blue,285
# 279,16,Blue,290
# 280,17,Blue,283
# 281,18,Blue,288
# 282,19,Blue,285
# 283,20,Blue,285
# 284,21,Blue,287
# 285,22,Blue,283
# 286,23,Blue,285
# 287,24,Blue,286
# 288,25,Blue,282
# 289,26,Blue,288
# 290,27,Blue,280
# 291,28,Blue,284
# 292,29,Blue,283
# 293,1,Black,281
# 294,2,Black,4
# 295,3,Black,4
# 296,4,Black,4
# 297,5,Black,4
# 298,6,Black,5
# 299,7,Black,5
# 300,8,Black,5
# 301,9,Black,4
# 302,10,Black,4
# 303,11,Black,4
# 304,12,Black,4
# 305,13,Black,4
# 306,14,Black,4
# 307,15,Black,4
# 308,16,Black,4
# 309,17,Black,4
# 310,18,Black,4
# 311,19,Black,4
# 312,20,Black,4
# 313,21,Black,4
# 314,22,Black,4
# 315,23,Black,4
# 316,24,Black,4
# 317,25,Black,4
# 318,26,Black,4
# 319,27,Black,4
# 320,28,Black,4
# 321,29,Black,4
# 322,0,Black,5
# 323,0,Black,4
# 324,0,Black,5
# 325,0,Black,4
# 326,0,Black,5
# 327,0,Black,4
# 328,0,Black,4
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,4
# 332,0,Black,4
# 333,0,Black,4
# 334,0,Black,4
# 335,0,Black,5
# 336,0,Black,4
# 337,0,Black,4
# 338,0,Black,4
# 339,0,Black,5
# 340,0,Black,4
# 341,0,Black,4
# 342,0,Black,4
# 343,0,Black,4
# 344,0,Black,4
# 345,0,Black,4
# 346,0,Black,4
# 347,0,Black,5
# 348,0,Black,4
# 349,0,Black,4
# 350,0,Black,5
# 351,0,Black,4
# 352,1,White,5
# 353,2,White,948
# 354,3,White,949
# 355,4,White,949
# 356,5,White,953
# 357,6,White,949
# 358,7,White,953
# 359,8,White,955
# 360,9,White,954
# 361,10,White,952
# 362,11,White,946
# 363,12,White,948
# 364,13,White,943
# 365,14,White,948
# 366,15,White,946
# 367,16,White,948
# 368,17,White,949
# 369,18,White,953
# 370,19,White,950
# 371,20,White,948
# 372,21,White,955
# 373,22,White,949
# 374,23,White,946
# 375,24,White,948
# 376,25,White,953
# 377,26,White,954
# 378,27,White,953
# 379,28,White,951
# 380,29,White,951
# 381,1,Red,948
# 382,2,Red,338
# 383,3,Red,342
# 384,4,Red,343
# 385,5,Red,345
# 386,6,Red,340
# 387,7,Red,345
# 388,8,Red,343
# 389,9,Red,342
# 390,10,Red,340
# 391,11,Red,340
# 392,12,Red,342
# 393,13,Red,343
# 394,14,Red,342
# 395,15,Red,346
# 396,16,Red,342
# 397,17,Red,339
# 398,18,Red,340
# 399,19,Red,341
# 400,20,Red,339
# 401,21,Red,336
# 402,22,Red,341
# 403,23,Red,343
# 404,24,Red,345
# 405,25,Red,348
# 406,26,Red,344
# 407,27,Red,343
# 408,28,Red,345
# 409,29,Red,343
# 410,1,Green,342
# 411,2,Green,438
# 412,3,Green,438
# 413,4,Green,436
# 414,5,Green,439
# 415,6,Green,439
# 416,7,Green,435
# 417,8,Green,437
# 418,9,Green,433
# 419,10,Green,430
# 420,11,Green,437
# 421,12,Green,436
# 422,13,Green,438
# 423,14,Green,436
# 424,15,Green,439
# 425,16,Green,436
# 426,17,Green,437
# 427,18,Green,438
# 428,19,Green,435
# 429,20,Green,432
# 430,21,Green,435
# 431,22,Green,433
# 432,23,Green,434
# 433,24,Green,431
# 434,25,Green,434
# 435,26,Green,435
# 436,27,Green,433
# 437,28,Green,433
# 438,29,Green,435
# 439,1,Blue,434
# 440,2,Blue,282
# 441,3,Blue,281
# 442,4,Blue,286
# 443,5,Blue,281
# 444,6,Blue,282
# 445,7,Blue,282
# 446,8,Blue,285
# 447,9,Blue,279
# 448,10,Blue,286
# 449,11,Blue,284
# 450,12,Blue,284
# 451,13,Blue,289
# 452,14,Blue,281
# 453,15,Blue,285
# 454,16,Blue,281
# 455,17,Blue,280
# 456,18,Blue,289
# 457,19,Blue,288
# 458,20,Blue,283
# 459,21,Blue,283
# 460,22,Blue,284
# 461,23,Blue,283
# 462,24,Blue,285
# 463,25,Blue,284
# 464,26,Blue,287
# 465,27,Blue,282
# 466,28,Blue,281
# 467,29,Blue,287
# 468,30,Blue,279
# 469,1,Black,280
# 470,2,Black,5
# 471,3,Black,5
# 472,4,Black,4
# 473,5,Black,4
# 474,6,Black,4
# 475,7,Black,4
# 476,8,Black,4
# 477,9,Black,4
# 478,10,Black,5
# 479,11,Black,4
# 480,12,Black,4
# 481,13,Black,4
# 482,14,Black,5
# 483,15,Black,4
# 484,16,Black,4
# 485,17,Black,5
# 486,18,Black,4
# 487,19,Black,4
# 488,20,Black,4
# 489,21,Black,4
# 490,22,Black,4
# 491,23,Black,4
# 492,24,Black,4
# 493,25,Black,5
# 494,26,Black,4
# 495,27,Black,4
# 496,28,Black,4
# 497,29,Black,4
# 498,0,Black,4
# 499,0,Black,4
# 500,0,Black,5
# 501,0,Black,4
# 502,0,Black,4
# 503,0,Black,4
# 504,0,Black,4
# 505,0,Black,4
# 506,0,Black,3
# 507,0,Black,4
# 508,0,Black,4
# 509,0,Black,4
# 510,0,Black,5
# 511,0,Black,4
# 512,0,Black,4
# 513,0,Black,4
# 514,0,Black,5
# 515,0,Black,4
# 516,0,Black,4
# 517,0,Black,4
# 518,0,Black,4
# 519,0,Black,4
# 520,0,Black,4
# 521,0,Black,4
# 522,0,Black,5
# 523,0,Black,4
# 524,0,Black,4
# 525,0,Black,4
# 526,0,Black,4
# 527,1,White,4
# 528,2,White,949
# 529,3,White,948
# 530,4,White,948
# 531,5,White,945
# 532,6,White,948
# 533,7,White,948
# 534,8,White,948
# 535,9,White,948
# 536,10,White,944
# 537,11,White,951
# 538,12,White,954
# 539,13,White,952
# 540,14,White,947
# 541,15,White,949
# 542,16,White,948
# 543,17,White,948
# 544,18,White,949
# 545,19,White,947
# 546,20,White,947
# 547,21,White,951
# 548,22,White,948
# 549,23,White,950
# 550,24,White,950
# 551,25,White,947
# 552,26,White,947
# 553,27,White,947
# 554,28,White,955
# 555,29,White,942
# 556,1,Red,948
# 557,2,Red,341
# 558,3,Red,340
# 559,4,Red,341
# 560,5,Red,346
# 561,6,Red,340
# 562,7,Red,342
# 563,8,Red,342
# 564,9,Red,342
# 565,10,Red,341
# 566,11,Red,340
# 567,12,Red,344
# 568,13,Red,345
# 569,14,Red,340
# 570,15,Red,338
# 571,16,Red,347
# 572,17,Red,340
# 573,18,Red,346
# 574,19,Red,342
# 575,20,Red,342
# 576,21,Red,342
# 577,22,Red,337
# 578,23,Red,341
# 579,24,Red,344
# 580,25,Red,340
# 581,26,Red,347
# 582,27,Red,338
# 583,28,Red,347
# 584,29,Red,338
# 585,30,Red,347
# 586,1,Green,345
# 587,2,Green,429
# 588,3,Green,432
# 589,4,Green,432
# 590,5,Green,440
# 591,6,Green,431
# 592,7,Green,434
# 593,8,Green,432
# 594,9,Green,438
# 595,10,Green,439
# 596,11,Green,439
# 597,12,Green,435
# 598,13,Green,436
# 599,14,Green,429
# 600,15,Green,428
# 601,16,Green,436
# 602,17,Green,428
# 603,18,Green,436
# 604,19,Green,437
# 605,20,Green,437
# 606,21,Green,435
# 607,22,Green,440
# 608,23,Green,435
# 609,24,Green,434
# 610,25,Green,434
# 611,26,Green,432
# 612,27,Green,436
# 613,28,Green,430
# 614,29,Green,440
# 615,1,Blue,434
# 616,2,Blue,287
# 617,3,Blue,286
# 618,4,Blue,285
# 619,5,Blue,287
# 620,6,Blue,285
# 621,7,Blue,288
# 622,8,Blue,283
# 623,9,Blue,287
# 624,10,Blue,283
# 625,11,Blue,284
# 626,12,Blue,288
# 627,13,Blue,290
# 628,14,Blue,289
# 629,15,Blue,286
# 630,16,Blue,289
# 631,17,Blue,283
# 632,18,Blue,282
# 633,19,Blue,283
# 634,20,Blue,282
# 635,21,Blue,282
# 636,22,Blue,282
# 637,23,Blue,284
# 638,24,Blue,284
# 639,25,Blue,283
# 640,26,Blue,283
# 641,27,Blue,291
# 642,28,Blue,286
# 643,29,Blue,290
# 644,1,Black,282
# 645,2,Black,4
# 646,3,Black,3
# 647,4,Black,5
# 648,5,Black,4
# 649,6,Black,4
# 650,7,Black,4
# 651,8,Black,5
# 652,9,Black,3
# 653,10,Black,4
# 654,11,Black,4
# 655,12,Black,4
# 656,13,Black,4
# 657,14,Black,5
# 658,15,Black,4
# 659,16,Black,4
# 660,17,Black,4
# 661,18,Black,4
# 662,19,Black,4
# 663,20,Black,4
# 664,21,Black,4
# 665,22,Black,4
# 666,23,Black,5
# 667,24,Black,4
# 668,25,Black,4
# 669,26,Black,4
# 670,27,Black,4
# 671,28,Black,5
# 672,29,Black,4
# 673,0,Black,5
# 674,0,Black,5
# 675,0,Black,4
# 676,0,Black,5
# 677,0,Black,5
# 678,0,Black,5
# 679,0,Black,5
# 680,0,Black,4
#
# ==================================================
#
# ไฟล์: N_raw/N_100/N100_A.txt
# N_100_ANH4CL 100mg/L tube  5ml  Reagent 500ul :08/10/2023,23:21:08
# 1,1,White,4
# 2,2,White,31
# 3,3,White,33
# 4,4,White,32
# 5,5,White,31
# 6,6,White,32
# 7,7,White,33
# 8,8,White,34
# 9,9,White,33
# 10,10,White,32
# 11,11,White,32
# 12,12,White,33
# 13,13,White,32
# 14,14,White,33
# 15,15,White,33
# 16,16,White,35
# 17,17,White,34
# 18,18,White,31
# 19,19,White,31
# 20,20,White,32
# 21,21,White,33
# 22,22,White,34
# 23,23,White,32
# 24,24,White,31
# 25,25,White,31
# 26,26,White,33
# 27,27,White,31
# 28,28,White,35
# 29,29,White,30
# 30,1,Red,32
# 31,2,Red,17
# 32,3,Red,19
# 33,4,Red,16
# 34,5,Red,18
# 35,6,Red,17
# 36,7,Red,17
# 37,8,Red,18
# 38,9,Red,18
# 39,10,Red,18
# 40,11,Red,16
# 41,12,Red,16
# 42,13,Red,17
# 43,14,Red,15
# 44,15,Red,17
# 45,16,Red,17
# 46,17,Red,18
# 47,18,Red,15
# 48,19,Red,16
# 49,20,Red,17
# 50,21,Red,15
# 51,22,Red,16
# 52,23,Red,18
# 53,24,Red,15
# 54,25,Red,18
# 55,26,Red,15
# 56,27,Red,16
# 57,28,Red,15
# 58,29,Red,16
# 59,1,Green,18
# 60,2,Green,14
# 61,3,Green,12
# 62,4,Green,13
# 63,5,Green,15
# 64,6,Green,13
# 65,7,Green,13
# 66,8,Green,13
# 67,9,Green,13
# 68,10,Green,13
# 69,11,Green,13
# 70,12,Green,13
# 71,13,Green,13
# 72,14,Green,13
# 73,15,Green,14
# 74,16,Green,14
# 75,17,Green,15
# 76,18,Green,13
# 77,19,Green,13
# 78,20,Green,13
# 79,21,Green,15
# 80,22,Green,13
# 81,23,Green,14
# 82,24,Green,14
# 83,25,Green,13
# 84,26,Green,14
# 85,27,Green,13
# 86,28,Green,13
# 87,29,Green,13
# 88,30,Green,13
# 89,1,Blue,14
# 90,2,Blue,11
# 91,3,Blue,10
# 92,4,Blue,10
# 93,5,Blue,10
# 94,6,Blue,10
# 95,7,Blue,10
# 96,8,Blue,11
# 97,9,Blue,10
# 98,10,Blue,10
# 99,11,Blue,11
# 100,12,Blue,9
# 101,13,Blue,10
# 102,14,Blue,10
# 103,15,Blue,9
# 104,16,Blue,10
# 105,17,Blue,10
# 106,18,Blue,11
# 107,19,Blue,9
# 108,20,Blue,9
# 109,21,Blue,11
# 110,22,Blue,11
# 111,23,Blue,10
# 112,24,Blue,10
# 113,25,Blue,11
# 114,26,Blue,9
# 115,27,Blue,11
# 116,28,Blue,10
# 117,29,Blue,10
# 118,1,Black,10
# 119,2,Black,4
# 120,3,Black,4
# 121,4,Black,4
# 122,5,Black,4
# 123,6,Black,4
# 124,7,Black,4
# 125,8,Black,4
# 126,9,Black,4
# 127,10,Black,4
# 128,11,Black,3
# 129,12,Black,4
# 130,13,Black,4
# 131,14,Black,4
# 132,15,Black,4
# 133,16,Black,4
# 134,17,Black,4
# 135,18,Black,4
# 136,19,Black,3
# 137,20,Black,4
# 138,21,Black,4
# 139,22,Black,4
# 140,23,Black,4
# 141,24,Black,4
# 142,25,Black,4
# 143,26,Black,4
# 144,27,Black,3
# 145,28,Black,3
# 146,29,Black,4
# 147,0,Black,4
# 148,0,Black,4
# 149,0,Black,4
# 150,0,Black,4
# 151,0,Black,4
# 152,0,Black,3
# 153,0,Black,4
# 154,0,Black,5
# 155,0,Black,4
# 156,0,Black,5
# 157,0,Black,4
# 158,0,Black,4
# 159,0,Black,4
# 160,0,Black,4
# 161,0,Black,5
# 162,0,Black,4
# 163,0,Black,5
# 164,0,Black,4
# 165,0,Black,4
# 166,0,Black,4
# 167,0,Black,4
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black,4
# 171,0,Black,5
# 172,0,Black,4
# 173,0,Black,4
# 174,0,Black,4
# 175,0,Black,4
# 176,1,White,4
# 177,2,White,30
# 178,3,White,29
# 179,4,White,33
# 180,5,White,31
# 181,6,White,32
# 182,7,White,34
# 183,8,White,30
# 184,9,White,34
# 185,10,White,32
# 186,11,White,29
# 187,12,White,32
# 188,13,White,30
# 189,14,White,32
# 190,15,White,33
# 191,16,White,32
# 192,17,White,31
# 193,18,White,30
# 194,19,White,33
# 195,20,White,31
# 196,21,White,33
# 197,22,White,29
# 198,23,White,35
# 199,24,White,32
# 200,25,White,33
# 201,26,White,33
# 202,27,White,33
# 203,28,White,32
# 204,29,White,33
# 205,30,White,33
# 206,1,Red,32
# 207,2,Red,18
# 208,3,Red,17
# 209,4,Red,20
# 210,5,Red,19
# 211,6,Red,20
# 212,7,Red,20
# 213,8,Red,18
# 214,9,Red,20
# 215,10,Red,19
# 216,11,Red,21
# 217,12,Red,18
# 218,13,Red,22
# 219,14,Red,20
# 220,15,Red,22
# 221,16,Red,20
# 222,17,Red,22
# 223,18,Red,19
# 224,19,Red,21
# 225,20,Red,19
# 226,21,Red,23
# 227,22,Red,19
# 228,23,Red,22
# 229,24,Red,20
# 230,25,Red,21
# 231,26,Red,20
# 232,27,Red,19
# 233,28,Red,21
# 234,29,Red,20
# 235,1,Green,24
# 236,2,Green,13
# 237,3,Green,12
# 238,4,Green,13
# 239,5,Green,13
# 240,6,Green,13
# 241,7,Green,13
# 242,8,Green,13
# 243,9,Green,12
# 244,10,Green,13
# 245,11,Green,15
# 246,12,Green,15
# 247,13,Green,13
# 248,14,Green,14
# 249,15,Green,15
# 250,16,Green,13
# 251,17,Green,13
# 252,18,Green,16
# 253,19,Green,14
# 254,20,Green,14
# 255,21,Green,15
# 256,22,Green,13
# 257,23,Green,15
# 258,24,Green,13
# 259,25,Green,15
# 260,26,Green,13
# 261,27,Green,15
# 262,28,Green,13
# 263,29,Green,13
# 264,1,Blue,13
# 265,2,Blue,11
# 266,3,Blue,10
# 267,4,Blue,11
# 268,5,Blue,9
# 269,6,Blue,11
# 270,7,Blue,11
# 271,8,Blue,10
# 272,9,Blue,9
# 273,10,Blue,11
# 274,11,Blue,9
# 275,12,Blue,9
# 276,13,Blue,11
# 277,14,Blue,9
# 278,15,Blue,9
# 279,16,Blue,11
# 280,17,Blue,11
# 281,18,Blue,11
# 282,19,Blue,10
# 283,20,Blue,10
# 284,21,Blue,12
# 285,22,Blue,11
# 286,23,Blue,11
# 287,24,Blue,10
# 288,25,Blue,10
# 289,26,Blue,12
# 290,27,Blue,11
# 291,28,Blue,11
# 292,29,Blue,10
# 293,1,Black,10
# 294,2,Black,4
# 295,3,Black,5
# 296,4,Black,3
# 297,5,Black,4
# 298,6,Black,3
# 299,7,Black,4
# 300,8,Black,4
# 301,9,Black,3
# 302,10,Black,4
# 303,11,Black,4
# 304,12,Black,4
# 305,13,Black,4
# 306,14,Black,4
# 307,15,Black,4
# 308,16,Black,4
# 309,17,Black,4
# 310,18,Black,4
# 311,19,Black,4
# 312,20,Black,4
# 313,21,Black,5
# 314,22,Black,4
# 315,23,Black,5
# 316,24,Black,3
# 317,25,Black,4
# 318,26,Black,4
# 319,27,Black,5
# 320,28,Black,5
# 321,29,Black,4
# 322,30,Black,3
# 323,0,Black,4
# 324,0,Black,4
# 325,0,Black,4
# 326,0,Black,3
# 327,0,Black,4
# 328,0,Black,4
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,4
# 332,0,Black,4
# 333,0,Black,4
# 334,0,Black,4
# 335,0,Black,4
# 336,0,Black,4
# 337,0,Black,4
# 338,0,Black,4
# 339,0,Black,4
# 340,0,Black,4
# 341,0,Black,5
# 342,0,Black,5
# 343,0,Black,5
# 344,0,Black,4
# 345,0,Black,3
# 346,0,Black,5
# 347,0,Black,4
# 348,0,Black,4
# 349,0,Black,4
# 350,0,Black,4
# 351,0,Black,4
# 352,1,White,4
# 353,2,White,43
# 354,3,White,42
# 355,4,White,43
# 356,5,White,45
# 357,6,White,43
# 358,7,White,44
# 359,8,White,44
# 360,9,White,44
# 361,10,White,43
# 362,11,White,44
# 363,12,White,45
# 364,13,White,43
# 365,14,White,41
# 366,15,White,43
# 367,16,White,44
# 368,17,White,45
# 369,18,White,41
# 370,19,White,44
# 371,20,White,43
# 372,21,White,47
# 373,22,White,43
# 374,23,White,47
# 375,24,White,43
# 376,25,White,44
# 377,26,White,44
# 378,27,White,45
# 379,28,White,42
# 380,29,White,44
# 381,1,Red,43
# 382,2,Red,28
# 383,3,Red,30
# 384,4,Red,30
# 385,5,Red,30
# 386,6,Red,29
# 387,7,Red,27
# 388,8,Red,29
# 389,9,Red,30
# 390,10,Red,29
# 391,11,Red,28
# 392,12,Red,31
# 393,13,Red,27
# 394,14,Red,30
# 395,15,Red,28
# 396,16,Red,29
# 397,17,Red,26
# 398,18,Red,27
# 399,19,Red,29
# 400,20,Red,31
# 401,21,Red,26
# 402,22,Red,28
# 403,23,Red,29
# 404,24,Red,30
# 405,25,Red,29
# 406,26,Red,30
# 407,27,Red,31
# 408,28,Red,26
# 409,29,Red,31
# 410,1,Green,29
# 411,2,Green,15
# 412,3,Green,14
# 413,4,Green,13
# 414,5,Green,13
# 415,6,Green,15
# 416,7,Green,16
# 417,8,Green,15
# 418,9,Green,16
# 419,10,Green,15
# 420,11,Green,14
# 421,12,Green,14
# 422,13,Green,13
# 423,14,Green,15
# 424,15,Green,13
# 425,16,Green,14
# 426,17,Green,13
# 427,18,Green,13
# 428,19,Green,14
# 429,20,Green,13
# 430,21,Green,16
# 431,22,Green,16
# 432,23,Green,14
# 433,24,Green,13
# 434,25,Green,13
# 435,26,Green,13
# 436,27,Green,14
# 437,28,Green,16
# 438,29,Green,14
# 439,30,Green,14
# 440,1,Blue,15
# 441,2,Blue,10
# 442,3,Blue,11
# 443,4,Blue,10
# 444,5,Blue,9
# 445,6,Blue,11
# 446,7,Blue,10
# 447,8,Blue,9
# 448,9,Blue,10
# 449,10,Blue,11
# 450,11,Blue,10
# 451,12,Blue,10
# 452,13,Blue,10
# 453,14,Blue,10
# 454,15,Blue,10
# 455,16,Blue,11
# 456,17,Blue,11
# 457,18,Blue,12
# 458,19,Blue,11
# 459,20,Blue,10
# 460,21,Blue,10
# 461,22,Blue,10
# 462,23,Blue,11
# 463,24,Blue,10
# 464,25,Blue,11
# ...
# 324,29,Black,4
# 325,0,Black,5
# 326,0,Black,4
# 327,0,Black,5
# 328,0,Black,4
# 329,0,Black,4
# 330,0,Black,4
# 331,0,Black,4
# 332,0,Black,4
# 333,0,Black,5
# 334,0,Black,5
# 335,0,Black,4
# 336,0,Black,4
# 337,0,Black,4
# 338,0,Black,4
# 339,0,Black,3
# 340,0,Black,4
# 341,0,Black,4
# 342,0,Black,5
# 343,0,Black,4
# 344,0,Black,4
# 345,0,Black,5
# 346,0,Black,5
# 347,0,Black,5
# 348,0,Black,4
# 349,0,Black,4
# 350,0,Black,4
# 351,0,Black,4
# 352,0,Black,4
# 353,0,Black,4
# 354,0,Black,4
# 355,1,White,4
# 356,2,White,943
# 357,3,White,944
# 358,4,White,944
# 359,5,White,945
# 360,6,White,945
# 361,7,White,951
# 362,8,White,947
# 363,9,White,945
# 364,10,White,945
# 365,11,White,946
# 366,12,White,950
# 367,13,White,947
# 368,14,White,951
# 369,15,White,946
# 370,16,White,951
# 371,17,White,950
# 372,18,White,953
# 373,19,White,949
# 374,20,White,946
# 375,21,White,945
# 376,22,White,946
# 377,23,White,949
# 378,24,White,950
# 379,25,White,946
# 380,26,White,946
# 381,27,White,953
# 382,28,White,947
# 383,29,White,953
# 384,30,White,950
# 385,1,Red,952
# 386,2,Red,337
# 387,3,Red,339
# 388,4,Red,336
# 389,5,Red,341
# 390,6,Red,342
# 391,7,Red,339
# 392,8,Red,339
# 393,9,Red,333
# 394,10,Red,343
# 395,11,Red,336
# 396,12,Red,339
# 397,13,Red,331
# 398,14,Red,332
# 399,15,Red,340
# 400,16,Red,338
# 401,17,Red,335
# 402,18,Red,340
# 403,19,Red,339
# 404,20,Red,339
# 405,21,Red,343
# 406,22,Red,337
# 407,23,Red,337
# 408,24,Red,339
# 409,25,Red,338
# 410,26,Red,336
# 411,27,Red,337
# 412,28,Red,341
# 413,29,Red,344
# 414,1,Green,337
# 415,2,Green,412
# 416,3,Green,419
# 417,4,Green,413
# 418,5,Green,418
# 419,6,Green,420
# 420,7,Green,419
# 421,8,Green,411
# 422,9,Green,414
# 423,10,Green,412
# 424,11,Green,416
# 425,12,Green,416
# 426,13,Green,413
# 427,14,Green,419
# 428,15,Green,414
# 429,16,Green,416
# 430,17,Green,415
# 431,18,Green,410
# 432,19,Green,414
# 433,20,Green,416
# 434,21,Green,414
# 435,22,Green,417
# 436,23,Green,415
# 437,24,Green,413
# 438,25,Green,411
# 439,26,Green,417
# 440,27,Green,420
# 441,28,Green,420
# 442,29,Green,407
# 443,30,Green,413
# 444,1,Blue,407
# 445,2,Blue,296
# 446,3,Blue,296
# 447,4,Blue,303
# 448,5,Blue,298
# 449,6,Blue,299
# 450,7,Blue,302
# 451,8,Blue,298
# 452,9,Blue,297
# 453,10,Blue,297
# 454,11,Blue,300
# 455,12,Blue,301
# 456,13,Blue,301
# 457,14,Blue,298
# 458,15,Blue,295
# 459,16,Blue,298
# 460,17,Blue,294
# 461,18,Blue,298
# 462,19,Blue,294
# 463,20,Blue,300
# 464,21,Blue,297
# 465,22,Blue,299
# 466,23,Blue,303
# 467,24,Blue,295
# 468,25,Blue,303
# 469,26,Blue,301
# 470,27,Blue,299
# 471,28,Blue,293
# 472,29,Blue,298
# 473,1,Black,297
# 474,2,Black,4
# 475,3,Black,4
# 476,4,Black,5
# 477,5,Black,5
# 478,6,Black,4
# 479,7,Black,3
# 480,8,Black,4
# 481,9,Black,4
# 482,10,Black,4
# 483,11,Black,4
# 484,12,Black,4
# 485,13,Black,3
# 486,14,Black,4
# 487,15,Black,4
# 488,16,Black,4
# 489,17,Black,4
# 490,18,Black,3
# 491,19,Black,4
# 492,20,Black,4
# 493,21,Black,4
# 494,22,Black,4
# 495,23,Black,4
# 496,24,Black,4
# 497,25,Black,4
# 498,26,Black,4
# 499,27,Black,4
# 500,28,Black,4
# 501,29,Black,4
# 502,30,Black,4
# 503,0,Black,4
# 504,0,Black,4
# 505,0,Black,4
# 506,0,Black,3
# 507,0,Black,4
# 508,0,Black,5
# 509,0,Black,4
# 510,0,Black,4
# 511,0,Black,4
# 512,0,Black,4
# 513,0,Black,4
# 514,0,Black,5
# 515,0,Black,4
# 516,0,Black,4
# 517,0,Black,3
# 518,0,Black,4
# 519,0,Black,5
# 520,0,Black,4
# 521,0,Black,4
# 522,0,Black,4
# 523,0,Black,4
# 524,0,Black,4
# 525,0,Black,4
# 526,0,Black,4
# 527,0,Black,4
# 528,0,Black,4
# 529,0,Black,5
# 530,0,Black,4
# 531,0,Black,4
# 532,1,White,4
# 533,2,White,945
# 534,3,White,950
# 535,4,White,949
# 536,5,White,945
# 537,6,White,951
# 538,7,White,950
# 539,8,White,943
# 540,9,White,951
# 541,10,White,948
# 542,11,White,951
# 543,12,White,951
# 544,13,White,953
# 545,14,White,949
# 546,15,White,952
# 547,16,White,947
# 548,17,White,949
# 549,18,White,952
# 550,19,White,948
# 551,20,White,948
# 552,21,White,948
# 553,22,White,946
# 554,23,White,949
# 555,24,White,948
# 556,25,White,947
# 557,26,White,953
# 558,27,White,948
# 559,28,White,951
# 560,29,White,950
# 561,30,White,953
# 562,1,Red,947
# 563,2,Red,341
# 564,3,Red,336
# 565,4,Red,331
# 566,5,Red,341
# 567,6,Red,339
# 568,7,Red,342
# 569,8,Red,339
# 570,9,Red,339
# 571,10,Red,339
# 572,11,Red,334
# 573,12,Red,333
# 574,13,Red,340
# 575,14,Red,339
# 576,15,Red,340
# 577,16,Red,337
# 578,17,Red,332
# 579,18,Red,341
# 580,19,Red,338
# 581,20,Red,343
# 582,21,Red,336
# 583,22,Red,342
# 584,23,Red,338
# 585,24,Red,336
# 586,25,Red,336
# 587,26,Red,334
# 588,27,Red,336
# 589,28,Red,338
# 590,29,Red,342
# 591,1,Green,332
# 592,2,Green,418
# 593,3,Green,421
# 594,4,Green,411
# 595,5,Green,418
# 596,6,Green,410
# 597,7,Green,412
# 598,8,Green,411
# 599,9,Green,418
# 600,10,Green,415
# 601,11,Green,406
# 602,12,Green,412
# 603,13,Green,411
# 604,14,Green,410
# 605,15,Green,411
# 606,16,Green,408
# 607,17,Green,408
# 608,18,Green,407
# 609,19,Green,414
# 610,20,Green,413
# 611,21,Green,418
# 612,22,Green,415
# 613,23,Green,416
# 614,24,Green,416
# 615,25,Green,412
# 616,26,Green,419
# 617,27,Green,414
# 618,28,Green,411
# 619,29,Green,413
# 620,30,Green,411
# 621,1,Blue,413
# 622,2,Blue,295
# 623,3,Blue,297
# 624,4,Blue,295
# 625,5,Blue,296
# 626,6,Blue,297
# 627,7,Blue,300
# 628,8,Blue,303
# 629,9,Blue,302
# 630,10,Blue,302
# 631,11,Blue,297
# 632,12,Blue,301
# 633,13,Blue,296
# 634,14,Blue,297
# 635,15,Blue,299
# 636,16,Blue,296
# 637,17,Blue,296
# 638,18,Blue,303
# 639,19,Blue,295
# 640,20,Blue,296
# 641,21,Blue,300
# 642,22,Blue,296
# 643,23,Blue,299
# 644,24,Blue,297
# 645,25,Blue,297
# 646,26,Blue,303
# 647,27,Blue,301
# 648,28,Blue,299
# 649,29,Blue,296
# 650,1,Black,300
# 651,2,Black,5
# 652,3,Black,4
# 653,4,Black,4
# 654,5,Black,3
# 655,6,Black,3
# 656,7,Black,4
# 657,8,Black,4
# 658,9,Black,5
# 659,10,Black,4
# 660,11,Black,4
# 661,12,Black,4
# 662,13,Black,4
# 663,14,Black,4
# 664,15,Black,4
# 665,16,Black,5
# 666,17,Black,4
# 667,18,Black,4
# 668,19,Black,3
# 669,20,Black,3
# 670,21,Black,4
# 671,22,Black,4
# 672,23,Black,4
# 673,24,Black,5
# 674,25,Black,4
# 675,26,Black,5
# 676,27,Black,3
# 677,28,Black,4
# 678,29,Black,4
# 679,30,Black,5
# 680,0,Black,3
#
# ==================================================
#
# ไฟล์: N_raw/N_6/N6_B.txt
# N_6_ANH4CL 6mg/L tube  5ml  Reagent 500ul :08/10/2023,19:06:14
# 1,1,White,5
# 2,2,White,482
# 3,3,White,481
# 4,4,White,478
# 5,5,White,480
# 6,6,White,486
# 7,7,White,490
# 8,8,White,482
# 9,9,White,481
# 10,10,White,480
# 11,11,White,484
# 12,12,White,486
# 13,13,White,488
# 14,14,White,489
# 15,15,White,486
# 16,16,White,481
# 17,17,White,480
# 18,18,White,482
# 19,19,White,485
# 20,20,White,482
# 21,21,White,485
# 22,22,White,481
# 23,23,White,484
# 24,24,White,488
# 25,25,White,476
# 26,26,White,478
# 27,27,White,485
# 28,28,White,481
# 29,29,White,485
# 30,1,Red,479
# 31,2,Red,266
# 32,3,Red,270
# 33,4,Red,267
# 34,5,Red,266
# 35,6,Red,268
# 36,7,Red,268
# 37,8,Red,265
# 38,9,Red,271
# 39,10,Red,269
# 40,11,Red,266
# 41,12,Red,266
# 42,13,Red,265
# 43,14,Red,268
# 44,15,Red,267
# 45,16,Red,269
# 46,17,Red,267
# 47,18,Red,268
# 48,19,Red,266
# 49,20,Red,269
# 50,21,Red,268
# 51,22,Red,267
# 52,23,Red,273
# 53,24,Red,266
# 54,25,Red,269
# 55,26,Red,272
# 56,27,Red,272
# 57,28,Red,268
# 58,29,Red,270
# 59,1,Green,269
# 60,2,Green,177
# 61,3,Green,180
# 62,4,Green,175
# 63,5,Green,181
# 64,6,Green,177
# 65,7,Green,175
# 66,8,Green,181
# 67,9,Green,176
# 68,10,Green,179
# 69,11,Green,174
# 70,12,Green,180
# 71,13,Green,181
# 72,14,Green,178
# 73,15,Green,182
# 74,16,Green,178
# 75,17,Green,177
# 76,18,Green,180
# 77,19,Green,179
# 78,20,Green,179
# 79,21,Green,177
# 80,22,Green,176
# 81,23,Green,182
# 82,24,Green,178
# 83,25,Green,176
# 84,26,Green,179
# 85,27,Green,181
# 86,28,Green,174
# 87,29,Green,179
# 88,30,Green,175
# 89,1,Blue,179
# 90,2,Blue,55
# 91,3,Blue,55
# 92,4,Blue,53
# 93,5,Blue,58
# 94,6,Blue,56
# 95,7,Blue,53
# 96,8,Blue,58
# 97,9,Blue,55
# 98,10,Blue,53
# 99,11,Blue,53
# 100,12,Blue,56
# 101,13,Blue,54
# 102,14,Blue,58
# 103,15,Blue,55
# 104,16,Blue,53
# 105,17,Blue,58
# 106,18,Blue,52
# 107,19,Blue,56
# 108,20,Blue,54
# 109,21,Blue,54
# 110,22,Blue,54
# 111,23,Blue,58
# 112,24,Blue,54
# 113,25,Blue,57
# 114,26,Blue,58
# 115,27,Blue,57
# 116,28,Blue,58
# 117,29,Blue,53
# 118,1,Black,52
# 119,2,Black,4
# 120,3,Black,4
# 121,4,Black,5
# 122,5,Black,4
# 123,6,Black,5
# 124,7,Black,4
# 125,8,Black,4
# 126,9,Black,5
# 127,10,Black,5
# 128,11,Black,5
# 129,12,Black,4
# 130,13,Black,4
# 131,14,Black,4
# 132,15,Black,5
# 133,16,Black,4
# 134,17,Black,4
# 135,18,Black,4
# 136,19,Black,4
# 137,20,Black,5
# 138,21,Black,5
# 139,22,Black,5
# 140,23,Black,4
# 141,24,Black,5
# 142,25,Black,4
# 143,26,Black,4
# 144,27,Black,5
# 145,28,Black,4
# 146,29,Black,5
# 147,0,Black,4
# 148,0,Black,4
# 149,0,Black,4
# 150,0,Black,4
# 151,0,Black,4
# 152,0,Black,4
# 153,0,Black,5
# 154,0,Black,5
# 155,0,Black,4
# 156,0,Black,4
# 157,0,Black,5
# 158,0,Black,5
# 159,0,Black,4
# 160,0,Black,4
# 161,0,Black,4
# 162,0,Black,5
# 163,0,Black,4
# 164,0,Black,5
# 165,0,Black,4
# 166,0,Black,4
# 167,0,Black,5
# 168,0,Black,4
# 169,0,Black,4
# 170,0,Black,4
# 171,0,Black,5
# 172,0,Black,5
# 173,0,Black,4
# 174,0,Black,4
# 175,0,Black,4
# 176,1,White,4
# 177,2,White,480
# 178,3,White,489
# 179,4,White,484
# 180,5,White,487
# 181,6,White,489
# 182,7,White,480
# 183,8,White,483
# 184,9,White,488
# 185,10,White,484
# 186,11,White,483
# 187,12,White,483
# 188,13,White,482
# 189,14,White,484
# 190,15,White,476
# 191,16,White,487
# 192,17,White,482
# 193,18,White,483
# 194,19,White,484
# 195,20,White,483
# 196,21,White,477
# 197,22,White,487
# 198,23,White,485
# 199,24,White,483
# 200,25,White,483
# 201,26,White,483
# 202,27,White,485
# 203,28,White,477
# 204,29,White,489
# 205,30,White,486
# 206,1,Red,485
# 207,2,Red,268
# 208,3,Red,269
# 209,4,Red,269
# 210,5,Red,269
# 211,6,Red,267
# 212,7,Red,274
# 213,8,Red,269
# 214,9,Red,266
# 215,10,Red,267
# 216,11,Red,267
# 217,12,Red,267
# 218,13,Red,274
# 219,14,Red,270
# 220,15,Red,270
# 221,16,Red,269
# 222,17,Red,270
# 223,18,Red,266
# 224,19,Red,271
# 225,20,Red,270
# 226,21,Red,267
# 227,22,Red,267
# 228,23,Red,267
# 229,24,Red,266
# 230,25,Red,272
# 231,26,Red,268
# 232,27,Red,266
# 233,28,Red,267
# 234,29,Red,272
# 235,1,Green,270
# 236,2,Green,179
# 237,3,Green,183
# 238,4,Green,178
# 239,5,Green,182
# 240,6,Green,182
# 241,7,Green,180
# 242,8,Green,180
# 243,9,Green,181
# 244,10,Green,177
# 245,11,Green,181
# 246,12,Green,175
# 247,13,Green,182
# 248,14,Green,177
# 249,15,Green,183
# 250,16,Green,175
# 251,17,Green,182
# 252,18,Green,183
# 253,19,Green,179
# 254,20,Green,176
# 255,21,Green,175
# 256,22,Green,179
# 257,23,Green,178
# 258,24,Green,179
# 259,25,Green,179
# 260,26,Green,175
# 261,27,Green,181
# 262,28,Green,181
# 263,29,Green,176
# 264,1,Blue,178
# 265,2,Blue,54
# 266,3,Blue,53
# 267,4,Blue,56
# 268,5,Blue,55
# 269,6,Blue,57
# 270,7,Blue,57
# 271,8,Blue,56
# 272,9,Blue,52
# 273,10,Blue,58
# 274,11,Blue,53
# 275,12,Blue,53
# 276,13,Blue,54
# 277,14,Blue,53
# 278,15,Blue,54
# 279,16,Blue,55
# 280,17,Blue,56
# 281,18,Blue,51
# 282,19,Blue,56
# 283,20,Blue,56
# 284,21,Blue,53
# 285,22,Blue,57
# 286,23,Blue,54
# 287,24,Blue,56
# 288,25,Blue,54
# 289,26,Blue,57
# 290,27,Blue,55
# 291,28,Blue,53
# 292,29,Blue,56
# 293,1,Black,59
# 294,2,Black,4
# 295,3,Black,4
# 296,4,Black,5
# 297,5,Black,4
# 298,6,Black,4
# 299,7,Black,4
# 300,8,Black,4
# 301,9,Black,5
# 302,10,Black,4
# 303,11,Black,4
# 304,12,Black,3
# 305,13,Black,4
# 306,14,Black,4
# 307,15,Black,5
# 308,16,Black,4
# 309,17,Black,4
# 310,18,Black,4
# 311,19,Black,4
# 312,20,Black,4
# 313,21,Black,4
# 314,22,Black,4
# 315,23,Black,5
# 316,24,Black,3
# 317,25,Black,5
# 318,26,Black,4
# 319,27,Black,4
# 320,28,Black,4
# 321,29,Black,5
# 322,30,Black,4
# 323,0,Black,5
# 324,0,Black,4
# 325,0,Black,4
# 326,0,Black,5
# 327,0,Black,4
# 328,0,Black,4
# 329,0,Black,4
# 330,0,Black,5
# 331,0,Black,4
# 332,0,Black,5
# 333,0,Black,5
# 334,0,Black,4
# 335,0,Black,4
# 336,0,Black,6
# 337,0,Black,4
# 338,0,Black,5
# 339,0,Black,4
# 340,0,Black,4
# 341,0,Black,4
# 342,0,Black,5
# 343,0,Black,5
# 344,0,Black,5
# 345,0,Black,4
# 346,0,Black,4
# 347,0,Black,4
# 348,0,Black,5
# 349,0,Black,4
# 350,0,Black,5
# 351,0,Black,4
# 352,1,White,5
# 353,2,White,487
# 354,3,White,487
# 355,4,White,483
# 356,5,White,489
# 357,6,White,487
# 358,7,White,490
# 359,8,White,482
# 360,9,White,487
# 361,10,White,487
# 362,11,White,484
# 363,12,White,484
# 364,13,White,485
# 365,14,White,483
# 366,15,White,484
# 367,16,White,483
# 368,17,White,483
# 369,18,White,484
# 370,19,White,488
# 371,20,White,483
# 372,21,White,483
# 373,22,White,486
# 374,23,White,489
# 375,24,White,491
# 376,25,White,482
# 377,26,White,489
# 378,27,White,484
# 379,28,White,488
# 380,29,White,483
# 381,1,Red,485
# 382,2,Red,270
# 383,3,Red,267
# 384,4,Red,273
# 385,5,Red,274
# 386,6,Red,273
# 387,7,Red,266
# 388,8,Red,272
# 389,9,Red,269
# 390,10,Red,266
# 391,11,Red,275
# 392,12,Red,268
# 393,13,Red,271
# 394,14,Red,270
# 395,15,Red,270
# 396,16,Red,270
# 397,17,Red,267
# 398,18,Red,273
# 399,19,Red,264
# 400,20,Red,271
# 401,21,Red,273
# 402,22,Red,267
# 403,23,Red,267
# 404,24,Red,268
# 405,25,Red,268
# 406,26,Red,272
# 407,27,Red,266
# 408,28,Red,268
# 409,29,Red,267
# 410,1,Green,271
# 411,2,Green,175
# 412,3,Green,174
# 413,4,Green,178
# 414,5,Green,175
# 415,6,Green,176
# 416,7,Green,176
# 417,8,Green,177
# 418,9,Green,173
# 419,10,Green,177
# 420,11,Green,180
# 421,12,Green,178
# 422,13,Green,176
# 423,14,Green,175
# 424,15,Green,178
# 425,16,Green,179
# 426,17,Green,176
# 427,18,Green,177
# 428,19,Green,177
# 429,20,Green,177
# 430,21,Green,173
# 431,22,Green,173
# 432,23,Green,173
# 433,24,Green,176
# 434,25,Green,179
# 435,26,Green,174
# 436,27,Green,176
# 437,28,Green,172
# 438,29,Green,176
# 439,30,Green,178
# 440,1,Blue,176
# 441,2,Blue,58
# 442,3,Blue,57
# 443,4,Blue,58
# 444,5,Blue,55
# 445,6,Blue,54
# 446,7,Blue,56
# 447,8,Blue,53
# 448,9,Blue,55
# 449,10,Blue,53
# 450,11,Blue,54
# 451,12,Blue,54
# 452,13,Blue,58
# 453,14,Blue,57
# 454,15,Blue,53
# 455,16,Blue,54
# 456,17,Blue,57
# 457,18,Blue,53
# 458,19,Blue,53
# 459,20,Blue,54
# 460,21,Blue,57
# 461,22,Blue,54
# 462,23,Blue,56
# 463,24,Blue,52
# 464,25,Blue,57
# 465,26,Blue,58
# 466,27,Blue,54
# 467,28,Blue,56
# 468,29,Blue,58
# 469,1,Black,54
# 470,2,Black,4
# 471,3,Black,4
# 472,4,Black,5
# 473,5,Black,4
# 474,6,Black,4
# 475,7,Black,4
# 476,8,Black,5
# 477,9,Black,4
# 478,10,Black,4
# 479,11,Black,5
# 480,12,Black,4
# 481,13,Black,5
# 482,14,Black,4
# 483,15,Black,4
# 484,16,Black,4
# 485,17,Black,4
# 486,18,Black,4
# 487,19,Black,4
# 488,20,Black,5
# 489,21,Black,4
# 490,22,Black,5
# 491,23,Black,5
# 492,24,Black,4
# 493,25,Black,5
# 494,26,Black,5
# 495,27,Black,4
# 496,28,Black,4
# 497,29,Black,5
# 498,0,Black,4
# 499,0,Black,4
# 500,0,Black,4
# 501,0,Black,4
# 502,0,Black,4
# 503,0,Black,4
# 504,0,Black,4
# 505,0,Black,4
# 506,0,Black,4
# 507,0,Black,5
# 508,0,Black,4
# 509,0,Black,4
# 510,0,Black,5
# 511,0,Black,4
# 512,0,Black,4
# 513,0,Black,5
# 514,0,Black,4
# 515,0,Black,4
# 516,0,Black,5
# 517,0,Black,4
# 518,0,Black,4
# 519,0,Black,4
# 520,0,Black,4
# 521,0,Black,5
# 522,0,Black,4
# 523,0,Black,4
# 524,0,Black,5
# 525,0,Black,4
# 526,0,Black,4
# 527,1,White,5
# 528,2,White,484
# 529,3,White,480
# 530,4,White,487
# 531,5,White,480
# 532,6,White,482
# 533,7,White,485
# 534,8,White,476
# 535,9,White,482
# 536,10,White,489
# 537,11,White,480
# 538,12,White,488
# 539,13,White,479
# 540,14,White,486
# 541,15,White,486
# 542,16,White,487
# 543,17,White,477
# 544,18,White,484
# 545,19,White,478
# 546,20,White,484
# 547,21,White,482
# 548,22,White,482
# 549,23,White,476
# 550,24,White,477
# 551,25,White,482
# 552,26,White,488
# 553,27,White,486
# 554,28,White,481
# 555,29,White,486
# 556,30,White,482
# 557,1,Red,489
# 558,2,Red,268
# 559,3,Red,268
# 560,4,Red,269
# 561,5,Red,270
# 562,6,Red,266
# 563,7,Red,269
# 564,8,Red,267
# 565,9,Red,269
# 566,10,Red,268
# 567,11,Red,272
# 568,12,Red,266
# 569,13,Red,269
# 570,14,Red,272
# 571,15,Red,267
# 572,16,Red,269
# 573,17,Red,273
# 574,18,Red,269
# 575,19,Red,267
# 576,20,Red,268
# 577,21,Red,271
# 578,22,Red,266
# 579,23,Red,271
# 580,24,Red,271
# 581,25,Red,268
# 582,26,Red,272
# 583,27,Red,269
# 584,28,Red,271
# 585,29,Red,266
# 586,1,Green,274
# 587,2,Green,179
# 588,3,Green,175
# 589,4,Green,176
# 590,5,Green,174
# 591,6,Green,180
# 592,7,Green,178
# 593,8,Green,177
# 594,9,Green,174
# 595,10,Green,174
# 596,11,Green,176
# 597,12,Green,175
# 598,13,Green,174
# 599,14,Green,172
# 600,15,Green,177
# 601,16,Green,175
# 602,17,Green,182
# 603,18,Green,180
# 604,19,Green,175
# 605,20,Green,176
# 606,21,Green,179
# 607,22,Green,176
# 608,23,Green,180
# 609,24,Green,174
# 610,25,Green,182
# 611,26,Green,173
# 612,27,Green,177
# 613,28,Green,179
# 614,29,Green,174
# 615,1,Blue,177
# 616,2,Blue,52
# 617,3,Blue,55
# 618,4,Blue,58
# 619,5,Blue,53
# 620,6,Blue,57
# 621,7,Blue,55
# 622,8,Blue,56
# 623,9,Blue,58
# 624,10,Blue,56
# 625,11,Blue,57
# 626,12,Blue,57
# 627,13,Blue,58
# 628,14,Blue,56
# 629,15,Blue,52
# 630,16,Blue,56
# 631,17,Blue,53
# 632,18,Blue,55
# 633,19,Blue,57
# 634,20,Blue,57
# 635,21,Blue,52
# 636,22,Blue,57
# 637,23,Blue,51
# 638,24,Blue,57
# 639,25,Blue,55
# 640,26,Blue,57
# 641,27,Blue,53
# 642,28,Blue,57
# 643,29,Blue,54
# 644,1,Black,55
# 645,2,Black,5
# 646,3,Black,4
# 647,4,Black,4
# 648,5,Black,4
# 649,6,Black,4
# 650,7,Black,5
# 651,8,Black,4
# 652,9,Black,5
# 653,10,Black,4
# 654,11,Black,5
# 655,12,Black,5
# 656,13,Black,5
# 657,14,Black,4
# 658,15,Black,4
# 659,16,Black,5
# 660,17,Black,4
# 661,18,Black,5
# 662,19,Black,5
# 663,20,Black,4
# 664,21,Black,4
# 665,22,Black,4
# 666,23,Black,4
# 667,24,Black,4
# 668,25,Black,4
# 669,26,Black,4
# 670,27,Black,4
# 671,28,Black,5
# 672,29,Black,4
# 673,30,Black,4
# 674,0,Black,4
# 675,0,Black,5
# 676,0,Black,4
# 677,0,Black,5
# 678,0,Black,5
# 679,0,Black,5
# 680,0,Black,5
#
# ==================================================

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "NdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Load the CSV file
    df = pd.read_csv(file_path)

    # Convert the 'Intensity' column to integers
    df['Intensity'] = df['Intensity'].astype(int)

    # Save the modified DataFrame back to the CSV file
    df.to_csv(file_path, index=False)

    # Print a confirmation message for each file
    print(f"Modified DataFrame saved to {file_path}")

print("All CSV files in the 'NdatasetCSV' folder have been processed.")
# Out:
# Modified DataFrame saved to NdatasetCSV/N10_blank.csv
# Modified DataFrame saved to NdatasetCSV/N10_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N4_blank.csv
# Modified DataFrame saved to NdatasetCSV/N20_R.csv
# Modified DataFrame saved to NdatasetCSV/N10_WR.csv
# Modified DataFrame saved to NdatasetCSV/N2n_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N20_A.csv
# Modified DataFrame saved to NdatasetCSV/N20_W.csv
# Modified DataFrame saved to NdatasetCSV/N80_WR.csv
# Modified DataFrame saved to NdatasetCSV/N100_blank.csv
# Modified DataFrame saved to NdatasetCSV/N20_B.csv
# Modified DataFrame saved to NdatasetCSV/N40_blank.csv
# Modified DataFrame saved to NdatasetCSV/N2_blank.csv
# Modified DataFrame saved to NdatasetCSV/N2_W.csv
# Modified DataFrame saved to NdatasetCSV/N8_blank.csv
# Modified DataFrame saved to NdatasetCSV/N40_R.csv
# Modified DataFrame saved to NdatasetCSV/N80_R.csv
# Modified DataFrame saved to NdatasetCSV/N60_W.csv
# Modified DataFrame saved to NdatasetCSV/N2n_R.csv
# Modified DataFrame saved to NdatasetCSV/N8_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N6_R.csv
# Modified DataFrame saved to NdatasetCSV/N60_A.csv
# Modified DataFrame saved to NdatasetCSV/N2_A.csv
# Modified DataFrame saved to NdatasetCSV/N4_R.csv
# Modified DataFrame saved to NdatasetCSV/N60_B.csv
# Modified DataFrame saved to NdatasetCSV/N2_B.csv
# Modified DataFrame saved to NdatasetCSV/N6_B.csv
# Modified DataFrame saved to NdatasetCSV/N2n_blank.csv
# Modified DataFrame saved to NdatasetCSV/N4_W.csv
# Modified DataFrame saved to NdatasetCSV/N2n_B.csv
# Modified DataFrame saved to NdatasetCSV/N4_A.csv
# Modified DataFrame saved to NdatasetCSV/N80_B.csv
# Modified DataFrame saved to NdatasetCSV/N100_WR.csv
# Modified DataFrame saved to NdatasetCSV/N40_B.csv
# Modified DataFrame saved to NdatasetCSV/N2n_WR.csv
# Modified DataFrame saved to NdatasetCSV/N60_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N60_blank.csv
# Modified DataFrame saved to NdatasetCSV/N2_R.csv
# Modified DataFrame saved to NdatasetCSV/N40_W.csv
# Modified DataFrame saved to NdatasetCSV/N20_WR.csv
# Modified DataFrame saved to NdatasetCSV/N60_R.csv
# Modified DataFrame saved to NdatasetCSV/N6_A.csv
# Modified DataFrame saved to NdatasetCSV/N80_W.csv
# Modified DataFrame saved to NdatasetCSV/N4_B.csv
# Modified DataFrame saved to NdatasetCSV/N2n_W.csv
# Modified DataFrame saved to NdatasetCSV/N6_W.csv
# Modified DataFrame saved to NdatasetCSV/N80_A.csv
# Modified DataFrame saved to NdatasetCSV/N40_A.csv
# Modified DataFrame saved to NdatasetCSV/N8_B.csv
# Modified DataFrame saved to NdatasetCSV/N6_WR.csv
# Modified DataFrame saved to NdatasetCSV/N10_W.csv
# Modified DataFrame saved to NdatasetCSV/N10_A.csv
# Modified DataFrame saved to NdatasetCSV/N80_blank.csv
# Modified DataFrame saved to NdatasetCSV/N8_A.csv
# Modified DataFrame saved to NdatasetCSV/N10_B.csv
# Modified DataFrame saved to NdatasetCSV/N8_W.csv
# Modified DataFrame saved to NdatasetCSV/N6_blank.csv
# Modified DataFrame saved to NdatasetCSV/N20_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N4_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N8_R.csv
# Modified DataFrame saved to NdatasetCSV/N4_WR.csv
# Modified DataFrame saved to NdatasetCSV/N80_NoR.csv
# Modified DataFrame saved to NdatasetCSV/BG_1.csv
# Modified DataFrame saved to NdatasetCSV/N8_WR.csv
# Modified DataFrame saved to NdatasetCSV/N10_R.csv
# Modified DataFrame saved to NdatasetCSV/N60_WR.csv
# Modified DataFrame saved to NdatasetCSV/BG_0.csv
# Modified DataFrame saved to NdatasetCSV/N40_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N6_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N100_R.csv
# Modified DataFrame saved to NdatasetCSV/N40_WR.csv
# Modified DataFrame saved to NdatasetCSV/N20_blank.csv
# Modified DataFrame saved to NdatasetCSV/N100_NoR.csv
# Modified DataFrame saved to NdatasetCSV/N100_W.csv
# Modified DataFrame saved to NdatasetCSV/N2_WR.csv
# Modified DataFrame saved to NdatasetCSV/N100_A.csv
# Modified DataFrame saved to NdatasetCSV/N100_B.csv
# All CSV files in the 'NdatasetCSV' folder have been processed.

# %%
import os
import pandas as pd

# Specify the folder path
folder_path = "NdatasetCSV"

# List all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

# Iterate through each CSV file and process it
for csv_file in csv_files:
    # Construct the full file path
    file_path = os.path.join(folder_path, csv_file)

    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Filter and remove rows where 'Order' is in the specified values (1,2,3,4,5,25,26, 27, 28, 29, 30)
    df = df[~df['Order'].isin([1,2,3,4,5,25,26, 27, 28, 29, 30])]

    # Save the modified DataFrame back to the same file
    df.to_csv(file_path, index=False)

    # Report the file name and the number of rows after the removal
    print(f"File: {csv_file}, Rows After Removal: {len(df)}")
# Out:
# File: N10_blank.csv, Rows After Removal: 380
# File: N10_NoR.csv, Rows After Removal: 380
# File: N4_blank.csv, Rows After Removal: 380
# File: N20_R.csv, Rows After Removal: 380
# File: N10_WR.csv, Rows After Removal: 380
# File: N2n_NoR.csv, Rows After Removal: 380
# File: N20_A.csv, Rows After Removal: 380
# File: N20_W.csv, Rows After Removal: 380
# File: N80_WR.csv, Rows After Removal: 380
# File: N100_blank.csv, Rows After Removal: 380
# File: N20_B.csv, Rows After Removal: 380
# File: N40_blank.csv, Rows After Removal: 380
# File: N2_blank.csv, Rows After Removal: 380
# File: N2_W.csv, Rows After Removal: 380
# File: N8_blank.csv, Rows After Removal: 380
# File: N40_R.csv, Rows After Removal: 380
# File: N80_R.csv, Rows After Removal: 380
# File: N60_W.csv, Rows After Removal: 380
# File: N2n_R.csv, Rows After Removal: 380
# File: N8_NoR.csv, Rows After Removal: 380
# File: N6_R.csv, Rows After Removal: 380
# File: N60_A.csv, Rows After Removal: 380
# File: N2_A.csv, Rows After Removal: 380
# File: N4_R.csv, Rows After Removal: 380
# File: N60_B.csv, Rows After Removal: 380
# File: N2_B.csv, Rows After Removal: 380
# File: N6_B.csv, Rows After Removal: 380
# File: N2n_blank.csv, Rows After Removal: 380
# File: N4_W.csv, Rows After Removal: 380
# File: N2n_B.csv, Rows After Removal: 380
# File: N4_A.csv, Rows After Removal: 380
# File: N80_B.csv, Rows After Removal: 380
# File: N100_WR.csv, Rows After Removal: 380
# File: N40_B.csv, Rows After Removal: 380
# File: N2n_WR.csv, Rows After Removal: 380
# File: N60_NoR.csv, Rows After Removal: 380
# File: N60_blank.csv, Rows After Removal: 380
# File: N2_R.csv, Rows After Removal: 380
# File: N40_W.csv, Rows After Removal: 380
# File: N20_WR.csv, Rows After Removal: 380
# File: N60_R.csv, Rows After Removal: 380
# File: N6_A.csv, Rows After Removal: 380
# File: N80_W.csv, Rows After Removal: 380
# File: N4_B.csv, Rows After Removal: 380
# File: N2n_W.csv, Rows After Removal: 380
# File: N6_W.csv, Rows After Removal: 380
# File: N80_A.csv, Rows After Removal: 380
# File: N40_A.csv, Rows After Removal: 380
# File: N8_B.csv, Rows After Removal: 380
# File: N6_WR.csv, Rows After Removal: 380
# File: N10_W.csv, Rows After Removal: 380
# File: N10_A.csv, Rows After Removal: 380
# File: N80_blank.csv, Rows After Removal: 380
# File: N8_A.csv, Rows After Removal: 380
# File: N10_B.csv, Rows After Removal: 380
# File: N8_W.csv, Rows After Removal: 380
# File: N6_blank.csv, Rows After Removal: 380
# File: N20_NoR.csv, Rows After Removal: 380
# File: N4_NoR.csv, Rows After Removal: 380
# File: N8_R.csv, Rows After Removal: 380
# File: N4_WR.csv, Rows After Removal: 380
# File: N80_NoR.csv, Rows After Removal: 380
# File: BG_1.csv, Rows After Removal: 379
# File: N8_WR.csv, Rows After Removal: 380
# File: N10_R.csv, Rows After Removal: 380
# File: N60_WR.csv, Rows After Removal: 380
# File: BG_0.csv, Rows After Removal: 379
# File: N40_NoR.csv, Rows After Removal: 380
# File: N6_NoR.csv, Rows After Removal: 380
# File: N100_R.csv, Rows After Removal: 380
# File: N40_WR.csv, Rows After Removal: 380
# File: N20_blank.csv, Rows After Removal: 380
# File: N100_NoR.csv, Rows After Removal: 380
# File: N100_W.csv, Rows After Removal: 380
# File: N2_WR.csv, Rows After Removal: 380
# File: N100_A.csv, Rows After Removal: 380
# File: N100_B.csv, Rows After Removal: 380
